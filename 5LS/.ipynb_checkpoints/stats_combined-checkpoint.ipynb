# %%
import pandas as pd

df = pd.read_csv('All Indices 5LS V_1.1.csv')
df
# Out:
#        Unnamed: 0        Date Position       Type      Expiry      Index  \
# 0               0  2017-01-05   CLOSED   STRADDLE  2017-01-05  BANKNIFTY
# 1               1  2017-01-05   CLOSED   STRADDLE  2017-01-05  BANKNIFTY
# 2               2  2017-01-05   CLOSED   STRADDLE  2017-01-05  BANKNIFTY
# 3               3  2017-01-05   CLOSED   STRADDLE  2017-01-05  BANKNIFTY
# 4               4  2017-01-05   CLOSED   STRADDLE  2017-01-05  BANKNIFTY
# ...           ...         ...      ...        ...         ...        ...
# 12869       12869  2023-06-28   CLOSED   STRADDLE  2023-06-28      NIFTY
# 12870       12870  2023-06-28   CLOSED  REBALANCE  2023-06-28      NIFTY
# 12871       12871  2023-06-28   CLOSED  REBALANCE  2023-06-28      NIFTY
# 12872       12872  2023-06-28   CLOSED  REBALANCE  2023-06-28      NIFTY
# 12873       12873  2023-06-28   CLOSED  REBALANCE  2023-06-28      NIFTY
#
#       Contract Entry Time Exit Time  Entry Price  Exit Price    Quantity  \
# 0      18000CE   09:16:00  15:22:00        58.00      105.30 -166.666667
# 1      18000PE   09:16:00  15:22:00        50.00        0.05 -166.666667
# 2      17900PE   09:16:00  15:22:00        18.35        0.05 -167.597765
# 3      18200PE   09:16:00  15:22:00       192.55       73.45 -164.835165
# 4      17900CE   09:16:00  15:22:00       117.65      195.00 -167.597765
# ...        ...        ...       ...          ...         ...         ...
# 12869  18950PE        NaN       NaN     10000.00    10000.00 -158.311346
# 12870  19000CE        NaN       NaN     10000.00    10000.00 -157.894737
# 12871  19000PE        NaN       NaN     10000.00    10000.00 -157.894737
# 12872  19050CE        NaN       NaN     10000.00    10000.00 -157.480315
# 12873  19050PE        NaN       NaN     10000.00    10000.00 -157.480315
#
#                 PnL  Points       ROI             Datetime
# 0      -7883.333333  -47.30 -0.007883  2017-01-05 09:16:00
# 1       8325.000000   49.95  0.008325  2017-01-05 09:16:00
# 2       3067.039106   18.30  0.003067  2017-01-05 09:16:00
# 3      19631.868130  119.10  0.019632  2017-01-05 09:16:00
# 4     -12963.687150  -77.35 -0.012964  2017-01-05 09:16:00
# ...             ...     ...       ...                  ...
# 12869      0.000000    0.00  0.000000                  NaN
# 12870      0.000000    0.00  0.000000                  NaN
# 12871      0.000000    0.00  0.000000                  NaN
# 12872      0.000000    0.00  0.000000                  NaN
# 12873      0.000000    0.00  0.000000                  NaN
#
# [12874 rows x 16 columns]

# %%
import pandas as pd
df['Date'] = pd.to_datetime(df['Date'])
daily_pnl = df.groupby(df['Date'].dt.date)['PnL'].sum().reset_index()

# Rename the columns for clarity
daily_pnl.columns = ['Date', 'Total PnL']

daily_pnl["Date"] = pd.to_datetime(daily_pnl["Date"])
daily_pnl['Trade Year'] = daily_pnl['Date'].dt.year
daily_pnl["ROI"] = daily_pnl["Total PnL"]/10000
# If you want to ensure 'Date' column is in datetime format
daily_pnl['Date'] = pd.to_datetime(daily_pnl['Date'])

# Display the resulting DataFrame
print(daily_pnl)
# Out:
#           Date      Total PnL  Trade Year        ROI
# 0   2017-01-05   12307.858996        2017   1.230786
# 1   2017-01-12   14123.588630        2017   1.412359
# 2   2017-01-19   22752.070533        2017   2.275207
# 3   2017-01-25 -107865.464333        2017 -10.786546
# 4   2017-02-02   18876.716383        2017   1.887672
# ..         ...            ...         ...        ...
# 467 2024-03-19   43825.696563        2024   4.382570
# 468 2024-03-20  -74661.617093        2024  -7.466162
# 469 2024-03-21   16315.220508        2024   1.631522
# 470 2024-03-26   41330.203443        2024   4.133020
# 471 2024-03-28 -163761.392905        2024 -16.376139
#
# [472 rows x 4 columns]

# %%
# df["Date"] = pd.to_datetime(df["Date"])
# print(type(df["Date"]))
df['Trade Year'] = df['Date'].dt.year
df
# Out:
#        Unnamed: 0       Date Position       Type      Expiry      Index  \
# 0               0 2017-01-05   CLOSED   STRADDLE  2017-01-05  BANKNIFTY
# 1               1 2017-01-05   CLOSED   STRADDLE  2017-01-05  BANKNIFTY
# 2               2 2017-01-05   CLOSED   STRADDLE  2017-01-05  BANKNIFTY
# 3               3 2017-01-05   CLOSED   STRADDLE  2017-01-05  BANKNIFTY
# 4               4 2017-01-05   CLOSED   STRADDLE  2017-01-05  BANKNIFTY
# ...           ...        ...      ...        ...         ...        ...
# 12869       12869 2023-06-28   CLOSED   STRADDLE  2023-06-28      NIFTY
# 12870       12870 2023-06-28   CLOSED  REBALANCE  2023-06-28      NIFTY
# 12871       12871 2023-06-28   CLOSED  REBALANCE  2023-06-28      NIFTY
# 12872       12872 2023-06-28   CLOSED  REBALANCE  2023-06-28      NIFTY
# 12873       12873 2023-06-28   CLOSED  REBALANCE  2023-06-28      NIFTY
#
#       Contract Entry Time Exit Time  Entry Price  Exit Price    Quantity  \
# 0      18000CE   09:16:00  15:22:00        58.00      105.30 -166.666667
# 1      18000PE   09:16:00  15:22:00        50.00        0.05 -166.666667
# 2      17900PE   09:16:00  15:22:00        18.35        0.05 -167.597765
# 3      18200PE   09:16:00  15:22:00       192.55       73.45 -164.835165
# 4      17900CE   09:16:00  15:22:00       117.65      195.00 -167.597765
# ...        ...        ...       ...          ...         ...         ...
# 12869  18950PE        NaN       NaN     10000.00    10000.00 -158.311346
# 12870  19000CE        NaN       NaN     10000.00    10000.00 -157.894737
# 12871  19000PE        NaN       NaN     10000.00    10000.00 -157.894737
# 12872  19050CE        NaN       NaN     10000.00    10000.00 -157.480315
# 12873  19050PE        NaN       NaN     10000.00    10000.00 -157.480315
#
#                 PnL  Points       ROI             Datetime  Trade Year
# 0      -7883.333333  -47.30 -0.007883  2017-01-05 09:16:00        2017
# 1       8325.000000   49.95  0.008325  2017-01-05 09:16:00        2017
# 2       3067.039106   18.30  0.003067  2017-01-05 09:16:00        2017
# 3      19631.868130  119.10  0.019632  2017-01-05 09:16:00        2017
# 4     -12963.687150  -77.35 -0.012964  2017-01-05 09:16:00        2017
# ...             ...     ...       ...                  ...         ...
# 12869      0.000000    0.00  0.000000                  NaN        2023
# 12870      0.000000    0.00  0.000000                  NaN        2023
# 12871      0.000000    0.00  0.000000                  NaN        2023
# 12872      0.000000    0.00  0.000000                  NaN        2023
# 12873      0.000000    0.00  0.000000                  NaN        2023
#
# [12874 rows x 17 columns]

# %%
# df = daily_pnl
stats_ = pd.DataFrame(index=range(2017, 2024), columns=['Total ROI', 'Total Trades', 'Win Rate', 'Avg Profit% per Trade', 'Avg Loss% per Trade', 'Max Drawdown', 'ROI/DD Ratio'])
df['ROI'] = df['ROI']*100
# Iterate over each year
for year in range(2017, 2024):
    # Filter trades for the current year
    year_trades = df[(df['Trade Year'] == year)]
    
    # Calculate total ROI
    total_roi = year_trades['ROI'].sum()
    
    # Calculate total number of trades
    total_trades = len(year_trades)
    
    # Calculate win rate
    win_rate = (year_trades['ROI'] > 0).mean()*100
    
    # Calculate average profit per trade
    avg_profit = year_trades[year_trades['ROI'] > 0]['ROI'].mean()
    
    # Calculate average loss per trade
    avg_loss = year_trades[year_trades['ROI'] < 0]['ROI'].mean()
    
    # Calculate maximum drawdown
    max_drawdown = (year_trades['ROI'].cumsum() - year_trades['ROI'].cumsum().cummax()).min()
    
    # Calculate ROI/DD ratio
    roi_dd_ratio = total_roi / abs(max_drawdown)
    # 
    # Store the statistics in the DataFrame
    stats_.loc[year] = [total_roi, total_trades, win_rate, avg_profit, avg_loss, max_drawdown, roi_dd_ratio]

# Calculate overall statistics
overall_total_roi = stats_['Total ROI'].sum()
overall_total_trades = stats_['Total Trades'].sum()
overall_win_rate = (df['ROI'] > 0).mean() * 100
overall_avg_profit = df[df['ROI'] > 0]['ROI'].mean()
overall_avg_loss = df[df['ROI'] < 0]['ROI'].mean()
overall_max_drawdown = (df['ROI'].cumsum() - df['ROI'].cumsum().cummax()).min()
overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)

# Store the overall statistics in the DataFrame
stats_.loc['Overall'] = [overall_total_roi, overall_total_trades, overall_win_rate, overall_avg_profit, overall_avg_loss, overall_max_drawdown, overall_roi_dd_ratio]
stats_
# Out:
#           Total ROI Total Trades   Win Rate Avg Profit% per Trade  \
# 2017      23.633577          850  49.764706              0.542098
# 2018      58.520154          956  58.368201              0.662016
# 2019     110.768062         1560  59.615385              0.704935
# 2020      65.741197         1790  55.921788              1.074154
# 2021     128.172349         1966  56.663276              0.820903
# 2022      71.045976         2268  57.054674              0.744847
# 2023      42.984682         2676  57.511211              0.528033
# Overall  500.865996      12066.0  56.975299              0.726939
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio
# 2017              -0.779068   -19.632158      1.20382
# 2018              -0.885712   -11.840881     4.942213
# 2019              -0.917207   -20.584523     5.381133
# 2020              -1.386658   -63.755372     1.031148
# 2021              -0.951953   -18.490474     6.931804
# 2022              -0.920398   -25.581147     2.777279
# 2023              -0.704815    -27.10256     1.586001
# Overall           -0.939948   -63.755372      7.85606
