# %%
import asyncio
import datetime as dt
import math
from typing import Literal

import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

# %%
import sys

sys.path.append("..")
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
async def get_expiry(f_today, index):

    if index == 'bnf':    
        if (f_today <= dt.date(2024, 1, 25)) and (f_today >= dt.date(2024, 1, 18)):
            f_expiry = dt.date(2024, 1, 25)
        elif (f_today <= dt.date(2024, 1, 31)) and (f_today >= dt.date(2024, 1, 26)):
            f_expiry = dt.date(2024, 1, 31)
        elif (f_today <= dt.date(2024, 2, 22)) and (f_today >= dt.date(2024, 2, 29)):
            f_expiry = dt.date(2024, 2, 29)
        elif (f_today <= dt.date(2024, 3, 25)) and (f_today >= dt.date(2024, 3, 27)):
            f_expiry = dt.date(2024, 2, 27)
        elif f_today < dt.date(2023, 9, 1):
            days_to_thursday = (3 - f_today.weekday()) % 7
            nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
            f_expiry = nearest_thursday
            if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
                f_expiry = nearest_thursday - dt.timedelta(days=1)
        elif f_today >= dt.date(2023, 9, 1):
            if f_today.day < 24:
                days_to_wednesday = (2 - f_today.weekday()) % 7
                nearest_wednesday = f_today + dt.timedelta(days=days_to_wednesday)
                f_expiry = nearest_wednesday
                if nse.valid_days(
                    start_date=nearest_wednesday, end_date=nearest_wednesday
                ).empty:
                    f_expiry = nearest_wednesday - dt.timedelta(days=1)
            else:
                days_to_thursday = (3 - f_today.weekday()) % 7
                nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
                f_expiry = nearest_thursday
                if nse.valid_days(
                    start_date=nearest_thursday, end_date=nearest_thursday
                ).empty:
                    f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'nifty':
        days_to_thursday = (3 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'finnifty' or index == 'fnf':
        days_to_thursday = (1 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'midcpnifty' or index == 'midcp':
        days_to_thursday = (0 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

async def get_expiry_nifty(f_today):

    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry


async def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"


def get_option_contract_name2(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"

# %%
bnf_1min = pd.read_csv("../data/gold_4hr_tv (2).csv")
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["time"])
bnf_1min = bnf_1min[bnf_1min["datetime"].dt.year >= 2012]

# %%
bnf_1min.tail()
# Out:
#                            time   open   high    low  close  \
# 9361  2024-07-08T21:00:00+05:30  72650  72660  72130  72343
# 9362  2024-07-09T09:00:00+05:30  72577  72598  72310  72316
# 9363  2024-07-09T13:00:00+05:30  72327  72506  72311  72385
# 9364  2024-07-09T17:00:00+05:30  72377  72634  72111  72200
# 9365  2024-07-09T21:00:00+05:30  72217  72450  72191  72432
#
#                       datetime
# 9361 2024-07-08 21:00:00+05:30
# 9362 2024-07-09 09:00:00+05:30
# 9363 2024-07-09 13:00:00+05:30
# 9364 2024-07-09 17:00:00+05:30
# 9365 2024-07-09 21:00:00+05:30

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("open").first().alias("open"),
                pl.col("high").max().alias("high"),
                pl.col("low").min().alias("low"),
                pl.col("close").last().alias("close"),
                pl.col("volume").sum().alias("volume"),
            ]
        )
    )


# ohlc_resampled = resample(pl.DataFrame(bnf_1min), '7d', pd.Timedelta(days=4))
# ohlc_resampled

# %%
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["datetime"])
list_of_traded_dates = set(bnf_1min["datetime"].dt.date)
list_of_traded_dates
# Out:
# {datetime.date(2022, 1, 27),
#  datetime.date(2017, 1, 20),
#  datetime.date(2022, 8, 11),
#  datetime.date(2023, 2, 24),
#  datetime.date(2016, 10, 17),
#  datetime.date(2018, 7, 13),
#  datetime.date(2017, 5, 5),
#  datetime.date(2020, 6, 9),
#  datetime.date(2023, 3, 17),
#  datetime.date(2015, 3, 6),
#  datetime.date(2023, 5, 3),
#  datetime.date(2022, 5, 10),
#  datetime.date(2017, 2, 27),
#  datetime.date(2015, 6, 8),
#  datetime.date(2022, 8, 16),
#  datetime.date(2018, 1, 19),
#  datetime.date(2023, 5, 16),
#  datetime.date(2020, 1, 9),
#  datetime.date(2015, 3, 18),
#  datetime.date(2016, 8, 4),
#  datetime.date(2020, 11, 18),
#  datetime.date(2023, 9, 6),
#  datetime.date(2020, 8, 24),
#  datetime.date(2015, 10, 29),
#  datetime.date(2017, 2, 15),
#  datetime.date(2020, 1, 24),
#  datetime.date(2022, 1, 20),
#  datetime.date(2020, 7, 29),
#  datetime.date(2021, 11, 22),
#  datetime.date(2020, 3, 11),
#  datetime.date(2024, 1, 17),
#  datetime.date(2020, 6, 23),
#  datetime.date(2015, 7, 20),
#  datetime.date(2023, 2, 7),
#  datetime.date(2015, 12, 18),
#  datetime.date(2019, 9, 11),
#  datetime.date(2020, 7, 31),
#  datetime.date(2016, 8, 19),
#  datetime.date(2022, 6, 1),
#  datetime.date(2024, 3, 20),
#  datetime.date(2016, 11, 3),
#  datetime.date(2020, 8, 18),
#  datetime.date(2020, 3, 13),
#  datetime.date(2023, 8, 11),
#  datetime.date(2024, 6, 17),
#  datetime.date(2023, 8, 2),
#  datetime.date(2015, 10, 28),
#  datetime.date(2015, 6, 26),
#  datetime.date(2021, 5, 10),
#  datetime.date(2019, 2, 26),
#  datetime.date(2015, 5, 19),
#  datetime.date(2016, 1, 5),
#  datetime.date(2022, 7, 12),
#  datetime.date(2019, 9, 3),
#  datetime.date(2016, 11, 7),
#  datetime.date(2015, 10, 7),
#  datetime.date(2021, 8, 31),
#  datetime.date(2017, 2, 21),
#  datetime.date(2016, 9, 5),
#  datetime.date(2020, 7, 13),
#  datetime.date(2024, 5, 20),
#  datetime.date(2020, 7, 6),
#  datetime.date(2022, 11, 17),
#  datetime.date(2015, 8, 26),
#  datetime.date(2016, 12, 23),
#  datetime.date(2020, 9, 4),
#  datetime.date(2019, 5, 7),
#  datetime.date(2021, 8, 10),
#  datetime.date(2020, 5, 5),
#  datetime.date(2020, 9, 29),
#  datetime.date(2015, 11, 17),
#  datetime.date(2019, 8, 22),
#  datetime.date(2019, 1, 17),
#  datetime.date(2021, 4, 15),
#  datetime.date(2016, 5, 4),
#  datetime.date(2017, 5, 3),
#  datetime.date(2023, 5, 31),
#  datetime.date(2019, 2, 8),
#  datetime.date(2020, 10, 26),
#  datetime.date(2020, 8, 14),
#  datetime.date(2023, 11, 29),
#  datetime.date(2020, 9, 8),
#  datetime.date(2019, 7, 3),
#  datetime.date(2019, 4, 22),
#  datetime.date(2018, 2, 13),
#  datetime.date(2015, 4, 16),
#  datetime.date(2022, 10, 31),
#  datetime.date(2021, 2, 5),
#  datetime.date(2018, 1, 16),
#  datetime.date(2021, 12, 22),
#  datetime.date(2020, 6, 3),
#  datetime.date(2018, 12, 4),
#  datetime.date(2020, 5, 11),
#  datetime.date(2023, 3, 8),
#  datetime.date(2024, 6, 7),
#  datetime.date(2018, 6, 12),
#  datetime.date(2018, 8, 2),
#  datetime.date(2023, 5, 5),
#  datetime.date(2022, 8, 31),
#  datetime.date(2021, 4, 8),
#  datetime.date(2016, 11, 1),
#  datetime.date(2018, 5, 31),
#  datetime.date(2018, 7, 26),
#  datetime.date(2022, 5, 31),
#  datetime.date(2019, 10, 31),
#  datetime.date(2021, 1, 29),
#  datetime.date(2015, 6, 17),
#  datetime.date(2019, 1, 14),
#  datetime.date(2019, 7, 29),
#  datetime.date(2021, 12, 21),
#  datetime.date(2023, 11, 23),
#  datetime.date(2016, 12, 9),
#  datetime.date(2017, 8, 2),
#  datetime.date(2022, 12, 9),
#  datetime.date(2017, 11, 20),
#  datetime.date(2023, 9, 12),
#  datetime.date(2019, 10, 16),
#  datetime.date(2023, 5, 18),
#  datetime.date(2016, 12, 8),
#  datetime.date(2019, 12, 3),
#  datetime.date(2023, 3, 10),
#  datetime.date(2016, 3, 31),
#  datetime.date(2019, 5, 3),
#  datetime.date(2022, 3, 25),
#  datetime.date(2023, 3, 21),
#  datetime.date(2018, 2, 19),
#  datetime.date(2020, 4, 22),
#  datetime.date(2019, 9, 13),
#  datetime.date(2023, 10, 23),
#  datetime.date(2016, 4, 26),
#  datetime.date(2017, 6, 15),
#  datetime.date(2022, 6, 6),
#  datetime.date(2020, 12, 23),
#  datetime.date(2023, 7, 12),
#  datetime.date(2015, 5, 14),
#  datetime.date(2022, 11, 9),
#  datetime.date(2017, 12, 28),
#  datetime.date(2024, 4, 9),
#  datetime.date(2019, 10, 9),
#  datetime.date(2018, 12, 28),
#  datetime.date(2022, 9, 28),
#  datetime.date(2017, 10, 18),
#  datetime.date(2020, 8, 25),
#  datetime.date(2016, 1, 19),
#  datetime.date(2023, 10, 24),
#  datetime.date(2022, 5, 16),
#  datetime.date(2015, 7, 30),
#  datetime.date(2020, 8, 27),
#  datetime.date(2021, 6, 21),
#  datetime.date(2016, 5, 25),
#  datetime.date(2021, 11, 18),
#  datetime.date(2022, 8, 23),
#  datetime.date(2018, 6, 19),
#  datetime.date(2018, 8, 30),
#  datetime.date(2022, 6, 8),
#  datetime.date(2020, 5, 15),
#  datetime.date(2022, 1, 4),
#  datetime.date(2024, 1, 12),
#  datetime.date(2022, 1, 12),
#  datetime.date(2021, 7, 30),
#  datetime.date(2019, 9, 30),
#  datetime.date(2021, 7, 15),
#  datetime.date(2016, 6, 29),
#  datetime.date(2021, 8, 6),
#  datetime.date(2017, 5, 23),
#  datetime.date(2019, 6, 13),
#  datetime.date(2018, 2, 27),
#  datetime.date(2023, 5, 25),
#  datetime.date(2021, 4, 28),
#  datetime.date(2020, 4, 21),
#  datetime.date(2015, 3, 2),
#  datetime.date(2023, 11, 16),
#  datetime.date(2016, 2, 5),
#  datetime.date(2022, 11, 3),
#  datetime.date(2016, 1, 11),
#  datetime.date(2018, 12, 31),
#  datetime.date(2016, 10, 25),
#  datetime.date(2023, 11, 1),
#  datetime.date(2023, 6, 6),
#  datetime.date(2015, 6, 9),
#  datetime.date(2019, 2, 12),
#  datetime.date(2023, 12, 15),
#  datetime.date(2023, 8, 1),
#  datetime.date(2019, 2, 20),
#  datetime.date(2017, 12, 14),
#  datetime.date(2017, 2, 28),
#  datetime.date(2022, 1, 3),
#  datetime.date(2017, 3, 27),
#  datetime.date(2015, 6, 12),
#  datetime.date(2020, 4, 23),
#  datetime.date(2019, 9, 10),
#  datetime.date(2016, 8, 10),
#  datetime.date(2019, 2, 7),
#  datetime.date(2024, 4, 29),
#  datetime.date(2022, 3, 31),
#  datetime.date(2018, 2, 22),
#  datetime.date(2018, 10, 18),
#  datetime.date(2018, 1, 8),
#  datetime.date(2016, 11, 4),
#  datetime.date(2024, 4, 10),
#  datetime.date(2020, 8, 7),
#  datetime.date(2022, 4, 5),
#  datetime.date(2018, 3, 8),
#  datetime.date(2017, 11, 21),
#  datetime.date(2022, 12, 5),
#  datetime.date(2020, 1, 3),
#  datetime.date(2017, 9, 5),
#  datetime.date(2024, 4, 8),
#  datetime.date(2019, 1, 29),
#  datetime.date(2023, 11, 22),
#  datetime.date(2018, 11, 29),
#  datetime.date(2015, 9, 16),
#  datetime.date(2021, 1, 7),
#  datetime.date(2016, 7, 19),
#  datetime.date(2020, 4, 27),
#  datetime.date(2017, 11, 29),
#  datetime.date(2023, 9, 29),
#  datetime.date(2016, 10, 30),
#  datetime.date(2019, 9, 27),
#  datetime.date(2024, 2, 15),
#  datetime.date(2017, 3, 24),
#  datetime.date(2015, 7, 10),
#  datetime.date(2020, 6, 19),
#  datetime.date(2022, 3, 11),
#  datetime.date(2022, 8, 19),
#  datetime.date(2017, 1, 17),
#  datetime.date(2021, 2, 15),
#  datetime.date(2022, 1, 7),
#  datetime.date(2015, 7, 31),
#  datetime.date(2021, 5, 31),
#  datetime.date(2022, 3, 17),
#  datetime.date(2018, 10, 8),
#  datetime.date(2018, 6, 8),
#  datetime.date(2021, 7, 23),
#  datetime.date(2017, 10, 27),
#  datetime.date(2019, 11, 6),
#  datetime.date(2017, 12, 6),
#  datetime.date(2015, 10, 23),
#  datetime.date(2022, 9, 21),
#  datetime.date(2015, 5, 4),
#  datetime.date(2023, 12, 29),
#  datetime.date(2018, 9, 20),
#  datetime.date(2022, 4, 27),
#  datetime.date(2016, 8, 26),
#  datetime.date(2018, 6, 13),
#  datetime.date(2018, 7, 10),
#  datetime.date(2019, 5, 15),
#  datetime.date(2021, 6, 4),
#  datetime.date(2018, 8, 7),
#  datetime.date(2018, 7, 17),
#  datetime.date(2018, 9, 18),
#  datetime.date(2021, 9, 27),
#  datetime.date(2023, 7, 24),
#  datetime.date(2015, 11, 25),
#  datetime.date(2020, 3, 31),
#  datetime.date(2019, 5, 9),
#  datetime.date(2024, 5, 28),
#  datetime.date(2018, 10, 16),
#  datetime.date(2021, 3, 18),
#  datetime.date(2022, 10, 24),
#  datetime.date(2015, 7, 16),
#  datetime.date(2021, 6, 9),
#  datetime.date(2016, 6, 10),
#  datetime.date(2016, 9, 27),
#  datetime.date(2021, 2, 16),
#  datetime.date(2021, 4, 19),
#  datetime.date(2016, 4, 8),
#  datetime.date(2019, 2, 14),
#  datetime.date(2020, 7, 15),
#  datetime.date(2015, 12, 17),
#  datetime.date(2015, 12, 28),
#  datetime.date(2018, 11, 21),
#  datetime.date(2022, 7, 11),
#  datetime.date(2023, 7, 28),
#  datetime.date(2021, 11, 24),
#  datetime.date(2018, 8, 20),
#  datetime.date(2020, 5, 6),
#  datetime.date(2022, 1, 31),
#  datetime.date(2017, 2, 9),
#  datetime.date(2021, 9, 20),
#  datetime.date(2017, 7, 13),
#  datetime.date(2016, 12, 19),
#  datetime.date(2019, 8, 14),
#  datetime.date(2015, 7, 14),
#  datetime.date(2024, 3, 18),
#  datetime.date(2022, 11, 14),
#  datetime.date(2020, 1, 1),
#  datetime.date(2016, 12, 26),
#  datetime.date(2015, 10, 12),
#  datetime.date(2020, 11, 2),
#  datetime.date(2021, 5, 19),
#  datetime.date(2019, 3, 19),
#  datetime.date(2022, 6, 28),
#  datetime.date(2016, 5, 16),
#  datetime.date(2022, 10, 6),
#  datetime.date(2023, 4, 24),
#  datetime.date(2023, 4, 21),
#  datetime.date(2015, 12, 29),
#  datetime.date(2016, 5, 31),
#  datetime.date(2019, 1, 4),
#  datetime.date(2023, 1, 2),
#  datetime.date(2015, 12, 21),
#  datetime.date(2018, 9, 19),
#  datetime.date(2021, 9, 3),
#  datetime.date(2024, 6, 26),
#  datetime.date(2022, 9, 16),
#  datetime.date(2024, 2, 19),
#  datetime.date(2018, 5, 10),
#  datetime.date(2021, 7, 14),
#  datetime.date(2016, 5, 11),
#  datetime.date(2017, 1, 2),
#  datetime.date(2024, 7, 8),
#  datetime.date(2019, 11, 1),
#  datetime.date(2016, 10, 18),
#  datetime.date(2021, 7, 13),
#  datetime.date(2017, 2, 1),
#  datetime.date(2019, 10, 25),
#  datetime.date(2022, 4, 22),
#  datetime.date(2024, 2, 27),
#  datetime.date(2019, 3, 12),
#  datetime.date(2024, 3, 28),
#  datetime.date(2016, 6, 24),
#  datetime.date(2021, 12, 16),
#  datetime.date(2017, 9, 25),
#  datetime.date(2016, 10, 4),
#  datetime.date(2018, 5, 23),
#  datetime.date(2019, 12, 4),
#  datetime.date(2019, 12, 5),
#  datetime.date(2023, 8, 4),
#  datetime.date(2023, 12, 13),
#  datetime.date(2024, 1, 23),
#  datetime.date(2015, 12, 2),
#  datetime.date(2023, 1, 20),
#  datetime.date(2015, 6, 15),
#  datetime.date(2022, 8, 3),
#  datetime.date(2016, 3, 8),
#  datetime.date(2016, 7, 4),
#  datetime.date(2024, 1, 19),
#  datetime.date(2018, 7, 12),
#  datetime.date(2020, 8, 17),
#  datetime.date(2017, 7, 17),
#  datetime.date(2022, 4, 20),
#  datetime.date(2015, 10, 22),
#  datetime.date(2016, 2, 26),
#  datetime.date(2017, 3, 21),
#  datetime.date(2024, 3, 14),
#  datetime.date(2023, 6, 21),
#  datetime.date(2015, 11, 27),
#  datetime.date(2015, 6, 11),
#  datetime.date(2018, 8, 14),
#  datetime.date(2024, 4, 12),
#  datetime.date(2020, 3, 16),
#  datetime.date(2016, 1, 1),
#  datetime.date(2023, 1, 25),
#  datetime.date(2020, 5, 19),
#  datetime.date(2022, 3, 24),
#  datetime.date(2015, 11, 16),
#  datetime.date(2020, 3, 12),
#  datetime.date(2021, 10, 22),
#  datetime.date(2022, 7, 26),
#  datetime.date(2017, 11, 30),
#  datetime.date(2019, 7, 8),
#  datetime.date(2022, 12, 26),
#  datetime.date(2020, 2, 5),
#  datetime.date(2017, 8, 23),
#  datetime.date(2018, 9, 13),
#  datetime.date(2018, 4, 2),
#  datetime.date(2016, 5, 3),
#  datetime.date(2020, 7, 27),
#  datetime.date(2020, 11, 14),
#  datetime.date(2022, 3, 16),
#  datetime.date(2021, 2, 26),
#  datetime.date(2020, 7, 21),
#  datetime.date(2021, 4, 9),
#  datetime.date(2015, 6, 3),
#  datetime.date(2020, 3, 9),
#  datetime.date(2021, 5, 25),
#  datetime.date(2024, 7, 4),
#  datetime.date(2019, 10, 8),
#  datetime.date(2021, 11, 16),
#  datetime.date(2021, 9, 24),
#  datetime.date(2022, 1, 17),
#  datetime.date(2017, 10, 20),
#  datetime.date(2020, 7, 16),
#  datetime.date(2020, 9, 11),
#  datetime.date(2023, 11, 2),
#  datetime.date(2017, 7, 11),
#  datetime.date(2017, 8, 16),
#  datetime.date(2016, 3, 1),
#  datetime.date(2021, 11, 15),
#  datetime.date(2017, 7, 4),
#  datetime.date(2016, 12, 15),
#  datetime.date(2016, 12, 13),
#  datetime.date(2016, 11, 29),
#  datetime.date(2022, 8, 10),
#  datetime.date(2017, 5, 4),
#  datetime.date(2019, 11, 22),
#  datetime.date(2021, 1, 27),
#  datetime.date(2017, 9, 7),
#  datetime.date(2021, 2, 8),
#  datetime.date(2018, 12, 24),
#  datetime.date(2019, 5, 10),
#  datetime.date(2020, 5, 12),
#  datetime.date(2017, 4, 4),
#  datetime.date(2024, 5, 7),
#  datetime.date(2021, 5, 7),
#  datetime.date(2023, 9, 19),
#  datetime.date(2020, 1, 28),
#  datetime.date(2022, 8, 5),
#  datetime.date(2020, 6, 29),
#  datetime.date(2024, 4, 22),
#  datetime.date(2023, 7, 13),
#  datetime.date(2019, 7, 24),
#  datetime.date(2022, 11, 7),
#  datetime.date(2016, 12, 20),
#  datetime.date(2016, 2, 15),
#  datetime.date(2017, 12, 11),
#  datetime.date(2022, 10, 17),
#  datetime.date(2023, 10, 10),
#  datetime.date(2016, 2, 9),
#  datetime.date(2023, 4, 17),
#  datetime.date(2017, 10, 3),
#  datetime.date(2021, 12, 20),
#  datetime.date(2020, 6, 15),
#  datetime.date(2023, 7, 11),
#  datetime.date(2021, 1, 12),
#  datetime.date(2020, 9, 9),
#  datetime.date(2020, 6, 10),
#  datetime.date(2015, 6, 16),
#  datetime.date(2017, 7, 19),
#  datetime.date(2018, 11, 12),
#  datetime.date(2015, 8, 31),
#  datetime.date(2023, 9, 18),
#  datetime.date(2019, 1, 31),
#  datetime.date(2024, 5, 1),
#  datetime.date(2018, 3, 26),
#  datetime.date(2018, 9, 6),
#  datetime.date(2019, 10, 4),
#  datetime.date(2020, 9, 2),
#  datetime.date(2015, 12, 22),
#  datetime.date(2021, 9, 7),
#  datetime.date(2019, 2, 13),
#  datetime.date(2023, 3, 15),
#  datetime.date(2018, 3, 14),
#  datetime.date(2021, 9, 23),
#  datetime.date(2024, 6, 28),
#  datetime.date(2017, 6, 22),
#  datetime.date(2023, 8, 31),
#  datetime.date(2017, 3, 6),
#  datetime.date(2023, 9, 22),
#  datetime.date(2020, 2, 17),
#  datetime.date(2018, 7, 23),
#  datetime.date(2021, 2, 22),
#  datetime.date(2023, 7, 5),
#  datetime.date(2022, 8, 17),
#  datetime.date(2020, 6, 30),
#  datetime.date(2015, 7, 9),
#  datetime.date(2019, 8, 28),
#  datetime.date(2019, 9, 24),
#  datetime.date(2023, 9, 5),
#  datetime.date(2016, 6, 15),
#  datetime.date(2016, 10, 10),
#  datetime.date(2023, 7, 17),
#  datetime.date(2023, 9, 21),
#  datetime.date(2016, 11, 16),
#  datetime.date(2015, 10, 8),
#  datetime.date(2022, 12, 1),
#  datetime.date(2020, 11, 30),
#  datetime.date(2024, 3, 11),
#  datetime.date(2017, 12, 12),
#  datetime.date(2018, 3, 20),
#  datetime.date(2017, 5, 9),
#  datetime.date(2018, 3, 7),
#  datetime.date(2017, 7, 6),
#  datetime.date(2015, 10, 16),
#  datetime.date(2022, 4, 19),
#  datetime.date(2016, 2, 17),
#  datetime.date(2015, 7, 17),
#  datetime.date(2020, 8, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 6, 1),
#  datetime.date(2021, 5, 24),
#  datetime.date(2015, 4, 8),
#  datetime.date(2023, 4, 19),
#  datetime.date(2017, 7, 31),
#  datetime.date(2019, 4, 12),
#  datetime.date(2022, 12, 23),
#  datetime.date(2015, 3, 12),
#  datetime.date(2023, 1, 12),
#  datetime.date(2015, 7, 7),
#  datetime.date(2016, 3, 15),
#  datetime.date(2018, 12, 5),
#  datetime.date(2017, 3, 30),
#  datetime.date(2019, 11, 8),
#  datetime.date(2023, 7, 14),
#  datetime.date(2018, 12, 3),
#  datetime.date(2018, 5, 22),
#  datetime.date(2016, 4, 13),
#  datetime.date(2015, 3, 5),
#  datetime.date(2023, 1, 23),
#  datetime.date(2017, 11, 23),
#  datetime.date(2023, 9, 15),
#  datetime.date(2023, 5, 22),
#  datetime.date(2023, 11, 20),
#  datetime.date(2016, 4, 12),
#  datetime.date(2022, 1, 21),
#  datetime.date(2018, 1, 30),
#  datetime.date(2021, 9, 15),
#  datetime.date(2021, 4, 13),
#  datetime.date(2021, 6, 3),
#  datetime.date(2015, 9, 14),
#  datetime.date(2018, 8, 29),
#  datetime.date(2023, 12, 28),
#  datetime.date(2022, 3, 18),
#  datetime.date(2023, 6, 15),
#  datetime.date(2017, 4, 12),
#  datetime.date(2021, 3, 26),
#  datetime.date(2018, 12, 10),
#  datetime.date(2019, 3, 21),
#  datetime.date(2020, 11, 16),
#  datetime.date(2019, 4, 9),
#  datetime.date(2021, 3, 19),
#  datetime.date(2019, 3, 27),
#  datetime.date(2021, 8, 3),
#  datetime.date(2021, 6, 16),
#  datetime.date(2021, 6, 23),
#  datetime.date(2023, 1, 9),
#  datetime.date(2016, 6, 14),
#  datetime.date(2018, 9, 7),
#  datetime.date(2018, 11, 1),
#  datetime.date(2022, 6, 7),
#  datetime.date(2019, 2, 6),
#  datetime.date(2022, 7, 6),
#  datetime.date(2021, 8, 2),
#  datetime.date(2024, 1, 4),
#  datetime.date(2023, 2, 8),
#  datetime.date(2017, 1, 24),
#  datetime.date(2016, 3, 21),
#  datetime.date(2018, 11, 14),
#  datetime.date(2019, 1, 16),
#  datetime.date(2016, 11, 8),
#  datetime.date(2018, 9, 27),
#  datetime.date(2021, 7, 26),
#  datetime.date(2023, 8, 18),
#  datetime.date(2024, 5, 10),
#  datetime.date(2017, 5, 30),
#  datetime.date(2020, 10, 7),
#  datetime.date(2023, 3, 7),
#  datetime.date(2020, 5, 26),
#  datetime.date(2016, 12, 30),
#  datetime.date(2017, 8, 1),
#  datetime.date(2016, 6, 20),
#  datetime.date(2019, 9, 25),
#  datetime.date(2023, 2, 22),
#  datetime.date(2017, 6, 14),
#  datetime.date(2018, 6, 18),
#  datetime.date(2017, 6, 8),
#  datetime.date(2016, 6, 6),
#  datetime.date(2017, 1, 10),
#  datetime.date(2022, 4, 4),
#  datetime.date(2015, 3, 10),
#  datetime.date(2020, 10, 27),
#  datetime.date(2022, 9, 7),
#  datetime.date(2021, 1, 14),
#  datetime.date(2023, 10, 26),
#  datetime.date(2021, 2, 24),
#  datetime.date(2023, 10, 27),
#  datetime.date(2019, 5, 27),
#  datetime.date(2021, 6, 11),
#  datetime.date(2018, 4, 18),
#  datetime.date(2015, 5, 25),
#  datetime.date(2019, 12, 18),
#  datetime.date(2024, 6, 24),
#  datetime.date(2017, 9, 29),
#  datetime.date(2024, 3, 22),
#  datetime.date(2021, 1, 19),
#  datetime.date(2019, 2, 4),
#  datetime.date(2015, 5, 6),
#  datetime.date(2019, 5, 14),
#  datetime.date(2018, 7, 9),
#  datetime.date(2018, 10, 15),
#  datetime.date(2019, 11, 12),
#  datetime.date(2015, 9, 3),
#  datetime.date(2015, 12, 15),
#  datetime.date(2018, 3, 29),
#  datetime.date(2018, 10, 12),
#  datetime.date(2018, 2, 26),
#  datetime.date(2020, 6, 26),
#  datetime.date(2020, 10, 6),
#  datetime.date(2020, 12, 4),
#  datetime.date(2023, 3, 6),
#  datetime.date(2016, 7, 8),
#  datetime.date(2019, 12, 20),
#  datetime.date(2021, 3, 8),
#  datetime.date(2016, 2, 2),
#  datetime.date(2016, 7, 29),
#  datetime.date(2019, 4, 1),
#  datetime.date(2016, 6, 8),
#  datetime.date(2023, 12, 21),
#  datetime.date(2016, 4, 25),
#  datetime.date(2017, 6, 2),
#  datetime.date(2023, 3, 16),
#  datetime.date(2016, 1, 22),
#  datetime.date(2017, 8, 24),
#  datetime.date(2024, 4, 16),
#  datetime.date(2021, 8, 16),
#  datetime.date(2018, 3, 16),
#  datetime.date(2017, 11, 6),
#  datetime.date(2018, 8, 24),
#  datetime.date(2022, 5, 20),
#  datetime.date(2016, 1, 21),
#  datetime.date(2020, 1, 31),
#  datetime.date(2018, 11, 16),
#  datetime.date(2019, 5, 2),
#  datetime.date(2018, 7, 19),
#  datetime.date(2022, 6, 2),
#  datetime.date(2017, 7, 12),
#  datetime.date(2020, 7, 30),
#  datetime.date(2020, 7, 24),
#  datetime.date(2018, 8, 1),
#  datetime.date(2017, 4, 3),
#  datetime.date(2015, 7, 22),
#  datetime.date(2023, 3, 30),
#  datetime.date(2022, 9, 9),
#  datetime.date(2015, 3, 27),
#  datetime.date(2017, 9, 22),
#  datetime.date(2020, 6, 12),
#  datetime.date(2023, 8, 8),
#  datetime.date(2016, 5, 12),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 1, 13),
#  datetime.date(2017, 3, 9),
#  datetime.date(2018, 8, 23),
#  datetime.date(2022, 5, 17),
#  datetime.date(2021, 2, 2),
#  datetime.date(2015, 8, 27),
#  datetime.date(2016, 10, 5),
#  datetime.date(2019, 6, 18),
#  datetime.date(2023, 6, 13),
#  datetime.date(2015, 7, 28),
#  datetime.date(2019, 8, 16),
#  datetime.date(2021, 5, 3),
#  datetime.date(2015, 9, 7),
#  datetime.date(2024, 4, 3),
#  datetime.date(2024, 7, 2),
#  datetime.date(2015, 8, 18),
#  datetime.date(2020, 3, 6),
#  datetime.date(2023, 1, 27),
#  datetime.date(2016, 3, 29),
#  datetime.date(2018, 7, 27),
#  datetime.date(2021, 1, 22),
#  datetime.date(2021, 11, 29),
#  datetime.date(2016, 8, 22),
#  datetime.date(2023, 2, 20),
#  datetime.date(2021, 12, 31),
#  datetime.date(2017, 8, 17),
#  datetime.date(2018, 6, 1),
#  datetime.date(2024, 5, 15),
#  datetime.date(2017, 10, 16),
#  datetime.date(2022, 12, 19),
#  datetime.date(2018, 4, 24),
#  datetime.date(2018, 5, 3),
#  datetime.date(2024, 6, 25),
#  datetime.date(2023, 2, 23),
#  datetime.date(2016, 2, 29),
#  datetime.date(2017, 4, 13),
#  datetime.date(2015, 3, 16),
#  datetime.date(2019, 3, 13),
#  datetime.date(2021, 9, 30),
#  datetime.date(2020, 4, 7),
#  datetime.date(2018, 11, 9),
#  datetime.date(2021, 2, 11),
#  datetime.date(2021, 12, 8),
#  datetime.date(2017, 3, 1),
#  datetime.date(2016, 1, 15),
#  datetime.date(2022, 8, 18),
#  datetime.date(2020, 7, 2),
#  datetime.date(2019, 3, 7),
#  datetime.date(2018, 1, 11),
#  datetime.date(2022, 9, 29),
#  datetime.date(2015, 3, 30),
#  datetime.date(2017, 10, 19),
#  datetime.date(2021, 6, 22),
#  datetime.date(2017, 4, 19),
#  datetime.date(2022, 3, 9),
#  datetime.date(2015, 11, 3),
#  datetime.date(2017, 10, 24),
#  datetime.date(2023, 3, 9),
#  datetime.date(2021, 11, 26),
#  datetime.date(2016, 2, 3),
#  datetime.date(2016, 7, 6),
#  datetime.date(2017, 9, 27),
#  datetime.date(2020, 6, 17),
#  datetime.date(2015, 6, 30),
#  datetime.date(2023, 4, 26),
#  datetime.date(2019, 6, 14),
#  datetime.date(2019, 1, 24),
#  datetime.date(2020, 7, 9),
#  datetime.date(2022, 1, 6),
#  datetime.date(2023, 3, 31),
#  datetime.date(2023, 4, 13),
#  datetime.date(2019, 11, 27),
#  datetime.date(2019, 9, 9),
#  datetime.date(2015, 4, 10),
#  datetime.date(2021, 6, 15),
#  datetime.date(2020, 10, 21),
#  datetime.date(2023, 2, 15),
#  datetime.date(2022, 7, 5),
#  datetime.date(2021, 10, 6),
#  datetime.date(2018, 4, 17),
#  datetime.date(2019, 3, 15),
#  datetime.date(2022, 5, 19),
#  datetime.date(2015, 4, 21),
#  datetime.date(2020, 6, 5),
#  datetime.date(2017, 2, 23),
#  datetime.date(2022, 2, 8),
#  datetime.date(2015, 6, 25),
#  datetime.date(2022, 7, 28),
#  datetime.date(2022, 9, 13),
#  datetime.date(2017, 9, 18),
#  datetime.date(2015, 9, 28),
#  datetime.date(2021, 3, 11),
#  datetime.date(2023, 11, 17),
#  datetime.date(2024, 2, 22),
#  datetime.date(2017, 9, 4),
#  datetime.date(2022, 3, 14),
#  datetime.date(2018, 11, 23),
#  datetime.date(2024, 6, 10),
#  datetime.date(2017, 3, 15),
#  datetime.date(2021, 4, 26),
#  datetime.date(2017, 10, 12),
#  datetime.date(2023, 1, 24),
#  datetime.date(2016, 10, 20),
#  datetime.date(2018, 10, 10),
#  datetime.date(2015, 9, 8),
#  datetime.date(2020, 12, 28),
#  datetime.date(2015, 7, 13),
#  datetime.date(2021, 10, 27),
#  datetime.date(2023, 9, 27),
#  datetime.date(2015, 5, 8),
#  datetime.date(2019, 6, 10),
#  datetime.date(2023, 2, 21),
#  datetime.date(2016, 3, 23),
#  datetime.date(2021, 10, 26),
#  datetime.date(2016, 10, 31),
#  datetime.date(2023, 10, 11),
#  datetime.date(2022, 10, 11),
#  datetime.date(2022, 9, 8),
#  datetime.date(2017, 9, 6),
#  datetime.date(2023, 7, 26),
#  datetime.date(2017, 8, 11),
#  datetime.date(2024, 3, 6),
#  datetime.date(2018, 4, 5),
#  datetime.date(2021, 11, 25),
#  datetime.date(2022, 3, 30),
#  datetime.date(2022, 12, 6),
#  datetime.date(2017, 11, 24),
#  datetime.date(2022, 6, 3),
#  datetime.date(2024, 1, 18),
#  datetime.date(2016, 2, 16),
#  datetime.date(2024, 4, 23),
#  datetime.date(2018, 9, 26),
#  datetime.date(2024, 3, 13),
#  datetime.date(2019, 11, 19),
#  datetime.date(2016, 7, 20),
#  datetime.date(2016, 11, 23),
#  datetime.date(2018, 12, 26),
#  datetime.date(2019, 5, 8),
#  datetime.date(2022, 3, 29),
#  datetime.date(2015, 3, 3),
#  datetime.date(2018, 1, 31),
#  datetime.date(2015, 9, 30),
#  datetime.date(2015, 11, 13),
#  datetime.date(2015, 10, 1),
#  datetime.date(2015, 5, 5),
#  datetime.date(2020, 3, 17),
#  datetime.date(2017, 12, 21),
#  datetime.date(2022, 6, 14),
#  datetime.date(2024, 5, 22),
#  datetime.date(2017, 6, 19),
#  datetime.date(2017, 12, 20),
#  datetime.date(2020, 4, 15),
#  datetime.date(2022, 2, 1),
#  datetime.date(2018, 7, 24),
#  datetime.date(2016, 1, 7),
#  datetime.date(2018, 8, 9),
#  datetime.date(2016, 7, 26),
#  datetime.date(2016, 1, 8),
#  datetime.date(2019, 7, 15),
#  datetime.date(2017, 11, 8),
#  datetime.date(2016, 3, 16),
#  datetime.date(2015, 9, 21),
#  datetime.date(2015, 4, 9),
#  datetime.date(2019, 3, 22),
#  datetime.date(2015, 6, 5),
#  datetime.date(2017, 6, 29),
#  datetime.date(2018, 2, 16),
#  datetime.date(2018, 9, 3),
#  datetime.date(2020, 11, 9),
#  datetime.date(2018, 8, 21),
#  datetime.date(2019, 10, 18),
#  datetime.date(2018, 2, 20),
#  datetime.date(2019, 8, 1),
#  datetime.date(2021, 6, 14),
#  datetime.date(2015, 5, 20),
#  datetime.date(2017, 2, 3),
#  datetime.date(2021, 10, 1),
#  datetime.date(2018, 8, 28),
#  datetime.date(2023, 3, 22),
#  datetime.date(2024, 3, 25),
#  datetime.date(2023, 3, 13),
#  datetime.date(2022, 6, 24),
#  datetime.date(2021, 12, 15),
#  datetime.date(2024, 7, 9),
#  datetime.date(2018, 11, 19),
#  datetime.date(2016, 6, 13),
#  datetime.date(2023, 6, 5),
#  datetime.date(2022, 4, 11),
#  datetime.date(2018, 6, 15),
#  datetime.date(2018, 6, 6),
#  datetime.date(2016, 9, 7),
#  datetime.date(2021, 6, 25),
#  datetime.date(2022, 11, 8),
#  datetime.date(2023, 11, 14),
#  datetime.date(2019, 4, 4),
#  datetime.date(2023, 6, 27),
#  datetime.date(2024, 5, 8),
#  datetime.date(2017, 11, 2),
#  datetime.date(2019, 7, 26),
#  datetime.date(2020, 11, 11),
#  datetime.date(2015, 12, 8),
#  datetime.date(2022, 2, 28),
#  datetime.date(2016, 10, 7),
#  datetime.date(2021, 5, 17),
#  datetime.date(2016, 2, 23),
#  datetime.date(2021, 8, 30),
#  datetime.date(2022, 12, 28),
#  datetime.date(2022, 7, 18),
#  datetime.date(2017, 5, 26),
#  datetime.date(2020, 10, 15),
#  datetime.date(2021, 2, 10),
#  datetime.date(2019, 1, 25),
#  datetime.date(2020, 11, 17),
#  datetime.date(2021, 8, 18),
#  datetime.date(2024, 1, 24),
#  datetime.date(2019, 1, 22),
#  datetime.date(2015, 4, 15),
#  datetime.date(2018, 3, 13),
#  datetime.date(2022, 5, 12),
#  datetime.date(2022, 12, 15),
#  datetime.date(2023, 1, 10),
#  datetime.date(2019, 2, 25),
#  datetime.date(2020, 1, 15),
#  datetime.date(2024, 2, 8),
#  datetime.date(2018, 2, 2),
#  datetime.date(2022, 8, 29),
#  datetime.date(2022, 9, 2),
#  datetime.date(2020, 8, 3),
#  datetime.date(2015, 3, 25),
#  datetime.date(2021, 4, 22),
#  datetime.date(2017, 5, 25),
#  datetime.date(2021, 7, 2),
#  datetime.date(2021, 8, 11),
#  datetime.date(2020, 1, 10),
#  datetime.date(2016, 11, 28),
#  datetime.date(2018, 5, 4),
#  datetime.date(2017, 12, 26),
#  datetime.date(2021, 5, 5),
#  datetime.date(2019, 5, 22),
#  datetime.date(2021, 12, 24),
#  datetime.date(2022, 12, 12),
#  datetime.date(2021, 3, 3),
#  datetime.date(2019, 10, 10),
#  datetime.date(2019, 12, 27),
#  datetime.date(2015, 7, 3),
#  datetime.date(2022, 5, 23),
#  datetime.date(2019, 10, 15),
#  datetime.date(2024, 4, 17),
#  datetime.date(2018, 5, 1),
#  datetime.date(2021, 3, 1),
#  datetime.date(2017, 10, 23),
#  datetime.date(2019, 8, 19),
#  datetime.date(2021, 10, 20),
#  datetime.date(2018, 9, 25),
#  datetime.date(2019, 6, 20),
#  datetime.date(2018, 10, 31),
#  datetime.date(2019, 8, 8),
#  datetime.date(2020, 7, 10),
#  datetime.date(2022, 2, 21),
#  datetime.date(2017, 2, 10),
#  datetime.date(2017, 7, 27),
#  datetime.date(2023, 7, 6),
#  datetime.date(2021, 1, 15),
#  datetime.date(2023, 10, 19),
#  datetime.date(2022, 9, 1),
#  datetime.date(2020, 5, 13),
#  datetime.date(2022, 9, 23),
#  datetime.date(2016, 7, 21),
#  datetime.date(2022, 5, 11),
#  datetime.date(2023, 11, 13),
#  datetime.date(2017, 12, 13),
#  datetime.date(2018, 12, 20),
#  datetime.date(2021, 2, 1),
#  datetime.date(2024, 4, 19),
#  datetime.date(2016, 4, 15),
#  datetime.date(2024, 2, 23),
#  datetime.date(2022, 11, 25),
#  datetime.date(2022, 11, 21),
#  datetime.date(2018, 8, 6),
#  datetime.date(2024, 4, 15),
#  datetime.date(2015, 7, 15),
#  datetime.date(2021, 4, 23),
#  datetime.date(2020, 10, 19),
#  datetime.date(2021, 3, 30),
#  datetime.date(2017, 10, 25),
#  datetime.date(2020, 2, 27),
#  datetime.date(2015, 11, 5),
#  datetime.date(2019, 7, 4),
#  datetime.date(2019, 4, 30),
#  datetime.date(2018, 11, 20),
#  datetime.date(2019, 6, 12),
#  datetime.date(2023, 5, 10),
#  datetime.date(2017, 2, 2),
#  datetime.date(2019, 11, 28),
#  datetime.date(2018, 2, 8),
#  datetime.date(2019, 8, 12),
#  datetime.date(2018, 2, 9),
#  datetime.date(2015, 8, 17),
#  datetime.date(2016, 7, 25),
#  datetime.date(2020, 12, 14),
#  datetime.date(2022, 3, 4),
#  datetime.date(2019, 8, 7),
#  datetime.date(2017, 11, 17),
#  datetime.date(2017, 11, 27),
#  datetime.date(2024, 4, 5),
#  datetime.date(2023, 8, 25),
#  datetime.date(2023, 10, 4),
#  datetime.date(2020, 9, 15),
#  datetime.date(2022, 5, 18),
#  datetime.date(2020, 10, 12),
#  datetime.date(2021, 4, 6),
#  datetime.date(2023, 5, 17),
#  datetime.date(2021, 7, 29),
#  datetime.date(2015, 4, 1),
#  datetime.date(2021, 8, 13),
#  datetime.date(2018, 9, 21),
#  datetime.date(2019, 8, 27),
#  datetime.date(2019, 11, 29),
#  datetime.date(2021, 10, 11),
#  datetime.date(2020, 12, 2),
#  datetime.date(2022, 7, 29),
#  datetime.date(2016, 12, 16),
#  datetime.date(2020, 5, 20),
#  datetime.date(2015, 5, 13),
#  datetime.date(2020, 8, 28),
#  datetime.date(2019, 12, 31),
#  datetime.date(2023, 6, 14),
#  datetime.date(2022, 3, 1),
#  datetime.date(2022, 2, 22),
#  datetime.date(2021, 5, 12),
#  datetime.date(2022, 7, 19),
#  datetime.date(2023, 4, 4),
#  datetime.date(2024, 4, 1),
#  datetime.date(2015, 11, 2),
#  datetime.date(2017, 3, 8),
#  datetime.date(2016, 11, 9),
#  datetime.date(2023, 7, 7),
#  datetime.date(2015, 9, 25),
#  datetime.date(2021, 7, 22),
#  datetime.date(2024, 6, 12),
#  datetime.date(2017, 8, 22),
#  datetime.date(2019, 10, 7),
#  datetime.date(2015, 10, 14),
#  datetime.date(2020, 1, 8),
#  datetime.date(2021, 7, 21),
#  datetime.date(2021, 3, 24),
#  datetime.date(2015, 3, 24),
#  datetime.date(2021, 5, 11),
#  datetime.date(2023, 2, 27),
#  datetime.date(2015, 3, 13),
#  datetime.date(2016, 6, 22),
#  datetime.date(2020, 2, 3),
#  datetime.date(2017, 4, 5),
#  datetime.date(2015, 8, 20),
#  datetime.date(2024, 6, 19),
#  datetime.date(2021, 1, 11),
#  datetime.date(2022, 2, 15),
#  datetime.date(2022, 11, 16),
#  datetime.date(2020, 2, 13),
#  datetime.date(2019, 5, 17),
#  datetime.date(2020, 10, 1),
#  datetime.date(2023, 7, 25),
#  datetime.date(2015, 9, 2),
#  datetime.date(2023, 10, 3),
#  datetime.date(2017, 3, 20),
#  datetime.date(2023, 6, 2),
#  datetime.date(2020, 8, 12),
#  datetime.date(2019, 10, 22),
#  datetime.date(2019, 9, 17),
#  datetime.date(2018, 3, 9),
#  ...}

# %%
def rename_ohlc_columns(df: pl.DataFrame) -> pl.DataFrame:

    column_mapping = {"o": "open", "h": "high", "l": "low", "c": "close", "v": "volume"}
    df = df.rename(column_mapping)

    return df

# %%
async def create_sell_signals(df):

    df["sell_signal"] = False

    df["sell_signal"] = (df["high"] < df["high"].shift(1)) & (
        df["high"].shift(2) < df["high"].shift(1)
    )

    return df

async def create_buy_signals(df):
    df["buy_signal"] = False

    df["buy_signal"] = (df["low"] > df["low"].shift(1)) & (
        df["low"].shift(2) > df["low"].shift(1)
    )

    return df

async def create_ma(df, period):
    df["close"] = pd.to_numeric(df["close"], errors="coerce")
    df["ma"] = df["close"].rolling(window=period).mean()
    return df

# %%
PORTFOLIO_VALUE = 10_00_000 # 10 Lacs
RPT_PCT = 0.01 # 1% RPT
SLIPPAGE_ = 0.005
LEVERAGE_ = 5

# %%
def positional(df, sl_pct, target_pct):
    trades = []
    in_trade_long = False
    in_trade_short = False
    current_trade = None
    king_candle = None
    queen_candle = None
    slippage_pct = SLIPPAGE_
    portfolio = 10000000
    index_lev = 6
    entry_time = None
    exit_time = None
    is_trailing_active_long = False
    is_trailing_active_short = False
    points_long = None
    points_short = None
    initial_sl_long = 100000
    initial_sl_short = 0

    df['100ma'] = df['close'].rolling(50).mean()

    for i in range(2, len(df)):
        prev2_candle = df.iloc[i-2]
        prev_candle = df.iloc[i-1]
        current_candle = df.iloc[i]

        # Check for King candle formation when not in a trade
        if not in_trade_long and current_candle['high'] < prev_candle['high'] and prev2_candle['high'] < prev_candle['high'] and prev_candle['high'] < prev_candle['100ma']:
            king_candle = prev_candle
            signal_time_long = king_candle['datetime']
            initial_sl_long = min(current_candle['low'], prev_candle['low'], prev2_candle['low'])

        # Check for King breakout (Long position)
        if king_candle is not None and not in_trade_long and current_candle['high'] > king_candle['high']:
            # if (current_candle['open'] > king_candle['high'] and current_candle['low'] <= king_candle['high']) or (current_candle['open'] <= king_candle['high']):
            #     entry_price_long = king_candle['high']
            #     stop_loss_long = entry_price_long * (1 - sl_pct)
            #     # stop_loss_long = initial_sl_long
            #     target_long = entry_price_long * (1 + target_pct)
            #     entry_time_long = df.iloc[i]['datetime']
            #     in_trade_long = True
            #     # print(f"Taking Long Position: Entry={entry_price}, SL={stop_loss}, Target={target}")
            # else:
            #     entry_price_long = current_candle['close']
            #     stop_loss_long = entry_price_long * (1 - sl_pct)
            #     # stop_loss_long = initial_sl_long
            #     target_long = entry_price_long * (1 + target_pct)
            #     entry_time_long = df.iloc[i]['datetime']
            #     in_trade_long = True
            #     # print(f"Taking Long Position: Entry={entry_price}, SL={stop_loss}, Target={target}")
            if (current_candle['open'] > king_candle['high'] and current_candle['low'] <= king_candle['high']) or (current_candle['open'] <= king_candle['high']):
                entry_price_long = king_candle['high']
                stop_loss_long = entry_price_long * (1 - sl_pct)
                # stop_loss_long = initial_sl_long
                target_long = entry_price_long * (1 + target_pct)
                entry_time_long = df.iloc[i]['datetime']
                in_trade_long = True
            #     # print(f"Taking Long Position: Entry={entry_price}, SL={stop_loss}, Target={target}")
            elif current_candle['open'] > king_candle['high']:
                king_candle = None
                in_trade_long = False

        if in_trade_long:
            if not is_trailing_active_long:
                if current_candle['low'] > current_candle['ma']:
                    is_trailing_active_long = True
            if not is_trailing_active_long:
                if (current_candle['low'] <= stop_loss_long):
                    if current_candle['open'] < stop_loss_long:
                        if current_candle['datetime'] != entry_time_long:
                            exit_price_long = current_candle['open']
                            exit_time_long = df.iloc[i]['datetime']
                            points_long = exit_price_long - entry_price_long
                            remarks_long = 'Gap SL'
                    else:
                        exit_price_long = stop_loss_long
                        exit_time_long = df.iloc[i]['datetime']
                        points_long = exit_price_long - entry_price_long
                        remarks_long = 'Initial SL Hit'
                    
                elif (current_candle['high'] >= target_long):
                    exit_price_long = target_long
                    exit_time_long = df.iloc[i]['datetime']
                    points_long = exit_price_long - entry_price_long
                    remarks_long = 'Target Hit'
            else:
                if (current_candle['low'] <= stop_loss_long):
                    if current_candle['open'] < stop_loss_long:
                        if current_candle['datetime'] != entry_time_long:
                            exit_price_long = current_candle['open']
                            exit_time_long = df.iloc[i]['datetime']
                            points_long = exit_price_long - entry_price_long
                            remarks_long = 'Gap SL'
                    else:
                        exit_price_long = stop_loss_long
                        exit_time_long = df.iloc[i]['datetime']
                        points_long = exit_price_long - entry_price_long
                        remarks_long = 'Initial SL Hit'
                    
                elif (current_candle['high'] >= target_long):
                    exit_price_long = target_long
                    exit_time_long = df.iloc[i]['datetime']
                    points_long = exit_price_long - entry_price_long
                    remarks_long = 'Target Hit'

                elif (current_candle['close'] <= current_candle['ma']):
                    exit_price_long = current_candle['close']
                    exit_time_long = df.iloc[i]['datetime']
                    points_long = exit_price_long - entry_price_long
                    remarks_long = 'Trailing SL Hit'

            if points_long:
                slippages = SLIPPAGE_ * (entry_price_long + exit_price_long)
                # qty = portfolio * index_lev / entry_price_long
                qty = portfolio * RPT_PCT / abs(entry_price_long - initial_sl_long)
                current_trade = {
                    'Type': 'LONG',
                    'Signal Generated At': signal_time_long,
                    'Entry Time': entry_time_long,
                    'Entry Price': entry_price_long,
                    'Initial SL': stop_loss_long,
                    'Initial Target': target_long,
                    'Exit Time': exit_time_long,
                    'Exit Price': exit_price_long,
                    'Points': points_long,
                    'Slippages': slippages,
                    'Remarks': remarks_long,
                    'Qty': qty,
                    'PnL': points_long * qty,
                    'PnL w cs': (points_long - slippages) * qty,
                    'ROI%': points_long * qty * 100 / portfolio,
                    'ROI%': (points_long - slippages) * qty * 100 / portfolio,
                }
                trades.append(current_trade) 
                in_trade_long = False  
                king_candle = None  
                is_trailing_active_long = False
                points_long = None
                signal_time_long = None
                initial_sl_long = 100000

        # Check for Queen candle formation when not in a trade
        if not in_trade_short and current_candle['low'] > prev_candle['low'] and prev2_candle['low'] > prev_candle['low'] and prev_candle['low'] > prev_candle['100ma']:
            queen_candle = prev_candle
            signal_time_short = queen_candle['datetime']
            initial_sl_short = max(current_candle['high'], prev_candle['high'], prev2_candle['high'])
            
        # Check for Queen breakout (Short position)
        if queen_candle is not None and not in_trade_short and current_candle['low'] < queen_candle['low']:
            # if (current_candle['open'] < queen_candle['low'] and current_candle['high'] >= queen_candle['low']) or (current_candle['open'] >= queen_candle['low']):
            #     entry_price_short = queen_candle['low']
            #     stop_loss_short = entry_price_short * (1 + sl_pct)
            #     # stop_loss_short = initial_sl_short
            #     target_short = entry_price_short * (1 - target_pct)
            #     entry_time_short = df.iloc[i]['datetime']
            #     in_trade_short = True
            # else:
            #     entry_price_short = current_candle['close']
            #     stop_loss_short = entry_price_short * (1 + sl_pct)
            #     # stop_loss_short = initial_sl_short
            #     target_short = entry_price_short * (1 - target_pct)
            #     entry_time_short = df.iloc[i]['datetime']
            #     in_trade_short = True
            if (current_candle['open'] < queen_candle['low'] and current_candle['high'] >= queen_candle['low']) or (current_candle['open'] >= queen_candle['low']):
                entry_price_short = queen_candle['low']
                stop_loss_short = entry_price_short * (1 + sl_pct)
                # stop_loss_short = initial_sl_short
                target_short = entry_price_short * (1 - target_pct)
                entry_time_short = df.iloc[i]['datetime']
                in_trade_short = True
            elif current_candle['open'] < queen_candle['low']:
                queen_candle = None
                in_trade_short = False
            
        if in_trade_short:
            if not is_trailing_active_short:
                if current_candle['high'] < current_candle['ma']:
                    is_trailing_active_short = True
            if not is_trailing_active_short:
                if (current_candle['high'] >= stop_loss_short):
                    if current_candle['open'] > stop_loss_short:
                        if current_candle['datetime'] != entry_time_short:
                            exit_price_short = current_candle['open']
                            exit_time_short = df.iloc[i]['datetime']
                            points_short = entry_price_short - exit_price_short
                            remarks_short = 'Gap SL'
                    else:
                        exit_price_short = stop_loss_short
                        exit_time_short = df.iloc[i]['datetime']
                        points_short = entry_price_short - exit_price_short
                        remarks_short = 'Initial SL Hit'
                    
                elif (current_candle['low'] <= target_short):
                    exit_price_short = target_short
                    exit_time_short = df.iloc[i]['datetime']
                    points_short = entry_price_short - exit_price_short
                    remarks_short = 'Target Hit'
            else:
                if (current_candle['high'] >= stop_loss_short):
                    if current_candle['open'] > stop_loss_short:
                        if current_candle['datetime'] != entry_time_short:
                            exit_price_short = current_candle['open']
                            exit_time_short = df.iloc[i]['datetime']
                            points_short = entry_price_short - exit_price_short
                            remarks_short = 'Gap SL'
                    else:
                        exit_price_short = stop_loss_short
                        exit_time_short = df.iloc[i]['datetime']
                        points_short = entry_price_short - exit_price_short
                        remarks_short = 'Initial SL Hit'
                    
                elif (current_candle['low'] <= target_short):
                    exit_price_short = target_short
                    exit_time_short = df.iloc[i]['datetime']
                    points_short = entry_price_short - exit_price_short
                    remarks_short = 'Target Hit'

                elif (current_candle['close'] >= current_candle['ma']):
                    exit_price_short = current_candle['close']
                    exit_time_short = df.iloc[i]['datetime']
                    points_short = entry_price_short - exit_price_short
                    remarks_short = 'Trailing SL Hit'

            if points_short:
                slippages = SLIPPAGE_ * (entry_price_short + exit_price_short)
                # qty = portfolio * index_lev / entry_price_short
                qty = portfolio * RPT_PCT / abs(entry_price_short - initial_sl_short)
                current_trade = {
                    'Type': 'SHORT',
                    'Signal Generated At': signal_time_short,
                    'Entry Time': entry_time_short,
                    'Entry Price': entry_price_short,
                    'Initial SL': stop_loss_short,
                    'Initial Target': target_short,
                    'Exit Time': exit_time_short,
                    'Exit Price': exit_price_short,
                    'Points': points_short,
                    'Slippages': slippages,
                    'Remarks': remarks_short,
                    'Qty': qty,
                    'PnL': points_short * qty,
                    'PnL w cs': (points_short - slippages) * qty,
                    'ROI%': points_short * qty * 100 / portfolio,
                    'ROI%': (points_short - slippages) * qty * 100 / portfolio,
                }
                trades.append(current_trade)
                in_trade_short = False
                queen_candle = None
                is_trailing_active_short = False
                points_short = None
                signal_time_short = None
                initial_sl_short = 0
            
    return trades


# Example usage:
# trades = identify_trades(df)
# print(trades)

# %%
tf = '60m'
ofs = '15m'
ma_period = 50

# data = resample(pl.DataFrame(bnf_1min), tf, ofs)
# data_pandas = data.to_pandas()
data_pandas = bnf_1min
data_pandas['ma'] = data_pandas['close'].rolling(ma_period).mean()
# data['ma'] = data['close'].rolling(ma_period).mean()
tb = positional(data_pandas, 0.015, 0.15)

# %%
tb_pandas = pd.DataFrame(tb)

# %%
tb_pandas['Entry Time'] = pd.to_datetime(tb_pandas['Entry Time'])
tb_pandas['Trade Year'] = tb_pandas['Entry Time'].dt.year
tb_pandas['ROI% w cs'] = tb_pandas['ROI%']

# %%
# (tb_pandas['pnl'].sum()) - (tb_pandas['slippage'].sum())
tb_pandas = tb_pandas[tb_pandas['Type'] == 'LONG']

# %%
tb_pandas
# Out:
#      Type       Signal Generated At                Entry Time  Entry Price  \
# 1    LONG 2015-03-19 09:00:00+05:30 2015-03-19 21:00:00+05:30        25946
# 7    LONG 2015-05-25 09:00:00+05:30 2015-05-25 21:00:00+05:30        27148
# 8    LONG 2015-05-28 21:00:00+05:30 2015-05-29 17:00:00+05:30        26886
# 9    LONG 2015-06-08 13:00:00+05:30 2015-06-09 09:00:00+05:30        26840
# 10   LONG 2015-06-17 17:00:00+05:30 2015-06-18 09:00:00+05:30        26909
# 11   LONG 2015-07-03 09:00:00+05:30 2015-07-03 17:00:00+05:30        26318
# 12   LONG 2015-07-10 13:00:00+05:30 2015-07-10 21:00:00+05:30        26149
# 13   LONG 2015-07-23 13:00:00+05:30 2015-07-27 09:00:00+05:30        24910
# 17   LONG 2015-07-29 21:00:00+05:30 2015-07-30 17:00:00+05:30        24817
# 19   LONG 2015-09-15 17:00:00+05:30 2015-09-16 09:00:00+05:30        26055
# 23   LONG 2015-11-06 09:00:00+05:30 2015-11-06 17:00:00+05:30        25880
# 24   LONG 2015-11-09 09:00:00+05:30 2015-11-09 17:00:00+05:30        25744
# 25   LONG 2015-11-18 13:00:00+05:30 2015-11-19 09:00:00+05:30        25174
# 32   LONG 2015-12-18 09:00:00+05:30 2015-12-18 17:00:00+05:30        24958
# 36   LONG 2016-03-18 21:00:00+05:30 2016-03-22 13:00:00+05:30        29200
# 37   LONG 2016-03-28 17:00:00+05:30 2016-03-29 17:00:00+05:30        28515
# 41   LONG 2016-05-19 21:00:00+05:30 2016-05-20 13:00:00+05:30        29840
# 44   LONG 2016-05-30 13:00:00+05:30 2016-05-30 21:00:00+05:30        28590
# 46   LONG 2016-07-15 13:00:00+05:30 2016-07-18 17:00:00+05:30        31100
# 48   LONG 2016-07-22 21:00:00+05:30 2016-07-25 21:00:00+05:30        30899
# 50   LONG 2016-08-08 17:00:00+05:30 2016-08-09 17:00:00+05:30        31208
# 51   LONG 2016-08-17 17:00:00+05:30 2016-08-18 09:00:00+05:30        31415
# 52   LONG 2016-09-01 17:00:00+05:30 2016-09-02 09:00:00+05:30        30869
# 53   LONG 2016-09-02 17:00:00+05:30 2016-09-06 17:00:00+05:30        31065
# 55   LONG 2016-09-16 17:00:00+05:30 2016-09-19 09:00:00+05:30        30934
# 57   LONG 2016-09-28 13:00:00+05:30 2016-09-29 09:00:00+05:30        31039
# 58   LONG 2016-10-11 21:00:00+05:30 2016-10-13 09:00:00+05:30        29785
# 59   LONG 2016-10-17 09:00:00+05:30 2016-10-17 17:00:00+05:30        29703
# 62   LONG 2016-11-18 17:00:00+05:30 2016-11-21 09:00:00+05:30        28980
# 63   LONG 2016-12-13 17:00:00+05:30 2016-12-14 13:00:00+05:30        27648
# 64   LONG 2016-12-16 13:00:00+05:30 2016-12-16 21:00:00+05:30        27147
# 65   LONG 2016-12-16 21:00:00+05:30 2016-12-19 17:00:00+05:30        27266
# 68   LONG 2016-12-23 21:00:00+05:30 2016-12-26 21:00:00+05:30        27042
# 72   LONG 2017-01-30 09:00:00+05:30 2017-01-30 17:00:00+05:30        28423
# 76   LONG 2017-03-13 17:00:00+05:30 2017-03-16 09:00:00+05:30        28420
# 81   LONG 2017-04-26 13:00:00+05:30 2017-04-26 21:00:00+05:30        28790
# 85   LONG 2017-05-11 17:00:00+05:30 2017-05-12 13:00:00+05:30        28093
# 86   LONG 2017-06-14 09:00:00+05:30 2017-06-14 17:00:00+05:30        29050
# 87   LONG 2017-06-20 17:00:00+05:30 2017-06-21 09:00:00+05:30        28599
# 88   LONG 2017-06-22 09:00:00+05:30 2017-06-22 17:00:00+05:30        28716
# 89   LONG 2017-06-27 13:00:00+05:30 2017-06-28 09:00:00+05:30        28648
# 90   LONG 2017-07-05 17:00:00+05:30 2017-07-06 09:00:00+05:30        28178
# 93   LONG 2017-07-10 17:00:00+05:30 2017-07-11 17:00:00+05:30        27820
# 94   LONG 2017-08-07 21:00:00+05:30 2017-08-08 13:00:00+05:30        28488
# 101  LONG 2017-09-20 09:00:00+05:30 2017-09-20 21:00:00+05:30        29784
# 102  LONG 2017-09-21 13:00:00+05:30 2017-09-22 09:00:00+05:30        29623
# 103  LONG 2017-10-03 17:00:00+05:30 2017-10-04 09:00:00+05:30        29570
# 104  LONG 2017-10-05 13:00:00+05:30 2017-10-06 17:00:00+05:30        29500
# 107  LONG 2017-10-18 17:00:00+05:30 2017-10-19 17:00:00+05:30        29628
# 108  LONG 2017-10-27 17:00:00+05:30 2017-10-30 21:00:00+05:30        29340
# 109  LONG 2017-11-02 09:00:00+05:30 2017-11-02 17:00:00+05:30        29314
# 111  LONG 2017-11-06 09:00:00+05:30 2017-11-06 21:00:00+05:30        29220
# 112  LONG 2017-12-01 13:00:00+05:30 2017-12-01 21:00:00+05:30        29274
# 117  LONG 2017-12-13 09:00:00+05:30 2017-12-13 17:00:00+05:30        28214
# 119  LONG 2018-02-12 09:00:00+05:30 2018-02-12 21:00:00+05:30        30145
# 121  LONG 2018-02-28 13:00:00+05:30 2018-03-02 17:00:00+05:30        30446
# 122  LONG 2018-03-12 21:00:00+05:30 2018-03-13 17:00:00+05:30        30342
# 123  LONG 2018-03-16 13:00:00+05:30 2018-03-19 21:00:00+05:30        30349
# 128  LONG 2018-05-02 09:00:00+05:30 2018-05-03 17:00:00+05:30        31014
# 129  LONG 2018-05-18 09:00:00+05:30 2018-05-18 17:00:00+05:30        31044
# 131  LONG 2018-05-21 21:00:00+05:30 2018-05-22 13:00:00+05:30        31127
# 132  LONG 2018-06-04 17:00:00+05:30 2018-06-05 21:00:00+05:30        31012
# 134  LONG 2018-06-06 13:00:00+05:30 2018-06-07 13:00:00+05:30        31024
# 135  LONG 2018-06-18 13:00:00+05:30 2018-06-19 09:00:00+05:30        31026
# 136  LONG 2018-06-21 21:00:00+05:30 2018-06-22 17:00:00+05:30        30634
# 137  LONG 2018-06-26 21:00:00+05:30 2018-06-27 13:00:00+05:30        30630
# 138  LONG 2018-06-29 21:00:00+05:30 2018-07-02 17:00:00+05:30        30483
# 141  LONG 2018-07-13 17:00:00+05:30 2018-07-16 09:00:00+05:30        30183
# 142  LONG 2018-07-19 09:00:00+05:30 2018-07-19 21:00:00+05:30        29825
# 143  LONG 2018-08-09 09:00:00+05:30 2018-08-09 17:00:00+05:30        29679
# 144  LONG 2018-08-17 17:00:00+05:30 2018-08-20 09:00:00+05:30        29451
# 149  LONG 2018-10-30 17:00:00+05:30 2018-10-31 09:00:00+05:30        31890
# 150  LONG 2018-10-31 17:00:00+05:30 2018-11-01 09:00:00+05:30        31847
# 151  LONG 2018-11-05 13:00:00+05:30 2018-11-06 13:00:00+05:30        31835
# 152  LONG 2018-11-15 09:00:00+05:30 2018-11-16 17:00:00+05:30        30937
# 153  LONG 2018-11-26 13:00:00+05:30 2018-11-26 21:00:00+05:30        30658
# 156  LONG 2018-11-30 13:00:00+05:30 2018-12-03 09:00:00+05:30        30420
# 158  LONG 2018-12-20 21:00:00+05:30 2018-12-21 13:00:00+05:30        31343
# 165  LONG 2019-03-18 17:00:00+05:30 2019-03-19 09:00:00+05:30        31740
# 166  LONG 2019-04-02 17:00:00+05:30 2019-04-04 13:00:00+05:30        31803
# 169  LONG 2019-04-18 13:00:00+05:30 2019-04-22 09:00:00+05:30        31616
# 170  LONG 2019-05-07 09:00:00+05:30 2019-05-07 17:00:00+05:30        31624
# 171  LONG 2019-05-22 09:00:00+05:30 2019-05-22 17:00:00+05:30        31465
# 176  LONG 2019-05-28 13:00:00+05:30 2019-05-29 09:00:00+05:30        31693
# 184  LONG 2019-09-16 09:00:00+05:30 2019-09-16 21:00:00+05:30        38163
# 186  LONG 2019-09-23 09:00:00+05:30 2019-09-23 17:00:00+05:30        37950
# 190  LONG 2019-10-22 13:00:00+05:30 2019-10-23 09:00:00+05:30        37950
# 191  LONG 2019-10-29 13:00:00+05:30 2019-10-30 17:00:00+05:30        38045
# 193  LONG 2019-11-06 13:00:00+05:30 2019-11-06 21:00:00+05:30        38129
# 194  LONG 2019-11-11 13:00:00+05:30 2019-11-13 09:00:00+05:30        37848
# 196  LONG 2019-11-15 17:00:00+05:30 2019-11-18 17:00:00+05:30        38040
# 197  LONG 2019-11-26 13:00:00+05:30 2019-11-26 21:00:00+05:30        37750
# 198  LONG 2019-11-28 13:00:00+05:30 2019-11-28 21:00:00+05:30        37725
# 199  LONG 2019-12-10 09:00:00+05:30 2019-12-10 17:00:00+05:30        37677
# 205  LONG 2020-01-15 17:00:00+05:30 2020-01-16 13:00:00+05:30        39700
# 208  LONG 2020-02-05 09:00:00+05:30 2020-02-06 13:00:00+05:30        40298
# 210  LONG 2020-02-12 13:00:00+05:30 2020-02-12 21:00:00+05:30        40470
# 213  LONG 2020-03-16 21:00:00+05:30 2020-03-17 17:00:00+05:30        40169
# 216  LONG 2020-05-05 13:00:00+05:30 2020-05-05 21:00:00+05:30        45680
# 218  LONG 2020-06-03 17:00:00+05:30 2020-06-04 21:00:00+05:30        46718
# 221  LONG 2020-06-08 21:00:00+05:30 2020-06-09 13:00:00+05:30        46160
# 227  LONG 2020-08-12 13:00:00+05:30 2020-08-12 21:00:00+05:30        52460
# 229  LONG 2020-09-25 21:00:00+05:30 2020-09-28 17:00:00+05:30        49699
# 233  LONG 2020-10-29 13:00:00+05:30 2020-10-30 17:00:00+05:30        50617
# 236  LONG 2020-11-10 21:00:00+05:30 2020-11-12 17:00:00+05:30        50618
# 237  LONG 2020-11-20 09:00:00+05:30 2020-11-20 17:00:00+05:30        50197
# 238  LONG 2020-12-01 17:00:00+05:30 2020-12-02 09:00:00+05:30        48640
# 243  LONG 2021-01-11 13:00:00+05:30 2021-01-12 09:00:00+05:30        49390
# 244  LONG 2021-01-18 09:00:00+05:30 2021-01-19 13:00:00+05:30        48995
# 246  LONG 2021-01-27 21:00:00+05:30 2021-01-28 17:00:00+05:30        48980
# 247  LONG 2021-02-01 17:00:00+05:30 2021-02-02 09:00:00+05:30        48550
# 248  LONG 2021-02-05 13:00:00+05:30 2021-02-05 21:00:00+05:30        47250
# 249  LONG 2021-02-19 17:00:00+05:30 2021-02-22 13:00:00+05:30        46490
# 250  LONG 2021-03-08 09:00:00+05:30 2021-03-09 17:00:00+05:30        44780
# 251  LONG 2021-03-15 09:00:00+05:30 2021-03-15 17:00:00+05:30        44964
# 253  LONG 2021-03-26 17:00:00+05:30 2021-03-29 17:00:00+05:30        44788
# 257  LONG 2021-03-31 09:00:00+05:30 2021-03-31 17:00:00+05:30        44488
# 264  LONG 2021-05-03 09:00:00+05:30 2021-05-03 17:00:00+05:30        47197
# 267  LONG 2021-06-14 17:00:00+05:30 2021-06-15 09:00:00+05:30        48675
# 268  LONG 2021-06-21 17:00:00+05:30 2021-06-22 09:00:00+05:30        47155
# 269  LONG 2021-06-24 17:00:00+05:30 2021-06-25 17:00:00+05:30        47159
# 273  LONG 2021-06-30 09:00:00+05:30 2021-06-30 17:00:00+05:30        46744
# 274  LONG 2021-07-22 21:00:00+05:30 2021-07-23 13:00:00+05:30        47690
# 276  LONG 2021-07-27 17:00:00+05:30 2021-07-28 09:00:00+05:30        47642
# 279  LONG 2021-08-10 09:00:00+05:30 2021-08-11 13:00:00+05:30        46112
# 280  LONG 2021-09-01 09:00:00+05:30 2021-09-01 17:00:00+05:30        47190
# 282  LONG 2021-09-03 09:00:00+05:30 2021-09-03 17:00:00+05:30        47140
# 283  LONG 2021-09-13 09:00:00+05:30 2021-09-13 17:00:00+05:30        46959
# 284  LONG 2021-09-13 17:00:00+05:30 2021-09-14 17:00:00+05:30        47043
# 286  LONG 2021-09-17 13:00:00+05:30 2021-09-20 17:00:00+05:30        46239
# 287  LONG 2021-09-27 09:00:00+05:30 2021-09-27 17:00:00+05:30        46186
# 289  LONG 2021-09-30 09:00:00+05:30 2021-09-30 17:00:00+05:30        45956
# 291  LONG 2021-11-03 17:00:00+05:30 2021-11-04 18:00:00+05:30        47458
# 295  LONG 2021-11-25 09:00:00+05:30 2021-11-26 09:00:00+05:30        47592
# 297  LONG 2021-12-29 21:00:00+05:30 2021-12-30 21:00:00+05:30        47866
# 298  LONG 2022-01-10 17:00:00+05:30 2022-01-11 09:00:00+05:30        47499
# 307  LONG 2022-01-31 09:00:00+05:30 2022-01-31 17:00:00+05:30        47693
# 308  LONG 2022-03-16 13:00:00+05:30 2022-03-17 09:00:00+05:30        51519
# 310  LONG 2022-03-30 09:00:00+05:30 2022-03-30 17:00:00+05:30        51247
# 312  LONG 2022-05-11 17:00:00+05:30 2022-05-12 09:00:00+05:30        50888
# 314  LONG 2022-05-16 09:00:00+05:30 2022-05-16 17:00:00+05:30        50116
# 317  LONG 2022-06-15 17:00:00+05:30 2022-06-16 17:00:00+05:30        50861
# 318  LONG 2022-06-21 09:00:00+05:30 2022-06-21 17:00:00+05:30        50860
# 319  LONG 2022-06-24 13:00:00+05:30 2022-06-27 09:00:00+05:30        50741
# 320  LONG 2022-07-08 09:00:00+05:30 2022-07-08 17:00:00+05:30        50747
# 321  LONG 2022-07-12 13:00:00+05:30 2022-07-13 17:00:00+05:30        50794
# 322  LONG 2022-07-15 17:00:00+05:30 2022-07-18 09:00:00+05:30        50249
# 329  LONG 2022-07-21 17:00:00+05:30 2022-07-22 09:00:00+05:30        50480
# 331  LONG 2022-08-22 17:00:00+05:30 2022-08-23 13:00:00+05:30        51233
# 332  LONG 2022-09-01 13:00:00+05:30 2022-09-02 13:00:00+05:30        50293
# 333  LONG 2022-09-19 17:00:00+05:30 2022-09-20 09:00:00+05:30        49410
# 334  LONG 2022-09-27 17:00:00+05:30 2022-09-28 17:00:00+05:30        49499
# 335  LONG 2022-10-20 09:00:00+05:30 2022-10-20 17:00:00+05:30        50386
# 337  LONG 2022-10-24 18:00:00+05:30 2022-10-25 17:00:00+05:30        50700
# 338  LONG 2022-10-31 17:00:00+05:30 2022-11-01 09:00:00+05:30        50447
# 351  LONG 2023-02-10 17:00:00+05:30 2023-02-13 09:00:00+05:30        56865
# 352  LONG 2023-02-13 09:00:00+05:30 2023-02-14 17:00:00+05:30        56920
# 353  LONG 2023-02-16 09:00:00+05:30 2023-02-16 21:00:00+05:30        56258
# 354  LONG 2023-02-16 21:00:00+05:30 2023-02-17 21:00:00+05:30        56279
# 355  LONG 2023-02-27 21:00:00+05:30 2023-02-28 17:00:00+05:30        55497
# 360  LONG 2023-03-08 21:00:00+05:30 2023-03-09 17:00:00+05:30        55112
# 362  LONG 2023-04-25 09:00:00+05:30 2023-04-25 21:00:00+05:30        60217
# 363  LONG 2023-04-28 17:00:00+05:30 2023-05-01 17:00:00+05:30        60050
# 364  LONG 2023-05-24 09:00:00+05:30 2023-05-24 17:00:00+05:30        60285
# 365  LONG 2023-05-29 09:00:00+05:30 2023-05-29 17:00:00+05:30        59539
# 368  LONG 2023-06-14 17:00:00+05:30 2023-06-16 13:00:00+05:30        59465
# 369  LONG 2023-06-22 17:00:00+05:30 2023-06-23 17:00:00+05:30        58608
# 370  LONG 2023-06-29 17:00:00+05:30 2023-06-30 17:00:00+05:30        58140
# 375  LONG 2023-07-28 09:00:00+05:30 2023-07-28 17:00:00+05:30        59198
# 376  LONG 2023-08-10 09:00:00+05:30 2023-08-10 17:00:00+05:30        59130
# 377  LONG 2023-08-18 17:00:00+05:30 2023-08-21 17:00:00+05:30        58580
# 380  LONG 2023-08-21 17:00:00+05:30 2023-08-22 09:00:00+05:30        58640
# 382  LONG 2023-09-11 09:00:00+05:30 2023-09-11 17:00:00+05:30        59099
# 383  LONG 2023-09-13 17:00:00+05:30 2023-09-15 09:00:00+05:30        58695
# 385  LONG 2023-10-06 09:00:00+05:30 2023-10-06 17:00:00+05:30        56739
# 387  LONG 2023-10-09 09:00:00+05:30 2023-10-09 21:00:00+05:30        57561
# 391  LONG 2023-11-13 13:00:00+05:30 2023-11-13 21:00:00+05:30        59772
# 392  LONG 2023-12-12 09:00:00+05:30 2023-12-12 17:00:00+05:30        61415
# 396  LONG 2024-01-04 21:00:00+05:30 2024-01-05 17:00:00+05:30        62750
# 397  LONG 2024-01-11 09:00:00+05:30 2024-01-11 17:00:00+05:30        62235
# 398  LONG 2024-01-18 09:00:00+05:30 2024-01-18 17:00:00+05:30        61724
# 400  LONG 2024-02-12 17:00:00+05:30 2024-02-13 17:00:00+05:30        62328
# 402  LONG 2024-02-14 21:00:00+05:30 2024-02-15 17:00:00+05:30        61478
# 407  LONG 2024-04-24 09:00:00+05:30 2024-04-24 17:00:00+05:30        71190
# 408  LONG 2024-04-25 17:00:00+05:30 2024-04-26 09:00:00+05:30        71580
# 409  LONG 2024-05-03 09:00:00+05:30 2024-05-03 17:00:00+05:30        70804
# 411  LONG 2024-05-03 17:00:00+05:30 2024-05-06 13:00:00+05:30        71129
# 414  LONG 2024-05-24 17:00:00+05:30 2024-05-27 09:00:00+05:30        71685
# 415  LONG 2024-06-10 21:00:00+05:30 2024-06-11 17:00:00+05:30        71490
# 417  LONG 2024-06-18 09:00:00+05:30 2024-06-18 21:00:00+05:30        71692
#
#      Initial SL  Initial Target                 Exit Time  Exit Price  \
# 1         25612      29837.9000 2015-04-09 09:00:00+05:30  26506.0000
# 7         27072      31220.2000 2015-05-26 09:00:00+05:30  27072.0000
# 8         26712      30918.9000 2015-06-01 13:00:00+05:30  26712.0000
# 9         26725      30866.0000 2015-06-11 13:00:00+05:30  26853.0000
# 10        26803      30945.3500 2015-06-22 13:00:00+05:30  26915.0000
# 11        26181      30265.7000 2015-07-07 17:00:00+05:30  26181.0000
# 12        26040      30071.3500 2015-07-10 21:00:00+05:30  26040.0000
# 13        24733      28646.5000 2015-07-28 13:00:00+05:30  24733.0000
# 17        24565      28539.5500 2015-08-27 21:00:00+05:30  26291.0000
# 19        25940      29963.2500 2015-09-22 17:00:00+05:30  26265.0000
# 23        25786      29762.0000 2015-11-06 17:00:00+05:30  25786.0000
# 24        25481      29605.6000 2015-11-11 17:00:00+05:30  25481.0000
# 25        24997      28950.1000 2015-11-27 17:00:00+05:30  24997.0000
# 32        24801      28701.7000 2016-02-11 09:00:00+05:30  28701.7000
# 36        28855      33580.0000 2016-03-23 09:00:00+05:30  28855.0000
# 37        28356      32792.2500 2016-04-01 17:00:00+05:30  28356.0000
# 41        29623      34316.0000 2016-05-23 09:00:00+05:30  29623.0000
# 44        28410      32878.5000 2016-06-22 17:00:00+05:30  30147.0000
# 46        30836      35765.0000 2016-07-20 17:00:00+05:30  30836.0000
# 48        30705      35533.8500 2016-08-05 21:00:00+05:30  31210.0000
# 50        31020      35889.2000 2016-08-11 21:00:00+05:30  31315.0000
# 51        31316      36127.2500 2016-08-19 17:00:00+05:30  31316.0000
# 52        30610      35499.3500 2016-09-02 17:00:00+05:30  30610.0000
# 53        30560      35724.7500 2016-09-14 21:00:00+05:30  31015.0000
# 55        30800      35574.1000 2016-09-27 17:00:00+05:30  31006.0000
# 57        30866      35694.8500 2016-09-30 21:00:00+05:30  30966.0000
# 58        29565      34252.7500 2016-10-14 17:00:00+05:30  29565.0000
# 59        29568      34158.4500 2016-10-24 21:00:00+05:30  29743.0000
# 62        28800      33327.0000 2016-11-23 17:00:00+05:30  28800.0000
# 63        27475      31795.2000 2016-12-15 09:00:00+05:30  27401.0000
# 64        27017      31219.0500 2016-12-16 21:00:00+05:30  27017.0000
# 65        26972      31355.9000 2016-12-21 21:00:00+05:30  26972.0000
# 68        26910      31098.3000 2017-01-25 17:00:00+05:30  28434.0000
# 72        28203      32686.4500 2017-02-21 13:00:00+05:30  29134.0000
# 76        28210      32683.0000 2017-03-30 21:00:00+05:30  28520.0000
# 81        28660      33108.5000 2017-05-01 21:00:00+05:30  28660.0000
# 85        27932      32306.9500 2017-06-09 17:00:00+05:30  28964.0000
# 86        28865      33407.5000 2017-06-15 09:00:00+05:30  28865.0000
# 87        28487      32888.8500 2017-06-21 17:00:00+05:30  28487.0000
# 88        28544      33023.4000 2017-06-26 17:00:00+05:30  28450.0000
# 89        28473      32945.2000 2017-06-29 13:00:00+05:30  28473.0000
# 90        28005      32404.7000 2017-07-07 13:00:00+05:30  28005.0000
# 93        27635      31993.0000 2017-08-03 09:00:00+05:30  28377.0000
# 94        28390      32761.2000 2017-08-08 17:00:00+05:30  28390.0000
# 101       29571      34251.6000 2017-09-21 09:00:00+05:30  29555.0000
# 102       29443      34066.4500 2017-09-27 17:00:00+05:30  29686.0000
# 103       29498      34005.5000 2017-10-04 13:00:00+05:30  29498.0000
# 104       29381      33925.0000 2017-10-06 17:00:00+05:30  29381.0000
# 107       29522      34072.2000 2017-10-23 09:00:00+05:30  29500.0000
# 108       29210      33741.0000 2017-10-31 17:00:00+05:30  29210.0000
# 109       29210      33711.1000 2017-11-02 17:00:00+05:30  29210.0000
# 111       29081      33603.0000 2017-11-17 09:00:00+05:30  29410.0000
# 112       29175      33665.1000 2017-12-01 21:00:00+05:30  29175.0000
# 117       28080      32446.1000 2018-02-07 17:00:00+05:30  30070.0000
# 119       29896      34666.7500 2018-02-27 17:00:00+05:30  30442.0000
# 121       30287      35012.9000 2018-03-08 17:00:00+05:30  30422.0000
# 122       30267      34893.3000 2018-03-13 17:00:00+05:30  30267.0000
# 123       30145      34901.3500 2018-03-29 17:00:00+05:30  30457.0000
# 128       30897      35666.1000 2018-05-08 09:00:00+05:30  31195.0000
# 129       30923      35700.6000 2018-05-21 09:00:00+05:30  30923.0000
# 131       30960      35796.0500 2018-05-25 17:00:00+05:30  31217.0000
# 132       30890      35663.8000 2018-06-06 13:00:00+05:30  30890.0000
# 134       30871      35677.6000 2018-06-15 17:00:00+05:30  31090.0000
# 135       30929      35679.9000 2018-06-19 17:00:00+05:30  30929.0000
# 136       30515      35229.1000 2018-06-26 13:00:00+05:30  30515.0000
# 137       30470      35224.5000 2018-06-29 09:00:00+05:30  30460.0000
# 138       30367      35055.4500 2018-07-02 21:00:00+05:30  30367.0000
# 141       30014      34710.4500 2018-07-17 17:00:00+05:30  30014.0000
# 142       29662      34298.7500 2018-07-27 13:00:00+05:30  29662.0000
# 143       29556      34130.8500 2018-08-14 09:00:00+05:30  29694.0000
# 144       29310      33868.6500 2018-08-23 09:00:00+05:30  29588.0000
# 149       31760      36673.5000 2018-10-31 13:00:00+05:30  31760.0000
# 150       31711      36624.0500 2018-11-02 09:00:00+05:30  31711.0000
# 151       31708      36610.2500 2018-11-06 21:00:00+05:30  31708.0000
# 152       30654      35577.5500 2018-11-22 21:00:00+05:30  30654.0000
# 153       30445      35256.7000 2018-11-27 21:00:00+05:30  30445.0000
# 156       30180      34983.0000 2018-12-18 13:00:00+05:30  31224.0000
# 158       31026      36044.4500 2018-12-31 09:00:00+05:30  31384.0000
# 165       31601      36501.0000 2019-03-28 17:00:00+05:30  31730.0000
# 166       31684      36573.4500 2019-04-04 17:00:00+05:30  31684.0000
# 169       31403      36358.4000 2019-04-30 21:00:00+05:30  31765.0000
# 170       31513      36367.6000 2019-05-17 17:00:00+05:30  31780.0000
# 171       31391      36184.7500 2019-05-23 09:00:00+05:30  31347.0000
# 176       31485      36446.9500 2019-07-01 09:00:00+05:30  33693.0000
# 184       37449      43887.4500 2019-09-20 09:00:00+05:30  37449.0000
# 186       37490      43642.5000 2019-09-25 17:00:00+05:30  37828.0000
# 190       37822      43642.5000 2019-10-28 17:00:00+05:30  37947.0000
# 191       37801      43751.7500 2019-11-05 17:00:00+05:30  38020.0000
# 193       37906      43848.3500 2019-11-07 21:00:00+05:30  37906.0000
# 194       37601      43525.2000 2019-11-15 09:00:00+05:30  37968.0000
# 196       37930      43746.0000 2019-11-19 13:00:00+05:30  38022.0000
# 197       37520      43412.5000 2019-11-27 21:00:00+05:30  37520.0000
# 198       37540      43383.7500 2019-12-06 17:00:00+05:30  37732.0000
# 199       37534      43328.5500 2019-12-11 09:00:00+05:30  37534.0000
# 205       39477      45655.0000 2020-01-21 13:00:00+05:30  39885.0000
# 208       39900      46342.7000 2020-02-11 09:00:00+05:30  40455.0000
# 210       40306      46540.5000 2020-02-28 21:00:00+05:30  41300.0000
# 213       38400      46194.3500 2020-04-13 09:00:00+05:30  46194.3500
# 216       45311      52532.0000 2020-05-08 17:00:00+05:30  45880.0000
# 218       45673      53725.7000 2020-06-05 17:00:00+05:30  45673.0000
# 221       45748      53084.0000 2020-07-06 09:00:00+05:30  48040.0000
# 227       49955      60329.0000 2020-09-21 13:00:00+05:30  51151.0000
# 229       49315      57153.8500 2020-10-07 09:00:00+05:30  50272.0000
# 233       50070      58209.5500 2020-11-04 21:00:00+05:30  50810.0000
# 236       50283      58210.7000 2020-11-16 17:00:00+05:30  50283.0000
# 237       49857      57726.5500 2020-11-23 17:00:00+05:30  49857.0000
# 238       47861      55936.0000 2020-12-04 17:00:00+05:30  49128.0000
# 243       48635      56798.5000 2021-01-15 21:00:00+05:30  48635.0000
# 244       48537      56344.2500 2021-01-27 17:00:00+05:30  48537.0000
# 246       48511      56327.0000 2021-02-01 09:00:00+05:30  48511.0000
# 247       47200      55832.5000 2021-02-04 17:00:00+05:30  47200.0000
# 248       46806      54337.5000 2021-02-16 17:00:00+05:30  46806.0000
# 249       45907      53463.5000 2021-02-26 17:00:00+05:30  45907.0000
# 250       44301      51497.0000 2021-03-12 17:00:00+05:30  44301.0000
# 251       44401      51708.6000 2021-03-22 09:00:00+05:30  44729.0000
# 253       44441      51506.2000 2021-03-30 09:00:00+05:30  44441.0000
# 257       44215      51161.2000 2021-04-28 09:00:00+05:30  46936.0000
# 264       46635      54276.5500 2021-06-03 17:00:00+05:30  48620.0000
# 267       48105      55976.2500 2021-06-17 09:00:00+05:30  48105.0000
# 268       46825      54228.2500 2021-06-24 09:00:00+05:30  46825.0000
# 269       46843      54232.8500 2021-06-29 13:00:00+05:30  46843.0000
# 273       46461      53755.6000 2021-07-20 17:00:00+05:30  47868.0000
# 274       47340      54843.5000 2021-07-23 17:00:00+05:30  47340.0000
# 276       47440      54788.3000 2021-08-02 09:00:00+05:30  47840.0000
# 279       45815      53028.8000 2021-08-27 13:00:00+05:30  47020.0000
# 280       46936      54268.5000 2021-09-02 17:00:00+05:30  46936.0000
# 282       46951      54211.0000 2021-09-07 17:00:00+05:30  46951.0000
# 283       46780      54002.8500 2021-09-13 17:00:00+05:30  46780.0000
# 284       46766      54099.4500 2021-09-14 17:00:00+05:30  46766.0000
# 286       45853      53174.8500 2021-09-24 17:00:00+05:30  45853.0000
# 287       45902      53113.9000 2021-09-28 09:00:00+05:30  45902.0000
# 289       45511      52849.4000 2021-10-29 17:00:00+05:30  47530.0000
# 291       46872      54576.7000 2021-11-22 17:00:00+05:30  48098.0000
# 295       47310      54730.8000 2021-12-21 09:00:00+05:30  48000.0000
# 297       47577      55045.9000 2022-01-06 13:00:00+05:30  47577.0000
# 298       47313      54623.8500 2022-01-13 17:00:00+05:30  47740.0000
# 307       47499      54846.9500 2022-03-08 17:00:00+05:30  54846.9500
# 308       51028      59246.8500 2022-03-29 13:00:00+05:30  51028.0000
# 310       50735      58934.0500 2022-04-04 09:00:00+05:30  51507.0000
# 312       50402      58521.2000 2022-05-12 21:00:00+05:30  50402.0000
# 314       49572      57633.4000 2022-06-01 09:00:00+05:30  50570.0000
# 317       50351      58490.1500 2022-06-16 17:00:00+05:30  50351.0000
# 318       50650      58489.0000 2022-06-22 09:00:00+05:30  50650.0000
# 319       50410      58352.1500 2022-06-27 17:00:00+05:30  50605.0000
# 320       50510      58359.0500 2022-07-08 17:00:00+05:30  50510.0000
# 321       50482      58413.1000 2022-07-13 17:00:00+05:30  50482.0000
# 322       49957      57786.3500 2022-07-21 09:00:00+05:30  49957.0000
# 329       49703      58052.0000 2022-08-17 13:00:00+05:30  51725.0000
# 331       50971      58917.9500 2022-08-29 09:00:00+05:30  50971.0000
# 332       49876      57836.9500 2022-09-15 09:00:00+05:30  49876.0000
# 333       49053      56821.5000 2022-09-23 09:00:00+05:30  49894.0000
# 334       49250      56923.8500 2022-09-28 17:00:00+05:30  49250.0000
# 335       50065      57943.9000 2022-10-21 09:00:00+05:30  50065.0000
# 337       50351      58305.0000 2022-10-28 09:00:00+05:30  50551.0000
# 338       50161      58014.0500 2022-11-03 09:00:00+05:30  50230.0000
# 351       56550      65394.7500 2023-02-13 09:00:00+05:30  56550.0000
# 352       56502      65458.0000 2023-02-14 17:00:00+05:30  56502.0000
# 353       56011      64696.7000 2023-02-16 21:00:00+05:30  56011.0000
# 354       55750      64720.8500 2023-02-23 13:00:00+05:30  55750.0000
# 355       55279      63821.5500 2023-03-07 17:00:00+05:30  55279.0000
# 360       54771      63378.8000 2023-04-19 09:00:00+05:30  60201.0000
# 362       59781      69249.5500 2023-04-27 17:00:00+05:30  59781.0000
# 363       59625      69057.5000 2023-05-12 13:00:00+05:30  60611.0000
# 364       59980      69327.7500 2023-05-24 17:00:00+05:30  59980.0000
# 365       59271      68469.8500 2023-05-29 21:00:00+05:30  59271.0000
# 368       59148      68384.7500 2023-06-19 13:00:00+05:30  59148.0000
# 369       58150      67399.2000 2023-06-27 17:00:00+05:30  58150.0000
# 370       57651      66861.0000 2023-07-06 17:00:00+05:30  58391.0000
# 375       58818      68077.7000 2023-08-02 17:00:00+05:30  59369.0000
# 376       58906      67999.5000 2023-08-10 17:00:00+05:30  58906.0000
# 377       58340      67367.0000 2023-08-21 17:00:00+05:30  58340.0000
# 380       58282      67436.0000 2023-09-07 09:00:00+05:30  59000.0000
# 382       58864      67963.8500 2023-09-12 09:00:00+05:30  58864.0000
# 383       58527      67499.2500 2023-09-21 13:00:00+05:30  58859.0000
# 385       56522      65249.8500 2023-10-06 17:00:00+05:30  56522.0000
# 387       56800      66195.1500 2023-11-06 21:00:00+05:30  60779.0000
# 391       59490      68737.8000 2023-12-08 17:00:00+05:30  62100.0000
# 392       61099      70627.2500 2023-12-13 09:00:00+05:30  61099.0000
# 396       62476      72162.5000 2024-01-08 09:00:00+05:30  62411.0000
# 397       61966      71570.2500 2024-01-11 21:00:00+05:30  61966.0000
# 398       61454      70982.6000 2024-01-29 21:00:00+05:30  62066.0000
# 400       61926      71677.2000 2024-02-13 17:00:00+05:30  61926.0000
# 402       61190      70699.7000 2024-02-22 17:00:00+05:30  61970.0000
# 407       70730      81868.5000 2024-04-25 09:00:00+05:30  70730.0000
# 408       70805      82317.0000 2024-04-30 17:00:00+05:30  70805.0000
# 409       70553      81424.6000 2024-05-03 17:00:00+05:30  70553.0000
# 411       70082      81798.3500 2024-05-09 09:00:00+05:30  71041.0000
# 414       71211      82437.7500 2024-06-07 13:00:00+05:30  72029.0000
# 415       71004      82213.5000 2024-06-13 21:00:00+05:30  71004.0000
# 417       71175      82445.8000 2024-06-21 17:00:00+05:30  71784.0000
#
#         Points  Slippages          Remarks       Qty          PnL  \
# 1     560.0000   262.2600  Trailing SL Hit  299.4012  167664.6707
# 7     -76.0000   271.1000   Initial SL Hit 1315.7895 -100000.0000
# 8    -174.0000   267.9900   Initial SL Hit  574.7126 -100000.0000
# 9      13.0000   268.4650  Trailing SL Hit  869.5652   11304.3478
# 10      6.0000   269.1200  Trailing SL Hit  943.3962    5660.3774
# 11   -137.0000   262.4950   Initial SL Hit  729.9270 -100000.0000
# 12   -109.0000   260.9450   Initial SL Hit  917.4312 -100000.0000
# 13   -177.0000   248.2150   Initial SL Hit  564.9718 -100000.0000
# 17   1474.0000   255.5400  Trailing SL Hit  396.8254  584920.6349
# 19    210.0000   261.6000  Trailing SL Hit  869.5652  182608.6957
# 23    -94.0000   258.3300   Initial SL Hit 1063.8298 -100000.0000
# 24   -263.0000   256.1250   Initial SL Hit  380.2281 -100000.0000
# 25   -177.0000   250.8550   Initial SL Hit  564.9718 -100000.0000
# 32   3743.7000   268.2985       Target Hit  636.9427 2384522.2930
# 36   -345.0000   290.2750   Initial SL Hit  289.8551 -100000.0000
# 37   -159.0000   284.3550   Initial SL Hit  628.9308 -100000.0000
# 41   -217.0000   297.3150   Initial SL Hit  460.8295 -100000.0000
# 44   1557.0000   293.6850  Trailing SL Hit  555.5556  865000.0000
# 46   -264.0000   309.6800   Initial SL Hit  378.7879 -100000.0000
# 48    311.0000   310.5450  Trailing SL Hit  515.4639  160309.2784
# 50    107.0000   312.6150  Trailing SL Hit  531.9149   56914.8936
# 51    -99.0000   313.6550   Initial SL Hit 1010.1010 -100000.0000
# 52   -259.0000   307.3950   Initial SL Hit  386.1004 -100000.0000
# 53    -50.0000   310.4000  Trailing SL Hit  198.0198   -9900.9901
# 55     72.0000   309.7000  Trailing SL Hit  746.2687   53731.3433
# 57    -73.0000   310.0250  Trailing SL Hit  578.0347  -42196.5318
# 58   -220.0000   296.7500   Initial SL Hit  454.5455 -100000.0000
# 59     40.0000   297.2300  Trailing SL Hit  740.7407   29629.6296
# 62   -180.0000   288.9000   Initial SL Hit  555.5556 -100000.0000
# 63   -247.0000   275.2450           Gap SL  578.0347 -142774.5665
# 64   -130.0000   270.8200   Initial SL Hit  769.2308 -100000.0000
# 65   -294.0000   271.1900   Initial SL Hit  340.1361 -100000.0000
# 68   1392.0000   277.3800  Trailing SL Hit  757.5758 1054545.4545
# 72    711.0000   287.7850  Trailing SL Hit  454.5455  323181.8182
# 76    100.0000   284.7000  Trailing SL Hit  476.1905   47619.0476
# 81   -130.0000   287.2500   Initial SL Hit  769.2308 -100000.0000
# 85    871.0000   285.2850  Trailing SL Hit  621.1180  540993.7888
# 86   -185.0000   289.5750   Initial SL Hit  540.5405 -100000.0000
# 87   -112.0000   285.4300   Initial SL Hit  892.8571 -100000.0000
# 88   -266.0000   285.8300           Gap SL  581.3953 -154651.1628
# 89   -175.0000   285.6050   Initial SL Hit  571.4286 -100000.0000
# 90   -173.0000   280.9150   Initial SL Hit  578.0347 -100000.0000
# 93    557.0000   280.9850  Trailing SL Hit  540.5405  301081.0811
# 94    -98.0000   284.3900   Initial SL Hit 1020.4082 -100000.0000
# 101  -229.0000   296.6950           Gap SL  469.4836 -107511.7371
# 102    63.0000   296.5450  Trailing SL Hit  555.5556   35000.0000
# 103   -72.0000   295.3400   Initial SL Hit 1388.8889 -100000.0000
# 104  -119.0000   294.4050   Initial SL Hit  840.3361 -100000.0000
# 107  -128.0000   295.6400           Gap SL  943.3962 -120754.7170
# 108  -130.0000   292.7500   Initial SL Hit  769.2308 -100000.0000
# 109  -104.0000   292.6200   Initial SL Hit  961.5385 -100000.0000
# 111   190.0000   293.1500  Trailing SL Hit  719.4245  136690.6475
# 112   -99.0000   292.2450   Initial SL Hit 1010.1010 -100000.0000
# 117  1856.0000   291.4200  Trailing SL Hit  746.2687 1385074.6269
# 119   297.0000   302.9350  Trailing SL Hit  401.6064  119277.1084
# 121   -24.0000   304.3400  Trailing SL Hit  628.9308  -15094.3396
# 122   -75.0000   303.0450   Initial SL Hit 1333.3333 -100000.0000
# 123   108.0000   304.0300  Trailing SL Hit  490.1961   52941.1765
# 128   181.0000   311.0450  Trailing SL Hit  854.7009  154700.8547
# 129  -121.0000   309.8350   Initial SL Hit  826.4463 -100000.0000
# 131    90.0000   311.7200  Trailing SL Hit  598.8024   53892.2156
# 132  -122.0000   309.5100   Initial SL Hit  819.6721 -100000.0000
# 134    66.0000   310.5700  Trailing SL Hit  653.5948   43137.2549
# 135   -97.0000   309.7750   Initial SL Hit 1030.9278 -100000.0000
# 136  -119.0000   305.7450   Initial SL Hit  840.3361 -100000.0000
# 137  -170.0000   305.4500           Gap SL  625.0000 -106250.0000
# 138  -116.0000   304.2500   Initial SL Hit  862.0690 -100000.0000
# 141  -169.0000   300.9850   Initial SL Hit  591.7160 -100000.0000
# 142  -163.0000   297.4350   Initial SL Hit  613.4969 -100000.0000
# 143    15.0000   296.8650  Trailing SL Hit  813.0081   12195.1220
# 144   137.0000   295.1950  Trailing SL Hit  709.2199   97163.1206
# 149  -130.0000   318.2500   Initial SL Hit  769.2308 -100000.0000
# 150  -136.0000   317.7900   Initial SL Hit  735.2941 -100000.0000
# 151  -127.0000   317.7150   Initial SL Hit  787.4016 -100000.0000
# 152  -283.0000   307.9550   Initial SL Hit  353.3569 -100000.0000
# 153  -213.0000   305.5150   Initial SL Hit  469.4836 -100000.0000
# 156   804.0000   308.2200  Trailing SL Hit  416.6667  335000.0000
# 158    41.0000   313.6350  Trailing SL Hit  315.4574   12933.7539
# 165   -10.0000   317.3500  Trailing SL Hit  719.4245   -7194.2446
# 166  -119.0000   317.4350   Initial SL Hit  840.3361 -100000.0000
# 169   149.0000   316.9050  Trailing SL Hit  469.4836   69953.0516
# 170   156.0000   317.0200  Trailing SL Hit  900.9009  140540.5405
# 171  -118.0000   314.0600           Gap SL 1351.3514 -159459.4595
# 176  2000.0000   326.9300  Trailing SL Hit  480.7692  961538.4615
# 184  -714.0000   378.0600   Initial SL Hit  140.0560 -100000.0000
# 186  -122.0000   378.8900  Trailing SL Hit  217.3913  -26521.7391
# 190    -3.0000   379.4850  Trailing SL Hit  781.2500   -2343.7500
# 191   -25.0000   380.3250  Trailing SL Hit  409.8361  -10245.9016
# 193  -223.0000   380.1750   Initial SL Hit  448.4305 -100000.0000
# 194   120.0000   379.0800  Trailing SL Hit  404.8583   48582.9960
# 196   -18.0000   380.3100  Trailing SL Hit  909.0909  -16363.6364
# 197  -230.0000   376.3500   Initial SL Hit  434.7826 -100000.0000
# 198     7.0000   377.2850  Trailing SL Hit  540.5405    3783.7838
# 199  -143.0000   376.0550   Initial SL Hit  699.3007 -100000.0000
# 205   185.0000   397.9250  Trailing SL Hit  448.4305   82959.6413
# 208   157.0000   403.7650  Trailing SL Hit  251.2563   39447.2362
# 210   830.0000   408.8500  Trailing SL Hit  609.7561  506097.5610
# 213  6025.3500   431.8168       Target Hit   56.5291  340607.6880
# 216   200.0000   457.8000  Trailing SL Hit  271.0027   54200.5420
# 218 -1045.0000   461.9550   Initial SL Hit   95.6938 -100000.0000
# 221  1880.0000   471.0000  Trailing SL Hit  242.7184  456310.6796
# 227 -1309.0000   518.0550  Trailing SL Hit   39.9202  -52255.4890
# 229   573.0000   499.8550  Trailing SL Hit  260.4167  149218.7500
# 233   193.0000   507.1350  Trailing SL Hit  182.8154   35283.3638
# 236  -335.0000   504.5050   Initial SL Hit  298.5075 -100000.0000
# 237  -340.0000   500.2700   Initial SL Hit  294.1176 -100000.0000
# 238   488.0000   488.8400  Trailing SL Hit  128.3697   62644.4159
# 243  -755.0000   490.1250   Initial SL Hit  132.4503 -100000.0000
# 244  -458.0000   487.6600   Initial SL Hit  218.3406 -100000.0000
# 246  -469.0000   487.4550   Initial SL Hit  213.2196 -100000.0000
# 247 -1350.0000   478.7500   Initial SL Hit   74.0741 -100000.0000
# 248  -444.0000   470.2800   Initial SL Hit  225.2252 -100000.0000
# 249  -583.0000   461.9850   Initial SL Hit  171.5266 -100000.0000
# 250  -479.0000   445.4050   Initial SL Hit  208.7683 -100000.0000
# 251  -235.0000   448.4650  Trailing SL Hit  177.6199  -41740.6750
# 253  -347.0000   446.1450   Initial SL Hit  288.1844 -100000.0000
# 257  2448.0000   457.1200  Trailing SL Hit  366.3004  896703.2967
# 264  1423.0000   479.0850  Trailing SL Hit  177.9359  253202.8470
# 267  -570.0000   483.9000   Initial SL Hit  175.4386 -100000.0000
# 268  -330.0000   469.9000   Initial SL Hit  303.0303 -100000.0000
# 269  -316.0000   470.0100   Initial SL Hit  316.4557 -100000.0000
# 273  1124.0000   473.0600  Trailing SL Hit  353.3569  397173.1449
# 274  -350.0000   475.1500   Initial SL Hit  285.7143 -100000.0000
# 276   198.0000   477.4100  Trailing SL Hit  495.0495   98019.8020
# 279   908.0000   465.6600  Trailing SL Hit  336.7003  305723.9057
# 280  -254.0000   470.6300   Initial SL Hit  393.7008 -100000.0000
# 282  -189.0000   470.4550   Initial SL Hit  529.1005 -100000.0000
# 283  -179.0000   468.6950   Initial SL Hit  558.6592 -100000.0000
# 284  -277.0000   469.0450   Initial SL Hit  361.0108 -100000.0000
# 286  -386.0000   460.4600   Initial SL Hit  259.0674 -100000.0000
# 287  -284.0000   460.4400   Initial SL Hit  352.1127 -100000.0000
# 289  1574.0000   467.4300  Trailing SL Hit  224.7191  353707.8652
# 291   640.0000   477.7800  Trailing SL Hit  170.6485  109215.0171
# 295   408.0000   477.9600  Trailing SL Hit  354.6099  144680.8511
# 297  -289.0000   477.2150   Initial SL Hit  346.0208 -100000.0000
# 298   241.0000   476.1950  Trailing SL Hit  537.6344  129569.8925
# 307  7153.9500   512.6997       Target Hit  515.4639 3687603.0928
# 308  -491.0000   512.7350   Initial SL Hit  203.6660 -100000.0000
# 310   260.0000   513.7700  Trailing SL Hit  195.3125   50781.2500
# 312  -486.0000   506.4500   Initial SL Hit  205.7613 -100000.0000
# 314   454.0000   503.4300  Trailing SL Hit  183.8235   83455.8824
# 317  -510.0000   506.0600   Initial SL Hit  196.0784 -100000.0000
# 318  -210.0000   507.5500   Initial SL Hit  476.1905 -100000.0000
# 319  -136.0000   506.7300  Trailing SL Hit  302.1148  -41087.6133
# 320  -237.0000   506.2850   Initial SL Hit  421.9409 -100000.0000
# 321  -312.0000   506.3800   Initial SL Hit  320.5128 -100000.0000
# 322  -292.0000   501.0300   Initial SL Hit  342.4658 -100000.0000
# 329  1245.0000   511.0250  Trailing SL Hit  128.7001  160231.6602
# 331  -262.0000   511.0200   Initial SL Hit  381.6794 -100000.0000
# 332  -417.0000   500.8450   Initial SL Hit  239.8082 -100000.0000
# 333   484.0000   496.5200  Trailing SL Hit  280.1120  135574.2297
# 334  -249.0000   493.7450   Initial SL Hit  401.6064 -100000.0000
# 335  -321.0000   502.2550   Initial SL Hit  311.5265 -100000.0000
# 337  -149.0000   506.2550  Trailing SL Hit  286.5330  -42693.4097
# 338  -217.0000   503.3850  Trailing SL Hit  349.6503  -75874.1259
# 351  -315.0000   567.0750   Initial SL Hit  317.4603 -100000.0000
# 352  -418.0000   567.1100   Initial SL Hit  239.2344 -100000.0000
# 353  -247.0000   561.3450   Initial SL Hit  404.8583 -100000.0000
# 354  -529.0000   560.1450   Initial SL Hit  189.0359 -100000.0000
# 355  -218.0000   553.8800   Initial SL Hit  458.7156 -100000.0000
# 360  5089.0000   576.5650  Trailing SL Hit  293.2551 1492375.3666
# 362  -436.0000   599.9900   Initial SL Hit  229.3578 -100000.0000
# 363   561.0000   603.3050  Trailing SL Hit  235.2941  132000.0000
# 364  -305.0000   601.3250   Initial SL Hit  327.8689 -100000.0000
# 365  -268.0000   594.0500   Initial SL Hit  373.1343 -100000.0000
# 368  -317.0000   593.0650   Initial SL Hit  315.4574 -100000.0000
# 369  -458.0000   583.7900   Initial SL Hit  218.3406 -100000.0000
# 370   251.0000   582.6550  Trailing SL Hit  204.4990   51329.2434
# 375   171.0000   592.8350  Trailing SL Hit  263.1579   45000.0000
# 376  -224.0000   590.1800   Initial SL Hit  446.4286 -100000.0000
# 377  -240.0000   584.6000   Initial SL Hit  416.6667 -100000.0000
# 380   360.0000   588.2000  Trailing SL Hit  279.3296  100558.6592
# 382  -235.0000   589.8150   Initial SL Hit  425.5319 -100000.0000
# 383   164.0000   587.7700  Trailing SL Hit  595.2381   97619.0476
# 385  -217.0000   566.3050   Initial SL Hit  460.8295 -100000.0000
# 387  3218.0000   591.7000  Trailing SL Hit  131.4060  422864.6518
# 391  2328.0000   609.3600  Trailing SL Hit  354.6099  825531.9149
# 392  -316.0000   612.5700   Initial SL Hit  316.4557 -100000.0000
# 396  -339.0000   625.8050           Gap SL  364.9635 -123722.6277
# 397  -269.0000   621.0050   Initial SL Hit  371.7472 -100000.0000
# 398   342.0000   618.9500  Trailing SL Hit  370.3704  126666.6667
# 400  -402.0000   621.2700   Initial SL Hit  248.7562 -100000.0000
# 402   492.0000   617.2400  Trailing SL Hit  347.2222  170833.3333
# 407  -460.0000   709.6000   Initial SL Hit  217.3913 -100000.0000
# 408  -775.0000   711.9250   Initial SL Hit  129.0323 -100000.0000
# 409  -251.0000   706.7850   Initial SL Hit  398.4064 -100000.0000
# 411   -88.0000   710.8500  Trailing SL Hit   95.5110   -8404.9666
# 414   344.0000   718.5700  Trailing SL Hit  210.9705   72573.8397
# 415  -486.0000   712.4700   Initial SL Hit  205.7613 -100000.0000
# 417    92.0000   717.3800  Trailing SL Hit  193.4236   17794.9710
#
#         PnL w cs    ROI%  Trade Year  ROI% w cs
# 1     89143.7126  0.8914        2015     0.8914
# 7   -456710.5263 -4.5671        2015    -4.5671
# 8   -254017.2414 -2.5402        2015    -2.5402
# 9   -222143.4783 -2.2214        2015    -2.2214
# 10  -248226.4151 -2.4823        2015    -2.4823
# 11  -291602.1898 -2.9160        2015    -2.9160
# 12  -339399.0826 -3.3940        2015    -3.3940
# 13  -240234.4633 -2.4023        2015    -2.4023
# 17   483515.8730  4.8352        2015     4.8352
# 19   -44869.5652 -0.4487        2015    -0.4487
# 23  -374819.1489 -3.7482        2015    -3.7482
# 24  -197385.9316 -1.9739        2015    -1.9739
# 25  -241725.9887 -2.4173        2015    -2.4173
# 32  2213631.5287 22.1363        2015    22.1363
# 36  -184137.6812 -1.8414        2016    -1.8414
# 37  -278839.6226 -2.7884        2016    -2.7884
# 41  -237011.5207 -2.3701        2016    -2.3701
# 44   701841.6667  7.0184        2016     7.0184
# 46  -217303.0303 -2.1730        2016    -2.1730
# 48      234.5361  0.0023        2016     0.0023
# 50  -109369.6809 -1.0937        2016    -1.0937
# 51  -416823.2323 -4.1682        2016    -4.1682
# 52  -218685.3282 -2.1869        2016    -2.1869
# 53   -71366.3366 -0.7137        2016    -0.7137
# 55  -177388.0597 -1.7739        2016    -1.7739
# 57  -221401.7341 -2.2140        2016    -2.2140
# 58  -234886.3636 -2.3489        2016    -2.3489
# 59  -190540.7407 -1.9054        2016    -1.9054
# 62  -260500.0000 -2.6050        2016    -2.6050
# 63  -301875.7225 -3.0188        2016    -3.0188
# 64  -308323.0769 -3.0832        2016    -3.0832
# 65  -192241.4966 -1.9224        2016    -1.9224
# 68   844409.0909  8.4441        2016     8.4441
# 72   192370.4545  1.9237        2017     1.9237
# 76   -87952.3810 -0.8795        2017    -0.8795
# 81  -320961.5385 -3.2096        2017    -3.2096
# 85   363798.1366  3.6380        2017     3.6380
# 86  -256527.0270 -2.5653        2017    -2.5653
# 87  -354848.2143 -3.5485        2017    -3.5485
# 88  -320831.3953 -3.2083        2017    -3.2083
# 89  -263202.8571 -2.6320        2017    -2.6320
# 90  -262378.6127 -2.6238        2017    -2.6238
# 93   149197.2973  1.4920        2017     1.4920
# 94  -390193.8776 -3.9019        2017    -3.9019
# 101 -246805.1643 -2.4681        2017    -2.4681
# 102 -129747.2222 -1.2975        2017    -1.2975
# 103 -510194.4444 -5.1019        2017    -5.1019
# 104 -347399.1597 -3.4740        2017    -3.4740
# 107 -399660.3774 -3.9966        2017    -3.9966
# 108 -325192.3077 -3.2519        2017    -3.2519
# 109 -381365.3846 -3.8137        2017    -3.8137
# 111  -74208.6331 -0.7421        2017    -0.7421
# 112 -395196.9697 -3.9520        2017    -3.9520
# 117 1167597.0149 11.6760        2017    11.6760
# 119   -2383.5341 -0.0238        2018    -0.0238
# 121 -206503.1447 -2.0650        2018    -2.0650
# 122 -504060.0000 -5.0406        2018    -5.0406
# 123  -96093.1373 -0.9609        2018    -0.9609
# 128 -111149.5726 -1.1115        2018    -1.1115
# 129 -356061.9835 -3.5606        2018    -3.5606
# 131 -132766.4671 -1.3277        2018    -1.3277
# 132 -353696.7213 -3.5370        2018    -3.5370
# 134 -159849.6732 -1.5985        2018    -1.5985
# 135 -419355.6701 -4.1936        2018    -4.1936
# 136 -356928.5714 -3.5693        2018    -3.5693
# 137 -297156.2500 -2.9716        2018    -2.9716
# 138 -362284.4828 -3.6228        2018    -3.6228
# 141 -278097.6331 -2.7810        2018    -2.7810
# 142 -282475.4601 -2.8248        2018    -2.8248
# 143 -229158.5366 -2.2916        2018    -2.2916
# 144 -112195.0355 -1.1220        2018    -1.1220
# 149 -344807.6923 -3.4481        2018    -3.4481
# 150 -333669.1176 -3.3367        2018    -3.3367
# 151 -350169.2913 -3.5017        2018    -3.5017
# 152 -208818.0212 -2.0882        2018    -2.0882
# 153 -243434.2723 -2.4343        2018    -2.4343
# 156  206575.0000  2.0657        2018     2.0657
# 158  -86004.7319 -0.8600        2018    -0.8600
# 165 -235503.5971 -2.3550        2019    -2.3550
# 166 -366752.1008 -3.6675        2019    -3.6675
# 169  -78828.6385 -0.7883        2019    -0.7883
# 170 -145063.0631 -1.4506        2019    -1.4506
# 171 -583864.8649 -5.8386        2019    -5.8386
# 176  804360.5769  8.0436        2019     8.0436
# 184 -152949.5798 -1.5295        2019    -1.5295
# 186 -108889.1304 -1.0889        2019    -1.0889
# 190 -298816.4062 -2.9882        2019    -2.9882
# 191 -166116.8033 -1.6612        2019    -1.6612
# 193 -270482.0628 -2.7048        2019    -2.7048
# 194 -104890.6883 -1.0489        2019    -1.0489
# 196 -362100.0000 -3.6210        2019    -3.6210
# 197 -263630.4348 -2.6363        2019    -2.6363
# 198 -200154.0541 -2.0015        2019    -2.0015
# 199 -362975.5245 -3.6298        2019    -3.6298
# 205  -95482.0628 -0.9548        2020    -0.9548
# 208  -62001.2563 -0.6200        2020    -0.6200
# 210  256798.7805  2.5680        2020     2.5680
# 213  316197.4703  3.1620        2020     3.1620
# 216  -69864.4986 -0.6986        2020    -0.6986
# 218 -144206.2201 -1.4421        2020    -1.4421
# 221  341990.2913  3.4199        2020     3.4199
# 227  -72936.3273 -0.7294        2020    -0.7294
# 229   19048.1771  0.1905        2020     0.1905
# 233  -57428.7020 -0.5743        2020    -0.5743
# 236 -250598.5075 -2.5060        2020    -2.5060
# 237 -247138.2353 -2.4714        2020    -2.4714
# 238    -107.8306 -0.0011        2020    -0.0011
# 243 -164917.2185 -1.6492        2021    -1.6492
# 244 -206475.9825 -2.0648        2021    -2.0648
# 246 -203934.9680 -2.0393        2021    -2.0393
# 247 -135462.9630 -1.3546        2021    -1.3546
# 248 -205918.9189 -2.0592        2021    -2.0592
# 249 -179242.7101 -1.7924        2021    -1.7924
# 250 -192986.4301 -1.9299        2021    -1.9299
# 251 -121396.9805 -1.2140        2021    -1.2140
# 253 -228572.0461 -2.2857        2021    -2.2857
# 257  729260.0733  7.2926        2021     7.2926
# 264  167956.4057  1.6796        2021     1.6796
# 267 -184894.7368 -1.8489        2021    -1.8489
# 268 -242393.9394 -2.4239        2021    -2.4239
# 269 -248737.3418 -2.4874        2021    -2.4874
# 273  230014.1343  2.3001        2021     2.3001
# 274 -235757.1429 -2.3576        2021    -2.3576
# 276 -138321.7822 -1.3832        2021    -1.3832
# 279  148936.0269  1.4894        2021     1.4894
# 280 -285287.4016 -2.8529        2021    -2.8529
# 282 -348917.9894 -3.4892        2021    -3.4892
# 283 -361840.7821 -3.6184        2021    -3.6184
# 284 -269330.3249 -2.6933        2021    -2.6933
# 286 -219290.1554 -2.1929        2021    -2.1929
# 287 -262126.7606 -2.6213        2021    -2.6213
# 289  248667.4157  2.4867        2021     2.4867
# 291   27682.5939  0.2768        2021     0.2768
# 295  -24808.5106 -0.2481        2021    -0.2481
# 297 -265126.2976 -2.6513        2021    -2.6513
# 298 -126448.9247 -1.2645        2022    -1.2645
# 307 3423324.8711 34.2332        2022    34.2332
# 308 -204426.6802 -2.0443        2022    -2.0443
# 310  -49564.4531 -0.4956        2022    -0.4956
# 312 -204207.8189 -2.0421        2022    -2.0421
# 314   -9086.3971 -0.0909        2022    -0.0909
# 317 -199227.4510 -1.9923        2022    -1.9923
# 318 -341690.4762 -3.4169        2022    -3.4169
# 319 -194178.2477 -1.9418        2022    -1.9418
# 320 -313622.3629 -3.1362        2022    -3.1362
# 321 -262301.2821 -2.6230        2022    -2.6230
# 322 -271585.6164 -2.7159        2022    -2.7159
# 329   94462.6770  0.9446        2022     0.9446
# 331 -295045.8015 -2.9505        2022    -2.9505
# 332 -220106.7146 -2.2011        2022    -2.2011
# 333   -3507.0028 -0.0351        2022    -0.0351
# 334 -298291.1647 -2.9829        2022    -2.9829
# 335 -256465.7321 -2.5647        2022    -2.5647
# 337 -187752.1490 -1.8775        2022    -1.8775
# 338 -251882.8671 -2.5188        2022    -2.5188
# 351 -280023.8095 -2.8002        2023    -2.8002
# 352 -235672.2488 -2.3567        2023    -2.3567
# 353 -327265.1822 -3.2727        2023    -3.2727
# 354 -205887.5236 -2.0589        2023    -2.0589
# 355 -354073.3945 -3.5407        2023    -3.5407
# 360 1323294.7214 13.2329        2023    13.2329
# 362 -237612.3853 -2.3761        2023    -2.3761
# 363   -9954.1176 -0.0995        2023    -0.0995
# 364 -297155.7377 -2.9716        2023    -2.9716
# 365 -321660.4478 -3.2166        2023    -3.2166
# 368 -287086.7508 -2.8709        2023    -2.8709
# 369 -227465.0655 -2.2747        2023    -2.2747
# 370  -67823.1084 -0.6782        2023    -0.6782
# 375 -111009.2105 -1.1101        2023    -1.1101
# 376 -363473.2143 -3.6347        2023    -3.6347
# 377 -343583.3333 -3.4358        2023    -3.4358
# 380  -63743.0168 -0.6374        2023    -0.6374
# 382 -350985.1064 -3.5099        2023    -3.5099
# 383 -252244.0476 -2.5224        2023    -2.5224
# 385 -360970.0461 -3.6097        2023    -3.6097
# 387  345111.6951  3.4511        2023     3.4511
# 391  609446.8085  6.0945        2023     6.0945
# 392 -293851.2658 -2.9385        2023    -2.9385
# 396 -352118.6131 -3.5212        2024    -3.5212
# 397 -330856.8773 -3.3086        2024    -3.3086
# 398 -102574.0741 -1.0257        2024    -1.0257
# 400 -254544.7761 -2.5454        2024    -2.5454
# 402  -43486.1111 -0.4349        2024    -0.4349
# 407 -254260.8696 -2.5426        2024    -2.5426
# 408 -191861.2903 -1.9186        2024    -1.9186
# 409 -381587.6494 -3.8159        2024    -3.8159
# 411  -76298.9494 -0.7630        2024    -0.7630
# 414  -79023.2068 -0.7902        2024    -0.7902
# 415 -246598.7654 -2.4660        2024    -2.4660
# 417 -120963.2495 -1.2096        2024    -1.2096

# %%
# tb_pandas.to_csv('Check KQ.csv', index=False)

# %%
# async def positional(df):

#     in_trade = False
#     tradebook = []
#     remark = ''
#     points = 0
#     entry_price = None
#     exit_price = None
#     initial_sl = None
#     # stoploss = None
#     is_trailing_active = False

#     for i in range(3, len(df)):
#         # SHORT Variation
    
#         if (not in_trade) and (df.iloc[i]['low'] < df.iloc[i-1]['low']) and (df.iloc[i-1]['sell_signal'] == True):
#             #Entry Triggered
#             if df.iloc[i]['open'] < df.iloc[i-1]['low']:
#                 if df.iloc[i]['high'] >= df.iloc[i-1]['low']:
#                     in_trade = True
#                     entry_price = df.iloc[i-1]['low']
#                     entry_time = df.iloc[i]['datetime']
#                     signal_time = df.iloc[i-1]['datetime']
#                     initial_sl = max(df.iloc[i-1]['high'], df.iloc[i-2]['high'], df.iloc[i-3]['high'])
#                     # stoploss = max(df.iloc[i-1]['high'], df.iloc[i-2]['high'], df.iloc[i-3]['high'])

#         if in_trade:
#             trade_entry_price = entry_price
#             trade_initial_sl = initial_sl
#             trade_final_sl = initial_sl

#             if (
#                 not is_trailing_active
#                 and df.iloc[i]['high'] < df.iloc[i]['ma']
#             ):
#                 is_trailing_active = True
            
#             if not is_trailing_active:
#                 if df.iloc[i]['open'] > trade_initial_sl:
#                     if (
#                         df.iloc[i]["datetime"].date() == entry_time.date()
#                         and df.iloc[i]["datetime"].time() == entry_time.time()
#                     ):
#                         if df.iloc[i]['close'] >= trade_initial_sl:
#                             in_trade = False
#                             points = trade_entry_price - trade_initial_sl
#                             exit_price = trade_initial_sl
#                             exit_time = df.iloc[i]["datetime"]
#                             remark = "Initial SL hit"

#                     else:
#                         # Gap Open Outside ISL
                        
#                         in_trade = False
#                         points = trade_entry_price - df.iloc[i]['open']
#                         exit_price = df.iloc[i]['open']
#                         exit_time = df.iloc[i]["datetime"]
#                         remark = "Gap Open Outside ISL"

#                 elif df.iloc[i]['high'] >= trade_initial_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = trade_entry_price - trade_initial_sl
#                     exit_price = trade_initial_sl
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "Initial SL Hit"

#             else:
#                 trade_final_sl = min(trade_initial_sl, df.iloc[i]['ma'])
#                 if df.iloc[i]['open'] > trade_initial_sl:
#                     if (
#                         df.iloc[i]["datetime"].date() == entry_time.date()
#                         and df.iloc[i]["datetime"].time() == entry_time.time()
#                     ):
#                         if df.iloc[i]['close'] >= trade_initial_sl:
#                             in_trade = False
#                             points = trade_entry_price - trade_initial_sl
#                             exit_price = trade_initial_sl
#                             exit_time = df.iloc[i]["datetime"]
#                             remark = "Initial SL hit"

#                     else:
#                         # Gap Open Outside ISL
                        
#                         in_trade = False
#                         points = trade_entry_price - df.iloc[i]['open']
#                         exit_price = df.iloc[i]['open']
#                         exit_time = df.iloc[i]["datetime"]
#                         remark = "Gap Open Outside ISL"

#                 elif df.iloc[i]['high'] >= trade_initial_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = trade_entry_price - trade_initial_sl
#                     exit_price = trade_initial_sl
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "Initial SL Hit"

#                 elif df.iloc[i]['close'] >= trade_final_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = trade_entry_price - df.iloc[i]['close']
#                     exit_price = df.iloc[i]['close']
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "TSL Hit"
    
#         if points:
#             slippage = SLIPPAGE_ * (entry_price + exit_price)
#             final_points = points - slippage
#             # sl_in_points = abs(entry_price - initial_sl)
#             qty = PORTFOLIO_VALUE * LEVERAGE_ / entry_price
#             trade = {
#                 'Signal Time': signal_time,
#                 'Trade Type': 'SHORT',
#                 'Entry Date': entry_time.date(),
#                 'Entry Time': entry_time.time(),
#                 'Entry Price': entry_price,
#                 'Initial SL': trade_initial_sl,
#                 'Final SL': trade_final_sl,
#                 'Exit Date': exit_time.date(),
#                 'Exit Time': exit_time.time(),
#                 'Exit Price': exit_price,
#                 'Points Captured': points,
#                 'After Costs': final_points,
#                 'Remarks': remark,
#                 'Qty': qty,
#                 'ROI%': (points * qty / PORTFOLIO_VALUE) * 100,
#                 'ROI% w cs': (final_points * qty / PORTFOLIO_VALUE) * 100,
#                 'Trade Year': entry_time.year,
#             }
#             # print(trade)
#             tradebook.append(trade)
#             points = 0
#             in_trade = False
#             remark = ''
#             entry_price = None
#             exit_price = None
#             initial_sl = None
#             # stoploss = None
#             is_trailing_active = False

#     for i in range(3, len(df)):
#         # LONG Variation
        
#         if (not in_trade) and (df.iloc[i]['high'] >= df.iloc[i-1]['high']) and (df.iloc[i-1]['buy_signal'] == True):
#             #Entry Triggered
#             if df.iloc[i]['open'] > df.iloc[i-1]['high']:
#                 if df.iloc[i]['low'] <= df.iloc[i-1]['high']:
#                     in_trade = True
#                     entry_price = df.iloc[i-1]['high']
#                     entry_time = df.iloc[i]['datetime']
#                     signal_time = df.iloc[i-1]['datetime']
#                     initial_sl = min(df.iloc[i-1]['low'], df.iloc[i-2]['low'], df.iloc[i-3]['low'])
#                     # stoploss = max(df.iloc[i-1]['low'], df.iloc[i-2]['low'], df.iloc[i-3]['low'])

#         if in_trade:
#             trade_entry_price = entry_price
#             trade_initial_sl = initial_sl
#             trade_final_sl = initial_sl

#             if (
#                 not is_trailing_active
#                 and df.iloc[i]['low'] > df.iloc[i]['ma']
#             ):
#                 is_trailing_active = True
            
#             if not is_trailing_active:
#                 if df.iloc[i]['open'] < trade_initial_sl:
#                     if (
#                         df.iloc[i]["datetime"].date() == entry_time.date()
#                         and df.iloc[i]["datetime"].time() == entry_time.time()
#                     ):
#                         if df.iloc[i]['close'] <= trade_initial_sl:
#                             in_trade = False
#                             points = trade_initial_sl - trade_entry_price
#                             exit_price = trade_initial_sl
#                             exit_time = df.iloc[i]["datetime"]
#                             remark = "Initial SL hit"

#                     else:
#                         # Gap Open Outside ISL
                        
#                         in_trade = False
#                         points = df.iloc[i]['open'] - trade_entry_price
#                         exit_price = df.iloc[i]['open']
#                         exit_time = df.iloc[i]["datetime"]
#                         remark = "Gap Open Outside ISL"

#                 elif df.iloc[i]['low'] <= trade_initial_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = trade_initial_sl - trade_entry_price
#                     exit_price = trade_initial_sl
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "Initial SL Hit"

#             else:
#                 trade_final_sl = max(trade_initial_sl, df.iloc[i]['ma'])
#                 if df.iloc[i]['open'] < trade_initial_sl:
#                     if (
#                         df.iloc[i]["datetime"].date() == entry_time.date()
#                         and df.iloc[i]["datetime"].time() == entry_time.time()
#                     ):
#                         if df.iloc[i]['close'] <= trade_initial_sl:
#                             in_trade = False
#                             points = trade_initial_sl - trade_entry_price
#                             exit_price = trade_initial_sl
#                             exit_time = df.iloc[i]["datetime"]
#                             remark = "Initial SL hit"

#                     else:
#                         # Gap Open Outside ISL
                        
#                         in_trade = False
#                         points = df.iloc[i]['open'] - trade_entry_price
#                         exit_price = df.iloc[i]['open']
#                         exit_time = df.iloc[i]["datetime"]
#                         remark = "Gap Open Outside ISL"

#                 elif df.iloc[i]['low'] <= trade_initial_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = trade_initial_sl - trade_entry_price
#                     exit_price = trade_initial_sl
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "Initial SL Hit"

#                 elif df.iloc[i]['close'] <= trade_final_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = df.iloc[i]['close'] - trade_entry_price
#                     exit_price = df.iloc[i]['close']
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "TSL Hit"    

#         if points:
#             slippage = SLIPPAGE_ * (entry_price + exit_price)
#             final_points = points - slippage
#             # sl_in_points = abs(entry_price - initial_sl)
#             qty = PORTFOLIO_VALUE * LEVERAGE_ / entry_price
#             trade = {
#                 'Signal Time': signal_time,
#                 'Trade Type': 'LONG',
#                 'Entry Date': entry_time.date(),
#                 'Entry Time': entry_time.time(),
#                 'Entry Price': entry_price,
#                 'Initial SL': trade_initial_sl,
#                 'Final SL': trade_final_sl,
#                 'Exit Date': exit_time.date(),
#                 'Exit Time': exit_time.time(),
#                 'Exit Price': exit_price,
#                 'Points Captured': points,
#                 'After Costs': final_points,
#                 'Remarks': remark,
#                 'Qty': qty,
#                 'ROI%': (points * qty / PORTFOLIO_VALUE) * 100,
#                 'ROI% w cs': (final_points * qty / PORTFOLIO_VALUE) * 100,
#                 'Trade Year': entry_time.year,
#             }
#             # print(trade)
#             tradebook.append(trade)
#             points = 0
#             in_trade = False
#             remark = ''
#             entry_price = None
#             exit_price = None
#             initial_sl = None
#             # stoploss = None
#             is_trailing_active = False

#     return pd.DataFrame(tradebook)

# %%
# async def trade(spot_data, index, tf):

#     if index == "bnf":
#         SPREAD = 100
#         index_full = "BANKNIFTY"
#     elif index == "nifty":
#         SPREAD = 50
#         index_full = "NIFTY"

#     start_date = dt.date(2017, 1, 1)
#     end_date = dt.date(2024, 3, 31)

#     flag = False

#     current_date = start_date

#     final_tb = pd.DataFrame()
#     tradebook = []

#     while current_date <= end_date:
#         # print(current_date)

#         if current_date.weekday() >= 5:
#             print("Skipping Weekend ! ", current_date)
#             current_date += dt.timedelta(days=1)
#             continue
#         elif current_date not in list_of_traded_dates:
#             print("Date Avoided ! ", current_date)
#             current_date += dt.timedelta(days=1)
#             continue
#         # elif current_date in list_of_dates_to_avoid_bnf:
#         #     # print('Date Avoided ! ', current_date)
#         #     current_date += dt.timedelta(days=1)
#         #     continue
#         else:
#             print("Working", current_date)
#             spot = spot_data[spot_data["datetime"].dt.date == current_date]
#             spot_open = spot.iloc[0]["open"]
#             # print(spot_open)
#             atm = int(round(spot_open / SPREAD) * SPREAD)
#             # print(atm)

#             current_expiry = await get_expiry(current_date, index)
#             dte = current_expiry - current_date

#             ce_df = await fetch_option_data(
#                 index=index,
#                 start_date=current_date,
#                 end_date=current_date,
#                 start_time=dt.time(9, 15),
#                 end_time=dt.time(15, 30),
#                 expiry=current_expiry,
#                 strike=atm,
#                 asset_class="C",
#             )
#             if not isinstance(ce_df, pl.DataFrame):
#                 print('Data Not Found for Options')
#                 current_date += dt.timedelta(days=1)
#                 continue
#             # print(ce_df.head())
#             ce_df = rename_ohlc_columns(ce_df)
#             # ce_5min = resample(ce_df, "5m")
#             ce_df = resample(ce_df, tf)
#             # call_option = ce_5min.to_pandas()
#             call_option = ce_df.to_pandas()

#             pe_df = await fetch_option_data(
#                 index=index,
#                 start_date=current_date,
#                 end_date=current_date,
#                 start_time=dt.time(9, 15),
#                 end_time=dt.time(15, 30),
#                 expiry=current_expiry,
#                 strike=atm,
#                 asset_class="P",
#             )
#             if not isinstance(pe_df, pl.DataFrame):
#                 print('Data Not Found for Options')
#                 current_date += dt.timedelta(days=1)
#                 continue
#             # print(pe_df.head())
#             pe_df = rename_ohlc_columns(pe_df)
#             # pe_5min = resample(pe_df, "5m")
#             pe_df = resample(pe_df, tf)
#             # put_option = pe_5min.to_pandas()
#             put_option = pe_df.to_pandas()

#             # call_option['datetime'] = pd.to_datetime(call_option['datetime'])
#             # put_option['datetime'] = pd.to_datetime(put_option['datetime'])

#             ce_df = await create_sell_signals(call_option)
#             pe_df = await create_sell_signals(put_option)

#             # print(ce_df.head())
#             # print(pe_df.head())

#             ce_contract = await get_option_contract_name(
#                 symbol=index_full,
#                 strike=atm,
#                 expiry=current_expiry,
#                 opt_type='CE'
#             )

#             pe_contract = await get_option_contract_name(
#                 symbol=index_full,
#                 strike=atm,
#                 expiry=current_expiry,
#                 opt_type='PE'
#             )

#             ce_trades = await option_trading(ce_df, ce_contract, atm, current_expiry)
#             pe_trades = await option_trading(pe_df, pe_contract, atm, current_expiry)

#             final_tb = pd.concat([final_tb, ce_trades, pe_trades], ignore_index=True)

#         current_date += dt.timedelta(days=1)

#     return final_tb

# %%
# async def trade_positional(spot_data, index, tf, offset, ma):

#     if index == "bnf":
#         SPREAD = 100
#         index_full = "BANKNIFTY"
#     elif index == "nifty":
#         SPREAD = 50
#         index_full = "NIFTY"

#     start_date = dt.date(2017, 1, 1)
#     end_date = dt.date(2024, 3, 31)

#     flag = False

#     current_date = start_date

#     final_tb = pd.DataFrame()
#     tradebook = []

#     # while current_date <= end_date:
#         # print(current_date)

#     # if current_date.weekday() >= 5:
#     #     print("Skipping Weekend ! ", current_date)
#     #     current_date += dt.timedelta(days=1)
#     #     continue
#     # elif current_date not in list_of_traded_dates:
#     #     print("Date Avoided ! ", current_date)
#     #     current_date += dt.timedelta(days=1)
#     #     continue
#     # # elif current_date in list_of_dates_to_avoid_bnf:
#     # #     # print('Date Avoided ! ', current_date)
#     # #     current_date += dt.timedelta(days=1)
#     # #     continue
#     # else:
#     #     print("Working", current_date)
#     data = resample(spot_data, tf, offset)
#     data_pandas = data.to_pandas()
#     data_pandas = await create_buy_signals(data_pandas)
#     data_pandas = await create_sell_signals(data_pandas)
#     data_pandas = await create_ma(data_pandas, ma)
#     # print(data.head(50))
#     # break
#     tb = await positional(data_pandas)
#     final_tb = pd.concat([tb, final_tb])

#         # current_date += dt.timedelta(days=1)

#     return final_tb

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2017, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2017, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI% w cs"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI% w cs"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI% w cs"] > 0]["ROI% w cs"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI% w cs"] < 0]["ROI% w cs"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI% w cs"].cumsum() - year_trades["ROI% w cs"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI% w cs"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI% w cs"] > 0]["ROI% w cs"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI% w cs"] < 0]["ROI% w cs"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI% w cs"].cumsum() - combined_df_sorted["ROI% w cs"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation

    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    
    # print(f'{overall_total_roi} , {overall_max_drawdown} , {overall_roi_dd_ratio}')
    
    return {overall_roi_dd_ratio: stats_df8}

# %%
stats = generate_stats(tb_pandas, '...')
lol = pd.DataFrame()
for x, y in stats.items():
    lol = pd.DataFrame(y)

lol
# Out:
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2017     -31.9370           21  19.0476                4.6824
# 2018     -56.2054           24   4.1667                2.0657
# 2019     -28.9666           16   6.2500                8.0436
# 2020      -0.6573           13  30.7692                2.3351
# 2021     -31.7322           28  21.4286                2.5875
# 2022      -1.7160           20  10.0000               17.5889
# 2023     -27.1369           23  13.0435                7.5928
# 2024     -24.3417           12   0.0000                   NaN
# Overall -202.6932          157  14.2105                5.7403
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio Variation
# 2017                -2.9804     -45.5367      -0.7013       ...
# 2018                -2.5335     -57.3873      -0.9794       ...
# 2019                -2.4673     -26.6115      -1.0885       ...
# 2020                -1.1108      -6.0916      -0.1079       ...
# 2021                -2.1481     -30.0831      -1.0548       ...
# 2022                -2.0497     -34.6848      -0.0495       ...
# 2023                -2.4958     -32.9477      -0.8236       ...
# 2024                -2.0285     -20.8206      -1.1691       ...
# Overall             -2.3293    -225.5752      -0.8986       ...

# %%
# tfs = ['15m', '30m', '60m', '1d']
# for i in range(5, 81, 5):
#     for tf in tfs:
#         if tf == '30m' or tf == '60m':
#             ofs = '15m'
#         else:
#             ofs = '0m'
#         variation = f'TF : {tf} , TMA : {i}'
#         print(variation)
#         x = await trade_positional(pl.DataFrame(bnf_1min), 'bnf', tf, ofs, i)
#         x['Entry Datetime'] = x.apply(lambda row: pd.to_datetime(f"{row['Entry Date']} {row['Entry Time']}"), axis=1)
#         x = x.sort_values(by='Entry Datetime')
#         stats = generate_stats(x, variation)
# # x

# %%
# x['Entry Datetime'] = x.apply(lambda row: pd.to_datetime(f"{row['Entry Date']} {row['Entry Time']}"), axis=1)
# x = x.sort_values(by='Entry Datetime')

# %%
# roi = x['ROI%'].sum()
# roi_w_cs = x['ROI% w cs'].sum()
# roi, roi_w_cs

# %%
# x = await trade_positional(pl.DataFrame(bnf_1min), 'bnf', '30m', '15m', 10)
# x['Entry Datetime'] = x.apply(lambda row: pd.to_datetime(f"{row['Entry Date']} {row['Entry Time']}"), axis=1)
# x = x.sort_values(by='Entry Datetime')
# stats = generate_stats(x, variation)

# %%
# for a, b in stats.items():
#     print(a)
#     print(b.to_string())

# %%
# x.tail()

# %%
# x['Slippage in Points'] = x.apply(lambda row: 0.25 / 100 * (row['Entry Price'] + row['Exit Price']), axis=1)

# %%
# x['Final Points'] = x.apply(lambda row: row['Points Captured'] - row['Slippage in Points'])
# x['PnL w cs'] = x.apply(lambda row: row['Final Points'] * row['Qty'])
# x['ROI% w cs'] = x.aply(lambda row: row['PnL w cs'] * 100 / 1000000)

# %%
# x
