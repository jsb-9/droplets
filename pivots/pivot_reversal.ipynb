# %%
import asyncio
import datetime as dt
import math
from typing import Literal

import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

# %%
import sys

sys.path.append("..")
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
async def get_expiry(f_today, index):

    if index == 'bnf':    
        if (f_today <= dt.date(2024, 1, 25)) and (f_today >= dt.date(2024, 1, 18)):
            f_expiry = dt.date(2024, 1, 25)
        elif (f_today <= dt.date(2024, 1, 31)) and (f_today >= dt.date(2024, 1, 26)):
            f_expiry = dt.date(2024, 1, 31)
        elif (f_today <= dt.date(2024, 2, 22)) and (f_today >= dt.date(2024, 2, 29)):
            f_expiry = dt.date(2024, 2, 29)
        elif (f_today <= dt.date(2024, 3, 25)) and (f_today >= dt.date(2024, 3, 27)):
            f_expiry = dt.date(2024, 2, 27)
        elif f_today < dt.date(2023, 9, 1):
            days_to_thursday = (3 - f_today.weekday()) % 7
            nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
            f_expiry = nearest_thursday
            if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
                f_expiry = nearest_thursday - dt.timedelta(days=1)
        elif f_today >= dt.date(2023, 9, 1):
            if f_today.day < 24:
                days_to_wednesday = (2 - f_today.weekday()) % 7
                nearest_wednesday = f_today + dt.timedelta(days=days_to_wednesday)
                f_expiry = nearest_wednesday
                if nse.valid_days(
                    start_date=nearest_wednesday, end_date=nearest_wednesday
                ).empty:
                    f_expiry = nearest_wednesday - dt.timedelta(days=1)
            else:
                days_to_thursday = (3 - f_today.weekday()) % 7
                nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
                f_expiry = nearest_thursday
                if nse.valid_days(
                    start_date=nearest_thursday, end_date=nearest_thursday
                ).empty:
                    f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'nifty':
        days_to_thursday = (3 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'finnifty' or index == 'fnf':
        days_to_thursday = (1 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'midcpnifty' or index == 'midcp':
        days_to_thursday = (0 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

async def get_expiry_nifty(f_today):

    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry


async def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"


def get_option_contract_name2(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"

# %%
bnf_1min = pd.read_csv("../data/bnf.csv")
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["datetime"])
bnf_1min = bnf_1min[bnf_1min["datetime"].dt.year >= 2017]

# %%
bnf_1min.tail()
# Out:
#                   datetime       open       high        low      close  volume
# 687621 2024-06-07 15:25:00 49800.4500 49812.7500 49792.7000 49806.2000       0
# 687622 2024-06-07 15:26:00 49807.2500 49811.7000 49798.7500 49807.5000       0
# 687623 2024-06-07 15:27:00 49810.8500 49823.8000 49797.6000 49817.3000       0
# 687624 2024-06-07 15:28:00 49816.2500 49827.6000 49805.8000 49816.0000       0
# 687625 2024-06-07 15:29:00 49820.3000 49825.0000 49805.2500 49806.6000       0

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("open").first().alias("open"),
                pl.col("high").max().alias("high"),
                pl.col("low").min().alias("low"),
                pl.col("close").last().alias("close"),
                pl.col("volume").sum().alias("volume"),
            ]
        )
    )


# ohlc_resampled = resample(pl.DataFrame(bnf_1min), '7d', pd.Timedelta(days=4))
# ohlc_resampled

# %%
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["datetime"])
list_of_traded_dates = set(bnf_1min["datetime"].dt.date)
list_of_traded_dates
# Out:
# {datetime.date(2018, 7, 25),
#  datetime.date(2023, 2, 2),
#  datetime.date(2018, 12, 18),
#  datetime.date(2019, 4, 26),
#  datetime.date(2019, 6, 26),
#  datetime.date(2022, 4, 27),
#  datetime.date(2020, 3, 20),
#  datetime.date(2022, 2, 11),
#  datetime.date(2017, 10, 18),
#  datetime.date(2017, 2, 14),
#  datetime.date(2018, 4, 3),
#  datetime.date(2019, 8, 8),
#  datetime.date(2023, 4, 10),
#  datetime.date(2017, 5, 24),
#  datetime.date(2020, 3, 5),
#  datetime.date(2020, 12, 11),
#  datetime.date(2023, 10, 4),
#  datetime.date(2018, 9, 4),
#  datetime.date(2023, 1, 4),
#  datetime.date(2024, 3, 13),
#  datetime.date(2017, 8, 8),
#  datetime.date(2018, 10, 12),
#  datetime.date(2019, 12, 18),
#  datetime.date(2024, 1, 29),
#  datetime.date(2022, 6, 14),
#  datetime.date(2019, 1, 18),
#  datetime.date(2021, 9, 7),
#  datetime.date(2024, 5, 23),
#  datetime.date(2018, 6, 7),
#  datetime.date(2017, 3, 28),
#  datetime.date(2020, 9, 21),
#  datetime.date(2021, 12, 17),
#  datetime.date(2023, 5, 11),
#  datetime.date(2023, 5, 19),
#  datetime.date(2017, 5, 12),
#  datetime.date(2023, 11, 13),
#  datetime.date(2019, 1, 24),
#  datetime.date(2019, 8, 26),
#  datetime.date(2023, 6, 5),
#  datetime.date(2021, 5, 5),
#  datetime.date(2018, 11, 6),
#  datetime.date(2022, 5, 24),
#  datetime.date(2021, 10, 21),
#  datetime.date(2023, 1, 3),
#  datetime.date(2019, 2, 22),
#  datetime.date(2023, 5, 4),
#  datetime.date(2021, 5, 10),
#  datetime.date(2019, 7, 22),
#  datetime.date(2022, 12, 29),
#  datetime.date(2024, 1, 17),
#  datetime.date(2017, 1, 25),
#  datetime.date(2018, 8, 30),
#  datetime.date(2018, 10, 26),
#  datetime.date(2018, 8, 31),
#  datetime.date(2023, 5, 10),
#  datetime.date(2021, 8, 20),
#  datetime.date(2020, 3, 25),
#  datetime.date(2021, 6, 25),
#  datetime.date(2017, 8, 11),
#  datetime.date(2021, 5, 12),
#  datetime.date(2018, 9, 3),
#  datetime.date(2020, 1, 9),
#  datetime.date(2022, 7, 21),
#  datetime.date(2020, 12, 10),
#  datetime.date(2017, 6, 15),
#  datetime.date(2020, 5, 5),
#  datetime.date(2024, 5, 10),
#  datetime.date(2020, 11, 11),
#  datetime.date(2018, 2, 2),
#  datetime.date(2020, 1, 29),
#  datetime.date(2021, 7, 16),
#  datetime.date(2019, 9, 24),
#  datetime.date(2021, 4, 1),
#  datetime.date(2021, 4, 27),
#  datetime.date(2021, 3, 3),
#  datetime.date(2023, 6, 27),
#  datetime.date(2020, 10, 5),
#  datetime.date(2017, 8, 9),
#  datetime.date(2020, 4, 23),
#  datetime.date(2019, 6, 19),
#  datetime.date(2018, 5, 17),
#  datetime.date(2017, 5, 23),
#  datetime.date(2020, 9, 24),
#  datetime.date(2017, 7, 10),
#  datetime.date(2019, 12, 3),
#  datetime.date(2020, 5, 4),
#  datetime.date(2019, 6, 13),
#  datetime.date(2017, 10, 3),
#  datetime.date(2017, 9, 28),
#  datetime.date(2019, 4, 12),
#  datetime.date(2023, 8, 9),
#  datetime.date(2023, 7, 14),
#  datetime.date(2022, 6, 21),
#  datetime.date(2020, 6, 9),
#  datetime.date(2017, 1, 6),
#  datetime.date(2021, 11, 12),
#  datetime.date(2020, 6, 16),
#  datetime.date(2024, 2, 12),
#  datetime.date(2023, 10, 3),
#  datetime.date(2023, 2, 7),
#  datetime.date(2022, 11, 10),
#  datetime.date(2021, 2, 25),
#  datetime.date(2019, 5, 6),
#  datetime.date(2022, 11, 21),
#  datetime.date(2020, 9, 16),
#  datetime.date(2020, 9, 28),
#  datetime.date(2020, 10, 27),
#  datetime.date(2017, 6, 14),
#  datetime.date(2024, 3, 1),
#  datetime.date(2022, 4, 21),
#  datetime.date(2022, 6, 28),
#  datetime.date(2020, 12, 28),
#  datetime.date(2020, 8, 19),
#  datetime.date(2023, 11, 28),
#  datetime.date(2018, 5, 18),
#  datetime.date(2018, 4, 30),
#  datetime.date(2017, 10, 24),
#  datetime.date(2019, 7, 30),
#  datetime.date(2023, 8, 11),
#  datetime.date(2022, 1, 19),
#  datetime.date(2019, 1, 3),
#  datetime.date(2018, 1, 23),
#  datetime.date(2023, 1, 19),
#  datetime.date(2021, 5, 21),
#  datetime.date(2023, 11, 3),
#  datetime.date(2024, 2, 29),
#  datetime.date(2020, 9, 7),
#  datetime.date(2020, 4, 13),
#  datetime.date(2021, 9, 1),
#  datetime.date(2019, 10, 16),
#  datetime.date(2017, 1, 30),
#  datetime.date(2022, 9, 22),
#  datetime.date(2021, 4, 7),
#  datetime.date(2020, 9, 9),
#  datetime.date(2023, 1, 20),
#  datetime.date(2019, 8, 1),
#  datetime.date(2020, 6, 19),
#  datetime.date(2020, 6, 25),
#  datetime.date(2021, 10, 12),
#  datetime.date(2024, 3, 5),
#  datetime.date(2019, 3, 13),
#  datetime.date(2018, 3, 8),
#  datetime.date(2022, 10, 28),
#  datetime.date(2021, 1, 6),
#  datetime.date(2024, 3, 19),
#  datetime.date(2019, 12, 16),
#  datetime.date(2020, 1, 1),
#  datetime.date(2021, 12, 2),
#  datetime.date(2023, 2, 10),
#  datetime.date(2017, 9, 11),
#  datetime.date(2021, 11, 30),
#  datetime.date(2021, 8, 18),
#  datetime.date(2018, 2, 5),
#  datetime.date(2024, 2, 7),
#  datetime.date(2020, 7, 27),
#  datetime.date(2024, 4, 30),
#  datetime.date(2023, 10, 9),
#  datetime.date(2024, 5, 13),
#  datetime.date(2023, 8, 7),
#  datetime.date(2017, 9, 18),
#  datetime.date(2023, 1, 11),
#  datetime.date(2021, 7, 6),
#  datetime.date(2019, 4, 11),
#  datetime.date(2023, 7, 7),
#  datetime.date(2020, 9, 25),
#  datetime.date(2019, 3, 7),
#  datetime.date(2022, 7, 20),
#  datetime.date(2017, 11, 23),
#  datetime.date(2020, 8, 12),
#  datetime.date(2021, 11, 25),
#  datetime.date(2018, 3, 28),
#  datetime.date(2022, 11, 16),
#  datetime.date(2017, 12, 27),
#  datetime.date(2017, 4, 17),
#  datetime.date(2023, 2, 17),
#  datetime.date(2019, 1, 10),
#  datetime.date(2018, 7, 6),
#  datetime.date(2021, 1, 15),
#  datetime.date(2019, 5, 8),
#  datetime.date(2021, 9, 22),
#  datetime.date(2019, 3, 11),
#  datetime.date(2022, 11, 14),
#  datetime.date(2022, 10, 31),
#  datetime.date(2023, 12, 21),
#  datetime.date(2018, 9, 7),
#  datetime.date(2017, 11, 21),
#  datetime.date(2022, 4, 26),
#  datetime.date(2019, 9, 9),
#  datetime.date(2021, 1, 22),
#  datetime.date(2017, 2, 10),
#  datetime.date(2022, 8, 11),
#  datetime.date(2021, 12, 28),
#  datetime.date(2023, 5, 25),
#  datetime.date(2023, 10, 26),
#  datetime.date(2017, 10, 9),
#  datetime.date(2017, 5, 31),
#  datetime.date(2023, 5, 8),
#  datetime.date(2019, 11, 1),
#  datetime.date(2018, 3, 21),
#  datetime.date(2023, 5, 5),
#  datetime.date(2019, 10, 29),
#  datetime.date(2022, 6, 24),
#  datetime.date(2017, 2, 2),
#  datetime.date(2019, 4, 15),
#  datetime.date(2019, 5, 23),
#  datetime.date(2021, 3, 10),
#  datetime.date(2020, 7, 22),
#  datetime.date(2022, 7, 1),
#  datetime.date(2017, 10, 6),
#  datetime.date(2023, 2, 1),
#  datetime.date(2018, 7, 2),
#  datetime.date(2024, 1, 18),
#  datetime.date(2017, 1, 20),
#  datetime.date(2017, 12, 26),
#  datetime.date(2024, 1, 3),
#  datetime.date(2022, 6, 8),
#  datetime.date(2021, 2, 3),
#  datetime.date(2021, 12, 1),
#  datetime.date(2018, 6, 15),
#  datetime.date(2024, 3, 21),
#  datetime.date(2022, 2, 3),
#  datetime.date(2018, 12, 14),
#  datetime.date(2021, 1, 28),
#  datetime.date(2022, 10, 3),
#  datetime.date(2018, 1, 8),
#  datetime.date(2020, 9, 22),
#  datetime.date(2020, 10, 8),
#  datetime.date(2022, 11, 2),
#  datetime.date(2019, 9, 19),
#  datetime.date(2018, 7, 23),
#  datetime.date(2019, 3, 26),
#  datetime.date(2019, 6, 14),
#  datetime.date(2022, 5, 11),
#  datetime.date(2023, 2, 14),
#  datetime.date(2022, 1, 14),
#  datetime.date(2024, 1, 19),
#  datetime.date(2021, 5, 6),
#  datetime.date(2022, 3, 11),
#  datetime.date(2017, 10, 27),
#  datetime.date(2017, 8, 24),
#  datetime.date(2018, 5, 31),
#  datetime.date(2020, 8, 13),
#  datetime.date(2022, 9, 13),
#  datetime.date(2023, 11, 1),
#  datetime.date(2019, 11, 8),
#  datetime.date(2021, 9, 28),
#  datetime.date(2022, 4, 13),
#  datetime.date(2019, 6, 17),
#  datetime.date(2018, 2, 7),
#  datetime.date(2017, 8, 2),
#  datetime.date(2017, 9, 20),
#  datetime.date(2019, 11, 5),
#  datetime.date(2023, 6, 14),
#  datetime.date(2018, 5, 8),
#  datetime.date(2023, 9, 27),
#  datetime.date(2023, 10, 17),
#  datetime.date(2020, 11, 3),
#  datetime.date(2022, 2, 23),
#  datetime.date(2018, 11, 29),
#  datetime.date(2021, 1, 14),
#  datetime.date(2017, 1, 13),
#  datetime.date(2022, 1, 31),
#  datetime.date(2024, 4, 15),
#  datetime.date(2023, 2, 9),
#  datetime.date(2021, 8, 25),
#  datetime.date(2021, 3, 26),
#  datetime.date(2020, 3, 2),
#  datetime.date(2022, 6, 1),
#  datetime.date(2022, 7, 25),
#  datetime.date(2017, 6, 23),
#  datetime.date(2021, 11, 4),
#  datetime.date(2018, 5, 15),
#  datetime.date(2019, 4, 1),
#  datetime.date(2020, 8, 5),
#  datetime.date(2023, 7, 11),
#  datetime.date(2019, 2, 15),
#  datetime.date(2018, 4, 12),
#  datetime.date(2019, 12, 19),
#  datetime.date(2020, 8, 26),
#  datetime.date(2023, 11, 10),
#  datetime.date(2022, 9, 15),
#  datetime.date(2021, 2, 24),
#  datetime.date(2018, 7, 17),
#  datetime.date(2022, 12, 9),
#  datetime.date(2017, 3, 31),
#  datetime.date(2022, 9, 27),
#  datetime.date(2024, 2, 26),
#  datetime.date(2022, 10, 11),
#  datetime.date(2023, 4, 12),
#  datetime.date(2024, 1, 20),
#  datetime.date(2017, 3, 8),
#  datetime.date(2022, 4, 5),
#  datetime.date(2018, 1, 11),
#  datetime.date(2018, 6, 12),
#  datetime.date(2022, 12, 14),
#  datetime.date(2023, 2, 15),
#  datetime.date(2017, 6, 9),
#  datetime.date(2022, 7, 29),
#  datetime.date(2021, 5, 24),
#  datetime.date(2021, 2, 23),
#  datetime.date(2020, 6, 3),
#  datetime.date(2022, 8, 26),
#  datetime.date(2024, 1, 23),
#  datetime.date(2018, 3, 7),
#  datetime.date(2018, 1, 5),
#  datetime.date(2020, 11, 24),
#  datetime.date(2022, 10, 12),
#  datetime.date(2017, 11, 30),
#  datetime.date(2024, 2, 22),
#  datetime.date(2023, 2, 16),
#  datetime.date(2023, 12, 7),
#  datetime.date(2020, 9, 29),
#  datetime.date(2022, 6, 20),
#  datetime.date(2017, 12, 21),
#  datetime.date(2018, 10, 15),
#  datetime.date(2019, 2, 4),
#  datetime.date(2022, 8, 16),
#  datetime.date(2022, 8, 2),
#  datetime.date(2019, 7, 11),
#  datetime.date(2022, 5, 5),
#  datetime.date(2021, 7, 19),
#  datetime.date(2021, 12, 10),
#  datetime.date(2019, 2, 14),
#  datetime.date(2019, 1, 2),
#  datetime.date(2024, 4, 26),
#  datetime.date(2020, 5, 8),
#  datetime.date(2018, 9, 27),
#  datetime.date(2018, 7, 11),
#  datetime.date(2017, 2, 6),
#  datetime.date(2019, 12, 4),
#  datetime.date(2019, 6, 4),
#  datetime.date(2021, 4, 6),
#  datetime.date(2021, 11, 3),
#  datetime.date(2022, 8, 22),
#  datetime.date(2023, 11, 29),
#  datetime.date(2023, 8, 16),
#  datetime.date(2017, 11, 27),
#  datetime.date(2019, 3, 29),
#  datetime.date(2021, 6, 22),
#  datetime.date(2023, 7, 21),
#  datetime.date(2020, 10, 7),
#  datetime.date(2020, 8, 31),
#  datetime.date(2022, 11, 9),
#  datetime.date(2021, 11, 1),
#  datetime.date(2022, 5, 10),
#  datetime.date(2017, 5, 4),
#  datetime.date(2020, 2, 26),
#  datetime.date(2017, 3, 9),
#  datetime.date(2021, 8, 3),
#  datetime.date(2020, 12, 15),
#  datetime.date(2017, 8, 1),
#  datetime.date(2018, 11, 13),
#  datetime.date(2021, 12, 3),
#  datetime.date(2022, 10, 13),
#  datetime.date(2024, 3, 12),
#  datetime.date(2018, 8, 6),
#  datetime.date(2019, 10, 1),
#  datetime.date(2023, 8, 8),
#  datetime.date(2020, 11, 10),
#  datetime.date(2022, 6, 3),
#  datetime.date(2017, 8, 18),
#  datetime.date(2023, 12, 13),
#  datetime.date(2018, 3, 15),
#  datetime.date(2021, 3, 18),
#  datetime.date(2020, 3, 24),
#  datetime.date(2019, 3, 6),
#  datetime.date(2023, 11, 6),
#  datetime.date(2023, 3, 24),
#  datetime.date(2018, 5, 2),
#  datetime.date(2020, 6, 1),
#  datetime.date(2017, 6, 2),
#  datetime.date(2020, 4, 3),
#  datetime.date(2017, 8, 16),
#  datetime.date(2023, 3, 3),
#  datetime.date(2018, 3, 1),
#  datetime.date(2021, 10, 4),
#  datetime.date(2022, 9, 23),
#  datetime.date(2017, 6, 5),
#  datetime.date(2017, 2, 13),
#  datetime.date(2018, 8, 16),
#  datetime.date(2023, 12, 1),
#  datetime.date(2020, 12, 14),
#  datetime.date(2017, 6, 13),
#  datetime.date(2021, 1, 21),
#  datetime.date(2022, 9, 30),
#  datetime.date(2017, 5, 2),
#  datetime.date(2018, 2, 21),
#  datetime.date(2022, 7, 18),
#  datetime.date(2020, 5, 26),
#  datetime.date(2017, 4, 3),
#  datetime.date(2021, 4, 30),
#  datetime.date(2017, 5, 10),
#  datetime.date(2019, 1, 9),
#  datetime.date(2023, 10, 12),
#  datetime.date(2019, 2, 18),
#  datetime.date(2021, 6, 4),
#  datetime.date(2017, 1, 12),
#  datetime.date(2017, 6, 12),
#  datetime.date(2017, 3, 17),
#  datetime.date(2018, 4, 23),
#  datetime.date(2021, 1, 5),
#  datetime.date(2017, 6, 8),
#  datetime.date(2021, 8, 4),
#  datetime.date(2023, 6, 8),
#  datetime.date(2020, 9, 14),
#  datetime.date(2020, 2, 11),
#  datetime.date(2019, 12, 9),
#  datetime.date(2019, 3, 22),
#  datetime.date(2017, 8, 7),
#  datetime.date(2024, 4, 3),
#  datetime.date(2020, 6, 4),
#  datetime.date(2018, 7, 3),
#  datetime.date(2022, 7, 7),
#  datetime.date(2021, 11, 11),
#  datetime.date(2019, 7, 16),
#  datetime.date(2022, 12, 19),
#  datetime.date(2022, 9, 2),
#  datetime.date(2018, 9, 21),
#  datetime.date(2018, 5, 7),
#  datetime.date(2019, 7, 26),
#  datetime.date(2018, 5, 28),
#  datetime.date(2018, 5, 29),
#  datetime.date(2019, 12, 5),
#  datetime.date(2022, 1, 10),
#  datetime.date(2020, 5, 20),
#  datetime.date(2019, 6, 18),
#  datetime.date(2019, 3, 28),
#  datetime.date(2019, 4, 9),
#  datetime.date(2019, 11, 19),
#  datetime.date(2020, 7, 29),
#  datetime.date(2022, 4, 4),
#  datetime.date(2021, 7, 22),
#  datetime.date(2023, 3, 22),
#  datetime.date(2018, 5, 4),
#  datetime.date(2021, 1, 13),
#  datetime.date(2020, 8, 18),
#  datetime.date(2022, 7, 14),
#  datetime.date(2020, 7, 14),
#  datetime.date(2018, 1, 1),
#  datetime.date(2023, 10, 23),
#  datetime.date(2023, 1, 6),
#  datetime.date(2017, 11, 7),
#  datetime.date(2017, 9, 8),
#  datetime.date(2019, 12, 27),
#  datetime.date(2023, 10, 6),
#  datetime.date(2022, 7, 15),
#  datetime.date(2018, 3, 12),
#  datetime.date(2017, 1, 2),
#  datetime.date(2019, 12, 13),
#  datetime.date(2023, 3, 8),
#  datetime.date(2021, 3, 17),
#  datetime.date(2018, 9, 24),
#  datetime.date(2018, 1, 2),
#  datetime.date(2017, 6, 6),
#  datetime.date(2020, 6, 22),
#  datetime.date(2020, 8, 17),
#  datetime.date(2021, 9, 30),
#  datetime.date(2018, 7, 12),
#  datetime.date(2018, 9, 19),
#  datetime.date(2017, 2, 27),
#  datetime.date(2017, 12, 6),
#  datetime.date(2017, 7, 24),
#  datetime.date(2021, 11, 22),
#  datetime.date(2018, 5, 10),
#  datetime.date(2024, 2, 1),
#  datetime.date(2020, 2, 17),
#  datetime.date(2018, 11, 2),
#  datetime.date(2021, 7, 9),
#  datetime.date(2023, 7, 10),
#  datetime.date(2020, 2, 1),
#  datetime.date(2020, 7, 31),
#  datetime.date(2018, 2, 9),
#  datetime.date(2023, 8, 24),
#  datetime.date(2018, 5, 22),
#  datetime.date(2018, 8, 10),
#  datetime.date(2023, 3, 14),
#  datetime.date(2021, 10, 27),
#  datetime.date(2024, 5, 27),
#  datetime.date(2021, 11, 23),
#  datetime.date(2021, 2, 15),
#  datetime.date(2022, 10, 4),
#  datetime.date(2018, 2, 14),
#  datetime.date(2022, 4, 20),
#  datetime.date(2020, 6, 12),
#  datetime.date(2021, 3, 12),
#  datetime.date(2023, 3, 15),
#  datetime.date(2023, 9, 4),
#  datetime.date(2023, 4, 25),
#  datetime.date(2021, 5, 25),
#  datetime.date(2022, 12, 20),
#  datetime.date(2020, 11, 14),
#  datetime.date(2020, 1, 23),
#  datetime.date(2021, 9, 16),
#  datetime.date(2020, 1, 16),
#  datetime.date(2024, 5, 14),
#  datetime.date(2022, 8, 29),
#  datetime.date(2018, 10, 22),
#  datetime.date(2023, 12, 20),
#  datetime.date(2020, 7, 3),
#  datetime.date(2021, 4, 23),
#  datetime.date(2020, 10, 9),
#  datetime.date(2023, 12, 19),
#  datetime.date(2023, 2, 23),
#  datetime.date(2017, 5, 11),
#  datetime.date(2018, 12, 24),
#  datetime.date(2020, 12, 3),
#  datetime.date(2017, 2, 1),
#  datetime.date(2021, 10, 18),
#  datetime.date(2017, 1, 27),
#  datetime.date(2018, 8, 23),
#  datetime.date(2017, 5, 25),
#  datetime.date(2018, 10, 29),
#  datetime.date(2022, 12, 21),
#  datetime.date(2017, 1, 11),
#  datetime.date(2017, 3, 23),
#  datetime.date(2019, 1, 14),
#  datetime.date(2019, 2, 7),
#  datetime.date(2020, 7, 16),
#  datetime.date(2022, 2, 2),
#  datetime.date(2022, 10, 14),
#  datetime.date(2021, 4, 5),
#  datetime.date(2022, 7, 6),
#  datetime.date(2021, 8, 13),
#  datetime.date(2022, 5, 26),
#  datetime.date(2023, 8, 21),
#  datetime.date(2023, 9, 8),
#  datetime.date(2021, 7, 14),
#  datetime.date(2020, 11, 9),
#  datetime.date(2022, 9, 9),
#  datetime.date(2022, 11, 22),
#  datetime.date(2018, 4, 16),
#  datetime.date(2021, 3, 19),
#  datetime.date(2017, 10, 23),
#  datetime.date(2022, 1, 11),
#  datetime.date(2024, 1, 30),
#  datetime.date(2024, 4, 12),
#  datetime.date(2017, 5, 16),
#  datetime.date(2023, 6, 30),
#  datetime.date(2018, 3, 20),
#  datetime.date(2018, 10, 1),
#  datetime.date(2021, 7, 13),
#  datetime.date(2017, 2, 9),
#  datetime.date(2017, 7, 4),
#  datetime.date(2021, 3, 31),
#  datetime.date(2021, 7, 30),
#  datetime.date(2017, 3, 6),
#  datetime.date(2018, 6, 28),
#  datetime.date(2022, 12, 2),
#  datetime.date(2022, 11, 23),
#  datetime.date(2020, 12, 17),
#  datetime.date(2018, 3, 9),
#  datetime.date(2018, 4, 4),
#  datetime.date(2023, 5, 31),
#  datetime.date(2023, 4, 3),
#  datetime.date(2024, 2, 23),
#  datetime.date(2019, 8, 2),
#  datetime.date(2023, 9, 12),
#  datetime.date(2021, 1, 11),
#  datetime.date(2018, 6, 5),
#  datetime.date(2020, 11, 23),
#  datetime.date(2017, 4, 25),
#  datetime.date(2022, 8, 25),
#  datetime.date(2019, 3, 27),
#  datetime.date(2018, 11, 27),
#  datetime.date(2023, 8, 17),
#  datetime.date(2023, 11, 8),
#  datetime.date(2022, 5, 30),
#  datetime.date(2020, 2, 18),
#  datetime.date(2020, 11, 5),
#  datetime.date(2017, 1, 10),
#  datetime.date(2018, 1, 18),
#  datetime.date(2018, 5, 23),
#  datetime.date(2019, 8, 7),
#  datetime.date(2023, 12, 14),
#  datetime.date(2022, 12, 13),
#  datetime.date(2019, 7, 31),
#  datetime.date(2023, 6, 16),
#  datetime.date(2017, 10, 26),
#  datetime.date(2023, 5, 3),
#  datetime.date(2017, 8, 28),
#  datetime.date(2022, 7, 27),
#  datetime.date(2019, 7, 29),
#  datetime.date(2021, 2, 11),
#  datetime.date(2021, 10, 13),
#  datetime.date(2019, 5, 2),
#  datetime.date(2018, 3, 13),
#  datetime.date(2020, 8, 24),
#  datetime.date(2024, 3, 2),
#  datetime.date(2023, 9, 28),
#  datetime.date(2019, 2, 27),
#  datetime.date(2017, 5, 29),
#  datetime.date(2021, 12, 13),
#  datetime.date(2022, 11, 3),
#  datetime.date(2023, 7, 24),
#  datetime.date(2022, 8, 10),
#  datetime.date(2023, 11, 30),
#  datetime.date(2022, 5, 13),
#  datetime.date(2020, 7, 30),
#  datetime.date(2019, 1, 7),
#  datetime.date(2019, 11, 14),
#  datetime.date(2017, 7, 7),
#  datetime.date(2023, 9, 29),
#  datetime.date(2021, 4, 15),
#  datetime.date(2022, 7, 8),
#  datetime.date(2022, 5, 4),
#  datetime.date(2018, 1, 17),
#  datetime.date(2022, 7, 26),
#  datetime.date(2023, 7, 6),
#  datetime.date(2022, 4, 1),
#  datetime.date(2018, 11, 21),
#  datetime.date(2018, 12, 20),
#  datetime.date(2020, 10, 22),
#  datetime.date(2019, 8, 14),
#  datetime.date(2022, 5, 20),
#  datetime.date(2023, 12, 8),
#  datetime.date(2019, 8, 23),
#  datetime.date(2020, 10, 26),
#  datetime.date(2019, 10, 4),
#  datetime.date(2020, 5, 12),
#  datetime.date(2018, 6, 13),
#  datetime.date(2023, 3, 31),
#  datetime.date(2024, 6, 5),
#  datetime.date(2017, 9, 27),
#  datetime.date(2021, 11, 9),
#  datetime.date(2018, 4, 5),
#  datetime.date(2018, 10, 9),
#  datetime.date(2019, 6, 12),
#  datetime.date(2021, 10, 11),
#  datetime.date(2022, 12, 28),
#  datetime.date(2017, 5, 30),
#  datetime.date(2018, 4, 24),
#  datetime.date(2021, 1, 12),
#  datetime.date(2021, 5, 11),
#  datetime.date(2024, 5, 21),
#  datetime.date(2018, 4, 25),
#  datetime.date(2020, 4, 1),
#  datetime.date(2017, 8, 21),
#  datetime.date(2021, 4, 28),
#  datetime.date(2021, 11, 8),
#  datetime.date(2020, 7, 23),
#  datetime.date(2019, 10, 31),
#  datetime.date(2020, 9, 2),
#  datetime.date(2021, 9, 8),
#  datetime.date(2017, 5, 19),
#  datetime.date(2020, 6, 29),
#  datetime.date(2020, 4, 9),
#  datetime.date(2021, 2, 12),
#  datetime.date(2021, 6, 23),
#  datetime.date(2022, 11, 18),
#  datetime.date(2024, 1, 1),
#  datetime.date(2018, 8, 21),
#  datetime.date(2021, 7, 15),
#  datetime.date(2022, 3, 7),
#  datetime.date(2021, 2, 9),
#  datetime.date(2022, 2, 10),
#  datetime.date(2021, 3, 4),
#  datetime.date(2019, 2, 19),
#  datetime.date(2018, 12, 7),
#  datetime.date(2022, 12, 15),
#  datetime.date(2023, 1, 25),
#  datetime.date(2023, 2, 24),
#  datetime.date(2018, 12, 31),
#  datetime.date(2023, 9, 14),
#  datetime.date(2018, 6, 11),
#  datetime.date(2022, 2, 21),
#  datetime.date(2018, 8, 7),
#  datetime.date(2017, 3, 14),
#  datetime.date(2020, 12, 23),
#  datetime.date(2018, 7, 16),
#  datetime.date(2020, 10, 13),
#  datetime.date(2018, 12, 12),
#  datetime.date(2019, 9, 12),
#  datetime.date(2020, 8, 6),
#  datetime.date(2017, 1, 5),
#  datetime.date(2017, 8, 4),
#  datetime.date(2020, 1, 17),
#  datetime.date(2024, 5, 6),
#  datetime.date(2017, 5, 15),
#  datetime.date(2024, 3, 15),
#  datetime.date(2018, 11, 22),
#  datetime.date(2020, 12, 29),
#  datetime.date(2022, 6, 7),
#  datetime.date(2021, 10, 5),
#  datetime.date(2017, 11, 8),
#  datetime.date(2023, 12, 4),
#  datetime.date(2023, 1, 10),
#  datetime.date(2019, 8, 5),
#  datetime.date(2023, 10, 13),
#  datetime.date(2020, 5, 11),
#  datetime.date(2019, 11, 7),
#  datetime.date(2022, 6, 15),
#  datetime.date(2022, 2, 7),
#  datetime.date(2018, 3, 14),
#  datetime.date(2022, 12, 23),
#  datetime.date(2023, 11, 16),
#  datetime.date(2019, 8, 16),
#  datetime.date(2019, 1, 8),
#  datetime.date(2017, 4, 12),
#  datetime.date(2020, 11, 26),
#  datetime.date(2021, 12, 30),
#  datetime.date(2023, 8, 30),
#  datetime.date(2019, 12, 6),
#  datetime.date(2021, 9, 21),
#  datetime.date(2017, 12, 11),
#  datetime.date(2020, 11, 17),
#  datetime.date(2022, 5, 23),
#  datetime.date(2022, 5, 18),
#  datetime.date(2022, 1, 4),
#  datetime.date(2020, 3, 31),
#  datetime.date(2022, 5, 6),
#  datetime.date(2018, 1, 12),
#  datetime.date(2020, 2, 14),
#  datetime.date(2020, 10, 19),
#  datetime.date(2019, 7, 12),
#  datetime.date(2019, 3, 1),
#  datetime.date(2024, 4, 19),
#  datetime.date(2020, 4, 21),
#  datetime.date(2021, 2, 4),
#  datetime.date(2021, 1, 27),
#  datetime.date(2019, 7, 9),
#  datetime.date(2022, 5, 17),
#  datetime.date(2021, 7, 28),
#  datetime.date(2019, 4, 5),
#  datetime.date(2017, 11, 20),
#  datetime.date(2020, 10, 1),
#  datetime.date(2017, 9, 4),
#  datetime.date(2022, 12, 30),
#  datetime.date(2023, 12, 27),
#  datetime.date(2024, 4, 4),
#  datetime.date(2018, 4, 9),
#  datetime.date(2020, 8, 20),
#  datetime.date(2021, 7, 7),
#  datetime.date(2017, 6, 29),
#  datetime.date(2017, 3, 1),
#  datetime.date(2018, 9, 25),
#  datetime.date(2023, 6, 6),
#  datetime.date(2023, 1, 17),
#  datetime.date(2020, 4, 24),
#  datetime.date(2022, 11, 29),
#  datetime.date(2022, 8, 1),
#  datetime.date(2023, 5, 9),
#  datetime.date(2024, 3, 22),
#  datetime.date(2017, 7, 31),
#  datetime.date(2021, 12, 16),
#  datetime.date(2022, 2, 25),
#  datetime.date(2017, 3, 16),
#  datetime.date(2020, 6, 11),
#  datetime.date(2023, 4, 17),
#  datetime.date(2023, 11, 9),
#  datetime.date(2022, 12, 8),
#  datetime.date(2017, 7, 3),
#  datetime.date(2018, 9, 11),
#  datetime.date(2021, 2, 5),
#  datetime.date(2021, 12, 6),
#  datetime.date(2022, 6, 23),
#  datetime.date(2019, 8, 13),
#  datetime.date(2024, 2, 28),
#  datetime.date(2019, 1, 17),
#  datetime.date(2023, 7, 4),
#  datetime.date(2023, 6, 15),
#  datetime.date(2022, 11, 25),
#  datetime.date(2021, 8, 11),
#  datetime.date(2018, 7, 10),
#  datetime.date(2022, 3, 28),
#  datetime.date(2024, 1, 16),
#  datetime.date(2020, 9, 11),
#  datetime.date(2019, 11, 4),
#  datetime.date(2017, 7, 18),
#  datetime.date(2022, 8, 18),
#  datetime.date(2018, 1, 19),
#  datetime.date(2023, 5, 24),
#  datetime.date(2019, 8, 19),
#  datetime.date(2021, 12, 21),
#  datetime.date(2024, 1, 8),
#  datetime.date(2019, 11, 6),
#  datetime.date(2021, 12, 24),
#  datetime.date(2022, 3, 9),
#  datetime.date(2020, 2, 12),
#  datetime.date(2021, 8, 16),
#  datetime.date(2024, 1, 11),
#  datetime.date(2021, 9, 29),
#  datetime.date(2017, 3, 15),
#  datetime.date(2018, 12, 6),
#  datetime.date(2017, 3, 20),
#  datetime.date(2023, 5, 30),
#  datetime.date(2023, 3, 6),
#  datetime.date(2019, 5, 22),
#  datetime.date(2020, 5, 15),
#  datetime.date(2017, 7, 13),
#  datetime.date(2018, 12, 26),
#  datetime.date(2018, 7, 31),
#  datetime.date(2018, 5, 3),
#  datetime.date(2021, 7, 27),
#  datetime.date(2023, 12, 28),
#  datetime.date(2023, 4, 20),
#  datetime.date(2017, 8, 17),
#  datetime.date(2018, 12, 21),
#  datetime.date(2018, 8, 29),
#  datetime.date(2017, 3, 27),
#  datetime.date(2019, 6, 10),
#  datetime.date(2024, 1, 15),
#  datetime.date(2022, 4, 18),
#  datetime.date(2018, 8, 13),
#  datetime.date(2024, 3, 11),
#  datetime.date(2019, 3, 19),
#  datetime.date(2020, 11, 25),
#  datetime.date(2022, 11, 28),
#  datetime.date(2018, 11, 5),
#  datetime.date(2023, 8, 14),
#  datetime.date(2020, 1, 2),
#  datetime.date(2018, 5, 14),
#  datetime.date(2018, 5, 30),
#  datetime.date(2022, 9, 16),
#  datetime.date(2024, 2, 2),
#  datetime.date(2017, 2, 17),
#  datetime.date(2020, 2, 20),
#  datetime.date(2020, 2, 25),
#  datetime.date(2020, 11, 19),
#  datetime.date(2020, 6, 2),
#  datetime.date(2019, 3, 18),
#  datetime.date(2019, 5, 30),
#  datetime.date(2023, 3, 27),
#  datetime.date(2023, 5, 22),
#  datetime.date(2018, 5, 9),
#  datetime.date(2017, 7, 11),
#  datetime.date(2017, 9, 6),
#  datetime.date(2020, 1, 20),
#  datetime.date(2022, 8, 17),
#  datetime.date(2018, 2, 19),
#  datetime.date(2022, 4, 19),
#  datetime.date(2019, 6, 28),
#  datetime.date(2021, 10, 6),
#  datetime.date(2018, 11, 7),
#  datetime.date(2020, 3, 26),
#  datetime.date(2020, 1, 27),
#  datetime.date(2021, 7, 29),
#  datetime.date(2022, 10, 17),
#  datetime.date(2019, 3, 15),
#  datetime.date(2023, 4, 19),
#  datetime.date(2020, 8, 7),
#  datetime.date(2017, 12, 28),
#  datetime.date(2019, 1, 29),
#  datetime.date(2023, 7, 27),
#  datetime.date(2018, 9, 5),
#  datetime.date(2018, 6, 6),
#  datetime.date(2018, 1, 16),
#  datetime.date(2020, 4, 28),
#  datetime.date(2024, 5, 8),
#  datetime.date(2018, 2, 16),
#  datetime.date(2020, 6, 30),
#  datetime.date(2018, 9, 26),
#  datetime.date(2019, 3, 8),
#  datetime.date(2021, 10, 19),
#  datetime.date(2017, 11, 16),
#  datetime.date(2020, 2, 19),
#  datetime.date(2019, 9, 3),
#  datetime.date(2023, 10, 27),
#  datetime.date(2023, 11, 7),
#  datetime.date(2018, 10, 5),
#  datetime.date(2022, 9, 1),
#  datetime.date(2018, 4, 11),
#  datetime.date(2022, 8, 24),
#  datetime.date(2018, 10, 8),
#  datetime.date(2020, 3, 4),
#  datetime.date(2017, 12, 8),
#  datetime.date(2023, 1, 31),
#  datetime.date(2024, 2, 16),
#  datetime.date(2018, 8, 20),
#  datetime.date(2022, 1, 24),
#  datetime.date(2019, 11, 25),
#  datetime.date(2020, 1, 28),
#  datetime.date(2017, 10, 4),
#  datetime.date(2021, 11, 16),
#  datetime.date(2019, 3, 5),
#  datetime.date(2017, 4, 13),
#  datetime.date(2022, 9, 29),
#  datetime.date(2023, 12, 26),
#  datetime.date(2019, 10, 22),
#  datetime.date(2024, 3, 26),
#  datetime.date(2024, 2, 27),
#  datetime.date(2018, 2, 15),
#  datetime.date(2017, 4, 24),
#  datetime.date(2018, 8, 3),
#  datetime.date(2018, 7, 18),
#  datetime.date(2019, 11, 28),
#  datetime.date(2020, 12, 2),
#  datetime.date(2022, 3, 29),
#  datetime.date(2021, 4, 19),
#  datetime.date(2020, 8, 4),
#  datetime.date(2018, 4, 27),
#  datetime.date(2017, 6, 20),
#  datetime.date(2019, 5, 28),
#  datetime.date(2018, 8, 28),
#  datetime.date(2021, 9, 3),
#  datetime.date(2018, 2, 28),
#  datetime.date(2017, 7, 17),
#  datetime.date(2022, 4, 25),
#  datetime.date(2017, 8, 14),
#  datetime.date(2022, 3, 21),
#  datetime.date(2018, 11, 9),
#  datetime.date(2017, 6, 16),
#  datetime.date(2020, 2, 7),
#  datetime.date(2020, 11, 13),
#  datetime.date(2017, 8, 30),
#  datetime.date(2019, 1, 28),
#  datetime.date(2021, 7, 20),
#  datetime.date(2021, 4, 16),
#  datetime.date(2017, 9, 26),
#  datetime.date(2021, 6, 11),
#  datetime.date(2017, 12, 22),
#  datetime.date(2018, 6, 20),
#  datetime.date(2021, 9, 20),
#  datetime.date(2017, 9, 15),
#  datetime.date(2018, 6, 19),
#  datetime.date(2020, 10, 30),
#  datetime.date(2017, 1, 3),
#  datetime.date(2023, 7, 17),
#  datetime.date(2017, 3, 22),
#  datetime.date(2019, 2, 26),
#  datetime.date(2020, 5, 18),
#  datetime.date(2024, 1, 4),
#  datetime.date(2023, 4, 28),
#  datetime.date(2017, 12, 15),
#  datetime.date(2019, 5, 7),
#  datetime.date(2021, 5, 26),
#  datetime.date(2021, 5, 18),
#  datetime.date(2021, 12, 8),
#  datetime.date(2022, 3, 14),
#  datetime.date(2023, 1, 27),
#  datetime.date(2020, 7, 20),
#  datetime.date(2022, 3, 30),
#  datetime.date(2022, 3, 16),
#  datetime.date(2022, 3, 3),
#  datetime.date(2021, 1, 4),
#  datetime.date(2020, 8, 28),
#  datetime.date(2022, 2, 18),
#  datetime.date(2022, 9, 7),
#  datetime.date(2020, 3, 18),
#  datetime.date(2022, 4, 6),
#  datetime.date(2020, 6, 18),
#  datetime.date(2020, 7, 15),
#  datetime.date(2017, 5, 9),
#  datetime.date(2017, 3, 24),
#  datetime.date(2019, 5, 14),
#  datetime.date(2024, 4, 1),
#  datetime.date(2024, 5, 24),
#  datetime.date(2017, 4, 11),
#  datetime.date(2019, 9, 25),
#  datetime.date(2018, 2, 6),
#  datetime.date(2018, 6, 26),
#  datetime.date(2022, 9, 21),
#  datetime.date(2023, 1, 12),
#  datetime.date(2022, 5, 31),
#  datetime.date(2018, 7, 19),
#  datetime.date(2022, 12, 27),
#  datetime.date(2020, 8, 3),
#  datetime.date(2024, 4, 10),
#  datetime.date(2023, 9, 7),
#  datetime.date(2017, 5, 5),
#  datetime.date(2020, 9, 3),
#  datetime.date(2023, 1, 23),
#  datetime.date(2021, 4, 29),
#  datetime.date(2017, 1, 17),
#  datetime.date(2020, 12, 1),
#  datetime.date(2023, 8, 10),
#  datetime.date(2017, 3, 29),
#  datetime.date(2021, 12, 27),
#  datetime.date(2018, 8, 9),
#  datetime.date(2018, 10, 3),
#  datetime.date(2021, 3, 8),
#  datetime.date(2020, 9, 15),
#  datetime.date(2021, 1, 18),
#  datetime.date(2019, 10, 11),
#  datetime.date(2019, 1, 16),
#  datetime.date(2018, 10, 4),
#  datetime.date(2019, 4, 25),
#  datetime.date(2020, 9, 23),
#  datetime.date(2021, 10, 7),
#  datetime.date(2020, 9, 30),
#  datetime.date(2020, 2, 6),
#  datetime.date(2021, 6, 18),
#  datetime.date(2018, 8, 8),
#  datetime.date(2018, 10, 16),
#  datetime.date(2021, 8, 9),
#  datetime.date(2023, 3, 17),
#  datetime.date(2024, 5, 18),
#  datetime.date(2020, 2, 10),
#  datetime.date(2018, 6, 29),
#  datetime.date(2018, 7, 4),
#  datetime.date(2018, 9, 12),
#  datetime.date(2017, 2, 16),
#  datetime.date(2021, 5, 28),
#  datetime.date(2020, 4, 27),
#  datetime.date(2022, 12, 1),
#  datetime.date(2023, 5, 15),
#  datetime.date(2017, 3, 2),
#  datetime.date(2024, 5, 3),
#  datetime.date(2019, 5, 29),
#  datetime.date(2020, 9, 18),
#  datetime.date(2020, 6, 8),
#  ...}

# %%
def rename_ohlc_columns(df: pl.DataFrame) -> pl.DataFrame:

    column_mapping = {"o": "open", "h": "high", "l": "low", "c": "close", "v": "volume"}
    df = df.rename(column_mapping)

    return df

# %%
async def create_sell_signals(df):

    df["sell_signal"] = False

    df["sell_signal"] = (df["high"] < df["high"].shift(1)) & (
        df["high"].shift(2) < df["high"].shift(1)
    )

    return df

async def create_buy_signals(df):
    df["buy_signal"] = False

    df["buy_signal"] = (df["low"] > df["low"].shift(1)) & (
        df["low"].shift(2) > df["low"].shift(1)
    )

    return df

async def create_ma(df, period):
    df["close"] = pd.to_numeric(df["close"], errors="coerce")
    df["ma"] = df["close"].rolling(window=period).mean()
    return df

# %%
PORTFOLIO_VALUE = 10_00_000 # 10 Lacs
RPT_PCT = 0.01 # 1% RPT
SLIPPAGE_ = 0.0001
LEVERAGE_ = 5

# %%
async def positional(df):

    in_trade = False
    tradebook = []
    remark = ''
    points = 0
    entry_price = None
    exit_price = None
    initial_sl = None
    # stoploss = None
    is_trailing_active = False

    for i in range(3, len(df)):
        # SHORT Variation
    
        if (not in_trade) and (df.iloc[i]['low'] < df.iloc[i-1]['low']) and (df.iloc[i-1]['sell_signal'] == True):
            #Entry Triggered
            if df.iloc[i]['open'] < df.iloc[i-1]['low']:
                if df.iloc[i]['high'] >= df.iloc[i-1]['low']:
                    in_trade = True
                    entry_price = df.iloc[i-1]['low']
                    entry_time = df.iloc[i]['datetime']
                    signal_time = df.iloc[i-1]['datetime']
                    initial_sl = max(df.iloc[i-1]['high'], df.iloc[i-2]['high'], df.iloc[i-3]['high'])
                    # stoploss = max(df.iloc[i-1]['high'], df.iloc[i-2]['high'], df.iloc[i-3]['high'])

        if in_trade:
            trade_entry_price = entry_price
            trade_initial_sl = initial_sl
            trade_final_sl = initial_sl

            if (
                not is_trailing_active
                and df.iloc[i]['high'] < df.iloc[i]['ma']
            ):
                is_trailing_active = True
            
            if not is_trailing_active:
                if df.iloc[i]['open'] > trade_initial_sl:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        if df.iloc[i]['close'] >= trade_initial_sl:
                            in_trade = False
                            points = trade_entry_price - trade_initial_sl
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL hit"

                    else:
                        # Gap Open Outside ISL
                        
                        in_trade = False
                        points = trade_entry_price - df.iloc[i]['open']
                        exit_price = df.iloc[i]['open']
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif df.iloc[i]['high'] >= trade_initial_sl:
                    # Initial SL Hit

                    in_trade = False
                    points = trade_entry_price - trade_initial_sl
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL Hit"

            else:
                trade_final_sl = min(trade_initial_sl, df.iloc[i]['ma'])
                if df.iloc[i]['open'] > trade_initial_sl:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        if df.iloc[i]['close'] >= trade_initial_sl:
                            in_trade = False
                            points = trade_entry_price - trade_initial_sl
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL hit"

                    else:
                        # Gap Open Outside ISL
                        
                        in_trade = False
                        points = trade_entry_price - df.iloc[i]['open']
                        exit_price = df.iloc[i]['open']
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif df.iloc[i]['high'] >= trade_initial_sl:
                    # Initial SL Hit

                    in_trade = False
                    points = trade_entry_price - trade_initial_sl
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL Hit"

                elif df.iloc[i]['close'] >= trade_final_sl:
                    # Initial SL Hit

                    in_trade = False
                    points = trade_entry_price - df.iloc[i]['close']
                    exit_price = df.iloc[i]['close']
                    exit_time = df.iloc[i]["datetime"]
                    remark = "TSL Hit"
    
        if points:
            slippage = SLIPPAGE_ * (entry_price + exit_price)
            final_points = points - slippage
            # sl_in_points = abs(entry_price - initial_sl)
            qty = PORTFOLIO_VALUE * LEVERAGE_ / entry_price
            trade = {
                'Signal Time': signal_time,
                'Trade Type': 'SHORT',
                'Entry Date': entry_time.date(),
                'Entry Time': entry_time.time(),
                'Entry Price': entry_price,
                'Initial SL': trade_initial_sl,
                'Final SL': trade_final_sl,
                'Exit Date': exit_time.date(),
                'Exit Time': exit_time.time(),
                'Exit Price': exit_price,
                'Points Captured': points,
                'After Costs': final_points,
                'Remarks': remark,
                'Qty': qty,
                'ROI%': (points * qty / PORTFOLIO_VALUE) * 100,
                'ROI% w cs': (final_points * qty / PORTFOLIO_VALUE) * 100,
                'Trade Year': entry_time.year,
            }
            # print(trade)
            tradebook.append(trade)
            points = 0
            in_trade = False
            remark = ''
            entry_price = None
            exit_price = None
            initial_sl = None
            # stoploss = None
            is_trailing_active = False

    for i in range(3, len(df)):
        # LONG Variation
        
        if (not in_trade) and (df.iloc[i]['high'] >= df.iloc[i-1]['high']) and (df.iloc[i-1]['buy_signal'] == True):
            #Entry Triggered
            if df.iloc[i]['open'] > df.iloc[i-1]['high']:
                if df.iloc[i]['low'] <= df.iloc[i-1]['high']:
                    in_trade = True
                    entry_price = df.iloc[i-1]['high']
                    entry_time = df.iloc[i]['datetime']
                    signal_time = df.iloc[i-1]['datetime']
                    initial_sl = min(df.iloc[i-1]['low'], df.iloc[i-2]['low'], df.iloc[i-3]['low'])
                    # stoploss = max(df.iloc[i-1]['low'], df.iloc[i-2]['low'], df.iloc[i-3]['low'])

        if in_trade:
            trade_entry_price = entry_price
            trade_initial_sl = initial_sl
            trade_final_sl = initial_sl

            if (
                not is_trailing_active
                and df.iloc[i]['low'] > df.iloc[i]['ma']
            ):
                is_trailing_active = True
            
            if not is_trailing_active:
                if df.iloc[i]['open'] < trade_initial_sl:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        if df.iloc[i]['close'] <= trade_initial_sl:
                            in_trade = False
                            points = trade_initial_sl - trade_entry_price
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL hit"

                    else:
                        # Gap Open Outside ISL
                        
                        in_trade = False
                        points = df.iloc[i]['open'] - trade_entry_price
                        exit_price = df.iloc[i]['open']
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif df.iloc[i]['low'] <= trade_initial_sl:
                    # Initial SL Hit

                    in_trade = False
                    points = trade_initial_sl - trade_entry_price
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL Hit"

            else:
                trade_final_sl = max(trade_initial_sl, df.iloc[i]['ma'])
                if df.iloc[i]['open'] < trade_initial_sl:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        if df.iloc[i]['close'] <= trade_initial_sl:
                            in_trade = False
                            points = trade_initial_sl - trade_entry_price
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL hit"

                    else:
                        # Gap Open Outside ISL
                        
                        in_trade = False
                        points = df.iloc[i]['open'] - trade_entry_price
                        exit_price = df.iloc[i]['open']
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif df.iloc[i]['low'] <= trade_initial_sl:
                    # Initial SL Hit

                    in_trade = False
                    points = trade_initial_sl - trade_entry_price
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL Hit"

                elif df.iloc[i]['close'] <= trade_final_sl:
                    # Initial SL Hit

                    in_trade = False
                    points = df.iloc[i]['close'] - trade_entry_price
                    exit_price = df.iloc[i]['close']
                    exit_time = df.iloc[i]["datetime"]
                    remark = "TSL Hit"    

        if points:
            slippage = SLIPPAGE_ * (entry_price + exit_price)
            final_points = points - slippage
            # sl_in_points = abs(entry_price - initial_sl)
            qty = PORTFOLIO_VALUE * LEVERAGE_ / entry_price
            trade = {
                'Signal Time': signal_time,
                'Trade Type': 'LONG',
                'Entry Date': entry_time.date(),
                'Entry Time': entry_time.time(),
                'Entry Price': entry_price,
                'Initial SL': trade_initial_sl,
                'Final SL': trade_final_sl,
                'Exit Date': exit_time.date(),
                'Exit Time': exit_time.time(),
                'Exit Price': exit_price,
                'Points Captured': points,
                'After Costs': final_points,
                'Remarks': remark,
                'Qty': qty,
                'ROI%': (points * qty / PORTFOLIO_VALUE) * 100,
                'ROI% w cs': (final_points * qty / PORTFOLIO_VALUE) * 100,
                'Trade Year': entry_time.year,
            }
            # print(trade)
            tradebook.append(trade)
            points = 0
            in_trade = False
            remark = ''
            entry_price = None
            exit_price = None
            initial_sl = None
            # stoploss = None
            is_trailing_active = False

    return pd.DataFrame(tradebook)

# %%
# async def trade(spot_data, index, tf):

#     if index == "bnf":
#         SPREAD = 100
#         index_full = "BANKNIFTY"
#     elif index == "nifty":
#         SPREAD = 50
#         index_full = "NIFTY"

#     start_date = dt.date(2017, 1, 1)
#     end_date = dt.date(2024, 3, 31)

#     flag = False

#     current_date = start_date

#     final_tb = pd.DataFrame()
#     tradebook = []

#     while current_date <= end_date:
#         # print(current_date)

#         if current_date.weekday() >= 5:
#             print("Skipping Weekend ! ", current_date)
#             current_date += dt.timedelta(days=1)
#             continue
#         elif current_date not in list_of_traded_dates:
#             print("Date Avoided ! ", current_date)
#             current_date += dt.timedelta(days=1)
#             continue
#         # elif current_date in list_of_dates_to_avoid_bnf:
#         #     # print('Date Avoided ! ', current_date)
#         #     current_date += dt.timedelta(days=1)
#         #     continue
#         else:
#             print("Working", current_date)
#             spot = spot_data[spot_data["datetime"].dt.date == current_date]
#             spot_open = spot.iloc[0]["open"]
#             # print(spot_open)
#             atm = int(round(spot_open / SPREAD) * SPREAD)
#             # print(atm)

#             current_expiry = await get_expiry(current_date, index)
#             dte = current_expiry - current_date

#             ce_df = await fetch_option_data(
#                 index=index,
#                 start_date=current_date,
#                 end_date=current_date,
#                 start_time=dt.time(9, 15),
#                 end_time=dt.time(15, 30),
#                 expiry=current_expiry,
#                 strike=atm,
#                 asset_class="C",
#             )
#             if not isinstance(ce_df, pl.DataFrame):
#                 print('Data Not Found for Options')
#                 current_date += dt.timedelta(days=1)
#                 continue
#             # print(ce_df.head())
#             ce_df = rename_ohlc_columns(ce_df)
#             # ce_5min = resample(ce_df, "5m")
#             ce_df = resample(ce_df, tf)
#             # call_option = ce_5min.to_pandas()
#             call_option = ce_df.to_pandas()

#             pe_df = await fetch_option_data(
#                 index=index,
#                 start_date=current_date,
#                 end_date=current_date,
#                 start_time=dt.time(9, 15),
#                 end_time=dt.time(15, 30),
#                 expiry=current_expiry,
#                 strike=atm,
#                 asset_class="P",
#             )
#             if not isinstance(pe_df, pl.DataFrame):
#                 print('Data Not Found for Options')
#                 current_date += dt.timedelta(days=1)
#                 continue
#             # print(pe_df.head())
#             pe_df = rename_ohlc_columns(pe_df)
#             # pe_5min = resample(pe_df, "5m")
#             pe_df = resample(pe_df, tf)
#             # put_option = pe_5min.to_pandas()
#             put_option = pe_df.to_pandas()

#             # call_option['datetime'] = pd.to_datetime(call_option['datetime'])
#             # put_option['datetime'] = pd.to_datetime(put_option['datetime'])

#             ce_df = await create_sell_signals(call_option)
#             pe_df = await create_sell_signals(put_option)

#             # print(ce_df.head())
#             # print(pe_df.head())

#             ce_contract = await get_option_contract_name(
#                 symbol=index_full,
#                 strike=atm,
#                 expiry=current_expiry,
#                 opt_type='CE'
#             )

#             pe_contract = await get_option_contract_name(
#                 symbol=index_full,
#                 strike=atm,
#                 expiry=current_expiry,
#                 opt_type='PE'
#             )

#             ce_trades = await option_trading(ce_df, ce_contract, atm, current_expiry)
#             pe_trades = await option_trading(pe_df, pe_contract, atm, current_expiry)

#             final_tb = pd.concat([final_tb, ce_trades, pe_trades], ignore_index=True)

#         current_date += dt.timedelta(days=1)

#     return final_tb

# %%
async def trade_positional(spot_data, index, tf, offset, ma):

    if index == "bnf":
        SPREAD = 100
        index_full = "BANKNIFTY"
    elif index == "nifty":
        SPREAD = 50
        index_full = "NIFTY"

    start_date = dt.date(2017, 1, 1)
    end_date = dt.date(2024, 3, 31)

    flag = False

    current_date = start_date

    final_tb = pd.DataFrame()
    tradebook = []

    # while current_date <= end_date:
        # print(current_date)

    # if current_date.weekday() >= 5:
    #     print("Skipping Weekend ! ", current_date)
    #     current_date += dt.timedelta(days=1)
    #     continue
    # elif current_date not in list_of_traded_dates:
    #     print("Date Avoided ! ", current_date)
    #     current_date += dt.timedelta(days=1)
    #     continue
    # # elif current_date in list_of_dates_to_avoid_bnf:
    # #     # print('Date Avoided ! ', current_date)
    # #     current_date += dt.timedelta(days=1)
    # #     continue
    # else:
    #     print("Working", current_date)
    data = resample(spot_data, tf, offset)
    data_pandas = data.to_pandas()
    data_pandas = await create_buy_signals(data_pandas)
    data_pandas = await create_sell_signals(data_pandas)
    data_pandas = await create_ma(data_pandas, ma)
    # print(data.head(50))
    # break
    tb = await positional(data_pandas)
    final_tb = pd.concat([tb, final_tb])

        # current_date += dt.timedelta(days=1)

    return final_tb

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2017, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2017, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI% w cs"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI% w cs"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI% w cs"] > 0]["ROI% w cs"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI% w cs"] < 0]["ROI% w cs"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI% w cs"].cumsum() - year_trades["ROI% w cs"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI% w cs"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI% w cs"] > 0]["ROI% w cs"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI% w cs"] < 0]["ROI% w cs"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI% w cs"].cumsum() - combined_df_sorted["ROI% w cs"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation

    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    
    print(f'{overall_total_roi} , {overall_max_drawdown} , {overall_roi_dd_ratio}')
    
    return {overall_roi_dd_ratio: stats_df8}

# %%
tfs = ['15m', '30m', '60m', '1d']
for i in range(5, 81, 5):
    for tf in tfs:
        if tf == '30m' or tf == '60m':
            ofs = '15m'
        else:
            ofs = '0m'
        variation = f'TF : {tf} , TMA : {i}'
        print(variation)
        x = await trade_positional(pl.DataFrame(bnf_1min), 'bnf', tf, ofs, i)
        x['Entry Datetime'] = x.apply(lambda row: pd.to_datetime(f"{row['Entry Date']} {row['Entry Time']}"), axis=1)
        x = x.sort_values(by='Entry Datetime')
        stats = generate_stats(x, variation)
# x
# Out:
# TF : 15m , TMA : 5
# -2.1484906347173505 , -51.27533416930685 , -0.041901055732239886
# TF : 30m , TMA : 5
# 46.90416363707107 , -35.9291695958315 , 1.305461945396948
# TF : 60m , TMA : 5
# -15.557217926717726 , -121.67857951271488 , -0.1278550258313302
# TF : 1d , TMA : 5
# -91.62738918593134 , -221.79252093094613 , -0.4131220872612698
# TF : 15m , TMA : 10
# 13.904824039053988 , -52.017285287985324 , 0.26731160540332255
# TF : 30m , TMA : 10
# 74.72872282071658 , -59.29814461656528 , 1.2602202531618616
# TF : 60m , TMA : 10
# -113.22822156080419 , -204.40194457700642 , -0.5539488471849962
# TF : 1d , TMA : 10
# -41.43185958525342 , -196.62269113433234 , -0.21071758984799588
# TF : 15m , TMA : 15
# -12.405262883263873 , -50.88307122330944 , -0.24379941275205583
# TF : 30m , TMA : 15
# 49.10383189536759 , -83.16140678392492 , 0.5904641803733814
# TF : 60m , TMA : 15
# -124.56560660191923 , -238.31814213762715 , -0.5226862104773518
# TF : 1d , TMA : 15
# -2.7933588799707323 , -193.33426303335455 , -0.014448338520776396
# TF : 15m , TMA : 20
# 15.439805786449504 , -53.800534449930865 , 0.2869823867794188
# TF : 30m , TMA : 20
# 9.808899662223048 , -77.5167535137949 , 0.1265390927456405
# TF : 60m , TMA : 20
# -183.02720107513943 , -285.41632888700224 , -0.641263945159917
# TF : 1d , TMA : 20
# 148.8478724613328 , -140.1648099217955 , 1.0619489481302902
# TF : 15m , TMA : 25
# -0.1415540614319717 , -46.00199453979842 , -0.003077128782090238
# TF : 30m , TMA : 25
# 14.397648624885086 , -71.99744472246816 , 0.19997443909828133
# TF : 60m , TMA : 25
# -220.8848344977282 , -306.8943316260036 , -0.7197423078081131
# TF : 1d , TMA : 25
# 147.5620230664877 , -145.28577352335168 , 1.0156673945971053
# TF : 15m , TMA : 30
# 12.119221388916205 , -65.7616558016349 , 0.18429008882429795
# TF : 30m , TMA : 30
# 60.26363053388764 , -88.24749724412065 , 0.6828933671306198
# TF : 60m , TMA : 30
# -260.8238933312561 , -324.0862573350366 , -0.8047977580907401
# TF : 1d , TMA : 30
# 134.00360852707564 , -151.6596605005788 , 0.8835810925909611
# TF : 15m , TMA : 35
# 57.90423967888921 , -56.596100344027704 , 1.023113594875085
# TF : 30m , TMA : 35
# 11.68356156447205 , -117.81079603347686 , 0.09917224870590022
# TF : 60m , TMA : 35
# -223.4685322590454 , -314.47826567630295 , -0.7106008797729277
# TF : 1d , TMA : 35
# 176.424770871628 , -130.685020339182 , 1.3499999496019692
# TF : 15m , TMA : 40
# 23.773360942283 , -66.71101439786966 , 0.3563633555397139
# TF : 30m , TMA : 40
# 12.158986154062397 , -118.37735332341687 , 0.1027137861482933
# TF : 60m , TMA : 40
# -245.46699617317103 , -329.25604079048725 , -0.7455200991418317
# TF : 1d , TMA : 40
# 270.3574430252487 , -98.10747958520983 , 2.7557271287397986
# TF : 15m , TMA : 45
# 15.96789472620469 , -60.04649212454839 , 0.2659255213957228
# TF : 30m , TMA : 45
# 30.427104848249247 , -122.72318022816286 , 0.24793282566243952
# TF : 60m , TMA : 45
# -222.6068739997314 , -310.2659623139923 , -0.7174711410156264
# TF : 1d , TMA : 45
# 268.7294829389882 , -111.71809105116549 , 2.4054249442546727
# TF : 15m , TMA : 50
# -13.21613800815366 , -69.6221032337038 , -0.18982675607759833
# TF : 30m , TMA : 50
# -6.014145378337981 , -130.30747804146034 , -0.046153493788164954
# TF : 60m , TMA : 50
# -201.3581312736619 , -296.75458987696385 , -0.6785341765299945
# TF : 1d , TMA : 50
# 252.8005820648982 , -114.67374179073408 , 2.204520216373764
# TF : 15m , TMA : 55
# -28.814256445451278 , -97.17832630191248 , -0.2965090832695707
# TF : 30m , TMA : 55
# -32.0732256373998 , -145.84452285958048 , -0.21991381649813477
# TF : 60m , TMA : 55
# -203.3541849610118 , -290.54061937875963 , -0.6999165397107924
# TF : 1d , TMA : 55
# 279.81991531819176 , -128.9593838325146 , 2.1698298099935602
# TF : 15m , TMA : 60
# -19.820829518757677 , -108.6861270376944 , -0.18236761267501453
# TF : 30m , TMA : 60
# -22.75813366946374 , -139.43560342967038 , -0.1632160876396441
# TF : 60m , TMA : 60
# -173.91615056171992 , -301.7696581754576 , -0.5763208654350532
# TF : 1d , TMA : 60
# 433.162464699558 , -96.96090144453657 , 4.467393126984643
# TF : 15m , TMA : 65
# 10.76094275152392 , -91.1831700466809 , 0.11801457161464
# TF : 30m , TMA : 65
# 14.683000590958418 , -129.48680726450505 , 0.11339379587115146
# TF : 60m , TMA : 65
# -157.90552215294397 , -274.4847125695209 , -0.5752798422715436
# TF : 1d , TMA : 65
# 315.6657038202974 , -96.96090144453657 , 3.255597865917779
# TF : 15m , TMA : 70
# 9.444909733603005 , -83.0480136014001 , 0.11372830395360321
# TF : 30m , TMA : 70
# 9.894184725538235 , -131.14087186969067 , 0.07544699516234482
# TF : 60m , TMA : 70
# -188.9757393016416 , -283.2625517403829 , -0.6671398606718848
# TF : 1d , TMA : 70
# 412.446069358849 , -97.88965864312472 , 4.2133773380751
# TF : 15m , TMA : 75
# 35.81446345522737 , -97.85658311731301 , 0.36598931123818274
# TF : 30m , TMA : 75
# -40.14978327346249 , -161.152196216245 , -0.24914201739817915
# TF : 60m , TMA : 75
# -196.90105964945081 , -286.41820733233004 , -0.6874599959386911
# TF : 1d , TMA : 75
# 494.60781573069886 , -100.8468215634294 , 4.904545409193749
# TF : 15m , TMA : 80
# 79.63350519417666 , -67.8592075466463 , 1.1735106859218292
# TF : 30m , TMA : 80
# -43.072090963679194 , -165.97024403467123 , -0.25951694663220126
# TF : 60m , TMA : 80
# -195.88717026019236 , -288.4298881205059 , -0.6791500407140566
# TF : 1d , TMA : 80
# 439.10451479499704 , -100.8468215634294 , 4.3541730714717115

# %%
x['Entry Datetime'] = x.apply(lambda row: pd.to_datetime(f"{row['Entry Date']} {row['Entry Time']}"), axis=1)
x = x.sort_values(by='Entry Datetime')

# %%
roi = x['ROI%'].sum()
roi_w_cs = x['ROI% w cs'].sum()
roi, roi_w_cs
# Out:
# (445.87649142332333, 439.1045147949971)

# %%
x = await trade_positional(pl.DataFrame(bnf_1min), 'bnf', '30m', '15m', 10)
x['Entry Datetime'] = x.apply(lambda row: pd.to_datetime(f"{row['Entry Date']} {row['Entry Time']}"), axis=1)
x = x.sort_values(by='Entry Datetime')
stats = generate_stats(x, variation)
# Out:
# 74.72872282071658 , -59.29814461656528 , 1.2602202531618616

# %%
for a, b in stats.items():
    print(a)
    print(b.to_string())
# Out:
# 1.2602202531618616
#         Total ROI Total Trades Win Rate Avg Profit% per Trade Avg Loss% per Trade Max Drawdown ROI/DD Ratio           Variation
# 2017      -3.4698           35  34.2857                2.1942             -1.2957     -12.3728      -0.2804  TF : 1d , TMA : 80
# 2018      12.5211           33  36.3636                3.7933             -1.5713     -17.1515       0.7300  TF : 1d , TMA : 80
# 2019      67.9400           41  31.7073                8.7426             -1.6326     -17.0856       3.9765  TF : 1d , TMA : 80
# 2020      23.4801           40  35.0000                7.3451             -3.0520     -27.5563       0.8521  TF : 1d , TMA : 80
# 2021      -9.1626           36  19.4444                5.8960             -1.7391     -28.6834      -0.3194  TF : 1d , TMA : 80
# 2022      -6.8914           41  21.9512                4.3950             -1.4515     -18.1594      -0.3795  TF : 1d , TMA : 80
# 2023     -10.3380           51  33.3333                2.1730             -1.3906     -16.3606      -0.6319  TF : 1d , TMA : 80
# 2024       0.6494           21  19.0476                7.3923             -1.7012     -14.4474       0.0449  TF : 1d , TMA : 80
# Overall   74.7287          298  29.5302                4.9508             -1.7188     -59.2981       1.2602  TF : 1d , TMA : 80

# %%
x.tail()
# Out:
#              Signal Time Trade Type  Entry Date Entry Time  Entry Price  \
# 1822 2024-05-30 15:15:00       LONG  2024-05-31   09:15:00   48838.6500
# 97   2024-05-31 09:45:00      SHORT  2024-05-31   10:15:00   48719.5000
# 1823 2024-05-31 12:45:00       LONG  2024-05-31   13:15:00   48863.4000
# 1824 2024-06-04 12:45:00       LONG  2024-06-04   13:15:00   47399.9000
# 1825 2024-06-06 13:15:00       LONG  2024-06-06   13:45:00   49378.8500
#
#       Initial SL   Final SL   Exit Date Exit Time  Exit Price  \
# 1822  48545.0000 48789.3950  2024-05-31  09:45:00  48719.5000
# 97    49079.0500 48766.0900  2024-05-31  12:45:00  48836.9500
# 1823  48681.2500 50690.5550  2024-06-04  09:15:00  49104.6000
# 1824  46077.8500 49267.7750  2024-06-06  12:15:00  49165.5000
# 1825  48906.7500 49738.0650  2024-06-07  14:15:00  49735.4500
#
#       Points Captured  After Costs  Remarks      Qty    ROI%  ROI% w cs  \
# 1822        -119.1500    -128.9058  TSL Hit 102.3779 -1.2198    -1.3197
# 97          -117.4500    -127.2056  TSL Hit 102.6283 -1.2054    -1.3055
# 1823         241.2000     231.4032  TSL Hit 102.3261  2.4681     2.3679
# 1824        1765.6000    1755.9435  TSL Hit 105.4855 18.6245    18.5226
# 1825         356.6000     346.6886  TSL Hit 101.2579  3.6109     3.5105
#
#       Trade Year      Entry Datetime
# 1822        2024 2024-05-31 09:15:00
# 97          2024 2024-05-31 10:15:00
# 1823        2024 2024-05-31 13:15:00
# 1824        2024 2024-06-04 13:15:00
# 1825        2024 2024-06-06 13:45:00

# %%
x['Slippage in Points'] = x.apply(lambda row: 0.25 / 100 * (row['Entry Price'] + row['Exit Price']), axis=1)

# %%
x['Final Points'] = x.apply(lambda row: row['Points Captured'] - row['Slippage in Points'])
x['PnL w cs'] = x.apply(lambda row: row['Final Points'] * row['Qty'])
x['ROI% w cs'] = x.aply(lambda row: row['PnL w cs'] * 100 / 1000000)

# %%
# x

# %%
async def trade_spot(spot_data, index, tf):

    start_date = dt.date(2017, 1, 1)
    end_date = dt.date(2024, 3, 31)

    flag = False

    current_date = start_date

    final_tb = pd.DataFrame()
    tradebook = []

    while current_date <= end_date:
        # print(current_date)

        if current_date.weekday() >= 5:
            print("Skipping Weekend ! ", current_date)
            current_date += dt.timedelta(days=1)
            continue
        elif current_date not in list_of_traded_dates:
            print("Date Avoided ! ", current_date)
            current_date += dt.timedelta(days=1)
            continue
        # elif current_date in list_of_dates_to_avoid_bnf:
        #     # print('Date Avoided ! ', current_date)
        #     current_date += dt.timedelta(days=1)
        #     continue
        else:
            print("Working", current_date)
            spot = spot_data[spot_data["datetime"].dt.date == current_date]
            spot_open = spot.iloc[0]["open"]
            # print(spot_open)

            spot_df = await create_sell_signals(spot_data)
            ce_df = await create_sell_signals(call_option)
            pe_df = await create_sell_signals(put_option)

            # print(ce_df.head())
            # print(pe_df.head())

            ce_contract = await get_option_contract_name(
                symbol=index_full,
                strike=atm,
                expiry=current_expiry,
                opt_type='CE'
            )

            pe_contract = await get_option_contract_name(
                symbol=index_full,
                strike=atm,
                expiry=current_expiry,
                opt_type='PE'
            )

            ce_trades = await option_trading(ce_df, ce_contract, atm, current_expiry)
            pe_trades = await option_trading(pe_df, pe_contract, atm, current_expiry)

            final_tb = pd.concat([final_tb, ce_trades, pe_trades], ignore_index=True)

        current_date += dt.timedelta(days=1)

    return final_tb
