# %%
import asyncio
import datetime as dt
import math
from typing import Literal

import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

# %%
import sys

sys.path.append("..")
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
async def get_expiry(f_today, index):

    if index == 'bnf':    
        if (f_today <= dt.date(2024, 1, 25)) and (f_today >= dt.date(2024, 1, 18)):
            f_expiry = dt.date(2024, 1, 25)
        elif (f_today <= dt.date(2024, 1, 31)) and (f_today >= dt.date(2024, 1, 26)):
            f_expiry = dt.date(2024, 1, 31)
        elif (f_today <= dt.date(2024, 2, 22)) and (f_today >= dt.date(2024, 2, 29)):
            f_expiry = dt.date(2024, 2, 29)
        elif (f_today <= dt.date(2024, 3, 25)) and (f_today >= dt.date(2024, 3, 27)):
            f_expiry = dt.date(2024, 2, 27)
        elif f_today < dt.date(2023, 9, 1):
            days_to_thursday = (3 - f_today.weekday()) % 7
            nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
            f_expiry = nearest_thursday
            if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
                f_expiry = nearest_thursday - dt.timedelta(days=1)
        elif f_today >= dt.date(2023, 9, 1):
            if f_today.day < 24:
                days_to_wednesday = (2 - f_today.weekday()) % 7
                nearest_wednesday = f_today + dt.timedelta(days=days_to_wednesday)
                f_expiry = nearest_wednesday
                if nse.valid_days(
                    start_date=nearest_wednesday, end_date=nearest_wednesday
                ).empty:
                    f_expiry = nearest_wednesday - dt.timedelta(days=1)
            else:
                days_to_thursday = (3 - f_today.weekday()) % 7
                nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
                f_expiry = nearest_thursday
                if nse.valid_days(
                    start_date=nearest_thursday, end_date=nearest_thursday
                ).empty:
                    f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'nifty':
        days_to_thursday = (3 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'finnifty' or index == 'fnf':
        days_to_thursday = (1 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'midcpnifty' or index == 'midcp':
        days_to_thursday = (0 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

async def get_expiry_nifty(f_today):

    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry


async def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"


def get_option_contract_name2(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"

# %%
bnf_1min = pd.read_csv("../data/ng_4h.csv")
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["time"])
bnf_1min = bnf_1min[bnf_1min["datetime"].dt.year >= 2012]

# %%
bnf_1min.head()
# Out:
#                         time     open     high      low    close  \
# 0  2015-03-02T09:00:00+05:30 169.0000 169.0000 167.8000 168.3000
# 1  2015-03-02T13:00:00+05:30 168.3000 168.8000 167.8000 168.4000
# 2  2015-03-02T17:00:00+05:30 168.3000 171.7000 168.2000 170.9000
# 3  2015-03-02T21:00:00+05:30 170.9000 171.7000 167.9000 169.1000
# 4  2015-03-03T09:00:00+05:30 168.8000 168.8000 166.1000 166.6000
#
#                    datetime
# 0 2015-03-02 09:00:00+05:30
# 1 2015-03-02 13:00:00+05:30
# 2 2015-03-02 17:00:00+05:30
# 3 2015-03-02 21:00:00+05:30
# 4 2015-03-03 09:00:00+05:30

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("open").first().alias("open"),
                pl.col("high").max().alias("high"),
                pl.col("low").min().alias("low"),
                pl.col("close").last().alias("close"),
                pl.col("volume").sum().alias("volume"),
            ]
        )
    )


# ohlc_resampled = resample(pl.DataFrame(bnf_1min), '7d', pd.Timedelta(days=4))
# ohlc_resampled

# %%
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["datetime"])
list_of_traded_dates = set(bnf_1min["datetime"].dt.date)
list_of_traded_dates
# Out:
# {datetime.date(2022, 1, 27),
#  datetime.date(2017, 1, 20),
#  datetime.date(2022, 8, 11),
#  datetime.date(2023, 2, 24),
#  datetime.date(2016, 10, 17),
#  datetime.date(2018, 7, 13),
#  datetime.date(2017, 5, 5),
#  datetime.date(2020, 6, 9),
#  datetime.date(2023, 3, 17),
#  datetime.date(2015, 3, 6),
#  datetime.date(2023, 5, 3),
#  datetime.date(2022, 5, 10),
#  datetime.date(2017, 2, 27),
#  datetime.date(2015, 6, 8),
#  datetime.date(2022, 8, 16),
#  datetime.date(2018, 1, 19),
#  datetime.date(2023, 5, 16),
#  datetime.date(2020, 1, 9),
#  datetime.date(2024, 9, 11),
#  datetime.date(2015, 3, 18),
#  datetime.date(2024, 8, 30),
#  datetime.date(2016, 8, 4),
#  datetime.date(2020, 11, 18),
#  datetime.date(2023, 9, 6),
#  datetime.date(2020, 8, 24),
#  datetime.date(2015, 10, 29),
#  datetime.date(2017, 2, 15),
#  datetime.date(2020, 1, 24),
#  datetime.date(2022, 1, 20),
#  datetime.date(2020, 7, 29),
#  datetime.date(2021, 11, 22),
#  datetime.date(2020, 3, 11),
#  datetime.date(2024, 1, 17),
#  datetime.date(2020, 6, 23),
#  datetime.date(2015, 7, 20),
#  datetime.date(2023, 2, 7),
#  datetime.date(2015, 12, 18),
#  datetime.date(2019, 9, 11),
#  datetime.date(2020, 7, 31),
#  datetime.date(2024, 7, 11),
#  datetime.date(2016, 8, 19),
#  datetime.date(2022, 6, 1),
#  datetime.date(2024, 3, 20),
#  datetime.date(2016, 11, 3),
#  datetime.date(2020, 8, 18),
#  datetime.date(2020, 3, 13),
#  datetime.date(2023, 8, 11),
#  datetime.date(2024, 6, 17),
#  datetime.date(2023, 8, 2),
#  datetime.date(2015, 10, 28),
#  datetime.date(2015, 6, 26),
#  datetime.date(2021, 5, 10),
#  datetime.date(2019, 2, 26),
#  datetime.date(2015, 5, 19),
#  datetime.date(2016, 1, 5),
#  datetime.date(2022, 7, 12),
#  datetime.date(2024, 8, 23),
#  datetime.date(2019, 9, 3),
#  datetime.date(2016, 11, 7),
#  datetime.date(2024, 8, 7),
#  datetime.date(2015, 10, 7),
#  datetime.date(2021, 8, 31),
#  datetime.date(2017, 2, 21),
#  datetime.date(2016, 9, 5),
#  datetime.date(2020, 7, 13),
#  datetime.date(2024, 5, 20),
#  datetime.date(2020, 7, 6),
#  datetime.date(2022, 11, 17),
#  datetime.date(2015, 8, 26),
#  datetime.date(2016, 12, 23),
#  datetime.date(2020, 9, 4),
#  datetime.date(2019, 5, 7),
#  datetime.date(2021, 8, 10),
#  datetime.date(2020, 5, 5),
#  datetime.date(2020, 9, 29),
#  datetime.date(2024, 8, 27),
#  datetime.date(2015, 11, 17),
#  datetime.date(2019, 8, 22),
#  datetime.date(2019, 1, 17),
#  datetime.date(2021, 4, 15),
#  datetime.date(2016, 5, 4),
#  datetime.date(2017, 5, 3),
#  datetime.date(2023, 5, 31),
#  datetime.date(2019, 2, 8),
#  datetime.date(2020, 10, 26),
#  datetime.date(2020, 8, 14),
#  datetime.date(2023, 11, 29),
#  datetime.date(2020, 9, 8),
#  datetime.date(2019, 7, 3),
#  datetime.date(2019, 4, 22),
#  datetime.date(2018, 2, 13),
#  datetime.date(2015, 4, 16),
#  datetime.date(2022, 10, 31),
#  datetime.date(2021, 2, 5),
#  datetime.date(2018, 1, 16),
#  datetime.date(2021, 12, 22),
#  datetime.date(2020, 6, 3),
#  datetime.date(2018, 12, 4),
#  datetime.date(2020, 5, 11),
#  datetime.date(2023, 3, 8),
#  datetime.date(2024, 6, 7),
#  datetime.date(2018, 6, 12),
#  datetime.date(2018, 8, 2),
#  datetime.date(2023, 5, 5),
#  datetime.date(2022, 8, 31),
#  datetime.date(2021, 4, 8),
#  datetime.date(2016, 11, 1),
#  datetime.date(2018, 5, 31),
#  datetime.date(2018, 7, 26),
#  datetime.date(2022, 5, 31),
#  datetime.date(2019, 10, 31),
#  datetime.date(2021, 1, 29),
#  datetime.date(2015, 6, 17),
#  datetime.date(2019, 1, 14),
#  datetime.date(2019, 7, 29),
#  datetime.date(2021, 12, 21),
#  datetime.date(2023, 11, 23),
#  datetime.date(2016, 12, 9),
#  datetime.date(2017, 8, 2),
#  datetime.date(2022, 12, 9),
#  datetime.date(2017, 11, 20),
#  datetime.date(2023, 9, 12),
#  datetime.date(2019, 10, 16),
#  datetime.date(2023, 5, 18),
#  datetime.date(2016, 12, 8),
#  datetime.date(2019, 12, 3),
#  datetime.date(2023, 3, 10),
#  datetime.date(2016, 3, 31),
#  datetime.date(2019, 5, 3),
#  datetime.date(2022, 3, 25),
#  datetime.date(2023, 3, 21),
#  datetime.date(2018, 2, 19),
#  datetime.date(2020, 4, 22),
#  datetime.date(2019, 9, 13),
#  datetime.date(2023, 10, 23),
#  datetime.date(2016, 4, 26),
#  datetime.date(2017, 6, 15),
#  datetime.date(2022, 6, 6),
#  datetime.date(2020, 12, 23),
#  datetime.date(2023, 7, 12),
#  datetime.date(2015, 5, 14),
#  datetime.date(2022, 11, 9),
#  datetime.date(2017, 12, 28),
#  datetime.date(2024, 4, 9),
#  datetime.date(2019, 10, 9),
#  datetime.date(2018, 12, 28),
#  datetime.date(2022, 9, 28),
#  datetime.date(2017, 10, 18),
#  datetime.date(2020, 8, 25),
#  datetime.date(2016, 1, 19),
#  datetime.date(2023, 10, 24),
#  datetime.date(2022, 5, 16),
#  datetime.date(2015, 7, 30),
#  datetime.date(2020, 8, 27),
#  datetime.date(2021, 6, 21),
#  datetime.date(2016, 5, 25),
#  datetime.date(2021, 11, 18),
#  datetime.date(2022, 8, 23),
#  datetime.date(2018, 6, 19),
#  datetime.date(2018, 8, 30),
#  datetime.date(2022, 6, 8),
#  datetime.date(2020, 5, 15),
#  datetime.date(2022, 1, 4),
#  datetime.date(2024, 1, 12),
#  datetime.date(2022, 1, 12),
#  datetime.date(2021, 7, 30),
#  datetime.date(2019, 9, 30),
#  datetime.date(2021, 7, 15),
#  datetime.date(2016, 6, 29),
#  datetime.date(2021, 8, 6),
#  datetime.date(2017, 5, 23),
#  datetime.date(2019, 6, 13),
#  datetime.date(2018, 2, 27),
#  datetime.date(2023, 5, 25),
#  datetime.date(2021, 4, 28),
#  datetime.date(2020, 4, 21),
#  datetime.date(2015, 3, 2),
#  datetime.date(2023, 11, 16),
#  datetime.date(2016, 2, 5),
#  datetime.date(2022, 11, 3),
#  datetime.date(2016, 1, 11),
#  datetime.date(2018, 12, 31),
#  datetime.date(2016, 10, 25),
#  datetime.date(2023, 11, 1),
#  datetime.date(2023, 6, 6),
#  datetime.date(2015, 6, 9),
#  datetime.date(2019, 2, 12),
#  datetime.date(2023, 12, 15),
#  datetime.date(2023, 8, 1),
#  datetime.date(2019, 2, 20),
#  datetime.date(2017, 12, 14),
#  datetime.date(2017, 2, 28),
#  datetime.date(2022, 1, 3),
#  datetime.date(2017, 3, 27),
#  datetime.date(2015, 6, 12),
#  datetime.date(2020, 4, 23),
#  datetime.date(2019, 9, 10),
#  datetime.date(2016, 8, 10),
#  datetime.date(2019, 2, 7),
#  datetime.date(2024, 4, 29),
#  datetime.date(2022, 3, 31),
#  datetime.date(2018, 2, 22),
#  datetime.date(2018, 10, 18),
#  datetime.date(2018, 1, 8),
#  datetime.date(2016, 11, 4),
#  datetime.date(2024, 4, 10),
#  datetime.date(2020, 8, 7),
#  datetime.date(2022, 4, 5),
#  datetime.date(2018, 3, 8),
#  datetime.date(2017, 11, 21),
#  datetime.date(2022, 12, 5),
#  datetime.date(2020, 1, 3),
#  datetime.date(2017, 9, 5),
#  datetime.date(2024, 4, 8),
#  datetime.date(2019, 1, 29),
#  datetime.date(2023, 11, 22),
#  datetime.date(2018, 11, 29),
#  datetime.date(2015, 9, 16),
#  datetime.date(2021, 1, 7),
#  datetime.date(2016, 7, 19),
#  datetime.date(2020, 4, 27),
#  datetime.date(2017, 11, 29),
#  datetime.date(2023, 9, 29),
#  datetime.date(2016, 10, 30),
#  datetime.date(2019, 9, 27),
#  datetime.date(2024, 2, 15),
#  datetime.date(2017, 3, 24),
#  datetime.date(2015, 7, 10),
#  datetime.date(2020, 6, 19),
#  datetime.date(2022, 3, 11),
#  datetime.date(2022, 8, 19),
#  datetime.date(2017, 1, 17),
#  datetime.date(2021, 2, 15),
#  datetime.date(2022, 1, 7),
#  datetime.date(2015, 7, 31),
#  datetime.date(2021, 5, 31),
#  datetime.date(2022, 3, 17),
#  datetime.date(2018, 10, 8),
#  datetime.date(2018, 6, 8),
#  datetime.date(2021, 7, 23),
#  datetime.date(2017, 10, 27),
#  datetime.date(2019, 11, 6),
#  datetime.date(2017, 12, 6),
#  datetime.date(2015, 10, 23),
#  datetime.date(2022, 9, 21),
#  datetime.date(2015, 5, 4),
#  datetime.date(2023, 12, 29),
#  datetime.date(2018, 9, 20),
#  datetime.date(2022, 4, 27),
#  datetime.date(2016, 8, 26),
#  datetime.date(2018, 6, 13),
#  datetime.date(2018, 7, 10),
#  datetime.date(2019, 5, 15),
#  datetime.date(2021, 6, 4),
#  datetime.date(2018, 8, 7),
#  datetime.date(2024, 10, 4),
#  datetime.date(2018, 7, 17),
#  datetime.date(2018, 9, 18),
#  datetime.date(2021, 9, 27),
#  datetime.date(2023, 7, 24),
#  datetime.date(2015, 11, 25),
#  datetime.date(2020, 3, 31),
#  datetime.date(2019, 5, 9),
#  datetime.date(2024, 5, 28),
#  datetime.date(2018, 10, 16),
#  datetime.date(2021, 3, 18),
#  datetime.date(2022, 10, 24),
#  datetime.date(2024, 9, 27),
#  datetime.date(2015, 7, 16),
#  datetime.date(2021, 6, 9),
#  datetime.date(2016, 6, 10),
#  datetime.date(2024, 9, 6),
#  datetime.date(2016, 9, 27),
#  datetime.date(2021, 2, 16),
#  datetime.date(2021, 4, 19),
#  datetime.date(2016, 4, 8),
#  datetime.date(2019, 2, 14),
#  datetime.date(2020, 7, 15),
#  datetime.date(2015, 12, 17),
#  datetime.date(2015, 12, 28),
#  datetime.date(2018, 11, 21),
#  datetime.date(2022, 7, 11),
#  datetime.date(2023, 7, 28),
#  datetime.date(2021, 11, 24),
#  datetime.date(2018, 8, 20),
#  datetime.date(2020, 5, 6),
#  datetime.date(2024, 7, 15),
#  datetime.date(2022, 1, 31),
#  datetime.date(2017, 2, 9),
#  datetime.date(2021, 9, 20),
#  datetime.date(2017, 7, 13),
#  datetime.date(2016, 12, 19),
#  datetime.date(2019, 8, 14),
#  datetime.date(2015, 7, 14),
#  datetime.date(2024, 3, 18),
#  datetime.date(2024, 8, 20),
#  datetime.date(2022, 11, 14),
#  datetime.date(2020, 1, 1),
#  datetime.date(2016, 12, 26),
#  datetime.date(2015, 10, 12),
#  datetime.date(2020, 11, 2),
#  datetime.date(2021, 5, 19),
#  datetime.date(2019, 3, 19),
#  datetime.date(2022, 6, 28),
#  datetime.date(2016, 5, 16),
#  datetime.date(2022, 10, 6),
#  datetime.date(2023, 4, 24),
#  datetime.date(2023, 4, 21),
#  datetime.date(2015, 12, 29),
#  datetime.date(2016, 5, 31),
#  datetime.date(2019, 1, 4),
#  datetime.date(2023, 1, 2),
#  datetime.date(2015, 12, 21),
#  datetime.date(2018, 9, 19),
#  datetime.date(2021, 9, 3),
#  datetime.date(2024, 6, 26),
#  datetime.date(2022, 9, 16),
#  datetime.date(2024, 2, 19),
#  datetime.date(2018, 5, 10),
#  datetime.date(2021, 7, 14),
#  datetime.date(2016, 5, 11),
#  datetime.date(2017, 1, 2),
#  datetime.date(2024, 7, 8),
#  datetime.date(2019, 11, 1),
#  datetime.date(2016, 10, 18),
#  datetime.date(2021, 7, 13),
#  datetime.date(2017, 2, 1),
#  datetime.date(2019, 10, 25),
#  datetime.date(2022, 4, 22),
#  datetime.date(2024, 2, 27),
#  datetime.date(2019, 3, 12),
#  datetime.date(2024, 3, 28),
#  datetime.date(2016, 6, 24),
#  datetime.date(2021, 12, 16),
#  datetime.date(2017, 9, 25),
#  datetime.date(2016, 10, 4),
#  datetime.date(2018, 5, 23),
#  datetime.date(2019, 12, 4),
#  datetime.date(2019, 12, 5),
#  datetime.date(2023, 8, 4),
#  datetime.date(2023, 12, 13),
#  datetime.date(2024, 1, 23),
#  datetime.date(2015, 12, 2),
#  datetime.date(2023, 1, 20),
#  datetime.date(2015, 6, 15),
#  datetime.date(2022, 8, 3),
#  datetime.date(2016, 3, 8),
#  datetime.date(2016, 7, 4),
#  datetime.date(2024, 1, 19),
#  datetime.date(2018, 7, 12),
#  datetime.date(2020, 8, 17),
#  datetime.date(2017, 7, 17),
#  datetime.date(2022, 4, 20),
#  datetime.date(2015, 10, 22),
#  datetime.date(2016, 2, 26),
#  datetime.date(2017, 3, 21),
#  datetime.date(2024, 3, 14),
#  datetime.date(2023, 6, 21),
#  datetime.date(2015, 11, 27),
#  datetime.date(2015, 6, 11),
#  datetime.date(2018, 8, 14),
#  datetime.date(2024, 4, 12),
#  datetime.date(2020, 3, 16),
#  datetime.date(2016, 1, 1),
#  datetime.date(2023, 1, 25),
#  datetime.date(2020, 5, 19),
#  datetime.date(2022, 3, 24),
#  datetime.date(2015, 11, 16),
#  datetime.date(2020, 3, 12),
#  datetime.date(2021, 10, 22),
#  datetime.date(2022, 7, 26),
#  datetime.date(2017, 11, 30),
#  datetime.date(2019, 7, 8),
#  datetime.date(2022, 12, 26),
#  datetime.date(2020, 2, 5),
#  datetime.date(2017, 8, 23),
#  datetime.date(2018, 9, 13),
#  datetime.date(2018, 4, 2),
#  datetime.date(2016, 5, 3),
#  datetime.date(2020, 7, 27),
#  datetime.date(2020, 11, 14),
#  datetime.date(2022, 3, 16),
#  datetime.date(2024, 10, 21),
#  datetime.date(2021, 2, 26),
#  datetime.date(2020, 7, 21),
#  datetime.date(2021, 4, 9),
#  datetime.date(2015, 6, 3),
#  datetime.date(2020, 3, 9),
#  datetime.date(2021, 5, 25),
#  datetime.date(2024, 7, 4),
#  datetime.date(2024, 10, 14),
#  datetime.date(2019, 10, 8),
#  datetime.date(2021, 11, 16),
#  datetime.date(2021, 9, 24),
#  datetime.date(2022, 1, 17),
#  datetime.date(2017, 10, 20),
#  datetime.date(2020, 7, 16),
#  datetime.date(2020, 9, 11),
#  datetime.date(2023, 11, 2),
#  datetime.date(2017, 7, 11),
#  datetime.date(2017, 8, 16),
#  datetime.date(2016, 3, 1),
#  datetime.date(2021, 11, 15),
#  datetime.date(2017, 7, 4),
#  datetime.date(2016, 12, 15),
#  datetime.date(2016, 12, 13),
#  datetime.date(2016, 11, 29),
#  datetime.date(2022, 8, 10),
#  datetime.date(2017, 5, 4),
#  datetime.date(2019, 11, 22),
#  datetime.date(2021, 1, 27),
#  datetime.date(2017, 9, 7),
#  datetime.date(2021, 2, 8),
#  datetime.date(2018, 12, 24),
#  datetime.date(2019, 5, 10),
#  datetime.date(2020, 5, 12),
#  datetime.date(2017, 4, 4),
#  datetime.date(2024, 5, 7),
#  datetime.date(2021, 5, 7),
#  datetime.date(2023, 9, 19),
#  datetime.date(2020, 1, 28),
#  datetime.date(2022, 8, 5),
#  datetime.date(2020, 6, 29),
#  datetime.date(2024, 4, 22),
#  datetime.date(2023, 7, 13),
#  datetime.date(2019, 7, 24),
#  datetime.date(2022, 11, 7),
#  datetime.date(2016, 12, 20),
#  datetime.date(2016, 2, 15),
#  datetime.date(2017, 12, 11),
#  datetime.date(2022, 10, 17),
#  datetime.date(2023, 10, 10),
#  datetime.date(2016, 2, 9),
#  datetime.date(2023, 4, 17),
#  datetime.date(2017, 10, 3),
#  datetime.date(2021, 12, 20),
#  datetime.date(2024, 8, 8),
#  datetime.date(2020, 6, 15),
#  datetime.date(2023, 7, 11),
#  datetime.date(2021, 1, 12),
#  datetime.date(2020, 9, 9),
#  datetime.date(2020, 6, 10),
#  datetime.date(2015, 6, 16),
#  datetime.date(2017, 7, 19),
#  datetime.date(2018, 11, 12),
#  datetime.date(2015, 8, 31),
#  datetime.date(2023, 9, 18),
#  datetime.date(2019, 1, 31),
#  datetime.date(2024, 5, 1),
#  datetime.date(2024, 9, 2),
#  datetime.date(2018, 3, 26),
#  datetime.date(2018, 9, 6),
#  datetime.date(2019, 10, 4),
#  datetime.date(2020, 9, 2),
#  datetime.date(2015, 12, 22),
#  datetime.date(2021, 9, 7),
#  datetime.date(2019, 2, 13),
#  datetime.date(2023, 3, 15),
#  datetime.date(2018, 3, 14),
#  datetime.date(2021, 9, 23),
#  datetime.date(2024, 6, 28),
#  datetime.date(2017, 6, 22),
#  datetime.date(2023, 8, 31),
#  datetime.date(2017, 3, 6),
#  datetime.date(2023, 9, 22),
#  datetime.date(2020, 2, 17),
#  datetime.date(2018, 7, 23),
#  datetime.date(2021, 2, 22),
#  datetime.date(2023, 7, 5),
#  datetime.date(2022, 8, 17),
#  datetime.date(2020, 6, 30),
#  datetime.date(2015, 7, 9),
#  datetime.date(2019, 8, 28),
#  datetime.date(2019, 9, 24),
#  datetime.date(2023, 9, 5),
#  datetime.date(2016, 6, 15),
#  datetime.date(2016, 10, 10),
#  datetime.date(2023, 7, 17),
#  datetime.date(2023, 9, 21),
#  datetime.date(2016, 11, 16),
#  datetime.date(2015, 10, 8),
#  datetime.date(2022, 12, 1),
#  datetime.date(2020, 11, 30),
#  datetime.date(2024, 3, 11),
#  datetime.date(2017, 12, 12),
#  datetime.date(2018, 3, 20),
#  datetime.date(2017, 5, 9),
#  datetime.date(2018, 3, 7),
#  datetime.date(2017, 7, 6),
#  datetime.date(2015, 10, 16),
#  datetime.date(2022, 4, 19),
#  datetime.date(2016, 2, 17),
#  datetime.date(2015, 7, 17),
#  datetime.date(2020, 8, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 6, 1),
#  datetime.date(2021, 5, 24),
#  datetime.date(2015, 4, 8),
#  datetime.date(2023, 4, 19),
#  datetime.date(2017, 7, 31),
#  datetime.date(2019, 4, 12),
#  datetime.date(2022, 12, 23),
#  datetime.date(2015, 3, 12),
#  datetime.date(2023, 1, 12),
#  datetime.date(2015, 7, 7),
#  datetime.date(2016, 3, 15),
#  datetime.date(2018, 12, 5),
#  datetime.date(2017, 3, 30),
#  datetime.date(2019, 11, 8),
#  datetime.date(2023, 7, 14),
#  datetime.date(2018, 12, 3),
#  datetime.date(2018, 5, 22),
#  datetime.date(2016, 4, 13),
#  datetime.date(2024, 7, 25),
#  datetime.date(2015, 3, 5),
#  datetime.date(2024, 9, 5),
#  datetime.date(2023, 1, 23),
#  datetime.date(2017, 11, 23),
#  datetime.date(2023, 9, 15),
#  datetime.date(2023, 5, 22),
#  datetime.date(2023, 11, 20),
#  datetime.date(2016, 4, 12),
#  datetime.date(2022, 1, 21),
#  datetime.date(2024, 8, 21),
#  datetime.date(2018, 1, 30),
#  datetime.date(2021, 9, 15),
#  datetime.date(2021, 4, 13),
#  datetime.date(2021, 6, 3),
#  datetime.date(2015, 9, 14),
#  datetime.date(2018, 8, 29),
#  datetime.date(2023, 12, 28),
#  datetime.date(2022, 3, 18),
#  datetime.date(2023, 6, 15),
#  datetime.date(2017, 4, 12),
#  datetime.date(2021, 3, 26),
#  datetime.date(2018, 12, 10),
#  datetime.date(2019, 3, 21),
#  datetime.date(2020, 11, 16),
#  datetime.date(2019, 4, 9),
#  datetime.date(2021, 3, 19),
#  datetime.date(2024, 10, 3),
#  datetime.date(2019, 3, 27),
#  datetime.date(2021, 8, 3),
#  datetime.date(2021, 6, 16),
#  datetime.date(2021, 6, 23),
#  datetime.date(2023, 1, 9),
#  datetime.date(2016, 6, 14),
#  datetime.date(2018, 9, 7),
#  datetime.date(2018, 11, 1),
#  datetime.date(2022, 6, 7),
#  datetime.date(2019, 2, 6),
#  datetime.date(2022, 7, 6),
#  datetime.date(2021, 8, 2),
#  datetime.date(2024, 1, 4),
#  datetime.date(2023, 2, 8),
#  datetime.date(2017, 1, 24),
#  datetime.date(2016, 3, 21),
#  datetime.date(2018, 11, 14),
#  datetime.date(2019, 1, 16),
#  datetime.date(2016, 11, 8),
#  datetime.date(2018, 9, 27),
#  datetime.date(2021, 7, 26),
#  datetime.date(2023, 8, 18),
#  datetime.date(2024, 5, 10),
#  datetime.date(2017, 5, 30),
#  datetime.date(2020, 10, 7),
#  datetime.date(2023, 3, 7),
#  datetime.date(2020, 5, 26),
#  datetime.date(2016, 12, 30),
#  datetime.date(2017, 8, 1),
#  datetime.date(2016, 6, 20),
#  datetime.date(2019, 9, 25),
#  datetime.date(2023, 2, 22),
#  datetime.date(2017, 6, 14),
#  datetime.date(2018, 6, 18),
#  datetime.date(2017, 6, 8),
#  datetime.date(2016, 6, 6),
#  datetime.date(2017, 1, 10),
#  datetime.date(2022, 4, 4),
#  datetime.date(2015, 3, 10),
#  datetime.date(2020, 10, 27),
#  datetime.date(2022, 9, 7),
#  datetime.date(2021, 1, 14),
#  datetime.date(2023, 10, 26),
#  datetime.date(2021, 2, 24),
#  datetime.date(2023, 10, 27),
#  datetime.date(2019, 5, 27),
#  datetime.date(2021, 6, 11),
#  datetime.date(2018, 4, 18),
#  datetime.date(2015, 5, 25),
#  datetime.date(2019, 12, 18),
#  datetime.date(2024, 6, 24),
#  datetime.date(2017, 9, 29),
#  datetime.date(2024, 3, 22),
#  datetime.date(2021, 1, 19),
#  datetime.date(2019, 2, 4),
#  datetime.date(2015, 5, 6),
#  datetime.date(2019, 5, 14),
#  datetime.date(2024, 8, 2),
#  datetime.date(2024, 10, 7),
#  datetime.date(2018, 7, 9),
#  datetime.date(2018, 10, 15),
#  datetime.date(2019, 11, 12),
#  datetime.date(2015, 9, 3),
#  datetime.date(2015, 12, 15),
#  datetime.date(2018, 3, 29),
#  datetime.date(2018, 10, 12),
#  datetime.date(2018, 2, 26),
#  datetime.date(2020, 6, 26),
#  datetime.date(2020, 10, 6),
#  datetime.date(2020, 12, 4),
#  datetime.date(2023, 3, 6),
#  datetime.date(2016, 7, 8),
#  datetime.date(2019, 12, 20),
#  datetime.date(2021, 3, 8),
#  datetime.date(2016, 2, 2),
#  datetime.date(2016, 7, 29),
#  datetime.date(2019, 4, 1),
#  datetime.date(2016, 6, 8),
#  datetime.date(2023, 12, 21),
#  datetime.date(2016, 4, 25),
#  datetime.date(2017, 6, 2),
#  datetime.date(2023, 3, 16),
#  datetime.date(2016, 1, 22),
#  datetime.date(2017, 8, 24),
#  datetime.date(2024, 4, 16),
#  datetime.date(2021, 8, 16),
#  datetime.date(2018, 3, 16),
#  datetime.date(2017, 11, 6),
#  datetime.date(2018, 8, 24),
#  datetime.date(2022, 5, 20),
#  datetime.date(2016, 1, 21),
#  datetime.date(2018, 11, 16),
#  datetime.date(2019, 5, 2),
#  datetime.date(2018, 7, 19),
#  datetime.date(2022, 6, 2),
#  datetime.date(2024, 7, 29),
#  datetime.date(2017, 7, 12),
#  datetime.date(2020, 7, 30),
#  datetime.date(2020, 7, 24),
#  datetime.date(2018, 8, 1),
#  datetime.date(2017, 4, 3),
#  datetime.date(2015, 7, 22),
#  datetime.date(2023, 3, 30),
#  datetime.date(2022, 9, 9),
#  datetime.date(2015, 3, 27),
#  datetime.date(2017, 9, 22),
#  datetime.date(2020, 6, 12),
#  datetime.date(2023, 8, 8),
#  datetime.date(2016, 5, 12),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 1, 13),
#  datetime.date(2017, 3, 9),
#  datetime.date(2018, 8, 23),
#  datetime.date(2022, 5, 17),
#  datetime.date(2021, 2, 2),
#  datetime.date(2015, 8, 27),
#  datetime.date(2016, 10, 5),
#  datetime.date(2019, 6, 18),
#  datetime.date(2023, 6, 13),
#  datetime.date(2015, 7, 28),
#  datetime.date(2019, 8, 16),
#  datetime.date(2021, 5, 3),
#  datetime.date(2015, 9, 7),
#  datetime.date(2024, 4, 3),
#  datetime.date(2024, 7, 2),
#  datetime.date(2015, 8, 18),
#  datetime.date(2020, 3, 6),
#  datetime.date(2023, 1, 27),
#  datetime.date(2016, 3, 29),
#  datetime.date(2018, 7, 27),
#  datetime.date(2021, 1, 22),
#  datetime.date(2021, 11, 29),
#  datetime.date(2016, 8, 22),
#  datetime.date(2023, 2, 20),
#  datetime.date(2021, 12, 31),
#  datetime.date(2017, 8, 17),
#  datetime.date(2018, 6, 1),
#  datetime.date(2024, 5, 15),
#  datetime.date(2017, 10, 16),
#  datetime.date(2022, 12, 19),
#  datetime.date(2018, 4, 24),
#  datetime.date(2018, 5, 3),
#  datetime.date(2024, 6, 25),
#  datetime.date(2023, 2, 23),
#  datetime.date(2016, 2, 29),
#  datetime.date(2024, 7, 24),
#  datetime.date(2017, 4, 13),
#  datetime.date(2015, 3, 16),
#  datetime.date(2019, 3, 13),
#  datetime.date(2021, 9, 30),
#  datetime.date(2020, 4, 7),
#  datetime.date(2018, 11, 9),
#  datetime.date(2021, 2, 11),
#  datetime.date(2021, 12, 8),
#  datetime.date(2017, 3, 1),
#  datetime.date(2016, 1, 15),
#  datetime.date(2022, 8, 18),
#  datetime.date(2020, 7, 2),
#  datetime.date(2019, 3, 7),
#  datetime.date(2018, 1, 11),
#  datetime.date(2022, 9, 29),
#  datetime.date(2015, 3, 30),
#  datetime.date(2017, 10, 19),
#  datetime.date(2021, 6, 22),
#  datetime.date(2017, 4, 19),
#  datetime.date(2022, 3, 9),
#  datetime.date(2015, 11, 3),
#  datetime.date(2017, 10, 24),
#  datetime.date(2023, 3, 9),
#  datetime.date(2021, 11, 26),
#  datetime.date(2016, 2, 3),
#  datetime.date(2016, 7, 6),
#  datetime.date(2017, 9, 27),
#  datetime.date(2020, 6, 17),
#  datetime.date(2015, 6, 30),
#  datetime.date(2023, 4, 26),
#  datetime.date(2019, 6, 14),
#  datetime.date(2019, 1, 24),
#  datetime.date(2020, 7, 9),
#  datetime.date(2022, 1, 6),
#  datetime.date(2023, 3, 31),
#  datetime.date(2023, 4, 13),
#  datetime.date(2019, 11, 27),
#  datetime.date(2024, 9, 18),
#  datetime.date(2019, 9, 9),
#  datetime.date(2015, 4, 10),
#  datetime.date(2021, 6, 15),
#  datetime.date(2024, 9, 10),
#  datetime.date(2020, 10, 21),
#  datetime.date(2023, 2, 15),
#  datetime.date(2022, 7, 5),
#  datetime.date(2021, 10, 6),
#  datetime.date(2018, 4, 17),
#  datetime.date(2019, 3, 15),
#  datetime.date(2022, 5, 19),
#  datetime.date(2015, 4, 21),
#  datetime.date(2020, 6, 5),
#  datetime.date(2017, 2, 23),
#  datetime.date(2022, 2, 8),
#  datetime.date(2015, 6, 25),
#  datetime.date(2022, 7, 28),
#  datetime.date(2022, 9, 13),
#  datetime.date(2017, 9, 18),
#  datetime.date(2015, 9, 28),
#  datetime.date(2021, 3, 11),
#  datetime.date(2023, 11, 17),
#  datetime.date(2024, 2, 22),
#  datetime.date(2017, 9, 4),
#  datetime.date(2022, 3, 14),
#  datetime.date(2018, 11, 23),
#  datetime.date(2024, 6, 10),
#  datetime.date(2017, 3, 15),
#  datetime.date(2021, 4, 26),
#  datetime.date(2017, 10, 12),
#  datetime.date(2023, 1, 24),
#  datetime.date(2024, 7, 16),
#  datetime.date(2016, 10, 20),
#  datetime.date(2018, 10, 10),
#  datetime.date(2015, 9, 8),
#  datetime.date(2020, 12, 28),
#  datetime.date(2015, 7, 13),
#  datetime.date(2021, 10, 27),
#  datetime.date(2023, 9, 27),
#  datetime.date(2015, 5, 8),
#  datetime.date(2019, 6, 10),
#  datetime.date(2023, 2, 21),
#  datetime.date(2016, 3, 23),
#  datetime.date(2021, 10, 26),
#  datetime.date(2016, 10, 31),
#  datetime.date(2023, 10, 11),
#  datetime.date(2022, 10, 11),
#  datetime.date(2022, 9, 8),
#  datetime.date(2017, 9, 6),
#  datetime.date(2023, 7, 26),
#  datetime.date(2017, 8, 11),
#  datetime.date(2024, 3, 6),
#  datetime.date(2018, 4, 5),
#  datetime.date(2021, 11, 25),
#  datetime.date(2022, 3, 30),
#  datetime.date(2022, 12, 6),
#  datetime.date(2017, 11, 24),
#  datetime.date(2022, 6, 3),
#  datetime.date(2024, 1, 18),
#  datetime.date(2016, 2, 16),
#  datetime.date(2024, 4, 23),
#  datetime.date(2018, 9, 26),
#  datetime.date(2024, 3, 13),
#  datetime.date(2019, 11, 19),
#  datetime.date(2016, 7, 20),
#  datetime.date(2016, 11, 23),
#  datetime.date(2018, 12, 26),
#  datetime.date(2019, 5, 8),
#  datetime.date(2022, 3, 29),
#  datetime.date(2015, 3, 3),
#  datetime.date(2018, 1, 31),
#  datetime.date(2015, 9, 30),
#  datetime.date(2015, 11, 13),
#  datetime.date(2015, 10, 1),
#  datetime.date(2015, 5, 5),
#  datetime.date(2020, 3, 17),
#  datetime.date(2024, 8, 29),
#  datetime.date(2017, 12, 21),
#  datetime.date(2022, 6, 14),
#  datetime.date(2024, 5, 22),
#  datetime.date(2017, 6, 19),
#  datetime.date(2017, 12, 20),
#  datetime.date(2020, 4, 15),
#  datetime.date(2022, 2, 1),
#  datetime.date(2018, 7, 24),
#  datetime.date(2016, 1, 7),
#  datetime.date(2018, 8, 9),
#  datetime.date(2016, 7, 26),
#  datetime.date(2016, 1, 8),
#  datetime.date(2019, 7, 15),
#  datetime.date(2017, 11, 8),
#  datetime.date(2016, 3, 16),
#  datetime.date(2015, 9, 21),
#  datetime.date(2015, 4, 9),
#  datetime.date(2019, 3, 22),
#  datetime.date(2015, 6, 5),
#  datetime.date(2017, 6, 29),
#  datetime.date(2018, 2, 16),
#  datetime.date(2018, 9, 3),
#  datetime.date(2020, 11, 9),
#  datetime.date(2018, 8, 21),
#  datetime.date(2019, 10, 18),
#  datetime.date(2018, 2, 20),
#  datetime.date(2019, 8, 1),
#  datetime.date(2021, 6, 14),
#  datetime.date(2015, 5, 20),
#  datetime.date(2017, 2, 3),
#  datetime.date(2021, 10, 1),
#  datetime.date(2018, 8, 28),
#  datetime.date(2023, 3, 22),
#  datetime.date(2024, 3, 25),
#  datetime.date(2023, 3, 13),
#  datetime.date(2022, 6, 24),
#  datetime.date(2021, 12, 15),
#  datetime.date(2024, 7, 9),
#  datetime.date(2018, 11, 19),
#  datetime.date(2016, 6, 13),
#  datetime.date(2023, 6, 5),
#  datetime.date(2022, 4, 11),
#  datetime.date(2018, 6, 15),
#  datetime.date(2018, 6, 6),
#  datetime.date(2016, 9, 7),
#  datetime.date(2021, 6, 25),
#  datetime.date(2022, 11, 8),
#  datetime.date(2023, 11, 14),
#  datetime.date(2019, 4, 4),
#  datetime.date(2023, 6, 27),
#  datetime.date(2024, 5, 8),
#  datetime.date(2017, 11, 2),
#  datetime.date(2019, 7, 26),
#  datetime.date(2020, 11, 11),
#  datetime.date(2015, 12, 8),
#  datetime.date(2022, 2, 28),
#  datetime.date(2016, 10, 7),
#  datetime.date(2021, 5, 17),
#  datetime.date(2016, 2, 23),
#  datetime.date(2021, 8, 30),
#  datetime.date(2022, 12, 28),
#  datetime.date(2022, 7, 18),
#  datetime.date(2017, 5, 26),
#  datetime.date(2020, 10, 15),
#  datetime.date(2021, 2, 10),
#  datetime.date(2019, 1, 25),
#  datetime.date(2020, 11, 17),
#  datetime.date(2021, 8, 18),
#  datetime.date(2024, 1, 24),
#  datetime.date(2019, 1, 22),
#  datetime.date(2015, 4, 15),
#  datetime.date(2018, 3, 13),
#  datetime.date(2022, 5, 12),
#  datetime.date(2022, 12, 15),
#  datetime.date(2023, 1, 10),
#  datetime.date(2019, 2, 25),
#  datetime.date(2020, 1, 15),
#  datetime.date(2024, 2, 8),
#  datetime.date(2018, 2, 2),
#  datetime.date(2022, 8, 29),
#  datetime.date(2022, 9, 2),
#  datetime.date(2020, 8, 3),
#  datetime.date(2015, 3, 25),
#  datetime.date(2021, 4, 22),
#  datetime.date(2017, 5, 25),
#  datetime.date(2021, 7, 2),
#  datetime.date(2021, 8, 11),
#  datetime.date(2020, 1, 10),
#  datetime.date(2016, 11, 28),
#  datetime.date(2018, 5, 4),
#  datetime.date(2017, 12, 26),
#  datetime.date(2021, 5, 5),
#  datetime.date(2019, 5, 22),
#  datetime.date(2021, 12, 24),
#  datetime.date(2022, 12, 12),
#  datetime.date(2021, 3, 3),
#  datetime.date(2019, 10, 10),
#  datetime.date(2019, 12, 27),
#  datetime.date(2015, 7, 3),
#  datetime.date(2022, 5, 23),
#  datetime.date(2019, 10, 15),
#  datetime.date(2024, 4, 17),
#  datetime.date(2018, 5, 1),
#  datetime.date(2021, 3, 1),
#  datetime.date(2017, 10, 23),
#  datetime.date(2019, 8, 19),
#  datetime.date(2021, 10, 20),
#  datetime.date(2018, 9, 25),
#  datetime.date(2019, 6, 20),
#  datetime.date(2018, 10, 31),
#  datetime.date(2019, 8, 8),
#  datetime.date(2020, 7, 10),
#  datetime.date(2022, 2, 21),
#  datetime.date(2017, 2, 10),
#  datetime.date(2017, 7, 27),
#  datetime.date(2023, 7, 6),
#  datetime.date(2021, 1, 15),
#  datetime.date(2023, 10, 19),
#  datetime.date(2022, 9, 1),
#  datetime.date(2020, 5, 13),
#  datetime.date(2022, 9, 23),
#  datetime.date(2016, 7, 21),
#  datetime.date(2022, 5, 11),
#  datetime.date(2023, 11, 13),
#  datetime.date(2017, 12, 13),
#  datetime.date(2018, 12, 20),
#  datetime.date(2021, 2, 1),
#  datetime.date(2024, 4, 19),
#  datetime.date(2024, 9, 13),
#  datetime.date(2016, 4, 15),
#  datetime.date(2024, 2, 23),
#  datetime.date(2022, 11, 25),
#  datetime.date(2022, 11, 21),
#  datetime.date(2018, 8, 6),
#  datetime.date(2024, 4, 15),
#  datetime.date(2015, 7, 15),
#  datetime.date(2021, 4, 23),
#  datetime.date(2020, 10, 19),
#  datetime.date(2021, 3, 30),
#  datetime.date(2017, 10, 25),
#  datetime.date(2020, 2, 27),
#  datetime.date(2015, 11, 5),
#  datetime.date(2019, 7, 4),
#  datetime.date(2019, 4, 30),
#  datetime.date(2018, 11, 20),
#  datetime.date(2019, 6, 12),
#  datetime.date(2023, 5, 10),
#  datetime.date(2017, 2, 2),
#  datetime.date(2019, 11, 28),
#  datetime.date(2018, 2, 8),
#  datetime.date(2019, 8, 12),
#  datetime.date(2018, 2, 9),
#  datetime.date(2015, 8, 17),
#  datetime.date(2016, 7, 25),
#  datetime.date(2020, 12, 14),
#  datetime.date(2022, 3, 4),
#  datetime.date(2019, 8, 7),
#  datetime.date(2017, 11, 17),
#  datetime.date(2017, 11, 27),
#  datetime.date(2024, 4, 5),
#  datetime.date(2023, 8, 25),
#  datetime.date(2023, 10, 4),
#  datetime.date(2020, 9, 15),
#  datetime.date(2022, 5, 18),
#  datetime.date(2020, 10, 12),
#  datetime.date(2021, 4, 6),
#  datetime.date(2023, 5, 17),
#  datetime.date(2021, 7, 29),
#  datetime.date(2015, 4, 1),
#  datetime.date(2021, 8, 13),
#  datetime.date(2018, 9, 21),
#  datetime.date(2019, 8, 27),
#  datetime.date(2019, 11, 29),
#  datetime.date(2021, 10, 11),
#  datetime.date(2020, 12, 2),
#  datetime.date(2022, 7, 29),
#  datetime.date(2016, 12, 16),
#  datetime.date(2020, 5, 20),
#  datetime.date(2015, 5, 13),
#  datetime.date(2020, 8, 28),
#  datetime.date(2019, 12, 31),
#  datetime.date(2023, 6, 14),
#  datetime.date(2022, 3, 1),
#  datetime.date(2024, 10, 8),
#  datetime.date(2022, 2, 22),
#  datetime.date(2021, 5, 12),
#  datetime.date(2022, 7, 19),
#  datetime.date(2024, 10, 17),
#  datetime.date(2023, 4, 4),
#  datetime.date(2024, 4, 1),
#  datetime.date(2015, 11, 2),
#  datetime.date(2017, 3, 8),
#  datetime.date(2016, 11, 9),
#  datetime.date(2023, 7, 7),
#  datetime.date(2015, 9, 25),
#  datetime.date(2021, 7, 22),
#  datetime.date(2024, 6, 12),
#  datetime.date(2017, 8, 22),
#  ...}

# %%
def rename_ohlc_columns(df: pl.DataFrame) -> pl.DataFrame:

    column_mapping = {"o": "open", "h": "high", "l": "low", "c": "close", "v": "volume"}
    df = df.rename(column_mapping)

    return df

# %%
async def create_sell_signals(df):

    df["sell_signal"] = False

    df["sell_signal"] = (df["high"] < df["high"].shift(1)) & (
        df["high"].shift(2) < df["high"].shift(1)
    )

    return df

async def create_buy_signals(df):
    df["buy_signal"] = False

    df["buy_signal"] = (df["low"] > df["low"].shift(1)) & (
        df["low"].shift(2) > df["low"].shift(1)
    )

    return df

async def create_ma(df, period):
    df["close"] = pd.to_numeric(df["close"], errors="coerce")
    df["ma"] = df["close"].rolling(window=period).mean()
    return df

# %%
PORTFOLIO_VALUE = 10_00_000 # 10 Lacs
RPT_PCT = 0.01 # 1% RPT
SLIPPAGE_ = 0.001
LEVERAGE_ = 5

# %%
def positional(df, sl_pct, target_pct):
    trades = []
    in_trade_long = False
    in_trade_short = False
    current_trade = None
    king_candle = None
    queen_candle = None
    slippage_pct = SLIPPAGE_
    portfolio = 10000000
    index_lev = 6
    entry_time = None
    exit_time = None
    is_trailing_active_long = False
    is_trailing_active_short = False
    points_long = None
    points_short = None
    initial_sl_long = 100000
    initial_sl_short = 0

    df['100ma'] = df['close'].rolling(100).mean()

    for i in range(2, len(df)):
        prev2_candle = df.iloc[i-2]
        prev_candle = df.iloc[i-1]
        current_candle = df.iloc[i]

        # Check for King candle formation when not in a trade
        if not in_trade_long and current_candle['high'] < prev_candle['high'] and prev2_candle['high'] < prev_candle['high'] and prev_candle['high'] < prev_candle['100ma']:
            king_candle = prev_candle
            signal_time_long = king_candle['datetime']
            initial_sl_long = min(current_candle['low'], prev_candle['low'], prev2_candle['low'])

        # Check for King breakout (Long position)
        if king_candle is not None and not in_trade_long and current_candle['high'] > king_candle['high']:
            # if (current_candle['open'] > king_candle['high'] and current_candle['low'] <= king_candle['high']) or (current_candle['open'] <= king_candle['high']):
            #     entry_price_long = king_candle['high']
            #     stop_loss_long = entry_price_long * (1 - sl_pct)
            #     # stop_loss_long = initial_sl_long
            #     target_long = entry_price_long * (1 + target_pct)
            #     entry_time_long = df.iloc[i]['datetime']
            #     in_trade_long = True
            #     # print(f"Taking Long Position: Entry={entry_price}, SL={stop_loss}, Target={target}")
            # else:
            #     entry_price_long = current_candle['close']
            #     stop_loss_long = entry_price_long * (1 - sl_pct)
            #     # stop_loss_long = initial_sl_long
            #     target_long = entry_price_long * (1 + target_pct)
            #     entry_time_long = df.iloc[i]['datetime']
            #     in_trade_long = True
            #     # print(f"Taking Long Position: Entry={entry_price}, SL={stop_loss}, Target={target}")
            if (current_candle['open'] > king_candle['high'] and current_candle['low'] <= king_candle['high']) or (current_candle['open'] <= king_candle['high']):
                entry_price_long = king_candle['high']
                # stop_loss_long = entry_price_long * (1 - sl_pct)
                stop_loss_long = initial_sl_long
                target_long = entry_price_long * (1 + target_pct)
                entry_time_long = df.iloc[i]['datetime']
                in_trade_long = True
            #     # print(f"Taking Long Position: Entry={entry_price}, SL={stop_loss}, Target={target}")
            elif current_candle['open'] > king_candle['high']:
                king_candle = None
                in_trade_long = False

        if in_trade_long:
            if not is_trailing_active_long:
                if current_candle['low'] > current_candle['ma']:
                    is_trailing_active_long = True
            if not is_trailing_active_long:
                if (current_candle['low'] <= stop_loss_long):
                    if current_candle['open'] < stop_loss_long:
                        if current_candle['datetime'] != entry_time_long:
                            exit_price_long = current_candle['open']
                            exit_time_long = df.iloc[i]['datetime']
                            points_long = exit_price_long - entry_price_long
                            remarks_long = 'Gap SL'
                    else:
                        exit_price_long = stop_loss_long
                        exit_time_long = df.iloc[i]['datetime']
                        points_long = exit_price_long - entry_price_long
                        remarks_long = 'Initial SL Hit'
                    
                elif (current_candle['high'] >= target_long):
                    exit_price_long = target_long
                    exit_time_long = df.iloc[i]['datetime']
                    points_long = exit_price_long - entry_price_long
                    remarks_long = 'Target Hit'
            else:
                if (current_candle['low'] <= stop_loss_long):
                    if current_candle['open'] < stop_loss_long:
                        if current_candle['datetime'] != entry_time_long:
                            exit_price_long = current_candle['open']
                            exit_time_long = df.iloc[i]['datetime']
                            points_long = exit_price_long - entry_price_long
                            remarks_long = 'Gap SL'
                    else:
                        exit_price_long = stop_loss_long
                        exit_time_long = df.iloc[i]['datetime']
                        points_long = exit_price_long - entry_price_long
                        remarks_long = 'Initial SL Hit'
                    
                elif (current_candle['high'] >= target_long):
                    exit_price_long = target_long
                    exit_time_long = df.iloc[i]['datetime']
                    points_long = exit_price_long - entry_price_long
                    remarks_long = 'Target Hit'

                elif (current_candle['close'] <= current_candle['ma']):
                    exit_price_long = current_candle['close']
                    exit_time_long = df.iloc[i]['datetime']
                    points_long = exit_price_long - entry_price_long
                    remarks_long = 'Trailing SL Hit'

            if points_long:
                slippages = SLIPPAGE_ * (entry_price_long + exit_price_long)
                # qty = portfolio * index_lev / entry_price_long
                qty = portfolio * RPT_PCT / abs(entry_price_long - initial_sl_long)
                current_trade = {
                    'Type': 'LONG',
                    'Signal Generated At': signal_time_long,
                    'Entry Time': entry_time_long,
                    'Entry Price': entry_price_long,
                    'Initial SL': stop_loss_long,
                    'Initial Target': target_long,
                    'Exit Time': exit_time_long,
                    'Exit Price': exit_price_long,
                    'Points': points_long,
                    'Slippages': slippages,
                    'Remarks': remarks_long,
                    'Qty': qty,
                    'PnL': points_long * qty,
                    'PnL w cs': (points_long - slippages) * qty,
                    'ROI%': points_long * qty * 100 / portfolio,
                    'ROI%': (points_long - slippages) * qty * 100 / portfolio,
                }
                trades.append(current_trade) 
                in_trade_long = False  
                king_candle = None  
                is_trailing_active_long = False
                points_long = None
                signal_time_long = None
                initial_sl_long = 100000

        # Check for Queen candle formation when not in a trade
        if not in_trade_short and current_candle['low'] > prev_candle['low'] and prev2_candle['low'] > prev_candle['low'] and prev_candle['low'] > prev_candle['100ma']:
            queen_candle = prev_candle
            signal_time_short = queen_candle['datetime']
            initial_sl_short = max(current_candle['high'], prev_candle['high'], prev2_candle['high'])
            
        # Check for Queen breakout (Short position)
        if queen_candle is not None and not in_trade_short and current_candle['low'] < queen_candle['low']:
            # if (current_candle['open'] < queen_candle['low'] and current_candle['high'] >= queen_candle['low']) or (current_candle['open'] >= queen_candle['low']):
            #     entry_price_short = queen_candle['low']
            #     stop_loss_short = entry_price_short * (1 + sl_pct)
            #     # stop_loss_short = initial_sl_short
            #     target_short = entry_price_short * (1 - target_pct)
            #     entry_time_short = df.iloc[i]['datetime']
            #     in_trade_short = True
            # else:
            #     entry_price_short = current_candle['close']
            #     stop_loss_short = entry_price_short * (1 + sl_pct)
            #     # stop_loss_short = initial_sl_short
            #     target_short = entry_price_short * (1 - target_pct)
            #     entry_time_short = df.iloc[i]['datetime']
            #     in_trade_short = True
            if (current_candle['open'] < queen_candle['low'] and current_candle['high'] >= queen_candle['low']) or (current_candle['open'] >= queen_candle['low']):
                entry_price_short = queen_candle['low']
                # stop_loss_short = entry_price_short * (1 + sl_pct)
                stop_loss_short = initial_sl_short
                target_short = entry_price_short * (1 - target_pct)
                entry_time_short = df.iloc[i]['datetime']
                in_trade_short = True
            elif current_candle['open'] < queen_candle['low']:
                queen_candle = None
                in_trade_short = False
            
        if in_trade_short:
            if not is_trailing_active_short:
                if current_candle['high'] < current_candle['ma']:
                    is_trailing_active_short = True
            if not is_trailing_active_short:
                if (current_candle['high'] >= stop_loss_short):
                    if current_candle['open'] > stop_loss_short:
                        if current_candle['datetime'] != entry_time_short:
                            exit_price_short = current_candle['open']
                            exit_time_short = df.iloc[i]['datetime']
                            points_short = entry_price_short - exit_price_short
                            remarks_short = 'Gap SL'
                    else:
                        exit_price_short = stop_loss_short
                        exit_time_short = df.iloc[i]['datetime']
                        points_short = entry_price_short - exit_price_short
                        remarks_short = 'Initial SL Hit'
                    
                elif (current_candle['low'] <= target_short):
                    exit_price_short = target_short
                    exit_time_short = df.iloc[i]['datetime']
                    points_short = entry_price_short - exit_price_short
                    remarks_short = 'Target Hit'
            else:
                if (current_candle['high'] >= stop_loss_short):
                    if current_candle['open'] > stop_loss_short:
                        if current_candle['datetime'] != entry_time_short:
                            exit_price_short = current_candle['open']
                            exit_time_short = df.iloc[i]['datetime']
                            points_short = entry_price_short - exit_price_short
                            remarks_short = 'Gap SL'
                    else:
                        exit_price_short = stop_loss_short
                        exit_time_short = df.iloc[i]['datetime']
                        points_short = entry_price_short - exit_price_short
                        remarks_short = 'Initial SL Hit'
                    
                elif (current_candle['low'] <= target_short):
                    exit_price_short = target_short
                    exit_time_short = df.iloc[i]['datetime']
                    points_short = entry_price_short - exit_price_short
                    remarks_short = 'Target Hit'

                elif (current_candle['close'] >= current_candle['ma']):
                    exit_price_short = current_candle['close']
                    exit_time_short = df.iloc[i]['datetime']
                    points_short = entry_price_short - exit_price_short
                    remarks_short = 'Trailing SL Hit'

            if points_short:
                slippages = SLIPPAGE_ * (entry_price_short + exit_price_short)
                # qty = portfolio * index_lev / entry_price_short
                qty = portfolio * RPT_PCT / abs(entry_price_short - initial_sl_short)
                current_trade = {
                    'Type': 'SHORT',
                    'Signal Generated At': signal_time_short,
                    'Entry Time': entry_time_short,
                    'Entry Price': entry_price_short,
                    'Initial SL': stop_loss_short,
                    'Initial Target': target_short,
                    'Exit Time': exit_time_short,
                    'Exit Price': exit_price_short,
                    'Points': points_short,
                    'Slippages': slippages,
                    'Remarks': remarks_short,
                    'Qty': qty,
                    'PnL': points_short * qty,
                    'PnL w cs': (points_short - slippages) * qty,
                    'ROI%': points_short * qty * 100 / portfolio,
                    'ROI%': (points_short - slippages) * qty * 100 / portfolio,
                }
                trades.append(current_trade)
                in_trade_short = False
                queen_candle = None
                is_trailing_active_short = False
                points_short = None
                signal_time_short = None
                initial_sl_short = 0
            
    return trades


# Example usage:
# trades = identify_trades(df)
# print(trades)

# %%
tf = '60m'
ofs = '15m'
ma_period = 50

# data = resample(pl.DataFrame(bnf_1min), tf, ofs)
# data_pandas = data.to_pandas()
data_pandas = bnf_1min
data_pandas['ma'] = data_pandas['close'].rolling(ma_period).mean()
# data['ma'] = data['close'].rolling(ma_period).mean()
tb = positional(data_pandas, 0.05, 0.25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 ma_period = 50
#       5 # data = resample(pl.DataFrame(bnf_1min), tf, ofs)
#       6 # data_pandas = data.to_pandas()
# ----> 7 data_pandas = bnf_1min
#       8 data_pandas['ma'] = data_pandas['close'].rolling(ma_period).mean()
#       9 # data['ma'] = data['close'].rolling(ma_period).mean()
#
# NameError: name 'bnf_1min' is not defined

# %%
tb_pandas = pd.DataFrame(tb)

# %%
tb_pandas['Entry Time'] = pd.to_datetime(tb_pandas['Entry Time'])
tb_pandas['Trade Year'] = tb_pandas['Entry Time'].dt.year
tb_pandas['ROI% w cs'] = tb_pandas['ROI%']

# %%
# (tb_pandas['pnl'].sum()) - (tb_pandas['slippage'].sum())
# tb_pandas = tb_pandas[tb_pandas['Type'] == 'LONG']
# tb_pandas

# %%
tb_pandas
# Out:
#       Type       Signal Generated At                Entry Time  Entry Price  \
# 0     LONG 2015-04-13 17:00:00+05:30 2015-04-14 17:00:00+05:30     159.4000
# 1     LONG 2015-04-21 17:00:00+05:30 2015-04-22 13:00:00+05:30     164.0000
# 2    SHORT 2015-05-05 21:00:00+05:30 2015-05-06 13:00:00+05:30     176.5000
# 3    SHORT 2015-05-07 09:00:00+05:30 2015-05-07 17:00:00+05:30     177.2000
# 4     LONG 2015-04-28 17:00:00+05:30 2015-04-29 17:00:00+05:30     162.2000
# 5     LONG 2015-06-01 13:00:00+05:30 2015-06-01 21:00:00+05:30     170.5000
# 6    SHORT 2015-05-18 13:00:00+05:30 2015-05-19 21:00:00+05:30     189.9000
# 7     LONG 2015-06-05 13:00:00+05:30 2015-06-08 09:00:00+05:30     169.8000
# 8    SHORT 2015-06-16 17:00:00+05:30 2015-06-18 09:00:00+05:30     182.5000
# 9     LONG 2015-06-24 17:00:00+05:30 2015-06-25 13:00:00+05:30     176.9000
# 10   SHORT 2015-07-02 17:00:00+05:30 2015-07-03 17:00:00+05:30     179.2000
# 11    LONG 2015-07-06 17:00:00+05:30 2015-07-07 13:00:00+05:30     177.0000
# 12   SHORT 2015-07-17 17:00:00+05:30 2015-07-20 17:00:00+05:30     179.6000
# 13    LONG 2015-07-09 13:00:00+05:30 2015-07-09 21:00:00+05:30     172.2000
# 14   SHORT 2015-07-22 17:00:00+05:30 2015-07-23 21:00:00+05:30     181.1000
# 15   SHORT 2015-07-29 17:00:00+05:30 2015-07-30 17:00:00+05:30     181.5000
# 16    LONG 2015-08-03 17:00:00+05:30 2015-08-04 09:00:00+05:30     179.3000
# 17   SHORT 2015-08-13 21:00:00+05:30 2015-08-14 13:00:00+05:30     183.1000
# 18    LONG 2015-08-19 17:00:00+05:30 2015-08-20 17:00:00+05:30     179.1000
# 19    LONG 2015-08-25 17:00:00+05:30 2015-08-26 13:00:00+05:30     178.9000
# 20    LONG 2015-09-02 17:00:00+05:30 2015-09-03 17:00:00+05:30     178.6000
# 21    LONG 2015-09-21 21:00:00+05:30 2015-09-22 13:00:00+05:30     170.9000
# 22    LONG 2015-09-25 17:00:00+05:30 2015-09-28 09:00:00+05:30     176.6000
# 23    LONG 2015-10-06 13:00:00+05:30 2015-10-07 17:00:00+05:30     163.3000
# 24    LONG 2015-10-28 09:00:00+05:30 2015-10-29 17:00:00+05:30     155.7000
# 25    LONG 2015-12-03 21:00:00+05:30 2015-12-04 13:00:00+05:30     147.7000
# 26    LONG 2015-12-08 13:00:00+05:30 2015-12-08 21:00:00+05:30     139.2000
# 27    LONG 2015-12-17 09:00:00+05:30 2015-12-17 17:00:00+05:30     122.1000
# 28   SHORT 2015-11-26 09:00:00+05:30 2015-11-26 17:00:00+05:30     151.5000
# 29   SHORT 2015-12-31 21:00:00+05:30 2016-01-04 13:00:00+05:30     153.3000
# 30    LONG 2015-12-18 17:00:00+05:30 2015-12-21 09:00:00+05:30     119.9000
# 31   SHORT 2016-01-07 17:00:00+05:30 2016-01-12 21:00:00+05:30     152.8000
# 32   SHORT 2016-01-29 17:00:00+05:30 2016-02-01 09:00:00+05:30     153.1000
# 33    LONG 2016-02-03 21:00:00+05:30 2016-02-08 09:00:00+05:30     141.0000
# 34    LONG 2016-02-16 17:00:00+05:30 2016-02-17 17:00:00+05:30     133.1000
# 35    LONG 2016-02-23 09:00:00+05:30 2016-02-23 17:00:00+05:30     126.1000
# 36    LONG 2016-02-23 17:00:00+05:30 2016-02-25 09:00:00+05:30     126.8000
# 37    LONG 2016-02-29 21:00:00+05:30 2016-03-01 21:00:00+05:30     119.6000
# 38    LONG 2016-03-03 21:00:00+05:30 2016-03-07 17:00:00+05:30     114.5000
# 39   SHORT 2016-03-30 17:00:00+05:30 2016-03-31 21:00:00+05:30     130.8000
# 40   SHORT 2016-04-05 09:00:00+05:30 2016-04-05 17:00:00+05:30     132.6000
# 41   SHORT 2016-04-05 21:00:00+05:30 2016-04-06 13:00:00+05:30     129.0000
# 42   SHORT 2016-04-11 09:00:00+05:30 2016-04-11 17:00:00+05:30     128.0000
# 43   SHORT 2016-04-13 17:00:00+05:30 2016-04-14 17:00:00+05:30     133.6000
# 44   SHORT 2016-04-20 17:00:00+05:30 2016-04-21 13:00:00+05:30     136.5000
# 45   SHORT 2016-04-25 21:00:00+05:30 2016-04-26 13:00:00+05:30     136.5000
# 46   SHORT 2016-04-27 21:00:00+05:30 2016-04-28 13:00:00+05:30     141.3000
# 47   SHORT 2016-05-05 21:00:00+05:30 2016-05-06 13:00:00+05:30     138.3000
# 48   SHORT 2016-05-11 17:00:00+05:30 2016-05-13 09:00:00+05:30     141.5000
# 49    LONG 2016-05-19 09:00:00+05:30 2016-05-19 17:00:00+05:30     135.7000
# 50    LONG 2016-05-19 21:00:00+05:30 2016-05-20 17:00:00+05:30     138.8000
# 51   SHORT 2016-06-07 09:00:00+05:30 2016-06-07 17:00:00+05:30     162.4000
# 52   SHORT 2016-06-10 09:00:00+05:30 2016-06-10 17:00:00+05:30     171.5000
# 53   SHORT 2016-06-15 13:00:00+05:30 2016-06-15 21:00:00+05:30     174.2000
# 54   SHORT 2016-06-16 17:00:00+05:30 2016-06-17 09:00:00+05:30     172.5000
# 55   SHORT 2016-06-22 13:00:00+05:30 2016-06-22 21:00:00+05:30     183.9000
# 56   SHORT 2016-07-01 17:00:00+05:30 2016-07-04 09:00:00+05:30     195.1000
# 57    LONG 2016-07-15 13:00:00+05:30 2016-07-15 21:00:00+05:30     183.0000
# 58   SHORT 2016-07-08 13:00:00+05:30 2016-07-11 17:00:00+05:30     185.7000
# 59    LONG 2016-07-21 17:00:00+05:30 2016-07-22 13:00:00+05:30     181.8000
# 60    LONG 2016-07-26 13:00:00+05:30 2016-07-26 21:00:00+05:30     184.1000
# 61    LONG 2016-07-27 17:00:00+05:30 2016-07-28 17:00:00+05:30     183.8000
# 62   SHORT 2016-07-29 17:00:00+05:30 2016-08-01 09:00:00+05:30     190.8000
# 63   SHORT 2016-08-04 09:00:00+05:30 2016-08-04 17:00:00+05:30     190.0000
# 64   SHORT 2016-08-04 17:00:00+05:30 2016-08-05 13:00:00+05:30     188.4000
# 65   SHORT 2016-08-29 13:00:00+05:30 2016-08-29 21:00:00+05:30     193.9000
# 66    LONG 2016-08-11 17:00:00+05:30 2016-08-12 17:00:00+05:30     174.2000
# 67   SHORT 2016-08-30 21:00:00+05:30 2016-08-31 17:00:00+05:30     189.9000
# 68   SHORT 2016-09-14 21:00:00+05:30 2016-09-15 17:00:00+05:30     190.8000
# 69    LONG 2016-09-07 17:00:00+05:30 2016-09-08 17:00:00+05:30     182.5000
# 70   SHORT 2016-09-21 17:00:00+05:30 2016-09-22 17:00:00+05:30     203.1000
# 71   SHORT 2016-10-11 17:00:00+05:30 2016-10-12 17:00:00+05:30     214.6000
# 72   SHORT 2016-10-17 17:00:00+05:30 2016-10-19 13:00:00+05:30     214.9000
# 73    LONG 2016-11-03 21:00:00+05:30 2016-11-07 09:00:00+05:30     189.9000
# 74    LONG 2016-11-09 21:00:00+05:30 2016-11-14 17:00:00+05:30     182.9000
# 75   SHORT 2016-11-23 09:00:00+05:30 2016-11-23 17:00:00+05:30     201.4000
# 76   SHORT 2016-11-29 21:00:00+05:30 2016-11-30 13:00:00+05:30     225.5000
# 77   SHORT 2016-12-06 13:00:00+05:30 2016-12-08 09:00:00+05:30     243.1000
# 78   SHORT 2016-12-12 21:00:00+05:30 2016-12-13 17:00:00+05:30     234.5000
# 79   SHORT 2016-12-15 21:00:00+05:30 2016-12-16 13:00:00+05:30     230.6000
# 80    LONG 2017-01-05 17:00:00+05:30 2017-01-06 09:00:00+05:30     225.2000
# 81   SHORT 2016-12-29 21:00:00+05:30 2016-12-30 17:00:00+05:30     255.3000
# 82    LONG 2017-01-10 21:00:00+05:30 2017-01-11 17:00:00+05:30     227.6000
# 83    LONG 2017-01-19 13:00:00+05:30 2017-01-19 21:00:00+05:30     228.5000
# 84    LONG 2017-01-23 13:00:00+05:30 2017-01-23 21:00:00+05:30     220.5000
# 85    LONG 2017-02-02 13:00:00+05:30 2017-02-02 21:00:00+05:30     216.1000
# 86    LONG 2017-02-06 09:00:00+05:30 2017-02-07 13:00:00+05:30     208.0000
# 87    LONG 2017-02-20 17:00:00+05:30 2017-02-21 09:00:00+05:30     186.2000
# 88    LONG 2017-02-22 21:00:00+05:30 2017-02-23 13:00:00+05:30     176.9000
# 89   SHORT 2017-03-14 09:00:00+05:30 2017-03-14 17:00:00+05:30     200.0000
# 90   SHORT 2017-03-21 17:00:00+05:30 2017-03-22 21:00:00+05:30     198.0000
# 91   SHORT 2017-03-31 21:00:00+05:30 2017-04-03 17:00:00+05:30     205.2000
# 92   SHORT 2017-04-05 17:00:00+05:30 2017-04-06 13:00:00+05:30     211.5000
# 93   SHORT 2017-04-28 17:00:00+05:30 2017-05-01 21:00:00+05:30     208.0000
# 94   SHORT 2017-05-12 17:00:00+05:30 2017-05-15 17:00:00+05:30     215.6000
# 95    LONG 2017-06-05 13:00:00+05:30 2017-06-06 17:00:00+05:30     196.4000
# 96   SHORT 2017-05-26 17:00:00+05:30 2017-05-29 09:00:00+05:30     210.4000
# 97    LONG 2017-06-14 17:00:00+05:30 2017-06-15 17:00:00+05:30     191.7000
# 98    LONG 2017-06-20 21:00:00+05:30 2017-06-21 13:00:00+05:30     188.4000
# 99    LONG 2017-07-06 13:00:00+05:30 2017-07-07 09:00:00+05:30     187.8000
# 100   LONG 2017-07-10 21:00:00+05:30 2017-07-11 13:00:00+05:30     190.4000
# 101  SHORT 2017-07-19 21:00:00+05:30 2017-07-20 17:00:00+05:30     197.1000
# 102   LONG 2017-07-26 09:00:00+05:30 2017-07-27 17:00:00+05:30     191.2000
# 103   LONG 2017-08-02 17:00:00+05:30 2017-08-03 13:00:00+05:30     181.3000
# 104  SHORT 2017-08-11 17:00:00+05:30 2017-08-14 17:00:00+05:30     190.5000
# 105   LONG 2017-08-04 17:00:00+05:30 2017-08-07 09:00:00+05:30     178.7000
# 106  SHORT 2017-08-29 21:00:00+05:30 2017-08-30 17:00:00+05:30     189.0000
# 107  SHORT 2017-09-04 09:00:00+05:30 2017-09-04 17:00:00+05:30     194.5000
# 108   LONG 2017-09-11 09:00:00+05:30 2017-09-11 17:00:00+05:30     187.7000
# 109  SHORT 2017-09-19 17:00:00+05:30 2017-09-20 13:00:00+05:30     201.1000
# 110   LONG 2017-10-11 17:00:00+05:30 2017-10-12 17:00:00+05:30     193.5000
# 111  SHORT 2017-09-28 21:00:00+05:30 2017-09-29 17:00:00+05:30     197.3000
# 112  SHORT 2017-11-10 17:00:00+05:30 2017-11-13 09:00:00+05:30     207.6000
# 113  SHORT 2017-11-15 13:00:00+05:30 2017-11-15 21:00:00+05:30     201.4000
# 114   LONG 2017-11-01 13:00:00+05:30 2017-11-02 17:00:00+05:30     190.1000
# 115  SHORT 2017-11-16 13:00:00+05:30 2017-11-16 21:00:00+05:30     201.0000
# 116  SHORT 2017-11-17 09:00:00+05:30 2017-11-20 13:00:00+05:30     198.8000
# 117   LONG 2017-11-24 09:00:00+05:30 2017-11-27 09:00:00+05:30     189.5000
# 118   LONG 2017-12-08 17:00:00+05:30 2017-12-11 09:00:00+05:30     182.5000
# 119   LONG 2017-12-14 21:00:00+05:30 2017-12-15 13:00:00+05:30     174.5000
# 120   LONG 2017-12-21 13:00:00+05:30 2017-12-21 21:00:00+05:30     170.4000
# 121  SHORT 2017-12-29 13:00:00+05:30 2018-01-01 09:00:00+05:30     187.7000
# 122  SHORT 2018-01-03 17:00:00+05:30 2018-01-04 21:00:00+05:30     188.6000
# 123  SHORT 2018-01-15 17:00:00+05:30 2018-01-16 13:00:00+05:30     197.8000
# 124  SHORT 2018-01-25 09:00:00+05:30 2018-01-25 17:00:00+05:30     218.0000
# 125  SHORT 2018-01-29 09:00:00+05:30 2018-01-29 17:00:00+05:30     195.7000
# 126  SHORT 2018-01-30 13:00:00+05:30 2018-01-31 09:00:00+05:30     202.7000
# 127   LONG 2018-02-19 13:00:00+05:30 2018-02-20 09:00:00+05:30     169.5000
# 128  SHORT 2018-03-08 17:00:00+05:30 2018-03-09 09:00:00+05:30     178.8000
# 129   LONG 2018-02-27 13:00:00+05:30 2018-02-27 21:00:00+05:30     176.0000
# 130  SHORT 2018-03-16 17:00:00+05:30 2018-03-19 17:00:00+05:30     173.7000
# 131  SHORT 2018-03-21 09:00:00+05:30 2018-03-21 17:00:00+05:30     174.5000
# 132  SHORT 2018-04-02 09:00:00+05:30 2018-04-02 17:00:00+05:30     178.2000
# 133   LONG 2018-04-03 09:00:00+05:30 2018-04-03 17:00:00+05:30     175.6000
# 134   LONG 2018-04-09 17:00:00+05:30 2018-04-10 09:00:00+05:30     175.4000
# 135   LONG 2018-04-11 17:00:00+05:30 2018-04-12 17:00:00+05:30     175.9000
# 136  SHORT 2018-04-18 09:00:00+05:30 2018-04-19 13:00:00+05:30     179.9000
# 137  SHORT 2018-04-26 17:00:00+05:30 2018-04-27 13:00:00+05:30     187.8000
# 138  SHORT 2018-05-09 17:00:00+05:30 2018-05-10 09:00:00+05:30     184.1000
# 139  SHORT 2018-05-15 09:00:00+05:30 2018-05-16 13:00:00+05:30     191.4000
# 140  SHORT 2018-05-25 09:00:00+05:30 2018-05-25 17:00:00+05:30     199.4000
# 141  SHORT 2018-05-29 09:00:00+05:30 2018-05-29 17:00:00+05:30     201.0000
# 142  SHORT 2018-06-11 17:00:00+05:30 2018-06-12 17:00:00+05:30     198.1000
# 143  SHORT 2018-06-19 09:00:00+05:30 2018-06-19 17:00:00+05:30     200.3000
# 144  SHORT 2018-06-21 17:00:00+05:30 2018-06-22 17:00:00+05:30     199.9000
# 145   LONG 2018-07-03 09:00:00+05:30 2018-07-03 17:00:00+05:30     198.2000
# 146   LONG 2018-07-16 09:00:00+05:30 2018-07-16 17:00:00+05:30     190.7000
# 147   LONG 2018-07-16 17:00:00+05:30 2018-07-17 17:00:00+05:30     190.9000
# 148  SHORT 2018-06-27 21:00:00+05:30 2018-06-28 21:00:00+05:30     203.9000
# 149   LONG 2018-07-18 17:00:00+05:30 2018-07-19 17:00:00+05:30     189.1000
# 150  SHORT 2018-08-09 21:00:00+05:30 2018-08-10 17:00:00+05:30     201.8000
# 151  SHORT 2018-08-16 09:00:00+05:30 2018-08-16 17:00:00+05:30     205.8000
# 152  SHORT 2018-08-22 17:00:00+05:30 2018-08-23 17:00:00+05:30     206.5000
# 153  SHORT 2018-08-27 09:00:00+05:30 2018-08-27 17:00:00+05:30     203.2000
# 154  SHORT 2018-08-30 17:00:00+05:30 2018-09-03 13:00:00+05:30     202.8000
# 155  SHORT 2018-09-05 09:00:00+05:30 2018-09-05 21:00:00+05:30     202.0000
# 156   LONG 2018-09-07 09:00:00+05:30 2018-09-10 09:00:00+05:30     201.5000
# 157  SHORT 2018-09-26 13:00:00+05:30 2018-09-26 21:00:00+05:30     220.5000
# 158  SHORT 2018-10-03 17:00:00+05:30 2018-10-04 17:00:00+05:30     232.1000
# 159   LONG 2018-09-17 09:00:00+05:30 2018-09-17 17:00:00+05:30     202.4000
# 160  SHORT 2018-10-09 21:00:00+05:30 2018-10-11 17:00:00+05:30     240.5000
# 161  SHORT 2018-10-30 13:00:00+05:30 2018-10-30 21:00:00+05:30     234.0000
# 162  SHORT 2018-10-31 17:00:00+05:30 2018-11-01 17:00:00+05:30     237.8000
# 163  SHORT 2018-11-13 17:00:00+05:30 2018-11-15 21:00:00+05:30     284.7000
# 164  SHORT 2018-11-19 17:00:00+05:30 2018-11-20 09:00:00+05:30     315.9000
# 165  SHORT 2018-11-22 17:00:00+05:30 2018-11-26 09:00:00+05:30     290.5000
# 166  SHORT 2018-11-29 21:00:00+05:30 2018-12-03 09:00:00+05:30     311.5000
# 167  SHORT 2018-12-05 21:00:00+05:30 2018-12-06 17:00:00+05:30     311.7000
# 168   LONG 2018-12-17 17:00:00+05:30 2018-12-18 17:00:00+05:30     268.0000
# 169   LONG 2018-12-26 21:00:00+05:30 2018-12-27 17:00:00+05:30     247.7000
# 170   LONG 2019-01-01 13:00:00+05:30 2019-01-02 13:00:00+05:30     212.7000
# 171  SHORT 2018-12-10 17:00:00+05:30 2018-12-11 17:00:00+05:30     319.0000
# 172   LONG 2019-01-03 17:00:00+05:30 2019-01-04 13:00:00+05:30     211.9000
# 173   LONG 2019-01-23 17:00:00+05:30 2019-01-25 09:00:00+05:30     226.3000
# 174   LONG 2019-01-30 21:00:00+05:30 2019-01-31 13:00:00+05:30     207.3000
# 175   LONG 2019-02-08 17:00:00+05:30 2019-02-11 09:00:00+05:30     186.1000
# 176  SHORT 2019-01-17 09:00:00+05:30 2019-01-17 21:00:00+05:30     243.4000
# 177   LONG 2019-02-14 21:00:00+05:30 2019-02-15 17:00:00+05:30     186.6000
# 178  SHORT 2019-02-27 09:00:00+05:30 2019-02-27 17:00:00+05:30     196.8000
# 179   LONG 2019-02-21 13:00:00+05:30 2019-02-21 21:00:00+05:30     191.9000
# 180  SHORT 2019-03-04 17:00:00+05:30 2019-03-05 17:00:00+05:30     201.6000
# 181   LONG 2019-03-25 17:00:00+05:30 2019-03-26 09:00:00+05:30     190.3000
# 182   LONG 2019-03-29 17:00:00+05:30 2019-04-01 17:00:00+05:30     188.7000
# 183   LONG 2019-04-04 13:00:00+05:30 2019-04-08 09:00:00+05:30     186.4000
# 184   LONG 2019-04-10 09:00:00+05:30 2019-04-10 17:00:00+05:30     188.4000
# 185   LONG 2019-04-22 09:00:00+05:30 2019-04-22 17:00:00+05:30     175.4000
# 186   LONG 2019-04-24 17:00:00+05:30 2019-04-25 17:00:00+05:30     173.9000
# 187   LONG 2019-04-26 09:00:00+05:30 2019-04-26 17:00:00+05:30     180.2000
# 188   LONG 2019-05-07 21:00:00+05:30 2019-05-08 13:00:00+05:30     178.6000
# 189  SHORT 2019-05-14 13:00:00+05:30 2019-05-15 17:00:00+05:30     185.9000
# 190   LONG 2019-05-28 09:00:00+05:30 2019-05-28 21:00:00+05:30     180.0000
# 191   LONG 2019-06-07 13:00:00+05:30 2019-06-07 21:00:00+05:30     163.8000
# 192  SHORT 2019-07-08 21:00:00+05:30 2019-07-09 17:00:00+05:30     163.1000
# 193   LONG 2019-06-21 13:00:00+05:30 2019-06-24 17:00:00+05:30     154.8000
# 194   LONG 2019-07-17 09:00:00+05:30 2019-07-17 17:00:00+05:30     160.6000
# 195  SHORT 2019-07-10 21:00:00+05:30 2019-07-11 21:00:00+05:30     166.2000
# 196   LONG 2019-07-30 13:00:00+05:30 2019-07-31 09:00:00+05:30     148.2000
# 197   LONG 2019-08-05 17:00:00+05:30 2019-08-06 13:00:00+05:30     150.3000
# 198  SHORT 2019-08-20 17:00:00+05:30 2019-08-21 17:00:00+05:30     157.2000
# 199  SHORT 2019-08-22 13:00:00+05:30 2019-08-23 09:00:00+05:30     154.8000
# 200  SHORT 2019-09-03 09:00:00+05:30 2019-09-03 17:00:00+05:30     166.0000
# 201  SHORT 2019-09-11 17:00:00+05:30 2019-09-12 09:00:00+05:30     182.0000
# 202  SHORT 2019-09-16 21:00:00+05:30 2019-09-17 17:00:00+05:30     189.8000
# 203   LONG 2019-08-13 17:00:00+05:30 2019-08-14 09:00:00+05:30     154.7000
# 204   LONG 2019-10-01 17:00:00+05:30 2019-10-03 21:00:00+05:30     166.8000
# 205   LONG 2019-10-04 09:00:00+05:30 2019-10-04 17:00:00+05:30     167.9000
# 206  SHORT 2019-09-18 09:00:00+05:30 2019-09-18 17:00:00+05:30     190.2000
# 207   LONG 2019-10-11 17:00:00+05:30 2019-10-14 09:00:00+05:30     161.0000
# 208   LONG 2019-10-18 09:00:00+05:30 2019-10-18 17:00:00+05:30     166.8000
# 209  SHORT 2019-10-31 21:00:00+05:30 2019-11-01 13:00:00+05:30     186.1000
# 210  SHORT 2019-11-05 17:00:00+05:30 2019-11-06 09:00:00+05:30     202.5000
# 211   LONG 2019-10-22 09:00:00+05:30 2019-10-22 17:00:00+05:30     160.2000
# 212  SHORT 2019-11-06 17:00:00+05:30 2019-11-07 09:00:00+05:30     200.8000
# 213   LONG 2019-11-26 17:00:00+05:30 2019-11-27 13:00:00+05:30     183.2000
# 214   LONG 2019-12-02 09:00:00+05:30 2019-12-03 09:00:00+05:30     170.6000
# 215   LONG 2019-12-10 09:00:00+05:30 2019-12-10 17:00:00+05:30     159.7000
# 216   LONG 2019-12-23 21:00:00+05:30 2019-12-26 13:00:00+05:30     159.5000
# 217   LONG 2020-01-03 09:00:00+05:30 2020-01-03 17:00:00+05:30     154.2000
# 218   LONG 2020-01-13 17:00:00+05:30 2020-01-14 17:00:00+05:30     158.2000
# 219   LONG 2020-01-16 09:00:00+05:30 2020-01-16 21:00:00+05:30     152.4000
# 220   LONG 2020-01-21 09:00:00+05:30 2020-01-21 17:00:00+05:30     139.1000
# 221   LONG 2020-01-22 17:00:00+05:30 2020-01-23 13:00:00+05:30     138.4000
# 222   LONG 2020-02-05 09:00:00+05:30 2020-02-06 09:00:00+05:30     134.8000
# 223  SHORT 2020-02-19 17:00:00+05:30 2020-02-20 17:00:00+05:30     139.5000
# 224   LONG 2020-02-25 17:00:00+05:30 2020-02-26 09:00:00+05:30     133.7000
# 225   LONG 2020-02-28 17:00:00+05:30 2020-03-02 09:00:00+05:30     126.0000
# 226   LONG 2020-03-06 17:00:00+05:30 2020-03-09 21:00:00+05:30     131.4000
# 227   LONG 2020-03-19 13:00:00+05:30 2020-03-20 13:00:00+05:30     127.0000
# 228  SHORT 2020-03-11 17:00:00+05:30 2020-03-12 09:00:00+05:30     140.8000
# 229   LONG 2020-03-24 09:00:00+05:30 2020-03-24 17:00:00+05:30     125.9000
# 230  SHORT 2020-04-09 13:00:00+05:30 2020-04-13 09:00:00+05:30     135.6000
# 231  SHORT 2020-04-22 13:00:00+05:30 2020-04-24 13:00:00+05:30     137.3000
# 232  SHORT 2020-04-29 09:00:00+05:30 2020-04-29 17:00:00+05:30     147.2000
# 233  SHORT 2020-05-05 17:00:00+05:30 2020-05-06 09:00:00+05:30     157.7000
# 234   LONG 2020-05-13 17:00:00+05:30 2020-05-15 17:00:00+05:30     131.5000
# 235  SHORT 2020-05-28 09:00:00+05:30 2020-05-28 17:00:00+05:30     141.1000
# 236   LONG 2020-06-02 17:00:00+05:30 2020-06-03 13:00:00+05:30     135.8000
# 237   LONG 2020-06-17 17:00:00+05:30 2020-06-18 13:00:00+05:30     125.9000
# 238  SHORT 2020-07-09 09:00:00+05:30 2020-07-09 17:00:00+05:30     137.2000
# 239  SHORT 2020-07-13 09:00:00+05:30 2020-07-13 21:00:00+05:30     133.1000
# 240  SHORT 2020-07-15 17:00:00+05:30 2020-07-16 21:00:00+05:30     130.4000
# 241   LONG 2020-07-21 09:00:00+05:30 2020-07-21 17:00:00+05:30     124.5000
# 242  SHORT 2020-07-24 17:00:00+05:30 2020-07-27 17:00:00+05:30     130.2000
# 243  SHORT 2020-07-29 17:00:00+05:30 2020-07-30 21:00:00+05:30     137.2000
# 244  SHORT 2020-08-05 21:00:00+05:30 2020-08-07 09:00:00+05:30     162.2000
# 245  SHORT 2020-08-07 21:00:00+05:30 2020-08-10 17:00:00+05:30     163.5000
# 246  SHORT 2020-08-19 17:00:00+05:30 2020-08-20 17:00:00+05:30     178.2000
# 247  SHORT 2020-08-28 21:00:00+05:30 2020-08-31 13:00:00+05:30     192.4000
# 248  SHORT 2020-09-03 21:00:00+05:30 2020-09-04 17:00:00+05:30     181.0000
# 249  SHORT 2020-09-07 17:00:00+05:30 2020-09-08 17:00:00+05:30     183.8000
# 250   LONG 2020-09-11 17:00:00+05:30 2020-09-14 09:00:00+05:30     172.1000
# 251  SHORT 2020-09-28 17:00:00+05:30 2020-09-29 17:00:00+05:30     200.0000
# 252  SHORT 2020-10-16 13:00:00+05:30 2020-10-16 21:00:00+05:30     202.4000
# 253  SHORT 2020-10-22 17:00:00+05:30 2020-10-23 09:00:00+05:30     219.6000
# 254  SHORT 2020-10-26 21:00:00+05:30 2020-10-27 17:00:00+05:30     220.8000
# 255  SHORT 2020-10-28 17:00:00+05:30 2020-10-29 13:00:00+05:30     242.2000
# 256   LONG 2020-09-22 13:00:00+05:30 2020-09-23 17:00:00+05:30     139.7000
# 257   LONG 2020-11-17 13:00:00+05:30 2020-11-18 13:00:00+05:30     203.6000
# 258  SHORT 2020-10-30 17:00:00+05:30 2020-11-02 17:00:00+05:30     242.7000
# 259   LONG 2020-11-20 17:00:00+05:30 2020-11-23 09:00:00+05:30     198.9000
# 260   LONG 2020-12-08 09:00:00+05:30 2020-12-09 13:00:00+05:30     183.6000
# 261   LONG 2020-12-10 21:00:00+05:30 2020-12-11 17:00:00+05:30     191.6000
# 262   LONG 2020-12-30 17:00:00+05:30 2020-12-31 09:00:00+05:30     181.6000
# 263  SHORT 2021-01-07 13:00:00+05:30 2021-01-08 13:00:00+05:30     195.7000
# 264  SHORT 2021-01-13 09:00:00+05:30 2021-01-13 21:00:00+05:30     199.3000
# 265   LONG 2021-01-21 17:00:00+05:30 2021-01-25 09:00:00+05:30     183.8000
# 266  SHORT 2021-01-28 09:00:00+05:30 2021-01-28 21:00:00+05:30     192.7000
# 267  SHORT 2021-02-03 09:00:00+05:30 2021-02-03 17:00:00+05:30     205.2000
# 268  SHORT 2021-02-08 09:00:00+05:30 2021-02-08 17:00:00+05:30     211.8000
# 269   LONG 2021-02-26 21:00:00+05:30 2021-03-02 17:00:00+05:30     206.8000
# 270   LONG 2021-03-10 13:00:00+05:30 2021-03-10 21:00:00+05:30     194.8000
# 271  SHORT 2021-02-17 13:00:00+05:30 2021-02-18 21:00:00+05:30     221.8000
# 272   LONG 2021-03-19 13:00:00+05:30 2021-03-19 21:00:00+05:30     182.5000
# 273   LONG 2021-04-06 13:00:00+05:30 2021-04-07 17:00:00+05:30     188.9000
# 274  SHORT 2021-04-20 17:00:00+05:30 2021-04-21 17:00:00+05:30     204.1000
# 275  SHORT 2021-04-26 09:00:00+05:30 2021-04-26 17:00:00+05:30     202.7000
# 276  SHORT 2021-04-29 09:00:00+05:30 2021-04-29 17:00:00+05:30     217.7000
# 277   LONG 2021-04-08 17:00:00+05:30 2021-04-09 17:00:00+05:30     189.2000
# 278  SHORT 2021-05-04 17:00:00+05:30 2021-05-05 17:00:00+05:30     217.0000
# 279  SHORT 2021-05-13 17:00:00+05:30 2021-05-14 21:00:00+05:30     216.0000
# 280  SHORT 2021-05-19 17:00:00+05:30 2021-05-20 17:00:00+05:30     215.3000
# 281   LONG 2021-05-25 09:00:00+05:30 2021-05-25 17:00:00+05:30     211.3000
# 282  SHORT 2021-05-26 17:00:00+05:30 2021-05-27 17:00:00+05:30     217.3000
# 283  SHORT 2021-06-02 09:00:00+05:30 2021-06-02 21:00:00+05:30     224.0000
# 284  SHORT 2021-06-10 13:00:00+05:30 2021-06-10 21:00:00+05:30     229.3000
# 285  SHORT 2021-06-14 17:00:00+05:30 2021-06-15 21:00:00+05:30     239.6000
# 286  SHORT 2021-06-24 09:00:00+05:30 2021-06-24 17:00:00+05:30     245.0000
# 287  SHORT 2021-06-30 17:00:00+05:30 2021-07-01 17:00:00+05:30     268.5000
# 288  SHORT 2021-07-05 13:00:00+05:30 2021-07-06 17:00:00+05:30     276.5000
# 289  SHORT 2021-07-13 17:00:00+05:30 2021-07-14 17:00:00+05:30     274.3000
# 290  SHORT 2021-07-26 17:00:00+05:30 2021-07-27 17:00:00+05:30     299.7000
# 291  SHORT 2021-08-05 17:00:00+05:30 2021-08-06 17:00:00+05:30     305.2000
# 292  SHORT 2021-08-27 13:00:00+05:30 2021-08-30 17:00:00+05:30     311.6000
# 293  SHORT 2021-09-06 17:00:00+05:30 2021-09-07 09:00:00+05:30     341.3000
# 294   LONG 2021-08-18 17:00:00+05:30 2021-08-20 09:00:00+05:30     288.0000
# 295  SHORT 2021-09-15 21:00:00+05:30 2021-09-16 13:00:00+05:30     390.5000
# 296  SHORT 2021-09-28 21:00:00+05:30 2021-09-29 17:00:00+05:30     420.2000
# 297  SHORT 2021-10-08 13:00:00+05:30 2021-10-11 17:00:00+05:30     419.4000
# 298   LONG 2021-10-19 13:00:00+05:30 2021-10-19 21:00:00+05:30     379.5000
# 299  SHORT 2021-10-27 17:00:00+05:30 2021-10-28 17:00:00+05:30     443.0000
# 300   LONG 2021-11-01 13:00:00+05:30 2021-11-02 21:00:00+05:30     413.0000
# 301   LONG 2021-11-11 09:00:00+05:30 2021-11-11 17:00:00+05:30     372.8000
# 302   LONG 2021-11-18 17:00:00+05:30 2021-11-19 21:00:00+05:30     374.3000
# 303   LONG 2021-11-23 21:00:00+05:30 2021-11-24 21:00:00+05:30     378.6000
# 304   LONG 2021-12-07 13:00:00+05:30 2021-12-07 21:00:00+05:30     288.7000
# 305   LONG 2021-12-17 21:00:00+05:30 2021-12-20 17:00:00+05:30     291.2000
# 306   LONG 2021-12-24 17:00:00+05:30 2021-12-27 09:00:00+05:30     286.1000
# 307   LONG 2021-12-31 17:00:00+05:30 2022-01-03 09:00:00+05:30     278.4000
# 308  SHORT 2022-01-18 17:00:00+05:30 2022-01-19 09:00:00+05:30     316.2000
# 309  SHORT 2022-01-31 21:00:00+05:30 2022-02-01 17:00:00+05:30     350.6000
# 310   LONG 2022-01-21 09:00:00+05:30 2022-01-21 21:00:00+05:30     296.6000
# 311  SHORT 2022-02-03 17:00:00+05:30 2022-02-04 17:00:00+05:30     361.0000
# 312   LONG 2022-02-11 13:00:00+05:30 2022-02-14 09:00:00+05:30     306.3000
# 313  SHORT 2022-02-21 13:00:00+05:30 2022-02-22 09:00:00+05:30     342.9000
# 314  SHORT 2022-03-02 21:00:00+05:30 2022-03-03 17:00:00+05:30     352.6000
# 315  SHORT 2022-03-07 17:00:00+05:30 2022-03-08 09:00:00+05:30     373.3000
# 316  SHORT 2022-03-14 13:00:00+05:30 2022-03-15 17:00:00+05:30     345.2000
# 317  SHORT 2022-03-18 17:00:00+05:30 2022-03-21 17:00:00+05:30     367.8000
# 318  SHORT 2022-03-24 09:00:00+05:30 2022-03-24 17:00:00+05:30     390.1000
# 319  SHORT 2022-03-28 17:00:00+05:30 2022-03-29 13:00:00+05:30     413.3000
# 320  SHORT 2022-04-06 21:00:00+05:30 2022-04-07 17:00:00+05:30     458.9000
# 321  SHORT 2022-04-18 13:00:00+05:30 2022-04-19 17:00:00+05:30     569.2000
# 322  SHORT 2022-04-27 13:00:00+05:30 2022-04-28 21:00:00+05:30     535.3000
# 323  SHORT 2022-05-05 17:00:00+05:30 2022-05-06 21:00:00+05:30     621.0000
# 324  SHORT 2022-05-16 13:00:00+05:30 2022-05-16 21:00:00+05:30     600.8000
# 325  SHORT 2022-05-17 21:00:00+05:30 2022-05-19 13:00:00+05:30     630.8000
# 326  SHORT 2022-05-20 17:00:00+05:30 2022-05-23 17:00:00+05:30     612.0000
# 327  SHORT 2022-05-30 17:00:00+05:30 2022-05-31 13:00:00+05:30     672.0000
# 328  SHORT 2022-06-07 17:00:00+05:30 2022-06-08 17:00:00+05:30     715.1000
# 329  SHORT 2022-06-10 17:00:00+05:30 2022-06-13 09:00:00+05:30     674.2000
# 330   LONG 2022-06-15 17:00:00+05:30 2022-06-16 13:00:00+05:30     602.0000
# 331   LONG 2022-06-21 09:00:00+05:30 2022-06-21 17:00:00+05:30     528.1000
# 332   LONG 2022-06-24 17:00:00+05:30 2022-06-27 21:00:00+05:30     496.9000
# 333   LONG 2022-07-06 17:00:00+05:30 2022-07-07 17:00:00+05:30     454.9000
# 334   LONG 2022-07-11 09:00:00+05:30 2022-07-11 17:00:00+05:30     506.8000
# 335  SHORT 2022-07-27 09:00:00+05:30 2022-07-27 17:00:00+05:30     696.5000
# 336  SHORT 2022-08-05 17:00:00+05:30 2022-08-08 09:00:00+05:30     627.3000
# 337  SHORT 2022-08-17 21:00:00+05:30 2022-08-18 17:00:00+05:30     723.9000
# 338  SHORT 2022-08-18 21:00:00+05:30 2022-08-19 13:00:00+05:30     710.0000
# 339  SHORT 2022-08-23 21:00:00+05:30 2022-08-24 17:00:00+05:30     727.6000
# 340   LONG 2022-09-08 17:00:00+05:30 2022-09-09 09:00:00+05:30     643.9000
# 341   LONG 2022-09-19 21:00:00+05:30 2022-09-20 21:00:00+05:30     632.5000
# 342   LONG 2022-09-28 13:00:00+05:30 2022-09-28 21:00:00+05:30     566.4000
# 343   LONG 2022-10-05 17:00:00+05:30 2022-10-06 09:00:00+05:30     574.3000
# 344   LONG 2022-10-11 21:00:00+05:30 2022-10-12 17:00:00+05:30     549.9000
# 345   LONG 2022-10-24 18:00:00+05:30 2022-10-25 13:00:00+05:30     434.0000
# 346   LONG 2022-10-28 13:00:00+05:30 2022-10-31 09:00:00+05:30     486.4000
# 347   LONG 2022-11-03 17:00:00+05:30 2022-11-04 13:00:00+05:30     512.8000
# 348  SHORT 2022-11-17 17:00:00+05:30 2022-11-18 09:00:00+05:30     508.3000
# 349  SHORT 2022-11-24 13:00:00+05:30 2022-11-24 21:00:00+05:30     580.1000
# 350  SHORT 2022-11-30 09:00:00+05:30 2022-11-30 21:00:00+05:30     577.9000
# 351   LONG 2022-12-06 17:00:00+05:30 2022-12-07 09:00:00+05:30     467.6000
# 352   LONG 2022-12-21 17:00:00+05:30 2022-12-22 09:00:00+05:30     465.8000
# 353   LONG 2022-12-26 09:00:00+05:30 2022-12-27 09:00:00+05:30     437.0000
# 354   LONG 2022-12-29 09:00:00+05:30 2022-12-29 17:00:00+05:30     400.5000
# 355   LONG 2023-01-11 17:00:00+05:30 2023-01-12 13:00:00+05:30     313.0000
# 356   LONG 2023-01-19 17:00:00+05:30 2023-01-23 09:00:00+05:30     278.5000
# 357   LONG 2023-01-30 21:00:00+05:30 2023-02-01 09:00:00+05:30     230.5000
# 358   LONG 2023-02-06 09:00:00+05:30 2023-02-06 17:00:00+05:30     206.6000
# 359   LONG 2023-02-10 13:00:00+05:30 2023-02-10 21:00:00+05:30     207.3000
# 360  SHORT 2022-12-13 17:00:00+05:30 2022-12-14 09:00:00+05:30     557.9000
# 361  SHORT 2023-03-02 21:00:00+05:30 2023-03-06 09:00:00+05:30     224.7000
# 362   LONG 2023-02-21 13:00:00+05:30 2023-02-22 21:00:00+05:30     188.0000
# 363  SHORT 2023-03-06 09:00:00+05:30 2023-03-06 17:00:00+05:30     220.4000
# 364   LONG 2023-03-21 13:00:00+05:30 2023-03-21 21:00:00+05:30     187.9000
# 365   LONG 2023-03-29 21:00:00+05:30 2023-03-31 17:00:00+05:30     185.6000
# 366  SHORT 2023-03-14 21:00:00+05:30 2023-03-15 13:00:00+05:30     209.8000
# 367   LONG 2023-04-03 17:00:00+05:30 2023-04-04 17:00:00+05:30     179.9000
# 368   LONG 2023-04-10 21:00:00+05:30 2023-04-11 13:00:00+05:30     183.3000
# 369   LONG 2023-04-17 09:00:00+05:30 2023-04-17 17:00:00+05:30     179.6000
# 370  SHORT 2023-04-26 21:00:00+05:30 2023-04-27 17:00:00+05:30     188.0000
# 371  SHORT 2023-05-01 21:00:00+05:30 2023-05-02 17:00:00+05:30     189.0000
# 372  SHORT 2023-05-16 17:00:00+05:30 2023-05-17 09:00:00+05:30     193.0000
# 373   LONG 2023-05-04 17:00:00+05:30 2023-05-08 09:00:00+05:30     180.0000
# 374  SHORT 2023-05-19 13:00:00+05:30 2023-05-22 09:00:00+05:30     211.7000
# 375  SHORT 2023-05-26 17:00:00+05:30 2023-05-29 17:00:00+05:30     197.8000
# 376   LONG 2023-06-02 17:00:00+05:30 2023-06-05 13:00:00+05:30     184.8000
# 377  SHORT 2023-06-20 09:00:00+05:30 2023-06-20 17:00:00+05:30     216.8000
# 378  SHORT 2023-06-21 09:00:00+05:30 2023-06-21 17:00:00+05:30     203.0000
# 379  SHORT 2023-06-22 17:00:00+05:30 2023-06-23 17:00:00+05:30     207.8000
# 380  SHORT 2023-06-27 17:00:00+05:30 2023-06-28 21:00:00+05:30     224.7000
# 381  SHORT 2023-07-03 17:00:00+05:30 2023-07-04 13:00:00+05:30     219.7000
# 382  SHORT 2023-07-06 21:00:00+05:30 2023-07-07 21:00:00+05:30     215.0000
# 383  SHORT 2023-07-11 13:00:00+05:30 2023-07-12 17:00:00+05:30     218.7000
# 384   LONG 2023-07-17 17:00:00+05:30 2023-07-18 13:00:00+05:30     212.2000
# 385  SHORT 2023-07-21 09:00:00+05:30 2023-07-21 17:00:00+05:30     224.2000
# 386   LONG 2023-07-28 09:00:00+05:30 2023-07-28 17:00:00+05:30     216.4000
# 387   LONG 2023-08-03 21:00:00+05:30 2023-08-04 13:00:00+05:30     214.8000
# 388   LONG 2023-08-18 17:00:00+05:30 2023-08-21 09:00:00+05:30     216.6000
# 389  SHORT 2023-08-10 21:00:00+05:30 2023-08-11 17:00:00+05:30     228.1000
# 390   LONG 2023-08-25 13:00:00+05:30 2023-08-25 21:00:00+05:30     210.2000
# 391  SHORT 2023-09-01 13:00:00+05:30 2023-09-04 09:00:00+05:30     227.2000
# 392   LONG 2023-09-07 17:00:00+05:30 2023-09-08 09:00:00+05:30     218.0000
# 393   LONG 2023-09-25 09:00:00+05:30 2023-09-25 17:00:00+05:30     220.1000
# 394  SHORT 2023-09-20 17:00:00+05:30 2023-09-21 17:00:00+05:30     225.0000
# 395  SHORT 2023-09-28 13:00:00+05:30 2023-09-29 17:00:00+05:30     239.6000
# 396  SHORT 2023-10-10 17:00:00+05:30 2023-10-11 17:00:00+05:30     278.4000
# 397  SHORT 2023-10-30 17:00:00+05:30 2023-10-31 09:00:00+05:30     277.4000
# 398  SHORT 2023-11-01 17:00:00+05:30 2023-11-02 13:00:00+05:30     286.2000
# 399   LONG 2023-10-23 17:00:00+05:30 2023-10-24 17:00:00+05:30     245.4000
# 400   LONG 2023-11-10 17:00:00+05:30 2023-11-13 09:00:00+05:30     256.9000
# 401   LONG 2023-11-22 21:00:00+05:30 2023-11-23 17:00:00+05:30     243.1000
# 402   LONG 2023-12-04 17:00:00+05:30 2023-12-05 17:00:00+05:30     230.7000
# 403  SHORT 2023-11-06 09:00:00+05:30 2023-11-06 17:00:00+05:30     281.8000
# 404   LONG 2023-12-13 21:00:00+05:30 2023-12-14 17:00:00+05:30     199.3000
# 405   LONG 2023-12-21 21:00:00+05:30 2023-12-22 13:00:00+05:30     216.9000
# 406  SHORT 2024-01-04 21:00:00+05:30 2024-01-05 17:00:00+05:30     228.9000
# 407  SHORT 2024-01-10 21:00:00+05:30 2024-01-11 13:00:00+05:30     247.2000
# 408   LONG 2023-12-28 21:00:00+05:30 2023-12-29 17:00:00+05:30     213.7000
# 409  SHORT 2024-01-15 09:00:00+05:30 2024-01-15 17:00:00+05:30     258.0000
# 410   LONG 2024-01-22 21:00:00+05:30 2024-01-24 09:00:00+05:30     204.2000
# 411   LONG 2024-01-30 21:00:00+05:30 2024-01-31 17:00:00+05:30     177.4000
# 412   LONG 2024-02-19 17:00:00+05:30 2024-02-20 13:00:00+05:30     131.9000
# 413  SHORT 2024-03-05 09:00:00+05:30 2024-03-05 17:00:00+05:30     158.8000
# 414  SHORT 2024-04-03 09:00:00+05:30 2024-04-04 13:00:00+05:30     154.7000
# 415  SHORT 2024-04-10 17:00:00+05:30 2024-04-11 17:00:00+05:30     156.5000
# 416   LONG 2024-04-16 21:00:00+05:30 2024-04-18 09:00:00+05:30     145.0000
# 417  SHORT 2024-04-29 17:00:00+05:30 2024-05-01 17:00:00+05:30     160.9000
# 418  SHORT 2024-05-08 21:00:00+05:30 2024-05-09 13:00:00+05:30     181.4000
# 419  SHORT 2024-05-13 09:00:00+05:30 2024-05-13 17:00:00+05:30     186.6000
# 420  SHORT 2024-05-15 09:00:00+05:30 2024-05-15 17:00:00+05:30     195.2000
# 421  SHORT 2024-05-21 17:00:00+05:30 2024-05-22 09:00:00+05:30     220.5000
# 422  SHORT 2024-05-30 17:00:00+05:30 2024-05-31 09:00:00+05:30     214.6000
# 423  SHORT 2024-06-03 21:00:00+05:30 2024-06-04 21:00:00+05:30     219.0000
# 424  SHORT 2024-06-10 13:00:00+05:30 2024-06-10 21:00:00+05:30     247.4000
# 425  SHORT 2024-06-12 21:00:00+05:30 2024-06-13 13:00:00+05:30     250.4000
# 426   LONG 2024-07-05 09:00:00+05:30 2024-07-05 17:00:00+05:30     199.2000
# 427   LONG 2024-07-08 17:00:00+05:30 2024-07-09 17:00:00+05:30     199.9000
# 428   LONG 2024-07-11 13:00:00+05:30 2024-07-12 21:00:00+05:30     196.3000
# 429   LONG 2024-07-18 21:00:00+05:30 2024-07-22 09:00:00+05:30     178.9000
# 430   LONG 2024-07-29 17:00:00+05:30 2024-07-30 09:00:00+05:30     175.9000
# 431  SHORT 2024-06-19 17:00:00+05:30 2024-06-20 13:00:00+05:30     238.7000
# 432   LONG 2024-08-06 09:00:00+05:30 2024-08-06 17:00:00+05:30     166.2000
# 433  SHORT 2024-08-12 21:00:00+05:30 2024-08-13 21:00:00+05:30     181.5000
# 434  SHORT 2024-08-16 09:00:00+05:30 2024-08-16 17:00:00+05:30     184.0000
# 435   LONG 2024-08-07 17:00:00+05:30 2024-08-08 17:00:00+05:30     177.8000
# 436  SHORT 2024-08-20 21:00:00+05:30 2024-08-21 17:00:00+05:30     182.3000
# 437  SHORT 2024-09-03 09:00:00+05:30 2024-09-03 17:00:00+05:30     182.7000
# 438  SHORT 2024-09-04 13:00:00+05:30 2024-09-04 21:00:00+05:30     183.5000
# 439  SHORT 2024-09-17 13:00:00+05:30 2024-09-17 21:00:00+05:30     198.5000
# 440  SHORT 2024-09-30 09:00:00+05:30 2024-09-30 17:00:00+05:30     241.1000
# 441  SHORT 2024-09-30 17:00:00+05:30 2024-10-01 17:00:00+05:30     240.7000
# 442   LONG 2024-10-21 17:00:00+05:30 2024-10-22 09:00:00+05:30     197.7000
# 443  SHORT 2024-10-03 17:00:00+05:30 2024-10-04 17:00:00+05:30     244.2000
#
#      Initial SL  Initial Target                 Exit Time  Exit Price  \
# 0      155.8000        318.8000 2015-04-20 09:00:00+05:30    162.4000
# 1      160.7000        328.0000 2015-04-23 17:00:00+05:30    160.7000
# 2      179.8000          0.0000 2015-05-06 17:00:00+05:30    179.8000
# 3      180.7000          0.0000 2015-05-07 17:00:00+05:30    180.7000
# 4      158.7000        324.4000 2015-05-22 17:00:00+05:30    185.6000
# 5      167.6000        341.0000 2015-06-02 17:00:00+05:30    167.6000
# 6      194.5000          0.0000 2015-06-09 13:00:00+05:30    176.4000
# 7      166.4000        339.6000 2015-06-18 21:00:00+05:30    177.4000
# 8      188.6000          0.0000 2015-06-19 17:00:00+05:30    178.4000
# 9      172.7000        353.8000 2015-06-26 21:00:00+05:30    178.1000
# 10     183.8000          0.0000 2015-07-07 13:00:00+05:30    177.9000
# 11     174.1000        354.0000 2015-07-07 17:00:00+05:30    174.1000
# 12     183.9000          0.0000 2015-07-22 17:00:00+05:30    183.9000
# 13     168.4000        344.4000 2015-07-24 09:00:00+05:30    179.7000
# 14     185.6000          0.0000 2015-07-28 17:00:00+05:30    182.2000
# 15     184.1000          0.0000 2015-08-05 09:00:00+05:30    180.4000
# 16     174.3000        358.6000 2015-08-05 21:00:00+05:30    179.8000
# 17     191.3000          0.0000 2015-08-20 17:00:00+05:30    182.0000
# 18     176.1000        358.2000 2015-08-21 09:00:00+05:30    180.1000
# 19     175.6000        357.8000 2015-08-31 09:00:00+05:30    178.1000
# 20     176.7000        357.2000 2015-09-03 17:00:00+05:30    176.7000
# 21     168.0000        341.8000 2015-09-24 17:00:00+05:30    168.0000
# 22     167.6000        353.2000 2015-09-29 13:00:00+05:30    174.9000
# 23     160.0000        326.6000 2015-10-15 21:00:00+05:30    160.0000
# 24     131.3000        311.4000 2015-11-19 21:00:00+05:30    153.1000
# 25     143.2000        295.4000 2015-12-07 09:00:00+05:30    143.2000
# 26     135.5000        278.4000 2015-12-10 21:00:00+05:30    135.5000
# 27     118.8000        244.2000 2015-12-17 21:00:00+05:30    118.8000
# 28     156.9000          0.0000 2015-12-23 21:00:00+05:30    129.0000
# 29     157.9000          0.0000 2016-01-04 21:00:00+05:30    157.9000
# 30     114.2000        239.8000 2016-01-13 09:00:00+05:30    152.6000
# 31     161.3000          0.0000 2016-01-27 13:00:00+05:30    150.0000
# 32     156.6000          0.0000 2016-02-08 17:00:00+05:30    146.5000
# 33     136.3000        282.0000 2016-02-11 21:00:00+05:30    136.3000
# 34     129.2000        266.2000 2016-02-18 17:00:00+05:30    129.2000
# 35     123.2000        252.2000 2016-02-23 17:00:00+05:30    123.2000
# 36     121.9000        253.6000 2016-02-25 21:00:00+05:30    121.9000
# 37     116.5000        239.2000 2016-03-01 21:00:00+05:30    116.5000
# 38     109.5000        229.0000 2016-03-23 21:00:00+05:30    121.4000
# 39     133.8000          0.0000 2016-04-04 13:00:00+05:30    133.8000
# 40     135.8000          0.0000 2016-04-05 17:00:00+05:30    135.8000
# 41     136.0000          0.0000 2016-04-07 17:00:00+05:30    132.0000
# 42     134.3000          0.0000 2016-04-12 13:00:00+05:30    129.5000
# 43     136.6000          0.0000 2016-04-19 17:00:00+05:30    134.3000
# 44     141.5000          0.0000 2016-04-22 21:00:00+05:30    141.5000
# 45     141.5000          0.0000 2016-04-27 09:00:00+05:30    144.5000
# 46     146.1000          0.0000 2016-04-29 21:00:00+05:30    146.1000
# 47     145.4000          0.0000 2016-05-06 17:00:00+05:30    140.1000
# 48     145.7000          0.0000 2016-05-13 17:00:00+05:30    144.8000
# 49     133.5000        271.4000 2016-05-19 17:00:00+05:30    133.5000
# 50     133.0000        277.6000 2016-05-23 21:00:00+05:30    139.5000
# 51     164.6000          0.0000 2016-06-07 17:00:00+05:30    164.6000
# 52     175.9000          0.0000 2016-06-13 13:00:00+05:30    175.9000
# 53     176.8000          0.0000 2016-06-15 21:00:00+05:30    176.8000
# 54     178.1000          0.0000 2016-06-20 09:00:00+05:30    178.1000
# 55     187.5000          0.0000 2016-06-28 09:00:00+05:30    187.5000
# 56     200.9000          0.0000 2016-07-07 13:00:00+05:30    190.1000
# 57     178.9000        366.0000 2016-07-20 17:00:00+05:30    178.9000
# 58     190.3000          0.0000 2016-07-22 17:00:00+05:30    186.0000
# 59     176.6000        363.6000 2016-07-26 09:00:00+05:30    182.7000
# 60     180.7000        368.2000 2016-07-27 09:00:00+05:30    180.6000
# 61     178.9000        367.6000 2016-08-02 17:00:00+05:30    184.4000
# 62     195.4000          0.0000 2016-08-03 21:00:00+05:30    191.3000
# 63     192.0000          0.0000 2016-08-04 17:00:00+05:30    192.0000
# 64     193.5000          0.0000 2016-08-22 17:00:00+05:30    181.3000
# 65     197.6000          0.0000 2016-08-30 17:00:00+05:30    197.6000
# 66     169.3000        348.4000 2016-09-05 17:00:00+05:30    183.2000
# 67     197.8000          0.0000 2016-09-09 13:00:00+05:30    188.7000
# 68     199.3000          0.0000 2016-09-20 13:00:00+05:30    199.3000
# 69     177.5000        365.0000 2016-09-30 09:00:00+05:30    197.5000
# 70     207.6000          0.0000 2016-10-05 21:00:00+05:30    202.7000
# 71     219.0000          0.0000 2016-10-13 17:00:00+05:30    219.0000
# 72     218.8000          0.0000 2016-10-28 17:00:00+05:30    207.4000
# 73     182.7000        379.8000 2016-11-08 17:00:00+05:30    182.7000
# 74     170.9000        365.8000 2016-11-17 21:00:00+05:30    185.4000
# 75     206.0000          0.0000 2016-11-23 17:00:00+05:30    206.0000
# 76     230.5000          0.0000 2016-11-30 17:00:00+05:30    230.5000
# 77     253.2000          0.0000 2016-12-09 17:00:00+05:30    253.2000
# 78     242.8000          0.0000 2016-12-15 09:00:00+05:30    242.8000
# 79     243.3000          0.0000 2016-12-22 09:00:00+05:30    243.3000
# 80     215.8000        450.4000 2017-01-09 17:00:00+05:30    215.8000
# 81     263.5000          0.0000 2017-01-16 09:00:00+05:30    234.4000
# 82     215.9000        455.2000 2017-01-18 21:00:00+05:30    226.2000
# 83     222.5000        457.0000 2017-01-20 21:00:00+05:30    222.5000
# 84     214.8000        441.0000 2017-01-31 17:00:00+05:30    214.8000
# 85     210.3000        432.2000 2017-02-03 13:00:00+05:30    210.3000
# 86     205.0000        416.0000 2017-02-10 09:00:00+05:30    205.0000
# 87     184.5000        372.4000 2017-02-21 13:00:00+05:30    184.5000
# 88     170.1000        353.8000 2017-03-16 21:00:00+05:30    191.8000
# 89     202.9000          0.0000 2017-03-17 21:00:00+05:30    193.5000
# 90     202.8000          0.0000 2017-03-27 09:00:00+05:30    202.8000
# 91     210.4000          0.0000 2017-04-04 17:00:00+05:30    210.4000
# 92     217.5000          0.0000 2017-04-26 13:00:00+05:30    206.3000
# 93     212.6000          0.0000 2017-05-03 13:00:00+05:30    205.8000
# 94     220.0000          0.0000 2017-05-19 17:00:00+05:30    210.3000
# 95     189.5000        392.8000 2017-06-14 13:00:00+05:30    189.5000
# 96     215.2000          0.0000 2017-06-15 17:00:00+05:30    196.2000
# 97     187.7000        383.4000 2017-06-19 09:00:00+05:30    190.4000
# 98     186.2000        376.8000 2017-06-21 21:00:00+05:30    186.2000
# 99     184.8000        375.6000 2017-07-07 21:00:00+05:30    184.8000
# 100    187.4000        380.8000 2017-07-12 17:00:00+05:30    193.0000
# 101    199.5000          0.0000 2017-07-20 17:00:00+05:30    199.5000
# 102    188.1000        382.4000 2017-07-31 09:00:00+05:30    188.1000
# 103    178.2000        362.6000 2017-08-04 09:00:00+05:30    178.2000
# 104    192.5000          0.0000 2017-08-22 17:00:00+05:30    192.5000
# 105    176.1000        357.4000 2017-08-25 17:00:00+05:30    185.3000
# 106    191.9000          0.0000 2017-08-31 21:00:00+05:30    191.9000
# 107    197.5000          0.0000 2017-09-12 13:00:00+05:30    190.6000
# 108    185.1000        375.4000 2017-09-21 17:00:00+05:30    193.4000
# 109    203.9000          0.0000 2017-09-27 09:00:00+05:30    199.1000
# 110    189.9000        387.0000 2017-10-12 17:00:00+05:30    189.9000
# 111    202.1000          0.0000 2017-10-12 17:00:00+05:30    194.4000
# 112    210.4000          0.0000 2017-11-13 17:00:00+05:30    210.4000
# 113    205.2000          0.0000 2017-11-15 21:00:00+05:30    205.2000
# 114    184.9000        380.2000 2017-11-16 21:00:00+05:30    200.1000
# 115    203.3000          0.0000 2017-11-16 21:00:00+05:30    203.3000
# 116    203.4000          0.0000 2017-11-28 13:00:00+05:30    198.7000
# 117    186.1000        379.0000 2017-11-30 21:00:00+05:30    196.4000
# 118    178.3000        365.0000 2017-12-12 17:00:00+05:30    178.3000
# 119    170.3000        349.0000 2017-12-15 21:00:00+05:30    170.3000
# 120    164.7000        340.8000 2017-12-26 17:00:00+05:30    173.6000
# 121    192.7000          0.0000 2018-01-02 09:00:00+05:30    192.9000
# 122    194.0000          0.0000 2018-01-08 09:00:00+05:30    181.7000
# 123    202.3000          0.0000 2018-01-17 13:00:00+05:30    202.3000
# 124    227.0000          0.0000 2018-01-25 17:00:00+05:30    227.0000
# 125    224.0000          0.0000 2018-01-30 09:00:00+05:30    206.5000
# 126    208.0000          0.0000 2018-02-21 17:00:00+05:30    173.2000
# 127    166.6000        339.0000 2018-02-23 09:00:00+05:30    167.8000
# 128    182.4000          0.0000 2018-03-12 17:00:00+05:30    182.4000
# 129    172.3000        352.0000 2018-03-14 13:00:00+05:30    177.6000
# 130    175.4000          0.0000 2018-03-20 17:00:00+05:30    175.4000
# 131    176.7000          0.0000 2018-03-27 21:00:00+05:30    176.0000
# 132    179.8000          0.0000 2018-04-02 17:00:00+05:30    179.8000
# 133    173.2000        351.2000 2018-04-05 17:00:00+05:30    173.2000
# 134    172.0000        350.8000 2018-04-10 17:00:00+05:30    173.6000
# 135    171.6000        351.8000 2018-04-19 21:00:00+05:30    176.8000
# 136    181.4000          0.0000 2018-04-20 17:00:00+05:30    180.1000
# 137    191.0000          0.0000 2018-05-07 17:00:00+05:30    185.9000
# 138    186.4000          0.0000 2018-05-10 17:00:00+05:30    186.4000
# 139    193.9000          0.0000 2018-05-17 21:00:00+05:30    193.9000
# 140    201.8000          0.0000 2018-05-25 17:00:00+05:30    201.8000
# 141    203.4000          0.0000 2018-06-07 17:00:00+05:30    199.1000
# 142    200.4000          0.0000 2018-06-13 17:00:00+05:30    200.4000
# 143    202.5000          0.0000 2018-06-20 13:00:00+05:30    199.8000
# 144    204.4000          0.0000 2018-06-27 09:00:00+05:30    203.5000
# 145    196.7000        396.4000 2018-07-03 17:00:00+05:30    196.7000
# 146    188.6000        381.4000 2018-07-16 17:00:00+05:30    188.6000
# 147    188.1000        381.8000 2018-07-17 17:00:00+05:30    188.1000
# 148    206.6000          0.0000 2018-07-26 09:00:00+05:30    191.1000
# 149    186.8000        378.2000 2018-08-01 13:00:00+05:30    189.5000
# 150    203.6000          0.0000 2018-08-13 13:00:00+05:30    203.6000
# 151    208.3000          0.0000 2018-08-21 13:00:00+05:30    208.3000
# 152    208.8000          0.0000 2018-08-23 21:00:00+05:30    208.8000
# 153    205.0000          0.0000 2018-08-30 13:00:00+05:30    205.0000
# 154    205.5000          0.0000 2018-09-04 13:00:00+05:30    205.5000
# 155    204.3000          0.0000 2018-09-10 17:00:00+05:30    204.3000
# 156    199.0000        403.0000 2018-09-13 21:00:00+05:30    202.9000
# 157    223.2000          0.0000 2018-09-27 21:00:00+05:30    223.2000
# 158    240.3000          0.0000 2018-10-04 17:00:00+05:30    240.3000
# 159    199.1000        404.8000 2018-10-18 21:00:00+05:30    237.2000
# 160    250.3000          0.0000 2018-10-30 09:00:00+05:30    235.9000
# 161    241.5000          0.0000 2018-10-31 09:00:00+05:30    240.3000
# 162    242.9000          0.0000 2018-11-01 17:00:00+05:30    242.9000
# 163    295.2000          0.0000 2018-11-16 09:00:00+05:30    296.7000
# 164    341.8000          0.0000 2018-11-21 13:00:00+05:30    341.8000
# 165    318.5000          0.0000 2018-11-27 21:00:00+05:30    304.3000
# 166    327.7000          0.0000 2018-12-04 13:00:00+05:30    313.0000
# 167    326.7000          0.0000 2018-12-07 17:00:00+05:30    317.7000
# 168    252.0000        536.0000 2018-12-19 17:00:00+05:30    252.0000
# 169    233.9000        495.4000 2018-12-28 17:00:00+05:30    233.9000
# 170    204.0000        425.4000 2019-01-03 17:00:00+05:30    204.0000
# 171    335.4000          0.0000 2019-01-14 09:00:00+05:30    234.1000
# 172    202.4000        423.8000 2019-01-22 17:00:00+05:30    224.5000
# 173    212.7000        452.6000 2019-01-28 09:00:00+05:30    212.7000
# ...
# 12  -1.0845        2015    -1.0845
# 13   1.8811        2015     1.8811
# 14  -0.3252        2015    -0.3252
# 15   0.2839        2015     0.2839
# 16   0.0282        2015     0.0282
# 17   0.0896        2015     0.0896
# 18   0.2136        2015     0.2136
# 19  -0.3506        2015    -0.3506
# 20  -1.1870        2015    -1.1870
# 21  -1.1169        2015    -1.1169
# 22  -0.2279        2015    -0.2279
# 23  -1.0980        2015    -1.0980
# 24  -0.1192        2015    -0.1192
# 25  -1.0646        2015    -1.0646
# 26  -1.0742        2015    -1.0742
# 27  -1.0730        2015    -1.0730
# 28   4.1147        2015     4.1147
# 29  -1.0677        2016    -1.0677
# 30   5.6890        2015     5.6890
# 31   0.2938        2016     0.2938
# 32   1.8001        2016     1.8001
# 33  -1.0590        2016    -1.0590
# 34  -1.0673        2016    -1.0673
# 35  -1.0860        2016    -1.0860
# 36  -1.0508        2016    -1.0508
# 37  -1.0762        2016    -1.0762
# 38   1.3328        2016     1.3328
# 39  -1.0882        2016    -1.0882
# 40  -1.0839        2016    -1.0839
# 41  -0.4659        2016    -0.4659
# 42  -0.2790        2016    -0.2790
# 43  -0.3226        2016    -0.3226
# 44  -1.0556        2016    -1.0556
# 45  -1.6562        2016    -1.6562
# 46  -1.0599        2016    -1.0599
# 47  -0.2927        2016    -0.2927
# 48  -0.8539        2016    -0.8539
# 49  -1.1224        2016    -1.1224
# 50   0.0727        2016     0.0727
# 51  -1.1486        2016    -1.1486
# 52  -1.0790        2016    -1.0790
# 53  -1.1350        2016    -1.1350
# 54  -1.0626        2016    -1.0626
# 55  -1.1032        2016    -1.1032
# 56   0.7957        2016     0.7957
# 57  -1.0883        2016    -1.0883
# 58  -0.1460        2016    -0.1460
# 59   0.1030        2016     0.1030
# 60  -1.1367        2016    -1.1367
# 61   0.0473        2016     0.0473
# 62  -0.1918        2016    -0.1918
# 63  -1.1910        2016    -1.1910
# 64   1.3197        2016     1.3197
# 65  -1.1058        2016    -1.1058
# 66   1.7638        2016     1.7638
# 67   0.1040        2016     0.1040
# 68  -1.0459        2016    -1.0459
# 69   2.9240        2016     2.9240
# 70  -0.0013        2016    -0.0013
# 71  -1.0985        2016    -1.0985
# 72   1.8148        2016     1.8148
# 73  -1.0517        2016    -1.0517
# 74   0.1776        2016     0.1776
# 75  -1.0886        2016    -1.0886
# 76  -1.0912        2016    -1.0912
# 77  -1.0491        2016    -1.0491
# 78  -1.0575        2016    -1.0575
# 79  -1.0373        2016    -1.0373
# 80  -1.0469        2017    -1.0469
# 81   2.4891        2016     2.4891
# 82  -0.1584        2017    -0.1584
# 83  -1.0752        2017    -1.0752
# 84  -1.0764        2017    -1.0764
# 85  -1.0735        2017    -1.0735
# 86  -1.1377        2017    -1.1377
# 87  -1.2181        2017    -1.2181
# 88   2.1370        2017     2.1370
# 89   2.1057        2017     2.1057
# 90  -1.0835        2017    -1.0835
# 91  -1.0799        2017    -1.0799
# 92   0.7970        2017     0.7970
# 93   0.3883        2017     0.3883
# 94   1.1077        2017     1.1077
# 95  -1.0559        2017    -1.0559
# 96   2.8736        2017     2.8736
# 97  -0.4205        2017    -0.4205
# 98  -1.1703        2017    -1.1703
# 99  -1.1242        2017    -1.1242
# 100  0.7389        2017     0.7389
# 101 -1.1652        2017    -1.1652
# 102 -1.1224        2017    -1.1224
# 103 -1.1160        2017    -1.1160
# 104 -1.1915        2017    -1.1915
# 105  2.3985        2017     2.3985
# 106 -1.1313        2017    -1.1313
# 107  1.1716        2017     1.1716
# 108  2.0457        2017     2.0457
# 109  0.5714        2017     0.5714
# 110 -1.1065        2017    -1.1065
# 111  0.5226        2017     0.5226
# 112 -1.1493        2017    -1.1493
# 113 -1.1070        2017    -1.1070
# 114  1.8480        2017     1.8480
# 115 -1.1758        2017    -1.1758
# 116 -0.0647        2017    -0.0647
# 117  1.9159        2017     1.9159
# 118 -1.0859        2017    -1.0859
# 119 -1.0821        2017    -1.0821
# 120  0.5011        2017     0.5011
# 121 -1.1161        2018    -1.1161
# 122  1.2092        2018     1.2092
# 123 -1.0889        2018    -1.0889
# 124 -1.0494        2018    -1.0494
# 125 -0.3958        2018    -0.3958
# 126  5.4951        2018     5.4951
# 127 -0.7025        2018    -0.7025
# 128 -1.1003        2018    -1.1003
# 129  0.3369        2018     0.3369
# 130 -1.2054        2018    -1.2054
# 131 -0.8411        2018    -0.8411
# 132 -1.2237        2018    -1.2237
# 133 -1.1453        2018    -1.1453
# 134 -0.6321        2018    -0.6321
# 135  0.1273        2018     0.1273
# 136 -0.3733        2018    -0.3733
# 137  0.4770        2018     0.4770
# 138 -1.1611        2018    -1.1611
# 139 -1.1541        2018    -1.1541
# 140 -1.1672        2018    -1.1672
# 141  0.6250        2018     0.6250
# 142 -1.1733        2018    -1.1733
# 143  0.0454        2018     0.0454
# 144 -0.8896        2018    -0.8896
# 145 -1.2633        2018    -1.2633
# 146 -1.1806        2018    -1.1806
# 147 -1.1354        2018    -1.1354
# 148  4.5944        2018     4.5944
# 149  0.0093        2018     0.0093
# 150 -1.2252        2018    -1.2252
# 151 -1.1656        2018    -1.1656
# 152 -1.1806        2018    -1.1806
# 153 -1.2268        2018    -1.2268
# 154 -1.1512        2018    -1.1512
# 155 -1.1767        2018    -1.1767
# 156  0.3982        2018     0.3982
# 157 -1.1643        2018    -1.1643
# 158 -1.0576        2018    -1.0576
# 159 10.4122        2018    10.4122
# 160  0.4208        2018     0.4208
# 161 -0.9032        2018    -0.9032
# 162 -1.0943        2018    -1.0943
# 163 -1.1982        2018    -1.1982
# 164 -1.0254        2018    -1.0254
# 165 -0.5141        2018    -0.5141
# 166 -0.1311        2018    -0.1311
# 167 -0.4420        2018    -0.4420
# 168 -1.0325        2018    -1.0325
# 169 -1.0349        2018    -1.0349
# 170 -1.0479        2019    -1.0479
# 171  5.1431        2018     5.1431
# 172  1.2804        2019     1.2804
# 173 -1.0323        2019    -1.0323
# 174 -1.1081        2019    -1.1081
# 175 -1.1118        2019    -1.1118
# 176  2.9867        2019     2.9867
# 177  0.2136        2019     0.2136
# 178 -1.0689        2019    -1.0689
# 179  1.1188        2019     1.1188
# 180  0.6153        2019     0.6153
# 181 -1.1109        2019    -1.1109
# 182 -1.1631        2019    -1.1631
# 183  0.2360        2019     0.2360
# 184 -1.2681        2019    -1.2681
# 185 -1.1744        2019    -1.1744
# 186 -1.2036        2019    -1.2036
# 187 -0.4153        2019    -0.4153
# 188  1.4518        2019     1.4518
# 189  0.3677        2019     0.3677
# 190  0.8404        2019     0.8404
# 191 -1.0983        2019    -1.0983
# 192 -1.0769        2019    -1.0769
# 193  1.4529        2019     1.4529
# 194 -1.1387        2019    -1.1387
# 195  2.1767        2019     2.1767
# 196 -1.1225        2019    -1.1225
# 197 -0.1053        2019    -0.1053
# 198 -1.1094        2019    -1.1094
# 199 -1.0978        2019    -1.0978
# 200 -1.1048        2019    -1.1048
# 201 -1.0710        2019    -1.0710
# 202 -1.0983        2019    -1.0983
# 203  4.9562        2019     4.9562
# 204 -1.0715        2019    -1.0715
# 205 -1.0463        2019    -1.0463
# 206  7.2861        2019     7.2861
# 207  0.5750        2019     0.5750
# 208 -1.1032        2019    -1.1032
# 209 -1.0438        2019    -1.0438
# 210 -1.1360        2019    -1.1360
# 211 14.6586        2019    14.6586
# 212  1.9036        2019     1.9036
# 213 -1.0954        2019    -1.0954
# 214 -1.0865        2019    -1.0865
# 215  0.0530        2019     0.0530
# 216 -1.1053        2019    -1.1053
# 217  0.0172        2020     0.0172
# 218 -1.0663        2020    -1.0663
# 219 -1.1441        2020    -1.1441
# 220 -1.0859        2020    -1.0859
# 221 -1.0883        2020    -1.0883
# 222 -1.0648        2020    -1.0648
# 223 -1.1405        2020    -1.1405
# 224 -1.0912        2020    -1.0912
# 225  1.0221        2020     1.0221
# 226  0.4950        2020     0.4950
# 227 -1.0436        2020    -1.0436
# 228  1.2010        2020     1.2010
# 229  0.0096        2020     0.0096
# 230  0.6350        2020     0.6350
# 231  0.0092        2020     0.0092
# 232 -1.0876        2020    -1.0876
# 233  3.4600        2020     3.4600
# 234  0.2076        2020     0.2076
# 235  0.6289        2020     0.6289
# 236  0.1645        2020     0.1645
# 237 -1.0731        2020    -1.0731
# 238 -1.0842        2020    -1.0842
# 239 -0.1896        2020    -0.1896
# 240 -1.0662        2020    -1.0662
# 241  1.0866        2020     1.0866
# 242 -0.3383        2020    -0.3383
# 243 -1.0341        2020    -1.0341
# 244 -1.0461        2020    -1.0461
# 245 -1.0452        2020    -1.0452
# 246 -1.0614        2020    -1.0614
# 247  0.4965        2020     0.4965
# 248 -0.9961        2020    -0.9961
# 249 -1.0731        2020    -1.0731
# 250 -1.0594        2020    -1.0594
# 251 -1.0504        2020    -1.0504
# 252 -1.0597        2020    -1.0597
# 253 -1.0730        2020    -1.0730
# 254 -3.2418        2020    -3.2418
# 255 -1.1163        2020    -1.1163
# 256 13.1566        2020    13.1566
# 257 -1.0960        2020    -1.0960
# 258  5.2621        2020     5.2621
# 259  0.2746        2020     0.2746
# 260 -1.0546        2020    -1.0546
# 261 -0.0144        2020    -0.0144
# 262  1.2015        2020     1.2015
# 263 -1.0697        2021    -1.0697
# 264  0.2724        2021     0.2724
# 265  1.7865        2021     1.7865
# 266 -1.0486        2021    -1.0486
# 267 -1.0352        2021    -1.0352
# 268 -1.0615        2021    -1.0615
# 269 -1.1487        2021    -1.1487
# 270 -1.1072        2021    -1.1072
# 271  4.1180        2021     4.1180
# 272  0.1790        2021     0.1790
# 273 -0.8749        2021    -0.8749
# 274 -1.1286        2021    -1.1286
# 275 -1.1077        2021    -1.1077
# 276 -1.0978        2021    -1.0978
# 277  5.6737        2021     5.6737
# 278 -0.1731        2021    -0.1731
# 279 -1.1118        2021    -1.1118
# 280 -0.8988        2021    -0.8988
# 281  0.9898        2021     0.9898
# 282 -0.0929        2021    -0.0929
# 283 -1.1103        2021    -1.1103
# 284 -1.1129        2021    -1.1129
# 285 -1.0988        2021    -1.0988
# 286 -1.1150        2021    -1.1150
# 287 -1.0498        2021    -1.0498
# 288 -1.1296        2021    -1.1296
# 289 -0.6055        2021    -0.6055
# 290 -1.0514        2021    -1.0514
# 291  1.4143        2021     1.4143
# 292 -1.0446        2021    -1.0446
# 293 -1.0863        2021    -1.0863
# 294 12.4752        2021    12.4752
# 295  0.5569        2021     0.5569
# 296 -1.0187        2021    -1.0187
# 297 -0.4199        2021    -0.4199
# 298  1.7401        2021     1.7401
# 299  1.1906        2021     1.1906
# 300 -0.3574        2021    -0.3574
# 301 -1.0504        2021    -1.0504
# 302 -1.0540        2021    -1.0540
# 303 -1.0606        2021    -1.0606
# 304 -1.0496        2021    -1.0496
# 305 -1.0381        2021    -1.0381
# 306  0.4105        2021     0.4105
# 307  2.3826        2022     2.3826
# 308  0.5563        2022     0.5563
# 309 -1.0359        2022    -1.0359
# 310  2.0698        2022     2.0698
# 311  0.5475        2022     0.5475
# 312  2.0500        2022     2.0500
# 313 -1.0345        2022    -1.0345
# 314 -1.0359        2022    -1.0359
# 315  0.6299        2022     0.6299
# 316 -1.0476        2022    -1.0476
# 317 -1.0679        2022    -1.0679
# 318 -1.0567        2022    -1.0567
# 319 -1.0592        2022    -1.0592
# 320 -1.0366        2022    -1.0366
# 321  1.4356        2022     1.4356
# 322 -0.2391        2022    -0.2391
# 323  0.8193        2022     0.8193
# 324 -1.0350        2022    -1.0350
# 325 -1.0719        2022    -1.0719
# 326 -1.0526        2022    -1.0526
# 327  0.1291        2022     0.1291
# 328 -1.0575        2022    -1.0575
# 329 -0.3954        2022    -0.3954
# 330 -1.0307        2022    -1.0307
# 331 -1.1164        2022    -1.1164
# 332 -1.0413        2022    -1.0413
# 333  0.9631        2022     0.9631
# 334  4.2046        2022     4.2046
# 335  1.2349        2022     1.2349
# 336 -1.0449        2022    -1.0449
# 337 -1.0347        2022    -1.0347
# 338 -1.0255        2022    -1.0255
# 339  0.4684        2022     0.4684
# 340  1.0288        2022     1.0288
# 341 -1.0311        2022    -1.0311
# 342 -1.0441        2022    -1.0441
# 343 -1.0353        2022    -1.0353
# 344 -1.0454        2022    -1.0454
# 345  1.6187        2022     1.6187
# 346 -0.5643        2022    -0.5643
# 347 -1.0505        2022    -1.0505
# 348 -1.0412        2022    -1.0412
# 349 -1.0480        2022    -1.0480
# 350  0.4297        2022     0.4297
# 351  2.1698        2022     2.1698
# 352 -1.0429        2022    -1.0429
# 353 -1.1186        2022    -1.1186
# 354 -1.0334        2022    -1.0334
# 355 -1.0216        2023    -1.0216
# 356 -1.0380        2023    -1.0380
# 357 -1.0552        2023    -1.0552
# 358 -1.0434        2023    -1.0434
# 359 -1.0648        2023    -1.0648
# 360 12.8220        2022    12.8220
# 361 -1.0375        2023    -1.0375
# 362  1.3935        2023     1.3935
# 363  0.0062        2023     0.0062
# 364 -1.0338        2023    -1.0338
# 365 -1.0369        2023    -1.0369
# 366  3.1947        2023     3.1947
# 367 -1.0451        2023    -1.0451
# 368 -0.7469        2023    -0.7469
# 369 -0.2055        2023    -0.2055
# 370 -1.0563        2023    -1.0563
# 371  0.2200        2023     0.2200
# 372 -1.0396        2023    -1.0396
# 373  1.6524        2023     1.6524
# 374  0.6556        2023     0.6556
# 375  0.6679        2023     0.6679
# 376  0.5901        2023     0.5901
# 377 -1.0953        2023    -1.0953
# 378 -1.0566        2023    -1.0566
# 379 -1.0536        2023    -1.0536
# 380 -1.0759        2023    -1.0759
# 381 -1.0730        2023    -1.0730
# 382 -1.0554        2023    -1.0554
# 383 -0.2120        2023    -0.2120
# 384  0.5828        2023     0.5828
# 385  0.3996        2023     0.3996
# 386  0.0119        2023     0.0119
# 387  0.8242        2023     0.8242
# 388 -1.0700        2023    -1.0700
# 389  0.3265        2023     0.3265
# 390  1.2619        2023     1.2619
# 391  0.8303        2023     0.8303
# 392  0.3518        2023     0.3518
# 393 -1.1119        2023    -1.1119
# 394 -2.5973        2023    -2.5973
# 395 -1.0561        2023    -1.0561
# 396  1.5583        2023     1.5583
# 397 -1.1216        2023    -1.1216
# 398 -1.0555        2023    -1.0555
# 399  3.7879        2023     3.7879
# 400 -1.0768        2023    -1.0768
# 401 -1.0647        2023    -1.0647
# 402 -1.0553        2023    -1.0553
# 403  4.2408        2023     4.2408
# 404  0.8164        2023     0.8164
# 405 -1.0332        2023    -1.0332
# 406 -1.0513        2024    -1.0513
# 407 -1.0385        2024    -1.0385
# 408  2.1424        2023     2.1424
# 409  0.8500        2024     0.8500
# 410 -3.0104        2024    -3.0104
# 411 -1.0659        2024    -1.0659
# 412  6.2475        2024     6.2475
# 413  1.0134        2024     1.0134
# 414 -1.1077        2024    -1.1077
# 415  1.1655        2024     1.1655
# 416 -0.5552        2024    -0.5552
# 417 -1.0342        2024    -1.0342
# 418 -1.0432        2024    -1.0432
# 419 -1.0653        2024    -1.0653
# 420 -1.0775        2024    -1.0775
# 421 -1.0352        2024    -1.0352
# 422 -1.0467        2024    -1.0467
# 423 -1.0325        2024    -1.0325
# 424 -1.0452        2024    -1.0452
# 425  1.0703        2024     1.0703
# 426 -1.1097        2024    -1.1097
# 427 -1.0578        2024    -1.0578
# 428 -1.0567        2024    -1.0567
# 429 -1.0449        2024    -1.0449
# 430 -1.0465        2024    -1.0465
# 431 11.4081        2024    11.4081
# 432 -1.0697        2024    -1.0697
# 433 -1.0475        2024    -1.0475
# 434 -1.0623        2024    -1.0623
# 435 -0.9012        2024    -0.9012
# 436  0.3999        2024     0.3999
# 437 -1.1315        2024    -1.1315
# 438 -1.0487        2024    -1.0487
# 439 -1.3868        2024    -1.3868
# 440 -1.0955        2024    -1.0955
# 441 -1.0708        2024    -1.0708
# 442 -1.0524        2024    -1.0524
# 443  4.7670        2024     4.7670

# %%
# tb_pandas.to_csv('Check KQ.csv', index=False)

# %%
# async def positional(df):

#     in_trade = False
#     tradebook = []
#     remark = ''
#     points = 0
#     entry_price = None
#     exit_price = None
#     initial_sl = None
#     # stoploss = None
#     is_trailing_active = False

#     for i in range(3, len(df)):
#         # SHORT Variation
    
#         if (not in_trade) and (df.iloc[i]['low'] < df.iloc[i-1]['low']) and (df.iloc[i-1]['sell_signal'] == True):
#             #Entry Triggered
#             if df.iloc[i]['open'] < df.iloc[i-1]['low']:
#                 if df.iloc[i]['high'] >= df.iloc[i-1]['low']:
#                     in_trade = True
#                     entry_price = df.iloc[i-1]['low']
#                     entry_time = df.iloc[i]['datetime']
#                     signal_time = df.iloc[i-1]['datetime']
#                     initial_sl = max(df.iloc[i-1]['high'], df.iloc[i-2]['high'], df.iloc[i-3]['high'])
#                     # stoploss = max(df.iloc[i-1]['high'], df.iloc[i-2]['high'], df.iloc[i-3]['high'])

#         if in_trade:
#             trade_entry_price = entry_price
#             trade_initial_sl = initial_sl
#             trade_final_sl = initial_sl

#             if (
#                 not is_trailing_active
#                 and df.iloc[i]['high'] < df.iloc[i]['ma']
#             ):
#                 is_trailing_active = True
            
#             if not is_trailing_active:
#                 if df.iloc[i]['open'] > trade_initial_sl:
#                     if (
#                         df.iloc[i]["datetime"].date() == entry_time.date()
#                         and df.iloc[i]["datetime"].time() == entry_time.time()
#                     ):
#                         if df.iloc[i]['close'] >= trade_initial_sl:
#                             in_trade = False
#                             points = trade_entry_price - trade_initial_sl
#                             exit_price = trade_initial_sl
#                             exit_time = df.iloc[i]["datetime"]
#                             remark = "Initial SL hit"

#                     else:
#                         # Gap Open Outside ISL
                        
#                         in_trade = False
#                         points = trade_entry_price - df.iloc[i]['open']
#                         exit_price = df.iloc[i]['open']
#                         exit_time = df.iloc[i]["datetime"]
#                         remark = "Gap Open Outside ISL"

#                 elif df.iloc[i]['high'] >= trade_initial_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = trade_entry_price - trade_initial_sl
#                     exit_price = trade_initial_sl
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "Initial SL Hit"

#             else:
#                 trade_final_sl = min(trade_initial_sl, df.iloc[i]['ma'])
#                 if df.iloc[i]['open'] > trade_initial_sl:
#                     if (
#                         df.iloc[i]["datetime"].date() == entry_time.date()
#                         and df.iloc[i]["datetime"].time() == entry_time.time()
#                     ):
#                         if df.iloc[i]['close'] >= trade_initial_sl:
#                             in_trade = False
#                             points = trade_entry_price - trade_initial_sl
#                             exit_price = trade_initial_sl
#                             exit_time = df.iloc[i]["datetime"]
#                             remark = "Initial SL hit"

#                     else:
#                         # Gap Open Outside ISL
                        
#                         in_trade = False
#                         points = trade_entry_price - df.iloc[i]['open']
#                         exit_price = df.iloc[i]['open']
#                         exit_time = df.iloc[i]["datetime"]
#                         remark = "Gap Open Outside ISL"

#                 elif df.iloc[i]['high'] >= trade_initial_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = trade_entry_price - trade_initial_sl
#                     exit_price = trade_initial_sl
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "Initial SL Hit"

#                 elif df.iloc[i]['close'] >= trade_final_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = trade_entry_price - df.iloc[i]['close']
#                     exit_price = df.iloc[i]['close']
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "TSL Hit"
    
#         if points:
#             slippage = SLIPPAGE_ * (entry_price + exit_price)
#             final_points = points - slippage
#             # sl_in_points = abs(entry_price - initial_sl)
#             qty = PORTFOLIO_VALUE * LEVERAGE_ / entry_price
#             trade = {
#                 'Signal Time': signal_time,
#                 'Trade Type': 'SHORT',
#                 'Entry Date': entry_time.date(),
#                 'Entry Time': entry_time.time(),
#                 'Entry Price': entry_price,
#                 'Initial SL': trade_initial_sl,
#                 'Final SL': trade_final_sl,
#                 'Exit Date': exit_time.date(),
#                 'Exit Time': exit_time.time(),
#                 'Exit Price': exit_price,
#                 'Points Captured': points,
#                 'After Costs': final_points,
#                 'Remarks': remark,
#                 'Qty': qty,
#                 'ROI%': (points * qty / PORTFOLIO_VALUE) * 100,
#                 'ROI% w cs': (final_points * qty / PORTFOLIO_VALUE) * 100,
#                 'Trade Year': entry_time.year,
#             }
#             # print(trade)
#             tradebook.append(trade)
#             points = 0
#             in_trade = False
#             remark = ''
#             entry_price = None
#             exit_price = None
#             initial_sl = None
#             # stoploss = None
#             is_trailing_active = False

#     for i in range(3, len(df)):
#         # LONG Variation
        
#         if (not in_trade) and (df.iloc[i]['high'] >= df.iloc[i-1]['high']) and (df.iloc[i-1]['buy_signal'] == True):
#             #Entry Triggered
#             if df.iloc[i]['open'] > df.iloc[i-1]['high']:
#                 if df.iloc[i]['low'] <= df.iloc[i-1]['high']:
#                     in_trade = True
#                     entry_price = df.iloc[i-1]['high']
#                     entry_time = df.iloc[i]['datetime']
#                     signal_time = df.iloc[i-1]['datetime']
#                     initial_sl = min(df.iloc[i-1]['low'], df.iloc[i-2]['low'], df.iloc[i-3]['low'])
#                     # stoploss = max(df.iloc[i-1]['low'], df.iloc[i-2]['low'], df.iloc[i-3]['low'])

#         if in_trade:
#             trade_entry_price = entry_price
#             trade_initial_sl = initial_sl
#             trade_final_sl = initial_sl

#             if (
#                 not is_trailing_active
#                 and df.iloc[i]['low'] > df.iloc[i]['ma']
#             ):
#                 is_trailing_active = True
            
#             if not is_trailing_active:
#                 if df.iloc[i]['open'] < trade_initial_sl:
#                     if (
#                         df.iloc[i]["datetime"].date() == entry_time.date()
#                         and df.iloc[i]["datetime"].time() == entry_time.time()
#                     ):
#                         if df.iloc[i]['close'] <= trade_initial_sl:
#                             in_trade = False
#                             points = trade_initial_sl - trade_entry_price
#                             exit_price = trade_initial_sl
#                             exit_time = df.iloc[i]["datetime"]
#                             remark = "Initial SL hit"

#                     else:
#                         # Gap Open Outside ISL
                        
#                         in_trade = False
#                         points = df.iloc[i]['open'] - trade_entry_price
#                         exit_price = df.iloc[i]['open']
#                         exit_time = df.iloc[i]["datetime"]
#                         remark = "Gap Open Outside ISL"

#                 elif df.iloc[i]['low'] <= trade_initial_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = trade_initial_sl - trade_entry_price
#                     exit_price = trade_initial_sl
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "Initial SL Hit"

#             else:
#                 trade_final_sl = max(trade_initial_sl, df.iloc[i]['ma'])
#                 if df.iloc[i]['open'] < trade_initial_sl:
#                     if (
#                         df.iloc[i]["datetime"].date() == entry_time.date()
#                         and df.iloc[i]["datetime"].time() == entry_time.time()
#                     ):
#                         if df.iloc[i]['close'] <= trade_initial_sl:
#                             in_trade = False
#                             points = trade_initial_sl - trade_entry_price
#                             exit_price = trade_initial_sl
#                             exit_time = df.iloc[i]["datetime"]
#                             remark = "Initial SL hit"

#                     else:
#                         # Gap Open Outside ISL
                        
#                         in_trade = False
#                         points = df.iloc[i]['open'] - trade_entry_price
#                         exit_price = df.iloc[i]['open']
#                         exit_time = df.iloc[i]["datetime"]
#                         remark = "Gap Open Outside ISL"

#                 elif df.iloc[i]['low'] <= trade_initial_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = trade_initial_sl - trade_entry_price
#                     exit_price = trade_initial_sl
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "Initial SL Hit"

#                 elif df.iloc[i]['close'] <= trade_final_sl:
#                     # Initial SL Hit

#                     in_trade = False
#                     points = df.iloc[i]['close'] - trade_entry_price
#                     exit_price = df.iloc[i]['close']
#                     exit_time = df.iloc[i]["datetime"]
#                     remark = "TSL Hit"    

#         if points:
#             slippage = SLIPPAGE_ * (entry_price + exit_price)
#             final_points = points - slippage
#             # sl_in_points = abs(entry_price - initial_sl)
#             qty = PORTFOLIO_VALUE * LEVERAGE_ / entry_price
#             trade = {
#                 'Signal Time': signal_time,
#                 'Trade Type': 'LONG',
#                 'Entry Date': entry_time.date(),
#                 'Entry Time': entry_time.time(),
#                 'Entry Price': entry_price,
#                 'Initial SL': trade_initial_sl,
#                 'Final SL': trade_final_sl,
#                 'Exit Date': exit_time.date(),
#                 'Exit Time': exit_time.time(),
#                 'Exit Price': exit_price,
#                 'Points Captured': points,
#                 'After Costs': final_points,
#                 'Remarks': remark,
#                 'Qty': qty,
#                 'ROI%': (points * qty / PORTFOLIO_VALUE) * 100,
#                 'ROI% w cs': (final_points * qty / PORTFOLIO_VALUE) * 100,
#                 'Trade Year': entry_time.year,
#             }
#             # print(trade)
#             tradebook.append(trade)
#             points = 0
#             in_trade = False
#             remark = ''
#             entry_price = None
#             exit_price = None
#             initial_sl = None
#             # stoploss = None
#             is_trailing_active = False

#     return pd.DataFrame(tradebook)

# %%
# async def trade(spot_data, index, tf):

#     if index == "bnf":
#         SPREAD = 100
#         index_full = "BANKNIFTY"
#     elif index == "nifty":
#         SPREAD = 50
#         index_full = "NIFTY"

#     start_date = dt.date(2017, 1, 1)
#     end_date = dt.date(2024, 3, 31)

#     flag = False

#     current_date = start_date

#     final_tb = pd.DataFrame()
#     tradebook = []

#     while current_date <= end_date:
#         # print(current_date)

#         if current_date.weekday() >= 5:
#             print("Skipping Weekend ! ", current_date)
#             current_date += dt.timedelta(days=1)
#             continue
#         elif current_date not in list_of_traded_dates:
#             print("Date Avoided ! ", current_date)
#             current_date += dt.timedelta(days=1)
#             continue
#         # elif current_date in list_of_dates_to_avoid_bnf:
#         #     # print('Date Avoided ! ', current_date)
#         #     current_date += dt.timedelta(days=1)
#         #     continue
#         else:
#             print("Working", current_date)
#             spot = spot_data[spot_data["datetime"].dt.date == current_date]
#             spot_open = spot.iloc[0]["open"]
#             # print(spot_open)
#             atm = int(round(spot_open / SPREAD) * SPREAD)
#             # print(atm)

#             current_expiry = await get_expiry(current_date, index)
#             dte = current_expiry - current_date

#             ce_df = await fetch_option_data(
#                 index=index,
#                 start_date=current_date,
#                 end_date=current_date,
#                 start_time=dt.time(9, 15),
#                 end_time=dt.time(15, 30),
#                 expiry=current_expiry,
#                 strike=atm,
#                 asset_class="C",
#             )
#             if not isinstance(ce_df, pl.DataFrame):
#                 print('Data Not Found for Options')
#                 current_date += dt.timedelta(days=1)
#                 continue
#             # print(ce_df.head())
#             ce_df = rename_ohlc_columns(ce_df)
#             # ce_5min = resample(ce_df, "5m")
#             ce_df = resample(ce_df, tf)
#             # call_option = ce_5min.to_pandas()
#             call_option = ce_df.to_pandas()

#             pe_df = await fetch_option_data(
#                 index=index,
#                 start_date=current_date,
#                 end_date=current_date,
#                 start_time=dt.time(9, 15),
#                 end_time=dt.time(15, 30),
#                 expiry=current_expiry,
#                 strike=atm,
#                 asset_class="P",
#             )
#             if not isinstance(pe_df, pl.DataFrame):
#                 print('Data Not Found for Options')
#                 current_date += dt.timedelta(days=1)
#                 continue
#             # print(pe_df.head())
#             pe_df = rename_ohlc_columns(pe_df)
#             # pe_5min = resample(pe_df, "5m")
#             pe_df = resample(pe_df, tf)
#             # put_option = pe_5min.to_pandas()
#             put_option = pe_df.to_pandas()

#             # call_option['datetime'] = pd.to_datetime(call_option['datetime'])
#             # put_option['datetime'] = pd.to_datetime(put_option['datetime'])

#             ce_df = await create_sell_signals(call_option)
#             pe_df = await create_sell_signals(put_option)

#             # print(ce_df.head())
#             # print(pe_df.head())

#             ce_contract = await get_option_contract_name(
#                 symbol=index_full,
#                 strike=atm,
#                 expiry=current_expiry,
#                 opt_type='CE'
#             )

#             pe_contract = await get_option_contract_name(
#                 symbol=index_full,
#                 strike=atm,
#                 expiry=current_expiry,
#                 opt_type='PE'
#             )

#             ce_trades = await option_trading(ce_df, ce_contract, atm, current_expiry)
#             pe_trades = await option_trading(pe_df, pe_contract, atm, current_expiry)

#             final_tb = pd.concat([final_tb, ce_trades, pe_trades], ignore_index=True)

#         current_date += dt.timedelta(days=1)

#     return final_tb

# %%
# async def trade_positional(spot_data, index, tf, offset, ma):

#     if index == "bnf":
#         SPREAD = 100
#         index_full = "BANKNIFTY"
#     elif index == "nifty":
#         SPREAD = 50
#         index_full = "NIFTY"

#     start_date = dt.date(2017, 1, 1)
#     end_date = dt.date(2024, 3, 31)

#     flag = False

#     current_date = start_date

#     final_tb = pd.DataFrame()
#     tradebook = []

#     # while current_date <= end_date:
#         # print(current_date)

#     # if current_date.weekday() >= 5:
#     #     print("Skipping Weekend ! ", current_date)
#     #     current_date += dt.timedelta(days=1)
#     #     continue
#     # elif current_date not in list_of_traded_dates:
#     #     print("Date Avoided ! ", current_date)
#     #     current_date += dt.timedelta(days=1)
#     #     continue
#     # # elif current_date in list_of_dates_to_avoid_bnf:
#     # #     # print('Date Avoided ! ', current_date)
#     # #     current_date += dt.timedelta(days=1)
#     # #     continue
#     # else:
#     #     print("Working", current_date)
#     data = resample(spot_data, tf, offset)
#     data_pandas = data.to_pandas()
#     data_pandas = await create_buy_signals(data_pandas)
#     data_pandas = await create_sell_signals(data_pandas)
#     data_pandas = await create_ma(data_pandas, ma)
#     # print(data.head(50))
#     # break
#     tb = await positional(data_pandas)
#     final_tb = pd.concat([tb, final_tb])

#         # current_date += dt.timedelta(days=1)

#     return final_tb

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2017, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2017, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI% w cs"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI% w cs"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI% w cs"] > 0]["ROI% w cs"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI% w cs"] < 0]["ROI% w cs"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI% w cs"].cumsum() - year_trades["ROI% w cs"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI% w cs"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI% w cs"] > 0]["ROI% w cs"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI% w cs"] < 0]["ROI% w cs"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI% w cs"].cumsum() - combined_df_sorted["ROI% w cs"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation

    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    
    # print(f'{overall_total_roi} , {overall_max_drawdown} , {overall_roi_dd_ratio}')
    
    return {overall_roi_dd_ratio: stats_df8}

# %%
stats = generate_stats(tb_pandas, '...')
lol = pd.DataFrame()
for x, y in stats.items():
    lol = pd.DataFrame(y)

lol
# Out:
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2017      -4.0952           40  37.5000                1.4082
# 2018      -7.4285           50  26.0000                2.2534
# 2019      11.7574           46  36.9565                2.4808
# 2020      -1.2571           46  36.9565                1.7252
# 2021       0.3979           44  27.2727                2.5673
# 2022       4.9859           49  36.7347                1.9756
# 2023      -5.7737           51  41.1765                1.2150
# 2024      -5.4692           37  21.6216                3.3652
# Overall   -6.8825          363  33.5586                1.8886
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio Variation
# 2017                -1.0087      -6.5712      -0.6232       ...
# 2018                -0.9925     -19.0829      -0.3893       ...
# 2019                -1.0488      -9.8329       1.1957       ...
# 2020                -1.0547     -19.0040      -0.0662       ...
# 2021                -0.9503     -10.2765       0.0387       ...
# 2022                -0.9863     -14.4063       0.3461       ...
# 2023                -1.0430     -11.5096      -0.5016       ...
# 2024                -1.1169     -13.1803      -0.4150       ...
# Overall             -1.0050     -41.0946      -0.1675       ...

# %%
# tfs = ['15m', '30m', '60m', '1d']
# for i in range(5, 81, 5):
#     for tf in tfs:
#         if tf == '30m' or tf == '60m':
#             ofs = '15m'
#         else:
#             ofs = '0m'
#         variation = f'TF : {tf} , TMA : {i}'
#         print(variation)
#         x = await trade_positional(pl.DataFrame(bnf_1min), 'bnf', tf, ofs, i)
#         x['Entry Datetime'] = x.apply(lambda row: pd.to_datetime(f"{row['Entry Date']} {row['Entry Time']}"), axis=1)
#         x = x.sort_values(by='Entry Datetime')
#         stats = generate_stats(x, variation)
# # x

# %%
# x['Entry Datetime'] = x.apply(lambda row: pd.to_datetime(f"{row['Entry Date']} {row['Entry Time']}"), axis=1)
# x = x.sort_values(by='Entry Datetime')

# %%
# roi = x['ROI%'].sum()
# roi_w_cs = x['ROI% w cs'].sum()
# roi, roi_w_cs

# %%
# x = await trade_positional(pl.DataFrame(bnf_1min), 'bnf', '30m', '15m', 10)
# x['Entry Datetime'] = x.apply(lambda row: pd.to_datetime(f"{row['Entry Date']} {row['Entry Time']}"), axis=1)
# x = x.sort_values(by='Entry Datetime')
# stats = generate_stats(x, variation)

# %%
# for a, b in stats.items():
#     print(a)
#     print(b.to_string())

# %%
# x.tail()

# %%
# x['Slippage in Points'] = x.apply(lambda row: 0.25 / 100 * (row['Entry Price'] + row['Exit Price']), axis=1)

# %%
# x['Final Points'] = x.apply(lambda row: row['Points Captured'] - row['Slippage in Points'])
# x['PnL w cs'] = x.apply(lambda row: row['Final Points'] * row['Qty'])
# x['ROI% w cs'] = x.aply(lambda row: row['PnL w cs'] * 100 / 1000000)

# %%
# x
