# %%
import asyncio
import datetime as dt
import math
from typing import Literal

import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

# %%
import sys

sys.path.append("..")
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
async def get_expiry(f_today, index):

    if index == 'bnf':    
        if (f_today <= dt.date(2024, 1, 25)) and (f_today >= dt.date(2024, 1, 18)):
            f_expiry = dt.date(2024, 1, 25)
        elif (f_today <= dt.date(2024, 1, 31)) and (f_today >= dt.date(2024, 1, 26)):
            f_expiry = dt.date(2024, 1, 31)
        elif (f_today <= dt.date(2024, 2, 22)) and (f_today >= dt.date(2024, 2, 29)):
            f_expiry = dt.date(2024, 2, 29)
        elif (f_today <= dt.date(2024, 3, 25)) and (f_today >= dt.date(2024, 3, 27)):
            f_expiry = dt.date(2024, 2, 27)
        elif f_today < dt.date(2023, 9, 1):
            days_to_thursday = (3 - f_today.weekday()) % 7
            nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
            f_expiry = nearest_thursday
            if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
                f_expiry = nearest_thursday - dt.timedelta(days=1)
        elif f_today >= dt.date(2023, 9, 1):
            if f_today.day < 24:
                days_to_wednesday = (2 - f_today.weekday()) % 7
                nearest_wednesday = f_today + dt.timedelta(days=days_to_wednesday)
                f_expiry = nearest_wednesday
                if nse.valid_days(
                    start_date=nearest_wednesday, end_date=nearest_wednesday
                ).empty:
                    f_expiry = nearest_wednesday - dt.timedelta(days=1)
            else:
                days_to_thursday = (3 - f_today.weekday()) % 7
                nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
                f_expiry = nearest_thursday
                if nse.valid_days(
                    start_date=nearest_thursday, end_date=nearest_thursday
                ).empty:
                    f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'nifty':
        days_to_thursday = (3 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'finnifty' or index == 'fnf':
        days_to_thursday = (1 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'midcpnifty' or index == 'midcp':
        days_to_thursday = (0 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

async def get_expiry_nifty(f_today):

    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry


async def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"


def get_option_contract_name2(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"

# %%
bnf_1min = pd.read_csv("../data/ng_4h.csv")
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["time"])
bnf_1min = bnf_1min[bnf_1min["datetime"].dt.year >= 2012]

# %%
bnf_1min.head()
# Out:
#                         time     open     high      low    close  \
# 0  2015-03-02T09:00:00+05:30 169.0000 169.0000 167.8000 168.3000
# 1  2015-03-02T13:00:00+05:30 168.3000 168.8000 167.8000 168.4000
# 2  2015-03-02T17:00:00+05:30 168.3000 171.7000 168.2000 170.9000
# 3  2015-03-02T21:00:00+05:30 170.9000 171.7000 167.9000 169.1000
# 4  2015-03-03T09:00:00+05:30 168.8000 168.8000 166.1000 166.6000
#
#                    datetime
# 0 2015-03-02 09:00:00+05:30
# 1 2015-03-02 13:00:00+05:30
# 2 2015-03-02 17:00:00+05:30
# 3 2015-03-02 21:00:00+05:30
# 4 2015-03-03 09:00:00+05:30

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("open").first().alias("open"),
                pl.col("high").max().alias("high"),
                pl.col("low").min().alias("low"),
                pl.col("close").last().alias("close"),
                pl.col("volume").sum().alias("volume"),
            ]
        )
    )


# ohlc_resampled = resample(pl.DataFrame(bnf_1min), '7d', pd.Timedelta(days=4))
# ohlc_resampled

# %%
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["datetime"])
list_of_traded_dates = set(bnf_1min["datetime"].dt.date)
list_of_traded_dates
# Out:
# {datetime.date(2017, 4, 11),
#  datetime.date(2023, 8, 24),
#  datetime.date(2017, 2, 2),
#  datetime.date(2022, 6, 2),
#  datetime.date(2015, 10, 23),
#  datetime.date(2017, 8, 17),
#  datetime.date(2016, 8, 2),
#  datetime.date(2022, 8, 10),
#  datetime.date(2021, 3, 17),
#  datetime.date(2020, 3, 27),
#  datetime.date(2024, 4, 11),
#  datetime.date(2019, 11, 14),
#  datetime.date(2023, 7, 28),
#  datetime.date(2018, 7, 18),
#  datetime.date(2024, 6, 10),
#  datetime.date(2024, 6, 18),
#  datetime.date(2022, 9, 22),
#  datetime.date(2024, 8, 30),
#  datetime.date(2016, 10, 28),
#  datetime.date(2019, 2, 27),
#  datetime.date(2021, 3, 12),
#  datetime.date(2017, 10, 27),
#  datetime.date(2021, 4, 20),
#  datetime.date(2018, 4, 4),
#  datetime.date(2018, 3, 29),
#  datetime.date(2021, 4, 14),
#  datetime.date(2021, 4, 21),
#  datetime.date(2022, 5, 4),
#  datetime.date(2020, 10, 1),
#  datetime.date(2019, 12, 4),
#  datetime.date(2020, 12, 14),
#  datetime.date(2023, 10, 9),
#  datetime.date(2018, 10, 1),
#  datetime.date(2018, 10, 8),
#  datetime.date(2021, 4, 9),
#  datetime.date(2023, 4, 26),
#  datetime.date(2019, 12, 18),
#  datetime.date(2023, 7, 6),
#  datetime.date(2015, 5, 7),
#  datetime.date(2021, 11, 19),
#  datetime.date(2024, 4, 2),
#  datetime.date(2016, 9, 27),
#  datetime.date(2020, 5, 22),
#  datetime.date(2020, 7, 29),
#  datetime.date(2021, 11, 18),
#  datetime.date(2019, 6, 24),
#  datetime.date(2019, 10, 23),
#  datetime.date(2022, 6, 30),
#  datetime.date(2023, 4, 19),
#  datetime.date(2023, 4, 28),
#  datetime.date(2021, 12, 21),
#  datetime.date(2021, 8, 12),
#  datetime.date(2022, 2, 14),
#  datetime.date(2022, 4, 20),
#  datetime.date(2020, 5, 20),
#  datetime.date(2018, 11, 12),
#  datetime.date(2021, 5, 17),
#  datetime.date(2017, 10, 11),
#  datetime.date(2022, 7, 6),
#  datetime.date(2019, 3, 14),
#  datetime.date(2018, 7, 24),
#  datetime.date(2020, 6, 11),
#  datetime.date(2024, 2, 19),
#  datetime.date(2018, 4, 24),
#  datetime.date(2023, 2, 17),
#  datetime.date(2023, 2, 24),
#  datetime.date(2022, 12, 30),
#  datetime.date(2016, 9, 20),
#  datetime.date(2019, 6, 19),
#  datetime.date(2016, 6, 1),
#  datetime.date(2017, 1, 12),
#  datetime.date(2024, 1, 1),
#  datetime.date(2016, 7, 27),
#  datetime.date(2023, 4, 21),
#  datetime.date(2016, 8, 19),
#  datetime.date(2020, 1, 7),
#  datetime.date(2018, 11, 2),
#  datetime.date(2015, 10, 27),
#  datetime.date(2018, 12, 19),
#  datetime.date(2019, 8, 2),
#  datetime.date(2019, 3, 26),
#  datetime.date(2015, 9, 23),
#  datetime.date(2021, 5, 14),
#  datetime.date(2015, 4, 15),
#  datetime.date(2019, 4, 4),
#  datetime.date(2015, 10, 5),
#  datetime.date(2016, 9, 29),
#  datetime.date(2015, 6, 17),
#  datetime.date(2024, 9, 2),
#  datetime.date(2016, 7, 22),
#  datetime.date(2019, 9, 17),
#  datetime.date(2015, 8, 11),
#  datetime.date(2022, 9, 6),
#  datetime.date(2018, 2, 8),
#  datetime.date(2024, 7, 12),
#  datetime.date(2021, 6, 14),
#  datetime.date(2016, 10, 24),
#  datetime.date(2017, 11, 24),
#  datetime.date(2015, 3, 10),
#  datetime.date(2018, 7, 23),
#  datetime.date(2022, 3, 25),
#  datetime.date(2017, 5, 31),
#  datetime.date(2017, 2, 20),
#  datetime.date(2015, 12, 1),
#  datetime.date(2015, 7, 1),
#  datetime.date(2015, 6, 12),
#  datetime.date(2016, 12, 26),
#  datetime.date(2019, 6, 10),
#  datetime.date(2024, 4, 22),
#  datetime.date(2017, 6, 15),
#  datetime.date(2019, 8, 30),
#  datetime.date(2022, 9, 21),
#  datetime.date(2024, 6, 4),
#  datetime.date(2018, 6, 4),
#  datetime.date(2024, 8, 12),
#  datetime.date(2023, 4, 6),
#  datetime.date(2020, 5, 19),
#  datetime.date(2017, 8, 18),
#  datetime.date(2016, 10, 19),
#  datetime.date(2020, 10, 14),
#  datetime.date(2021, 3, 29),
#  datetime.date(2016, 2, 19),
#  datetime.date(2021, 9, 6),
#  datetime.date(2016, 7, 20),
#  datetime.date(2019, 2, 13),
#  datetime.date(2024, 10, 8),
#  datetime.date(2021, 3, 18),
#  datetime.date(2016, 6, 13),
#  datetime.date(2023, 6, 15),
#  datetime.date(2019, 3, 13),
#  datetime.date(2016, 12, 7),
#  datetime.date(2020, 4, 9),
#  datetime.date(2018, 7, 31),
#  datetime.date(2022, 3, 24),
#  datetime.date(2022, 3, 29),
#  datetime.date(2020, 3, 16),
#  datetime.date(2022, 8, 2),
#  datetime.date(2019, 8, 1),
#  datetime.date(2020, 10, 7),
#  datetime.date(2023, 9, 6),
#  datetime.date(2017, 2, 21),
#  datetime.date(2023, 3, 14),
#  datetime.date(2022, 3, 21),
#  datetime.date(2022, 4, 8),
#  datetime.date(2022, 10, 26),
#  datetime.date(2024, 2, 12),
#  datetime.date(2016, 9, 5),
#  datetime.date(2018, 8, 28),
#  datetime.date(2015, 5, 26),
#  datetime.date(2017, 9, 20),
#  datetime.date(2023, 11, 2),
#  datetime.date(2016, 8, 8),
#  datetime.date(2022, 6, 14),
#  datetime.date(2022, 10, 3),
#  datetime.date(2024, 6, 26),
#  datetime.date(2022, 4, 6),
#  datetime.date(2017, 11, 27),
#  datetime.date(2024, 6, 5),
#  datetime.date(2019, 5, 29),
#  datetime.date(2018, 9, 10),
#  datetime.date(2021, 5, 3),
#  datetime.date(2016, 7, 19),
#  datetime.date(2023, 3, 3),
#  datetime.date(2023, 11, 16),
#  datetime.date(2020, 2, 21),
#  datetime.date(2024, 9, 26),
#  datetime.date(2018, 11, 8),
#  datetime.date(2015, 5, 19),
#  datetime.date(2019, 7, 30),
#  datetime.date(2021, 9, 22),
#  datetime.date(2015, 7, 7),
#  datetime.date(2016, 11, 2),
#  datetime.date(2019, 5, 22),
#  datetime.date(2020, 10, 22),
#  datetime.date(2023, 7, 18),
#  datetime.date(2017, 9, 8),
#  datetime.date(2019, 9, 6),
#  datetime.date(2024, 3, 21),
#  datetime.date(2019, 4, 15),
#  datetime.date(2020, 12, 9),
#  datetime.date(2021, 7, 12),
#  datetime.date(2024, 9, 25),
#  datetime.date(2021, 11, 12),
#  datetime.date(2024, 3, 1),
#  datetime.date(2015, 11, 25),
#  datetime.date(2021, 10, 4),
#  datetime.date(2023, 1, 2),
#  datetime.date(2016, 6, 9),
#  datetime.date(2018, 11, 15),
#  datetime.date(2023, 1, 25),
#  datetime.date(2021, 10, 25),
#  datetime.date(2023, 10, 31),
#  datetime.date(2017, 4, 7),
#  datetime.date(2023, 1, 6),
#  datetime.date(2017, 5, 26),
#  datetime.date(2022, 9, 29),
#  datetime.date(2019, 1, 8),
#  datetime.date(2015, 7, 8),
#  datetime.date(2017, 2, 14),
#  datetime.date(2020, 5, 8),
#  datetime.date(2018, 7, 12),
#  datetime.date(2020, 5, 29),
#  datetime.date(2017, 2, 8),
#  datetime.date(2015, 8, 18),
#  datetime.date(2019, 10, 7),
#  datetime.date(2021, 5, 12),
#  datetime.date(2018, 1, 24),
#  datetime.date(2018, 9, 4),
#  datetime.date(2021, 9, 30),
#  datetime.date(2020, 12, 15),
#  datetime.date(2021, 11, 10),
#  datetime.date(2019, 8, 22),
#  datetime.date(2023, 5, 31),
#  datetime.date(2021, 3, 1),
#  datetime.date(2015, 6, 25),
#  datetime.date(2016, 7, 4),
#  datetime.date(2019, 1, 18),
#  datetime.date(2019, 6, 26),
#  datetime.date(2017, 8, 7),
#  datetime.date(2018, 5, 30),
#  datetime.date(2020, 1, 13),
#  datetime.date(2023, 2, 1),
#  datetime.date(2020, 12, 7),
#  datetime.date(2016, 12, 6),
#  datetime.date(2021, 10, 11),
#  datetime.date(2020, 12, 28),
#  datetime.date(2022, 2, 16),
#  datetime.date(2017, 5, 18),
#  datetime.date(2015, 9, 2),
#  datetime.date(2018, 2, 15),
#  datetime.date(2020, 11, 11),
#  datetime.date(2023, 4, 25),
#  datetime.date(2018, 8, 30),
#  datetime.date(2017, 12, 18),
#  datetime.date(2018, 6, 11),
#  datetime.date(2022, 6, 22),
#  datetime.date(2018, 8, 17),
#  datetime.date(2018, 3, 16),
#  datetime.date(2024, 8, 19),
#  datetime.date(2018, 9, 17),
#  datetime.date(2019, 3, 12),
#  datetime.date(2015, 10, 16),
#  datetime.date(2019, 1, 31),
#  datetime.date(2024, 5, 6),
#  datetime.date(2019, 1, 30),
#  datetime.date(2021, 2, 9),
#  datetime.date(2022, 4, 18),
#  datetime.date(2018, 3, 15),
#  datetime.date(2018, 6, 14),
#  datetime.date(2020, 7, 8),
#  datetime.date(2024, 5, 10),
#  datetime.date(2016, 11, 9),
#  datetime.date(2023, 1, 5),
#  datetime.date(2016, 11, 3),
#  datetime.date(2018, 5, 17),
#  datetime.date(2021, 2, 22),
#  datetime.date(2022, 11, 21),
#  datetime.date(2019, 4, 26),
#  datetime.date(2023, 2, 3),
#  datetime.date(2024, 8, 29),
#  datetime.date(2019, 8, 5),
#  datetime.date(2016, 12, 14),
#  datetime.date(2019, 6, 7),
#  datetime.date(2016, 9, 1),
#  datetime.date(2015, 6, 30),
#  datetime.date(2020, 7, 6),
#  datetime.date(2024, 6, 28),
#  datetime.date(2017, 1, 19),
#  datetime.date(2016, 9, 7),
#  datetime.date(2023, 4, 17),
#  datetime.date(2021, 12, 14),
#  datetime.date(2019, 9, 19),
#  datetime.date(2020, 11, 20),
#  datetime.date(2021, 7, 27),
#  datetime.date(2024, 4, 5),
#  datetime.date(2018, 11, 13),
#  datetime.date(2020, 5, 6),
#  datetime.date(2021, 3, 23),
#  datetime.date(2022, 12, 20),
#  datetime.date(2017, 9, 18),
#  datetime.date(2019, 10, 4),
#  datetime.date(2023, 5, 15),
#  datetime.date(2021, 10, 19),
#  datetime.date(2019, 11, 12),
#  datetime.date(2015, 8, 19),
#  datetime.date(2021, 2, 12),
#  datetime.date(2022, 10, 13),
#  datetime.date(2022, 5, 12),
#  datetime.date(2024, 7, 18),
#  datetime.date(2022, 3, 8),
#  datetime.date(2024, 1, 16),
#  datetime.date(2024, 4, 19),
#  datetime.date(2017, 8, 3),
#  datetime.date(2020, 8, 11),
#  datetime.date(2023, 4, 24),
#  datetime.date(2018, 3, 28),
#  datetime.date(2015, 4, 7),
#  datetime.date(2023, 10, 27),
#  datetime.date(2015, 6, 8),
#  datetime.date(2024, 10, 21),
#  datetime.date(2020, 1, 6),
#  datetime.date(2019, 2, 22),
#  datetime.date(2020, 8, 20),
#  datetime.date(2024, 7, 29),
#  datetime.date(2017, 6, 28),
#  datetime.date(2019, 7, 24),
#  datetime.date(2018, 7, 6),
#  datetime.date(2020, 1, 15),
#  datetime.date(2016, 11, 11),
#  datetime.date(2018, 10, 5),
#  datetime.date(2023, 3, 15),
#  datetime.date(2024, 7, 24),
#  datetime.date(2023, 11, 21),
#  datetime.date(2017, 1, 23),
#  datetime.date(2017, 8, 23),
#  datetime.date(2018, 9, 26),
#  datetime.date(2022, 3, 2),
#  datetime.date(2016, 11, 25),
#  datetime.date(2023, 5, 18),
#  datetime.date(2017, 5, 23),
#  datetime.date(2016, 12, 13),
#  datetime.date(2016, 3, 8),
#  datetime.date(2019, 9, 26),
#  datetime.date(2018, 2, 26),
#  datetime.date(2020, 7, 22),
#  datetime.date(2019, 3, 22),
#  datetime.date(2015, 7, 21),
#  datetime.date(2019, 1, 9),
#  datetime.date(2022, 1, 28),
#  datetime.date(2017, 6, 8),
#  datetime.date(2023, 11, 24),
#  datetime.date(2017, 1, 4),
#  datetime.date(2019, 6, 20),
#  datetime.date(2020, 12, 24),
#  datetime.date(2017, 5, 29),
#  datetime.date(2017, 10, 17),
#  datetime.date(2015, 7, 20),
#  datetime.date(2019, 6, 13),
#  datetime.date(2021, 12, 7),
#  datetime.date(2016, 1, 15),
#  datetime.date(2020, 5, 28),
#  datetime.date(2021, 7, 28),
#  datetime.date(2024, 1, 30),
#  datetime.date(2016, 12, 22),
#  datetime.date(2019, 1, 11),
#  datetime.date(2019, 6, 3),
#  datetime.date(2019, 5, 30),
#  datetime.date(2022, 4, 29),
#  datetime.date(2016, 5, 6),
#  datetime.date(2016, 5, 30),
#  datetime.date(2016, 6, 16),
#  datetime.date(2023, 6, 23),
#  datetime.date(2017, 3, 2),
#  datetime.date(2024, 7, 3),
#  datetime.date(2018, 9, 6),
#  datetime.date(2022, 6, 29),
#  datetime.date(2022, 11, 11),
#  datetime.date(2018, 12, 28),
#  datetime.date(2021, 9, 17),
#  datetime.date(2024, 3, 12),
#  datetime.date(2016, 5, 24),
#  datetime.date(2022, 5, 10),
#  datetime.date(2017, 11, 14),
#  datetime.date(2015, 3, 25),
#  datetime.date(2018, 12, 18),
#  datetime.date(2020, 5, 12),
#  datetime.date(2017, 12, 11),
#  datetime.date(2017, 9, 7),
#  datetime.date(2024, 8, 1),
#  datetime.date(2016, 3, 14),
#  datetime.date(2021, 12, 2),
#  datetime.date(2015, 5, 20),
#  datetime.date(2020, 10, 27),
#  datetime.date(2019, 8, 27),
#  datetime.date(2018, 12, 14),
#  datetime.date(2019, 4, 30),
#  datetime.date(2024, 7, 16),
#  datetime.date(2017, 4, 24),
#  datetime.date(2015, 9, 24),
#  datetime.date(2019, 7, 16),
#  datetime.date(2023, 2, 20),
#  datetime.date(2023, 9, 29),
#  datetime.date(2020, 1, 8),
#  datetime.date(2020, 12, 2),
#  datetime.date(2020, 8, 5),
#  datetime.date(2018, 1, 19),
#  datetime.date(2019, 12, 19),
#  datetime.date(2024, 4, 23),
#  datetime.date(2015, 10, 29),
#  datetime.date(2016, 12, 1),
#  datetime.date(2021, 10, 8),
#  datetime.date(2019, 1, 1),
#  datetime.date(2017, 3, 15),
#  datetime.date(2018, 8, 24),
#  datetime.date(2015, 9, 11),
#  datetime.date(2018, 9, 20),
#  datetime.date(2016, 6, 10),
#  datetime.date(2021, 12, 30),
#  datetime.date(2020, 4, 28),
#  datetime.date(2022, 6, 21),
#  datetime.date(2023, 12, 1),
#  datetime.date(2015, 11, 5),
#  datetime.date(2020, 11, 14),
#  datetime.date(2022, 8, 22),
#  datetime.date(2017, 11, 29),
#  datetime.date(2024, 10, 17),
#  datetime.date(2019, 5, 3),
#  datetime.date(2018, 11, 20),
#  datetime.date(2020, 12, 21),
#  datetime.date(2024, 5, 13),
#  datetime.date(2022, 7, 4),
#  datetime.date(2015, 10, 15),
#  datetime.date(2020, 7, 14),
#  datetime.date(2016, 6, 28),
#  datetime.date(2018, 11, 26),
#  datetime.date(2024, 5, 20),
#  datetime.date(2022, 8, 31),
#  datetime.date(2018, 6, 13),
#  datetime.date(2024, 2, 13),
#  datetime.date(2015, 8, 28),
#  datetime.date(2017, 9, 5),
#  datetime.date(2021, 1, 20),
#  datetime.date(2020, 6, 9),
#  datetime.date(2023, 3, 2),
#  datetime.date(2019, 11, 19),
#  datetime.date(2021, 8, 5),
#  datetime.date(2021, 2, 24),
#  datetime.date(2019, 11, 22),
#  datetime.date(2020, 11, 30),
#  datetime.date(2024, 9, 23),
#  datetime.date(2020, 12, 1),
#  datetime.date(2019, 12, 26),
#  datetime.date(2024, 3, 19),
#  datetime.date(2017, 7, 14),
#  datetime.date(2016, 3, 17),
#  datetime.date(2016, 7, 1),
#  datetime.date(2021, 5, 18),
#  datetime.date(2022, 1, 14),
#  datetime.date(2021, 12, 9),
#  datetime.date(2021, 4, 27),
#  datetime.date(2017, 6, 14),
#  datetime.date(2021, 2, 23),
#  datetime.date(2020, 2, 12),
#  datetime.date(2016, 5, 10),
#  datetime.date(2021, 12, 29),
#  datetime.date(2020, 3, 26),
#  datetime.date(2023, 5, 19),
#  datetime.date(2021, 9, 14),
#  datetime.date(2024, 8, 22),
#  datetime.date(2019, 5, 10),
#  datetime.date(2015, 3, 20),
#  datetime.date(2015, 11, 11),
#  datetime.date(2022, 8, 4),
#  datetime.date(2018, 2, 1),
#  datetime.date(2016, 7, 12),
#  datetime.date(2021, 9, 7),
#  datetime.date(2015, 10, 30),
#  datetime.date(2020, 10, 29),
#  datetime.date(2023, 12, 5),
#  datetime.date(2016, 8, 1),
#  datetime.date(2021, 1, 1),
#  datetime.date(2023, 7, 24),
#  datetime.date(2024, 1, 17),
#  datetime.date(2024, 9, 30),
#  datetime.date(2024, 8, 23),
#  datetime.date(2023, 11, 1),
#  datetime.date(2019, 4, 16),
#  datetime.date(2019, 4, 3),
#  datetime.date(2022, 3, 28),
#  datetime.date(2015, 9, 9),
#  datetime.date(2016, 1, 21),
#  datetime.date(2022, 1, 25),
#  datetime.date(2024, 3, 25),
#  datetime.date(2024, 4, 15),
#  datetime.date(2023, 12, 18),
#  datetime.date(2015, 6, 9),
#  datetime.date(2024, 1, 11),
#  datetime.date(2015, 4, 6),
#  datetime.date(2020, 1, 14),
#  datetime.date(2021, 12, 8),
#  datetime.date(2022, 4, 1),
#  datetime.date(2023, 11, 17),
#  datetime.date(2017, 12, 8),
#  datetime.date(2020, 12, 3),
#  datetime.date(2017, 12, 29),
#  datetime.date(2019, 9, 10),
#  datetime.date(2018, 11, 16),
#  datetime.date(2022, 9, 27),
#  datetime.date(2017, 10, 12),
#  datetime.date(2021, 5, 13),
#  datetime.date(2023, 3, 22),
#  datetime.date(2018, 12, 20),
#  datetime.date(2015, 4, 13),
#  datetime.date(2019, 2, 28),
#  datetime.date(2015, 6, 19),
#  datetime.date(2018, 10, 22),
#  datetime.date(2021, 7, 23),
#  datetime.date(2020, 3, 20),
#  datetime.date(2020, 6, 30),
#  datetime.date(2016, 7, 18),
#  datetime.date(2016, 2, 1),
#  datetime.date(2017, 5, 5),
#  datetime.date(2015, 9, 22),
#  datetime.date(2022, 12, 26),
#  datetime.date(2024, 2, 16),
#  datetime.date(2016, 5, 18),
#  datetime.date(2019, 11, 15),
#  datetime.date(2020, 7, 2),
#  datetime.date(2017, 5, 30),
#  datetime.date(2017, 10, 9),
#  datetime.date(2020, 7, 15),
#  datetime.date(2021, 12, 3),
#  datetime.date(2020, 6, 12),
#  datetime.date(2018, 4, 16),
#  datetime.date(2015, 3, 5),
#  datetime.date(2022, 12, 27),
#  datetime.date(2016, 12, 12),
#  datetime.date(2023, 5, 29),
#  datetime.date(2016, 3, 7),
#  datetime.date(2019, 8, 29),
#  datetime.date(2017, 10, 16),
#  datetime.date(2022, 5, 24),
#  datetime.date(2015, 3, 2),
#  datetime.date(2020, 4, 30),
#  datetime.date(2020, 10, 20),
#  datetime.date(2019, 10, 8),
#  datetime.date(2023, 10, 24),
#  datetime.date(2020, 2, 4),
#  datetime.date(2024, 6, 14),
#  datetime.date(2020, 9, 14),
#  datetime.date(2019, 8, 20),
#  datetime.date(2017, 11, 30),
#  datetime.date(2016, 11, 14),
#  datetime.date(2021, 11, 24),
#  datetime.date(2016, 6, 7),
#  datetime.date(2017, 5, 3),
#  datetime.date(2021, 4, 15),
#  datetime.date(2015, 4, 2),
#  datetime.date(2023, 10, 6),
#  datetime.date(2024, 7, 1),
#  datetime.date(2022, 5, 25),
#  datetime.date(2016, 9, 26),
#  datetime.date(2019, 5, 15),
#  datetime.date(2021, 5, 20),
#  datetime.date(2017, 4, 27),
#  datetime.date(2018, 9, 25),
#  datetime.date(2019, 1, 23),
#  datetime.date(2024, 10, 7),
#  datetime.date(2020, 7, 13),
#  datetime.date(2015, 9, 15),
#  datetime.date(2018, 10, 26),
#  datetime.date(2016, 8, 16),
#  datetime.date(2023, 10, 19),
#  datetime.date(2024, 3, 5),
#  datetime.date(2018, 4, 26),
#  datetime.date(2024, 5, 21),
#  datetime.date(2020, 8, 13),
#  datetime.date(2021, 3, 25),
#  datetime.date(2024, 4, 30),
#  datetime.date(2020, 5, 18),
#  datetime.date(2024, 10, 16),
#  datetime.date(2020, 7, 1),
#  datetime.date(2024, 3, 11),
#  datetime.date(2016, 6, 6),
#  datetime.date(2017, 4, 17),
#  datetime.date(2019, 3, 8),
#  datetime.date(2022, 4, 25),
#  datetime.date(2023, 12, 22),
#  datetime.date(2022, 1, 5),
#  datetime.date(2021, 2, 5),
#  datetime.date(2023, 8, 1),
#  datetime.date(2020, 6, 15),
#  datetime.date(2022, 1, 31),
#  datetime.date(2022, 10, 11),
#  datetime.date(2021, 4, 23),
#  datetime.date(2020, 5, 5),
#  datetime.date(2015, 8, 10),
#  datetime.date(2020, 7, 20),
#  datetime.date(2015, 9, 28),
#  datetime.date(2021, 2, 17),
#  datetime.date(2016, 3, 18),
#  datetime.date(2023, 8, 10),
#  datetime.date(2022, 9, 1),
#  datetime.date(2017, 7, 26),
#  datetime.date(2024, 5, 3),
#  datetime.date(2016, 5, 27),
#  datetime.date(2019, 5, 24),
#  datetime.date(2018, 1, 30),
#  datetime.date(2016, 8, 30),
#  datetime.date(2017, 1, 25),
#  datetime.date(2016, 11, 23),
#  datetime.date(2016, 3, 21),
#  datetime.date(2017, 1, 18),
#  datetime.date(2022, 10, 5),
#  datetime.date(2016, 1, 6),
#  datetime.date(2016, 8, 4),
#  datetime.date(2022, 7, 14),
#  datetime.date(2016, 3, 4),
#  datetime.date(2020, 6, 18),
#  datetime.date(2015, 4, 21),
#  datetime.date(2017, 3, 16),
#  datetime.date(2024, 2, 14),
#  datetime.date(2018, 2, 2),
#  datetime.date(2022, 3, 15),
#  datetime.date(2015, 5, 28),
#  datetime.date(2018, 1, 22),
#  datetime.date(2018, 11, 5),
#  datetime.date(2022, 4, 11),
#  datetime.date(2015, 10, 12),
#  datetime.date(2017, 1, 13),
#  datetime.date(2023, 6, 22),
#  datetime.date(2017, 2, 9),
#  datetime.date(2024, 1, 25),
#  datetime.date(2016, 1, 19),
#  datetime.date(2016, 10, 7),
#  datetime.date(2018, 1, 12),
#  datetime.date(2023, 11, 9),
#  datetime.date(2015, 5, 6),
#  datetime.date(2021, 10, 12),
#  datetime.date(2019, 3, 7),
#  datetime.date(2018, 5, 8),
#  datetime.date(2019, 7, 1),
#  datetime.date(2019, 9, 11),
#  datetime.date(2020, 10, 6),
#  datetime.date(2023, 11, 7),
#  datetime.date(2020, 11, 4),
#  datetime.date(2017, 10, 5),
#  datetime.date(2019, 11, 25),
#  datetime.date(2024, 4, 1),
#  datetime.date(2020, 3, 6),
#  datetime.date(2023, 2, 28),
#  datetime.date(2022, 5, 23),
#  datetime.date(2017, 10, 24),
#  datetime.date(2019, 4, 22),
#  datetime.date(2018, 6, 8),
#  datetime.date(2017, 11, 8),
#  datetime.date(2020, 4, 3),
#  datetime.date(2018, 8, 14),
#  datetime.date(2020, 7, 21),
#  datetime.date(2022, 8, 30),
#  datetime.date(2024, 3, 26),
#  datetime.date(2019, 3, 29),
#  datetime.date(2020, 8, 17),
#  datetime.date(2016, 2, 17),
#  datetime.date(2019, 3, 6),
#  datetime.date(2017, 7, 10),
#  datetime.date(2018, 12, 6),
#  datetime.date(2019, 10, 22),
#  datetime.date(2015, 7, 2),
#  datetime.date(2016, 5, 31),
#  datetime.date(2022, 3, 17),
#  datetime.date(2023, 12, 6),
#  datetime.date(2015, 11, 20),
#  datetime.date(2022, 11, 7),
#  datetime.date(2016, 2, 22),
#  datetime.date(2015, 9, 7),
#  datetime.date(2016, 1, 22),
#  datetime.date(2017, 9, 15),
#  datetime.date(2019, 12, 24),
#  datetime.date(2015, 10, 22),
#  datetime.date(2020, 11, 24),
#  datetime.date(2023, 10, 23),
#  datetime.date(2015, 3, 6),
#  datetime.date(2020, 11, 16),
#  datetime.date(2020, 9, 21),
#  datetime.date(2016, 11, 17),
#  datetime.date(2022, 11, 8),
#  datetime.date(2020, 5, 7),
#  datetime.date(2016, 9, 30),
#  datetime.date(2022, 1, 10),
#  datetime.date(2023, 11, 15),
#  datetime.date(2020, 9, 4),
#  datetime.date(2021, 7, 9),
#  datetime.date(2020, 3, 5),
#  datetime.date(2021, 9, 13),
#  datetime.date(2018, 7, 11),
#  datetime.date(2022, 6, 28),
#  datetime.date(2019, 11, 18),
#  datetime.date(2019, 1, 16),
#  datetime.date(2022, 3, 23),
#  datetime.date(2021, 12, 22),
#  datetime.date(2022, 3, 18),
#  datetime.date(2021, 1, 27),
#  datetime.date(2020, 9, 23),
#  datetime.date(2022, 4, 19),
#  datetime.date(2019, 1, 14),
#  datetime.date(2022, 7, 12),
#  datetime.date(2017, 4, 10),
#  datetime.date(2019, 10, 10),
#  datetime.date(2018, 12, 11),
#  datetime.date(2021, 12, 27),
#  datetime.date(2021, 3, 8),
#  datetime.date(2018, 6, 22),
#  datetime.date(2021, 7, 26),
#  datetime.date(2020, 7, 28),
#  datetime.date(2020, 9, 11),
#  datetime.date(2016, 2, 12),
#  datetime.date(2024, 5, 2),
#  datetime.date(2023, 12, 13),
#  datetime.date(2016, 8, 11),
#  datetime.date(2019, 6, 14),
#  datetime.date(2019, 1, 4),
#  datetime.date(2024, 6, 27),
#  datetime.date(2017, 6, 20),
#  datetime.date(2022, 1, 12),
#  datetime.date(2023, 6, 14),
#  datetime.date(2018, 5, 3),
#  datetime.date(2023, 6, 8),
#  datetime.date(2020, 3, 4),
#  datetime.date(2023, 1, 23),
#  datetime.date(2015, 12, 7),
#  datetime.date(2020, 3, 9),
#  datetime.date(2020, 1, 22),
#  datetime.date(2021, 10, 5),
#  datetime.date(2018, 3, 7),
#  datetime.date(2024, 10, 25),
#  datetime.date(2023, 8, 14),
#  datetime.date(2019, 4, 25),
#  datetime.date(2018, 6, 28),
#  datetime.date(2017, 2, 1),
#  datetime.date(2016, 7, 28),
#  datetime.date(2016, 2, 10),
#  datetime.date(2020, 9, 16),
#  datetime.date(2022, 9, 7),
#  datetime.date(2018, 12, 27),
#  datetime.date(2020, 5, 14),
#  datetime.date(2018, 9, 27),
#  datetime.date(2019, 3, 1),
#  datetime.date(2015, 6, 22),
#  datetime.date(2023, 4, 12),
#  datetime.date(2019, 6, 4),
#  datetime.date(2022, 9, 16),
#  datetime.date(2015, 7, 29),
#  datetime.date(2024, 6, 17),
#  datetime.date(2018, 12, 31),
#  datetime.date(2019, 1, 25),
#  datetime.date(2024, 8, 21),
#  datetime.date(2023, 9, 20),
#  datetime.date(2017, 3, 8),
#  datetime.date(2022, 12, 28),
#  datetime.date(2024, 1, 12),
#  datetime.date(2017, 7, 20),
#  datetime.date(2021, 6, 7),
#  datetime.date(2021, 8, 24),
#  datetime.date(2017, 3, 1),
#  datetime.date(2024, 9, 27),
#  datetime.date(2023, 1, 10),
#  datetime.date(2020, 3, 18),
#  datetime.date(2015, 11, 10),
#  datetime.date(2023, 10, 18),
#  datetime.date(2016, 8, 23),
#  datetime.date(2022, 8, 8),
#  datetime.date(2015, 4, 14),
#  datetime.date(2019, 10, 11),
#  datetime.date(2017, 11, 21),
#  datetime.date(2024, 4, 12),
#  datetime.date(2020, 2, 20),
#  datetime.date(2017, 9, 25),
#  datetime.date(2018, 6, 29),
#  datetime.date(2021, 11, 26),
#  datetime.date(2021, 8, 4),
#  datetime.date(2017, 3, 9),
#  datetime.date(2017, 12, 20),
#  datetime.date(2020, 6, 17),
#  datetime.date(2015, 10, 1),
#  datetime.date(2023, 4, 3),
#  datetime.date(2023, 4, 18),
#  datetime.date(2019, 11, 27),
#  datetime.date(2015, 8, 7),
#  datetime.date(2020, 8, 3),
#  datetime.date(2023, 10, 10),
#  datetime.date(2015, 9, 1),
#  datetime.date(2016, 9, 14),
#  datetime.date(2016, 4, 6),
#  datetime.date(2024, 8, 26),
#  datetime.date(2015, 5, 13),
#  datetime.date(2017, 8, 22),
#  datetime.date(2019, 1, 7),
#  datetime.date(2018, 12, 21),
#  datetime.date(2023, 6, 7),
#  datetime.date(2024, 2, 26),
#  datetime.date(2020, 8, 19),
#  datetime.date(2017, 7, 19),
#  datetime.date(2015, 4, 1),
#  datetime.date(2015, 4, 22),
#  datetime.date(2015, 11, 17),
#  datetime.date(2019, 4, 5),
#  datetime.date(2023, 12, 15),
#  datetime.date(2016, 6, 24),
#  datetime.date(2023, 9, 7),
#  datetime.date(2019, 4, 18),
#  datetime.date(2016, 1, 20),
#  datetime.date(2019, 12, 20),
#  datetime.date(2020, 8, 6),
#  datetime.date(2022, 10, 12),
#  datetime.date(2022, 12, 29),
#  datetime.date(2016, 2, 24),
#  datetime.date(2018, 2, 12),
#  datetime.date(2023, 1, 30),
#  datetime.date(2022, 6, 3),
#  datetime.date(2023, 12, 26),
#  datetime.date(2023, 3, 7),
#  datetime.date(2017, 4, 20),
#  datetime.date(2015, 4, 17),
#  datetime.date(2021, 6, 29),
#  datetime.date(2021, 11, 25),
#  datetime.date(2024, 1, 15),
#  datetime.date(2024, 6, 24),
#  datetime.date(2017, 12, 4),
#  datetime.date(2018, 7, 17),
#  datetime.date(2019, 6, 27),
#  datetime.date(2016, 11, 4),
#  datetime.date(2022, 11, 24),
#  datetime.date(2020, 2, 11),
#  datetime.date(2016, 11, 24),
#  datetime.date(2020, 1, 16),
#  datetime.date(2015, 6, 23),
#  datetime.date(2021, 2, 11),
#  datetime.date(2019, 5, 17),
#  datetime.date(2024, 10, 9),
#  datetime.date(2019, 1, 28),
#  datetime.date(2018, 10, 16),
#  datetime.date(2017, 1, 16),
#  datetime.date(2021, 9, 15),
#  datetime.date(2019, 8, 12),
#  datetime.date(2020, 9, 18),
#  datetime.date(2023, 8, 18),
#  datetime.date(2024, 4, 10),
#  datetime.date(2015, 4, 29),
#  datetime.date(2019, 3, 4),
#  datetime.date(2015, 4, 24),
#  datetime.date(2020, 10, 16),
#  datetime.date(2015, 10, 8),
#  datetime.date(2023, 8, 8),
#  datetime.date(2016, 9, 22),
#  datetime.date(2018, 3, 14),
#  datetime.date(2017, 8, 29),
#  datetime.date(2023, 6, 13),
#  datetime.date(2019, 11, 21),
#  datetime.date(2022, 6, 8),
#  datetime.date(2022, 7, 19),
#  datetime.date(2020, 3, 10),
#  datetime.date(2024, 6, 3),
#  datetime.date(2024, 6, 13),
#  datetime.date(2017, 11, 22),
#  datetime.date(2024, 4, 26),
#  datetime.date(2020, 1, 17),
#  datetime.date(2023, 1, 4),
#  datetime.date(2018, 6, 20),
#  datetime.date(2022, 10, 4),
#  datetime.date(2019, 10, 9),
#  datetime.date(2015, 8, 4),
#  datetime.date(2021, 12, 17),
#  datetime.date(2023, 3, 13),
#  datetime.date(2018, 1, 29),
#  datetime.date(2018, 2, 14),
#  datetime.date(2019, 9, 18),
#  datetime.date(2018, 3, 6),
#  datetime.date(2015, 3, 16),
#  datetime.date(2023, 8, 3),
#  datetime.date(2019, 12, 17),
#  datetime.date(2019, 8, 19),
#  datetime.date(2020, 5, 15),
#  datetime.date(2024, 2, 27),
#  datetime.date(2019, 2, 12),
#  datetime.date(2017, 4, 12),
#  datetime.date(2019, 3, 21),
#  datetime.date(2018, 5, 7),
#  datetime.date(2017, 7, 13),
#  datetime.date(2016, 3, 16),
#  datetime.date(2022, 3, 9),
#  datetime.date(2016, 6, 21),
#  datetime.date(2018, 4, 27),
#  datetime.date(2024, 3, 6),
#  datetime.date(2017, 11, 7),
#  datetime.date(2024, 5, 24),
#  datetime.date(2015, 3, 30),
#  datetime.date(2018, 2, 6),
#  datetime.date(2021, 12, 15),
#  datetime.date(2019, 5, 20),
#  datetime.date(2016, 9, 6),
#  datetime.date(2020, 9, 22),
#  datetime.date(2022, 6, 16),
#  datetime.date(2015, 12, 31),
#  datetime.date(2018, 4, 5),
#  datetime.date(2022, 10, 14),
#  datetime.date(2021, 1, 14),
#  datetime.date(2020, 7, 24),
#  datetime.date(2017, 12, 5),
#  datetime.date(2022, 5, 11),
#  datetime.date(2024, 8, 2),
#  datetime.date(2021, 4, 1),
#  datetime.date(2016, 3, 23),
#  datetime.date(2015, 11, 3),
#  datetime.date(2023, 6, 12),
#  datetime.date(2018, 5, 22),
#  datetime.date(2020, 3, 24),
#  datetime.date(2020, 9, 29),
#  datetime.date(2018, 11, 28),
#  datetime.date(2020, 3, 25),
#  datetime.date(2020, 2, 10),
#  datetime.date(2019, 10, 21),
#  datetime.date(2022, 5, 3),
#  datetime.date(2019, 9, 23),
#  datetime.date(2022, 12, 21),
#  datetime.date(2016, 5, 5),
#  datetime.date(2017, 5, 8),
#  datetime.date(2018, 11, 19),
#  datetime.date(2021, 5, 26),
#  datetime.date(2024, 9, 11),
#  datetime.date(2023, 9, 4),
#  datetime.date(2019, 3, 28),
#  datetime.date(2020, 9, 3),
#  datetime.date(2021, 8, 25),
#  datetime.date(2022, 1, 24),
#  datetime.date(2016, 12, 23),
#  datetime.date(2017, 3, 30),
#  datetime.date(2022, 11, 28),
#  datetime.date(2015, 7, 31),
#  datetime.date(2021, 9, 20),
#  datetime.date(2023, 5, 9),
#  datetime.date(2018, 7, 16),
#  datetime.date(2017, 4, 26),
#  datetime.date(2017, 11, 28),
#  datetime.date(2021, 7, 19),
#  datetime.date(2017, 10, 31),
#  datetime.date(2020, 10, 13),
#  datetime.date(2018, 8, 16),
#  datetime.date(2023, 11, 10),
#  datetime.date(2024, 2, 7),
#  datetime.date(2023, 5, 11),
#  datetime.date(2024, 8, 9),
#  datetime.date(2020, 3, 2),
#  datetime.date(2022, 1, 20),
#  datetime.date(2016, 10, 11),
#  datetime.date(2015, 4, 27),
#  datetime.date(2021, 6, 22),
#  datetime.date(2021, 3, 31),
#  datetime.date(2024, 7, 5),
#  datetime.date(2018, 8, 13),
#  datetime.date(2021, 1, 18),
#  datetime.date(2018, 4, 6),
#  datetime.date(2017, 10, 30),
#  datetime.date(2016, 1, 5),
#  datetime.date(2020, 7, 23),
#  datetime.date(2022, 8, 11),
#  datetime.date(2018, 8, 1),
#  datetime.date(2022, 7, 18),
#  datetime.date(2017, 10, 18),
#  datetime.date(2017, 11, 13),
#  datetime.date(2020, 10, 30),
#  datetime.date(2023, 2, 8),
#  datetime.date(2019, 5, 1),
#  datetime.date(2016, 4, 22),
#  datetime.date(2019, 11, 7),
#  datetime.date(2016, 8, 26),
#  datetime.date(2019, 8, 7),
#  datetime.date(2020, 10, 5),
#  datetime.date(2021, 9, 8),
#  datetime.date(2016, 5, 16),
#  datetime.date(2016, 7, 8),
#  datetime.date(2023, 8, 31),
#  datetime.date(2018, 11, 21),
#  datetime.date(2024, 7, 22),
#  datetime.date(2023, 4, 11),
#  datetime.date(2021, 5, 28),
#  datetime.date(2018, 5, 21),
#  datetime.date(2024, 5, 27),
#  datetime.date(2021, 3, 11),
#  datetime.date(2024, 4, 25),
#  datetime.date(2024, 7, 9),
#  datetime.date(2024, 9, 12),
#  datetime.date(2023, 6, 5),
#  datetime.date(2022, 11, 25),
#  datetime.date(2017, 6, 2),
#  datetime.date(2019, 12, 16),
#  datetime.date(2022, 3, 10),
#  datetime.date(2017, 3, 14),
#  datetime.date(2022, 12, 23),
#  datetime.date(2018, 9, 11),
#  datetime.date(2017, 10, 26),
#  datetime.date(2021, 5, 4),
#  datetime.date(2020, 5, 21),
#  datetime.date(2024, 5, 14),
#  datetime.date(2019, 8, 23),
#  datetime.date(2019, 1, 3),
#  datetime.date(2019, 1, 21),
#  datetime.date(2018, 10, 15),
#  datetime.date(2020, 2, 13),
#  datetime.date(2023, 11, 8),
#  datetime.date(2018, 8, 27),
#  datetime.date(2015, 9, 18),
#  datetime.date(2021, 5, 10),
#  datetime.date(2015, 11, 18),
#  datetime.date(2018, 9, 13),
#  datetime.date(2018, 9, 19),
#  datetime.date(2024, 9, 4),
#  datetime.date(2024, 10, 15),
#  datetime.date(2017, 3, 27),
#  datetime.date(2023, 4, 10),
#  ...}

# %%
def rename_ohlc_columns(df: pl.DataFrame) -> pl.DataFrame:

    column_mapping = {"o": "open", "h": "high", "l": "low", "c": "close", "v": "volume"}
    df = df.rename(column_mapping)

    return df

# %%
async def create_sell_signals(df):

    df["sell_signal"] = False

    df["sell_signal"] = (df["high"] < df["high"].shift(1)) & (
        df["high"].shift(2) < df["high"].shift(1)
    )

    return df

async def create_buy_signals(df):
    df["buy_signal"] = False

    df["buy_signal"] = (df["low"] > df["low"].shift(1)) & (
        df["low"].shift(2) > df["low"].shift(1)
    )

    return df

async def create_ma(df, period):
    df["close"] = pd.to_numeric(df["close"], errors="coerce")
    df["ma"] = df["close"].rolling(window=period).mean()
    return df

# %%
PORTFOLIO_VALUE = 10_00_000 # 10 Lacs
RPT_PCT = 0.01 # 1% RPT
SLIPPAGE_ = 0.001
LEVERAGE_ = 5

# %%
def positional(df, sl_pct, target_pct):
    trades = []
    in_trade_long = False
    in_trade_short = False
    current_trade = None
    king_candle = None
    queen_candle = None
    slippage_pct = SLIPPAGE_
    portfolio = 10000000
    index_lev = 6
    entry_time = None
    exit_time = None
    is_trailing_active_long = False
    is_trailing_active_short = False
    points_long = None
    points_short = None
    initial_sl_long = 100000
    initial_sl_short = 0
    latest_king_found = False
    latest_queen_found = False

    # df['100ma'] = df['close'].rolling(100).mean()

    for i in range(3, len(df)):
        prev2_candle = df.iloc[i-3]
        prev_candle = df.iloc[i-2]
        last_candle = df.iloc[i-1]
        current_candle = df.iloc[i]

        if last_candle['high'] <= prev_candle['high'] and prev2_candle['high'] <= prev_candle['high']:
            king_candle = prev_candle
            print(f'King Candle : \n{df.iloc[i-2]}')

        if last_candle['low'] >= prev_candle['low'] and prev2_candle['low'] >= prev_candle['low']:
            queen_candle = prev_candle
            print(f'Queen Candle : \n{df.iloc[i-2]}')

        # Check for King candle formation when not in a trade
        if not in_trade_long and last_candle['high'] <= prev_candle['high'] and prev2_candle['high'] <= prev_candle['high']:
            king_candle = prev_candle
            signal_time_long = king_candle['datetime']
            # initial_sl_long = min(current_candle['low'], prev_candle['low'], prev2_candle['low'])
            initial_sl_long = queen_candle['low'] if (queen_candle is not None and queen_candle['low'] < king_candle['high']) else (min(last_candle['low'], prev_candle['low'], prev2_candle['low']))
            # print(f'King Candle Setup Complete : {df.iloc[i-1]["datetime"]}')

        # Check for Queen candle formation when not in a trade
        if not in_trade_short and last_candle['low'] >= prev_candle['low'] and prev2_candle['low'] >= prev_candle['low']:
            queen_candle = prev_candle
            signal_time_short = queen_candle['datetime']
            # initial_sl_short = max(current_candle['high'], prev_candle['high'], prev2_candle['high'])
            initial_sl_short = king_candle['high'] if (king_candle is not None and king_candle['high'] > queen_candle['low']) else (max(last_candle['high'], prev_candle['high'], prev2_candle['high']))
            # print(f'Queen Candle Setup Complete : {df.iloc[i-1]["datetime"]}')
            
        # Check for King breakout (Long position)
        if king_candle is not None and not in_trade_long and current_candle['high'] >= king_candle['high']:
            
            if (current_candle['open'] > king_candle['high'] and current_candle['low'] <= king_candle['high']) or (current_candle['open'] <= king_candle['high']):
                entry_price_long = king_candle['high']
                stop_loss_long = queen_candle['low'] if (queen_candle is not None and queen_candle['low'] < king_candle['high']) else (min(last_candle['low'], prev_candle['low'], prev2_candle['low']))
                # stop_loss_long = entry_price_long * (1 - sl_pct)
                # stop_loss_long = initial_sl_long
                # target_long = entry_price_long * (1 + target_pct)
                entry_time_long = df.iloc[i]['datetime']
                in_trade_long = True
            
            elif current_candle['low'] > king_candle['high']:
                king_candle = None
                in_trade_long = False

        if in_trade_long:

            if last_candle['high'] <= prev_candle['high'] and prev2_candle['high'] <= prev_candle['high']:
                # King Candle Formed, Trail SL
                latest_king_found = True

            if (last_candle['low'] >= prev_candle['low'] and prev2_candle['low'] >= prev_candle['low']) and latest_king_found and (prev_candle['low'] >= stop_loss_long):
                # Queen Candle Formed, Trail SL
                stop_loss_long = prev_candle['low']
                latest_king_found = False
        
            if (current_candle['low'] <= stop_loss_long):
                if current_candle['open'] < stop_loss_long:
                    if current_candle['datetime'] != entry_time_long:
                        exit_price_long = current_candle['open']
                        exit_time_long = df.iloc[i]['datetime']
                        points_long = exit_price_long - entry_price_long
                        # remarks_long = 'Gap SL'
                else:
                    exit_price_long = stop_loss_long
                    exit_time_long = df.iloc[i]['datetime']
                    points_long = exit_price_long - entry_price_long
                    # remarks_long = 'Initial SL Hit'
                
            # elif (current_candle['high'] >= target_long):
            #     exit_price_long = target_long
            #     exit_time_long = df.iloc[i]['datetime']
            #     points_long = exit_price_long - entry_price_long
            #     # remarks_long = 'Target Hit'
            
            if points_long:
                slippages = SLIPPAGE_ * (entry_price_long + exit_price_long)
                # qty = portfolio * index_lev / entry_price_long
                qty = portfolio * RPT_PCT / abs(entry_price_long - initial_sl_long)
                current_trade = {
                    'Type': 'LONG',
                    'Signal Generated At': signal_time_long,
                    'Entry Time': entry_time_long,
                    'Entry Price': entry_price_long,
                    'Initial SL': initial_sl_long,
                    'Final SL': stop_loss_long,
                    'Exit Time': exit_time_long,
                    'Exit Price': exit_price_long,
                    'Points': points_long,
                    'Slippages': slippages,
                    # 'Remarks': remarks_long,
                    'Qty': qty,
                    'PnL': points_long * qty,
                    'PnL w cs': (points_long - slippages) * qty,
                    # 'ROI%': points_long * qty * 100 / portfolio,
                    'ROI%': (points_long - slippages) * qty * 100 / portfolio,
                }
                trades.append(current_trade) 
                in_trade_long = False  
                king_candle = None  
                is_trailing_active_long = False
                points_long = None
                signal_time_long = None
                initial_sl_long = 100000

            
        # Check for Queen breakout (Short position)
        if queen_candle is not None and not in_trade_short and current_candle['low'] <= queen_candle['low']:
            
            if (current_candle['open'] < queen_candle['low'] and current_candle['high'] >= queen_candle['low']) or (current_candle['open'] >= queen_candle['low']):
                entry_price_short = queen_candle['low']
                stop_loss_short = king_candle['high'] if (king_candle is not None and king_candle['high'] > queen_candle['low']) else (max(last_candle['high'], prev_candle['high'], prev2_candle['high']))
                # stop_loss_short = entry_price_short * (1 + sl_pct)
                # stop_loss_short = initial_sl_short
                # target_short = entry_price_short * (1 - target_pct)
                entry_time_short = df.iloc[i]['datetime']
                in_trade_short = True
            elif current_candle['high'] < queen_candle['low']:
                queen_candle = None
                in_trade_short = False
            
        if in_trade_short:

            if last_candle['low'] >= prev_candle['low'] and prev2_candle['low'] >= prev_candle['low']:
                # Queen Candle Formed, Trail SL
                latest_queen_found = True
            
            if (last_candle['high'] <= prev_candle['high'] and prev2_candle['high'] <= prev_candle['high']) and latest_queen_found and (prev_candle['high'] <= stop_loss_short):
                # King Candle Formed, Trail SL
                stop_loss_short = prev_candle['high']
                latest_queen_found = False
            
            if (current_candle['high'] >= stop_loss_short):
                if current_candle['open'] > stop_loss_short:
                    if current_candle['datetime'] != entry_time_short:
                        exit_price_short = current_candle['open']
                        exit_time_short = df.iloc[i]['datetime']
                        points_short = entry_price_short - exit_price_short
                        # remarks_short = 'Gap SL'
                else:
                    exit_price_short = stop_loss_short
                    exit_time_short = df.iloc[i]['datetime']
                    points_short = entry_price_short - exit_price_short
                    # remarks_short = 'Initial SL Hit'
                
            # elif (current_candle['low'] <= target_short):
            #     exit_price_short = target_short
            #     exit_time_short = df.iloc[i]['datetime']
            #     points_short = entry_price_short - exit_price_short
            #     # remarks_short = 'Target Hit'
                
            if points_short:
                slippages = SLIPPAGE_ * (entry_price_short + exit_price_short)
                # qty = portfolio * index_lev / entry_price_short
                qty = portfolio * RPT_PCT / abs(entry_price_short - initial_sl_short)
                current_trade = {
                    'Type': 'SHORT',
                    'Signal Generated At': signal_time_short,
                    'Entry Time': entry_time_short,
                    'Entry Price': entry_price_short,
                    'Initial SL': initial_sl_short,
                    'Final SL': stop_loss_short,
                    'Exit Time': exit_time_short,
                    'Exit Price': exit_price_short,
                    'Points': points_short,
                    'Slippages': slippages,
                    # 'Remarks': remarks_short,
                    'Qty': qty,
                    'PnL': points_short * qty,
                    'PnL w cs': (points_short - slippages) * qty,
                    # 'ROI%': points_short * qty * 100 / portfolio,
                    'ROI%': (points_short - slippages) * qty * 100 / portfolio,
                }
                trades.append(current_trade)
                in_trade_short = False
                queen_candle = None
                is_trailing_active_short = False
                points_short = None
                signal_time_short = None
                initial_sl_short = 0
            
    return trades


# Example usage:
# trades = identify_trades(df)
# print(trades)

# %%
def positional2(df, sl_pct, target_pct):
    trades = []
    in_trade_long = False
    in_trade_short = False
    current_trade = None
    king_candle = None
    queen_candle = None
    slippage_pct = SLIPPAGE_
    portfolio = 10000000
    index_lev = 6
    entry_time = None
    exit_time = None
    is_trailing_active_long = False
    is_trailing_active_short = False
    points_long = None
    points_short = None
    initial_sl_long = 100000
    initial_sl_short = 0
    latest_king_found = False
    latest_queen_found = False
    long_trade_ready = False

    for i in range(3, len(df)):
        current_candle = df.iloc[i]
        n_1_candle = df.iloc[i-1]
        n_2_candle = df.iloc[i-2]
        n_3_candle = df.iloc[i-3]

        if (n_1_candle['high'] <= n_2_candle['high']) and (n_3_candle['high'] <= n_2_candle['high']):
            # King Candle Formed
            king_candle = n_2_candle

        if (n_1_candle['low'] >= n_2_candle['low']) and (n_3_candle['low'] >= n_2_candle['low']):
            # Queen Candle Formed
            queen_candle = n_2_candle

        if not in_trade_long:
            if king_candle is not None:
                if current_candle['high'] >= king_candle['high']:
                    # Go Long
                    if (current_candle['open'] > king_candle['high'] and current_candle['low'] <= king_candle['high']) or (current_candle['open'] <= king_candle['high']):
                        # Confirmation of Entry Triggered
                        entry_price_long = king_candle['high']
                        initial_sl_long = queen_candle['low']
                        stop_loss_long = initial_sl_long
                        entry_time_long = current_candle['datetime']
                        in_trade_long = True
                        signal_time_long = king_candle['datetime']
                        # long_trade_ready = True
                    else:
                        # Entry Skipped
                        in_trade_long = False

        if in_trade_long:
            
            if (n_1_candle['high'] <= n_2_candle['high']) and (n_3_candle['high'] <= n_2_candle['high']):
                latest_king_found = True

            if latest_king_found:
                if (n_1_candle['low'] >= n_2_candle['low']) and (n_3_candle['low'] >= n_2_candle['low']) and (n_2_candle['low'] > stop_loss_long):
                    # Queen Candle Formed, Trail SL
                    stop_loss_long = n_2_candle['low']

            if current_candle['low'] <= stop_loss_long:
                if (current_candle['open'] < stop_loss_long):
                    # SL Skipped
                    exit_price_long = current_candle['open']
                    in_trade_long = False
                    points_long = exit_price_long - entry_price_long
                    exit_time_long = current_candle['datetime']

                elif (current_candle['open'] >= stop_loss_long) and (current_candle['low'] <= stop_loss_long):
                    # SL Hit
                    exit_price_long = stop_loss_long
                    in_trade_long = False
                    points_long = exit_price_long - entry_price_long
                    exit_time_long = current_candle['datetime']

        if points_long:
            if entry_price_long > initial_sl_long:
                slippages = SLIPPAGE_ * (entry_price_long + exit_price_long)
                # qty = portfolio * index_lev / entry_price_long
                qty = portfolio * RPT_PCT / abs(entry_price_long - initial_sl_long)
                current_trade = {
                    'Type': 'LONG',
                    'Signal Generated At': signal_time_long,
                    'Entry Time': entry_time_long,
                    'Entry Price': entry_price_long,
                    'Initial SL': initial_sl_long,
                    'Final SL': stop_loss_long,
                    'Exit Time': exit_time_long,
                    'Exit Price': exit_price_long,
                    'Points': points_long,
                    'Slippages': slippages,
                    # 'Remarks': remarks_long,
                    'Qty': qty,
                    'PnL': points_long * qty,
                    'PnL w cs': (points_long - slippages) * qty,
                    # 'ROI%': points_long * qty * 100 / portfolio,
                    'ROI%': (points_long - slippages) * qty * 100 / portfolio,
                }
                trades.append(current_trade) 
            in_trade_long = False  
            king_candle = None  
            is_trailing_active_long = False
            points_long = None
            signal_time_long = None
            initial_sl_long = 100000
            # long_trade_ready = False

    return trades

# %%
# data_pandas.head(30)

# %%
tf = '60m'
ofs = '15m'
ma_period = 50

# data = resample(pl.DataFrame(bnf_1min), tf, ofs)
# data_pandas = data.to_pandas()
data_pandas = bnf_1min
data_pandas['ma'] = data_pandas['close'].rolling(ma_period).mean()
# data['ma'] = data['close'].rolling(ma_period).mean()
tb = positional2(data_pandas, 0.05, 1)

# %%
tb_pandas = pd.DataFrame(tb)
tb_pandas = tb_pandas.sort_values(by='Signal Generated At')

# %%
# tb_pandas = tb_pandas[tb_pandas['Type'] == 'LONG']

# %%
# tb_pandas['ROI% w cs'].sum()

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2015, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2015, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI% w cs"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI% w cs"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI% w cs"] > 0]["ROI% w cs"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI% w cs"] < 0]["ROI% w cs"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI% w cs"].cumsum() - year_trades["ROI% w cs"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI% w cs"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI% w cs"] > 0]["ROI% w cs"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI% w cs"] < 0]["ROI% w cs"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI% w cs"].cumsum() - combined_df_sorted["ROI% w cs"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation

    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    
    # print(f'{overall_total_roi} , {overall_max_drawdown} , {overall_roi_dd_ratio}')
    
    return {overall_roi_dd_ratio: stats_df8}

# %%
tb_pandas['Entry Time'] = pd.to_datetime(tb_pandas['Entry Time'])
tb_pandas['Trade Year'] = tb_pandas['Entry Time'].dt.year
tb_pandas['ROI% w cs'] = tb_pandas['ROI%']

# %%
stats = generate_stats(tb_pandas, '...')
lol = pd.DataFrame()
for x, y in stats.items():
    lol = pd.DataFrame(y)

lol
# Out:
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2015      -9.6568           47  25.5319                1.5830
# 2016       7.6917           52  36.5385                1.8769
# 2017     -23.4923           66  25.7576                1.0407
# 2018      -6.0952           61  34.4262                1.1775
# 2019      -1.3586           60  31.6667                1.6047
# 2020     -10.9800           62  32.2581                1.0724
# 2021       5.8855           55  40.0000                1.5219
# 2022      11.8698           51  37.2549                1.7293
# 2023     -12.1830           57  28.0702                1.2029
# 2024       4.8286           45  37.7778                1.7186
# Overall  -33.4903          556  32.7338                1.4495
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio Variation
# 2015                -0.8187     -20.0833      -0.4808       ...
# 2016                -0.8475      -7.2074       1.0672       ...
# 2017                -0.8405     -22.3543      -1.0509       ...
# 2018                -0.7706     -18.1344      -0.3361       ...
# 2019                -0.7768      -8.0423      -0.1689       ...
# 2020                -0.7721     -10.6608      -1.0299       ...
# 2021                -0.8363      -9.9721       0.5902       ...
# 2022                -0.6558      -7.1912       1.6506       ...
# 2023                -0.7666     -14.7158      -0.8279       ...
# 2024                -0.8710     -10.1253       0.4769       ...
# Overall             -0.7949     -58.3625      -0.5738       ...

# %%
tb2 = tb_pandas[(tb_pandas['Trade Year'] <= 2016)]
tb2
# Out:
#     Type       Signal Generated At                Entry Time  Entry Price  \
# 0   LONG 2015-03-03 17:00:00+05:30 2015-03-04 09:00:00+05:30     170.2000
# 1   LONG 2015-03-10 21:00:00+05:30 2015-03-11 17:00:00+05:30     173.5000
# 2   LONG 2015-03-11 21:00:00+05:30 2015-03-12 17:00:00+05:30     179.4000
# 3   LONG 2015-03-13 21:00:00+05:30 2015-03-17 13:00:00+05:30     174.5000
# 4   LONG 2015-03-30 09:00:00+05:30 2015-03-30 17:00:00+05:30     167.5000
# 5   LONG 2015-03-30 17:00:00+05:30 2015-03-31 17:00:00+05:30     168.6000
# 6   LONG 2015-04-01 13:00:00+05:30 2015-04-02 17:00:00+05:30     167.8000
# 7   LONG 2015-04-13 17:00:00+05:30 2015-04-14 17:00:00+05:30     159.4000
# 8   LONG 2015-04-21 17:00:00+05:30 2015-04-22 13:00:00+05:30     164.0000
# 9   LONG 2015-04-28 17:00:00+05:30 2015-04-29 17:00:00+05:30     162.2000
# 10  LONG 2015-05-06 21:00:00+05:30 2015-05-07 17:00:00+05:30     180.7000
# 11  LONG 2015-05-07 17:00:00+05:30 2015-05-08 17:00:00+05:30     181.7000
# 12  LONG 2015-05-26 13:00:00+05:30 2015-05-27 17:00:00+05:30     182.3000
# 13  LONG 2015-06-01 13:00:00+05:30 2015-06-01 21:00:00+05:30     170.5000
# 14  LONG 2015-06-05 13:00:00+05:30 2015-06-08 09:00:00+05:30     169.8000
# 15  LONG 2015-06-16 13:00:00+05:30 2015-06-17 17:00:00+05:30     188.6000
# 16  LONG 2015-06-24 17:00:00+05:30 2015-06-25 09:00:00+05:30     176.9000
# 17  LONG 2015-07-06 17:00:00+05:30 2015-07-07 13:00:00+05:30     177.0000
# 18  LONG 2015-07-09 13:00:00+05:30 2015-07-09 21:00:00+05:30     172.2000
# 19  LONG 2015-07-13 09:00:00+05:30 2015-07-13 17:00:00+05:30     179.0000
# 20  LONG 2015-07-20 21:00:00+05:30 2015-07-21 17:00:00+05:30     182.9000
# 21  LONG 2015-07-24 21:00:00+05:30 2015-07-27 17:00:00+05:30     180.0000
# 22  LONG 2015-08-03 17:00:00+05:30 2015-08-04 09:00:00+05:30     179.3000
# 23  LONG 2015-08-07 17:00:00+05:30 2015-08-10 09:00:00+05:30     180.8000
# 24  LONG 2015-08-11 09:00:00+05:30 2015-08-11 21:00:00+05:30     182.9000
# 25  LONG 2015-08-19 17:00:00+05:30 2015-08-20 17:00:00+05:30     179.1000
# 26  LONG 2015-08-25 17:00:00+05:30 2015-08-26 13:00:00+05:30     178.9000
# 27  LONG 2015-08-27 21:00:00+05:30 2015-08-28 17:00:00+05:30     180.3000
# 28  LONG 2015-09-02 17:00:00+05:30 2015-09-03 17:00:00+05:30     178.6000
# 29  LONG 2015-09-04 13:00:00+05:30 2015-09-07 17:00:00+05:30     181.1000
# 30  LONG 2015-09-07 17:00:00+05:30 2015-09-08 17:00:00+05:30     181.4000
# 31  LONG 2015-09-11 17:00:00+05:30 2015-09-14 13:00:00+05:30     181.2000
# 32  LONG 2015-09-21 21:00:00+05:30 2015-09-22 13:00:00+05:30     170.9000
# 33  LONG 2015-09-25 17:00:00+05:30 2015-09-28 09:00:00+05:30     176.6000
# 34  LONG 2015-10-05 17:00:00+05:30 2015-10-06 13:00:00+05:30     163.3000
# 35  LONG 2015-10-08 17:00:00+05:30 2015-10-12 09:00:00+05:30     164.9000
# 36  LONG 2015-10-14 21:00:00+05:30 2015-10-15 13:00:00+05:30     165.0000
# 37  LONG 2015-10-28 09:00:00+05:30 2015-10-29 17:00:00+05:30     155.7000
# 38  LONG 2015-11-02 21:00:00+05:30 2015-11-03 13:00:00+05:30     150.3000
# 39  LONG 2015-11-04 17:00:00+05:30 2015-11-05 17:00:00+05:30     152.4000
# 40  LONG 2015-11-10 21:00:00+05:30 2015-11-13 21:00:00+05:30     157.2000
# 41  LONG 2015-12-01 09:00:00+05:30 2015-12-01 17:00:00+05:30     151.1000
# 42  LONG 2015-12-03 21:00:00+05:30 2015-12-04 13:00:00+05:30     147.7000
# 43  LONG 2015-12-08 13:00:00+05:30 2015-12-08 21:00:00+05:30     139.2000
# 44  LONG 2015-12-08 21:00:00+05:30 2015-12-09 13:00:00+05:30     140.1000
# 45  LONG 2015-12-17 09:00:00+05:30 2015-12-17 17:00:00+05:30     122.1000
# 46  LONG 2015-12-18 17:00:00+05:30 2015-12-21 09:00:00+05:30     119.9000
# 47  LONG 2016-01-06 09:00:00+05:30 2016-01-06 17:00:00+05:30     157.3000
# 48  LONG 2016-01-15 17:00:00+05:30 2016-01-18 21:00:00+05:30     145.6000
# 49  LONG 2016-01-20 13:00:00+05:30 2016-01-20 21:00:00+05:30     145.5000
# 50  LONG 2016-01-25 17:00:00+05:30 2016-01-27 09:00:00+05:30     146.5000
# 51  LONG 2016-02-03 13:00:00+05:30 2016-02-03 21:00:00+05:30     140.8000
# 52  LONG 2016-02-05 17:00:00+05:30 2016-02-08 09:00:00+05:30     140.9000
# 53  LONG 2016-02-16 17:00:00+05:30 2016-02-17 17:00:00+05:30     133.1000
# 54  LONG 2016-02-23 09:00:00+05:30 2016-02-23 17:00:00+05:30     126.1000
# 55  LONG 2016-02-29 21:00:00+05:30 2016-03-01 21:00:00+05:30     119.6000
# 56  LONG 2016-03-03 21:00:00+05:30 2016-03-07 17:00:00+05:30     114.5000
# 57  LONG 2016-03-16 13:00:00+05:30 2016-03-16 21:00:00+05:30     126.7000
# 58  LONG 2016-03-17 13:00:00+05:30 2016-03-17 21:00:00+05:30     127.3000
# 59  LONG 2016-03-22 17:00:00+05:30 2016-03-23 13:00:00+05:30     124.4000
# 60  LONG 2016-03-29 09:00:00+05:30 2016-03-29 17:00:00+05:30     131.0000
# 61  LONG 2016-04-05 17:00:00+05:30 2016-04-08 09:00:00+05:30     136.0000
# 62  LONG 2016-04-18 17:00:00+05:30 2016-04-19 17:00:00+05:30     129.9000
# 63  LONG 2016-04-21 17:00:00+05:30 2016-04-22 17:00:00+05:30     139.9000
# 64  LONG 2016-04-28 13:00:00+05:30 2016-04-29 21:00:00+05:30     143.6000
# 65  LONG 2016-05-03 17:00:00+05:30 2016-05-04 17:00:00+05:30     140.5000
# 66  LONG 2016-05-09 09:00:00+05:30 2016-05-09 17:00:00+05:30     140.8000
# 67  LONG 2016-05-19 21:00:00+05:30 2016-05-20 17:00:00+05:30     138.8000
# 68  LONG 2016-05-27 09:00:00+05:30 2016-05-27 17:00:00+05:30     145.0000
# 69  LONG 2016-06-08 17:00:00+05:30 2016-06-09 17:00:00+05:30     167.0000
# 70  LONG 2016-06-10 17:00:00+05:30 2016-06-13 13:00:00+05:30     174.6000
# 71  LONG 2016-06-14 21:00:00+05:30 2016-06-15 17:00:00+05:30     176.7000
# 72  LONG 2016-06-15 21:00:00+05:30 2016-06-16 17:00:00+05:30     177.0000
# 73  LONG 2016-06-17 17:00:00+05:30 2016-06-20 09:00:00+05:30     176.5000
# 74  LONG 2016-06-24 17:00:00+05:30 2016-06-27 13:00:00+05:30     182.7000
# 75  LONG 2016-07-04 13:00:00+05:30 2016-07-05 13:00:00+05:30     198.5000
# 76  LONG 2016-07-08 17:00:00+05:30 2016-07-11 09:00:00+05:30     190.3000
# 77  LONG 2016-07-12 13:00:00+05:30 2016-07-13 13:00:00+05:30     185.0000
# 78  LONG 2016-07-15 13:00:00+05:30 2016-07-15 21:00:00+05:30     183.0000
# 79  LONG 2016-07-21 17:00:00+05:30 2016-07-22 13:00:00+05:30     181.8000
# 80  LONG 2016-07-27 17:00:00+05:30 2016-07-28 17:00:00+05:30     183.8000
# 81  LONG 2016-08-02 17:00:00+05:30 2016-08-03 17:00:00+05:30     187.7000
# 82  LONG 2016-08-18 21:00:00+05:30 2016-08-22 17:00:00+05:30     180.5000
# 83  LONG 2016-08-29 17:00:00+05:30 2016-08-30 17:00:00+05:30     197.6000
# 84  LONG 2016-09-02 21:00:00+05:30 2016-09-05 21:00:00+05:30     189.6000
# 85  LONG 2016-09-07 17:00:00+05:30 2016-09-08 17:00:00+05:30     182.5000
# 86  LONG 2016-09-15 21:00:00+05:30 2016-09-16 17:00:00+05:30     197.0000
# 87  LONG 2016-09-26 21:00:00+05:30 2016-09-27 17:00:00+05:30     200.9000
# 88  LONG 2016-10-03 17:00:00+05:30 2016-10-05 09:00:00+05:30     196.1000
# 89  LONG 2016-10-17 17:00:00+05:30 2016-10-18 13:00:00+05:30     218.8000
# 90  LONG 2016-10-28 09:00:00+05:30 2016-10-28 17:00:00+05:30     207.5000
# 91  LONG 2016-11-03 21:00:00+05:30 2016-11-07 09:00:00+05:30     189.9000
# 92  LONG 2016-11-09 21:00:00+05:30 2016-11-14 17:00:00+05:30     182.9000
# 93  LONG 2016-11-16 17:00:00+05:30 2016-11-17 09:00:00+05:30     189.4000
# 94  LONG 2016-11-24 13:00:00+05:30 2016-11-24 21:00:00+05:30     209.4000
# 95  LONG 2016-11-30 21:00:00+05:30 2016-12-01 13:00:00+05:30     231.0000
# 96  LONG 2016-12-13 17:00:00+05:30 2016-12-15 09:00:00+05:30     241.6000
# 97  LONG 2016-12-16 21:00:00+05:30 2016-12-19 17:00:00+05:30     231.7000
# 98  LONG 2016-12-19 17:00:00+05:30 2016-12-21 17:00:00+05:30     233.8000
#
#     Initial SL  Final SL                 Exit Time  Exit Price  Points  \
# 0     165.4000  171.9000 2015-03-09 13:00:00+05:30    171.9000  1.7000
# 1     169.6000  169.6000 2015-03-11 17:00:00+05:30    169.6000 -3.9000
# 2     168.5000  174.8000 2015-03-12 21:00:00+05:30    174.8000 -4.6000
# 3     169.4000  175.0000 2015-03-19 17:00:00+05:30    175.0000  0.5000
# 4     166.1000  166.1000 2015-03-30 17:00:00+05:30    165.6000 -1.9000
# 5     164.7000  165.3000 2015-04-01 13:00:00+05:30    165.3000 -3.3000
# 6     162.2000  166.1000 2015-04-08 13:00:00+05:30    166.1000 -1.7000
# 7     155.7000  161.8000 2015-04-20 17:00:00+05:30    161.8000  2.4000
# 8     160.7000  163.1000 2015-04-23 17:00:00+05:30    163.1000 -0.9000
# 9     160.1000  176.5000 2015-05-06 13:00:00+05:30    176.5000 14.3000
# 10    177.2000  177.2000 2015-05-07 17:00:00+05:30    177.2000 -3.5000
# 11    174.5000  189.9000 2015-05-19 21:00:00+05:30    189.9000  8.2000
# 12    177.8000  181.8000 2015-05-28 13:00:00+05:30    181.8000 -0.5000
# 13    167.6000  167.6000 2015-06-02 17:00:00+05:30    167.6000 -2.9000
# 14    166.4000  181.1000 2015-06-11 21:00:00+05:30    181.1000 11.3000
# 15    182.5000  182.5000 2015-06-17 21:00:00+05:30    182.5000 -6.1000
# 16    172.7000  179.2000 2015-07-03 17:00:00+05:30    179.2000  2.3000
# 17    174.1000  174.1000 2015-07-07 17:00:00+05:30    174.1000 -2.9000
# 18    171.2000  171.2000 2015-07-09 21:00:00+05:30    169.9000 -2.3000
# 19    168.4000  180.9000 2015-07-17 17:00:00+05:30    180.9000  1.9000
# 20    177.7000  181.1000 2015-07-23 21:00:00+05:30    181.1000 -1.8000
# 21    176.2000  181.5000 2015-07-30 17:00:00+05:30    181.5000  1.5000
# 22    174.3000  178.0000 2015-08-06 09:00:00+05:30    178.0000 -1.3000
# 23    174.5000  180.5000 2015-08-11 13:00:00+05:30    180.5000 -0.3000
# 24    180.5000  183.1000 2015-08-14 13:00:00+05:30    183.1000  0.2000
# 25    176.1000  176.6000 2015-08-24 09:00:00+05:30    176.6000 -2.5000
# 26    175.6000  177.5000 2015-08-27 17:00:00+05:30    177.5000 -1.4000
# 27    175.8000  177.1000 2015-09-02 17:00:00+05:30    177.1000 -3.2000
# 28    176.0000  176.0000 2015-09-03 17:00:00+05:30    176.0000 -2.6000
# 29    177.9000  177.9000 2015-09-07 21:00:00+05:30    177.9000 -3.2000
# 30    177.6000  177.6000 2015-09-09 17:00:00+05:30    177.6000 -3.8000
# 31    177.8000  179.4000 2015-09-16 17:00:00+05:30    179.4000 -1.8000
# 32    168.0000  170.0000 2015-09-23 21:00:00+05:30    170.0000 -0.9000
# 33    167.2000  177.3000 2015-09-29 13:00:00+05:30    177.3000  0.7000
# 34    159.5000  160.9000 2015-10-08 17:00:00+05:30    160.9000 -2.4000
# 35    161.3000  163.3000 2015-10-13 21:00:00+05:30    163.3000 -1.6000
# 36    161.7000  161.7000 2015-10-15 17:00:00+05:30    161.7000 -3.3000
# 37    147.9000  147.9000 2015-10-30 09:00:00+05:30    147.9000 -7.8000
# 38    147.3000  149.1000 2015-11-04 21:00:00+05:30    149.1000 -1.2000
# 39    149.0000  154.1000 2015-11-09 17:00:00+05:30    154.1000  1.7000
# 40    148.6000  153.9000 2015-11-19 21:00:00+05:30    153.9000 -3.3000
# 41    147.5000  148.3000 2015-12-01 21:00:00+05:30    148.3000 -2.8000
# 42    143.2000  143.2000 2015-12-07 09:00:00+05:30    143.2000 -4.5000
# 43    136.9000  136.9000 2015-12-08 21:00:00+05:30    136.9000 -2.3000
# 44    135.5000  137.7000 2015-12-10 13:00:00+05:30    137.7000 -2.4000
# 45    118.8000  118.8000 2015-12-17 21:00:00+05:30    118.8000 -3.3000
# 46    114.2000  153.3000 2016-01-04 13:00:00+05:30    153.3000 33.4000
# 47    150.8000  158.8000 2016-01-12 09:00:00+05:30    158.7000  1.4000
# 48    138.5000  141.3000 2016-01-19 21:00:00+05:30    141.3000 -4.3000
# 49    140.7000  143.1000 2016-01-25 09:00:00+05:30    143.1000 -2.4000
# 50    140.9000  153.1000 2016-02-01 09:00:00+05:30    153.1000  6.6000
# 51    135.2000  136.3000 2016-02-04 13:00:00+05:30    136.3000 -4.5000
# 52    132.8000  140.8000 2016-02-10 17:00:00+05:30    140.8000 -0.1000
# 53    129.2000  129.8000 2016-02-18 17:00:00+05:30    129.8000 -3.3000
# 54    121.4000  121.4000 2016-02-24 09:00:00+05:30    121.4000 -4.7000
# 55    116.5000  116.5000 2016-03-01 21:00:00+05:30    116.5000 -3.1000
# 56    109.0000  124.0000 2016-03-16 17:00:00+05:30    124.0000  9.5000
# 57    124.0000  124.0000 2016-03-17 17:00:00+05:30    124.0000 -2.7000
# 58    123.0000  123.0000 2016-03-17 21:00:00+05:30    122.8000 -4.5000
# 59    120.8000  123.2000 2016-03-23 21:00:00+05:30    123.2000 -1.2000
# 60    117.2000  130.8000 2016-03-31 21:00:00+05:30    130.8000 -0.2000
# 61    126.4000  132.6000 2016-04-11 09:00:00+05:30    132.5000 -3.5000
# 62    126.2000  136.5000 2016-04-21 13:00:00+05:30    136.5000  6.6000
# 63    136.1000  136.1000 2016-04-22 17:00:00+05:30    136.1000 -3.8000
# 64    141.3000  141.3000 2016-04-29 21:00:00+05:30    140.4000 -3.2000
# 65    136.3000  138.3000 2016-05-06 13:00:00+05:30    138.3000 -2.2000
# 66    136.8000  141.5000 2016-05-13 09:00:00+05:30    141.5000  0.7000
# 67    133.0000  138.5000 2016-05-24 17:00:00+05:30    138.5000 -0.3000
# 68    131.8000  162.4000 2016-06-07 17:00:00+05:30    162.4000 17.4000
# 69    163.6000  171.5000 2016-06-10 17:00:00+05:30    171.5000  4.5000
# 70    171.0000  171.0000 2016-06-14 17:00:00+05:30    171.0000 -3.6000
# 71    171.0000  174.2000 2016-06-15 21:00:00+05:30    174.2000 -2.5000
# 72    174.2000  174.2000 2016-06-16 17:00:00+05:30    173.7000 -3.3000
# 73    172.2000  183.9000 2016-06-22 21:00:00+05:30    183.9000  7.4000
# 74    179.7000  195.1000 2016-07-04 09:00:00+05:30    195.1000 12.4000
# 75    194.7000  194.7000 2016-07-05 17:00:00+05:30    194.7000 -3.8000
# 76    185.7000  185.7000 2016-07-11 17:00:00+05:30    185.7000 -4.6000
# 77    180.7000  181.4000 2016-07-14 17:00:00+05:30    181.4000 -3.6000
# 78    181.1000  181.1000 2016-07-15 21:00:00+05:30    180.6000 -2.4000
# 79    176.6000  180.7000 2016-07-27 09:00:00+05:30    180.6000 -1.2000
# 80    178.9000  190.8000 2016-08-01 09:00:00+05:30    190.8000  7.0000
# 81    183.0000  190.0000 2016-08-04 17:00:00+05:30    190.0000  2.3000
# 82    173.5000  193.9000 2016-08-29 21:00:00+05:30    193.9000 13.4000
# 83    193.1000  193.1000 2016-08-30 17:00:00+05:30    193.1000 -4.5000
# 84    185.8000  185.8000 2016-09-05 21:00:00+05:30    183.1000 -6.5000
# 85    177.5000  195.5000 2016-09-14 17:00:00+05:30    195.5000 13.0000
# 86    190.0000  203.1000 2016-09-22 17:00:00+05:30    203.1000  6.1000
# 87    197.4000  197.8000 2016-09-28 17:00:00+05:30    197.8000 -3.1000
# 88    192.0000  214.6000 2016-10-12 17:00:00+05:30    214.6000 18.5000
# 89    214.9000  214.9000 2016-10-19 13:00:00+05:30    214.9000 -3.9000
# 90    201.2000  202.4000 2016-11-01 09:00:00+05:30    202.4000 -5.1000
# 91    183.8000  186.2000 2016-11-08 13:00:00+05:30    186.2000 -3.7000
# 92    172.7000  182.7000 2016-11-16 17:00:00+05:30    182.7000 -0.2000
# 93    182.4000  201.4000 2016-11-23 17:00:00+05:30    201.4000 12.0000
# 94    206.5000  225.5000 2016-11-30 13:00:00+05:30    225.5000 16.1000
# 95    225.3000  246.4000 2016-12-08 09:00:00+05:30    246.4000 15.4000
# 96    232.6000  232.6000 2016-12-15 21:00:00+05:30    232.6000 -9.0000
# 97    227.0000  227.0000 2016-12-19 17:00:00+05:30    227.0000 -4.7000
# 98    221.1000  255.3000 2016-12-30 17:00:00+05:30    255.3000 21.5000
#
#     Slippages         Qty          PnL     PnL w cs    ROI%  Trade Year  \
# 0      0.3421  20833.3333   35416.6667   28289.5833  0.2829        2015
# 1      0.3431  25641.0256 -100000.0000 -108797.4359 -1.0880        2015
# 2      0.3542   9174.3119  -42201.8349  -45451.3761 -0.4545        2015
# 3      0.3495  19607.8431    9803.9216    2950.9804  0.0295        2015
# 4      0.3331  71428.5714 -135714.2857 -159507.1429 -1.5951        2015
# 5      0.3339  25641.0256  -84615.3846  -93176.9231 -0.9318        2015
# 6      0.3339  17857.1429  -30357.1429  -36319.6429 -0.3632        2015
# 7      0.3212  27027.0270   64864.8649   56183.7838  0.5618        2015
# 8      0.3271  30303.0303  -27272.7273  -37184.8485 -0.3718        2015
# 9      0.3387  47619.0476  680952.3810  664823.8095  6.6482        2015
# 10     0.3579  28571.4286 -100000.0000 -110225.7143 -1.1023        2015
# 11     0.3716  13888.8889  113888.8889  108727.7778  1.0873        2015
# 12     0.3641  22222.2222  -11111.1111  -19202.2222 -0.1920        2015
# 13     0.3381  34482.7586 -100000.0000 -111658.6207 -1.1166        2015
# 14     0.3509  29411.7647  332352.9412  322032.3529  3.2203        2015
# 15     0.3711  16393.4426 -100000.0000 -106083.6066 -1.0608        2015
# 16     0.3561  23809.5238   54761.9048   46283.3333  0.4628        2015
# 17     0.3511  34482.7586 -100000.0000 -112106.8966 -1.1211        2015
# 18     0.3421 100000.0000 -230000.0000 -264210.0000 -2.6421        2015
# 19     0.3599   9433.9623   17924.5283   14529.2453  0.1453        2015
# 20     0.3640  19230.7692  -34615.3846  -41615.3846 -0.4162        2015
# 21     0.3615  26315.7895   39473.6842   29960.5263  0.2996        2015
# 22     0.3573  20000.0000  -26000.0000  -33146.0000 -0.3315        2015
# 23     0.3613  15873.0159   -4761.9048  -10496.8254 -0.1050        2015
# 24     0.3660  41666.6667    8333.3333   -6916.6667 -0.0692        2015
# 25     0.3557  33333.3333  -83333.3333  -95190.0000 -0.9519        2015
# 26     0.3564  30303.0303  -42424.2424  -53224.2424 -0.5322        2015
# 27     0.3574  22222.2222  -71111.1111  -79053.3333 -0.7905        2015
# 28     0.3546  38461.5385 -100000.0000 -113638.4615 -1.1364        2015
# 29     0.3590  31250.0000 -100000.0000 -111218.7500 -1.1122        2015
# 30     0.3590  26315.7895 -100000.0000 -109447.3684 -1.0945        2015
# 31     0.3606  29411.7647  -52941.1765  -63547.0588 -0.6355        2015
# 32     0.3409  34482.7586  -31034.4828  -42789.6552 -0.4279        2015
# 33     0.3539  10638.2979    7446.8085    3681.9149  0.0368        2015
# 34     0.3242  26315.7895  -63157.8947  -71689.4737 -0.7169        2015
# 35     0.3282  27777.7778  -44444.4444  -53561.1111 -0.5356        2015
# 36     0.3267  30303.0303 -100000.0000 -109900.0000 -1.0990        2015
# 37     0.3036  12820.5128 -100000.0000 -103892.3077 -1.0389        2015
# 38     0.2994  33333.3333  -40000.0000  -49980.0000 -0.4998        2015
# 39     0.3065  29411.7647   50000.0000   40985.2941  0.4099        2015
# 40     0.3111  11627.9070  -38372.0930  -41989.5349 -0.4199        2015
# 41     0.2994  27777.7778  -77777.7778  -86094.4444 -0.8609        2015
# 42     0.2909  22222.2222 -100000.0000 -106464.4444 -1.0646        2015
# 43     0.2761  43478.2609 -100000.0000 -112004.3478 -1.1200        2015
# 44     0.2778  21739.1304  -52173.9130  -58213.0435 -0.5821        2015
# 45     0.2409  30303.0303 -100000.0000 -107300.0000 -1.0730        2015
# 46     0.2732  17543.8596  585964.9123  581171.9298  5.8117        2015
# 47     0.3160  15384.6154   21538.4615   16676.9231  0.1668        2016
# 48     0.2869  14084.5070  -60563.3803  -64604.2254 -0.6460        2016
# 49     0.2886  20833.3333  -50000.0000  -56012.5000 -0.5601        2016
# 50     0.2996  17857.1429  117857.1429  112507.1429  1.1251        2016
# 51     0.2771  17857.1429  -80357.1429  -85305.3571 -0.8531        2016
# 52     0.2817  12345.6790   -1234.5679   -4712.3457 -0.0471        2016
# 53     0.2629  25641.0256  -84615.3846  -91356.4103 -0.9136        2016
# 54     0.2475  21276.5957 -100000.0000 -105265.9574 -1.0527        2016
# 55     0.2361  32258.0645 -100000.0000 -107616.1290 -1.0762        2016
# 56     0.2385  18181.8182  172727.2727  168390.9091  1.6839        2016
# 57     0.2507  37037.0370 -100000.0000 -109285.1852 -1.0929        2016
# 58     0.2501  23255.8140 -104651.1628 -110467.4419 -1.1047        2016
# 59     0.2476  27777.7778  -33333.3333  -40211.1111 -0.4021        2016
# 60     0.2618   7246.3768   -1449.2754   -3346.3768 -0.0335        2016
# 61     0.2685  10416.6667  -36458.3333  -39255.2083 -0.3926        2016
# 62     0.2664  27027.0270  178378.3784  171178.3784  1.7118        2016
# 63     0.2760  26315.7895 -100000.0000 -107263.1579 -1.0726        2016
# 64     0.2840  43478.2609 -139130.4348 -151478.2609 -1.5148        2016
# 65     0.2788  23809.5238  -52380.9524  -59019.0476 -0.5902        2016
# 66     0.2823  25000.0000   17500.0000   10442.5000  0.1044        2016
# 67     0.2773  17241.3793   -5172.4138   -9953.4483 -0.0995        2016
# 68     0.3074   7575.7576  131818.1818  129489.3939  1.2949        2016
# 69     0.3385  29411.7647  132352.9412  122397.0588  1.2240        2016
# 70     0.3456  27777.7778 -100000.0000 -109600.0000 -1.0960        2016
# 71     0.3509  17543.8596  -43859.6491  -50015.7895 -0.5002        2016
# 72     0.3507  35714.2857 -117857.1429 -130382.1429 -1.3038        2016
# 73     0.3604  23255.8140  172093.0233  163711.6279  1.6371        2016
# 74     0.3778  33333.3333  413333.3333  400740.0000  4.0074        2016
# 75     0.3932  26315.7895 -100000.0000 -110347.3684 -1.1035        2016
# 76     0.3760  21739.1304 -100000.0000 -108173.9130 -1.0817        2016
# 77     0.3664  23255.8140  -83720.9302  -92241.8605 -0.9224        2016
# 78     0.3636  52631.5789 -126315.7895 -145452.6316 -1.4545        2016
# 79     0.3624  19230.7692  -23076.9231  -30046.1538 -0.3005        2016
# 80     0.3746  20408.1633  142857.1429  135212.2449  1.3521        2016
# 81     0.3777  21276.5957   48936.1702   40900.0000  0.4090        2016
# 82     0.3744  14285.7143  191428.5714  186080.0000  1.8608        2016
# 83     0.3907  22222.2222 -100000.0000 -108682.2222 -1.0868        2016
# 84     0.3727  26315.7895 -171052.6316 -180860.5263 -1.8086        2016
# 85     0.3780  20000.0000  260000.0000  252440.0000  2.5244        2016
# 86     0.4001  14285.7143   87142.8571   81427.1429  0.8143        2016
# 87     0.3987  28571.4286  -88571.4286  -99962.8571 -0.9996        2016
# 88     0.4107  24390.2439  451219.5122  441202.4390  4.4120        2016
# 89     0.4337  25641.0256 -100000.0000 -111120.5128 -1.1112        2016
# 90     0.4099  15873.0159  -80952.3810  -87458.7302 -0.8746        2016
# 91     0.3761  16393.4426  -60655.7377  -66821.3115 -0.6682        2016
# 92     0.3656   9803.9216   -1960.7843   -5545.0980 -0.0555        2016
# 93     0.3908  14285.7143  171428.5714  165845.7143  1.6585        2016
# 94     0.4349  34482.7586  555172.4138  540175.8621  5.4018        2016
# 95     0.4774  17543.8596  270175.4386  261800.0000  2.6180        2016
# 96     0.4742  11111.1111 -100000.0000 -105268.8889 -1.0527        2016
# 97     0.4587  21276.5957 -100000.0000 -109759.5745 -1.0976        2016
# 98     0.4891   7874.0157  169291.3386  165440.1575  1.6544        2016
#
#     ROI% w cs
# 0      0.2829
# 1     -1.0880
# 2     -0.4545
# 3      0.0295
# 4     -1.5951
# 5     -0.9318
# 6     -0.3632
# 7      0.5618
# 8     -0.3718
# 9      6.6482
# 10    -1.1023
# 11     1.0873
# 12    -0.1920
# 13    -1.1166
# 14     3.2203
# 15    -1.0608
# 16     0.4628
# 17    -1.1211
# 18    -2.6421
# 19     0.1453
# 20    -0.4162
# 21     0.2996
# 22    -0.3315
# 23    -0.1050
# 24    -0.0692
# 25    -0.9519
# 26    -0.5322
# 27    -0.7905
# 28    -1.1364
# 29    -1.1122
# 30    -1.0945
# 31    -0.6355
# 32    -0.4279
# 33     0.0368
# 34    -0.7169
# 35    -0.5356
# 36    -1.0990
# 37    -1.0389
# 38    -0.4998
# 39     0.4099
# 40    -0.4199
# 41    -0.8609
# 42    -1.0646
# 43    -1.1200
# 44    -0.5821
# 45    -1.0730
# 46     5.8117
# 47     0.1668
# 48    -0.6460
# 49    -0.5601
# 50     1.1251
# 51    -0.8531
# 52    -0.0471
# 53    -0.9136
# 54    -1.0527
# 55    -1.0762
# 56     1.6839
# 57    -1.0929
# 58    -1.1047
# 59    -0.4021
# 60    -0.0335
# 61    -0.3926
# 62     1.7118
# 63    -1.0726
# 64    -1.5148
# 65    -0.5902
# 66     0.1044
# 67    -0.0995
# 68     1.2949
# 69     1.2240
# 70    -1.0960
# 71    -0.5002
# 72    -1.3038
# 73     1.6371
# 74     4.0074
# 75    -1.1035
# 76    -1.0817
# 77    -0.9224
# 78    -1.4545
# 79    -0.3005
# 80     1.3521
# 81     0.4090
# 82     1.8608
# 83    -1.0868
# 84    -1.8086
# 85     2.5244
# 86     0.8143
# 87    -0.9996
# 88     4.4120
# 89    -1.1112
# 90    -0.8746
# 91    -0.6682
# 92    -0.0555
# 93     1.6585
# 94     5.4018
# 95     2.6180
# 96    -1.0527
# 97    -1.0976
# 98     1.6544

# %%
tb2['Points'].sum()
# Out:
# -22.19999999999999

# %% [markdown]
# # Change No. 1 :
# ## Alternate King and Queen candle for trailing
#
# # Change No. 2 :
# ## Confirmation to be done based on candle closing. CHECK FORWARD BIAS
