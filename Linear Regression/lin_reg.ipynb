# %%
# Linear Regression

# %%
import datetime as dt

import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

import sys

sys.path.append("..")
from fetching_from_local_db.enums import AssetClass, Index, StrikeSpread
from fetching_from_local_db.fetch_from_db import (
    _fetch_batch,
    fetch_data,
    fetch_spot_data,
)
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
def get_expiry(f_today):
    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry

# %%
async def get_expiry(f_today, symbol):
    if symbol == 'bnf':
        if (f_today <= dt.date(2024, 1, 25)) and (f_today >= dt.date(2024, 1, 18)):
            f_expiry = dt.date(2024, 1, 25)
        elif (f_today <= dt.date(2024, 1, 31)) and (f_today >= dt.date(2024, 1, 26)):
            f_expiry = dt.date(2024, 1, 31)
        elif (f_today <= dt.date(2024, 2, 22)) and (f_today >= dt.date(2024, 2, 29)):
            f_expiry = dt.date(2024, 2, 29)
        elif (f_today <= dt.date(2024, 3, 25)) and (f_today >= dt.date(2024, 3, 27)):
            f_expiry = dt.date(2024, 2, 27)
        elif f_today < dt.date(2023, 9, 1):
            days_to_thursday = (3 - f_today.weekday()) % 7
            nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
            f_expiry = nearest_thursday
            if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
                f_expiry = nearest_thursday - dt.timedelta(days=1)
        elif f_today >= dt.date(2023, 9, 1):
            if f_today.day < 24:
                days_to_wednesday = (2 - f_today.weekday()) % 7
                nearest_wednesday = f_today + dt.timedelta(days=days_to_wednesday)
                f_expiry = nearest_wednesday
                if nse.valid_days(
                    start_date=nearest_wednesday, end_date=nearest_wednesday
                ).empty:
                    f_expiry = nearest_wednesday - dt.timedelta(days=1)
            else:
                days_to_thursday = (3 - f_today.weekday()) % 7
                nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
                f_expiry = nearest_thursday
                if nse.valid_days(
                    start_date=nearest_thursday, end_date=nearest_thursday
                ).empty:
                    f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry
    elif symbol == 'nifty':
        days_to_thursday = (3 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif symbol == 'fnf':
        days_to_thursday = (1 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif symbol == 'midcp':
        days_to_thursday = (0 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    else:
        return 0

# %%
def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"

# %%
bnf_pandas = pd.read_csv("../data/bnf.csv")

# %%
symbol = 'bnf'
# symbol = 'nifty'
# symbol = 'fnf'
# symbol = 'midcp'

if symbol == 'bnf':
    LEVERAGE_ = 5
    LOT_SIZE_ = 15
    SLIPPAGE_ = 0.01
    SPREAD_ = 100
elif symbol == 'nifty' or 'fnf':
    LEVERAGE_ = 7
    LOT_SIZE_ = 25
    SLIPPAGE_ = 0.01
    SPREAD_ = 50
elif symbol == 'midcp':
    LEVERAGE_ = 10
    LOT_SIZE_ = 50
    SLIPPAGE_ = 0.01
    SPREAD_ = 25

PORTFOLIO = 10000000

# %%
bnf_pandas.tail()
# Out:
#                    datetime       open       high        low      close  \
# 687621  2024-06-07 15:25:00 49800.4500 49812.7500 49792.7000 49806.2000
# 687622  2024-06-07 15:26:00 49807.2500 49811.7000 49798.7500 49807.5000
# 687623  2024-06-07 15:27:00 49810.8500 49823.8000 49797.6000 49817.3000
# 687624  2024-06-07 15:28:00 49816.2500 49827.6000 49805.8000 49816.0000
# 687625  2024-06-07 15:29:00 49820.3000 49825.0000 49805.2500 49806.6000
#
#         volume
# 687621       0
# 687622       0
# 687623       0
# 687624       0
# 687625       0

# %%
# If Stocks Data ...
bnf_pandas["datetime"] = pd.to_datetime(bnf_pandas["datetime"])
bnf_pandas["datetime"] = bnf_pandas["datetime"].dt.tz_localize(None)
bnf_pandas = bnf_pandas[bnf_pandas["datetime"].dt.year >= 2017]
# bnf_pandas.drop(columns=["datetime"], inplace=True)
# bnf_pandas

# %%
bnf = pl.DataFrame(bnf_pandas)
print(type(bnf))
# bnf
# Out:
# <class 'polars.dataframe.frame.DataFrame'>

# %%
# # For crude oil Data
# bnf1 = pd.DataFrame(bnf_pandas)
# bnf1 = bnf1.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
# bnf1['datetime'] = pd.to_datetime(bnf1['datetime'])
# bnf1['index'] = bnf1['datetime']
# bnf1.rename(columns={'o': 'open', 'h': 'high', 'l': 'low', 'c': 'close'}, inplace=True)
# bnf = pl.DataFrame(bnf1)
# print(type(bnf))
# bnf

# %%
# bnf['datetime'] = pd.to_datetime(bnf['datetime'])
# bnf = bnf.drop(columns=['Unnamed: 0'])
# bnf.set_index(bnf['datetime'], inplace=True)
# bnf
# bnf = bnf.with_columns(pl.col('datetime').str.to_datetime(format='%Y-%m-%dT%H:%M:%S.%f'))
# print(bnf)
# bnf = bnf.with_columns(pl.col('datetime').cast(pl.DateTime))

# Set 'datetime' column as index
bnf = bnf.with_columns([pl.col("datetime").alias("index")]).drop("datetime")

# Now 'datetime' is set as the index
# bnf

# %%
bnf = bnf.with_columns(pl.col("index").alias("datetime"))
# bnf

# %%
bnf.tail()
# Out:
# shape: (5, 7)
# ┌──────────┬──────────┬──────────┬─────────┬────────┬─────────────────────┬─────────────────────┐
# │ open     ┆ high     ┆ low      ┆ close   ┆ volume ┆ index               ┆ datetime            │
# │ ---      ┆ ---      ┆ ---      ┆ ---     ┆ ---    ┆ ---                 ┆ ---                 │
# │ f64      ┆ f64      ┆ f64      ┆ f64     ┆ i64    ┆ datetime[ns]        ┆ datetime[ns]        │
# ╞══════════╪══════════╪══════════╪═════════╪════════╪═════════════════════╪═════════════════════╡
# │ 49800.45 ┆ 49812.75 ┆ 49792.7  ┆ 49806.2 ┆ 0      ┆ 2024-06-07 15:25:00 ┆ 2024-06-07 15:25:00 │
# │ 49807.25 ┆ 49811.7  ┆ 49798.75 ┆ 49807.5 ┆ 0      ┆ 2024-06-07 15:26:00 ┆ 2024-06-07 15:26:00 │
# │ 49810.85 ┆ 49823.8  ┆ 49797.6  ┆ 49817.3 ┆ 0      ┆ 2024-06-07 15:27:00 ┆ 2024-06-07 15:27:00 │
# │ 49816.25 ┆ 49827.6  ┆ 49805.8  ┆ 49816.0 ┆ 0      ┆ 2024-06-07 15:28:00 ┆ 2024-06-07 15:28:00 │
# │ 49820.3  ┆ 49825.0  ┆ 49805.25 ┆ 49806.6 ┆ 0      ┆ 2024-06-07 15:29:00 ┆ 2024-06-07 15:29:00 │
# └──────────┴──────────┴──────────┴─────────┴────────┴─────────────────────┴─────────────────────┘

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("o").first().alias("o"),
                pl.col("h").max().alias("h"),
                pl.col("l").min().alias("l"),
                pl.col("c").last().alias("c"),
                # pl.col("volume").sum().alias("volume"),
            ]
        )
    )

# ohlc_resampled = resample(bnf, '60m', pd.Timedelta(minutes=15))

# bnf_df = bnf.to_pandas()
# bnf_df.set_index(bnf_df['datetime'], inplace=True)
# ohlc_15min = bnf_df.resample('60min').agg({
#     'open': 'first',
#     'high': 'max',
#     'low': 'min',
#     'close': 'last',
# })

# ohlc_15min.dropna(inplace=True)

# ohlc_15min.reset_index(inplace=True)

# bnf_1hr = ohlc_15min
# bnf_1hr = ohlc_resampled
# bnf_final = bnf_1hr.to_pandas()
# bnf_final['datetime'] = pd.to_datetime(bnf_final['datetime'])
# bnf_final
# bnf_1hr

# %%
# bnf_final = bnf
# bnf_final

# %%
# # bnf_final = bnf_1hr
# bnf_final['datetime'] = pd.to_datetime(bnf_final['datetime'])
# bnf_final

# %%
import pandas as pd
import numpy as np

def linear_regression_vectorized(df, period, trailing):
    
    if 'c' not in df.columns:
        print(df.columns)
        raise ValueError("The DataFrame must contain a 'close' column.")

    df['c'] = df['c'].astype(float)
    x = np.arange(period)
    x_sum = np.sum(x)
    x_squared_sum = np.sum(x**2)
    
    denominator = period * x_squared_sum - x_sum**2
    
    y_rolling = df['c'].rolling(window=period)
    
    y_sum = y_rolling.sum()
    xy_sum = y_rolling.apply(lambda y: np.dot(x, y), raw=True)
    
    slope = (period * xy_sum - x_sum * y_sum) / denominator
    intercept = (y_sum - slope * x_sum) / period
    
    predicted_values = intercept + slope * (period - 1)
    df['LR'] = predicted_values

    x = np.arange(trailing)
    x_sum = np.sum(x)
    x_squared_sum = np.sum(x**2)
    
    denominator = trailing * x_squared_sum - x_sum**2
    
    y_rolling = df['c'].rolling(window=trailing)
    
    y_sum = y_rolling.sum()
    xy_sum = y_rolling.apply(lambda y: np.dot(x, y), raw=True)
    
    slope = (trailing * xy_sum - x_sum * y_sum) / denominator
    intercept = (y_sum - slope * x_sum) / trailing
    
    predicted_values = intercept + slope * (trailing - 1)
    df['LR2'] = predicted_values
    
    return df

# data = linear_regression_vectorized(bnf.to_pandas(), 20)

# %%
# Positional

def execute(df, n):

    trade_book = []
    in_trade = False
    signal_entry_price = 100000
    signal_initial_sl = 0
    already_signal_exists = False
    is_trailing_active = False
    remark = ""
    portfolio_value = 1_00_00_000

    for i in range(1, len(df)):
        points = 0
        current_candle_open = df.iloc[i]["o"]
        current_candle_high = df.iloc[i]["h"]
        current_candle_low = df.iloc[i]["l"]
        current_candle_close = df.iloc[i]["c"]
        current_linear_regression = df.iloc[i]['LR2']

        if not in_trade:
            if df.iloc[i]["Buy_Signal"] == 1:
                if not already_signal_exists:
                    # Fresh Buy Signal
                    # print(df.iloc[i])
                    # print('Fresh Buy Signal')
                    signal_entry_price = current_candle_high
                    # signal_initial_sl = current_candle_low
                    signal_initial_sl = df.iloc[i-n+1:i+1]['l'].min()
                    signal_creation_time = df.iloc[i]["datetime"]
                    already_signal_exists = True

                else:
                    if current_candle_open > signal_entry_price:
                        # Gap Up Open, SKIP trade
                        # print(df.iloc[i])
                        # print('Gap Up Open, Skip Trade')
                        already_signal_exists = False
                        signal_entry_price = 100000
                        signal_initial_sl = 0
                    elif current_candle_high < signal_entry_price:
                        # Better Candle
                        # print(df.iloc[i])
                        # print('Better Candle')
                        signal_entry_price = current_candle_high
                        # signal_initial_sl = current_candle_low
                        signal_initial_sl = df.iloc[i-n+1:i+1]['l'].min()
                        signal_creation_time = df.iloc[i]["datetime"]

                        # if (signal_entry_price - signal_initial_sl > 400):
                        #     # Skip Signal Candle Due To Big Size
                        #     already_signal_exists = False
                        #     signal_entry_price = 100000
                        #     signal_initial_sl = 0

                    elif current_candle_high > signal_entry_price:
                        # Entry Triggered
                        # print(df.iloc[i])
                        # print('Entry Triggered')
                        in_trade = True
                        entry_time = df.iloc[i]["datetime"]
                        entry_price = signal_entry_price
                        points = 0
            else:
                if df.iloc[i - 1]["Buy_Signal"] == 1:
                    # Considering the forward bias condition as well now
                    signal_entry_price = df.iloc[i - 1]["h"]
                    # signal_initial_sl = df.iloc[i - 1]["l"]
                    signal_initial_sl = df.iloc[i-n:i]['l'].min()
                    signal_creation_time = df.iloc[i - 1]["datetime"]
                    already_signal_exists = True

                    if current_candle_high > signal_entry_price:
                        in_trade = True
                        entry_time = df.iloc[i]["datetime"]
                        entry_price = signal_entry_price
                        points = 0
                    else:
                        # Discard Existing Signal
                        already_signal_exists = False
                        signal_entry_price = 100000
                        signal_initial_sl = 0

        if in_trade:
            trade_entry_price = signal_entry_price
            trade_initial_sl = signal_initial_sl
            trade_final_sl = signal_initial_sl

            if (
                not is_trailing_active
                and current_candle_low > current_linear_regression
            ):
                is_trailing_active = True

            if not is_trailing_active:
                if current_candle_open < trade_initial_sl:
                    # if df.iloc[i-1]['l'] < trade_initial_sl:
                    #     #Previous Candle Already Hit the SL Hence don't check gap down
                    #     print(df.iloc[i])
                    #     print('Initial SL Hit Before Gap Down')
                    #     in_trade = False
                    #     points = trade_initial_sl - trade_entry_price
                    #     exit_price = trade_initial_sl
                    #     exit_time = df.iloc[i-1]['datetime']
                    #     remark = 'Initial SL Hit Before Gap Down'
                    # else:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        if current_candle_close <= trade_initial_sl:
                            in_trade = False
                            points = trade_initial_sl - trade_entry_price
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL hit"

                    else:
                        # Gap Open Outside ISL
                        # print(df.iloc[i])
                        # print('Gap Open Outside ISL')
                        in_trade = False
                        points = current_candle_open - trade_entry_price
                        exit_price = current_candle_open
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif current_candle_low <= trade_initial_sl:
                    # Initial SL Hit
                    # print(df.iloc[i])
                    # print('Initial SL Hit')
                    in_trade = False
                    points = trade_initial_sl - trade_entry_price
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL Hit"

            else:
                trade_final_sl = max(trade_initial_sl, current_linear_regression)

                if current_candle_open <= trade_initial_sl:
                    # if df.iloc[i-1]['l'] < trade_initial_sl:
                    #     #Previous Candle Already Hit the SL Hence don't check gap down
                    #     print(df.iloc[i])
                    #     print('Initial SL Hit Before Gap Down')
                    #     in_trade = False
                    #     points = trade_initial_sl - trade_entry_price
                    #     exit_price = trade_initial_sl
                    #     exit_time = df.iloc[i-1]['datetime']
                    #     remark = 'Initial SL Hit'
                    # else:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        if current_candle_close <= trade_initial_sl:
                            in_trade = False
                            points = trade_initial_sl - trade_entry_price
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL hit"

                    else:
                        # Gap Open Outside ISL
                        # print(df.iloc[i])
                        # print('Gap Open Outside ISL')
                        in_trade = False
                        points = current_candle_open - trade_entry_price
                        exit_price = current_candle_open
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif current_candle_low <= trade_initial_sl:
                    # if trade_initial_sl >= current_linear_regression:
                    # Despite Trailing, Initial SL hit
                    # print(df.iloc[i])
                    # print('Initial SL Hit')
                    in_trade = False
                    points = trade_initial_sl - trade_entry_price
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL hit"

                elif current_candle_close <= trade_final_sl:
                    # Price Closed below TSL i.e. MA10 , TSL Hit
                    # print(df.iloc[i])
                    # print('Initial SL Hit')
                    in_trade = False
                    points = current_candle_close - trade_entry_price
                    exit_price = current_candle_close
                    exit_time = df.iloc[i]["datetime"]
                    is_trailing_active = False
                    remark = "TSL Hit"

            if points:
                index_lev = 6
                qty = int(round(portfolio_value * LEVERAGE_ / entry_price / LOT_SIZE_)) * LOT_SIZE_
                slippage = SLIPPAGE_ * (entry_price + exit_price)
                # slippage = 10
                final_points = points - slippage
                # final_points = points
                trade = {
                    "Signal Generated At": signal_creation_time,
                    "Trade Type": "LONG",
                    "Entry Time": entry_time,
                    "Entry Price": entry_price,
                    "Initial SL": trade_initial_sl,
                    "Final SL": trade_final_sl,
                    "Exit Time": exit_time,
                    "Exit Price": exit_price,
                    "Points Captured": points,
                    "After Costs": final_points,
                    "PnL": final_points * qty,
                    "Remarks": remark,
                    "Qty": qty,
                    "Leverage": index_lev,
                    "ROI%": (final_points * qty / portfolio_value) * 100,
                    "Trade Year": entry_time.year,
                    "Trade Month": entry_time.month,
                }
                trade_book.append(trade)
                points = 0
                in_trade = False
                already_signal_exists = False
                remark = ""
                is_trailing_active = False

    trade_book_df = pd.DataFrame(trade_book)
    return trade_book_df

# %%
# Positional Short

def execute_short(df, n):

    trade_book = []
    in_trade = False
    signal_entry_price = 100000
    signal_initial_sl = 0
    already_signal_exists = False
    is_trailing_active = False
    remark = ""
    portfolio_value = 1_00_00_000

    for i in range(1, len(df)):
        points = 0
        current_candle_open = df.iloc[i]["o"]
        current_candle_high = df.iloc[i]["h"]
        current_candle_low = df.iloc[i]["l"]
        current_candle_close = df.iloc[i]["c"]
        current_linear_regression = df.iloc[i]['LR2']

        if not in_trade:
            if df.iloc[i]["Sell_Signal"] == 1:
                if not already_signal_exists:
                    # Fresh Buy Signal
                    # print(df.iloc[i])
                    # print('Fresh Buy Signal')
                    signal_entry_price = current_candle_low
                    # signal_initial_sl = current_candle_low
                    signal_initial_sl = df.iloc[i-n+1:i+1]['h'].max()
                    signal_creation_time = df.iloc[i]["datetime"]
                    already_signal_exists = True

                else:
                    if current_candle_open < signal_entry_price:
                        # Gap Down Open, SKIP trade
                        # print(df.iloc[i])
                        # print('Gap Up Open, Skip Trade')
                        already_signal_exists = False
                        signal_entry_price = 100000
                        signal_initial_sl = 0
                    elif current_candle_low > signal_entry_price:
                        # Better Candle
                        # print(df.iloc[i])
                        # print('Better Candle')
                        signal_entry_price = current_candle_low
                        # signal_initial_sl = current_candle_low
                        signal_initial_sl = df.iloc[i-n+1:i+1]['h'].max()
                        signal_creation_time = df.iloc[i]["datetime"]

                        # if (signal_entry_price - signal_initial_sl > 400):
                        #     # Skip Signal Candle Due To Big Size
                        #     already_signal_exists = False
                        #     signal_entry_price = 100000
                        #     signal_initial_sl = 0

                    elif current_candle_low <= signal_entry_price:
                        # Entry Triggered
                        # print(df.iloc[i])
                        # print('Entry Triggered')
                        in_trade = True
                        entry_time = df.iloc[i]["datetime"]
                        entry_price = signal_entry_price
                        points = 0
            else:
                if df.iloc[i - 1]["Sell_Signal"] == 1:
                    # Considering the forward bias condition as well now
                    signal_entry_price = df.iloc[i - 1]["l"]
                    # signal_initial_sl = df.iloc[i - 1]["l"]
                    signal_initial_sl = df.iloc[i-n:i]['h'].max()
                    signal_creation_time = df.iloc[i - 1]["datetime"]
                    already_signal_exists = True

                    if current_candle_low <= signal_entry_price:
                        in_trade = True
                        entry_time = df.iloc[i]["datetime"]
                        entry_price = signal_entry_price
                        points = 0
                    else:
                        # Discard Existing Signal
                        already_signal_exists = False
                        signal_entry_price = 100000
                        signal_initial_sl = 0

        if in_trade:
            trade_entry_price = signal_entry_price
            trade_initial_sl = signal_initial_sl
            trade_final_sl = signal_initial_sl

            if (
                not is_trailing_active
                and current_candle_high < current_linear_regression
            ):
                is_trailing_active = True

            if not is_trailing_active:
                if current_candle_open >= trade_initial_sl:
                    # if df.iloc[i-1]['l'] < trade_initial_sl:
                    #     #Previous Candle Already Hit the SL Hence don't check gap down
                    #     print(df.iloc[i])
                    #     print('Initial SL Hit Before Gap Down')
                    #     in_trade = False
                    #     points = trade_initial_sl - trade_entry_price
                    #     exit_price = trade_initial_sl
                    #     exit_time = df.iloc[i-1]['datetime']
                    #     remark = 'Initial SL Hit Before Gap Down'
                    # else:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        in_trade = False
                        points = trade_entry_price - trade_initial_sl
                        exit_price = trade_initial_sl
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Initial SL hit"

                    else:
                        # Gap Open Outside ISL
                        # print(df.iloc[i])
                        # print('Gap Open Outside ISL')
                        in_trade = False
                        points = trade_entry_price - current_candle_open
                        exit_price = current_candle_open
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif current_candle_high >= trade_initial_sl:
                    # Initial SL Hit
                    # print(df.iloc[i])
                    # print('Initial SL Hit')
                    in_trade = False
                    points = trade_entry_price - trade_initial_sl
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL Hit"

            else:
                trade_final_sl = min(trade_initial_sl, current_linear_regression)

                if current_candle_open >= trade_initial_sl:
                    # if df.iloc[i-1]['l'] < trade_initial_sl:
                    #     #Previous Candle Already Hit the SL Hence don't check gap down
                    #     print(df.iloc[i])
                    #     print('Initial SL Hit Before Gap Down')
                    #     in_trade = False
                    #     points = trade_initial_sl - trade_entry_price
                    #     exit_price = trade_initial_sl
                    #     exit_time = df.iloc[i-1]['datetime']
                    #     remark = 'Initial SL Hit'
                    # else:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        in_trade = False
                        points = trade_entry_price - trade_initial_sl
                        exit_price = trade_initial_sl
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Initial SL hit"

                    else:
                        # Gap Open Outside ISL
                        # print(df.iloc[i])
                        # print('Gap Open Outside ISL')
                        in_trade = False
                        points = trade_entry_price - current_candle_open
                        exit_price = current_candle_open
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif current_candle_high >= trade_initial_sl:
                    # if trade_initial_sl >= current_linear_regression:
                    # Despite Trailing, Initial SL hit
                    # print(df.iloc[i])
                    # print('Initial SL Hit')
                    in_trade = False
                    points = trade_entry_price - trade_initial_sl
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL hit"

                elif current_candle_close >= trade_final_sl:
                    # Price Closed below TSL i.e. MA10 , TSL Hit
                    # print(df.iloc[i])
                    # print('Initial SL Hit')
                    in_trade = False
                    points = trade_entry_price - current_candle_close
                    exit_price = current_candle_close
                    exit_time = df.iloc[i]["datetime"]
                    is_trailing_active = False
                    remark = "TSL Hit"

            if points:
                index_lev = 6
                qty = int(round(portfolio_value * index_lev / entry_price / 25)) * 25
                slippage = 0.0001 * (entry_price + exit_price)
                # slippage = 10
                final_points = points - slippage
                # final_points = points
                trade = {
                    "Signal Generated At": signal_creation_time,
                    "Trade Type": "SHORT",
                    "Entry Time": entry_time,
                    "Entry Price": entry_price,
                    "Initial SL": trade_initial_sl,
                    "Final SL": trade_final_sl,
                    "Exit Time": exit_time,
                    "Exit Price": exit_price,
                    "Points Captured": points,
                    "After Costs": final_points,
                    "PnL": final_points * qty,
                    "Remarks": remark,
                    "Qty": qty,
                    "Leverage": index_lev,
                    "ROI%": (final_points * qty / portfolio_value) * 100,
                    "Trade Year": entry_time.year,
                    "Trade Month": entry_time.month,
                }
                trade_book.append(trade)
                points = 0
                in_trade = False
                already_signal_exists = False
                remark = ""
                is_trailing_active = False

    trade_book_df = pd.DataFrame(trade_book)
    return trade_book_df

# %%
# Option Selling

async def option_selling(df, index, strike, asset_class, expiry, trade_date, sl_pct):

    trade_book = []
    in_trade = False
    signal_entry_price = 100000
    signal_initial_sl = 0
    already_signal_exists = False
    is_trailing_active = False
    remark = ""
    portfolio_value = 1_00_00_000

    df['datetime'] = pd.to_datetime(df['datetime'])

    df = df[df['datetime'].dt.date >= trade_date]

    # print(df.head(25).to_string())

    for i in range(2, len(df)):
        points = 0
        current_candle_open = df.iloc[i]["o"]
        current_candle_high = df.iloc[i]["h"]
        current_candle_low = df.iloc[i]["l"]
        current_candle_close = df.iloc[i]["c"]
        current_linear_regression = df.iloc[i]['LR2']
        # print(df.iloc[i])

        if not in_trade:
            if df.iloc[i-1]['LR'] < df.iloc[i-2]['LR']:
                # Previous Candle has a signal
                signal_entry_price = df.iloc[i-1]['l']
                signal_initial_sl = signal_entry_price * (1 + sl_pct)
                signal_generation_time = df.iloc[i-1]['datetime']

                if current_candle_low <= signal_entry_price:
                    if current_candle_open <= signal_entry_price:
                        if current_candle_high >= signal_entry_price:
                            # Entry Triggered
                            in_trade = True
                            entry_time = df.iloc[i]['datetime']
                            entry_price = signal_entry_price
                            points = 0
                        else:
                            # Trade Skipped, Gap Open Outside Entry
                            continue
                    else:
                        # Entry Triggered
                        in_trade = True
                        entry_time = df.iloc[i]['datetime']
                        entry_price = signal_entry_price
                        points = 0
                else:
                    # Check Next Iteration for Better Candle Scenario
                    continue

        if in_trade:
            trade_entry_price = signal_entry_price
            trade_initial_sl = signal_initial_sl
            trade_final_sl = signal_initial_sl
            
            if (
                not is_trailing_active
                and current_candle_high < current_linear_regression
            ):
                is_trailing_active = True

            if not is_trailing_active:
                if current_candle_open >= signal_initial_sl:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        # Check if this Gap Open below SL candle is the Entry Candle
                        if current_candle_close >= trade_initial_sl:
                            in_trade = False
                            points = trade_entry_price - trade_initial_sl
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL Hit"

                    # else:
                    #     # Gap Open Outside ISL
                    #     in_trade = False
                    #     points = trade_entry_price - current_candle_open
                    #     exit_price = current_candle_open
                    #     exit_time = df.iloc[i]["datetime"]
                    #     remark = "Gap Open Outside ISL"

                elif current_candle_high >= trade_initial_sl:
                    # Initial SL Hit
                    in_trade = False
                    points = trade_entry_price - trade_initial_sl
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL Hit"

                elif df.iloc[i]['datetime'] >= dt.datetime.combine(trade_date, dt.time(15, 20)):
                    in_trade = False
                    points = trade_entry_price - current_candle_close
                    exit_price = current_candle_close
                    exit_time = df.iloc[i]["datetime"]
                    remark = "EOD Exit"

            else:
                trade_final_sl = min(trade_initial_sl, current_linear_regression)

                if current_candle_open >= trade_initial_sl:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        if current_candle_close >= trade_initial_sl:
                            in_trade = False
                            points = trade_entry_price - trade_initial_sl
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL Hit"

                    # else:
                    #     # Gap Open Outside ISL
                    #     in_trade = False
                    #     points = trade_entry_price - current_candle_open
                    #     exit_price = current_candle_open
                    #     exit_time = df.iloc[i]["datetime"]
                    #     remark = "Gap Open Outside ISL"

                elif current_candle_high >= trade_initial_sl:
                    # Despite Trailing, Initial SL hit
                    in_trade = False
                    points = trade_entry_price - trade_initial_sl
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL Hit"

                elif current_candle_close >= trade_final_sl:
                    # Price Closed below TSL
                    in_trade = False
                    points = trade_entry_price - current_candle_close
                    exit_price = current_candle_close
                    exit_time = df.iloc[i]["datetime"]
                    is_trailing_active = False
                    remark = "TSL Hit"

                elif df.iloc[i]['datetime'] >= dt.datetime.combine(trade_date, dt.time(15, 20)):
                    in_trade = False
                    points = trade_entry_price - current_candle_close
                    exit_price = current_candle_close
                    exit_time = df.iloc[i]["datetime"]
                    remark = "EOD Exit"

            if points:
                qty = int(round((PORTFOLIO * LEVERAGE_ / strike) / LOT_SIZE_)) * LOT_SIZE_
                slippage = SLIPPAGE_ * (entry_price + exit_price)
                # slippage = 10
                final_points = points - slippage
                # final_points = points
                trade = {
                    "Trade Type": "SHORT",
                    "Index": index,
                    "Strike": strike,
                    "Asset Class": asset_class,
                    "Expiry": expiry,
                    "Signal Generated At": signal_generation_time,
                    "Entry Time": entry_time,
                    "Entry Price": entry_price,
                    "Initial SL": trade_initial_sl,
                    "Final SL": trade_final_sl,
                    "Exit Time": exit_time,
                    "Exit Price": exit_price,
                    "Points Captured": points,
                    "After Costs": final_points,
                    "PnL": final_points * qty,
                    "Remarks": remark,
                    "Qty": qty,
                    "Leverage": LEVERAGE_,
                    "ROI%": (final_points * qty / PORTFOLIO) * 100,
                    "Trade Year": entry_time.year,
                    "Trade Month": entry_time.month,
                }
                # print(trade)
                trade_book.append(trade)
                points = 0
                in_trade = False
                already_signal_exists = False
                remark = ""
                is_trailing_active = False

    trade_book_df = pd.DataFrame(trade_book)
    return trade_book_df

# %%
bnf1 = bnf
bnf2 = bnf

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2017, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2017, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI%"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI%"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI%"] > 0]["ROI%"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI%"] < 0]["ROI%"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI%"].cumsum() - year_trades["ROI%"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI%"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI%"] > 0]["ROI%"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI%"].cumsum() - combined_df_sorted["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation
    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    # print(stats_df8)
    return {overall_roi_dd_ratio : stats_df8}

# %%
def generate_stats_by_dte(tb_expiry, variation):
    # Create a DataFrame to store the statistics
    stats_df8 = pd.DataFrame(
        columns=[
            "DTE",
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ]
    )

    # Group the data by 'DTE'
    grouped_by_dte = tb_expiry.groupby("DTE")

    # Iterate over each DTE group
    for dte_value, dte_trades in grouped_by_dte:
        # Calculate total ROI for the current DTE group
        total_roi = dte_trades["ROI%"].sum()

        # Calculate total number of trades for the current DTE group
        total_trades = len(dte_trades)

        # Calculate win rate for the current DTE group
        win_rate = (dte_trades["ROI%"] > 0).mean() * 100

        # Calculate average profit per trade
        avg_profit = dte_trades[dte_trades["ROI%"] > 0]["ROI%"].mean()

        # Calculate average loss per trade
        avg_loss = dte_trades[dte_trades["ROI%"] < 0]["ROI%"].mean()

        # Calculate maximum drawdown for the current DTE group
        max_drawdown = (
            dte_trades["ROI%"].cumsum() - dte_trades["ROI%"].cumsum().cummax()
        ).min()

        # Calculate ROI/DD ratio for the current DTE group
        roi_dd_ratio = total_roi / abs(max_drawdown) if max_drawdown != 0 else 0

        # Store the statistics in the DataFrame for the current DTE
        stats_df8 = pd.concat([stats_df8, pd.DataFrame({
            "DTE": [dte_value],
            "Total ROI": [total_roi],
            "Total Trades": [total_trades],
            "Win Rate": [win_rate],
            "Avg Profit% per Trade": [avg_profit],
            "Avg Loss% per Trade": [avg_loss],
            "Max Drawdown": [max_drawdown],
            "ROI/DD Ratio": [roi_dd_ratio],
            "Variation": [variation],
        })], ignore_index=True)

    # Overall statistics across all DTE groups
    overall_total_roi = tb_expiry["ROI%"].sum()
    overall_total_trades = len(tb_expiry)
    overall_win_rate = (tb_expiry["ROI%"] > 0).mean() * 100
    overall_avg_profit = tb_expiry[tb_expiry["ROI%"] > 0]["ROI%"].mean()
    overall_avg_loss = tb_expiry[tb_expiry["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        tb_expiry["ROI%"].cumsum() - tb_expiry["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown) if overall_max_drawdown != 0 else 0
    overall_variation = variation

    # Store the overall statistics in the DataFrame
    stats_df8 = pd.concat([stats_df8, pd.DataFrame({
        "DTE": ["Overall"],
        "Total ROI": [overall_total_roi],
        "Total Trades": [overall_total_trades],
        "Win Rate": [overall_win_rate],
        "Avg Profit% per Trade": [overall_avg_profit],
        "Avg Loss% per Trade": [overall_avg_loss],
        "Max Drawdown": [overall_max_drawdown],
        "ROI/DD Ratio": [overall_roi_dd_ratio],
        "Variation": [overall_variation],
    })], ignore_index=True)

    return stats_df8

def generate_stats_by_remarks(tb_expiry, variation):
    # Create a DataFrame to store the statistics
    stats_df8 = pd.DataFrame(
        columns=[
            "Remarks",
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ]
    )

    # Group the data by 'Remarks'
    grouped_by_remarks = tb_expiry.groupby("Remarks")

    # Iterate over each group
    for remarks_value, remarks_trades in grouped_by_remarks:
        # Calculate total ROI for the current group
        total_roi = remarks_trades["ROI%"].sum()

        # Calculate total number of trades for the current group
        total_trades = len(remarks_trades)

        # Calculate win rate for the current group
        win_rate = (remarks_trades["ROI%"] > 0).mean() * 100

        # Calculate average profit per trade
        avg_profit = remarks_trades[remarks_trades["ROI%"] > 0]["ROI%"].mean()

        # Calculate average loss per trade
        avg_loss = remarks_trades[remarks_trades["ROI%"] < 0]["ROI%"].mean()

        # Calculate maximum drawdown for the current group
        max_drawdown = (
            remarks_trades["ROI%"].cumsum() - remarks_trades["ROI%"].cumsum().cummax()
        ).min()

        # Calculate ROI/DD ratio for the current group
        roi_dd_ratio = total_roi / abs(max_drawdown) if max_drawdown != 0 else 0

        # Store the statistics in the DataFrame for the current group
        stats_df8 = pd.concat([stats_df8, pd.DataFrame({
            "Remarks": [remarks_value],
            "Total ROI": [total_roi],
            "Total Trades": [total_trades],
            "Win Rate": [win_rate],
            "Avg Profit% per Trade": [avg_profit],
            "Avg Loss% per Trade": [avg_loss],
            "Max Drawdown": [max_drawdown],
            "ROI/DD Ratio": [roi_dd_ratio],
            "Variation": [variation],
        })], ignore_index=True)

    # Overall statistics across all groups
    overall_total_roi = tb_expiry["ROI%"].sum()
    overall_total_trades = len(tb_expiry)
    overall_win_rate = (tb_expiry["ROI%"] > 0).mean() * 100
    overall_avg_profit = tb_expiry[tb_expiry["ROI%"] > 0]["ROI%"].mean()
    overall_avg_loss = tb_expiry[tb_expiry["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        tb_expiry["ROI%"].cumsum() - tb_expiry["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown) if overall_max_drawdown != 0 else 0
    overall_variation = variation

    # Store the overall statistics in the DataFrame
    stats_df8 = pd.concat([stats_df8, pd.DataFrame({
        "Remarks": ["Overall"],
        "Total ROI": [overall_total_roi],
        "Total Trades": [overall_total_trades],
        "Win Rate": [overall_win_rate],
        "Avg Profit% per Trade": [overall_avg_profit],
        "Avg Loss% per Trade": [overall_avg_loss],
        "Max Drawdown": [overall_max_drawdown],
        "ROI/DD Ratio": [overall_roi_dd_ratio],
        "Variation": [overall_variation],
    })], ignore_index=True)

    return stats_df8

# %%
bnf1 = bnf1.to_pandas()

# %%
# # bnf2 = bnf2.to_pandas()
# data = linear_regression_vectorized(bnf1, 80)
# signals_df1 = generate_signals1(data, 1)
# # signals_df2 = generate_signals2(bnf2)

# %%
# data[data['Buy_Signal'] > 0].tail()

# %%
bnf1.tail()
# Out:
#              open       high        low      close  volume  \
# 687621 49800.4500 49812.7500 49792.7000 49806.2000       0
# 687622 49807.2500 49811.7000 49798.7500 49807.5000       0
# 687623 49810.8500 49823.8000 49797.6000 49817.3000       0
# 687624 49816.2500 49827.6000 49805.8000 49816.0000       0
# 687625 49820.3000 49825.0000 49805.2500 49806.6000       0
#
#                      index            datetime
# 687621 2024-06-07 15:25:00 2024-06-07 15:25:00
# 687622 2024-06-07 15:26:00 2024-06-07 15:26:00
# 687623 2024-06-07 15:27:00 2024-06-07 15:27:00
# 687624 2024-06-07 15:28:00 2024-06-07 15:28:00
# 687625 2024-06-07 15:29:00 2024-06-07 15:29:00

# %%
async def trade(df, lr_1, lr_2, sl_pct, tf, ofs):

    total_trades = pd.DataFrame()
    
    start_dt = dt.date(2017, 1, 1)
    end_dt = dt.date(2024, 9, 30)
    current_dt = start_dt

    while current_dt <= end_dt:
        
        combined_trades_ce = pd.DataFrame()
        combined_trades_pe = pd.DataFrame()
        
        # print(current_dt)

        spot = df.loc[df['datetime'].dt.date == current_dt, 'open']
        if len(spot) == 0:                                                                # This will give us 9:15 open
            current_dt += dt.timedelta(days=1)
            continue
        else:
            spot_open = spot.iloc[0]
            # print(spot_open)
            # break

            atm_strike = int(round(spot_open / SPREAD_) * SPREAD_)
            # print(atm_strike)

            current_expiry = await get_expiry(current_dt, symbol)

            ce_df = await fetch_data(
                index=symbol,
                start_date=current_dt - dt.timedelta(days=3),
                end_date=current_dt,
                start_time=dt.time(9, 15),
                end_time=dt.time(15, 30),
                expiry=current_expiry,
                strike=atm_strike,
                asset_class="C",
            )

            if not isinstance(ce_df, str) and ce_df is not None:
                ce_df = ce_df.select(["datetime", "o", "h", "l", "c", "v"])
                ce_df = resample(ce_df, tf, offset=ofs)
                ce_df_pandas = ce_df.to_pandas()
                ce_df_pandas = ce_df_pandas[~(ce_df_pandas['datetime'].dt.time == pd.to_datetime('15:30').time())]
                ce_df_pandas = linear_regression_vectorized(ce_df_pandas, lr_1, lr_2)

            else:
                ce_df_pandas = pd.DataFrame()

            pe_df = await fetch_data(
                index=symbol,
                start_date=current_dt - dt.timedelta(days=3),
                end_date=current_dt,
                start_time=dt.time(9, 15),
                end_time=dt.time(15, 30),
                expiry=current_expiry,
                strike=atm_strike,
                asset_class="P",
            )

            if not isinstance(pe_df, str) and pe_df is not None:
                pe_df = pe_df.select(["datetime", "o", "h", "l", "c", "v"])
                pe_df = resample(pe_df, tf, offset=ofs)
                pe_df_pandas = pe_df.to_pandas()
                pe_df_pandas = pe_df_pandas[~(pe_df_pandas['datetime'].dt.time == pd.to_datetime('15:30').time())]
                pe_df_pandas = linear_regression_vectorized(pe_df_pandas, lr_1, lr_2)

            else:
                pe_df_pandas = pd.DataFrame()

            if len(ce_df_pandas) > 0:
                ce_trades = await option_selling(
                    df=ce_df_pandas,
                    index=symbol,
                    strike=atm_strike,
                    asset_class="C",
                    expiry=current_expiry,
                    trade_date=current_dt,
                    sl_pct=sl_pct,
                )
                combined_trades_ce = pd.concat([combined_trades_ce, ce_trades], ignore_index=True)

            if len(pe_df_pandas) > 0:
                pe_trades = await option_selling(
                    df=pe_df_pandas,
                    index=symbol,
                    strike=atm_strike,
                    asset_class="P",
                    expiry=current_expiry,
                    trade_date=current_dt,
                    sl_pct=sl_pct,
                )
                combined_trades_pe = pd.concat([combined_trades_pe, pe_trades], ignore_index=True)

        total_trades = pd.concat([total_trades, combined_trades_ce, combined_trades_pe], ignore_index=True)
        if len(total_trades) > 0:
            total_trades = total_trades.sort_values(by="Signal Generated At", ignore_index=True)
            
        current_dt += dt.timedelta(days=1)
    return total_trades

# %%
tb = await trade(bnf1, 11, 21, 0.75, '10m', '5m')

# %%
tb['Entry Time'] = pd.to_datetime(tb['Entry Time'])
tb['Expiry'] = pd.to_datetime(tb['Expiry'])
tb['DTE'] = (tb['Expiry'] - tb['Entry Time']).dt.days + 1

# %%
stats = generate_stats_by_dte(tb , '...')
print(stats.to_string())
# Out:
#        DTE  Total ROI Total Trades  Win Rate  Avg Profit% per Trade  Avg Loss% per Trade  Max Drawdown  ROI/DD Ratio Variation
# 0        0   157.5834         2103   53.7803                 0.7200              -0.6757      -31.4024        5.0182       ...
# 1        1    59.4692         1721   52.7600                 0.8333              -0.8575      -29.2381        2.0340       ...
# 2        2    68.1663         1602   50.3121                 0.8404              -0.7654      -29.6616        2.2981       ...
# 3        3   -70.8882         1403   47.1133                 0.7933              -0.8022      -78.0196       -0.9086       ...
# 4        4     0.2202            2   50.0000                 0.2609              -0.0407       -0.0407        5.4065       ...
# 5        5   -36.6089          176   51.1364                 0.6816              -1.1390      -39.5651       -0.9253       ...
# 6        6  -104.5716         1510   47.6821                 0.7859              -0.8487     -110.0559       -0.9502       ...
# 7        7     1.3248            4   75.0000                 0.7061              -0.7935       -0.7935        1.6696       ...
# 8  Overall    74.6951         8521   50.6983                 0.7876              -0.7921     -127.4280        0.5862       ...
# /tmp/ipykernel_3931/610469842.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stats_df8 = pd.concat([stats_df8, pd.DataFrame({

# %%
stats = generate_stats_by_remarks(tb , '...')
print(stats.to_string())
# Out:
#           Remarks  Total ROI Total Trades  Win Rate  Avg Profit% per Trade  Avg Loss% per Trade  Max Drawdown  ROI/DD Ratio Variation
# 0        EOD Exit   751.2001         2209   66.9986                 0.7879              -0.5692       -8.1162       92.5556       ...
# 1  Initial SL Hit -1137.2733          776    0.0000                    NaN              -1.4656    -1136.3790       -1.0008       ...
# 2         TSL Hit   460.7684         5536   51.3006                 0.7874              -0.6585      -26.4783       17.4017       ...
# 3         Overall    74.6951         8521   50.6983                 0.7876              -0.7921     -127.4280        0.5862       ...
# /tmp/ipykernel_3931/610469842.py:130: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stats_df8 = pd.concat([stats_df8, pd.DataFrame({

# %%
tb.tail()
# Out:
#       Trade Type Index  Strike Asset Class     Expiry Signal Generated At  \
# 19482      SHORT   bnf   49300           C 2024-06-12 2024-06-07 14:33:00
# 19483      SHORT   bnf   49300           P 2024-06-12 2024-06-07 14:45:00
# 19484      SHORT   bnf   49300           C 2024-06-12 2024-06-07 14:54:00
# 19485      SHORT   bnf   49300           P 2024-06-12 2024-06-07 15:15:00
# 19486      SHORT   bnf   49300           P 2024-06-12 2024-06-07 15:24:00
#
#                Entry Time  Entry Price  Initial SL  Final SL  \
# 19482 2024-06-07 14:36:00     783.6000   1057.8600  795.0763
# 19483 2024-06-07 14:48:00     265.3000    358.1550  266.2050
# 19484 2024-06-07 14:57:00     806.2500   1088.4375  798.2315
# 19485 2024-06-07 15:18:00     269.9000    364.3650  364.3650
# 19486 2024-06-07 15:27:00     260.9000    352.2150  352.2150
#
#                 Exit Time  Exit Price  Points Captured  After Costs  \
# 19482 2024-06-07 14:48:00    806.4000         -22.8000     -38.7000
# 19483 2024-06-07 14:57:00    271.4500          -6.1500     -11.5175
# 19484 2024-06-07 15:18:00    817.1500         -10.9000     -27.1340
# 19485 2024-06-07 15:21:00    263.2500           6.6500       1.3185
# 19486 2024-06-07 15:27:00    260.4000           0.5000      -4.7130
#
#               PnL   Remarks   Qty  Leverage    ROI%  Trade Year  Trade Month  \
# 19482 -39474.0000   TSL Hit  1020         5 -0.3947        2024            6
# 19483 -11747.8500   TSL Hit  1020         5 -0.1175        2024            6
# 19484 -27676.6800   TSL Hit  1020         5 -0.2768        2024            6
# 19485   1344.8700  EOD Exit  1020         5  0.0134        2024            6
# 19486  -4807.2600  EOD Exit  1020         5 -0.0481        2024            6
#
#        DTE
# 19482    5
# 19483    5
# 19484    5
# 19485    5
# 19486    5

# %%
stats_dictionary = {}

sls = [0.5, 1.0, 1.5, 2.0]
tfs = ['5m']

for i in range(5, 81, 5):
    for j in range(5, 31, 5):
        for sl in sls:
            for tf in tfs:
                if tf == '10m':
                    ofs = '5m'
                else:
                    ofs = '0m'
                variation = f"LR: {i}, TLR: {j}, SL: {sl*100}%, TF: {tf}"
                print(variation)
                bnf2 = bnf1
                new_tb = await trade(bnf2, i, j, sl, tf, ofs)
                new_tb["DD%"] = new_tb["ROI%"].cumsum() - new_tb["ROI%"].cumsum().cummax()
                tradebook_buy_side = new_tb
                stats = generate_stats(tradebook_buy_side, variation)
                for overall_roi_dd_ratio, stats_df in stats.items():
                    if overall_roi_dd_ratio is not None and overall_roi_dd_ratio > 10:
                        print(stats_df.to_string())
                        stats_dictionary[overall_roi_dd_ratio] = stats_df
# Out:
# LR: 5, TLR: 5, SL: 50.0%, TF: 5m
# LR: 5, TLR: 5, SL: 100.0%, TF: 5m
# LR: 5, TLR: 5, SL: 150.0%, TF: 5m
# LR: 5, TLR: 5, SL: 200.0%, TF: 5m
# LR: 5, TLR: 10, SL: 50.0%, TF: 5m
# LR: 5, TLR: 10, SL: 100.0%, TF: 5m
# LR: 5, TLR: 10, SL: 150.0%, TF: 5m
# LR: 5, TLR: 10, SL: 200.0%, TF: 5m
# LR: 5, TLR: 15, SL: 50.0%, TF: 5m
# LR: 5, TLR: 15, SL: 100.0%, TF: 5m
# LR: 5, TLR: 15, SL: 150.0%, TF: 5m
# LR: 5, TLR: 15, SL: 200.0%, TF: 5m
# LR: 5, TLR: 20, SL: 50.0%, TF: 5m
# LR: 5, TLR: 20, SL: 100.0%, TF: 5m
# LR: 5, TLR: 20, SL: 150.0%, TF: 5m
# LR: 5, TLR: 20, SL: 200.0%, TF: 5m
# LR: 5, TLR: 25, SL: 50.0%, TF: 5m
# LR: 5, TLR: 25, SL: 100.0%, TF: 5m
# LR: 5, TLR: 25, SL: 150.0%, TF: 5m
# LR: 5, TLR: 25, SL: 200.0%, TF: 5m
# LR: 5, TLR: 30, SL: 50.0%, TF: 5m
# LR: 5, TLR: 30, SL: 100.0%, TF: 5m
# LR: 5, TLR: 30, SL: 150.0%, TF: 5m
# LR: 5, TLR: 30, SL: 200.0%, TF: 5m
# LR: 10, TLR: 5, SL: 50.0%, TF: 5m
# LR: 10, TLR: 5, SL: 100.0%, TF: 5m
# LR: 10, TLR: 5, SL: 150.0%, TF: 5m
# LR: 10, TLR: 5, SL: 200.0%, TF: 5m
# LR: 10, TLR: 10, SL: 50.0%, TF: 5m
# LR: 10, TLR: 10, SL: 100.0%, TF: 5m
# LR: 10, TLR: 10, SL: 150.0%, TF: 5m
# LR: 10, TLR: 10, SL: 200.0%, TF: 5m
# LR: 10, TLR: 15, SL: 50.0%, TF: 5m
# LR: 10, TLR: 15, SL: 100.0%, TF: 5m
# LR: 10, TLR: 15, SL: 150.0%, TF: 5m
# LR: 10, TLR: 15, SL: 200.0%, TF: 5m
# LR: 10, TLR: 20, SL: 50.0%, TF: 5m
# LR: 10, TLR: 20, SL: 100.0%, TF: 5m
# LR: 10, TLR: 20, SL: 150.0%, TF: 5m
# LR: 10, TLR: 20, SL: 200.0%, TF: 5m
# LR: 10, TLR: 25, SL: 50.0%, TF: 5m
# LR: 10, TLR: 25, SL: 100.0%, TF: 5m
# LR: 10, TLR: 25, SL: 150.0%, TF: 5m
# LR: 10, TLR: 25, SL: 200.0%, TF: 5m
# LR: 10, TLR: 30, SL: 50.0%, TF: 5m
# LR: 10, TLR: 30, SL: 100.0%, TF: 5m
# LR: 10, TLR: 30, SL: 150.0%, TF: 5m
# LR: 10, TLR: 30, SL: 200.0%, TF: 5m
# LR: 15, TLR: 5, SL: 50.0%, TF: 5m
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3931/4000798174.py in ?()
#      13                     ofs = '0m'
#      14                 variation = f"LR: {i}, TLR: {j}, SL: {sl*100}%, TF: {tf}"
#      15                 print(variation)
#      16                 bnf2 = bnf1
# ---> 17                 new_tb = await trade(bnf2, i, j, sl, tf, ofs)
#      18                 new_tb["DD%"] = new_tb["ROI%"].cumsum() - new_tb["ROI%"].cumsum().cummax()
#      19                 tradebook_buy_side = new_tb
#      20                 stats = generate_stats(tradebook_buy_side, variation)
#
# /tmp/ipykernel_3931/3529743881.py in ?(df, lr_1, lr_2, sl_pct, tf, ofs)
#      93                 )
#      94                 combined_trades_pe = pd.concat([combined_trades_pe, pe_trades], ignore_index=True)
#      95
#      96         total_trades = pd.concat([total_trades, combined_trades_ce, combined_trades_pe], ignore_index=True)
# ---> 97         total_trades = total_trades.sort_values(by="Signal Generated At", ignore_index=True)
#      98
#      99         current_dt += dt.timedelta(days=1)
#     100     return total_trades
#
# ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7169             )
#    7170         elif len(by):
#    7171             # len(by) == 1
#    7172
# -> 7173             k = self._get_label_or_level_values(by[0], axis=axis)
#    7174
#    7175             # need to rewrap column in Series to apply key function
#    7176             if key is not None:
#
# ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1906             values = self.xs(key, axis=other_axes[0])._values
#    1907         elif self._is_level_reference(key, axis=axis):
#    1908             values = self.axes[axis].get_level_values(key)._values
#    1909         else:
# -> 1910             raise KeyError(key)
#    1911
#    1912         # Check for duplicates
#    1913         if values.ndim > 1:
#
# KeyError: 'Signal Generated At'

# %%
sorted_stats = {k: v for k, v in sorted(stats_dictionary.items(), key=lambda item: item[0], reverse=True)}

# %%
sorted_stats

# %% [markdown]
# ## NIFTY

# %%
# signals_df2.tail(130)

# %%
bnf2 = resample(pl.DataFrame(bnf1), "30m", "15m")
data = linear_regression_vectorized(bnf2.to_pandas(), 20, 10)
# print(data.tail(10).to_string())
signals_df1 = generate_signals1(data, 4)
signals_df1 = signals_df1.rename(columns={"open": "o", "high": "h", "low": "l", "close": "c"})
new_tb = execute(signals_df1, 4)

# new_tb = execute(signals_df1)
new_tb["DD%"] = new_tb["ROI%"].cumsum() - new_tb["ROI%"].cumsum().cummax()
tradebook_buy_side = new_tb
# new_tb.tail(25)

# %%
# tradebook_buy_side['DD%'] = (tradebook_buy_side['ROI%'].cumsum() - tradebook_buy_side['ROI%'].cumsum().cummax())
# tradebook_buy_side

# %%
stats2 = generate_stats(new_tb, "...")
roi_overall, stats_overall = next(iter(stats2.items()))
stats_overall
# Out:
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2017      50.9849          149  40.9396                2.7176
# 2018      38.8996          139  41.7266                3.3688
# 2019      72.9224          122  43.4426                4.1850
# 2020     156.3541          151  43.0464                6.6275
# 2021     114.7110          138  48.5507                4.3187
# 2022      65.3621          139  38.8489                4.8798
# 2023      81.4258          135  42.9630                3.7075
# 2024      19.6732           53  41.5094                4.0667
# Overall  600.3332         1026  42.6901                4.2720
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio Variation
# 2017                -1.3044     -11.7579       4.3362       ...
# 2018                -1.9320     -28.4217       1.3687       ...
# 2019                -2.1577     -23.1758       3.1465       ...
# 2020                -3.1911     -34.6281       4.5152       ...
# 2021                -2.4598     -23.3700       4.9085       ...
# 2022                -2.3311     -31.9077       2.0485       ...
# 2023                -1.7352     -24.2438       3.3586       ...
# 2024                -2.2514     -17.8705       1.1009       ...
# Overall             -2.1612     -34.6281      17.3366       ...

# %% [markdown]
# # Short Side Simulation Below

# %%
stats_dictionary = {}

tf_list = ["3m", "5m", "15m", "30m"]
previous_n_number_of_candles_for_sl = [1, 2, 3, 4]

for i in range(10, 51, 5):
    for j in range(10, 31, 5):
        for k in range(1, 6):
            for n in previous_n_number_of_candles_for_sl:
                for tf in tf_list:
                    if tf == "10m":
                        offset = "5m"
                    elif tf == "30m" or tf == "60m":
                        offset = "15m"
                    else:
                        offset = "0m"
                    variation = f"LR Period: {i} , Trailing LR : {j} , No. of Candles : {k}, TF : {tf} , {n} Candles SL"
                    print(variation)
                    bnf2 = resample(pl.DataFrame(bnf1), tf, offset)
                    data = linear_regression_vectorized(bnf2.to_pandas(), i, j)
                    signals_df2 = generate_signals2(data, k)
                    signals_df2 = signals_df2.rename(columns={"open": "o", "high": "h", "low": "l", "close": "c"})
                    new_tb = execute_short(signals_df2, n)
                    new_tb["DD%"] = new_tb["ROI%"].cumsum() - new_tb["ROI%"].cumsum().cummax()
                    tradebook_sell_side = new_tb
                    stats = generate_stats(tradebook_sell_side, variation)
                    for overall_roi_dd_ratio, stats_df in stats.items():
                        if overall_roi_dd_ratio is not None and overall_roi_dd_ratio > 3:
                            print(stats_df.to_string())
                            stats_dictionary[overall_roi_dd_ratio] = stats_df
# Out:
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 10 , No. of Candles : 5, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 1, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 2, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 3, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 4, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 15 , No. of Candles : 5, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 1, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 2, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 3, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 4, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 20 , No. of Candles : 5, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 1, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 2, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 3, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 4, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 25 , No. of Candles : 5, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 1, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 2, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 3, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 4, TF : 30m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 3m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 5m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 15m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 30m , 1 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 3m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 5m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 15m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 30m , 2 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 3m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 5m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 15m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 30m , 3 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 3m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 5m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 15m , 4 Candles SL
# LR Period: 10 , Trailing LR : 30 , No. of Candles : 5, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 10 , No. of Candles : 5, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 1, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 2, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 3, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 4, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 15 , No. of Candles : 5, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 1, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 2, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 15m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 30m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 3m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 5m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 15m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 30m , 2 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 3m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 5m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 15m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 30m , 3 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 3m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 5m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 15m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 3, TF : 30m , 4 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 4, TF : 3m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 4, TF : 5m , 1 Candles SL
# LR Period: 15 , Trailing LR : 20 , No. of Candles : 4, TF : 15m , 1 Candles SL
# ...
# LR Period: 25 , Trailing LR : 25 , No. of Candles : 5, TF : 15m , 2 Candles SL
# LR Period: 25 , Trailing LR : 25 , No. of Candles : 5, TF : 30m , 2 Candles SL
# LR Period: 25 , Trailing LR : 25 , No. of Candles : 5, TF : 3m , 3 Candles SL
# LR Period: 25 , Trailing LR : 25 , No. of Candles : 5, TF : 5m , 3 Candles SL
# LR Period: 25 , Trailing LR : 25 , No. of Candles : 5, TF : 15m , 3 Candles SL
# LR Period: 25 , Trailing LR : 25 , No. of Candles : 5, TF : 30m , 3 Candles SL
# LR Period: 25 , Trailing LR : 25 , No. of Candles : 5, TF : 3m , 4 Candles SL
# LR Period: 25 , Trailing LR : 25 , No. of Candles : 5, TF : 5m , 4 Candles SL
# LR Period: 25 , Trailing LR : 25 , No. of Candles : 5, TF : 15m , 4 Candles SL
# LR Period: 25 , Trailing LR : 25 , No. of Candles : 5, TF : 30m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 3m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 5m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 15m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 30m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 3m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 5m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 15m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 30m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 3m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 5m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 15m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 30m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 3m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 5m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 15m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 1, TF : 30m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 3m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 5m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 15m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 30m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 3m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 5m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 15m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 30m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 3m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 5m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 15m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 30m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 3m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 5m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 15m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 2, TF : 30m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 3m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 5m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 15m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 30m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 3m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 5m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 15m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 30m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 3m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 5m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 15m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 30m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 3m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 5m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 15m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 3, TF : 30m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 3m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 5m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 15m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 30m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 3m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 5m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 15m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 30m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 3m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 5m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 15m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 30m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 3m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 5m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 15m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 4, TF : 30m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 3m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 5m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 15m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 30m , 1 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 3m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 5m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 15m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 30m , 2 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 3m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 5m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 15m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 30m , 3 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 3m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 5m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 15m , 4 Candles SL
# LR Period: 25 , Trailing LR : 30 , No. of Candles : 5, TF : 30m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 3m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 5m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 15m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 1, TF : 30m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 3m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 5m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 15m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 2, TF : 30m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 3m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 5m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 15m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 3, TF : 30m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 3m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 5m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 15m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 4, TF : 30m , 4 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 5, TF : 3m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 5, TF : 5m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 5, TF : 15m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 5, TF : 30m , 1 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 5, TF : 3m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 5, TF : 5m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 5, TF : 15m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 5, TF : 30m , 2 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 5, TF : 3m , 3 Candles SL
# LR Period: 30 , Trailing LR : 10 , No. of Candles : 5, TF : 5m , 3 Candles SL
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[192], line 23
#      21 signals_df2 = generate_signals2(data, k)
#      22 signals_df2 = signals_df2.rename(columns={"open": "o", "high": "h", "low": "l", "close": "c"})
# ---> 23 new_tb = execute_short(signals_df2, n)
#      24 new_tb["DD%"] = new_tb["ROI%"].cumsum() - new_tb["ROI%"].cumsum().cummax()
#      25 tradebook_sell_side = new_tb
#
# Cell In[191], line 17, in execute_short(df, n)
#      15 points = 0
#      16 current_candle_open = df.iloc[i]["o"]
# ---> 17 current_candle_high = df.iloc[i]["h"]
#      18 current_candle_low = df.iloc[i]["l"]
#      19 current_candle_close = df.iloc[i]["c"]
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/indexing.py:1755, in _iLocIndexer._getitem_axis(self, key, axis)
#    1752 # validate the location
#    1753 self._validate_integer(key, axis)
# -> 1755 return self.obj._ixs(key, axis=axis)
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/frame.py:3984, in DataFrame._ixs(self, i, axis)
#    3982 # irow
#    3983 if axis == 0:
# -> 3984     new_mgr = self._mgr.fast_xs(i)
#    3986     # if we are a copy, mark as such
#    3987     copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/internals/managers.py:985, in BlockManager.fast_xs(self, loc)
#     977     block = new_block(
#     978         result,
#     979         placement=bp,
#     980         ndim=1,
#     981         refs=self.blocks[0].refs,
#     982     )
#     983     return SingleBlockManager(block, self.axes[0])
# --> 985 dtype = interleaved_dtype([blk.dtype for blk in self.blocks])
#     987 n = len(self)
#     989 if isinstance(dtype, ExtensionDtype):
#     990     # TODO: use object dtype as workaround for non-performant
#     991     #  EA.__setitem__ methods. (primarily ArrowExtensionArray.__setitem__
#     992     #  when iteratively setting individual values)
#     993     #  https://github.com/pandas-dev/pandas/pull/54508#issuecomment-1675827918
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/internals/base.py:394, in interleaved_dtype(dtypes)
#     391 if not len(dtypes):
#     392     return None
# --> 394 return find_common_type(dtypes)
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/dtypes/cast.py:1461, in find_common_type(types)
#    1458     return first
#    1460 # get unique types (dict.fromkeys is used as order-preserving set())
# -> 1461 types = list(dict.fromkeys(types).keys())
#    1463 if any(isinstance(t, ExtensionDtype) for t in types):
#    1464     for t in types:
#
# KeyboardInterrupt:

# %%
sorted_stats = {k: v for k, v in sorted(stats_dictionary.items(), key=lambda item: item[0], reverse=True)}
sorted_stats

# %%
bnf2 = resample(pl.DataFrame(bnf1), "30m", "15m")
data = linear_regression_vectorized(bnf2.to_pandas(), 20, 10)
# print(data.tail(10).to_string())
signals_df2 = generate_signals2(data, 2)
signals_df2 = signals_df2.rename(columns={"open": "o", "high": "h", "low": "l", "close": "c"})
new_tb = execute_short(signals_df2, 4)

# new_tb = execute(signals_df1)
new_tb["DD%"] = new_tb["ROI%"].cumsum() - new_tb["ROI%"].cumsum().cummax()
tradebook_sell_side = new_tb
# new_tb.tail(25)

# %%
# stats2 = generate_stats(tradebook_sell_side, "...")
# roi_overall, stats_overall = next(iter(stats2.items()))
# stats_overall

# %%
tradebook_sell_side.tail(73)
# Out:
#      Signal Generated At Trade Type          Entry Time  Entry Price  \
# 1082 2024-01-02 09:15:00      SHORT 2024-01-02 09:45:00   21699.0000
# 1083 2024-01-03 13:45:00      SHORT 2024-01-03 14:15:00   21561.0000
# 1084 2024-01-05 12:15:00      SHORT 2024-01-05 12:45:00   21685.5500
# 1085 2024-01-08 11:15:00      SHORT 2024-01-08 11:45:00   21605.3000
# 1086 2024-01-10 10:15:00      SHORT 2024-01-10 10:45:00   21523.4000
# 1087 2024-01-16 11:45:00      SHORT 2024-01-16 12:15:00   22062.2000
# 1088 2024-01-17 12:15:00      SHORT 2024-01-17 12:45:00   21642.8000
# 1089 2024-01-18 13:45:00      SHORT 2024-01-18 14:15:00   21434.7500
# 1090 2024-01-20 11:15:00      SHORT 2024-01-20 11:45:00   21643.5500
# 1091 2024-01-20 14:15:00      SHORT 2024-01-20 14:45:00   21586.9000
# 1092 2024-01-23 10:45:00      SHORT 2024-01-23 11:15:00   21519.9000
# 1093 2024-01-25 11:45:00      SHORT 2024-01-25 12:15:00   21279.7500
# 1094 2024-01-30 11:45:00      SHORT 2024-01-30 12:15:00   21698.0500
# 1095 2024-02-01 12:45:00      SHORT 2024-02-01 13:15:00   21711.0000
# 1096 2024-02-02 15:15:00      SHORT 2024-02-05 09:15:00   21837.8500
# 1097 2024-02-05 11:15:00      SHORT 2024-02-05 11:45:00   21899.4000
# 1098 2024-02-06 09:45:00      SHORT 2024-02-06 10:15:00   21832.1500
# 1099 2024-02-07 12:15:00      SHORT 2024-02-07 12:45:00   21885.0000
# 1100 2024-02-08 12:45:00      SHORT 2024-02-08 13:15:00   21783.3000
# 1101 2024-02-12 11:15:00      SHORT 2024-02-12 11:45:00   21690.7500
# 1102 2024-02-14 10:15:00      SHORT 2024-02-14 10:45:00   21590.6000
# 1103 2024-02-19 09:15:00      SHORT 2024-02-19 09:45:00   22049.7000
# 1104 2024-02-20 10:15:00      SHORT 2024-02-20 10:45:00   22093.8500
# 1105 2024-02-21 13:45:00      SHORT 2024-02-21 14:15:00   22105.4000
# 1106 2024-02-22 09:45:00      SHORT 2024-02-22 10:15:00   21901.0500
# 1107 2024-02-23 14:45:00      SHORT 2024-02-23 15:15:00   22209.5000
# 1108 2024-02-26 14:15:00      SHORT 2024-02-26 14:45:00   22138.3500
# 1109 2024-02-28 11:15:00      SHORT 2024-02-28 11:45:00   22020.0000
# 1110 2024-02-28 13:45:00      SHORT 2024-02-28 14:15:00   21993.1500
# 1111 2024-03-02 12:15:00      SHORT 2024-03-04 09:15:00   22372.2000
# 1112 2024-03-04 14:45:00      SHORT 2024-03-04 15:15:00   22403.0500
# 1113 2024-03-05 11:45:00      SHORT 2024-03-05 12:15:00   22317.3500
# 1114 2024-03-06 10:15:00      SHORT 2024-03-06 10:45:00   22274.5500
# 1115 2024-03-07 14:45:00      SHORT 2024-03-07 15:15:00   22475.7000
# 1116 2024-03-11 09:45:00      SHORT 2024-03-11 10:15:00   22429.6500
# 1117 2024-03-12 11:15:00      SHORT 2024-03-12 11:45:00   22323.8500
# 1118 2024-03-13 10:15:00      SHORT 2024-03-13 10:45:00   22279.1000
# 1119 2024-03-13 13:15:00      SHORT 2024-03-13 13:45:00   22053.2500
# 1120 2024-03-15 09:45:00      SHORT 2024-03-15 10:15:00   21981.3000
# 1121 2024-03-19 13:15:00      SHORT 2024-03-19 13:45:00   21844.5500
# 1122 2024-03-20 10:15:00      SHORT 2024-03-20 10:45:00   21716.0000
# 1123 2024-03-26 11:15:00      SHORT 2024-03-26 11:45:00   22029.7000
# 1124 2024-04-01 12:15:00      SHORT 2024-04-01 12:45:00   22461.0000
# 1125 2024-04-01 14:15:00      SHORT 2024-04-01 14:45:00   22434.1500
# 1126 2024-04-02 10:15:00      SHORT 2024-04-02 10:45:00   22409.3500
# 1127 2024-04-02 12:45:00      SHORT 2024-04-02 13:15:00   22408.2000
# 1128 2024-04-04 09:15:00      SHORT 2024-04-04 09:45:00   22451.6000
# 1129 2024-04-05 13:45:00      SHORT 2024-04-05 14:15:00   22489.9500
# 1130 2024-04-09 12:45:00      SHORT 2024-04-09 13:15:00   22682.1500
# 1131 2024-04-12 11:45:00      SHORT 2024-04-12 12:15:00   22679.4000
# 1132 2024-04-15 10:45:00      SHORT 2024-04-15 11:15:00   22361.2000
# 1133 2024-04-16 10:45:00      SHORT 2024-04-16 11:15:00   22183.8000
# 1134 2024-04-18 13:45:00      SHORT 2024-04-18 14:15:00   22091.7500
# 1135 2024-04-19 10:15:00      SHORT 2024-04-19 10:45:00   21853.6000
# 1136 2024-04-25 11:45:00      SHORT 2024-04-25 12:15:00   22387.3000
# 1137 2024-04-26 12:15:00      SHORT 2024-04-26 12:45:00   22494.7500
# 1138 2024-04-29 09:15:00      SHORT 2024-04-29 09:45:00   22468.8000
# 1139 2024-05-02 10:15:00      SHORT 2024-05-02 10:45:00   22655.9500
# 1140 2024-05-03 10:45:00      SHORT 2024-05-03 11:15:00   22583.4500
# 1141 2024-05-03 12:45:00      SHORT 2024-05-03 13:15:00   22396.6000
# 1142 2024-05-07 10:15:00      SHORT 2024-05-07 10:45:00   22317.6000
# 1143 2024-05-07 13:45:00      SHORT 2024-05-07 14:15:00   22292.7500
# 1144 2024-05-09 09:45:00      SHORT 2024-05-09 10:15:00   22188.3500
# 1145 2024-05-13 09:45:00      SHORT 2024-05-13 10:15:00   21828.4000
# 1146 2024-05-15 11:45:00      SHORT 2024-05-15 12:15:00   22179.7500
# 1147 2024-05-16 12:45:00      SHORT 2024-05-16 13:15:00   22103.8000
# 1148 2024-05-18 11:15:00      SHORT 2024-05-18 11:45:00   22488.2500
# 1149 2024-05-22 09:15:00      SHORT 2024-05-22 09:45:00   22496.7500
# 1150 2024-05-24 14:15:00      SHORT 2024-05-24 14:45:00   22964.0500
# 1151 2024-05-28 09:15:00      SHORT 2024-05-28 09:45:00   22936.5500
# 1152 2024-05-29 13:15:00      SHORT 2024-05-29 13:45:00   22758.2500
# 1153 2024-05-30 10:45:00      SHORT 2024-05-30 11:15:00   22562.7500
# 1154 2024-06-04 09:45:00      SHORT 2024-06-04 10:15:00   22565.6500
#
#       Initial SL   Final SL           Exit Time  Exit Price  Points Captured  \
# 1082  21834.3500 21558.1891 2024-01-03 11:15:00  21574.1500         124.8500
# 1083  21591.4500 21553.6755 2024-01-04 09:15:00  21605.8000         -44.8000
# 1084  21744.0500 21744.0500 2024-01-08 09:15:00  21747.6000         -62.0500
# 1085  21763.9500 21540.7236 2024-01-10 09:15:00  21558.2500          47.0500
# 1086  21661.9000 21661.9000 2024-01-11 09:15:00  21688.0000        -164.6000
# 1087  22124.1500 21636.0727 2024-01-17 11:45:00  21675.4500         386.7500
# 1088  21836.9000 21419.9591 2024-01-18 10:15:00  21452.7000         190.1000
# 1089  21539.4000 21539.4000 2024-01-19 09:15:00  21615.2000        -180.4500
# 1090  21720.3000 21644.3991 2024-01-20 12:45:00  21653.2500          -9.7000
# 1091  21663.3500 21663.3500 2024-01-23 09:15:00  21716.7000        -129.8000
# 1092  21750.2500 21297.3027 2024-01-24 12:45:00  21300.8500         219.0500
# 1093  21459.0000 21459.0000 2024-01-29 09:15:00  21459.0000        -179.2500
# 1094  21813.0500 21534.2300 2024-01-31 09:15:00  21576.3500         121.7000
# 1095  21832.9500 21832.9500 2024-02-02 09:15:00  21832.9500        -121.9500
# 1096  21939.7500 21939.7500 2024-02-05 09:45:00  21939.7500        -101.9000
# 1097  21964.3000 21782.9627 2024-02-06 09:15:00  21836.4500          62.9500
# 1098  21944.2000 21937.1673 2024-02-06 14:15:00  21944.2000        -112.0500
# 1099  22021.0500 21784.7018 2024-02-08 11:45:00  21804.0500          80.9500
# 1100  21967.5500 21710.1464 2024-02-12 10:45:00  21717.3000          66.0000
# 1101  21831.7000 21708.2955 2024-02-13 13:15:00  21734.1000         -43.3500
# 1102  21761.5500 21761.5500 2024-02-14 14:15:00  21761.5500        -170.9500
# 1103  22107.6000 22107.6000 2024-02-19 10:45:00  22107.6000         -57.9000
# 1104  22186.6500 22186.6500 2024-02-20 14:45:00  22186.6500         -92.8000
# 1105  22241.5000 22028.4009 2024-02-22 09:15:00  22047.1500          58.2500
# 1106  22204.6000 22204.6000 2024-02-22 14:45:00  22204.6000        -303.5500
# 1107  22268.6500 22093.4127 2024-02-26 11:45:00  22096.7000         112.8000
# 1108  22173.8500 22126.7427 2024-02-27 10:15:00  22135.0500           3.3000
# 1109  22229.1500 22039.3945 2024-02-28 12:15:00  22051.7500         -31.7500
# 1110  22088.2000 21986.9927 2024-02-29 14:45:00  21996.7000          -3.5500
# 1111  22420.2500 22420.2500 2024-03-04 09:15:00  22420.2500         -48.0500
# 1112  22434.2500 22300.1273 2024-03-05 11:15:00  22324.7000          78.3500
# 1113  22406.5500 22406.5500 2024-03-05 12:45:00  22406.5500         -89.2000
# 1114  22384.0500 22384.0500 2024-03-06 13:45:00  22384.0500        -109.5000
# 1115  22525.6500 22525.6500 2024-03-11 09:15:00  22525.6500         -49.9500
# 1116  22526.6000 22362.5673 2024-03-12 09:15:00  22428.5500           1.1000
# 1117  22452.5500 22340.2473 2024-03-13 09:15:00  22342.2500         -18.4000
# 1118  22446.7500 22078.5491 2024-03-13 12:45:00  22109.5500         169.5500
# 1119  22317.3000 22137.2355 2024-03-14 14:45:00  22144.2500         -91.0000
# 1120  22163.7000 21794.5955 2024-03-19 11:45:00  21828.0500         153.2500
# 1121  21882.3500 21836.8173 2024-03-20 09:15:00  21882.3500         -37.8000
# 1122  21891.7000 21891.7000 2024-03-20 12:45:00  21891.7000        -175.7000
# 1123  22095.0000 22018.1073 2024-03-26 15:15:00  22018.2500          11.4500
# 1124  22524.4000 22450.0264 2024-04-01 13:45:00  22454.5000           6.5000
# 1125  22489.0500 22489.0500 2024-04-02 09:15:00  22489.0500         -54.9000
# 1126  22497.6000 22422.2227 2024-04-02 12:15:00  22427.9500         -18.6000
# 1127  22448.3500 22448.3500 2024-04-02 14:45:00  22448.3500         -40.1500
# 1128  22619.0000 22496.0536 2024-04-05 10:45:00  22514.4000         -62.8000
# 1129  22528.9000 22528.9000 2024-04-05 15:15:00  22528.9000         -38.9500
# 1130  22768.4000 22625.8518 2024-04-09 14:15:00  22633.6500          48.5000
# 1131  22726.4500 22353.7791 2024-04-15 10:15:00  22378.0500         301.3500
# 1132  22549.0500 22183.2118 2024-04-16 10:15:00  22188.3500         172.8500
# 1133  22314.9500 22314.9500 2024-04-18 12:15:00  22314.9500        -131.1500
# 1134  22326.5000 21857.4991 2024-04-19 09:45:00  21884.7500         207.0000
# 1135  22171.3000 22171.3000 2024-04-19 13:45:00  22171.3000        -317.7000
# 1136  22475.5500 22424.9255 2024-04-25 12:45:00  22452.1500         -64.8500
# 1137  22600.4500 22420.1545 2024-04-26 15:15:00  22450.2000          44.5500
# 1138  22532.5000 22532.5000 2024-04-29 10:15:00  22532.5000         -63.7000
# 1139  22783.3500 22691.2073 2024-05-03 09:15:00  22783.3500        -127.4000
# 1140  22794.7000 22520.3636 2024-05-03 12:15:00  22541.8500          41.6000
# 1141  22696.7000 22519.8118 2024-05-06 11:45:00  22520.9500        -124.3500
# 1142  22499.0500 22246.5291 2024-05-07 12:15:00  22253.0000          64.6000
# 1143  22330.4000 22236.2436 2024-05-08 11:15:00  22278.1500          14.6000
# 1144  22322.3500 22029.0582 2024-05-10 13:15:00  22035.0500         153.3000
# 1145  22072.4000 21876.1364 2024-05-13 10:45:00  21911.1000         -82.7000
# 1146  22297.5500 22297.5500 2024-05-16 09:15:00  22319.2000        -139.4500
# 1147  22303.5500 22129.4064 2024-05-16 14:15:00  22244.0500        -140.2500
# 1148  22519.8500 22482.2791 2024-05-21 10:45:00  22503.8500         -15.6000
# 1149  22578.5000 22578.5000 2024-05-22 12:15:00  22578.5000         -81.7500
# 1150  23026.4000 22981.5345 2024-05-27 09:15:00  23038.9500         -74.9000
# 1151  23091.8500 22703.0609 2024-05-29 11:15:00  22722.9500         213.6000
# 1152  22802.4000 22587.7545 2024-05-30 10:15:00  22590.5500         167.7000
# 1153  22738.1000 22530.3600 2024-05-31 12:45:00  22535.3500          27.4000
# 1154  23308.2500 22548.4155 2024-06-05 14:15:00  22577.1000         -11.4500
#
#       After Costs          PnL               Remarks   Qty  Leverage    ROI%  \
# 1082     120.5227  334450.4509               TSL Hit  2775         6  3.3445
# 1083     -49.1167 -136298.7870  Gap Open Outside ISL  2775         6 -1.3630
# 1084     -66.3933 -184241.4491  Gap Open Outside ISL  2775         6 -1.8424
# 1085      42.7336  118585.8649               TSL Hit  2775         6  1.1859
# 1086    -168.9211 -472979.1920  Gap Open Outside ISL  2800         6 -4.7298
# 1087     382.3762 1041975.2404               TSL Hit  2725         6 10.4198
# 1088     185.7904  515568.4987               TSL Hit  2775         6  5.1557
# 1089    -184.7550 -517313.9860  Gap Open Outside ISL  2800         6 -5.1731
# 1090     -14.0297  -38932.3620               TSL Hit  2775         6 -0.3893
# 1091    -134.1304 -372211.7490  Gap Open Outside ISL  2775         6 -3.7221
# 1092     214.7679  601350.1900               TSL Hit  2800         6  6.0135
# 1093    -183.5239 -518454.9469        Initial SL Hit  2825         6 -5.1845
# 1094     117.3726  325708.8540               TSL Hit  2775         6  3.2571
# 1095    -126.3044 -350494.6961        Initial SL Hit  2775         6 -3.5049
# 1096    -106.2778 -292263.8400        Initial SL Hit  2750         6 -2.9226
# 1097      58.5764  161085.1413               TSL Hit  2750         6  1.6109
# 1098    -116.4276 -320175.9962        Initial SL hit  2750         6 -3.2018
# 1099      76.5811  210598.0113               TSL Hit  2750         6  2.1060
# 1100      61.6499  169537.3350               TSL Hit  2750         6  1.6954
# 1101     -47.6925 -132346.6459               TSL Hit  2775         6 -1.3235
# 1102    -175.2852 -486416.4716        Initial SL Hit  2775         6 -4.8642
# 1103     -62.3157 -169810.3642        Initial SL Hit  2725         6 -1.6981
# 1104     -97.2281 -264946.4363        Initial SL Hit  2725         6 -2.6495
# 1105      53.8347  146699.6801               TSL Hit  2725         6  1.4670
# 1106    -307.9606 -846891.5537        Initial SL Hit  2750         6 -8.4689
# 1107     108.3694  292597.3260               TSL Hit  2700         6  2.9260
# 1108      -1.1273   -3043.8180               TSL Hit  2700         6 -0.0304
# 1109     -36.1572  -98528.3019               TSL Hit  2725         6 -0.9853
# 1110      -7.9490  -21660.9841               TSL Hit  2725         6 -0.2166
# 1111     -52.5292 -140515.7304        Initial SL Hit  2675         6 -1.4052
# 1112      73.8772  197621.5769               TSL Hit  2675         6  1.9762
# 1113     -93.6724 -252915.4530        Initial SL Hit  2700         6 -2.5292
# 1114    -113.9659 -307707.8220        Initial SL Hit  2700         6 -3.0771
# 1115     -54.4501 -145654.1111        Initial SL Hit  2675         6 -1.4565
# 1116      -3.3858   -9057.0685               TSL Hit  2675         6 -0.0906
# 1117     -22.8666  -61739.8470               TSL Hit  2700         6 -0.6174
# 1118     165.1111  445800.0645               TSL Hit  2700         6  4.4580
# 1119     -95.4197 -260018.8187               TSL Hit  2725         6 -2.6002
# 1120     148.8691  405668.2021               TSL Hit  2725         6  4.0567
# 1121     -42.1727 -115974.8975        Initial SL hit  2750         6 -1.1597
# 1122    -180.0608 -499668.6368        Initial SL Hit  2775         6 -4.9967
# 1123       7.0452   19198.1836               TSL Hit  2725         6  0.1920
# 1124       2.0084    5372.6037               TSL Hit  2675         6  0.0537
# 1125     -59.3923 -158874.4560        Initial SL Hit  2675         6 -1.5887
# 1126     -23.0837  -61748.9778               TSL Hit  2675         6 -0.6175
# 1127     -44.6357 -119400.3771        Initial SL Hit  2675         6 -1.1940
# 1128     -67.2966 -180018.4050               TSL Hit  2675         6 -1.8002
# 1129     -43.4519 -116233.7924        Initial SL Hit  2675         6 -1.1623
# 1130      43.9684  116516.3130               TSL Hit  2650         6  1.1652
# 1131     296.8443  786637.2758               TSL Hit  2650         6  7.8664
# 1132     168.3950  450456.7454               TSL Hit  2675         6  4.5046
# 1133    -135.5999 -366119.6625        Initial SL Hit  2700         6 -3.6612
# 1134     202.6024  552091.4038               TSL Hit  2725         6  5.5209
# 1135    -322.1025 -885781.8475        Initial SL Hit  2750         6 -8.8578
# 1136     -69.3339 -185468.3029               TSL Hit  2675         6 -1.8547
# 1137      40.0555  107148.4759               TSL Hit  2675         6  1.0715
# 1138     -68.2001 -182435.3478        Initial SL Hit  2675         6 -1.8244
# 1139    -131.9439 -349651.4145        Initial SL hit  2650         6 -3.4965
# 1140      37.0875   98281.7955               TSL Hit  2650         6  0.9828
# 1141    -128.8418 -344651.6946               TSL Hit  2675         6 -3.4465
# 1142      60.1429  162385.9380               TSL Hit  2700         6  1.6239
# 1143      10.1429   27385.8570               TSL Hit  2700         6  0.2739
# 1144     148.8777  401969.6820               TSL Hit  2700         6  4.0197
# 1145     -87.0739 -239453.3625               TSL Hit  2750         6 -2.3945
# 1146    -143.8999 -388529.7165  Gap Open Outside ISL  2700         6 -3.8853
# 1147    -144.6848 -394266.0391               TSL Hit  2725         6 -3.9427
# 1148     -20.0992  -53765.3867               TSL Hit  2675         6 -0.5377
# 1149     -86.2575 -230738.8794        Initial SL Hit  2675         6 -2.3074
# 1150     -79.5003 -208688.2875  Gap Open Outside ISL  2625         6 -2.0869
# 1151     209.0340  548714.3812               TSL Hit  2625         6  5.4871
# 1152     163.1651  428308.4400               TSL Hit  2625         6  4.2831
# 1153      22.8902   60659.0035               TSL Hit  2650         6  0.6066
# 1154     -15.9643  -42305.3287               TSL Hit  2650         6 -0.4231
#
#       Trade Year  Trade Month       DD%
# 1082        2024            1 -236.1104
# 1083        2024            1 -237.4734
# 1084        2024            1 -239.3158
# 1085        2024            1 -238.1300
# 1086        2024            1 -242.8598
# 1087        2024            1 -232.4400
# 1088        2024            1 -227.2843
# 1089        2024            1 -232.4575
# 1090        2024            1 -232.8468
# 1091        2024            1 -236.5689
# 1092        2024            1 -230.5554
# 1093        2024            1 -235.7400
# 1094        2024            1 -232.4829
# 1095        2024            2 -235.9878
# 1096        2024            2 -238.9105
# 1097        2024            2 -237.2996
# 1098        2024            2 -240.5014
# 1099        2024            2 -238.3954
# 1100        2024            2 -236.7000
# 1101        2024            2 -238.0235
# 1102        2024            2 -242.8877
# 1103        2024            2 -244.5858
# 1104        2024            2 -247.2352
# 1105        2024            2 -245.7682
# 1106        2024            2 -254.2371
# 1107        2024            2 -251.3112
# 1108        2024            2 -251.3416
# 1109        2024            2 -252.3269
# 1110        2024            2 -252.5435
# 1111        2024            3 -253.9487
# 1112        2024            3 -251.9724
# 1113        2024            3 -254.5016
# 1114        2024            3 -257.5787
# 1115        2024            3 -259.0352
# 1116        2024            3 -259.1258
# 1117        2024            3 -259.7432
# 1118        2024            3 -255.2852
# 1119        2024            3 -257.8854
# 1120        2024            3 -253.8287
# 1121        2024            3 -254.9884
# 1122        2024            3 -259.9851
# 1123        2024            3 -259.7931
# 1124        2024            4 -259.7394
# 1125        2024            4 -261.3282
# 1126        2024            4 -261.9457
# 1127        2024            4 -263.1397
# 1128        2024            4 -264.9398
# 1129        2024            4 -266.1022
# 1130        2024            4 -264.9370
# 1131        2024            4 -257.0706
# 1132        2024            4 -252.5661
# 1133        2024            4 -256.2273
# 1134        2024            4 -250.7064
# 1135        2024            4 -259.5642
# 1136        2024            4 -261.4189
# 1137        2024            4 -260.3474
# 1138        2024            4 -262.1717
# 1139        2024            5 -265.6682
# 1140        2024            5 -264.6854
# 1141        2024            5 -268.1319
# 1142        2024            5 -266.5081
# 1143        2024            5 -266.2342
# 1144        2024            5 -262.2145
# 1145        2024            5 -264.6091
# 1146        2024            5 -268.4944
# 1147        2024            5 -272.4370
# 1148        2024            5 -272.9747
# 1149        2024            5 -275.2821
# 1150        2024            5 -277.3689
# 1151        2024            5 -271.8818
# 1152        2024            5 -267.5987
# 1153        2024            5 -266.9921
# 1154        2024            6 -267.4152

# %%
import matplotlib.pyplot as plt

# tradebook = both_indices_combined_tb
tradebook = pd.read_csv('MIDFAIR_JJ.csv')
# tradebook.tail(1)

# %%
tradebook["Cumulative Returns"] = tradebook["ROI%"].cumsum()
plt.figure(figsize=(22, 6))
plt.plot(tradebook["Cumulative Returns"], linestyle="-")
plt.title("Combined 4 Indices ROI Over Time")
plt.xlabel("Trade Number")
plt.ylabel("ROI")
plt.grid(True)
plt.show()

# %%
# tradebook
