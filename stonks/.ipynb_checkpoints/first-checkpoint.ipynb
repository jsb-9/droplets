# %%
import pandas as pd
import polars as pl
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import mplfinance as mpf
from plotly.subplots import make_subplots
from dash import Dash, dcc, html
import pandas_market_calendars as mcal
import sys
import asyncio
nse = mcal.get_calendar('NSE')

# %%
import sys
sys.path.append('..')
from tooling.filter import find_atm, option_tool
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm
from tooling.enums import Index, AssetClass, StrikeSpread, Spot

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(25_000)
# Out:
# polars.config.Config

# %%
stock = pd.read_csv('../data/Nifty Next50 FNO Data/berger_paints_10_1_monthly.csv')
current_stock = 'BERGER PAINT'
stock
# Out:
#            time        open        high         low       close    Up Trend  \
# 0    1995-05-01    0.831950    0.911860    0.831950    0.902460         NaN
# 1    1995-06-01    0.846060    1.052870    0.846060    0.940060         NaN
# 2    1995-07-03    0.864860    0.869560    0.799520    0.864860         NaN
# 3    1995-08-01    0.940530    0.958860    0.846060    0.930660         NaN
# 4    1995-09-01    0.930660    0.987060    0.808450    0.808450         NaN
# 5    1995-10-02    0.925960    1.038300    0.911860    0.921260         NaN
# 6    1995-11-01    0.921260    0.958860    0.639240    0.658040         NaN
# 7    1995-12-01    0.705050    0.863920    0.705050    0.841350         NaN
# 8    1996-01-01    0.850760    0.942460    0.568580    0.595240         NaN
# 9    1996-02-01    0.587180    0.917660    0.587180    0.768850         NaN
# 10   1996-03-01    0.793650    0.855040    0.589660    0.636160         NaN
# 11   1996-04-01    0.635540    0.855660    0.635540    0.768850         NaN
# 12   1996-05-01    0.768850    0.787450    0.646080    0.713050         NaN
# 13   1996-06-03    0.707470    1.052210    0.706850    0.917660         NaN
# 14   1996-07-01    0.899060    0.902160    0.744050    0.756450         NaN
# 15   1996-08-01    0.744050    0.818450    0.719250    0.763270         NaN
# 16   1996-09-02    0.768850    0.824030    0.685140    0.685140         NaN
# 17   1996-10-01    0.706850    0.731650    0.607640    0.644840         NaN
# 18   1996-11-01    0.657240    0.669640    0.468130    0.496030         NaN
# 19   1996-12-02    0.511530    0.638640    0.511530    0.626240         NaN
# 20   1997-01-01    0.657240    0.812250    0.654140    0.765130    0.543455
# 21   1997-02-03    0.744050    0.867440    0.667160    0.828990    0.576506
# 22   1997-03-03    0.868060    0.928200    0.655380    0.655380    0.592793
# 23   1997-04-01    0.682040    0.830230    0.644840    0.830230    0.592793
# 24   1997-05-01    0.830850    0.874260    0.719250    0.822170    0.603382
# 25   1997-06-02    0.840770    1.234500    0.782490    1.069570    0.789258
# 26   1997-07-01    1.091270    1.398190    1.075770    1.388270    1.006805
# 27   1997-08-01    1.376490    1.401290    1.054070    1.066470    1.006805
# 28   1997-09-01    1.032370    1.103050    0.944940    0.972220         NaN
# 29   1997-10-01    0.967260    0.979660    0.856280    0.925720         NaN
# 30   1997-11-03    0.905260    1.016870    0.793650    0.939360         NaN
# 31   1997-12-01    0.893480    1.162570    0.883560    1.054690         NaN
# 32   1998-01-01    1.004460    1.114210    0.868060    0.930060         NaN
# 33   1998-02-02    0.911460    0.967260    0.846970    0.936260         NaN
# 34   1998-03-02    0.930060    1.085070    0.918900    0.986480         NaN
# 334  2023-04-03  482.499807  509.999796  473.208127  508.624780         NaN
# 335  2023-05-02  510.041454  545.583123  506.291456  542.041458  469.960863
# 336  2023-06-01  543.749783  574.166437  532.708120  565.083091  498.912663
# 337  2023-07-03  566.583123  579.541443  545.624782  568.666456  510.119292
# 338  2023-08-01  569.041422  604.916441  564.624766  598.833077  533.523998
# 339  2023-09-01  599.708110  679.750000  566.250000  568.849980  565.528055
# 340  2023-10-03  573.400020  585.900020  533.099980  558.599980         NaN
# 341  2023-11-01  558.549990  592.650020  541.150020  574.400020         NaN
# 342  2023-12-01  576.000000  607.000000  562.700010  604.650020         NaN
# 343  2024-01-01  607.500000  609.000000  542.549990  565.150020         NaN
# 344  2024-02-01  565.549990  620.599980  543.450010  606.700010         NaN
# 345  2024-03-01  589.299990  603.799990  542.250000  573.049990         NaN
# 346  2024-04-01  570.000000  574.000000  500.700010  508.549990         NaN
# 347  2024-05-02  511.049990  527.750000  478.000000  491.850010         NaN
#
#      Down Trend
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9      0.970258
# 10     0.944942
# 11     0.944942
# 12     0.931012
# 13     0.931012
# 14     0.931012
# 15     0.931012
# 16     0.931012
# 17     0.864408
# 18     0.764322
# 19     0.764322
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28     1.257498
# 29     1.140461
# 30     1.127824
# 31     1.127824
# 32     1.127824
# 33     1.126146
# 34     1.126146
# 35     1.126146
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN
# 54          NaN
# 55          NaN
# 56          NaN
# 57          NaN
# 58          NaN
# 59          NaN
# 60          NaN
# 61          NaN
# 62          NaN
# 63          NaN
# 64          NaN
# 65          NaN
# 66          NaN
# 67          NaN
# 68          NaN
# 69          NaN
# 70          NaN
# 71          NaN
# 72          NaN
# 73          NaN
# 74          NaN
# 75          NaN
# 76          NaN
# 77     2.292145
# 78     2.263947
# 79     2.108733
# 80     2.023355
# 81     2.023355
# 82     2.023355
# 83     2.023355
# 84     2.023355
# 85     2.023355
# 86     2.023355
# 87     2.023355
# 88     2.023355
# 89     2.023355
# 90     2.023355
# 91     2.023355
# 92     2.011736
# 93     1.913799
# 94     1.913799
# 95          NaN
# 96          NaN
# 97          NaN
# 98          NaN
# 99          NaN
# 100         NaN
# 101         NaN
# 102         NaN
# 103         NaN
# 104         NaN
# 105    5.160945
# 106    5.160945
# 107    4.940885
# 108    4.940885
# 109    4.940885
# 110         NaN
# 111         NaN
# 112         NaN
# 113         NaN
# 114         NaN
# 115         NaN
# 116         NaN
# 117         NaN
# 118         NaN
# 119         NaN
# 120         NaN
# 121         NaN
# 122         NaN
# 123         NaN
# 124         NaN
# 125         NaN
# 126         NaN
# 127         NaN
# 128         NaN
# 129         NaN
# 130         NaN
# 131   17.327997
# 132   16.649883
# 133   16.649883
# 134   16.649883
# 135   16.649883
# 136   16.649883
# 137   16.649883
# 138   16.533262
# 139   15.743774
# 140   14.641122
# 141   13.678497
# 142   13.652908
# 143   13.652908
# 144         NaN
# 145         NaN
# 146         NaN
# 147         NaN
# 148         NaN
# 149         NaN
# 150         NaN
# 151   19.247014
# 152   16.145231
# 153   15.126689
# 154   15.126689
# 155   15.126689
# 156   14.213356
# 157   14.213356
# 158   14.213356
# 159   14.208406
# 160   12.360483
# 161   12.360483
# 162   12.360483
# 163   12.360483
# 164   12.360483
# 165   12.360483
# 166   12.360483
# 167         NaN
# 168         NaN
# 169         NaN
# 170         NaN
# 171         NaN
# 172         NaN
# 173         NaN
# 174         NaN
# 175         NaN
# 176         NaN
# 177         NaN
# 178         NaN
# 179         NaN
# 180         NaN
# 181         NaN
# 182         NaN
# 183         NaN
# 184         NaN
# 185         NaN
# 186         NaN
# 187   32.530554
# 188   31.042309
# 189   31.042309
# 190   31.042309
# 191         NaN
# 192         NaN
# 193         NaN
# 194         NaN
# 195         NaN
# 196         NaN
# 197         NaN
# 198   32.404791
# 199   32.404791
# 200   32.404791
# 201   32.404791
# 202         NaN
# 203         NaN
# 204         NaN
# 205         NaN
# 206         NaN
# 207         NaN
# 208         NaN
# 209         NaN
# 210         NaN
# 211         NaN
# 212         NaN
# 213         NaN
# 214         NaN
# 215         NaN
# 216         NaN
# 217   75.113367
# 218   73.932380
# 219   73.932380
# 220   73.932380
# 221   73.932380
# 222   73.932380
# 223   73.905890
# 224   70.881365
# 225   70.881365
# 226         NaN
# 227         NaN
# 228         NaN
# 229         NaN
# 230         NaN
# 231         NaN
# 232         NaN
# 233         NaN
# 234         NaN
# 235         NaN
# 236         NaN
# 237         NaN
# 238         NaN
# 239         NaN
# 240  130.532638
# 241  130.532638
# 242  130.532638
# 243         NaN
# 244         NaN
# 245         NaN
# 246         NaN
# 247         NaN
# 248  169.418979
# 249  158.497911
# 250  158.497911
# 251         NaN
# 252         NaN
# 253         NaN
# 254         NaN
# 255         NaN
# 256         NaN
# 257  215.156845
# 258  207.130734
# 259  207.130734
# 260  207.130734
# 261  207.130734
# 262         NaN
# 263         NaN
# 264         NaN
# 265         NaN
# 266         NaN
# 267         NaN
# 268         NaN
# 269         NaN
# 270         NaN
# 271         NaN
# 272         NaN
# 273         NaN
# 274         NaN
# 275         NaN
# 276         NaN
# 277         NaN
# 278         NaN
# 279  288.441610
# 280  262.007861
# 281         NaN
# 282         NaN
# 283         NaN
# 284         NaN
# 285         NaN
# 286         NaN
# 287         NaN
# 288         NaN
# 289         NaN
# 290         NaN
# 291         NaN
# 292         NaN
# 293         NaN
# 294         NaN
# 295         NaN
# 296         NaN
# 297  458.911630
# 298  458.911630
# 299  448.740262
# 300  448.740262
# 301  448.740262
# 302  448.740262
# 303         NaN
# 304         NaN
# 305         NaN
# 306         NaN
# 307         NaN
# 308  678.507881
# 309  673.809160
# 310  673.809160
# 311  673.809160
# 312  673.809160
# 313         NaN
# 314         NaN
# 315         NaN
# 316  726.655617
# 317  716.450455
# 318  694.257461
# 319  692.656690
# 320  651.395171
# 321  633.622314
# 322  633.622314
# 323  602.905685
# 324  568.646373
# 325  568.646373
# 326  568.646373
# 327  568.646373
# 328  568.646373
# 329  568.646373
# 330  566.613303
# 331  531.306135
# 332  525.348435
# 333  525.348435
# 334  525.348435
# 335         NaN
# 336         NaN
# 337         NaN
# 338         NaN
# 339         NaN
# 340  607.961894
# 341  607.961894
# 342  607.961894
# 343  607.961894
# 344  607.961894
# 345  607.961894
# 346  597.816068
# 347  562.269457

# %%
df = stock
df['monthly_long'] = 0
df['monthly_long'] = np.where(pd.notna(df['Down Trend']), -1, df['monthly_long'])
df['monthly_long'] = np.where(pd.notna(df['Up Trend']), 1, df['monthly_long'])
df['monthly_long'] = df['monthly_long'].replace(0, np.nan)
df['monthly_long'] = df['monthly_long'].ffill()

df = df.rename(columns={'time': 'datetime', 'Up Trend': 'monthly_supertrend_green', 'Down Trend': 'monthly_supertrend_red'})
# df = df.drop(columns=['Up Trend.1', 'Down Trend.1'])

df['datetime'] = pd.to_datetime(df['datetime'])
df['datetime'] = df['datetime'].dt.tz_localize(None)

# df

# %%
df = df[(df['datetime'].dt.year >= 2015)]
df = df.reset_index()
df['indexer'] = df.index

# %%
df
# Out:
#      index   datetime        open        high         low       close  \
# 0      235 2015-01-01  119.657567  150.416456  119.345071  136.279571
# 1      236 2015-02-02  133.868854  135.714096  118.184358  133.303385
# 2      237 2015-03-02  133.333147  135.059329  119.702219  124.196249
# 3      238 2015-04-01  124.583159  137.975997  119.166500  125.386723
# 4      239 2015-05-04  126.487918  130.327199  120.922444  126.577198
# 5      240 2015-06-01  125.595062  126.785537  101.607001  116.279605
# 6      241 2015-07-01  117.231979  134.493859  116.368885  129.702193
# 7      242 2015-08-03  130.476008  139.880757  116.071266  126.487918
# 8      243 2015-09-01  124.999825  134.821240  123.779589  130.743859
# 9      244 2015-10-01  131.249816  137.291469  128.571249  131.964101
# 10     245 2015-11-02  131.309346  138.065283  128.035541  131.011727
# 11     246 2015-12-01  131.547435  161.220018  127.410536  160.029544
# 12     247 2016-01-01  160.684305  164.761668  143.035514  158.600974
# 13     248 2016-02-01  158.928349  168.839043  130.743859  133.511718
# 14     249 2016-03-01  133.392676  146.428367  132.440291  145.714082
# 15     250 2016-04-01  145.833129  157.737875  142.350985  153.273595
# 16     251 2016-05-02  153.124786  179.702124  148.511697  168.333092
# 17     252 2016-06-01  167.856908  177.083086  161.904535  164.404538
# 18     253 2016-07-01  164.583103  208.249908  163.958110  198.208262
# 19     254 2016-08-01  199.999920  226.083234  184.458268  216.958255
# 20     255 2016-09-01  216.999905  230.666566  209.416583  217.541571
# 21     256 2016-10-03  220.833245  227.374917  211.458249  214.499906
# 22     257 2016-11-01  216.499905  225.416576  148.291607  190.708265
# 23     258 2016-12-01  192.458256  197.208246  158.333270  175.458263
# 24     259 2017-01-02  176.666596  189.083249  172.708264  176.249929
# 25     260 2017-02-01  176.666596  197.208246  174.333264  193.166589
# 26     261 2017-03-01  194.916580  202.999927  183.583260  201.749928
# 27     262 2017-04-03  202.416577  221.124920  191.083257  217.708246
# 28     263 2017-05-02  218.333246  223.249902  195.916597  209.791583
# 29     264 2017-06-01  209.999916  215.333239  195.333247  205.208251
# 30     265 2017-07-03  206.458251  216.583238  200.833253  206.499917
# 31     266 2017-08-01  206.666584  214.833239  192.124923  204.999918
# 32     267 2017-09-01  205.166585  228.458234  198.333254  204.249927
# 33     268 2017-10-03  205.458251  238.583229  204.541585  221.708236
# 34     269 2017-11-01  222.874919  227.166584  205.124910  215.458239
# 35     270 2017-12-01  216.416588  233.333240  202.958252  228.124909
# 36     271 2018-01-01  230.583249  233.958240  204.166585  208.624925
# 97                        NaN              525.348435          -1.0       97
# 98                        NaN              525.348435          -1.0       98
# 99                        NaN              525.348435          -1.0       99
# 100                469.960863                     NaN           1.0      100
# 101                498.912663                     NaN           1.0      101
# 102                510.119292                     NaN           1.0      102
# 103                533.523998                     NaN           1.0      103
# 104                565.528055                     NaN           1.0      104
# 105                       NaN              607.961894          -1.0      105
# 106                       NaN              607.961894          -1.0      106
# 107                       NaN              607.961894          -1.0      107
# 108                       NaN              607.961894          -1.0      108
# 109                       NaN              607.961894          -1.0      109
# 110                       NaN              607.961894          -1.0      110
# 111                       NaN              597.816068          -1.0      111
# 112                       NaN              562.269457          -1.0      112

# %%
# def trade_high_break(stock_name):

#     in_trade = False
#     signal_active = False
#     entry_price = 0
#     exit_price = 0
#     signal_candle_high = 0
#     points = 0
#     remark = ''
#     initial_sl_pct = 3
#     target_pct = 15
#     portfolio_value = 5_00_000

#     tradebook = []
    
#     for i in range(0, len(df)):
        
#         if df.iloc[i]['monthly_long'] == 1 and df.iloc[i]['hourly_long'] == 1 and not in_trade:
#             #Signal Generated
#             if not signal_active:
#                 signal_active = True
#                 signal_time = df.iloc[i]['datetime']
#                 signal_candle_high = df.iloc[i]['high']
#             else:
#                 if df.iloc[i]['high'] < df.iloc[i-1]['high']:
#                     #Better Candle Formed
#                     signal_time = df.iloc[i]['datetime']
#                     signal_candle_high = df.iloc[i]['high']
            
#         if signal_active and not in_trade:
#             if df.iloc[i]['high'] > signal_candle_high:
#                 # Entry Triggered
#                 # print(df.iloc[i]['datetime'] , 'Entry Triggered' , signal_candle_high)
#                 in_trade = True
#                 entry_price = signal_candle_high
#                 entry_time = df.iloc[i]['datetime']
#                 initial_sl = entry_price * (1 - (initial_sl_pct / 100))
#                 initial_target = entry_price * (1 + (target_pct / 100))
#                 continue

#         if in_trade:
#             if df.iloc[i]['hourly_long'] == 0:
#                 # Supertrend reversed, SL hit
#                 # print(df.iloc[i]['datetime'] , 'Exited Trade' , df.iloc[i]['low'])
#                 exit_price = df.iloc[i]['close']
#                 exit_time = df.iloc[i]['datetime']
#                 in_trade = False
#                 signal_active = False
#                 points = exit_price - entry_price
#                 remark = 'SuperTrend Reversed'

#             elif df.iloc[i]['low'] < initial_sl:
#                 #Initial SL hit
                
#                 if df.iloc[i]['open'] < initial_sl:
#                     #Gapped below Initial SL, exit at open
#                     exit_price = initial_sl
#                     exit_time = df.iloc[i]['datetime']
#                     remark = 'Gapped Outside Initial SL'

#                 else:
#                     exit_price = initial_sl
#                     exit_time = df.iloc[i]['datetime']
#                     remark = 'Initial SL Hit'
                    
#                 in_trade = False
#                 signal_active = False
#                 points = exit_price - entry_price

#             elif df.iloc[i]['high'] > initial_target:
#                 # Target Hit
#                 exit_price = initial_target
#                 exit_time = df.iloc[i]['datetime']
#                 in_trade = False
#                 signal_active = False
#                 points = exit_price - entry_price
#                 remark = 'Target Hit'

#         if points:
            
#             qty = portfolio_value / entry_price
#             slippage = 0.001 * (entry_price + exit_price)
#             final_points = points - slippage
            
#             trade = {
#                 'Signal Generated At': signal_time,
#                 'Stock Name': stock_name,
#                 'Entry Date': entry_time.date(),
#                 'Entry Time': entry_time.time(),
#                 'Entry Price': entry_price,
#                 'Initial SL': initial_sl,
#                 'Initial Target': initial_target,
#                 'Exit Date': exit_time.date(),
#                 'Exit Time': exit_time.time(),
#                 'Exit Price': exit_price,
#                 'Remark': remark,
#                 'Points Captured': points,
#                 'After Costs': final_points,
#                 'Qty': qty,
#                 'PnL': final_points * qty,
#                 'ROI%': (final_points * qty / portfolio_value) * 100,
#                 'Trade Year': entry_time.year,
#                 'Trade Month': entry_time.month
#                 }
#             tradebook.append(trade)
#             entry_price = 0
#             exit_price = 0
#             points = 0
#             remark = ''
#             in_trade = False
#             signal_active = False

#     return tradebook

# %%
# def trade_next_open(stock_name):

#     in_trade = False
#     # signal_active = False
#     entry_price = 0
#     exit_price = 0
#     signal_candle_high = 0
#     points = 0
#     remark = ''
#     initial_sl_pct = 100
#     target_pct = 1500
#     portfolio_value = 5_00_000

#     tradebook = []
    
#     for i in range(0, len(df)):
        
#         if (df.iloc[i]['monthly_long'] == 1) and (df.iloc[i-1]['monthly_long'] == 1) and not in_trade:
#             #Entry Triggered
#             in_trade = True
#             entry_price = df.iloc[i]['open']
#             entry_time = df.iloc[i]['datetime']
#             initial_sl = entry_price * (1 - (initial_sl_pct / 100))
#             initial_target = entry_price * (1 + (target_pct / 100))
    
#             print('Entry Triggered ! ', df.iloc[i]['datetime'])

#             continue

#             #TODO : Try using the nearer SL between low of entry candle and initial_sl fixed for Initial SL of the trade
#             # ----> initial_sl = max( df.iloc[i]['low'] , entry_price * (1 - (initial_sl_pct / 100)) )
            
#         if in_trade:
#             if df.iloc[i]['monthly_long'] == -1:
#                 # Supertrend reversed, SL hit
#                 # print(df.iloc[i]['datetime'] , 'Exited Trade' , df.iloc[i]['low'])
#                 exit_price = df.iloc[i]['close']
#                 exit_time = df.iloc[i]['datetime']
#                 in_trade = False
#                 # signal_active = False
                
#                 points = exit_price - entry_price
#                 remark = 'SuperTrend Reversed'
#                 print(remark, df.iloc[i]['datetime'])

#             elif df.iloc[i]['low'] < initial_sl:
#                 #Initial SL hit
                
#                 if df.iloc[i]['open'] < initial_sl:
#                     #Gapped below Initial SL, exit at open
#                     exit_price = initial_sl
#                     exit_time = df.iloc[i]['datetime']
#                     remark = 'Gapped Outside Initial SL'
#                     print(remark, df.iloc[i]['datetime'])

#                 else:
#                     exit_price = initial_sl
#                     exit_time = df.iloc[i]['datetime']
#                     remark = 'Initial SL Hit'
#                     print(remark, df.iloc[i]['datetime'])
                    
#                 in_trade = False
#                 # signal_active = False
#                 points = exit_price - entry_price

#             elif df.iloc[i]['high'] > initial_target:
#                 # Target Hit
#                 exit_price = initial_target
#                 exit_time = df.iloc[i]['datetime']
#                 in_trade = False
#                 # signal_active = False
#                 points = exit_price - entry_price
#                 remark = 'Target Hit'
#                 print(remark, df.iloc[i]['datetime'])

#         if points:
            
#             qty = portfolio_value / entry_price
#             slippage = 0.001 * (entry_price + exit_price)
#             final_points = points - slippage
            
#             trade = {
#                 'Stock Name': stock_name,
#                 'Entry Date': entry_time.date(),
#                 'Entry Price': entry_price,
#                 'Initial SL': initial_sl,
#                 'Initial Target': initial_target,
#                 'Exit Date': exit_time.date(),
#                 'Exit Price': exit_price,
#                 'Remark': remark,
#                 'Points Captured': points,
#                 'After Costs': final_points,
#                 'Qty': qty,
#                 'PnL': final_points * qty,
#                 'ROI%': (final_points * qty / portfolio_value) * 100,
#                 'Trade Year': entry_time.year,
#                 'Trade Month': entry_time.month
#                 }
#             tradebook.append(trade)
#             entry_price = 0
#             exit_price = 0
#             points = 0
#             remark = ''
#             in_trade = False
#             # signal_active = False

#     return tradebook

# %%
# tb = trade_next_open(current_stock)
# tb_pandas = pd.DataFrame(tb)
# # tb_pandas

# %%
# tb_pandas

# %%
# roi = tb_pandas['ROI%'].sum()
# roi

# %%
# def stats(stock_name, df):
#     print(stock_name)
#     stats = pd.DataFrame(index=range(2012, 2025), columns=['Total ROI', 'Total Trades', 'Win Rate', 'Avg Profit% per Trade', 'Avg Loss% per Trade', 'Max Drawdown', 'ROI/DD Ratio'])
    
#     # Iterate over each year
#     for year in range(2012, 2025):
#         # Filter trades for the current year
#         year_trades = df[(df['Trade Year'] == year)]
        
#         # Calculate total ROI
#         total_roi = year_trades['ROI%'].sum()
        
#         # Calculate total number of trades
#         total_trades = len(year_trades)
        
#         # Calculate win rate
#         win_rate = (year_trades['ROI%'] > 0).mean()*100
        
#         # Calculate average profit per trade
#         avg_profit = year_trades[year_trades['ROI%'] > 0]['ROI%'].mean()
        
#         # Calculate average loss per trade
#         avg_loss = year_trades[year_trades['ROI%'] < 0]['ROI%'].mean()
        
#         # Calculate maximum drawdown
#         max_drawdown = (year_trades['ROI%'].cumsum() - year_trades['ROI%'].cumsum().cummax()).min()
        
#         # Calculate ROI/DD ratio
#         roi_dd_ratio = total_roi / abs(max_drawdown)
        
#         # Store the statistics in the DataFrame
#         stats.loc[year] = [total_roi, total_trades, win_rate, avg_profit, avg_loss, max_drawdown, roi_dd_ratio]
    
#     # Calculate overall statistics
#     overall_total_roi = stats['Total ROI'].sum()
#     overall_total_trades = stats['Total Trades'].sum()
#     overall_win_rate = (df['ROI%'] > 0).mean() * 100
#     overall_avg_profit = df[df['ROI%'] > 0]['ROI%'].mean()
#     overall_avg_loss = df[df['ROI%'] < 0]['ROI%'].mean()
#     overall_max_drawdown = (df['ROI%'].cumsum() - df['ROI%'].cumsum().cummax()).min()
#     overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    
#     # Store the overall statistics in the DataFrame
#     stats.loc['Overall'] = [overall_total_roi, overall_total_trades, overall_win_rate, overall_avg_profit, overall_avg_loss, overall_max_drawdown, overall_roi_dd_ratio]
#     return stats

# results = stats(current_stock, tb_pandas)
# results

# %%
# tradebook_name = f'{current_stock}_stonks_v2_tradebook.csv'
# tb_pandas.to_csv(tradebook_name)

# %%
from datetime import timedelta

def trade_next_open_monthly_long(stock_name, df):
    in_trade = False
    entry_price = 0
    exit_price = 0
    signal_candle_high = 0
    points = 0
    remark = ''
    initial_sl_pct = 100
    target_pct = 1500
    portfolio_value = 10_00_000
    trade_number = 1

    tradebook = []
    
    for i in range(0, len(df)):
        
        if (df.iloc[i]['monthly_long'] == 1) and not in_trade:
            #Entry Triggered
            in_trade = True
            entry_price = df.iloc[i]['close']
            entry_time = df.iloc[i]['datetime']
            initial_sl = entry_price * (1 - (initial_sl_pct / 100))
            initial_target = entry_price * (1 + (target_pct / 100))
    
            # print('Entry Triggered ! ', df.iloc[i]['datetime'])

            continue

            #TODO : Try using the nearer SL between low of entry candle and initial_sl fixed for Initial SL of the trade
            # ----> initial_sl = max( df.iloc[i]['low'] , entry_price * (1 - (initial_sl_pct / 100)) )
            
        if in_trade:
            if df.iloc[i]['monthly_long'] == -1:
                # Supertrend reversed, SL hit
                exit_price = df.iloc[i]['close']
                exit_time = df.iloc[i]['datetime']
                in_trade = False
                points = exit_price - entry_price
                remark = 'SuperTrend Reversed'
                # print(remark, df.iloc[i]['datetime'])

            elif df.iloc[i]['low'] < initial_sl:
                #Initial SL hit
                
                if df.iloc[i]['open'] < initial_sl:
                    #Gapped below Initial SL, exit at open
                    exit_price = df.iloc[i]['open']
                    exit_time = df.iloc[i]['datetime']
                    remark = 'Gapped Outside Initial SL'
                    # print(remark, df.iloc[i]['datetime'])

                else:
                    exit_price = initial_sl
                    exit_time = df.iloc[i]['datetime']
                    remark = 'Initial SL Hit'
                    print(remark, df.iloc[i]['datetime'])
                    
                in_trade = False
                points = exit_price - entry_price

            elif df.iloc[i]['high'] > initial_target:
                # Target Hit
                exit_price = initial_target
                exit_time = df.iloc[i]['datetime']
                in_trade = False
                points = exit_price - entry_price
                remark = 'Target Hit'
                # print(remark, df.iloc[i]['datetime'])

            elif df.iloc[i]['indexer'] == df.iloc[-1]['indexer']:
                # Ending Currently Active Trade
                exit_price = df.iloc[i]['close']
                exit_time = df.iloc[i]['datetime']
                in_trade = False
                points = exit_price - entry_price
                remark = 'Currently Active Trade'
                # print(remark, df.iloc[i]['datetime'])

        if points:
            # Calculate PnL for the whole trade duration
            qty = portfolio_value / entry_price
            slippage = 0.001 * (entry_price + exit_price)
            # final_points = points - slippage
            
            trade_duration = (exit_time - entry_time)

            st_index = df.loc[df['datetime'] == entry_time, 'indexer'].iloc[0]
            en_index = df.loc[df['datetime'] == exit_time, 'indexer'].iloc[0]
            current_index = df.loc[df['datetime'] == entry_time, 'indexer'].iloc[0]
            st_index += 1
            while current_index < en_index:
                trade = {
                    'Stock Name': stock_name,
                    'Trade Type': 'LONG',
                    'Entry Date': df.iloc[current_index]['datetime'],
                    'Entry Price': df.iloc[current_index]['close'],
                    'Exit Date': df.iloc[st_index]['datetime'],
                    'Exit Price': df.iloc[st_index]['close'],
                    'Points Captured': df.iloc[st_index]['close'] - df.iloc[current_index]['close'],
                    'Qty': qty,
                    'PnL': (df.loc[st_index]['close'] - df.iloc[current_index]['close']) * qty,
                    'ROI%': ((df.loc[st_index]['close'] - df.iloc[current_index]['close']) * qty / portfolio_value) * 100,
                    'Pct Change on Stock': ((df.loc[st_index]['close'] - df.iloc[current_index]['close']) / df.loc[current_index]['close']) * 100,
                    'Trade Year': entry_time.year,
                    'Trade Number': f'{trade_number}L',
                }
                # print(trade)
                current_index += 1
                st_index += 1
    
                tradebook.append(trade)
            trade_number += 1
                
            entry_price = 0
            exit_price = 0
            points = 0
            remark = ''
            in_trade = False

    return pd.DataFrame(tradebook)

# %%
from datetime import timedelta

def trade_next_open_monthly_short(stock_name, df):
    in_trade = False
    entry_price = 0
    exit_price = 0
    signal_candle_high = 0
    points = 0
    remark = ''
    initial_sl_pct = 100
    target_pct = 1500
    portfolio_value = 10_00_000
    trade_number = 1

    tradebook = []
    
    for i in range(0, len(df)):
        
        if (df.iloc[i]['monthly_long'] == -1) and not in_trade:
            #Entry Triggered
            in_trade = True
            entry_price = df.iloc[i]['close']
            entry_time = df.iloc[i]['datetime']
            initial_sl = entry_price * (1 + (initial_sl_pct / 100))
            initial_target = entry_price * (1 - (target_pct / 100))
    
            # print('Entry Triggered ! ', df.iloc[i]['datetime'])

            continue

            #TODO : Try using the nearer SL between low of entry candle and initial_sl fixed for Initial SL of the trade
            # ----> initial_sl = max( df.iloc[i]['low'] , entry_price * (1 - (initial_sl_pct / 100)) )
            
        if in_trade:
            if df.iloc[i]['monthly_long'] == 1:
                # Supertrend reversed, SL hit
                exit_price = df.iloc[i]['close']
                exit_time = df.iloc[i]['datetime']
                in_trade = False
                points = entry_price - exit_price
                remark = 'SuperTrend Reversed'
                # print(remark, df.iloc[i]['datetime'])

            elif df.iloc[i]['high'] > initial_sl:
                #Initial SL hit
                
                if df.iloc[i]['open'] > initial_sl:
                    #Gapped above Initial SL, exit at open
                    exit_price = df.iloc[i]['open']
                    exit_time = df.iloc[i]['datetime']
                    remark = 'Gapped Outside Initial SL'
                    # print(remark, df.iloc[i]['datetime'])

                else:
                    exit_price = initial_sl
                    exit_time = df.iloc[i]['datetime']
                    remark = 'Initial SL Hit'
                    print(remark, df.iloc[i]['datetime'])
                    
                in_trade = False
                points = entry_price - exit_price

            elif df.iloc[i]['low'] < initial_target:
                # Target Hit
                exit_price = initial_target
                exit_time = df.iloc[i]['datetime']
                in_trade = False
                points = entry_price - exit_price
                remark = 'Target Hit'
                # print(remark, df.iloc[i]['datetime'])

            elif df.iloc[i]['indexer'] == df.iloc[-1]['indexer']:
                # Ending Currently Active Trade
                exit_price = df.iloc[i]['close']
                exit_time = df.iloc[i]['datetime']
                in_trade = False
                points = entry_price - exit_price
                remark = 'Currently Active Trade'
                # print(remark, df.iloc[i]['datetime'])

        if points:
            # Calculate PnL for the whole trade duration
            qty = portfolio_value / entry_price
            slippage = 0.001 * (entry_price + exit_price)
            # final_points = points - slippage
            
            trade_duration = (exit_time - entry_time)

            st_index = df.loc[df['datetime'] == entry_time, 'indexer'].iloc[0]
            en_index = df.loc[df['datetime'] == exit_time, 'indexer'].iloc[0]
            current_index = df.loc[df['datetime'] == entry_time, 'indexer'].iloc[0]
            st_index += 1
            while current_index < en_index:
                trade = {
                    'Stock Name': stock_name,
                    'Trade Type': 'SHORT',
                    'Entry Date': df.iloc[current_index]['datetime'],
                    'Entry Price': df.iloc[current_index]['close'],
                    'Exit Date': df.iloc[st_index]['datetime'],
                    'Exit Price': df.iloc[st_index]['close'],
                    'Points Captured': df.iloc[current_index]['close'] - df.iloc[st_index]['close'],
                    'Qty': qty,
                    'PnL': (df.loc[st_index]['close'] - df.iloc[current_index]['close']) * qty,
                    'ROI%': ((df.loc[st_index]['close'] - df.iloc[current_index]['close']) * qty / portfolio_value) * 100,
                    'Pct Change on Stock': ((df.loc[st_index]['close'] - df.iloc[current_index]['close']) / df.loc[current_index]['close']) * 100,
                    'Trade Year': entry_time.year,
                    'Trade Number': f'{trade_number}S',
                }
                # print(trade)
                current_index += 1
                st_index += 1
    
                tradebook.append(trade)
            trade_number += 1
                
            entry_price = 0
            exit_price = 0
            points = 0
            remark = ''
            in_trade = False

    return pd.DataFrame(tradebook)

# %%
tb_per_month_long = trade_next_open_monthly_long(current_stock, df)
tb_per_month_short = trade_next_open_monthly_short(current_stock, df)
final_tb = pd.concat([tb_per_month_long, tb_per_month_short], ignore_index=True)
final_tb = final_tb.sort_values(by='Entry Date')
tb_pandas_per_month = pd.DataFrame(final_tb)
tb_pandas_per_month
# Out:
#        Stock Name Trade Type Entry Date  Entry Price  Exit Date  Exit Price  \
# 0    BERGER PAINT       LONG 2015-01-01   136.279571 2015-02-02  133.303385
# 1    BERGER PAINT       LONG 2015-02-02   133.303385 2015-03-02  124.196249
# 2    BERGER PAINT       LONG 2015-03-02   124.196249 2015-04-01  125.386723
# 3    BERGER PAINT       LONG 2015-04-01   125.386723 2015-05-04  126.577198
# 4    BERGER PAINT       LONG 2015-05-04   126.577198 2015-06-01  116.279605
# 62   BERGER PAINT      SHORT 2015-06-01   116.279605 2015-07-01  129.702193
# 63   BERGER PAINT      SHORT 2015-07-01   129.702193 2015-08-03  126.487918
# 64   BERGER PAINT      SHORT 2015-08-03   126.487918 2015-09-01  130.743859
# 5    BERGER PAINT       LONG 2015-09-01   130.743859 2015-10-01  131.964101
# 6    BERGER PAINT       LONG 2015-10-01   131.964101 2015-11-02  131.011727
# 7    BERGER PAINT       LONG 2015-11-02   131.011727 2015-12-01  160.029544
# 8    BERGER PAINT       LONG 2015-12-01   160.029544 2016-01-01  158.600974
# 9    BERGER PAINT       LONG 2016-01-01   158.600974 2016-02-01  133.511718
# 65   BERGER PAINT      SHORT 2016-02-01   133.511718 2016-03-01  145.714082
# 66   BERGER PAINT      SHORT 2016-03-01   145.714082 2016-04-01  153.273595
# 67   BERGER PAINT      SHORT 2016-04-01   153.273595 2016-05-02  168.333092
# 10   BERGER PAINT       LONG 2016-05-02   168.333092 2016-06-01  164.404538
# 11   BERGER PAINT       LONG 2016-06-01   164.404538 2016-07-01  198.208262
# 12   BERGER PAINT       LONG 2016-07-01   198.208262 2016-08-01  216.958255
# 31              6.102393        2017           4L
# 32            -12.443985        2017           4L
# 73             -4.487289        2018           4S
# 74             14.255092        2018           4S
# 33              3.283302        2018           5L
# 34             -3.496818        2018           5L
# 35             -4.329409        2018           5L
# 36              6.164942        2018           5L
# 37             -1.482622        2018           5L
# 38              3.558545        2018           5L
# 39             -3.875262        2018           5L
# 40              4.188973        2018           5L
# 41             11.593108        2018           5L
# 42             17.784099        2018           5L
# 43             21.193657        2018           5L
# 44             -5.769052        2018           5L
# 45              3.826402        2018           5L
# 46              8.650961        2018           5L
# 47              1.142546        2018           5L
# 48            -12.108372        2018           5L
# 75              2.098600        2020           5S
# 76             -3.274978        2020           5S
# 77              0.437212        2020           5S
# 78              6.600529        2020           5S
# 79              2.127257        2020           5S
# 80              8.554956        2020           5S
# 49              6.741473        2020           6L
# 50              3.964371        2020           6L
# 51             17.244309        2020           6L
# 52             -6.926069        2020           6L
# 53             -3.819764        2020           6L
# 81             12.524825        2021           6S
# 82             -7.973856        2021           6S
# 83             14.424714        2021           6S
# 84             -0.055864        2021           6S
# 85              4.775806        2021           6S
# 54             -2.696936        2021           7L
# 55             -1.437621        2021           7L
# 56             -8.343634        2021           7L
# 86              1.382333        2021           7S
# 87              2.660459        2021           7S
# 88             -6.394555        2021           7S
# 89             -4.422759        2021           7S
# 90              1.339706        2021           7S
# 91              2.608261        2021           7S
# 92            -14.353366        2021           7S
# 93             -7.578473        2021           7S
# 94              9.924339        2021           7S
# 95              7.843765        2021           7S
# 96             -8.416210        2021           7S
# 97             -5.056728        2021           7S
# 98              6.247871        2021           7S
# 99             -6.595443        2021           7S
# 100            -5.538825        2021           7S
# 101             5.544926        2021           7S
# 102             0.362324        2021           7S
# 103             4.925214        2021           7S
# 104             6.570006        2021           7S
# 57              4.250899        2023           8L
# 58              0.634131        2023           8L
# 59              5.304801        2023           8L
# 60             -5.006921        2023           8L
# 61             -1.801881        2023           8L
# 105             2.828507        2023           8S
# 106             5.266365        2023           8S
# 107            -6.532705        2023           8S
# 108             7.352028        2023           8S
# 109            -5.546402        2023           8S
# 110           -11.255563        2023           8S
# 111            -3.283842        2023           8S

# %%
def stats(stock_name, df):
    print(stock_name)
    stats = pd.DataFrame(index=range(2012, 2025), columns=['Total ROI', 'Total Trades', 'Win Rate', 'Avg Profit% per Trade', 'Avg Loss% per Trade', 'Max Drawdown', 'ROI/DD Ratio'])
    
    # Iterate over each year
    for year in range(2012, 2025):
        # Filter trades for the current year
        year_trades = df[(df['Trade Year'] == year)]
        
        # Calculate total ROI
        total_roi = year_trades['ROI%'].sum()
        
        # Calculate total number of trades
        total_trades = len(year_trades)
        
        # Calculate win rate
        win_rate = (year_trades['ROI%'] > 0).mean()*100
        
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades['ROI%'] > 0]['ROI%'].mean()
        
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades['ROI%'] < 0]['ROI%'].mean()
        
        # Calculate maximum drawdown
        max_drawdown = (year_trades['ROI%'].cumsum() - year_trades['ROI%'].cumsum().cummax()).min()
        
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)
        
        # Store the statistics in the DataFrame
        stats.loc[year] = [total_roi, total_trades, win_rate, avg_profit, avg_loss, max_drawdown, roi_dd_ratio]
    
    # Calculate overall statistics
    overall_total_roi = stats['Total ROI'].sum()
    overall_total_trades = stats['Total Trades'].sum()
    overall_win_rate = (df['ROI%'] > 0).mean() * 100
    overall_avg_profit = df[df['ROI%'] > 0]['ROI%'].mean()
    overall_avg_loss = df[df['ROI%'] < 0]['ROI%'].mean()
    overall_max_drawdown = (df['ROI%'].cumsum() - df['ROI%'].cumsum().cummax()).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    
    # Store the overall statistics in the DataFrame
    stats.loc['Overall'] = [overall_total_roi, overall_total_trades, overall_win_rate, overall_avg_profit, overall_avg_loss, overall_max_drawdown, overall_roi_dd_ratio]
    return stats

results = stats(current_stock, tb_pandas_per_month)
results
# Out:
# BERGER PAINT
#           Total ROI Total Trades   Win Rate Avg Profit% per Trade  \
# 2012            0.0            0        NaN                   NaN
# 2013            0.0            0        NaN                   NaN
# 2014            0.0            0        NaN                   NaN
# 2015      -0.119479           13  46.153846              6.679713
# 2016      53.531078           14  71.428571              7.980199
# 2017      12.172245           17  47.058824              6.741627
# 2018      64.834835           18  61.111111             10.337203
# 2019            0.0            0        NaN                   NaN
# 2020      33.693102           11  72.727273              6.334245
# 2021      -0.298001           27  51.851852              5.265553
# 2022            0.0            0        NaN                   NaN
# 2023      -8.894668           12       50.0              4.359904
# 2024            0.0            0        NaN                   NaN
# Overall  154.919113        112.0      56.25               6.95355
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio
# 2012                    NaN          NaN          NaN
# 2013                    NaN          NaN          NaN
# 2014                    NaN          NaN          NaN
# 2015              -5.742537   -20.282273    -0.005891
# 2016              -6.567727   -23.937109     2.236322
# 2017              -4.640086   -15.942591     0.763505
# 2018              -6.982056   -21.450901     3.022476
# 2019                    NaN          NaN          NaN
# 2020              -5.660285   -13.637147     2.470685
# 2021              -5.693519   -38.038339    -0.007834
# 2022                    NaN          NaN          NaN
# 2023              -5.842349    -20.56033    -0.432613
# 2024                    NaN          NaN          NaN
# Overall           -5.778664   -38.038339      4.07271

# %%
tradebook_name_2 = f'{current_stock}_nxt50_tb_ls_stonks.csv'
tb_pandas_per_month.to_csv(tradebook_name_2)

# %%
tb_pandas_per_month
# Out:
#        Stock Name Trade Type Entry Date  Entry Price  Exit Date  Exit Price  \
# 0    BERGER PAINT       LONG 2015-01-01   136.279571 2015-02-02  133.303385
# 1    BERGER PAINT       LONG 2015-02-02   133.303385 2015-03-02  124.196249
# 2    BERGER PAINT       LONG 2015-03-02   124.196249 2015-04-01  125.386723
# 3    BERGER PAINT       LONG 2015-04-01   125.386723 2015-05-04  126.577198
# 4    BERGER PAINT       LONG 2015-05-04   126.577198 2015-06-01  116.279605
# 62   BERGER PAINT      SHORT 2015-06-01   116.279605 2015-07-01  129.702193
# 63   BERGER PAINT      SHORT 2015-07-01   129.702193 2015-08-03  126.487918
# 64   BERGER PAINT      SHORT 2015-08-03   126.487918 2015-09-01  130.743859
