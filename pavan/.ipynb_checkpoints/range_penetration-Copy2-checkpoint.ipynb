# %%
import asyncio
import datetime as dt
import math
from typing import Literal

import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

# %%
import sys

sys.path.append("..")
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
async def get_expiry(f_today, index):

    if index == 'bnf':    
        if (f_today <= dt.date(2024, 1, 25)) and (f_today >= dt.date(2024, 1, 18)):
            f_expiry = dt.date(2024, 1, 25)
        elif (f_today <= dt.date(2024, 1, 31)) and (f_today >= dt.date(2024, 1, 26)):
            f_expiry = dt.date(2024, 1, 31)
        elif (f_today <= dt.date(2024, 2, 22)) and (f_today >= dt.date(2024, 2, 29)):
            f_expiry = dt.date(2024, 2, 29)
        elif (f_today <= dt.date(2024, 3, 25)) and (f_today >= dt.date(2024, 3, 27)):
            f_expiry = dt.date(2024, 2, 27)
        elif f_today < dt.date(2023, 9, 1):
            days_to_thursday = (3 - f_today.weekday()) % 7
            nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
            f_expiry = nearest_thursday
            if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
                f_expiry = nearest_thursday - dt.timedelta(days=1)
        elif f_today >= dt.date(2023, 9, 1):
            if f_today.day < 24:
                days_to_wednesday = (2 - f_today.weekday()) % 7
                nearest_wednesday = f_today + dt.timedelta(days=days_to_wednesday)
                f_expiry = nearest_wednesday
                if nse.valid_days(
                    start_date=nearest_wednesday, end_date=nearest_wednesday
                ).empty:
                    f_expiry = nearest_wednesday - dt.timedelta(days=1)
            else:
                days_to_thursday = (3 - f_today.weekday()) % 7
                nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
                f_expiry = nearest_thursday
                if nse.valid_days(
                    start_date=nearest_thursday, end_date=nearest_thursday
                ).empty:
                    f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'nifty':
        days_to_thursday = (3 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'finnifty' or index == 'fnf':
        days_to_thursday = (1 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'midcpnifty' or index == 'midcp':
        days_to_thursday = (0 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

async def get_expiry_nifty(f_today):

    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry


async def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"


def get_option_contract_name2(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"

# %%
bnf_1min = pd.read_csv("../data/gold_tv_4h.csv")
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["time"])
bnf_1min = bnf_1min[bnf_1min["datetime"].dt.year >= 2012]

# %%
bnf_1min.head()
# Out:
#                         time   open   high    low  close  MA  Shapes  \
# 0  2015-03-02T09:00:00+05:30  26600  26769  26600  26700 NaN       0
# 1  2015-03-02T13:00:00+05:30  26709  26730  26653  26680 NaN       0
# 2  2015-03-02T17:00:00+05:30  26684  26742  26576  26619 NaN       0
# 3  2015-03-02T21:00:00+05:30  26623  26624  26500  26506 NaN       0
# 4  2015-03-03T09:00:00+05:30  26500  26525  26444  26463 NaN       0
#
#    Shapes.1  RSI                  datetime
# 0         0  NaN 2015-03-02 09:00:00+05:30
# 1         0  NaN 2015-03-02 13:00:00+05:30
# 2         0  NaN 2015-03-02 17:00:00+05:30
# 3         0  NaN 2015-03-02 21:00:00+05:30
# 4         0  NaN 2015-03-03 09:00:00+05:30

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("open").first().alias("open"),
                pl.col("high").max().alias("high"),
                pl.col("low").min().alias("low"),
                pl.col("close").last().alias("close"),
                pl.col("volume").sum().alias("volume"),
            ]
        )
    )


# ohlc_resampled = resample(pl.DataFrame(bnf_1min), '7d', pd.Timedelta(days=4))
# ohlc_resampled

# %%
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["datetime"])
list_of_traded_dates = set(bnf_1min["datetime"].dt.date)
list_of_traded_dates
# Out:
# {datetime.date(2015, 8, 20),
#  datetime.date(2023, 7, 26),
#  datetime.date(2018, 1, 15),
#  datetime.date(2016, 6, 30),
#  datetime.date(2018, 5, 21),
#  datetime.date(2022, 4, 25),
#  datetime.date(2018, 2, 7),
#  datetime.date(2017, 2, 9),
#  datetime.date(2023, 10, 26),
#  datetime.date(2024, 9, 5),
#  datetime.date(2016, 5, 31),
#  datetime.date(2019, 1, 25),
#  datetime.date(2017, 6, 14),
#  datetime.date(2019, 1, 1),
#  datetime.date(2019, 8, 8),
#  datetime.date(2017, 1, 17),
#  datetime.date(2019, 11, 26),
#  datetime.date(2022, 11, 8),
#  datetime.date(2021, 12, 30),
#  datetime.date(2022, 3, 31),
#  datetime.date(2019, 10, 3),
#  datetime.date(2016, 10, 19),
#  datetime.date(2022, 3, 28),
#  datetime.date(2022, 5, 24),
#  datetime.date(2015, 6, 15),
#  datetime.date(2017, 2, 10),
#  datetime.date(2023, 6, 20),
#  datetime.date(2022, 5, 3),
#  datetime.date(2018, 1, 12),
#  datetime.date(2018, 4, 16),
#  datetime.date(2016, 8, 12),
#  datetime.date(2023, 3, 28),
#  datetime.date(2015, 3, 6),
#  datetime.date(2017, 2, 15),
#  datetime.date(2018, 7, 20),
#  datetime.date(2016, 4, 4),
#  datetime.date(2020, 4, 21),
#  datetime.date(2020, 2, 28),
#  datetime.date(2022, 8, 3),
#  datetime.date(2016, 9, 28),
#  datetime.date(2019, 6, 4),
#  datetime.date(2017, 11, 23),
#  datetime.date(2017, 7, 25),
#  datetime.date(2018, 8, 29),
#  datetime.date(2023, 3, 29),
#  datetime.date(2021, 9, 3),
#  datetime.date(2021, 2, 15),
#  datetime.date(2024, 3, 15),
#  datetime.date(2015, 10, 12),
#  datetime.date(2019, 1, 21),
#  datetime.date(2023, 1, 25),
#  datetime.date(2024, 3, 19),
#  datetime.date(2016, 9, 16),
#  datetime.date(2024, 4, 11),
#  datetime.date(2017, 7, 11),
#  datetime.date(2017, 8, 21),
#  datetime.date(2024, 7, 12),
#  datetime.date(2018, 3, 20),
#  datetime.date(2019, 9, 4),
#  datetime.date(2016, 2, 4),
#  datetime.date(2019, 5, 13),
#  datetime.date(2015, 11, 27),
#  datetime.date(2016, 2, 12),
#  datetime.date(2022, 7, 11),
#  datetime.date(2021, 5, 24),
#  datetime.date(2015, 12, 7),
#  datetime.date(2020, 8, 25),
#  datetime.date(2024, 2, 12),
#  datetime.date(2019, 3, 27),
#  datetime.date(2019, 7, 11),
#  datetime.date(2022, 9, 9),
#  datetime.date(2021, 11, 2),
#  datetime.date(2015, 4, 8),
#  datetime.date(2016, 6, 17),
#  datetime.date(2018, 5, 14),
#  datetime.date(2020, 1, 16),
#  datetime.date(2016, 8, 5),
#  datetime.date(2017, 1, 5),
#  datetime.date(2020, 7, 20),
#  datetime.date(2020, 10, 29),
#  datetime.date(2020, 8, 17),
#  datetime.date(2019, 6, 25),
#  datetime.date(2024, 6, 19),
#  datetime.date(2015, 5, 7),
#  datetime.date(2022, 12, 13),
#  datetime.date(2019, 2, 6),
#  datetime.date(2017, 1, 31),
#  datetime.date(2015, 5, 18),
#  datetime.date(2022, 8, 17),
#  datetime.date(2024, 1, 1),
#  datetime.date(2019, 6, 27),
#  datetime.date(2018, 7, 11),
#  datetime.date(2023, 3, 22),
#  datetime.date(2021, 9, 9),
#  datetime.date(2021, 8, 19),
#  datetime.date(2015, 7, 29),
#  datetime.date(2016, 10, 26),
#  datetime.date(2016, 6, 20),
#  datetime.date(2023, 11, 12),
#  datetime.date(2017, 10, 25),
#  datetime.date(2020, 8, 12),
#  datetime.date(2018, 8, 27),
#  datetime.date(2021, 8, 2),
#  datetime.date(2019, 2, 18),
#  datetime.date(2020, 3, 30),
#  datetime.date(2021, 8, 3),
#  datetime.date(2020, 6, 25),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 11, 16),
#  datetime.date(2020, 4, 3),
#  datetime.date(2024, 7, 10),
#  datetime.date(2020, 1, 7),
#  datetime.date(2022, 2, 14),
#  datetime.date(2016, 8, 16),
#  datetime.date(2020, 11, 11),
#  datetime.date(2017, 5, 10),
#  datetime.date(2020, 3, 23),
#  datetime.date(2022, 8, 25),
#  datetime.date(2015, 4, 9),
#  datetime.date(2021, 9, 6),
#  datetime.date(2024, 7, 18),
#  datetime.date(2023, 4, 12),
#  datetime.date(2024, 3, 5),
#  datetime.date(2016, 4, 1),
#  datetime.date(2021, 1, 1),
#  datetime.date(2016, 3, 28),
#  datetime.date(2018, 7, 17),
#  datetime.date(2024, 7, 30),
#  datetime.date(2015, 8, 12),
#  datetime.date(2020, 3, 18),
#  datetime.date(2020, 4, 22),
#  datetime.date(2015, 9, 25),
#  datetime.date(2019, 2, 19),
#  datetime.date(2024, 3, 7),
#  datetime.date(2024, 5, 8),
#  datetime.date(2021, 3, 29),
#  datetime.date(2017, 7, 28),
#  datetime.date(2022, 6, 2),
#  datetime.date(2023, 10, 4),
#  datetime.date(2021, 12, 27),
#  datetime.date(2015, 6, 9),
#  datetime.date(2020, 3, 31),
#  datetime.date(2017, 6, 12),
#  datetime.date(2019, 12, 9),
#  datetime.date(2022, 12, 14),
#  datetime.date(2022, 10, 26),
#  datetime.date(2015, 12, 10),
#  datetime.date(2018, 2, 9),
#  datetime.date(2018, 7, 31),
#  datetime.date(2017, 7, 18),
#  datetime.date(2018, 6, 8),
#  datetime.date(2022, 1, 21),
#  datetime.date(2022, 2, 25),
#  datetime.date(2018, 3, 14),
#  datetime.date(2023, 9, 1),
#  datetime.date(2016, 10, 25),
#  datetime.date(2024, 1, 25),
#  datetime.date(2019, 6, 13),
#  datetime.date(2016, 7, 11),
#  datetime.date(2017, 6, 9),
#  datetime.date(2017, 8, 18),
#  datetime.date(2023, 8, 31),
#  datetime.date(2018, 6, 25),
#  datetime.date(2019, 12, 13),
#  datetime.date(2023, 12, 27),
#  datetime.date(2018, 2, 28),
#  datetime.date(2018, 1, 9),
#  datetime.date(2020, 2, 4),
#  datetime.date(2019, 7, 30),
#  datetime.date(2020, 9, 18),
#  datetime.date(2023, 4, 5),
#  datetime.date(2021, 5, 5),
#  datetime.date(2024, 5, 24),
#  datetime.date(2023, 2, 2),
#  datetime.date(2016, 8, 3),
#  datetime.date(2021, 2, 11),
#  datetime.date(2019, 10, 11),
#  datetime.date(2024, 2, 1),
#  datetime.date(2018, 4, 4),
#  datetime.date(2023, 6, 26),
#  datetime.date(2019, 8, 22),
#  datetime.date(2020, 11, 24),
#  datetime.date(2016, 2, 25),
#  datetime.date(2015, 5, 22),
#  datetime.date(2024, 7, 15),
#  datetime.date(2018, 6, 20),
#  datetime.date(2019, 9, 24),
#  datetime.date(2021, 1, 20),
#  datetime.date(2021, 2, 24),
#  datetime.date(2016, 7, 20),
#  datetime.date(2021, 4, 1),
#  datetime.date(2021, 5, 10),
#  datetime.date(2020, 10, 15),
#  datetime.date(2022, 1, 6),
#  datetime.date(2019, 1, 30),
#  datetime.date(2017, 4, 21),
#  datetime.date(2019, 6, 11),
#  datetime.date(2017, 1, 16),
#  datetime.date(2016, 6, 3),
#  datetime.date(2020, 6, 30),
#  datetime.date(2016, 2, 24),
#  datetime.date(2016, 7, 15),
#  datetime.date(2024, 2, 13),
#  datetime.date(2016, 5, 17),
#  datetime.date(2020, 7, 2),
#  datetime.date(2023, 1, 12),
#  datetime.date(2016, 7, 1),
#  datetime.date(2016, 4, 6),
#  datetime.date(2022, 7, 22),
#  datetime.date(2024, 5, 2),
#  datetime.date(2020, 9, 24),
#  datetime.date(2017, 9, 14),
#  datetime.date(2019, 2, 12),
#  datetime.date(2017, 5, 30),
#  datetime.date(2018, 5, 28),
#  datetime.date(2022, 4, 26),
#  datetime.date(2017, 1, 30),
#  datetime.date(2016, 5, 6),
#  datetime.date(2018, 4, 26),
#  datetime.date(2022, 3, 16),
#  datetime.date(2021, 8, 11),
#  datetime.date(2017, 4, 17),
#  datetime.date(2019, 2, 13),
#  datetime.date(2020, 6, 15),
#  datetime.date(2019, 6, 5),
#  datetime.date(2021, 3, 12),
#  datetime.date(2020, 7, 24),
#  datetime.date(2022, 11, 4),
#  datetime.date(2017, 6, 22),
#  datetime.date(2020, 8, 21),
#  datetime.date(2016, 4, 28),
#  datetime.date(2020, 11, 27),
#  datetime.date(2022, 10, 31),
#  datetime.date(2023, 7, 25),
#  datetime.date(2020, 1, 14),
#  datetime.date(2021, 11, 18),
#  datetime.date(2023, 5, 11),
#  datetime.date(2023, 5, 29),
#  datetime.date(2019, 10, 17),
#  datetime.date(2019, 9, 19),
#  datetime.date(2021, 11, 11),
#  datetime.date(2015, 12, 31),
#  datetime.date(2023, 11, 13),
#  datetime.date(2019, 8, 7),
#  datetime.date(2019, 8, 12),
#  datetime.date(2017, 10, 11),
#  datetime.date(2015, 12, 30),
#  datetime.date(2022, 9, 22),
#  datetime.date(2015, 10, 5),
#  datetime.date(2020, 2, 24),
#  datetime.date(2023, 5, 15),
#  datetime.date(2015, 4, 14),
#  datetime.date(2020, 1, 15),
#  datetime.date(2024, 8, 23),
#  datetime.date(2019, 6, 20),
#  datetime.date(2021, 11, 4),
#  datetime.date(2020, 9, 17),
#  datetime.date(2020, 9, 8),
#  datetime.date(2022, 10, 27),
#  datetime.date(2019, 2, 8),
#  datetime.date(2018, 2, 23),
#  datetime.date(2019, 6, 7),
#  datetime.date(2016, 3, 29),
#  datetime.date(2023, 11, 2),
#  datetime.date(2023, 9, 28),
#  datetime.date(2022, 11, 17),
#  datetime.date(2022, 12, 1),
#  datetime.date(2022, 12, 16),
#  datetime.date(2020, 7, 29),
#  datetime.date(2018, 10, 12),
#  datetime.date(2017, 6, 13),
#  datetime.date(2018, 9, 20),
#  datetime.date(2023, 3, 6),
#  datetime.date(2018, 9, 3),
#  datetime.date(2024, 4, 10),
#  datetime.date(2023, 7, 4),
#  datetime.date(2017, 7, 10),
#  datetime.date(2016, 1, 15),
#  datetime.date(2024, 6, 20),
#  datetime.date(2016, 11, 24),
#  datetime.date(2022, 9, 20),
#  datetime.date(2016, 12, 30),
#  datetime.date(2021, 3, 18),
#  datetime.date(2017, 9, 7),
#  datetime.date(2024, 8, 20),
#  datetime.date(2015, 4, 23),
#  datetime.date(2018, 10, 5),
#  datetime.date(2018, 12, 20),
#  datetime.date(2020, 2, 13),
#  datetime.date(2018, 5, 17),
#  datetime.date(2017, 10, 10),
#  datetime.date(2021, 1, 21),
#  datetime.date(2022, 6, 15),
#  datetime.date(2024, 7, 2),
#  datetime.date(2016, 8, 24),
#  datetime.date(2019, 5, 9),
#  datetime.date(2021, 2, 4),
#  datetime.date(2018, 7, 6),
#  datetime.date(2022, 5, 16),
#  datetime.date(2023, 8, 30),
#  datetime.date(2015, 10, 27),
#  datetime.date(2015, 10, 8),
#  datetime.date(2020, 12, 21),
#  datetime.date(2016, 6, 24),
#  datetime.date(2016, 4, 12),
#  datetime.date(2021, 5, 3),
#  datetime.date(2020, 1, 31),
#  datetime.date(2018, 10, 8),
#  datetime.date(2019, 2, 7),
#  datetime.date(2020, 3, 24),
#  datetime.date(2020, 9, 9),
#  datetime.date(2018, 4, 13),
#  datetime.date(2021, 10, 20),
#  datetime.date(2015, 3, 9),
#  datetime.date(2016, 10, 3),
#  datetime.date(2015, 7, 9),
#  datetime.date(2022, 1, 25),
#  datetime.date(2023, 6, 15),
#  datetime.date(2017, 2, 27),
#  datetime.date(2016, 3, 24),
#  datetime.date(2016, 4, 21),
#  datetime.date(2022, 1, 17),
#  datetime.date(2019, 4, 2),
#  datetime.date(2021, 9, 24),
#  datetime.date(2024, 1, 10),
#  datetime.date(2023, 7, 5),
#  datetime.date(2019, 7, 25),
#  datetime.date(2024, 8, 28),
#  datetime.date(2024, 3, 18),
#  datetime.date(2020, 12, 8),
#  datetime.date(2020, 11, 13),
#  datetime.date(2024, 3, 13),
#  datetime.date(2023, 4, 14),
#  datetime.date(2015, 5, 29),
#  datetime.date(2018, 8, 28),
#  datetime.date(2022, 8, 2),
#  datetime.date(2015, 8, 3),
#  datetime.date(2015, 10, 6),
#  datetime.date(2015, 6, 2),
#  datetime.date(2015, 8, 28),
#  datetime.date(2017, 8, 9),
#  datetime.date(2018, 7, 13),
#  datetime.date(2019, 5, 30),
#  datetime.date(2020, 12, 9),
#  datetime.date(2015, 3, 30),
#  datetime.date(2023, 7, 17),
#  datetime.date(2016, 8, 23),
#  datetime.date(2017, 8, 24),
#  datetime.date(2020, 5, 25),
#  datetime.date(2023, 10, 25),
#  datetime.date(2019, 4, 22),
#  datetime.date(2019, 11, 21),
#  datetime.date(2018, 3, 26),
#  datetime.date(2018, 10, 22),
#  datetime.date(2019, 1, 18),
#  datetime.date(2021, 7, 20),
#  datetime.date(2022, 9, 16),
#  datetime.date(2023, 1, 20),
#  datetime.date(2018, 2, 20),
#  datetime.date(2017, 10, 31),
#  datetime.date(2023, 5, 17),
#  datetime.date(2018, 2, 12),
#  datetime.date(2016, 11, 17),
#  datetime.date(2023, 3, 13),
#  datetime.date(2020, 6, 11),
#  datetime.date(2020, 1, 8),
#  datetime.date(2022, 4, 8),
#  datetime.date(2022, 8, 24),
#  datetime.date(2024, 10, 9),
#  datetime.date(2023, 5, 5),
#  datetime.date(2024, 5, 15),
#  datetime.date(2020, 9, 7),
#  datetime.date(2021, 7, 19),
#  datetime.date(2021, 10, 29),
#  datetime.date(2015, 4, 28),
#  datetime.date(2018, 11, 13),
#  datetime.date(2021, 12, 8),
#  datetime.date(2017, 12, 27),
#  datetime.date(2016, 9, 19),
#  datetime.date(2017, 10, 3),
#  datetime.date(2020, 4, 13),
#  datetime.date(2015, 3, 16),
#  datetime.date(2020, 10, 13),
#  datetime.date(2015, 9, 29),
#  datetime.date(2016, 7, 5),
#  datetime.date(2023, 10, 6),
#  datetime.date(2019, 6, 6),
#  datetime.date(2023, 8, 29),
#  datetime.date(2023, 9, 12),
#  datetime.date(2022, 10, 20),
#  datetime.date(2015, 12, 17),
#  datetime.date(2016, 3, 4),
#  datetime.date(2018, 3, 27),
#  datetime.date(2018, 2, 21),
#  datetime.date(2016, 11, 15),
#  datetime.date(2023, 1, 30),
#  datetime.date(2022, 9, 19),
#  datetime.date(2023, 2, 15),
#  datetime.date(2020, 7, 16),
#  datetime.date(2017, 3, 21),
#  datetime.date(2021, 2, 12),
#  datetime.date(2017, 12, 4),
#  datetime.date(2020, 12, 18),
#  datetime.date(2020, 12, 24),
#  datetime.date(2022, 5, 18),
#  datetime.date(2015, 3, 18),
#  datetime.date(2015, 3, 25),
#  datetime.date(2018, 9, 21),
#  datetime.date(2021, 2, 9),
#  datetime.date(2017, 7, 12),
#  datetime.date(2016, 10, 21),
#  datetime.date(2016, 12, 26),
#  datetime.date(2018, 2, 19),
#  datetime.date(2020, 9, 2),
#  datetime.date(2019, 8, 27),
#  datetime.date(2022, 5, 31),
#  datetime.date(2021, 11, 25),
#  datetime.date(2022, 1, 7),
#  datetime.date(2017, 9, 18),
#  datetime.date(2020, 8, 26),
#  datetime.date(2023, 9, 22),
#  datetime.date(2019, 4, 18),
#  datetime.date(2017, 10, 6),
#  datetime.date(2021, 6, 4),
#  datetime.date(2020, 6, 5),
#  datetime.date(2018, 9, 27),
#  datetime.date(2023, 5, 19),
#  datetime.date(2020, 6, 26),
#  datetime.date(2019, 12, 17),
#  datetime.date(2018, 1, 2),
#  datetime.date(2021, 4, 9),
#  datetime.date(2021, 9, 27),
#  datetime.date(2023, 5, 25),
#  datetime.date(2015, 11, 23),
#  datetime.date(2024, 8, 30),
#  datetime.date(2018, 12, 14),
#  datetime.date(2023, 11, 22),
#  datetime.date(2023, 4, 25),
#  datetime.date(2015, 6, 25),
#  datetime.date(2024, 2, 26),
#  datetime.date(2017, 5, 23),
#  datetime.date(2015, 8, 18),
#  datetime.date(2015, 7, 10),
#  datetime.date(2020, 1, 3),
#  datetime.date(2021, 6, 1),
#  datetime.date(2023, 2, 10),
#  datetime.date(2023, 3, 7),
#  datetime.date(2016, 3, 2),
#  datetime.date(2016, 12, 29),
#  datetime.date(2019, 3, 15),
#  datetime.date(2017, 12, 29),
#  datetime.date(2016, 11, 1),
#  datetime.date(2022, 7, 18),
#  datetime.date(2021, 10, 4),
#  datetime.date(2024, 3, 26),
#  datetime.date(2018, 10, 17),
#  datetime.date(2017, 6, 6),
#  datetime.date(2018, 4, 20),
#  datetime.date(2016, 10, 12),
#  datetime.date(2022, 5, 11),
#  datetime.date(2023, 7, 7),
#  datetime.date(2023, 11, 17),
#  datetime.date(2020, 11, 18),
#  datetime.date(2020, 1, 20),
#  datetime.date(2016, 8, 10),
#  datetime.date(2022, 1, 10),
#  datetime.date(2018, 1, 11),
#  datetime.date(2018, 7, 5),
#  datetime.date(2019, 10, 14),
#  datetime.date(2019, 10, 10),
#  datetime.date(2024, 1, 31),
#  datetime.date(2019, 4, 24),
#  datetime.date(2021, 3, 15),
#  datetime.date(2016, 9, 12),
#  datetime.date(2019, 2, 1),
#  datetime.date(2022, 1, 24),
#  datetime.date(2022, 10, 18),
#  datetime.date(2023, 10, 18),
#  datetime.date(2020, 5, 11),
#  datetime.date(2022, 6, 16),
#  datetime.date(2018, 10, 15),
#  datetime.date(2018, 5, 15),
#  datetime.date(2018, 10, 24),
#  datetime.date(2024, 6, 24),
#  datetime.date(2024, 2, 27),
#  datetime.date(2019, 3, 1),
#  datetime.date(2021, 3, 11),
#  datetime.date(2019, 9, 16),
#  datetime.date(2020, 7, 3),
#  datetime.date(2021, 11, 30),
#  datetime.date(2017, 4, 26),
#  datetime.date(2019, 9, 10),
#  datetime.date(2020, 4, 28),
#  datetime.date(2021, 7, 30),
#  datetime.date(2024, 6, 21),
#  datetime.date(2015, 8, 7),
#  datetime.date(2019, 1, 15),
#  datetime.date(2024, 9, 11),
#  datetime.date(2024, 7, 31),
#  datetime.date(2022, 6, 28),
#  datetime.date(2017, 12, 12),
#  datetime.date(2021, 6, 28),
#  datetime.date(2023, 10, 20),
#  datetime.date(2016, 10, 31),
#  datetime.date(2019, 9, 6),
#  datetime.date(2018, 4, 10),
#  datetime.date(2017, 2, 8),
#  datetime.date(2018, 9, 17),
#  datetime.date(2022, 9, 13),
#  datetime.date(2024, 6, 7),
#  datetime.date(2019, 8, 30),
#  datetime.date(2019, 2, 25),
#  datetime.date(2017, 10, 16),
#  datetime.date(2016, 3, 8),
#  datetime.date(2021, 3, 5),
#  datetime.date(2024, 2, 9),
#  datetime.date(2022, 3, 30),
#  datetime.date(2017, 3, 1),
#  datetime.date(2015, 11, 25),
#  datetime.date(2023, 10, 27),
#  datetime.date(2017, 9, 20),
#  datetime.date(2022, 12, 15),
#  datetime.date(2015, 5, 27),
#  datetime.date(2017, 11, 14),
#  datetime.date(2022, 9, 7),
#  datetime.date(2017, 3, 16),
#  datetime.date(2020, 5, 28),
#  datetime.date(2021, 8, 6),
#  datetime.date(2017, 11, 10),
#  datetime.date(2018, 4, 24),
#  datetime.date(2016, 7, 8),
#  datetime.date(2024, 2, 22),
#  datetime.date(2018, 11, 5),
#  datetime.date(2016, 8, 2),
#  datetime.date(2018, 5, 18),
#  datetime.date(2015, 7, 1),
#  datetime.date(2022, 8, 26),
#  datetime.date(2022, 1, 28),
#  datetime.date(2021, 5, 14),
#  datetime.date(2023, 5, 3),
#  datetime.date(2021, 10, 13),
#  datetime.date(2019, 7, 29),
#  datetime.date(2022, 2, 18),
#  datetime.date(2016, 4, 15),
#  datetime.date(2019, 3, 26),
#  datetime.date(2015, 6, 10),
#  datetime.date(2017, 7, 5),
#  datetime.date(2023, 11, 20),
#  datetime.date(2024, 7, 19),
#  datetime.date(2017, 5, 19),
#  datetime.date(2015, 6, 1),
#  datetime.date(2019, 1, 28),
#  datetime.date(2021, 1, 27),
#  datetime.date(2018, 11, 29),
#  datetime.date(2021, 7, 1),
#  datetime.date(2019, 5, 3),
#  datetime.date(2023, 6, 12),
#  datetime.date(2018, 9, 10),
#  datetime.date(2016, 11, 11),
#  datetime.date(2021, 1, 6),
#  datetime.date(2015, 10, 19),
#  datetime.date(2020, 12, 11),
#  datetime.date(2016, 10, 10),
#  datetime.date(2015, 7, 28),
#  datetime.date(2016, 5, 18),
#  datetime.date(2020, 2, 12),
#  datetime.date(2017, 6, 2),
#  datetime.date(2023, 6, 1),
#  datetime.date(2020, 7, 31),
#  datetime.date(2022, 8, 31),
#  datetime.date(2017, 7, 13),
#  datetime.date(2024, 7, 8),
#  datetime.date(2015, 7, 7),
#  datetime.date(2022, 9, 14),
#  datetime.date(2018, 7, 12),
#  datetime.date(2020, 11, 16),
#  datetime.date(2018, 3, 16),
#  datetime.date(2017, 2, 24),
#  datetime.date(2022, 10, 5),
#  datetime.date(2022, 2, 15),
#  datetime.date(2023, 5, 22),
#  datetime.date(2016, 11, 14),
#  datetime.date(2018, 1, 17),
#  datetime.date(2020, 1, 28),
#  datetime.date(2015, 5, 4),
#  datetime.date(2017, 9, 28),
#  datetime.date(2023, 3, 16),
#  datetime.date(2024, 7, 17),
#  datetime.date(2021, 2, 1),
#  datetime.date(2022, 2, 23),
#  datetime.date(2018, 5, 23),
#  datetime.date(2019, 3, 18),
#  datetime.date(2019, 2, 14),
#  datetime.date(2017, 2, 13),
#  datetime.date(2019, 10, 29),
#  datetime.date(2017, 1, 13),
#  datetime.date(2023, 2, 7),
#  datetime.date(2023, 9, 21),
#  datetime.date(2017, 4, 28),
#  datetime.date(2015, 11, 11),
#  datetime.date(2017, 12, 14),
#  datetime.date(2023, 11, 9),
#  datetime.date(2021, 4, 14),
#  datetime.date(2023, 9, 11),
#  datetime.date(2018, 6, 6),
#  datetime.date(2022, 10, 11),
#  datetime.date(2023, 4, 27),
#  datetime.date(2015, 3, 2),
#  datetime.date(2021, 8, 13),
#  datetime.date(2019, 4, 11),
#  datetime.date(2021, 11, 9),
#  datetime.date(2022, 2, 17),
#  datetime.date(2019, 12, 6),
#  datetime.date(2023, 4, 3),
#  datetime.date(2021, 3, 30),
#  datetime.date(2021, 6, 18),
#  datetime.date(2019, 6, 24),
#  datetime.date(2023, 8, 14),
#  datetime.date(2021, 10, 8),
#  datetime.date(2021, 3, 9),
#  datetime.date(2016, 3, 15),
#  datetime.date(2022, 11, 14),
#  datetime.date(2016, 4, 14),
#  datetime.date(2020, 9, 22),
#  datetime.date(2015, 3, 4),
#  datetime.date(2016, 6, 28),
#  datetime.date(2021, 2, 2),
#  datetime.date(2019, 8, 28),
#  datetime.date(2022, 10, 13),
#  datetime.date(2019, 3, 12),
#  datetime.date(2016, 9, 23),
#  datetime.date(2024, 3, 27),
#  datetime.date(2021, 9, 17),
#  datetime.date(2016, 12, 1),
#  datetime.date(2023, 11, 14),
#  datetime.date(2019, 12, 20),
#  datetime.date(2022, 6, 14),
#  datetime.date(2021, 6, 8),
#  datetime.date(2022, 12, 19),
#  datetime.date(2024, 6, 17),
#  datetime.date(2020, 10, 12),
#  datetime.date(2016, 10, 14),
#  datetime.date(2024, 2, 16),
#  datetime.date(2024, 1, 18),
#  datetime.date(2018, 6, 21),
#  datetime.date(2020, 1, 1),
#  datetime.date(2016, 7, 19),
#  datetime.date(2016, 2, 18),
#  datetime.date(2019, 6, 12),
#  datetime.date(2022, 8, 22),
#  datetime.date(2018, 11, 15),
#  datetime.date(2022, 11, 29),
#  datetime.date(2021, 9, 22),
#  datetime.date(2016, 11, 21),
#  datetime.date(2015, 3, 17),
#  datetime.date(2022, 6, 9),
#  datetime.date(2015, 7, 15),
#  datetime.date(2019, 4, 23),
#  datetime.date(2019, 5, 15),
#  datetime.date(2021, 9, 2),
#  datetime.date(2016, 12, 14),
#  datetime.date(2021, 2, 3),
#  datetime.date(2015, 9, 9),
#  datetime.date(2023, 10, 31),
#  datetime.date(2019, 9, 25),
#  datetime.date(2021, 9, 23),
#  datetime.date(2018, 6, 19),
#  datetime.date(2024, 9, 3),
#  datetime.date(2015, 8, 11),
#  datetime.date(2023, 1, 24),
#  datetime.date(2018, 5, 4),
#  datetime.date(2018, 4, 5),
#  datetime.date(2021, 4, 27),
#  datetime.date(2018, 11, 8),
#  datetime.date(2021, 12, 24),
#  datetime.date(2024, 8, 8),
#  datetime.date(2023, 12, 26),
#  datetime.date(2024, 6, 13),
#  datetime.date(2020, 7, 28),
#  datetime.date(2023, 8, 22),
#  datetime.date(2016, 7, 12),
#  datetime.date(2022, 3, 29),
#  datetime.date(2019, 1, 10),
#  datetime.date(2021, 10, 28),
#  datetime.date(2015, 6, 26),
#  datetime.date(2015, 6, 5),
#  datetime.date(2021, 9, 7),
#  datetime.date(2015, 12, 21),
#  datetime.date(2022, 6, 27),
#  datetime.date(2021, 3, 25),
#  datetime.date(2023, 7, 11),
#  datetime.date(2019, 8, 1),
#  datetime.date(2017, 10, 30),
#  datetime.date(2021, 11, 26),
#  datetime.date(2018, 12, 21),
#  datetime.date(2024, 9, 4),
#  datetime.date(2019, 12, 12),
#  datetime.date(2020, 7, 21),
#  datetime.date(2024, 6, 14),
#  datetime.date(2017, 3, 10),
#  datetime.date(2019, 7, 3),
#  datetime.date(2021, 6, 7),
#  datetime.date(2022, 6, 1),
#  datetime.date(2017, 11, 15),
#  datetime.date(2022, 11, 15),
#  datetime.date(2018, 2, 15),
#  datetime.date(2024, 5, 3),
#  datetime.date(2023, 6, 6),
#  datetime.date(2021, 2, 10),
#  datetime.date(2023, 12, 1),
#  datetime.date(2020, 6, 22),
#  datetime.date(2020, 8, 27),
#  datetime.date(2015, 4, 17),
#  datetime.date(2022, 6, 21),
#  datetime.date(2016, 5, 20),
#  datetime.date(2022, 11, 3),
#  datetime.date(2022, 12, 26),
#  datetime.date(2018, 8, 20),
#  datetime.date(2022, 6, 17),
#  datetime.date(2016, 3, 7),
#  datetime.date(2021, 6, 24),
#  datetime.date(2024, 9, 23),
#  datetime.date(2024, 6, 4),
#  datetime.date(2015, 6, 29),
#  datetime.date(2021, 4, 13),
#  datetime.date(2018, 3, 21),
#  datetime.date(2024, 8, 7),
#  datetime.date(2015, 10, 30),
#  datetime.date(2017, 11, 20),
#  datetime.date(2019, 8, 16),
#  datetime.date(2022, 5, 26),
#  datetime.date(2015, 5, 6),
#  datetime.date(2015, 7, 27),
#  datetime.date(2022, 12, 9),
#  datetime.date(2019, 11, 20),
#  datetime.date(2020, 2, 21),
#  datetime.date(2018, 2, 6),
#  datetime.date(2024, 9, 24),
#  datetime.date(2016, 5, 27),
#  datetime.date(2015, 3, 20),
#  datetime.date(2017, 8, 3),
#  datetime.date(2022, 4, 27),
#  datetime.date(2022, 6, 6),
#  datetime.date(2019, 3, 7),
#  datetime.date(2020, 7, 27),
#  datetime.date(2015, 8, 24),
#  datetime.date(2019, 8, 14),
#  datetime.date(2017, 2, 21),
#  datetime.date(2018, 12, 12),
#  datetime.date(2017, 3, 6),
#  datetime.date(2019, 7, 1),
#  datetime.date(2021, 4, 22),
#  datetime.date(2018, 9, 7),
#  datetime.date(2022, 12, 28),
#  datetime.date(2017, 6, 19),
#  datetime.date(2020, 1, 29),
#  datetime.date(2021, 1, 22),
#  datetime.date(2023, 9, 29),
#  datetime.date(2016, 4, 18),
#  datetime.date(2019, 3, 22),
#  datetime.date(2022, 8, 16),
#  datetime.date(2016, 6, 29),
#  datetime.date(2015, 8, 5),
#  datetime.date(2016, 6, 9),
#  datetime.date(2019, 5, 20),
#  datetime.date(2021, 7, 2),
#  datetime.date(2020, 11, 30),
#  datetime.date(2023, 9, 18),
#  datetime.date(2022, 9, 5),
#  datetime.date(2019, 11, 5),
#  datetime.date(2021, 10, 21),
#  datetime.date(2019, 5, 6),
#  datetime.date(2016, 5, 25),
#  datetime.date(2020, 6, 4),
#  datetime.date(2018, 4, 2),
#  datetime.date(2015, 12, 29),
#  datetime.date(2021, 10, 18),
#  datetime.date(2017, 7, 3),
#  datetime.date(2018, 8, 1),
#  datetime.date(2022, 8, 29),
#  datetime.date(2024, 8, 26),
#  datetime.date(2021, 1, 14),
#  datetime.date(2019, 11, 28),
#  datetime.date(2015, 5, 8),
#  datetime.date(2017, 11, 8),
#  datetime.date(2021, 8, 9),
#  datetime.date(2018, 10, 30),
#  datetime.date(2021, 4, 21),
#  datetime.date(2015, 4, 7),
#  datetime.date(2023, 9, 14),
#  datetime.date(2015, 11, 13),
#  datetime.date(2020, 12, 4),
#  datetime.date(2020, 9, 14),
#  datetime.date(2016, 12, 8),
#  datetime.date(2022, 2, 9),
#  datetime.date(2024, 4, 23),
#  datetime.date(2018, 5, 25),
#  datetime.date(2018, 11, 14),
#  datetime.date(2015, 8, 14),
#  datetime.date(2015, 12, 22),
#  datetime.date(2018, 8, 31),
#  datetime.date(2019, 5, 8),
#  datetime.date(2016, 8, 31),
#  datetime.date(2021, 9, 21),
#  datetime.date(2018, 5, 9),
#  datetime.date(2016, 8, 1),
#  datetime.date(2022, 7, 21),
#  datetime.date(2020, 3, 4),
#  datetime.date(2015, 7, 8),
#  datetime.date(2024, 5, 21),
#  datetime.date(2019, 10, 28),
#  datetime.date(2022, 10, 25),
#  datetime.date(2018, 1, 4),
#  datetime.date(2018, 9, 6),
#  datetime.date(2017, 3, 28),
#  datetime.date(2016, 1, 7),
#  datetime.date(2018, 7, 27),
#  datetime.date(2020, 2, 5),
#  datetime.date(2019, 9, 18),
#  datetime.date(2015, 7, 13),
#  datetime.date(2017, 10, 17),
#  datetime.date(2017, 7, 31),
#  datetime.date(2024, 10, 4),
#  datetime.date(2017, 2, 16),
#  datetime.date(2022, 1, 27),
#  datetime.date(2018, 11, 26),
#  datetime.date(2019, 6, 28),
#  datetime.date(2015, 10, 20),
#  datetime.date(2017, 8, 28),
#  datetime.date(2020, 12, 23),
#  datetime.date(2021, 11, 15),
#  datetime.date(2020, 8, 24),
#  datetime.date(2015, 6, 8),
#  datetime.date(2019, 10, 25),
#  datetime.date(2022, 11, 16),
#  datetime.date(2015, 7, 2),
#  datetime.date(2018, 11, 28),
#  datetime.date(2021, 10, 6),
#  datetime.date(2022, 11, 22),
#  datetime.date(2023, 6, 13),
#  datetime.date(2017, 5, 24),
#  datetime.date(2017, 10, 19),
#  datetime.date(2017, 7, 14),
#  datetime.date(2017, 7, 17),
#  datetime.date(2018, 9, 25),
#  datetime.date(2015, 7, 3),
#  datetime.date(2018, 8, 30),
#  datetime.date(2020, 11, 2),
#  datetime.date(2019, 2, 26),
#  datetime.date(2023, 4, 6),
#  datetime.date(2021, 7, 6),
#  datetime.date(2015, 9, 10),
#  datetime.date(2017, 11, 7),
#  datetime.date(2018, 12, 6),
#  datetime.date(2023, 12, 19),
#  datetime.date(2023, 9, 7),
#  datetime.date(2019, 4, 15),
#  datetime.date(2019, 7, 15),
#  datetime.date(2019, 4, 4),
#  datetime.date(2022, 2, 3),
#  datetime.date(2020, 5, 6),
#  datetime.date(2022, 5, 2),
#  datetime.date(2023, 11, 28),
#  datetime.date(2018, 11, 7),
#  datetime.date(2018, 6, 22),
#  datetime.date(2023, 12, 4),
#  datetime.date(2019, 5, 2),
#  datetime.date(2023, 4, 28),
#  datetime.date(2022, 8, 19),
#  datetime.date(2019, 11, 25),
#  datetime.date(2015, 10, 29),
#  datetime.date(2015, 10, 1),
#  datetime.date(2018, 1, 24),
#  datetime.date(2018, 12, 17),
#  datetime.date(2019, 3, 11),
#  datetime.date(2015, 9, 15),
#  datetime.date(2022, 1, 20),
#  datetime.date(2024, 4, 19),
#  datetime.date(2023, 10, 24),
#  datetime.date(2023, 2, 24),
#  datetime.date(2020, 9, 21),
#  datetime.date(2018, 2, 5),
#  datetime.date(2023, 3, 30),
#  datetime.date(2017, 6, 23),
#  datetime.date(2020, 5, 7),
#  datetime.date(2023, 8, 8),
#  datetime.date(2024, 2, 19),
#  datetime.date(2024, 5, 13),
#  datetime.date(2020, 9, 15),
#  datetime.date(2018, 3, 19),
#  datetime.date(2022, 10, 28),
#  datetime.date(2023, 12, 12),
#  datetime.date(2023, 6, 7),
#  datetime.date(2021, 11, 3),
#  datetime.date(2016, 9, 20),
#  datetime.date(2024, 7, 29),
#  datetime.date(2024, 3, 25),
#  datetime.date(2024, 8, 5),
#  datetime.date(2022, 12, 23),
#  datetime.date(2024, 2, 7),
#  datetime.date(2018, 8, 7),
#  datetime.date(2022, 1, 12),
#  datetime.date(2020, 1, 27),
#  datetime.date(2018, 6, 7),
#  datetime.date(2020, 3, 16),
#  datetime.date(2018, 12, 31),
#  datetime.date(2017, 2, 3),
#  datetime.date(2020, 11, 14),
#  datetime.date(2021, 2, 25),
#  datetime.date(2016, 6, 15),
#  datetime.date(2018, 4, 3),
#  datetime.date(2018, 1, 29),
#  datetime.date(2021, 8, 31),
#  datetime.date(2015, 7, 14),
#  datetime.date(2016, 6, 21),
#  datetime.date(2015, 11, 10),
#  datetime.date(2015, 3, 11),
#  datetime.date(2023, 6, 27),
#  datetime.date(2019, 2, 5),
#  datetime.date(2017, 2, 2),
#  datetime.date(2018, 6, 4),
#  datetime.date(2015, 5, 1),
#  datetime.date(2016, 12, 22),
#  datetime.date(2020, 1, 6),
#  datetime.date(2023, 5, 30),
#  datetime.date(2020, 9, 23),
#  datetime.date(2022, 8, 11),
#  datetime.date(2023, 10, 30),
#  datetime.date(2020, 4, 17),
#  datetime.date(2021, 1, 19),
#  datetime.date(2022, 9, 21),
#  datetime.date(2015, 5, 15),
#  datetime.date(2015, 7, 23),
#  datetime.date(2022, 8, 9),
#  datetime.date(2024, 2, 6),
#  datetime.date(2023, 2, 9),
#  datetime.date(2016, 5, 2),
#  datetime.date(2021, 7, 22),
#  datetime.date(2015, 7, 30),
#  datetime.date(2024, 8, 9),
#  datetime.date(2018, 4, 19),
#  datetime.date(2019, 11, 27),
#  datetime.date(2019, 4, 26),
#  datetime.date(2022, 8, 4),
#  datetime.date(2024, 6, 12),
#  datetime.date(2017, 3, 15),
#  datetime.date(2021, 9, 28),
#  datetime.date(2015, 4, 30),
#  datetime.date(2016, 4, 27),
#  datetime.date(2017, 5, 2),
#  datetime.date(2018, 7, 2),
#  datetime.date(2020, 5, 14),
#  datetime.date(2019, 12, 5),
#  datetime.date(2023, 11, 16),
#  datetime.date(2017, 12, 15),
#  datetime.date(2020, 11, 10),
#  datetime.date(2021, 10, 19),
#  datetime.date(2016, 8, 18),
#  datetime.date(2021, 7, 29),
#  datetime.date(2023, 7, 27),
#  datetime.date(2018, 1, 3),
#  datetime.date(2019, 11, 13),
#  datetime.date(2022, 1, 13),
#  datetime.date(2022, 12, 2),
#  datetime.date(2015, 12, 14),
#  datetime.date(2018, 8, 3),
#  datetime.date(2021, 11, 8),
#  datetime.date(2020, 10, 14),
#  datetime.date(2016, 12, 9),
#  datetime.date(2023, 8, 24),
#  datetime.date(2021, 11, 23),
#  datetime.date(2016, 10, 4),
#  datetime.date(2021, 4, 6),
#  datetime.date(2015, 11, 24),
#  datetime.date(2020, 6, 9),
#  datetime.date(2016, 3, 21),
#  datetime.date(2017, 11, 29),
#  datetime.date(2024, 9, 16),
#  datetime.date(2021, 9, 8),
#  datetime.date(2016, 6, 13),
#  datetime.date(2019, 1, 11),
#  datetime.date(2024, 2, 5),
#  datetime.date(2022, 6, 10),
#  datetime.date(2017, 9, 8),
#  datetime.date(2016, 12, 13),
#  datetime.date(2021, 12, 17),
#  datetime.date(2015, 9, 24),
#  datetime.date(2023, 7, 6),
#  datetime.date(2016, 2, 15),
#  datetime.date(2019, 4, 9),
#  datetime.date(2018, 3, 2),
#  datetime.date(2018, 1, 22),
#  datetime.date(2016, 5, 23),
#  datetime.date(2018, 2, 8),
#  datetime.date(2015, 10, 9),
#  datetime.date(2021, 5, 4),
#  datetime.date(2021, 6, 22),
#  datetime.date(2022, 2, 24),
#  datetime.date(2022, 7, 1),
#  datetime.date(2020, 7, 17),
#  ...}

# %%
def rename_ohlc_columns(df: pl.DataFrame) -> pl.DataFrame:

    column_mapping = {"o": "open", "h": "high", "l": "low", "c": "close", "v": "volume"}
    df = df.rename(column_mapping)

    return df

# %%
PORTFOLIO_VALUE = 10_00_000 # 10 Lacs
RPT_PCT = 0.01 # 1% RPT
SLIPPAGE_ = 0.001
LEVERAGE_ = 5

# %%
def calculate_signals(df, ema_length, x_days, pct):
    # Calculate X-day High/Low and 20 EMA
    df['X_High'] = df['high'].rolling(x_days).mean()
    df['X_Low'] = df['low'].rolling(x_days).mean()
    df['EMA_20'] = df['close'].ewm(span=ema_length, adjust=False).mean()
    
    # Trend conditions
    # df['EMA_Trend'] = df['EMA_20'] > df['EMA_20'].shift(1)
    
    # Signal conditions
    # df['Buy_Signal'] = (
    #     (df['close'] > df['X_High'].shift(1) * (1 + (pct / 100))) & 
    #     (df['EMA_Trend']) & 
    #     (df['close'] > df['EMA_20'])
    # )
    # df['Sell_Signal'] = (
    #     (df['close'] < df['X_Low'].shift(1) * (1 - (pct / 100))) & 
    #     (~df['EMA_Trend']) & 
    #     (df['close'] < df['EMA_20'])
    # )
    
    df['MA'] = df['close'].rolling(9).mean()
    df['EMA'] = df['close'].ewm(span=30, adjust=False).mean()

    df['Buy_Signal'] = (
       (df['MA'] > df['EMA']) &
        (df['MA'].shift(1) <= df['EMA'].shift(1))
    )
    return df

# %%
# def backtest(df):
#     position = 0
#     entry_price = 0
#     trades = []
#     trailing_stop = None
    
#     for i in range(len(df)):
#         if df.loc[i, 'Buy_Signal'] and position == 0:
#             position = 1
#             # entry_price = df.loc[i, 'close']
#             trailing_stop_long = df.loc[i, 'EMA_20']
#             # trades.append({'Type': 'Buy', 'Price': entry_price, 'Date': df.loc[i, 'datetime']})
#             entry_time_long = df.loc[i, 'datetime']
#             entry_price_long = df.loc[i, 'close']
#             initial_sl_long = trailing_stop_long
        
#         elif df.loc[i, 'Sell_Signal'] and position == 0:
#             position = -1
#             entry_price = df.loc[i, 'close']
#             trailing_stop_short = df.loc[i, 'EMA_20']
#             # trades.append({'Type': 'Sell', 'Price': entry_price, 'Date': df.loc[i, 'datetime']})
#             entry_time_short = df.loc[i, 'datetime']
#             entry_price_short = df.loc[i, 'close']
#             initial_sl_short = trailing_stop_short
        
#         elif position == 1:
#             if df.loc[i, 'low'] < trailing_stop_long:
#                 # trades.append({'Type': 'Exit', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 position = 0
#                 exit_time_long = df.loc[i, 'datetime']
#                 exit_price_long = trailing_stop_long
#                 points_long = exit_price_long - entry_price_long
                
#             elif df.loc[i, 'Add_Long']:
#                 # trades.append({'Type': 'Add Long', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 entry_time_long = df.loc[i, 'datetime']
#                 entry_price_long = df.loc[i, 'close']
#                 initial_sl_long = trailing_stop_long
#                 trailing_stop_long = max(trailing_stop_long, df.loc[i, 'EMA_20'])
        
#         elif position == -1:
#             if df.loc[i, 'high'] > trailing_stop:
#                 trades.append({'Type': 'Exit', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 position = 0
#             elif df.loc[i, 'Add_Short']:
#                 trades.append({'Type': 'Add Short', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 trailing_stop = min(trailing_stop, df.loc[i, 'EMA_20'])
    
#     return pd.DataFrame(trades)

# %%
def backtest(df, y_days):
    # Variables for long trades
    long_position = 0  # 0 = no position, 1 = long
    long_entry_price = 0
    long_entry_date = None
    long_trades = []
    tradebook = pd.DataFrame()
    tradebook_long = pd.DataFrame()
    tradebook_short = pd.DataFrame()
    long_trailing_stop = None
    # Variables for short trades
    short_position = 0  # 0 = no position, -1 = short
    short_entry_price = 0
    short_entry_date = None
    short_trades = []
    short_trailing_stop = None

    can_add_long = False
    can_add_short = False

    trade_number = 0
    lock_initial_sl = False
    first_sl = 0

    lock_initial_sl_2 = False
    first_sl_2 = 0

    for i in range(len(df)):
        # Entry signals for long trades
        long_trailing_stop = df.loc[i, 'EMA_20']
        # short_trailing_stop = df.loc[i, 'EMA_20']
        
        if df.loc[i, 'Buy_Signal'] and long_position == 0:
            long_position = 1
            long_entry_price = df.loc[i, 'close']
            long_entry_date = df.loc[i, 'datetime']
            # long_trailing_stop = df.loc[i, 'EMA_20']
            long_initial_sl = long_entry_price * 0.985

            tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
                'Trade No.': trade_number,
                'Entry_Date': df.loc[i, 'datetime'],
                'Exit_Date': None,
                'Trade_Type': 'Long',
                'Entry_Price': df.loc[i, 'close'],
                'Initial SL': long_initial_sl,
                'Exit_Price': None,
                # 'Profit/Loss': None  # Filled when exited
            }])], ignore_index=True)

            if not lock_initial_sl:
                first_sl = long_initial_sl
                lock_initial_sl = True
                
        # Exit or add to long position
        if long_position == 1:
            
            y_days_low = df['low'].rolling(y_days).min().iloc[i-1]
            y_days_high = df['high'].rolling(y_days).max().iloc[i-1]
            
            # print(df.iloc[i]['datetime'], y_days_high, y_days_low)
            
            if df.loc[i, 'low'] <= long_initial_sl:
                tradebook_long.loc[
                    (tradebook_long['Trade No.'] == trade_number),
                    ['Exit_Date', 'Exit_Price', 'Exit Remark']
                ] = [df.loc[i, 'datetime'] , long_initial_sl , 'Initial SL Hit']
                long_position = 0
                can_add_long = False
                trade_number += 1
                lock_initial_sl = False
                first_sl = 0

            elif df.loc[i, 'MA'] <= df.loc[i, 'EMA']:
                tradebook_long.loc[
                    (tradebook_long['Trade No.'] == trade_number),
                    ['Exit_Date', 'Exit_Price', 'Exit Remark']
                ] = [df.loc[i, 'datetime'] , df.loc[i, 'close'] , 'MA Cross Reversal']
                long_position = 0
                can_add_long = False
                trade_number += 1
                lock_initial_sl = False
                first_sl = 0
            
            # elif df.loc[i, 'close'] <= long_trailing_stop:
            #     tradebook_long.loc[
            #         (tradebook_long['Trade No.'] == trade_number),
            #         ['Exit_Date', 'Exit_Price', 'Exit Remark']
            #     ] = [df.loc[i, 'datetime'] , df.loc[i, 'close'] , 'Trailing SL Hit']
            #     long_position = 0
            #     can_add_long = False
            #     trade_number += 1
            #     lock_initial_sl = False
            #     first_sl = 0

            elif (df.loc[i, 'low'] <= y_days_low) and not can_add_long:
                # Previous Y Candle Low Breached, confirmation found. Add position on high break
                can_add_long = True

            if can_add_long and long_position:
                if df.loc[i, 'high'] >= y_days_high:
                    tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
                        'Trade No.': trade_number,
                        'Entry_Date': df.loc[i, 'datetime'],
                        'Exit_Date': None,
                        'Trade_Type': 'Add_Long',
                        'Entry_Price': y_days_high,
                        'Initial SL': first_sl,
                        'Exit_Price': None,
                        # 'Profit/Loss': None  # Filled when exited
                    }])], ignore_index=True)
                    can_add_long = False

    # for i in range(len(df)):
        
    #     # Entry signals for long trades
    #     long_trailing_stop = df.loc[i, 'EMA_20']
    #     short_trailing_stop = df.loc[i, 'EMA_20']

    #     # Entry signals for short trades
    #     if df.loc[i, 'Sell_Signal'] and short_position == 0:
    #         short_position = -1
    #         short_entry_price = df.loc[i, 'close']
    #         short_entry_date = df.loc[i, 'datetime']
    #         short_trailing_stop = df.loc[i, 'EMA_20']
    #         short_initial_sl = df.loc[i, 'X_High']

    #         tradebook_short = pd.concat([tradebook_short, pd.DataFrame([{
    #             'Trade No.': trade_number,
    #             'Entry_Date': df.loc[i, 'datetime'],
    #             'Exit_Date': None,
    #             'Trade_Type': 'Short',
    #             'Entry_Price': df.loc[i, 'close'],
    #             'Initial SL': short_initial_sl,
    #             'Exit_Price': None,
    #             # 'Profit/Loss': None  # Filled when exited
    #         }])], ignore_index=True)
            
    #         if not lock_initial_sl_2:
    #             first_sl_2 = short_initial_sl
    #             lock_initial_sl_2 = True

    #     if short_position == -1:

    #         y_days_low = df['low'].rolling(y_days).min().iloc[i-1]
    #         y_days_high = df['high'].rolling(y_days).max().iloc[i-1]
            
    #         # print(df.iloc[i]['datetime'], y_days_high, y_days_low)
            
    #         if df.loc[i, 'high'] >= short_initial_sl:
    #             tradebook_short.loc[
    #                 (tradebook_short['Trade No.'] == trade_number),
    #                 ['Exit_Date', 'Exit_Price', 'Exit Remark']
    #             ] = [df.loc[i, 'datetime'] , short_initial_sl , 'Initial SL Hit']
    #             short_position = 0
    #             can_add_short = False
    #             trade_number += 1
    #             lock_initial_sl_2 = False
    #             first_sl_2 = 0
            
    #         elif df.loc[i, 'close'] >= short_trailing_stop:
    #             tradebook_short.loc[
    #                 (tradebook_short['Trade No.'] == trade_number),
    #                 ['Exit_Date', 'Exit_Price', 'Exit Remark']
    #             ] = [df.loc[i, 'datetime'] , df.loc[i, 'close'] , 'Trailing SL Hit']
    #             short_position = 0
    #             can_add_short = False
    #             trade_number += 1
    #             lock_initial_sl_2 = False
    #             first_sl_2 = 0

    #         elif (df.loc[i, 'high'] >= y_days_high) and not can_add_short:
    #             # Previous Y Candle High Breached, confirmation found. Add position on low break
    #             can_add_short = True

    #         if can_add_short and short_position:
    #             if df.loc[i, 'low'] <= y_days_low:
    #                 tradebook_short = pd.concat([tradebook_short, pd.DataFrame([{
    #                     'Trade No.': trade_number,
    #                     'Entry_Date': df.loc[i, 'datetime'],
    #                     'Exit_Date': None,
    #                     'Trade_Type': 'Add_Short',
    #                     'Entry_Price': y_days_low,
    #                     'Initial SL': first_sl_2,
    #                     'Exit_Price': None,
    #                     # 'Profit/Loss': None  # Filled when exited
    #                 }])], ignore_index=True)
    #                 can_add_short = False
    
    tradebook = pd.concat([tradebook_long, tradebook_short], ignore_index=True)
    return tradebook

# %%
# def backtest(df, y_days):
#     # Variables for long trades
#     long_position = 0  # 0 = no position, 1 = long
#     long_entry_price = 0
#     long_entry_date = None
#     long_trades = []
#     tradebook = pd.DataFrame()
#     tradebook_long = pd.DataFrame()
#     tradebook_short = pd.DataFrame()
#     long_trailing_stop = None
#     # Variables for short trades
#     short_position = 0  # 0 = no position, -1 = short
#     short_entry_price = 0
#     short_entry_date = None
#     short_trades = []
#     short_trailing_stop = None

#     can_add_long = False
#     can_add_short = False

#     trade_number = 0

#     for i in range(len(df)):
#         # Entry signals for long trades
#         long_trailing_stop = df.loc[i, 'EMA_20']
#         short_trailing_stop = df.loc[i, 'EMA_20']
        
#         if df.loc[i, 'Buy_Signal'] and long_position == 0:
#             long_position = 1
#             long_entry_price = df.loc[i, 'close']
#             long_entry_date = df.loc[i, 'datetime']
#             long_trailing_stop = df.loc[i, 'EMA_20']
#             long_initial_sl = df.loc[i, 'X_Low']

#             tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
#                 'Trade No.': trade_number,
#                 'Entry_Date': df.loc[i, 'datetime'],
#                 'Exit_Date': None,
#                 'Trade_Type': 'Long',
#                 'Entry_Price': df.loc[i, 'close'],
#                 'Initial SL': long_initial_sl,
#                 'Exit_Price': None,
#                 # 'Profit/Loss': None  # Filled when exited
#             }])], ignore_index=True)

#         # Exit or add to long position
#         if long_position == 1:
            
#             y_days_low = df['low'].rolling(y_days).min().iloc[i-1]
#             y_days_high = df['high'].rolling(y_days).max().iloc[i-1]
            
#             # print(df.iloc[i]['datetime'], y_days_high, y_days_low)
            
#             if df.loc[i, 'low'] <= long_initial_sl:
#                 tradebook_long.loc[
#                     (tradebook_long['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] , long_initial_sl]
#                 long_position = 0
#                 can_add_long = False
#                 trade_number += 1
            
#             elif df.loc[i, 'close'] <= long_trailing_stop:
#                 tradebook_long.loc[
#                     (tradebook_long['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] , df.loc[i, 'close']]
#                 long_position = 0
#                 can_add_long = False
#                 trade_number += 1

#             elif (df.loc[i, 'low'] <= y_days_low) and not can_add_long:
#                 # Previous Y Candle Low Breached, confirmation found. Add position on high break
#                 can_add_long = True

#             if can_add_long and long_position:
#                 if df.loc[i, 'high'] >= y_days_high:
#                     tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
#                         'Trade No.': trade_number,
#                         'Entry_Date': df.loc[i, 'datetime'],
#                         'Exit_Date': None,
#                         'Trade_Type': 'Add_Long',
#                         'Entry_Price': y_days_high,
#                         'Initial SL': long_initial_sl,
#                         'Exit_Price': None,
#                         # 'Profit/Loss': None  # Filled when exited
#                     }])], ignore_index=True)
#                     can_add_long = False

#     for i in range(len(df)):
        
#         # Entry signals for long trades
#         long_trailing_stop = df.loc[i, 'EMA_20']
#         short_trailing_stop = df.loc[i, 'EMA_20']

#         # Entry signals for short trades
#         if df.loc[i, 'Sell_Signal'] and short_position == 0:
#             short_position = -1
#             short_entry_price = df.loc[i, 'close']
#             short_entry_date = df.loc[i, 'datetime']
#             short_trailing_stop = df.loc[i, 'EMA_20']
#             short_initial_sl = df.loc[i, 'X_High']

#             tradebook_short = pd.concat([tradebook_short, pd.DataFrame([{
#                 'Trade No.': trade_number,
#                 'Entry_Date': df.loc[i, 'datetime'],
#                 'Exit_Date': None,
#                 'Trade_Type': 'Short',
#                 'Entry_Price': df.loc[i, 'close'],
#                 'Initial SL': short_initial_sl,
#                 'Exit_Price': None,
#                 # 'Profit/Loss': None  # Filled when exited
#             }])], ignore_index=True)

#         if short_position == -1:
            
#             y_days_low = df['low'].rolling(y_days).min().iloc[i-1]
#             y_days_high = df['high'].rolling(y_days).max().iloc[i-1]
            
#             # print(df.iloc[i]['datetime'], y_days_high, y_days_low)
            
#             if df.loc[i, 'high'] >= short_initial_sl:
#                 tradebook_short.loc[
#                     (tradebook_short['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] ,short_initial_sl]
#                 short_position = 0
#                 can_add_short = False
#                 trade_number += 1
            
#             elif df.loc[i, 'close'] >= short_trailing_stop:
#                 tradebook_short.loc[
#                     (tradebook_short['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] , df.loc[i, 'close']]
#                 short_position = 0
#                 can_add_short = False
#                 trade_number += 1

#             elif (df.loc[i, 'high'] >= y_days_high) and not can_add_short:
#                 # Previous Y Candle High Breached, confirmation found. Add position on low break
#                 can_add_short = True

#             if can_add_short and short_position:
#                 if df.loc[i, 'low'] <= y_days_low:
#                     tradebook_short = pd.concat([tradebook_short, pd.DataFrame([{
#                         'Trade No.': trade_number,
#                         'Entry_Date': df.loc[i, 'datetime'],
#                         'Exit_Date': None,
#                         'Trade_Type': 'Add_Short',
#                         'Entry_Price': y_days_low,
#                         'Initial SL': short_initial_sl,
#                         'Exit_Price': None,
#                         # 'Profit/Loss': None  # Filled when exited
#                     }])], ignore_index=True)
#                     can_add_short = False
    
#     tradebook = pd.concat([tradebook_long, tradebook_short], ignore_index=True)
#     return tradebook

# %%
ema_length = 55
x_days = 28
y_days = 7
pct = 1.05
RPT = 5
df = bnf_1min
df = calculate_signals(df, ema_length=ema_length, x_days=x_days, pct=pct)
tb = backtest(df, y_days=y_days)
tb = tb.sort_values(by='Entry_Date')
variation = f'EMA: {ema_length}, X: {x_days}, Y: {y_days}, PCT: {pct}%, RPT: {RPT}%'
# Out:
# /tmp/ipykernel_30393/4053321522.py:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'MA Cross Reversal' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_long.loc[

# %%
import numpy as np
portfolio = 10000000
tb['PnL'] = np.where(
    tb['Trade_Type'].isin(['Long', 'Add_Long']),  # For Long and Add_Long
    tb['Exit_Price'] - tb['Entry_Price'],
    np.where(
        tb['Trade_Type'].isin(['Short', 'Add_Short']),  # For Short and Add_Short
        tb['Entry_Price'] - tb['Exit_Price'],
        0  # Default case if Trade_Type is something unexpected
    )
)

tb['Slippage'] = SLIPPAGE_ * (tb['Entry_Price'] + tb['Exit_Price'])
tb['PnL w cs'] = tb['PnL'] - tb['Slippage']
tb['Qty'] = abs(RPT / 100 * portfolio / (tb['Entry_Price'] - tb['Initial SL']))
tb['Profit_Loss INR'] = tb['Qty'] * tb['PnL w cs']
tb['ROI%'] = tb['Profit_Loss INR'] * 100 / portfolio

# %%
tb['Cumulative_PnL'] = tb['PnL w cs'].cumsum()

# %%
# tb.to_csv('GOLD TRADE CHECK JJPP.csv', index=False)

# %%
tb = tb.reset_index()
# tb

# %%
import matplotlib.pyplot as plt

def plot_cumulative_pnl(tb, title="Cumulative PnL Over Time"):
    if 'Cumulative_PnL' not in tb.columns:
        raise ValueError("The DataFrame must contain a 'Cumulative_PnL' column.")

    # Plot cumulative PnL
    plt.figure(figsize=(12, 3))
    plt.plot(tb.index, tb['Cumulative_PnL'], label='Cumulative PnL', color='blue', linewidth=2)
    plt.title(title, fontsize=8)
    plt.xlabel('Trade Index', fontsize=6)
    plt.ylabel('Cumulative PnL', fontsize=6)
    plt.legend(fontsize=6)
    plt.grid(alpha=0.5)
    plt.show()

# %%
tb_long_only = tb[(tb['Trade_Type'] == 'Long') | (tb['Trade_Type'] == 'Add_Long')].copy()
tb_long_only['Cumulative_PnL'] = tb_long_only['PnL w cs'].cumsum()
tb_short_only = tb[(tb['Trade_Type'] == 'Short') | (tb['Trade_Type'] == 'Add_Short')].copy()
tb_short_only['Cumulative_PnL'] = tb_short_only['PnL w cs'].cumsum()

# %%
# tb2 = tb.groupby('Trade No.', as_index=False)['PnL w cs'].sum()
# tb2['Cumulative_PnL'] = tb2['PnL w cs'].cumsum()

# %%
# plot_cumulative_pnl(tb_long_only)
# print(tb_long_only['PnL w cs'].sum())

# %%
# plot_cumulative_pnl(tb_short_only)
# print(tb_short_only['PnL w cs'].sum())

# %%
# plot_cumulative_pnl(tb)
# print(tb['PnL w cs'].sum())

# %%
# plot_cumulative_pnl(tb2)
# print(tb2['PnL w cs'].sum())

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2015, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2015, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI%"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI%"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI%"] > 0]["ROI%"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI%"] < 0]["ROI%"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI%"].cumsum() - year_trades["ROI%"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI%"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI%"] > 0]["ROI%"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI%"].cumsum() - combined_df_sorted["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation

    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    
    # print(f'{overall_total_roi} , {overall_max_drawdown} , {overall_roi_dd_ratio}')
    
    return {overall_roi_dd_ratio: stats_df8}

# %%
tb_long_only['Entry_Date'] = pd.to_datetime(tb_long_only['Entry_Date'])
tb_long_only['Trade Year'] = tb_long_only['Entry_Date'].dt.year
tb_long_only['ROI% w cs'] = tb_long_only['ROI%']

# %%
stats = generate_stats(tb_long_only, variation)
lol = pd.DataFrame()
for x, y in stats.items():
    lol = pd.DataFrame(y)

lol
# Out:
#          Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2015     -151.5458           27   0.0000                   NaN
# 2016     -164.9753           30   0.0000                   NaN
# 2017     -165.6626           30   0.0000                   NaN
# 2018     -175.5372           32   0.0000                   NaN
# 2019     -160.9305           29   0.0000                   NaN
# 2020     -199.0602           36   0.0000                   NaN
# 2021     -188.6989           34   0.0000                   NaN
# 2022     -177.2999           32   0.0000                   NaN
# 2023     -180.7236           33   0.0000                   NaN
# 2024     -168.6067           31   0.0000                   NaN
# Overall -1733.0407          314   0.0000                   NaN
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
# 2015                -5.6128    -145.8841      -1.0388
# 2016                -5.4992    -159.3136      -1.0355
# 2017                -5.5221    -160.5124      -1.0321
# 2018                -5.4855    -170.2972      -1.0308
# 2019                -5.5493    -155.2689      -1.0365
# 2020                -5.5295    -193.3986      -1.0293
# 2021                -5.5500    -183.0372      -1.0309
# 2022                -5.5406    -171.6382      -1.0330
# 2023                -5.4765    -175.5694      -1.0294
# 2024                -5.4389    -163.2890      -1.0326
# Overall             -5.5192   -1727.3790      -1.0033
#
#                                          Variation
# 2015     EMA: 55, X: 28, Y: 7, PCT: 1.05%, RPT: 5%
# 2016     EMA: 55, X: 28, Y: 7, PCT: 1.05%, RPT: 5%
# 2017     EMA: 55, X: 28, Y: 7, PCT: 1.05%, RPT: 5%
# 2018     EMA: 55, X: 28, Y: 7, PCT: 1.05%, RPT: 5%
# 2019     EMA: 55, X: 28, Y: 7, PCT: 1.05%, RPT: 5%
# 2020     EMA: 55, X: 28, Y: 7, PCT: 1.05%, RPT: 5%
# 2021     EMA: 55, X: 28, Y: 7, PCT: 1.05%, RPT: 5%
# 2022     EMA: 55, X: 28, Y: 7, PCT: 1.05%, RPT: 5%
# 2023     EMA: 55, X: 28, Y: 7, PCT: 1.05%, RPT: 5%
# 2024     EMA: 55, X: 28, Y: 7, PCT: 1.05%, RPT: 5%
# Overall  EMA: 55, X: 28, Y: 7, PCT: 1.05%, RPT: 5%

# %%
tb_long_only
# Out:
#      index  Trade No.                Entry_Date                  Exit_Date  \
# 0        0          0 2015-03-20 17:00:00+05:30  2015-04-01 09:00:00+05:30
# 1        1          1 2015-04-01 17:00:00+05:30  2015-04-10 17:00:00+05:30
# 2        2          2 2015-04-13 17:00:00+05:30  2015-04-15 17:00:00+05:30
# 3        3          3 2015-04-17 13:00:00+05:30  2015-04-24 17:00:00+05:30
# 4        4          3 2015-04-24 13:00:00+05:30  2015-04-24 17:00:00+05:30
# 5        5          4 2015-04-24 21:00:00+05:30  2015-05-04 21:00:00+05:30
# 6        6          4 2015-04-27 17:00:00+05:30  2015-05-04 21:00:00+05:30
# 7        7          5 2015-05-07 13:00:00+05:30  2015-05-11 17:00:00+05:30
# 8        8          6 2015-05-12 17:00:00+05:30  2015-05-21 17:00:00+05:30
# 9        9          7 2015-06-03 13:00:00+05:30  2015-06-05 13:00:00+05:30
# 10      10          8 2015-06-11 09:00:00+05:30  2015-06-15 09:00:00+05:30
# 11      11          9 2015-06-15 17:00:00+05:30  2015-06-23 13:00:00+05:30
# 12      12          9 2015-06-18 13:00:00+05:30  2015-06-23 13:00:00+05:30
# 13      13         10 2015-08-04 09:00:00+05:30  2015-08-05 09:00:00+05:30
# 14      14         11 2015-08-10 13:00:00+05:30  2015-08-27 17:00:00+05:30
# 310    310        175 2024-09-11 13:00:00+05:30  2024-10-09 17:00:00+05:30
# 311    311        175 2024-09-19 13:00:00+05:30  2024-10-09 17:00:00+05:30
# 312    312        175 2024-09-30 09:00:00+05:30  2024-10-09 17:00:00+05:30
# 313    313        175 2024-10-04 17:00:00+05:30  2024-10-09 17:00:00+05:30
#
#     Trade_Type  Entry_Price  Initial SL Exit_Price        Exit Remark  \
# 0         Long   26108.0000  25716.3800 25716.3800  MA Cross Reversal
# 1         Long   26620.0000  26220.7000 26220.7000  MA Cross Reversal
# 2         Long   26669.0000  26268.9650 26268.9650  MA Cross Reversal
# 3         Long   26745.0000  26343.8250 26343.8250  MA Cross Reversal
# 4     Add_Long   26929.0000  26343.8250 26343.8250  MA Cross Reversal
# 5         Long   26720.0000  26319.2000 26319.2000  MA Cross Reversal
# 6     Add_Long   26959.0000  26319.2000 26319.2000  MA Cross Reversal
# 7         Long   26967.0000  26562.4950 26562.4950  MA Cross Reversal
# 8         Long   27145.0000  26737.8250 26737.8250  MA Cross Reversal
# 9         Long   27140.0000  26732.9000 26732.9000     Initial SL Hit
# 10        Long   26918.0000  26514.2300 26514.2300  MA Cross Reversal
# 11        Long   26998.0000  26593.0300 26593.0300  MA Cross Reversal
# 12    Add_Long   27050.0000  26593.0300 26593.0300  MA Cross Reversal
# 13        Long   24820.0000  24447.7000 24447.7000  MA Cross Reversal
# 14        Long   24959.0000  24584.6150 24584.6150  MA Cross Reversal
# 15    Add_Long   25978.0000  24584.6150 24584.6150  MA Cross Reversal
# 16        Long   26680.0000  26279.8000 26279.8000  MA Cross Reversal
# 17        Long   26487.0000  26089.6950 26089.6950  MA Cross Reversal
# 18    Add_Long   26450.0000  26089.6950 26089.6950  MA Cross Reversal
# 19        Long   26625.0000  26225.6250 26225.6250  MA Cross Reversal
# 20    Add_Long   26670.0000  26225.6250 26225.6250  MA Cross Reversal
# 21    Add_Long   27170.0000  26225.6250 26225.6250  MA Cross Reversal
# 22        Long   26790.0000  26388.1500 26388.1500  MA Cross Reversal
# 23        Long   25111.0000  24734.3350 24734.3350  MA Cross Reversal
# 24        Long   25709.0000  25323.3650 25323.3650     Initial SL Hit
# 25    Add_Long   25674.0000  25323.3650 25323.3650     Initial SL Hit
# 26        Long   25274.0000  24894.8900 24894.8900  MA Cross Reversal
# 27        Long   25383.0000  25002.2550 25002.2550  MA Cross Reversal
# 28    Add_Long   25966.0000  25002.2550 25002.2550  MA Cross Reversal
# 29    Add_Long   26100.0000  25002.2550 25002.2550  MA Cross Reversal
# 30    Add_Long   26399.0000  25002.2550 25002.2550  MA Cross Reversal
# 31    Add_Long   26760.0000  25002.2550 25002.2550  MA Cross Reversal
# 32    Add_Long   28485.0000  25002.2550 25002.2550  MA Cross Reversal
# 33    Add_Long   29050.0000  25002.2550 25002.2550  MA Cross Reversal
# 34    Add_Long   29750.0000  25002.2550 25002.2550  MA Cross Reversal
# 35        Long   29910.0000  29461.3500 29461.3500     Initial SL Hit
# 36        Long   29503.0000  29060.4550 29060.4550  MA Cross Reversal
# 37        Long   28649.0000  28219.2650 28219.2650  MA Cross Reversal
# 38        Long   29245.0000  28806.3250 28806.3250  MA Cross Reversal
# 39        Long   29369.0000  28928.4650 28928.4650  MA Cross Reversal
# 40    Add_Long   30180.0000  28928.4650 28928.4650  MA Cross Reversal
# 41        Long   30153.0000  29700.7050 29700.7050     Initial SL Hit
# 42        Long   29385.0000  28944.2250 28944.2250  MA Cross Reversal
# 43    Add_Long   29499.0000  28944.2250 28944.2250  MA Cross Reversal
# 44    Add_Long   30657.0000  28944.2250 28944.2250  MA Cross Reversal
# 45        Long   31370.0000  30899.4500 30899.4500  MA Cross Reversal
# 46    Add_Long   31420.0000  30899.4500 30899.4500  MA Cross Reversal
# 47        Long   31089.0000  30622.6650 30622.6650  MA Cross Reversal
# 48        Long   31439.0000  30967.4150 30967.4150  MA Cross Reversal
# 49        Long   31339.0000  30868.9150 30868.9150  MA Cross Reversal
# 50        Long   31372.0000  30901.4200 30901.4200  MA Cross Reversal
# 51        Long   31211.0000  30742.8350 30742.8350  MA Cross Reversal
# 52        Long   30969.0000  30504.4650 30504.4650  MA Cross Reversal
# 53        Long   29989.0000  29539.1650 29539.1650  MA Cross Reversal
# 54        Long   29843.0000  29395.3550 29395.3550  MA Cross Reversal
# 55    Add_Long   29989.0000  29395.3550 29395.3550  MA Cross Reversal
# 56        Long   27256.0000  26847.1600 26847.1600  MA Cross Reversal
# 57    Add_Long   28696.0000  26847.1600 26847.1600  MA Cross Reversal
# 58        Long   28806.0000  28373.9100 28373.9100  MA Cross Reversal
# 59        Long   29193.0000  28755.1050 28755.1050  MA Cross Reversal
# 60    Add_Long   29325.0000  28755.1050 28755.1050  MA Cross Reversal
# 61        Long   28578.0000  28149.3300 28149.3300  MA Cross Reversal
# 62    Add_Long   28599.0000  28149.3300 28149.3300  MA Cross Reversal
# 63    Add_Long   28924.0000  28149.3300 28149.3300  MA Cross Reversal
# 64        Long   29021.0000  28585.6850 28585.6850  MA Cross Reversal
# 65    Add_Long   28950.0000  28585.6850 28585.6850  MA Cross Reversal
# 66        Long   29214.0000  28775.7900 28775.7900  MA Cross Reversal
# 67    Add_Long   29483.0000  28775.7900 28775.7900  MA Cross Reversal
# 68    Add_Long   29348.0000  28775.7900 28775.7900  MA Cross Reversal
# 69        Long   28542.0000  28113.8700 28113.8700  MA Cross Reversal
# 70    Add_Long   28765.0000  28113.8700 28113.8700  MA Cross Reversal
# 71    Add_Long   28986.0000  28113.8700 28113.8700  MA Cross Reversal
# 72    Add_Long   29119.0000  28113.8700 28113.8700  MA Cross Reversal
# 73        Long   28117.0000  27695.2450 27695.2450  MA Cross Reversal
# 74    Add_Long   28539.0000  27695.2450 27695.2450  MA Cross Reversal
# 75    Add_Long   28618.0000  27695.2450 27695.2450  MA Cross Reversal
# 76        Long   28830.0000  28397.5500 28397.5500  MA Cross Reversal
# 77    Add_Long   29139.0000  28397.5500 28397.5500  MA Cross Reversal
# 78    Add_Long   29214.0000  28397.5500 28397.5500  MA Cross Reversal
# 79    Add_Long   29730.0000  28397.5500 28397.5500  MA Cross Reversal
# 271   -293888.2411        2023   -5.6617
# 272   -294947.2739        2023   -5.6199
# 273   -296694.9947        2023   -5.3604
# 274   -297700.3199        2023   -5.6617
# 275   -298679.1654        2023   -5.6617
# 276   -302832.1820        2023   -5.1457
# 277   -307226.4395        2023   -5.1377
# 278   -308258.2783        2023   -5.6617
# 279   -309540.3670        2023   -5.5203
# 280   -312391.0228        2023   -5.2243
# 281   -313452.5683        2023   -5.6617
# 282   -314396.9968        2023   -5.7553
# 283   -316490.5733        2024   -5.3177
# 284   -317551.7791        2024   -5.6617
# 285   -318611.7790        2024   -5.6617
# 286   -320126.2329        2024   -5.4472
# 287   -321187.7444        2024   -5.6617
# 288   -322243.3112        2024   -5.6617
# 289   -323460.0390        2024   -5.5650
# 290   -328091.1778        2024   -5.1409
# 291   -333304.8986        2024   -5.1254
# 292   -345300.3944        2024   -5.0566
# 293   -357117.7122        2024   -5.0574
# 294   -358333.7533        2024   -5.6617
# 295   -359542.1681        2024   -5.6617
# 296   -360919.7519        2024   -5.5719
# 297   -362151.8438        2024   -5.6617
# 298   -363377.6512        2024   -5.6617
# 299   -364593.4715        2024   -5.6617
# 300   -366833.3148        2024   -5.3413
# 301   -369198.2830        2024   -5.3224
# 302   -370387.1821        2024   -5.6617
# 303   -372296.8011        2024   -5.3945
# 304   -373483.2034        2024   -5.6617
# 305   -375815.7506        2024   -5.3188
# 306   -378173.3229        2024   -5.3152
# 307   -381395.7591        2024   -5.2283
# 308   -384894.4714        2024   -5.2099
# 309   -386117.7311        2024   -5.6617
# 310   -387342.6893        2024   -5.6617
# 311   -389870.9495        2024   -5.3030
# 312   -394702.5107        2024   -5.1566
# 313   -400400.9379        2024   -5.1330

# %%
# tb_long_only.to_csv('GOLD Range JJPP.csv', index=False)

# %%
tb_long_only_1 = tb_long_only[tb_long_only['Trade_Type'] == 'Add_Long']
tb_long_only_2 = tb_long_only[tb_long_only['Trade_Type'] == 'Long']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 tb_long_only_1 = tb_long_only[tb_long_only['Trade_Type'] == 'Add_Long']
#       2 tb_long_only_2 = tb_long_only[tb_long_only['Trade_Type'] == 'Long']
#
# NameError: name 'tb_long_only' is not defined

# %%
tb_long_only_1['ROI%'].sum() , tb_long_only_2['ROI%'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 tb_long_only_1['ROI%'].sum() , tb_long_only_2['ROI%'].sum()
#
# NameError: name 'tb_long_only_1' is not defined

# %%
# ema_length = 55
# x_days = 28
# y_days = 7
# pct = 1.05
# RPT = 5

pct_range = [0.5, 0.75, 0.9, 1.05, 1.25, 1.4]

for ema_length in range(25, 81, 5):
    for x_days in range(4, 37, 4):
        for y_days in range(3, 19, 3):
            for pct in pct_range:
                RPT = 5
                variation = f'EMA:{ema_length}, X:{x_days}, Y:{y_days}, PCT:{pct}, RPT:{5}'
                print(variation)
                df = bnf_1min
                df = calculate_signals(df, ema_length=ema_length, x_days=x_days, pct=pct)
                tb = backtest(df, y_days=y_days)
                if len(tb) > 0:
                    tb = tb.sort_values(by='Entry_Date')
                    portfolio = 10000000
                    tb['PnL'] = np.where(
                        tb['Trade_Type'].isin(['Long', 'Add_Long']),  # For Long and Add_Long
                        tb['Exit_Price'] - tb['Entry_Price'],
                        np.where(
                            tb['Trade_Type'].isin(['Short', 'Add_Short']),  # For Short and Add_Short
                            tb['Entry_Price'] - tb['Exit_Price'],
                            0  # Default case if Trade_Type is something unexpected
                        )
                    )
                    
                    tb['Slippage'] = SLIPPAGE_ * (tb['Entry_Price'] + tb['Exit_Price'])
                    tb['PnL w cs'] = tb['PnL'] - tb['Slippage']
                    tb['Qty'] = abs(RPT / 100 * portfolio / (tb['Entry_Price'] - tb['Initial SL']))
                    tb['Profit_Loss INR'] = tb['Qty'] * tb['PnL w cs']
                    tb['ROI%'] = tb['Profit_Loss INR'] * 100 / portfolio
                    tb['Entry_Date'] = pd.to_datetime(tb['Entry_Date'])
                    tb['Trade Year'] = tb['Entry_Date'].dt.year
                    tb_long_only = tb[(tb['Trade_Type'] == 'Long') | (tb['Trade_Type'] == 'Add_Long')].copy()
                    tb_long_only['Cumulative_PnL'] = tb_long_only['PnL w cs'].cumsum()
                    tb_short_only = tb[(tb['Trade_Type'] == 'Short') | (tb['Trade_Type'] == 'Add_Short')].copy()
                    tb_short_only['Cumulative_PnL'] = tb_short_only['PnL w cs'].cumsum()

                    stats1 = generate_stats(tb_long_only, variation)
                    for x, y in stats1.items():
                        if x > 2:
                            print('Long Only')
                            print(pd.DataFrame(y).to_string())
                        break
                    stats2 = generate_stats(tb_short_only, variation)
                    for x, y in stats2.items():
                        if x > 2:
                            print('Short Only')
                            print(pd.DataFrame(y).to_string())
                        break
# Out:
# EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# /tmp/ipykernel_4593/453456106.py:76: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Trailing SL Hit' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_long.loc[
# /tmp/ipykernel_4593/453456106.py:152: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Trailing SL Hit' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_short.loc[
# Long Only
#         Total ROI Total Trades Win Rate Avg Profit% per Trade Avg Loss% per Trade Max Drawdown ROI/DD Ratio                         Variation
# 2015     -10.4907           37  27.0270                9.5618             -3.9300     -53.4513      -0.1963  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2016     110.7251           49  38.7755               10.2685             -2.8126     -45.3811       2.4399  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2017     -24.7094           50  24.0000                5.3332             -2.3344     -58.6098      -0.4216  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2018     -34.4612           41  34.1463                3.8950             -3.2960     -62.1415      -0.5546  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2019      15.7352           53  30.1887                8.4490             -3.2283     -63.4594       0.2480  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2020      52.1499           56  35.7143                7.6980             -2.8280     -48.1340       1.0834  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2021     -56.1503           50  30.0000                3.5960             -3.1454     -52.6194      -1.0671  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2022      40.4968           49  40.8163                6.1063             -2.8148     -38.3656       1.0556  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2023      33.0695           32  37.5000                8.2146             -3.2753     -30.8135       1.0732  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2024     124.8223           38  36.8421               12.8036             -2.3665     -34.8992       3.5766  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# Overall  251.1871          455  33.4066                7.5808             -2.9838    -109.6321       2.2912  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# /tmp/ipykernel_4593/453456106.py:76: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Trailing SL Hit' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_long.loc[
# /tmp/ipykernel_4593/453456106.py:152: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Trailing SL Hit' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_short.loc[
# Long Only
#         Total ROI Total Trades Win Rate Avg Profit% per Trade Avg Loss% per Trade Max Drawdown ROI/DD Ratio                          Variation
# 2015     -33.3079           22  18.1818                9.3994             -3.9392     -39.1528      -0.8507  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2016      89.5199           41  39.0244                9.9028             -2.7570     -37.4115       2.3928  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2017     -23.8991           32  25.0000                3.8688             -2.2854     -45.7482      -0.5224  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2018      -5.2815           24  41.6667                4.3309             -3.4707     -34.6120      -0.1526  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2019      10.9014           33  36.3636                6.7004             -3.3097     -43.0486       0.2532  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2020      32.5295           41  34.1463                6.9959             -2.4227     -33.9253       0.9589  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2021     -19.1174           40  37.5000                3.0021             -2.5659     -31.9564      -0.5982  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2022      43.8966           34  50.0000                4.9361             -2.3539     -24.7778       1.7716  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 