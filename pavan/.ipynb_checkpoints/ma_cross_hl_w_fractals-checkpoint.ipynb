# %%
import asyncio
import datetime as dt
import math
from typing import Literal

import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

# %%
import sys

sys.path.append("..")
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
async def get_expiry(f_today, index):

    if index == 'bnf':    
        if (f_today <= dt.date(2024, 1, 25)) and (f_today >= dt.date(2024, 1, 18)):
            f_expiry = dt.date(2024, 1, 25)
        elif (f_today <= dt.date(2024, 1, 31)) and (f_today >= dt.date(2024, 1, 26)):
            f_expiry = dt.date(2024, 1, 31)
        elif (f_today <= dt.date(2024, 2, 22)) and (f_today >= dt.date(2024, 2, 29)):
            f_expiry = dt.date(2024, 2, 29)
        elif (f_today <= dt.date(2024, 3, 25)) and (f_today >= dt.date(2024, 3, 27)):
            f_expiry = dt.date(2024, 2, 27)
        elif f_today < dt.date(2023, 9, 1):
            days_to_thursday = (3 - f_today.weekday()) % 7
            nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
            f_expiry = nearest_thursday
            if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
                f_expiry = nearest_thursday - dt.timedelta(days=1)
        elif f_today >= dt.date(2023, 9, 1):
            if f_today.day < 24:
                days_to_wednesday = (2 - f_today.weekday()) % 7
                nearest_wednesday = f_today + dt.timedelta(days=days_to_wednesday)
                f_expiry = nearest_wednesday
                if nse.valid_days(
                    start_date=nearest_wednesday, end_date=nearest_wednesday
                ).empty:
                    f_expiry = nearest_wednesday - dt.timedelta(days=1)
            else:
                days_to_thursday = (3 - f_today.weekday()) % 7
                nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
                f_expiry = nearest_thursday
                if nse.valid_days(
                    start_date=nearest_thursday, end_date=nearest_thursday
                ).empty:
                    f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'nifty':
        days_to_thursday = (3 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'finnifty' or index == 'fnf':
        days_to_thursday = (1 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'midcpnifty' or index == 'midcp':
        days_to_thursday = (0 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

async def get_expiry_nifty(f_today):

    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry


async def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"


def get_option_contract_name2(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"

# %%
bnf_1min = pd.read_csv("../data/gold_tv_4h.csv")
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["time"])
bnf_1min = bnf_1min[bnf_1min["datetime"].dt.year >= 2012]

# %%
bnf_1min.head()
# Out:
#                         time   open   high    low  close  MA  Shapes  \
# 0  2015-03-02T09:00:00+05:30  26600  26769  26600  26700 NaN       0
# 1  2015-03-02T13:00:00+05:30  26709  26730  26653  26680 NaN       0
# 2  2015-03-02T17:00:00+05:30  26684  26742  26576  26619 NaN       0
# 3  2015-03-02T21:00:00+05:30  26623  26624  26500  26506 NaN       0
# 4  2015-03-03T09:00:00+05:30  26500  26525  26444  26463 NaN       0
#
#    Shapes.1  RSI                  datetime
# 0         0  NaN 2015-03-02 09:00:00+05:30
# 1         0  NaN 2015-03-02 13:00:00+05:30
# 2         0  NaN 2015-03-02 17:00:00+05:30
# 3         0  NaN 2015-03-02 21:00:00+05:30
# 4         0  NaN 2015-03-03 09:00:00+05:30

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("open").first().alias("open"),
                pl.col("high").max().alias("high"),
                pl.col("low").min().alias("low"),
                pl.col("close").last().alias("close"),
                pl.col("volume").sum().alias("volume"),
            ]
        )
    )


# ohlc_resampled = resample(pl.DataFrame(bnf_1min), '7d', pd.Timedelta(days=4))
# ohlc_resampled

# %%
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["datetime"])
list_of_traded_dates = set(bnf_1min["datetime"].dt.date)
list_of_traded_dates
# Out:
# {datetime.date(2018, 1, 1),
#  datetime.date(2015, 11, 6),
#  datetime.date(2017, 8, 18),
#  datetime.date(2024, 3, 22),
#  datetime.date(2015, 6, 17),
#  datetime.date(2023, 7, 20),
#  datetime.date(2024, 1, 10),
#  datetime.date(2021, 7, 27),
#  datetime.date(2024, 1, 8),
#  datetime.date(2019, 1, 15),
#  datetime.date(2019, 12, 23),
#  datetime.date(2017, 8, 4),
#  datetime.date(2017, 3, 6),
#  datetime.date(2015, 10, 23),
#  datetime.date(2017, 2, 3),
#  datetime.date(2021, 2, 16),
#  datetime.date(2017, 4, 25),
#  datetime.date(2018, 7, 11),
#  datetime.date(2021, 8, 18),
#  datetime.date(2024, 3, 12),
#  datetime.date(2023, 7, 10),
#  datetime.date(2019, 2, 15),
#  datetime.date(2020, 9, 23),
#  datetime.date(2019, 5, 14),
#  datetime.date(2024, 5, 13),
#  datetime.date(2019, 2, 12),
#  datetime.date(2017, 11, 22),
#  datetime.date(2016, 11, 29),
#  datetime.date(2019, 10, 30),
#  datetime.date(2016, 8, 22),
#  datetime.date(2021, 11, 10),
#  datetime.date(2021, 2, 11),
#  datetime.date(2019, 12, 9),
#  datetime.date(2020, 8, 11),
#  datetime.date(2022, 2, 24),
#  datetime.date(2023, 11, 9),
#  datetime.date(2021, 3, 15),
#  datetime.date(2023, 10, 16),
#  datetime.date(2016, 9, 16),
#  datetime.date(2021, 5, 26),
#  datetime.date(2021, 10, 22),
#  datetime.date(2016, 5, 2),
#  datetime.date(2015, 7, 28),
#  datetime.date(2020, 10, 7),
#  datetime.date(2016, 9, 30),
#  datetime.date(2020, 8, 25),
#  datetime.date(2015, 4, 16),
#  datetime.date(2023, 8, 25),
#  datetime.date(2015, 10, 22),
#  datetime.date(2021, 10, 4),
#  datetime.date(2023, 9, 19),
#  datetime.date(2015, 7, 27),
#  datetime.date(2024, 8, 27),
#  datetime.date(2022, 2, 18),
#  datetime.date(2017, 4, 27),
#  datetime.date(2023, 1, 5),
#  datetime.date(2016, 4, 6),
#  datetime.date(2015, 5, 14),
#  datetime.date(2021, 9, 8),
#  datetime.date(2019, 6, 12),
#  datetime.date(2020, 6, 29),
#  datetime.date(2020, 2, 24),
#  datetime.date(2021, 5, 27),
#  datetime.date(2023, 9, 21),
#  datetime.date(2021, 3, 9),
#  datetime.date(2023, 11, 8),
#  datetime.date(2022, 7, 12),
#  datetime.date(2023, 12, 6),
#  datetime.date(2023, 3, 30),
#  datetime.date(2016, 10, 11),
#  datetime.date(2023, 6, 22),
#  datetime.date(2015, 6, 1),
#  datetime.date(2016, 5, 27),
#  datetime.date(2021, 10, 6),
#  datetime.date(2017, 12, 18),
#  datetime.date(2018, 5, 17),
#  datetime.date(2017, 8, 25),
#  datetime.date(2017, 7, 7),
#  datetime.date(2023, 7, 4),
#  datetime.date(2017, 5, 10),
#  datetime.date(2015, 4, 14),
#  datetime.date(2015, 6, 26),
#  datetime.date(2022, 5, 26),
#  datetime.date(2024, 5, 1),
#  datetime.date(2018, 6, 12),
#  datetime.date(2017, 9, 1),
#  datetime.date(2019, 4, 26),
#  datetime.date(2024, 1, 31),
#  datetime.date(2024, 4, 3),
#  datetime.date(2023, 11, 7),
#  datetime.date(2020, 1, 23),
#  datetime.date(2022, 12, 19),
#  datetime.date(2017, 4, 3),
#  datetime.date(2022, 1, 14),
#  datetime.date(2022, 9, 29),
#  datetime.date(2022, 4, 26),
#  datetime.date(2017, 9, 25),
#  datetime.date(2017, 11, 29),
#  datetime.date(2019, 11, 28),
#  datetime.date(2022, 7, 22),
#  datetime.date(2016, 12, 15),
#  datetime.date(2021, 2, 4),
#  datetime.date(2022, 6, 30),
#  datetime.date(2017, 7, 3),
#  datetime.date(2021, 2, 19),
#  datetime.date(2015, 7, 9),
#  datetime.date(2020, 4, 28),
#  datetime.date(2017, 5, 3),
#  datetime.date(2015, 9, 16),
#  datetime.date(2018, 9, 26),
#  datetime.date(2018, 7, 12),
#  datetime.date(2024, 9, 27),
#  datetime.date(2018, 7, 19),
#  datetime.date(2022, 6, 29),
#  datetime.date(2022, 11, 15),
#  datetime.date(2018, 6, 1),
#  datetime.date(2023, 8, 14),
#  datetime.date(2021, 10, 18),
#  datetime.date(2018, 7, 4),
#  datetime.date(2016, 8, 10),
#  datetime.date(2016, 11, 18),
#  datetime.date(2022, 12, 7),
#  datetime.date(2020, 9, 4),
#  datetime.date(2018, 8, 7),
#  datetime.date(2024, 10, 3),
#  datetime.date(2022, 2, 11),
#  datetime.date(2017, 3, 28),
#  datetime.date(2023, 5, 5),
#  datetime.date(2016, 9, 14),
#  datetime.date(2024, 9, 10),
#  datetime.date(2023, 6, 6),
#  datetime.date(2023, 7, 7),
#  datetime.date(2019, 9, 16),
#  datetime.date(2018, 6, 27),
#  datetime.date(2022, 1, 3),
#  datetime.date(2021, 3, 5),
#  datetime.date(2018, 6, 25),
#  datetime.date(2017, 3, 7),
#  datetime.date(2018, 9, 25),
#  datetime.date(2020, 12, 2),
#  datetime.date(2018, 10, 29),
#  datetime.date(2023, 12, 29),
#  datetime.date(2024, 6, 5),
#  datetime.date(2020, 12, 14),
#  datetime.date(2022, 9, 13),
#  datetime.date(2020, 7, 23),
#  datetime.date(2024, 1, 11),
#  datetime.date(2024, 3, 15),
#  datetime.date(2024, 5, 22),
#  datetime.date(2020, 7, 28),
#  datetime.date(2015, 11, 16),
#  datetime.date(2022, 9, 21),
#  datetime.date(2023, 1, 12),
#  datetime.date(2023, 8, 11),
#  datetime.date(2023, 8, 24),
#  datetime.date(2023, 4, 14),
#  datetime.date(2023, 3, 23),
#  datetime.date(2016, 8, 12),
#  datetime.date(2020, 4, 24),
#  datetime.date(2015, 8, 5),
#  datetime.date(2015, 4, 29),
#  datetime.date(2018, 10, 3),
#  datetime.date(2019, 10, 22),
#  datetime.date(2022, 11, 21),
#  datetime.date(2016, 2, 3),
#  datetime.date(2021, 5, 28),
#  datetime.date(2016, 8, 1),
#  datetime.date(2020, 7, 14),
#  datetime.date(2022, 12, 27),
#  datetime.date(2023, 12, 27),
#  datetime.date(2016, 4, 8),
#  datetime.date(2015, 5, 13),
#  datetime.date(2017, 6, 7),
#  datetime.date(2018, 10, 25),
#  datetime.date(2024, 8, 1),
#  datetime.date(2015, 10, 28),
#  datetime.date(2015, 6, 10),
#  datetime.date(2022, 6, 7),
#  datetime.date(2022, 9, 9),
#  datetime.date(2022, 8, 1),
#  datetime.date(2018, 7, 3),
#  datetime.date(2019, 3, 13),
#  datetime.date(2021, 4, 15),
#  datetime.date(2023, 8, 22),
#  datetime.date(2019, 9, 5),
#  datetime.date(2015, 7, 21),
#  datetime.date(2021, 6, 9),
#  datetime.date(2024, 1, 25),
#  datetime.date(2015, 7, 22),
#  datetime.date(2019, 5, 27),
#  datetime.date(2023, 10, 20),
#  datetime.date(2022, 3, 23),
#  datetime.date(2019, 10, 17),
#  datetime.date(2024, 5, 10),
#  datetime.date(2022, 4, 29),
#  datetime.date(2018, 4, 17),
#  datetime.date(2015, 11, 11),
#  datetime.date(2022, 12, 15),
#  datetime.date(2023, 5, 30),
#  datetime.date(2017, 1, 19),
#  datetime.date(2019, 5, 7),
#  datetime.date(2016, 6, 6),
#  datetime.date(2023, 8, 30),
#  datetime.date(2020, 3, 31),
#  datetime.date(2019, 1, 16),
#  datetime.date(2019, 9, 13),
#  datetime.date(2023, 2, 22),
#  datetime.date(2017, 3, 31),
#  datetime.date(2017, 3, 24),
#  datetime.date(2022, 7, 7),
#  datetime.date(2021, 7, 1),
#  datetime.date(2016, 3, 10),
#  datetime.date(2016, 2, 24),
#  datetime.date(2023, 11, 15),
#  datetime.date(2021, 7, 28),
#  datetime.date(2022, 12, 21),
#  datetime.date(2018, 1, 29),
#  datetime.date(2024, 4, 5),
#  datetime.date(2019, 2, 20),
#  datetime.date(2018, 10, 22),
#  datetime.date(2019, 11, 25),
#  datetime.date(2020, 6, 24),
#  datetime.date(2022, 9, 27),
#  datetime.date(2021, 5, 21),
#  datetime.date(2023, 2, 8),
#  datetime.date(2017, 9, 7),
#  datetime.date(2018, 11, 12),
#  datetime.date(2019, 11, 11),
#  datetime.date(2021, 12, 14),
#  datetime.date(2019, 2, 25),
#  datetime.date(2024, 8, 19),
#  datetime.date(2016, 6, 17),
#  datetime.date(2024, 9, 13),
#  datetime.date(2019, 3, 15),
#  datetime.date(2017, 8, 8),
#  datetime.date(2023, 12, 12),
#  datetime.date(2017, 10, 11),
#  datetime.date(2021, 7, 30),
#  datetime.date(2019, 7, 4),
#  datetime.date(2016, 4, 27),
#  datetime.date(2019, 6, 13),
#  datetime.date(2021, 8, 6),
#  datetime.date(2023, 6, 20),
#  datetime.date(2024, 4, 23),
#  datetime.date(2019, 1, 30),
#  datetime.date(2018, 9, 7),
#  datetime.date(2021, 3, 31),
#  datetime.date(2016, 10, 5),
#  datetime.date(2024, 1, 1),
#  datetime.date(2019, 8, 2),
#  datetime.date(2019, 10, 28),
#  datetime.date(2020, 7, 10),
#  datetime.date(2020, 1, 22),
#  datetime.date(2023, 9, 8),
#  datetime.date(2017, 10, 9),
#  datetime.date(2018, 4, 6),
#  datetime.date(2020, 2, 17),
#  datetime.date(2019, 12, 17),
#  datetime.date(2022, 5, 20),
#  datetime.date(2022, 8, 24),
#  datetime.date(2024, 3, 20),
#  datetime.date(2018, 12, 18),
#  datetime.date(2016, 6, 9),
#  datetime.date(2016, 10, 26),
#  datetime.date(2019, 4, 23),
#  datetime.date(2024, 10, 7),
#  datetime.date(2019, 2, 21),
#  datetime.date(2023, 9, 22),
#  datetime.date(2022, 2, 25),
#  datetime.date(2019, 11, 18),
#  datetime.date(2015, 5, 6),
#  datetime.date(2016, 8, 4),
#  datetime.date(2021, 11, 11),
#  datetime.date(2024, 7, 19),
#  datetime.date(2020, 10, 16),
#  datetime.date(2018, 11, 26),
#  datetime.date(2024, 4, 26),
#  datetime.date(2020, 12, 15),
#  datetime.date(2020, 2, 18),
#  datetime.date(2019, 8, 28),
#  datetime.date(2024, 7, 29),
#  datetime.date(2022, 4, 1),
#  datetime.date(2022, 8, 4),
#  datetime.date(2019, 7, 19),
#  datetime.date(2018, 4, 26),
#  datetime.date(2020, 2, 26),
#  datetime.date(2022, 3, 14),
#  datetime.date(2019, 10, 3),
#  datetime.date(2024, 7, 8),
#  datetime.date(2023, 12, 20),
#  datetime.date(2019, 6, 5),
#  datetime.date(2023, 3, 28),
#  datetime.date(2019, 9, 25),
#  datetime.date(2021, 2, 22),
#  datetime.date(2017, 8, 2),
#  datetime.date(2019, 10, 8),
#  datetime.date(2021, 8, 2),
#  datetime.date(2017, 8, 1),
#  datetime.date(2023, 7, 14),
#  datetime.date(2017, 9, 20),
#  datetime.date(2024, 8, 16),
#  datetime.date(2017, 6, 29),
#  datetime.date(2020, 1, 13),
#  datetime.date(2018, 6, 19),
#  datetime.date(2016, 7, 6),
#  datetime.date(2020, 5, 20),
#  datetime.date(2022, 12, 9),
#  datetime.date(2016, 5, 19),
#  datetime.date(2020, 12, 23),
#  datetime.date(2024, 5, 31),
#  datetime.date(2015, 5, 4),
#  datetime.date(2024, 1, 24),
#  datetime.date(2021, 2, 2),
#  datetime.date(2023, 2, 16),
#  datetime.date(2023, 1, 4),
#  datetime.date(2016, 5, 13),
#  datetime.date(2019, 12, 24),
#  datetime.date(2020, 8, 4),
#  datetime.date(2021, 11, 16),
#  datetime.date(2016, 12, 16),
#  datetime.date(2022, 2, 9),
#  datetime.date(2020, 8, 28),
#  datetime.date(2016, 3, 9),
#  datetime.date(2021, 10, 28),
#  datetime.date(2016, 2, 16),
#  datetime.date(2015, 3, 9),
#  datetime.date(2019, 9, 9),
#  datetime.date(2016, 9, 12),
#  datetime.date(2020, 5, 4),
#  datetime.date(2023, 8, 3),
#  datetime.date(2016, 10, 6),
#  datetime.date(2016, 1, 22),
#  datetime.date(2016, 11, 30),
#  datetime.date(2016, 7, 7),
#  datetime.date(2021, 2, 17),
#  datetime.date(2018, 11, 14),
#  datetime.date(2018, 7, 18),
#  datetime.date(2024, 4, 17),
#  datetime.date(2016, 7, 14),
#  datetime.date(2019, 2, 19),
#  datetime.date(2019, 3, 6),
#  datetime.date(2017, 2, 15),
#  datetime.date(2021, 12, 9),
#  datetime.date(2022, 6, 23),
#  datetime.date(2018, 1, 31),
#  datetime.date(2020, 5, 22),
#  datetime.date(2015, 12, 29),
#  datetime.date(2021, 6, 29),
#  datetime.date(2015, 9, 8),
#  datetime.date(2017, 12, 29),
#  datetime.date(2024, 4, 18),
#  datetime.date(2016, 3, 22),
#  datetime.date(2019, 7, 23),
#  datetime.date(2021, 7, 22),
#  datetime.date(2020, 8, 17),
#  datetime.date(2017, 10, 27),
#  datetime.date(2017, 9, 12),
#  datetime.date(2020, 7, 15),
#  datetime.date(2018, 5, 16),
#  datetime.date(2024, 8, 5),
#  datetime.date(2024, 6, 24),
#  datetime.date(2022, 8, 17),
#  datetime.date(2022, 3, 16),
#  datetime.date(2017, 5, 19),
#  datetime.date(2018, 9, 6),
#  datetime.date(2023, 9, 1),
#  datetime.date(2015, 12, 9),
#  datetime.date(2022, 6, 27),
#  datetime.date(2019, 7, 9),
#  datetime.date(2021, 10, 14),
#  datetime.date(2021, 5, 25),
#  datetime.date(2018, 9, 3),
#  datetime.date(2024, 6, 28),
#  datetime.date(2024, 2, 21),
#  datetime.date(2024, 5, 2),
#  datetime.date(2015, 7, 30),
#  datetime.date(2019, 9, 30),
#  datetime.date(2016, 2, 25),
#  datetime.date(2020, 4, 15),
#  datetime.date(2022, 7, 11),
#  datetime.date(2018, 6, 4),
#  datetime.date(2024, 2, 2),
#  datetime.date(2021, 7, 7),
#  datetime.date(2019, 3, 12),
#  datetime.date(2015, 12, 2),
#  datetime.date(2020, 1, 6),
#  datetime.date(2024, 3, 1),
#  datetime.date(2021, 9, 13),
#  datetime.date(2023, 12, 28),
#  datetime.date(2015, 4, 28),
#  datetime.date(2018, 6, 21),
#  datetime.date(2022, 11, 4),
#  datetime.date(2022, 10, 19),
#  datetime.date(2022, 7, 27),
#  datetime.date(2023, 4, 18),
#  datetime.date(2016, 1, 8),
#  datetime.date(2015, 4, 22),
#  datetime.date(2018, 8, 6),
#  datetime.date(2023, 9, 6),
#  datetime.date(2018, 8, 21),
#  datetime.date(2022, 3, 10),
#  datetime.date(2024, 6, 21),
#  datetime.date(2024, 7, 23),
#  datetime.date(2019, 9, 3),
#  datetime.date(2015, 7, 10),
#  datetime.date(2019, 1, 9),
#  datetime.date(2022, 10, 6),
#  datetime.date(2023, 5, 25),
#  datetime.date(2020, 3, 17),
#  datetime.date(2021, 1, 14),
#  datetime.date(2023, 1, 19),
#  datetime.date(2016, 9, 15),
#  datetime.date(2020, 12, 16),
#  datetime.date(2016, 2, 26),
#  datetime.date(2021, 12, 30),
#  datetime.date(2017, 6, 22),
#  datetime.date(2019, 11, 5),
#  datetime.date(2024, 8, 12),
#  datetime.date(2024, 4, 29),
#  datetime.date(2018, 4, 9),
#  datetime.date(2015, 3, 26),
#  datetime.date(2019, 10, 15),
#  datetime.date(2017, 12, 13),
#  datetime.date(2023, 8, 21),
#  datetime.date(2015, 3, 27),
#  datetime.date(2024, 3, 13),
#  datetime.date(2024, 9, 25),
#  datetime.date(2022, 7, 5),
#  datetime.date(2016, 1, 18),
#  datetime.date(2022, 4, 25),
#  datetime.date(2017, 10, 13),
#  datetime.date(2017, 3, 21),
#  datetime.date(2019, 11, 21),
#  datetime.date(2024, 8, 29),
#  datetime.date(2024, 6, 13),
#  datetime.date(2022, 8, 29),
#  datetime.date(2022, 9, 28),
#  datetime.date(2019, 7, 2),
#  datetime.date(2018, 1, 19),
#  datetime.date(2019, 11, 26),
#  datetime.date(2023, 3, 8),
#  datetime.date(2017, 2, 14),
#  datetime.date(2019, 1, 7),
#  datetime.date(2024, 9, 9),
#  datetime.date(2018, 10, 10),
#  datetime.date(2018, 4, 30),
#  datetime.date(2020, 11, 16),
#  datetime.date(2015, 3, 25),
#  datetime.date(2022, 6, 3),
#  datetime.date(2022, 6, 24),
#  datetime.date(2023, 6, 21),
#  datetime.date(2016, 12, 20),
#  datetime.date(2023, 4, 17),
#  datetime.date(2023, 10, 30),
#  datetime.date(2019, 5, 17),
#  datetime.date(2018, 8, 24),
#  datetime.date(2019, 10, 7),
#  datetime.date(2020, 7, 13),
#  datetime.date(2023, 7, 27),
#  datetime.date(2016, 12, 1),
#  datetime.date(2017, 4, 5),
#  datetime.date(2024, 3, 27),
#  datetime.date(2022, 3, 29),
#  datetime.date(2024, 5, 16),
#  datetime.date(2015, 8, 24),
#  datetime.date(2018, 8, 28),
#  datetime.date(2021, 7, 20),
#  datetime.date(2024, 6, 18),
#  datetime.date(2018, 2, 20),
#  datetime.date(2015, 9, 23),
#  datetime.date(2022, 12, 26),
#  datetime.date(2024, 5, 29),
#  datetime.date(2017, 10, 24),
#  datetime.date(2021, 3, 11),
#  datetime.date(2024, 4, 24),
#  datetime.date(2023, 1, 25),
#  datetime.date(2017, 3, 15),
#  datetime.date(2022, 4, 28),
#  datetime.date(2021, 9, 30),
#  datetime.date(2024, 9, 26),
#  datetime.date(2020, 7, 17),
#  datetime.date(2023, 1, 6),
#  datetime.date(2020, 12, 17),
#  datetime.date(2019, 5, 1),
#  datetime.date(2018, 1, 25),
#  datetime.date(2018, 3, 23),
#  datetime.date(2016, 2, 17),
#  datetime.date(2019, 10, 23),
#  datetime.date(2019, 6, 4),
#  datetime.date(2016, 3, 3),
#  datetime.date(2017, 6, 15),
#  datetime.date(2019, 3, 11),
#  datetime.date(2024, 6, 11),
#  datetime.date(2024, 1, 22),
#  datetime.date(2021, 12, 22),
#  datetime.date(2020, 8, 20),
#  datetime.date(2016, 5, 23),
#  datetime.date(2018, 9, 10),
#  datetime.date(2019, 12, 18),
#  datetime.date(2021, 1, 29),
#  datetime.date(2017, 12, 28),
#  datetime.date(2024, 3, 26),
#  datetime.date(2023, 1, 20),
#  datetime.date(2019, 11, 1),
#  datetime.date(2023, 9, 27),
#  datetime.date(2019, 9, 11),
#  datetime.date(2017, 6, 14),
#  datetime.date(2019, 6, 17),
#  datetime.date(2024, 4, 22),
#  datetime.date(2023, 1, 18),
#  datetime.date(2024, 7, 17),
#  datetime.date(2015, 7, 29),
#  datetime.date(2022, 11, 7),
#  datetime.date(2019, 6, 20),
#  datetime.date(2018, 2, 21),
#  datetime.date(2024, 6, 7),
#  datetime.date(2018, 4, 27),
#  datetime.date(2023, 6, 13),
#  datetime.date(2023, 7, 21),
#  datetime.date(2020, 2, 5),
#  datetime.date(2020, 7, 31),
#  datetime.date(2016, 6, 10),
#  datetime.date(2021, 4, 6),
#  datetime.date(2020, 7, 21),
#  datetime.date(2021, 12, 27),
#  datetime.date(2015, 4, 1),
#  datetime.date(2018, 2, 22),
#  datetime.date(2018, 5, 4),
#  datetime.date(2015, 6, 15),
#  datetime.date(2024, 2, 7),
#  datetime.date(2021, 9, 6),
#  datetime.date(2021, 6, 11),
#  datetime.date(2022, 6, 15),
#  datetime.date(2018, 9, 12),
#  datetime.date(2019, 1, 8),
#  datetime.date(2021, 11, 18),
#  datetime.date(2019, 5, 3),
#  datetime.date(2017, 5, 18),
#  datetime.date(2021, 6, 24),
#  datetime.date(2019, 10, 1),
#  datetime.date(2015, 6, 29),
#  datetime.date(2015, 11, 20),
#  datetime.date(2015, 11, 9),
#  datetime.date(2016, 11, 15),
#  datetime.date(2020, 9, 10),
#  datetime.date(2016, 12, 21),
#  datetime.date(2018, 4, 13),
#  datetime.date(2023, 9, 13),
#  datetime.date(2019, 3, 27),
#  datetime.date(2016, 4, 4),
#  datetime.date(2020, 8, 7),
#  datetime.date(2019, 1, 18),
#  datetime.date(2018, 12, 21),
#  datetime.date(2019, 1, 10),
#  datetime.date(2022, 4, 6),
#  datetime.date(2021, 12, 13),
#  datetime.date(2022, 11, 1),
#  datetime.date(2016, 3, 11),
#  datetime.date(2021, 1, 1),
#  datetime.date(2019, 9, 4),
#  datetime.date(2018, 12, 13),
#  datetime.date(2023, 8, 29),
#  datetime.date(2017, 10, 17),
#  datetime.date(2015, 9, 18),
#  datetime.date(2019, 12, 4),
#  datetime.date(2021, 1, 20),
#  datetime.date(2017, 3, 14),
#  datetime.date(2018, 4, 19),
#  datetime.date(2017, 10, 30),
#  datetime.date(2018, 6, 15),
#  datetime.date(2015, 3, 11),
#  datetime.date(2015, 4, 27),
#  datetime.date(2023, 12, 21),
#  datetime.date(2018, 7, 31),
#  datetime.date(2016, 10, 20),
#  datetime.date(2020, 10, 8),
#  datetime.date(2021, 7, 21),
#  datetime.date(2017, 7, 24),
#  datetime.date(2023, 5, 8),
#  datetime.date(2017, 2, 17),
#  datetime.date(2022, 6, 13),
#  datetime.date(2023, 11, 21),
#  datetime.date(2016, 2, 18),
#  datetime.date(2019, 12, 30),
#  datetime.date(2018, 8, 8),
#  datetime.date(2020, 7, 1),
#  datetime.date(2021, 6, 14),
#  datetime.date(2021, 5, 6),
#  datetime.date(2022, 10, 11),
#  datetime.date(2015, 9, 29),
#  datetime.date(2015, 7, 31),
#  datetime.date(2021, 2, 15),
#  datetime.date(2018, 8, 22),
#  datetime.date(2021, 11, 23),
#  datetime.date(2024, 2, 29),
#  datetime.date(2017, 11, 20),
#  datetime.date(2022, 10, 14),
#  datetime.date(2023, 12, 26),
#  datetime.date(2019, 5, 30),
#  datetime.date(2022, 4, 12),
#  datetime.date(2021, 9, 3),
#  datetime.date(2019, 4, 22),
#  datetime.date(2015, 11, 13),
#  datetime.date(2024, 4, 2),
#  datetime.date(2022, 11, 18),
#  datetime.date(2017, 10, 20),
#  datetime.date(2018, 4, 23),
#  datetime.date(2015, 10, 7),
#  datetime.date(2023, 6, 26),
#  datetime.date(2020, 6, 8),
#  datetime.date(2021, 3, 3),
#  datetime.date(2016, 9, 6),
#  datetime.date(2022, 9, 12),
#  datetime.date(2020, 8, 14),
#  datetime.date(2017, 5, 25),
#  datetime.date(2021, 3, 8),
#  datetime.date(2016, 3, 21),
#  datetime.date(2018, 5, 15),
#  datetime.date(2018, 3, 21),
#  datetime.date(2024, 5, 28),
#  datetime.date(2020, 11, 4),
#  datetime.date(2020, 8, 6),
#  datetime.date(2017, 9, 6),
#  datetime.date(2015, 6, 2),
#  datetime.date(2015, 5, 26),
#  datetime.date(2020, 2, 19),
#  datetime.date(2017, 10, 31),
#  datetime.date(2017, 2, 16),
#  datetime.date(2015, 6, 19),
#  datetime.date(2020, 3, 26),
#  datetime.date(2021, 1, 6),
#  datetime.date(2023, 6, 12),
#  datetime.date(2023, 7, 6),
#  datetime.date(2020, 10, 12),
#  datetime.date(2024, 5, 24),
#  datetime.date(2019, 3, 7),
#  datetime.date(2023, 9, 25),
#  datetime.date(2018, 7, 23),
#  datetime.date(2022, 4, 5),
#  datetime.date(2023, 5, 23),
#  datetime.date(2016, 4, 7),
#  datetime.date(2019, 10, 4),
#  datetime.date(2018, 3, 12),
#  datetime.date(2016, 5, 5),
#  datetime.date(2017, 7, 27),
#  datetime.date(2021, 7, 16),
#  datetime.date(2018, 12, 27),
#  datetime.date(2016, 11, 16),
#  datetime.date(2015, 9, 21),
#  datetime.date(2019, 3, 28),
#  datetime.date(2016, 6, 27),
#  datetime.date(2021, 1, 25),
#  datetime.date(2023, 7, 26),
#  datetime.date(2021, 5, 5),
#  datetime.date(2023, 12, 5),
#  datetime.date(2015, 11, 18),
#  datetime.date(2020, 12, 9),
#  datetime.date(2023, 7, 12),
#  datetime.date(2020, 10, 5),
#  datetime.date(2022, 9, 20),
#  datetime.date(2018, 3, 19),
#  datetime.date(2019, 8, 30),
#  datetime.date(2019, 4, 30),
#  datetime.date(2016, 10, 12),
#  datetime.date(2018, 10, 30),
#  datetime.date(2016, 10, 4),
#  datetime.date(2015, 11, 5),
#  datetime.date(2019, 5, 20),
#  datetime.date(2020, 8, 18),
#  datetime.date(2017, 9, 4),
#  datetime.date(2020, 1, 21),
#  datetime.date(2019, 9, 12),
#  datetime.date(2023, 11, 6),
#  datetime.date(2021, 12, 2),
#  datetime.date(2023, 10, 24),
#  datetime.date(2023, 5, 3),
#  datetime.date(2016, 3, 14),
#  datetime.date(2022, 8, 5),
#  datetime.date(2019, 3, 18),
#  datetime.date(2019, 11, 7),
#  datetime.date(2024, 9, 23),
#  datetime.date(2018, 4, 3),
#  datetime.date(2017, 3, 2),
#  datetime.date(2018, 2, 5),
#  datetime.date(2017, 11, 17),
#  datetime.date(2015, 12, 23),
#  datetime.date(2020, 6, 11),
#  datetime.date(2020, 1, 17),
#  datetime.date(2022, 6, 8),
#  datetime.date(2021, 12, 10),
#  datetime.date(2023, 1, 11),
#  datetime.date(2023, 4, 28),
#  datetime.date(2021, 10, 15),
#  datetime.date(2022, 4, 13),
#  datetime.date(2020, 3, 27),
#  datetime.date(2021, 6, 15),
#  datetime.date(2021, 3, 12),
#  datetime.date(2016, 3, 28),
#  datetime.date(2022, 5, 27),
#  datetime.date(2020, 2, 28),
#  datetime.date(2017, 4, 18),
#  datetime.date(2022, 3, 8),
#  datetime.date(2022, 3, 17),
#  datetime.date(2022, 6, 14),
#  datetime.date(2015, 10, 29),
#  datetime.date(2022, 5, 12),
#  datetime.date(2016, 9, 7),
#  datetime.date(2016, 5, 6),
#  datetime.date(2015, 10, 19),
#  datetime.date(2018, 2, 2),
#  datetime.date(2015, 9, 10),
#  datetime.date(2020, 7, 2),
#  datetime.date(2015, 3, 12),
#  datetime.date(2018, 8, 1),
#  datetime.date(2023, 8, 2),
#  datetime.date(2024, 4, 30),
#  datetime.date(2017, 5, 9),
#  datetime.date(2022, 5, 11),
#  datetime.date(2015, 3, 3),
#  datetime.date(2017, 3, 8),
#  datetime.date(2024, 8, 28),
#  datetime.date(2021, 11, 5),
#  datetime.date(2022, 10, 10),
#  datetime.date(2019, 2, 26),
#  datetime.date(2021, 3, 2),
#  datetime.date(2024, 10, 4),
#  datetime.date(2019, 4, 9),
#  datetime.date(2015, 9, 17),
#  datetime.date(2016, 9, 5),
#  datetime.date(2023, 5, 24),
#  datetime.date(2023, 3, 15),
#  datetime.date(2022, 2, 3),
#  datetime.date(2018, 9, 17),
#  datetime.date(2017, 11, 13),
#  datetime.date(2015, 12, 14),
#  datetime.date(2023, 4, 6),
#  datetime.date(2019, 2, 27),
#  datetime.date(2022, 11, 3),
#  datetime.date(2022, 3, 11),
#  datetime.date(2021, 7, 19),
#  datetime.date(2024, 1, 16),
#  datetime.date(2024, 7, 9),
#  datetime.date(2020, 12, 31),
#  datetime.date(2021, 7, 23),
#  datetime.date(2020, 4, 21),
#  datetime.date(2019, 6, 26),
#  datetime.date(2017, 8, 10),
#  datetime.date(2021, 4, 14),
#  datetime.date(2017, 3, 22),
#  datetime.date(2019, 12, 26),
#  datetime.date(2018, 5, 21),
#  datetime.date(2023, 11, 27),
#  datetime.date(2015, 8, 10),
#  datetime.date(2023, 6, 23),
#  datetime.date(2019, 6, 3),
#  datetime.date(2015, 4, 23),
#  datetime.date(2017, 12, 12),
#  datetime.date(2019, 7, 26),
#  datetime.date(2015, 10, 6),
#  datetime.date(2022, 7, 28),
#  datetime.date(2021, 5, 14),
#  datetime.date(2022, 6, 6),
#  datetime.date(2018, 2, 6),
#  datetime.date(2024, 6, 10),
#  datetime.date(2024, 2, 23),
#  datetime.date(2017, 11, 1),
#  datetime.date(2019, 1, 1),
#  datetime.date(2016, 6, 23),
#  datetime.date(2022, 2, 28),
#  datetime.date(2018, 10, 8),
#  datetime.date(2016, 10, 7),
#  datetime.date(2024, 8, 6),
#  datetime.date(2015, 7, 24),
#  datetime.date(2023, 2, 13),
#  datetime.date(2019, 3, 5),
#  datetime.date(2019, 1, 21),
#  datetime.date(2022, 3, 1),
#  datetime.date(2017, 10, 5),
#  datetime.date(2024, 6, 14),
#  datetime.date(2020, 3, 19),
#  datetime.date(2021, 9, 23),
#  datetime.date(2020, 5, 12),
#  datetime.date(2019, 9, 17),
#  datetime.date(2016, 9, 2),
#  datetime.date(2018, 9, 11),
#  datetime.date(2020, 6, 19),
#  datetime.date(2023, 6, 19),
#  datetime.date(2018, 1, 15),
#  datetime.date(2015, 6, 12),
#  datetime.date(2022, 3, 31),
#  datetime.date(2015, 7, 7),
#  datetime.date(2015, 10, 13),
#  datetime.date(2024, 7, 5),
#  datetime.date(2021, 1, 27),
#  datetime.date(2023, 4, 12),
#  datetime.date(2022, 8, 25),
#  datetime.date(2024, 5, 21),
#  datetime.date(2022, 8, 19),
#  datetime.date(2023, 5, 26),
#  datetime.date(2024, 1, 30),
#  datetime.date(2018, 7, 17),
#  datetime.date(2019, 11, 20),
#  datetime.date(2017, 3, 10),
#  datetime.date(2019, 4, 2),
#  datetime.date(2018, 1, 11),
#  datetime.date(2017, 7, 25),
#  datetime.date(2021, 11, 12),
#  datetime.date(2018, 3, 20),
#  datetime.date(2024, 2, 12),
#  datetime.date(2018, 8, 30),
#  datetime.date(2019, 4, 25),
#  datetime.date(2015, 12, 11),
#  datetime.date(2018, 1, 18),
#  datetime.date(2016, 2, 9),
#  datetime.date(2021, 3, 4),
#  datetime.date(2017, 12, 1),
#  datetime.date(2020, 10, 26),
#  datetime.date(2023, 3, 20),
#  datetime.date(2016, 7, 8),
#  datetime.date(2021, 10, 8),
#  datetime.date(2016, 2, 5),
#  datetime.date(2015, 3, 24),
#  datetime.date(2020, 6, 15),
#  datetime.date(2020, 2, 25),
#  datetime.date(2016, 12, 13),
#  datetime.date(2020, 4, 3),
#  datetime.date(2022, 1, 13),
#  datetime.date(2022, 11, 23),
#  datetime.date(2022, 10, 31),
#  datetime.date(2018, 6, 7),
#  datetime.date(2015, 5, 7),
#  datetime.date(2015, 12, 15),
#  datetime.date(2016, 5, 4),
#  datetime.date(2018, 12, 3),
#  datetime.date(2017, 3, 29),
#  datetime.date(2015, 7, 3),
#  datetime.date(2024, 1, 3),
#  datetime.date(2021, 1, 19),
#  datetime.date(2020, 5, 11),
#  datetime.date(2019, 7, 22),
#  datetime.date(2018, 2, 9),
#  datetime.date(2015, 8, 14),
#  datetime.date(2021, 8, 11),
#  datetime.date(2022, 2, 16),
#  datetime.date(2017, 11, 15),
#  datetime.date(2023, 11, 14),
#  datetime.date(2017, 2, 1),
#  datetime.date(2016, 11, 3),
#  datetime.date(2019, 8, 23),
#  datetime.date(2017, 3, 17),
#  datetime.date(2018, 6, 22),
#  datetime.date(2018, 9, 5),
#  datetime.date(2022, 2, 10),
#  datetime.date(2016, 2, 2),
#  datetime.date(2017, 1, 9),
#  datetime.date(2021, 8, 23),
#  datetime.date(2015, 6, 8),
#  datetime.date(2018, 5, 22),
#  datetime.date(2020, 10, 14),
#  datetime.date(2021, 3, 24),
#  datetime.date(2015, 9, 14),
#  datetime.date(2021, 7, 26),
#  datetime.date(2019, 4, 10),
#  datetime.date(2020, 3, 20),
#  datetime.date(2017, 5, 15),
#  datetime.date(2017, 6, 27),
#  datetime.date(2020, 2, 14),
#  datetime.date(2020, 4, 27),
#  datetime.date(2023, 11, 3),
#  datetime.date(2021, 6, 4),
#  datetime.date(2024, 9, 24),
#  datetime.date(2021, 6, 16),
#  datetime.date(2020, 9, 25),
#  datetime.date(2019, 7, 5),
#  datetime.date(2016, 2, 11),
#  datetime.date(2016, 9, 26),
#  datetime.date(2015, 6, 16),
#  datetime.date(2020, 3, 18),
#  datetime.date(2023, 2, 3),
#  datetime.date(2024, 2, 8),
#  datetime.date(2023, 12, 19),
#  datetime.date(2015, 12, 22),
#  datetime.date(2017, 11, 27),
#  datetime.date(2016, 1, 13),
#  datetime.date(2015, 9, 30),
#  datetime.date(2018, 5, 1),
#  datetime.date(2015, 9, 22),
#  datetime.date(2021, 11, 8),
#  datetime.date(2016, 11, 9),
#  datetime.date(2015, 8, 27),
#  datetime.date(2019, 6, 7),
#  datetime.date(2023, 2, 6),
#  datetime.date(2018, 11, 22),
#  datetime.date(2016, 2, 22),
#  datetime.date(2024, 1, 2),
#  datetime.date(2015, 6, 30),
#  datetime.date(2017, 1, 4),
#  datetime.date(2021, 6, 23),
#  datetime.date(2020, 6, 17),
#  datetime.date(2024, 6, 17),
#  datetime.date(2019, 2, 8),
#  datetime.date(2024, 1, 18),
#  datetime.date(2020, 9, 11),
#  datetime.date(2016, 8, 2),
#  datetime.date(2023, 12, 8),
#  datetime.date(2019, 5, 22),
#  datetime.date(2023, 2, 20),
#  datetime.date(2019, 10, 9),
#  datetime.date(2017, 12, 11),
#  datetime.date(2019, 12, 16),
#  datetime.date(2022, 11, 11),
#  datetime.date(2022, 8, 2),
#  datetime.date(2018, 1, 24),
#  datetime.date(2017, 10, 4),
#  datetime.date(2022, 5, 10),
#  datetime.date(2022, 1, 4),
#  datetime.date(2016, 12, 14),
#  datetime.date(2021, 7, 14),
#  datetime.date(2019, 11, 13),
#  datetime.date(2023, 10, 23),
#  datetime.date(2016, 4, 26),
#  datetime.date(2022, 8, 30),
#  datetime.date(2019, 9, 20),
#  datetime.date(2018, 2, 27),
#  datetime.date(2018, 4, 20),
#  datetime.date(2020, 12, 10),
#  datetime.date(2017, 5, 30),
#  datetime.date(2022, 1, 10),
#  datetime.date(2016, 3, 24),
#  datetime.date(2016, 3, 8),
#  datetime.date(2022, 9, 5),
#  datetime.date(2016, 6, 1),
#  datetime.date(2017, 1, 5),
#  datetime.date(2020, 9, 16),
#  datetime.date(2020, 4, 17),
#  datetime.date(2020, 6, 30),
#  datetime.date(2021, 8, 30),
#  datetime.date(2021, 8, 10),
#  datetime.date(2018, 7, 24),
#  datetime.date(2019, 7, 1),
#  datetime.date(2021, 6, 10),
#  datetime.date(2021, 2, 3),
#  datetime.date(2015, 12, 17),
#  datetime.date(2023, 2, 1),
#  datetime.date(2019, 7, 15),
#  datetime.date(2021, 8, 9),
#  datetime.date(2021, 1, 11),
#  datetime.date(2019, 10, 11),
#  datetime.date(2017, 4, 12),
#  datetime.date(2018, 2, 15),
#  datetime.date(2019, 11, 22),
#  datetime.date(2022, 5, 30),
#  datetime.date(2016, 7, 11),
#  datetime.date(2017, 7, 26),
#  datetime.date(2021, 4, 13),
#  datetime.date(2019, 3, 14),
#  datetime.date(2015, 9, 28),
#  datetime.date(2015, 3, 13),
#  datetime.date(2021, 9, 15),
#  datetime.date(2017, 1, 17),
#  datetime.date(2024, 6, 12),
#  datetime.date(2019, 2, 22),
#  datetime.date(2018, 10, 19),
#  datetime.date(2017, 12, 15),
#  datetime.date(2015, 7, 23),
#  datetime.date(2021, 5, 7),
#  datetime.date(2021, 9, 7),
#  datetime.date(2020, 6, 22),
#  datetime.date(2016, 10, 13),
#  datetime.date(2022, 8, 23),
#  datetime.date(2023, 8, 28),
#  datetime.date(2021, 6, 7),
#  datetime.date(2018, 8, 14),
#  datetime.date(2022, 2, 15),
#  datetime.date(2024, 9, 4),
#  datetime.date(2019, 2, 18),
#  datetime.date(2018, 3, 7),
#  datetime.date(2022, 6, 2),
#  datetime.date(2021, 8, 19),
#  datetime.date(2017, 3, 3),
#  datetime.date(2021, 4, 22),
#  datetime.date(2022, 8, 8),
#  datetime.date(2019, 3, 20),
#  datetime.date(2016, 6, 15),
#  datetime.date(2023, 9, 4),
#  datetime.date(2018, 9, 13),
#  datetime.date(2020, 11, 5),
#  datetime.date(2018, 12, 4),
#  datetime.date(2020, 9, 7),
#  datetime.date(2016, 3, 17),
#  datetime.date(2018, 5, 24),
#  datetime.date(2020, 5, 5),
#  datetime.date(2016, 8, 3),
#  datetime.date(2016, 12, 27),
#  datetime.date(2021, 5, 18),
#  datetime.date(2019, 8, 1),
#  datetime.date(2020, 4, 23),
#  datetime.date(2023, 10, 31),
#  datetime.date(2017, 2, 13),
#  datetime.date(2018, 11, 8),
#  ...}

# %%
def rename_ohlc_columns(df: pl.DataFrame) -> pl.DataFrame:

    column_mapping = {"o": "open", "h": "high", "l": "low", "c": "close", "v": "volume"}
    df = df.rename(column_mapping)

    return df

# %%
PORTFOLIO_VALUE = 10_00_000 # 10 Lacs
RPT_PCT = 0.01 # 1% RPT
SLIPPAGE_ = 0.001
LEVERAGE_ = 5

# %%
def calculate_signals(df, fast_ma, slow_ma):
    # Calculate X-day High/Low and 20 EMA
    df['X_High'] = df['high'].rolling(fast_ma).mean()
    df['Y_Low'] = df['low'].rolling(slow_ma).mean()
    
    df['Buy_Signal'] = (
        (df['X_High'] > df['Y_Low'])
    )
    return df

# %%
# def backtest(df):
#     position = 0
#     entry_price = 0
#     trades = []
#     trailing_stop = None
    
#     for i in range(len(df)):
#         if df.loc[i, 'Buy_Signal'] and position == 0:
#             position = 1
#             # entry_price = df.loc[i, 'close']
#             trailing_stop_long = df.loc[i, 'EMA_20']
#             # trades.append({'Type': 'Buy', 'Price': entry_price, 'Date': df.loc[i, 'datetime']})
#             entry_time_long = df.loc[i, 'datetime']
#             entry_price_long = df.loc[i, 'close']
#             initial_sl_long = trailing_stop_long
        
#         elif df.loc[i, 'Sell_Signal'] and position == 0:
#             position = -1
#             entry_price = df.loc[i, 'close']
#             trailing_stop_short = df.loc[i, 'EMA_20']
#             # trades.append({'Type': 'Sell', 'Price': entry_price, 'Date': df.loc[i, 'datetime']})
#             entry_time_short = df.loc[i, 'datetime']
#             entry_price_short = df.loc[i, 'close']
#             initial_sl_short = trailing_stop_short
        
#         elif position == 1:
#             if df.loc[i, 'low'] < trailing_stop_long:
#                 # trades.append({'Type': 'Exit', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 position = 0
#                 exit_time_long = df.loc[i, 'datetime']
#                 exit_price_long = trailing_stop_long
#                 points_long = exit_price_long - entry_price_long
                
#             elif df.loc[i, 'Add_Long']:
#                 # trades.append({'Type': 'Add Long', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 entry_time_long = df.loc[i, 'datetime']
#                 entry_price_long = df.loc[i, 'close']
#                 initial_sl_long = trailing_stop_long
#                 trailing_stop_long = max(trailing_stop_long, df.loc[i, 'EMA_20'])
        
#         elif position == -1:
#             if df.loc[i, 'high'] > trailing_stop:
#                 trades.append({'Type': 'Exit', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 position = 0
#             elif df.loc[i, 'Add_Short']:
#                 trades.append({'Type': 'Add Short', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 trailing_stop = min(trailing_stop, df.loc[i, 'EMA_20'])
    
#     return pd.DataFrame(trades)

# %%
def backtest(df, fractal_num):
    # Variables for long trades
    long_position = 0  # 0 = no position, 1 = long
    long_entry_price = 0
    long_entry_date = None
    long_trades = []
    tradebook = pd.DataFrame()
    tradebook_long = pd.DataFrame()
    tradebook_short = pd.DataFrame()
    long_trailing_stop = 0
    # Variables for short trades
    short_position = 0  # 0 = no position, -1 = short
    short_entry_price = 0
    short_entry_date = None
    short_trades = []
    short_trailing_stop = None

    can_add_long = False
    can_add_short = False

    trade_number = 0
    lock_initial_sl = False
    first_sl = 0

    lock_initial_sl_2 = False
    first_sl_2 = 0

    buy_pending = False
    long_trailing_stop = 0

    for i in range(1, len(df)):
        if df.loc[i-1, 'Buy_Signal'] and long_position == 0:
            # Signal Found
            signal_entry_price = df.loc[i-1, 'high']
            signal_entry_time = df.loc[i-1, 'datetime']
            long_initial_sl = min(min(df.loc[i-1, 'low'], df.loc[i-2, 'low'], df.loc[i-3, 'low']), signal_entry_price*0.985)
            buy_pending = True

        if buy_pending and long_position == 0:
            if df.loc[i, 'high'] >= signal_entry_price:
                if (df.loc[i, 'open'] <= signal_entry_price) or (df.loc[i, 'open'] > signal_entry_price and df.loc[i, 'low'] < signal_entry_price):
                    # Entry Triggered
                    long_position = 1
                    tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
                        'Trade No.': trade_number,
                        'Entry_Date': df.loc[i, 'datetime'],
                        'Exit_Date': None,
                        'Trade_Type': 'Long',
                        'Entry_Price': signal_entry_price,
                        'Initial SL': long_initial_sl,
                        'Trailing SL': long_trailing_stop,
                        'Exit_Price': None,
                    }])], ignore_index=True)

        if not df.loc[i-1, 'Buy_Signal']:
            buy_pending = False
            signal_entry_price = 0
                
        # Exit or add to long position
        if long_position == 1:
            
            # y_days_low = df['low'].rolling(y_days).min().iloc[i-1]
            # y_days_high = df['high'].rolling(y_days).max().iloc[i-1]

            if all(df.loc[i - j, 'low'] >= df.loc[i - fractal_num, 'low'] for j in range(0, ((fractal_num * 2) + 1))):
                long_trailing_stop = df.loc[i - fractal_num, 'low']
            
            # print(df.iloc[i]['datetime'], y_days_high, y_days_low)
            
            if df.loc[i, 'low'] <= long_initial_sl:
                tradebook_long.loc[
                    (tradebook_long['Trade No.'] == trade_number),
                    ['Exit_Date', 'Exit_Price', 'Exit Remark', 'Trailing SL']
                ] = [df.loc[i, 'datetime'] , long_initial_sl , 'Initial SL Hit', long_trailing_stop]
                long_position = 0
                can_add_long = False
                trade_number += 1
                lock_initial_sl = False
                first_sl = 0
                long_trailing_stop = 0
                buy_pending = False

            elif df.loc[i, 'X_High'] < df.loc[i, 'Y_Low']:
                tradebook_long.loc[
                    (tradebook_long['Trade No.'] == trade_number),
                    ['Exit_Date', 'Exit_Price', 'Exit Remark', 'Trailing SL']
                ] = [df.loc[i, 'datetime'] , df.loc[i, 'close'] , 'MA Cross', long_trailing_stop]
                long_position = 0
                can_add_long = False
                trade_number += 1
                lock_initial_sl = False
                first_sl = 0
                long_trailing_stop = 0
                buy_pending = False
            
            elif df.loc[i, 'close'] <= long_trailing_stop:
                tradebook_long.loc[
                    (tradebook_long['Trade No.'] == trade_number),
                    ['Exit_Date', 'Exit_Price', 'Exit Remark', 'Trailing SL']
                ] = [df.loc[i, 'datetime'] , df.loc[i, 'close'] , 'Trailing SL Hit', long_trailing_stop]
                long_position = 0
                can_add_long = False
                trade_number += 1
                lock_initial_sl = False
                first_sl = 0
                long_trailing_stop = 0
                buy_pending = False

            # elif (df.loc[i, 'low'] <= y_days_low) and not can_add_long:
            #     # Previous Y Candle Low Breached, confirmation found. Add position on high break
            #     can_add_long = True

            # if can_add_long and long_position:
            #     if df.loc[i, 'high'] >= y_days_high:
            #         tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
            #             'Trade No.': trade_number,
            #             'Entry_Date': df.loc[i, 'datetime'],
            #             'Exit_Date': None,
            #             'Trade_Type': 'Add_Long',
            #             'Entry_Price': y_days_high,
            #             'Initial SL': first_sl,
            #             'Trailing SL': long_trailing_stop,
            #             'Exit_Price': None,
            #             # 'Profit/Loss': None  # Filled when exited
            #         }])], ignore_index=True)
            #         can_add_long = False

    tradebook = pd.concat([tradebook, tradebook_long], ignore_index=True)
    return tradebook

# %%
# def backtest(df, y_days):
#     # Variables for long trades
#     long_position = 0  # 0 = no position, 1 = long
#     long_entry_price = 0
#     long_entry_date = None
#     long_trades = []
#     tradebook = pd.DataFrame()
#     tradebook_long = pd.DataFrame()
#     tradebook_short = pd.DataFrame()
#     long_trailing_stop = None
#     # Variables for short trades
#     short_position = 0  # 0 = no position, -1 = short
#     short_entry_price = 0
#     short_entry_date = None
#     short_trades = []
#     short_trailing_stop = None

#     can_add_long = False
#     can_add_short = False

#     trade_number = 0

#     for i in range(len(df)):
#         # Entry signals for long trades
#         long_trailing_stop = df.loc[i, 'EMA_20']
#         short_trailing_stop = df.loc[i, 'EMA_20']
        
#         if df.loc[i, 'Buy_Signal'] and long_position == 0:
#             long_position = 1
#             long_entry_price = df.loc[i, 'close']
#             long_entry_date = df.loc[i, 'datetime']
#             long_trailing_stop = df.loc[i, 'EMA_20']
#             long_initial_sl = df.loc[i, 'X_Low']

#             tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
#                 'Trade No.': trade_number,
#                 'Entry_Date': df.loc[i, 'datetime'],
#                 'Exit_Date': None,
#                 'Trade_Type': 'Long',
#                 'Entry_Price': df.loc[i, 'close'],
#                 'Initial SL': long_initial_sl,
#                 'Exit_Price': None,
#                 # 'Profit/Loss': None  # Filled when exited
#             }])], ignore_index=True)

#         # Exit or add to long position
#         if long_position == 1:
            
#             y_days_low = df['low'].rolling(y_days).min().iloc[i-1]
#             y_days_high = df['high'].rolling(y_days).max().iloc[i-1]
            
#             # print(df.iloc[i]['datetime'], y_days_high, y_days_low)
            
#             if df.loc[i, 'low'] <= long_initial_sl:
#                 tradebook_long.loc[
#                     (tradebook_long['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] , long_initial_sl]
#                 long_position = 0
#                 can_add_long = False
#                 trade_number += 1
            
#             elif df.loc[i, 'close'] <= long_trailing_stop:
#                 tradebook_long.loc[
#                     (tradebook_long['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] , df.loc[i, 'close']]
#                 long_position = 0
#                 can_add_long = False
#                 trade_number += 1

#             elif (df.loc[i, 'low'] <= y_days_low) and not can_add_long:
#                 # Previous Y Candle Low Breached, confirmation found. Add position on high break
#                 can_add_long = True

#             if can_add_long and long_position:
#                 if df.loc[i, 'high'] >= y_days_high:
#                     tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
#                         'Trade No.': trade_number,
#                         'Entry_Date': df.loc[i, 'datetime'],
#                         'Exit_Date': None,
#                         'Trade_Type': 'Add_Long',
#                         'Entry_Price': y_days_high,
#                         'Initial SL': long_initial_sl,
#                         'Exit_Price': None,
#                         # 'Profit/Loss': None  # Filled when exited
#                     }])], ignore_index=True)
#                     can_add_long = False

#     for i in range(len(df)):
        
#         # Entry signals for long trades
#         long_trailing_stop = df.loc[i, 'EMA_20']
#         short_trailing_stop = df.loc[i, 'EMA_20']

#         # Entry signals for short trades
#         if df.loc[i, 'Sell_Signal'] and short_position == 0:
#             short_position = -1
#             short_entry_price = df.loc[i, 'close']
#             short_entry_date = df.loc[i, 'datetime']
#             short_trailing_stop = df.loc[i, 'EMA_20']
#             short_initial_sl = df.loc[i, 'X_High']

#             tradebook_short = pd.concat([tradebook_short, pd.DataFrame([{
#                 'Trade No.': trade_number,
#                 'Entry_Date': df.loc[i, 'datetime'],
#                 'Exit_Date': None,
#                 'Trade_Type': 'Short',
#                 'Entry_Price': df.loc[i, 'close'],
#                 'Initial SL': short_initial_sl,
#                 'Exit_Price': None,
#                 # 'Profit/Loss': None  # Filled when exited
#             }])], ignore_index=True)

#         if short_position == -1:
            
#             y_days_low = df['low'].rolling(y_days).min().iloc[i-1]
#             y_days_high = df['high'].rolling(y_days).max().iloc[i-1]
            
#             # print(df.iloc[i]['datetime'], y_days_high, y_days_low)
            
#             if df.loc[i, 'high'] >= short_initial_sl:
#                 tradebook_short.loc[
#                     (tradebook_short['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] ,short_initial_sl]
#                 short_position = 0
#                 can_add_short = False
#                 trade_number += 1
            
#             elif df.loc[i, 'close'] >= short_trailing_stop:
#                 tradebook_short.loc[
#                     (tradebook_short['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] , df.loc[i, 'close']]
#                 short_position = 0
#                 can_add_short = False
#                 trade_number += 1

#             elif (df.loc[i, 'high'] >= y_days_high) and not can_add_short:
#                 # Previous Y Candle High Breached, confirmation found. Add position on low break
#                 can_add_short = True

#             if can_add_short and short_position:
#                 if df.loc[i, 'low'] <= y_days_low:
#                     tradebook_short = pd.concat([tradebook_short, pd.DataFrame([{
#                         'Trade No.': trade_number,
#                         'Entry_Date': df.loc[i, 'datetime'],
#                         'Exit_Date': None,
#                         'Trade_Type': 'Add_Short',
#                         'Entry_Price': y_days_low,
#                         'Initial SL': short_initial_sl,
#                         'Exit_Price': None,
#                         # 'Profit/Loss': None  # Filled when exited
#                     }])], ignore_index=True)
#                     can_add_short = False
    
#     tradebook = pd.concat([tradebook_long, tradebook_short], ignore_index=True)
#     return tradebook

# %%
# ema_length = 55
# x_days = 28
# y_days = 7
# pct = 1.05
RPT = 5
df = bnf_1min
df = calculate_signals(df, 7, 28)
tb = backtest(df, 5)
tb = tb.sort_values(by='Entry_Date')
# variation = f'EMA: {ema_length}, X: {x_days}, Y: {y_days}, PCT: {pct}%, RPT: {RPT}%'
# Out:
# /tmp/ipykernel_42620/3627175074.py:84: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'MA Cross' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_long.loc[

# %%
import numpy as np
portfolio = 10000000
tb['PnL'] = np.where(
    tb['Trade_Type'].isin(['Long', 'Add_Long']),  # For Long and Add_Long
    tb['Exit_Price'] - tb['Entry_Price'],
    np.where(
        tb['Trade_Type'].isin(['Short', 'Add_Short']),  # For Short and Add_Short
        tb['Entry_Price'] - tb['Exit_Price'],
        0  # Default case if Trade_Type is something unexpected
    )
)

tb['Slippage'] = SLIPPAGE_ * (tb['Entry_Price'] + tb['Exit_Price'])
tb['PnL w cs'] = tb['PnL'] - tb['Slippage']
tb['Qty'] = abs(RPT / 100 * portfolio / (tb['Entry_Price'] - tb['Initial SL']))
tb['Profit_Loss INR'] = tb['Qty'] * tb['PnL w cs']
tb['ROI%'] = tb['Profit_Loss INR'] * 100 / portfolio

# %%
tb['Cumulative_PnL'] = tb['PnL w cs'].cumsum()

# %%
# tb.to_csv('GOLD TRADE CHECK JJPP.csv', index=False)

# %%
tb = tb.reset_index()
# tb

# %%
tb_long_only = tb[(tb['Trade_Type'] == 'Long') | (tb['Trade_Type'] == 'Add_Long')].copy()
tb_long_only['Cumulative_PnL'] = tb_long_only['PnL w cs'].cumsum()
tb_short_only = tb[(tb['Trade_Type'] == 'Short') | (tb['Trade_Type'] == 'Add_Short')].copy()
tb_short_only['Cumulative_PnL'] = tb_short_only['PnL w cs'].cumsum()

# %%
# tb2 = tb.groupby('Trade No.', as_index=False)['PnL w cs'].sum()
# tb2['Cumulative_PnL'] = tb2['PnL w cs'].cumsum()

# %%
# plot_cumulative_pnl(tb_long_only)
# print(tb_long_only['PnL w cs'].sum())

# %%
# plot_cumulative_pnl(tb_short_only)
# print(tb_short_only['PnL w cs'].sum())

# %%
# plot_cumulative_pnl(tb)
# print(tb['PnL w cs'].sum())

# %%
# plot_cumulative_pnl(tb2)
# print(tb2['PnL w cs'].sum())

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2015, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2015, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI%"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI%"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI%"] > 0]["ROI%"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI%"] < 0]["ROI%"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI%"].cumsum() - year_trades["ROI%"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI%"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI%"] > 0]["ROI%"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI%"].cumsum() - combined_df_sorted["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation

    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    
    # print(f'{overall_total_roi} , {overall_max_drawdown} , {overall_roi_dd_ratio}')
    
    return {overall_roi_dd_ratio: stats_df8}

# %%
tb_long_only['Entry_Date'] = pd.to_datetime(tb_long_only['Entry_Date'])
tb_long_only['Trade Year'] = tb_long_only['Entry_Date'].dt.year
tb_long_only['ROI% w cs'] = tb_long_only['ROI%']

# %%
stats = generate_stats(tb_long_only, '...')
lol = pd.DataFrame()
for x, y in stats.items():
    lol = pd.DataFrame(y)

lol
# Out:
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2015     -20.1939           27  22.2222                6.5862
# 2016      49.1418           26  38.4615                9.9596
# 2017      33.8455           21  42.8571                6.3319
# 2018      -8.4527           30  30.0000                5.5778
# 2019       0.1923           29  27.5862                7.7843
# 2020       9.4919           35  25.7143               10.7274
# 2021     -40.5529           31  25.8065                5.0912
# 2022      49.1373           25  32.0000               11.6683
# 2023       0.9868           26  30.7692                5.2895
# 2024      44.1696           19  47.3684                8.6959
# Overall  117.7656          269  31.2268                7.8545
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio Variation
# 2015                -2.8434     -27.1581      -0.7436       ...
# 2016                -3.1534     -21.9402       2.2398       ...
# 2017                -1.9285     -10.5186       3.2177       ...
# 2018                -2.7930     -33.1662      -0.2549       ...
# 2019                -2.9563     -30.6019       0.0063       ...
# 2020                -3.3483     -51.2413       0.1852       ...
# 2021                -3.5340     -38.0882      -1.0647       ...
# 2022                -2.6005     -17.2378       2.8506       ...
# 2023                -2.2961     -23.5164       0.0420       ...
# 2024                -3.4093     -10.6822       4.1349       ...
# Overall             -2.9298     -93.3441       1.2616       ...

# %%
tb_long_only.tail(15)
# Out:
#      index  Trade No.                Entry_Date                  Exit_Date  \
# 254    254        254 2024-02-13 17:00:00+05:30  2024-02-13 21:00:00+05:30
# 255    255        255 2024-02-20 09:00:00+05:30  2024-03-18 09:00:00+05:30
# 256    256        256 2024-03-18 13:00:00+05:30  2024-04-22 21:00:00+05:30
# 257    257        257 2024-04-29 13:00:00+05:30  2024-04-30 17:00:00+05:30
# 258    258        258 2024-05-01 17:00:00+05:30  2024-05-02 21:00:00+05:30
# 259    259        259 2024-05-03 17:00:00+05:30  2024-05-23 21:00:00+05:30
# 260    260        260 2024-05-30 17:00:00+05:30  2024-06-03 09:00:00+05:30
# 261    261        261 2024-06-03 13:00:00+05:30  2024-06-10 09:00:00+05:30
# 262    262        262 2024-06-10 13:00:00+05:30  2024-06-10 21:00:00+05:30
# 263    263        263 2024-06-13 13:00:00+05:30  2024-06-26 17:00:00+05:30
# 264    264        264 2024-07-01 13:00:00+05:30  2024-07-22 17:00:00+05:30
# 265    265        265 2024-07-31 17:00:00+05:30  2024-08-08 13:00:00+05:30
# 266    266        266 2024-08-08 21:00:00+05:30  2024-09-03 17:00:00+05:30
# 267    267        267 2024-09-05 17:00:00+05:30  2024-10-08 09:00:00+05:30
# 268    268        268 2024-10-08 13:00:00+05:30  2024-10-09 17:00:00+05:30
#
#     Trade_Type  Entry_Price  Initial SL  Trailing SL Exit_Price  \
# 254       Long        62309  61374.3650            0      61497
# 255       Long        62026  61095.6100        65382      65369
# 256       Long        65395  64414.0750        71200      71190
# 257       Long        71481  70408.7850            0 70408.7850
# 258       Long        70565  69506.5250            0      70761
# 259       Long        70706  69645.4100        71750      71510
# 260       Long        71900  70821.5000        71634      71580
# 261       Long        71685  70609.7250        71290      70999
# 262       Long        71150  70082.7500            0      71418
# 263       Long        71555  70481.6750        71175      71057
# 264       Long        71615  70540.7750        72111      72625
# 265       Long        69550  67945.0000        68379      69362
# 266       Long        69746  68699.8100        71426      71190
# 267       Long        71998  70918.0300        75735      75702
# 268       Long        75995  74855.0750            0 74855.0750
#
#          Exit Remark        PnL Slippage   PnL w cs      Qty Profit_Loss INR  \
# 254         MA Cross       -812 123.8060  -935.8060 534.9682    -500626.4478
# 255  Trailing SL Hit       3343 127.3950  3215.6050 537.4090    1728095.2074
# 256  Trailing SL Hit       5795 136.5850  5658.4150 509.7230    2884224.0742
# 257   Initial SL Hit -1072.2150 141.8898 -1214.1048 466.3244    -566166.6667
# 258         MA Cross        196 141.3260    54.6740 472.3777      25826.7791
# 259  Trailing SL Hit        804 142.2160   661.7840 471.4357     311988.6101
# 260  Trailing SL Hit       -320 143.4800  -463.4800 463.6069    -214872.5081
# 261  Trailing SL Hit       -686 142.6840  -828.6840 464.9973    -385335.8443
# 262         MA Cross        268 142.5680   125.4320 468.4938      58764.1134
# 263  Trailing SL Hit       -498 142.6120  -640.6120 465.8421    -298424.0561
# 264         MA Cross       1010 144.2400   865.7600 465.4518     402969.5827
# 265         MA Cross       -188 138.9120  -326.9120 311.5265    -101841.7445
# 266  Trailing SL Hit       1444 140.9360  1303.0640 477.9247     622766.4191
# 267  Trailing SL Hit       3704 147.7000  3556.3000 462.9758    1646480.9208
# 268   Initial SL Hit -1139.9250 150.8501 -1290.7751 438.6253    -566166.6667
#
#        ROI% Cumulative_PnL  Trade Year ROI% w cs
# 254 -5.0063      2343.7117        2024   -5.0063
# 255 17.2810      5559.3167        2024   17.2810
# 256 28.8422     11217.7317        2024   28.8422
# 257 -5.6617     10003.6269        2024   -5.6617
# 258  0.2583     10058.3009        2024    0.2583
# 259  3.1199     10720.0849        2024    3.1199
# 260 -2.1487     10256.6049        2024   -2.1487
# 261 -3.8534      9427.9209        2024   -3.8534
# 262  0.5876      9553.3529        2024    0.5876
# 263 -2.9842      8912.7409        2024   -2.9842
# 264  4.0297      9778.5009        2024    4.0297
# 265 -1.0184      9451.5889        2024   -1.0184
# 266  6.2277     10754.6529        2024    6.2277
# 267 16.4648     14310.9529        2024   16.4648
# 268 -5.6617     13020.1779        2024   -5.6617

# %%
# tb_long_only.to_csv('GOLD Range JJPP.csv', index=False)

# %%
tb_long_only_1 = tb_long_only[tb_long_only['Trade_Type'] == 'Add_Long']
tb_long_only_2 = tb_long_only[tb_long_only['Trade_Type'] == 'Long']

# %%
tb_long_only_1['ROI%'].sum() , tb_long_only_2['ROI%'].sum()
# Out:
# (0, 190.16998953576362)

# %%
for i in range(4, 33, 2):
    for j in range(10, 71, 4):
        for k in range(1, 6):
            RPT = 5
            variation = f'{i}, {j}, {k}'
            print(variation)
            df = bnf_1min
            df = calculate_signals(df, i, j)
            tb = backtest(df, k)
            if len(tb) > 0:
                tb = tb.sort_values(by='Entry_Date')
                portfolio = 10000000
                tb['PnL'] = np.where(
                    tb['Trade_Type'].isin(['Long', 'Add_Long']),  # For Long and Add_Long
                    tb['Exit_Price'] - tb['Entry_Price'],
                    np.where(
                        tb['Trade_Type'].isin(['Short', 'Add_Short']),  # For Short and Add_Short
                        tb['Entry_Price'] - tb['Exit_Price'],
                        0  # Default case if Trade_Type is something unexpected
                    )
                )
                
                tb['Slippage'] = SLIPPAGE_ * (tb['Entry_Price'] + tb['Exit_Price'])
                tb['PnL w cs'] = tb['PnL'] - tb['Slippage']
                tb['Qty'] = abs(RPT / 100 * portfolio / (tb['Entry_Price'] - tb['Initial SL']))
                tb['Profit_Loss INR'] = tb['Qty'] * tb['PnL w cs']
                tb['ROI%'] = tb['Profit_Loss INR'] * 100 / portfolio
                tb['Entry_Date'] = pd.to_datetime(tb['Entry_Date'])
                tb['Trade Year'] = tb['Entry_Date'].dt.year
                
                stats1 = generate_stats(tb, variation)
                for x, y in stats1.items():
                    if x > 10:
                        print('Long Only')
                        print(pd.DataFrame(y).to_string())
                    break
# Out:
# 4, 10, 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 8
#       6 print(variation)
#       7 df = bnf_1min
# ----> 8 df = calculate_signals(df, ema_length=ema_length, x_days=x_days, pct=pct)
#       9 tb = backtest(df, y_days=y_days)
#      10 if len(tb) > 0:
#
# NameError: name 'x_days' is not defined
