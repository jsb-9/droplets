# %%
import asyncio
import datetime as dt
import math
from typing import Literal

import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

# %%
import sys

sys.path.append("..")
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
async def get_expiry(f_today, index):

    if index == 'bnf':    
        if (f_today <= dt.date(2024, 1, 25)) and (f_today >= dt.date(2024, 1, 18)):
            f_expiry = dt.date(2024, 1, 25)
        elif (f_today <= dt.date(2024, 1, 31)) and (f_today >= dt.date(2024, 1, 26)):
            f_expiry = dt.date(2024, 1, 31)
        elif (f_today <= dt.date(2024, 2, 22)) and (f_today >= dt.date(2024, 2, 29)):
            f_expiry = dt.date(2024, 2, 29)
        elif (f_today <= dt.date(2024, 3, 25)) and (f_today >= dt.date(2024, 3, 27)):
            f_expiry = dt.date(2024, 2, 27)
        elif f_today < dt.date(2023, 9, 1):
            days_to_thursday = (3 - f_today.weekday()) % 7
            nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
            f_expiry = nearest_thursday
            if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
                f_expiry = nearest_thursday - dt.timedelta(days=1)
        elif f_today >= dt.date(2023, 9, 1):
            if f_today.day < 24:
                days_to_wednesday = (2 - f_today.weekday()) % 7
                nearest_wednesday = f_today + dt.timedelta(days=days_to_wednesday)
                f_expiry = nearest_wednesday
                if nse.valid_days(
                    start_date=nearest_wednesday, end_date=nearest_wednesday
                ).empty:
                    f_expiry = nearest_wednesday - dt.timedelta(days=1)
            else:
                days_to_thursday = (3 - f_today.weekday()) % 7
                nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
                f_expiry = nearest_thursday
                if nse.valid_days(
                    start_date=nearest_thursday, end_date=nearest_thursday
                ).empty:
                    f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'nifty':
        days_to_thursday = (3 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'finnifty' or index == 'fnf':
        days_to_thursday = (1 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'midcpnifty' or index == 'midcp':
        days_to_thursday = (0 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

async def get_expiry_nifty(f_today):

    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry


async def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"


def get_option_contract_name2(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"

# %%
bnf_1min = pd.read_csv("../data/gold_tv_4h.csv")
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["time"])
bnf_1min = bnf_1min[bnf_1min["datetime"].dt.year >= 2012]

# %%
bnf_1min.head()
# Out:
#                         time   open   high    low  close  MA  Shapes  \
# 0  2015-03-02T09:00:00+05:30  26600  26769  26600  26700 NaN       0
# 1  2015-03-02T13:00:00+05:30  26709  26730  26653  26680 NaN       0
# 2  2015-03-02T17:00:00+05:30  26684  26742  26576  26619 NaN       0
# 3  2015-03-02T21:00:00+05:30  26623  26624  26500  26506 NaN       0
# 4  2015-03-03T09:00:00+05:30  26500  26525  26444  26463 NaN       0
#
#    Shapes.1  RSI                  datetime
# 0         0  NaN 2015-03-02 09:00:00+05:30
# 1         0  NaN 2015-03-02 13:00:00+05:30
# 2         0  NaN 2015-03-02 17:00:00+05:30
# 3         0  NaN 2015-03-02 21:00:00+05:30
# 4         0  NaN 2015-03-03 09:00:00+05:30

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("open").first().alias("open"),
                pl.col("high").max().alias("high"),
                pl.col("low").min().alias("low"),
                pl.col("close").last().alias("close"),
                pl.col("volume").sum().alias("volume"),
            ]
        )
    )


# ohlc_resampled = resample(pl.DataFrame(bnf_1min), '7d', pd.Timedelta(days=4))
# ohlc_resampled

# %%
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["datetime"])
list_of_traded_dates = set(bnf_1min["datetime"].dt.date)
list_of_traded_dates
# Out:
# {datetime.date(2018, 1, 17),
#  datetime.date(2020, 5, 6),
#  datetime.date(2021, 11, 12),
#  datetime.date(2019, 4, 23),
#  datetime.date(2024, 1, 15),
#  datetime.date(2015, 6, 11),
#  datetime.date(2022, 6, 28),
#  datetime.date(2015, 7, 2),
#  datetime.date(2024, 1, 18),
#  datetime.date(2020, 3, 9),
#  datetime.date(2019, 7, 17),
#  datetime.date(2015, 9, 28),
#  datetime.date(2016, 5, 27),
#  datetime.date(2020, 11, 11),
#  datetime.date(2017, 11, 7),
#  datetime.date(2016, 7, 14),
#  datetime.date(2019, 9, 4),
#  datetime.date(2021, 6, 29),
#  datetime.date(2020, 4, 23),
#  datetime.date(2017, 4, 7),
#  datetime.date(2017, 8, 24),
#  datetime.date(2024, 7, 22),
#  datetime.date(2021, 2, 17),
#  datetime.date(2020, 12, 14),
#  datetime.date(2022, 10, 10),
#  datetime.date(2022, 7, 20),
#  datetime.date(2023, 7, 3),
#  datetime.date(2016, 12, 21),
#  datetime.date(2021, 9, 8),
#  datetime.date(2022, 10, 19),
#  datetime.date(2021, 12, 22),
#  datetime.date(2019, 7, 8),
#  datetime.date(2022, 4, 5),
#  datetime.date(2017, 1, 3),
#  datetime.date(2019, 2, 8),
#  datetime.date(2016, 8, 4),
#  datetime.date(2017, 5, 23),
#  datetime.date(2016, 10, 17),
#  datetime.date(2020, 6, 18),
#  datetime.date(2018, 12, 20),
#  datetime.date(2023, 5, 3),
#  datetime.date(2022, 1, 27),
#  datetime.date(2020, 5, 29),
#  datetime.date(2016, 10, 4),
#  datetime.date(2015, 6, 10),
#  datetime.date(2017, 12, 18),
#  datetime.date(2019, 9, 18),
#  datetime.date(2023, 9, 11),
#  datetime.date(2021, 11, 15),
#  datetime.date(2022, 1, 12),
#  datetime.date(2018, 2, 15),
#  datetime.date(2018, 1, 16),
#  datetime.date(2023, 1, 12),
#  datetime.date(2023, 12, 12),
#  datetime.date(2021, 9, 3),
#  datetime.date(2024, 9, 5),
#  datetime.date(2024, 7, 24),
#  datetime.date(2018, 10, 4),
#  datetime.date(2016, 11, 21),
#  datetime.date(2015, 6, 1),
#  datetime.date(2015, 7, 3),
#  datetime.date(2018, 4, 10),
#  datetime.date(2017, 3, 15),
#  datetime.date(2020, 3, 4),
#  datetime.date(2016, 10, 6),
#  datetime.date(2022, 7, 11),
#  datetime.date(2020, 6, 10),
#  datetime.date(2020, 2, 20),
#  datetime.date(2023, 7, 7),
#  datetime.date(2023, 8, 31),
#  datetime.date(2023, 11, 17),
#  datetime.date(2022, 2, 18),
#  datetime.date(2018, 12, 17),
#  datetime.date(2019, 1, 18),
#  datetime.date(2019, 2, 21),
#  datetime.date(2021, 10, 29),
#  datetime.date(2023, 3, 8),
#  datetime.date(2019, 3, 14),
#  datetime.date(2019, 3, 26),
#  datetime.date(2021, 2, 15),
#  datetime.date(2020, 9, 14),
#  datetime.date(2016, 8, 30),
#  datetime.date(2018, 2, 27),
#  datetime.date(2020, 6, 22),
#  datetime.date(2015, 10, 13),
#  datetime.date(2022, 4, 28),
#  datetime.date(2023, 10, 19),
#  datetime.date(2022, 9, 26),
#  datetime.date(2018, 3, 14),
#  datetime.date(2020, 5, 27),
#  datetime.date(2022, 11, 30),
#  datetime.date(2016, 4, 21),
#  datetime.date(2020, 2, 10),
#  datetime.date(2024, 2, 6),
#  datetime.date(2022, 2, 9),
#  datetime.date(2024, 6, 5),
#  datetime.date(2022, 1, 13),
#  datetime.date(2016, 3, 14),
#  datetime.date(2016, 12, 7),
#  datetime.date(2020, 5, 22),
#  datetime.date(2023, 2, 14),
#  datetime.date(2022, 7, 7),
#  datetime.date(2024, 3, 7),
#  datetime.date(2019, 1, 10),
#  datetime.date(2018, 7, 27),
#  datetime.date(2018, 6, 5),
#  datetime.date(2017, 2, 28),
#  datetime.date(2017, 10, 4),
#  datetime.date(2015, 3, 4),
#  datetime.date(2020, 7, 23),
#  datetime.date(2022, 2, 14),
#  datetime.date(2024, 4, 22),
#  datetime.date(2019, 6, 18),
#  datetime.date(2022, 1, 24),
#  datetime.date(2019, 10, 3),
#  datetime.date(2023, 7, 10),
#  datetime.date(2017, 5, 3),
#  datetime.date(2019, 5, 15),
#  datetime.date(2017, 5, 8),
#  datetime.date(2022, 6, 21),
#  datetime.date(2023, 8, 23),
#  datetime.date(2020, 10, 16),
#  datetime.date(2020, 4, 16),
#  datetime.date(2017, 9, 6),
#  datetime.date(2017, 8, 22),
#  datetime.date(2015, 3, 11),
#  datetime.date(2016, 6, 29),
#  datetime.date(2021, 2, 19),
#  datetime.date(2024, 7, 16),
#  datetime.date(2019, 5, 16),
#  datetime.date(2016, 2, 16),
#  datetime.date(2024, 10, 7),
#  datetime.date(2021, 11, 2),
#  datetime.date(2015, 7, 21),
#  datetime.date(2019, 3, 12),
#  datetime.date(2021, 11, 19),
#  datetime.date(2023, 8, 16),
#  datetime.date(2020, 6, 24),
#  datetime.date(2020, 9, 22),
#  datetime.date(2015, 8, 24),
#  datetime.date(2024, 8, 26),
#  datetime.date(2016, 6, 7),
#  datetime.date(2019, 3, 8),
#  datetime.date(2015, 7, 30),
#  datetime.date(2015, 8, 13),
#  datetime.date(2017, 10, 11),
#  datetime.date(2018, 5, 28),
#  datetime.date(2015, 3, 23),
#  datetime.date(2023, 8, 11),
#  datetime.date(2018, 7, 9),
#  datetime.date(2015, 3, 10),
#  datetime.date(2021, 9, 6),
#  datetime.date(2023, 5, 5),
#  datetime.date(2021, 7, 19),
#  datetime.date(2018, 4, 20),
#  datetime.date(2015, 6, 5),
#  datetime.date(2020, 12, 21),
#  datetime.date(2015, 11, 24),
#  datetime.date(2022, 5, 25),
#  datetime.date(2023, 8, 24),
#  datetime.date(2020, 6, 15),
#  datetime.date(2019, 1, 7),
#  datetime.date(2015, 12, 18),
#  datetime.date(2020, 8, 21),
#  datetime.date(2016, 11, 29),
#  datetime.date(2024, 6, 6),
#  datetime.date(2022, 12, 13),
#  datetime.date(2018, 5, 11),
#  datetime.date(2021, 10, 14),
#  datetime.date(2022, 2, 1),
#  datetime.date(2023, 11, 21),
#  datetime.date(2018, 10, 22),
#  datetime.date(2024, 3, 13),
#  datetime.date(2021, 9, 1),
#  datetime.date(2018, 10, 16),
#  datetime.date(2024, 4, 24),
#  datetime.date(2019, 9, 5),
#  datetime.date(2015, 4, 15),
#  datetime.date(2015, 12, 31),
#  datetime.date(2017, 4, 13),
#  datetime.date(2020, 12, 10),
#  datetime.date(2015, 6, 4),
#  datetime.date(2021, 9, 28),
#  datetime.date(2019, 9, 30),
#  datetime.date(2020, 1, 28),
#  datetime.date(2021, 9, 29),
#  datetime.date(2016, 7, 4),
#  datetime.date(2018, 9, 12),
#  datetime.date(2022, 6, 24),
#  datetime.date(2017, 9, 4),
#  datetime.date(2022, 7, 27),
#  datetime.date(2018, 2, 2),
#  datetime.date(2021, 3, 26),
#  datetime.date(2016, 8, 12),
#  datetime.date(2024, 1, 2),
#  datetime.date(2018, 1, 4),
#  datetime.date(2022, 9, 30),
#  datetime.date(2024, 6, 25),
#  datetime.date(2015, 11, 13),
#  datetime.date(2019, 5, 2),
#  datetime.date(2020, 5, 21),
#  datetime.date(2021, 11, 1),
#  datetime.date(2018, 9, 21),
#  datetime.date(2024, 9, 11),
#  datetime.date(2015, 5, 20),
#  datetime.date(2015, 5, 25),
#  datetime.date(2018, 1, 12),
#  datetime.date(2017, 3, 24),
#  datetime.date(2016, 4, 12),
#  datetime.date(2016, 10, 25),
#  datetime.date(2021, 4, 21),
#  datetime.date(2018, 4, 18),
#  datetime.date(2020, 7, 31),
#  datetime.date(2016, 7, 5),
#  datetime.date(2017, 9, 21),
#  datetime.date(2015, 8, 4),
#  datetime.date(2017, 9, 15),
#  datetime.date(2020, 3, 16),
#  datetime.date(2022, 10, 28),
#  datetime.date(2016, 3, 2),
#  datetime.date(2022, 3, 25),
#  datetime.date(2016, 5, 25),
#  datetime.date(2021, 1, 7),
#  datetime.date(2019, 2, 18),
#  datetime.date(2024, 6, 11),
#  datetime.date(2022, 6, 2),
#  datetime.date(2020, 10, 7),
#  datetime.date(2018, 3, 28),
#  datetime.date(2022, 2, 24),
#  datetime.date(2020, 12, 8),
#  datetime.date(2020, 4, 7),
#  datetime.date(2020, 8, 26),
#  datetime.date(2022, 5, 26),
#  datetime.date(2023, 6, 26),
#  datetime.date(2023, 3, 7),
#  datetime.date(2017, 1, 10),
#  datetime.date(2019, 4, 9),
#  datetime.date(2018, 9, 28),
#  datetime.date(2019, 1, 23),
#  datetime.date(2019, 3, 13),
#  datetime.date(2019, 3, 20),
#  datetime.date(2023, 6, 27),
#  datetime.date(2020, 10, 21),
#  datetime.date(2017, 6, 6),
#  datetime.date(2016, 11, 25),
#  datetime.date(2020, 7, 24),
#  datetime.date(2020, 9, 25),
#  datetime.date(2023, 11, 22),
#  datetime.date(2016, 12, 5),
#  datetime.date(2018, 10, 29),
#  datetime.date(2020, 7, 3),
#  datetime.date(2022, 1, 10),
#  datetime.date(2018, 3, 1),
#  datetime.date(2016, 6, 1),
#  datetime.date(2023, 11, 14),
#  datetime.date(2018, 4, 24),
#  datetime.date(2020, 10, 12),
#  datetime.date(2021, 2, 2),
#  datetime.date(2022, 12, 7),
#  datetime.date(2020, 5, 8),
#  datetime.date(2023, 10, 11),
#  datetime.date(2019, 5, 14),
#  datetime.date(2020, 3, 26),
#  datetime.date(2017, 11, 15),
#  datetime.date(2017, 12, 5),
#  datetime.date(2021, 6, 14),
#  datetime.date(2019, 12, 26),
#  datetime.date(2022, 8, 17),
#  datetime.date(2021, 3, 18),
#  datetime.date(2016, 2, 29),
#  datetime.date(2021, 9, 22),
#  datetime.date(2016, 9, 15),
#  datetime.date(2022, 7, 21),
#  datetime.date(2023, 12, 29),
#  datetime.date(2023, 9, 12),
#  datetime.date(2016, 5, 26),
#  datetime.date(2015, 7, 20),
#  datetime.date(2018, 5, 14),
#  datetime.date(2022, 7, 6),
#  datetime.date(2015, 9, 16),
#  datetime.date(2019, 12, 13),
#  datetime.date(2020, 8, 4),
#  datetime.date(2020, 9, 17),
#  datetime.date(2019, 11, 20),
#  datetime.date(2019, 10, 31),
#  datetime.date(2019, 9, 3),
#  datetime.date(2016, 9, 30),
#  datetime.date(2021, 1, 11),
#  datetime.date(2022, 8, 8),
#  datetime.date(2020, 8, 7),
#  datetime.date(2016, 3, 3),
#  datetime.date(2019, 10, 21),
#  datetime.date(2022, 4, 22),
#  datetime.date(2020, 4, 30),
#  datetime.date(2018, 10, 11),
#  datetime.date(2018, 4, 25),
#  datetime.date(2022, 6, 15),
#  datetime.date(2015, 7, 15),
#  datetime.date(2019, 5, 6),
#  datetime.date(2021, 8, 4),
#  datetime.date(2022, 10, 12),
#  datetime.date(2017, 3, 6),
#  datetime.date(2016, 9, 29),
#  datetime.date(2017, 10, 17),
#  datetime.date(2018, 3, 21),
#  datetime.date(2018, 10, 18),
#  datetime.date(2019, 7, 15),
#  datetime.date(2016, 11, 7),
#  datetime.date(2016, 7, 29),
#  datetime.date(2021, 1, 19),
#  datetime.date(2019, 4, 10),
#  datetime.date(2017, 5, 24),
#  datetime.date(2016, 8, 25),
#  datetime.date(2018, 10, 26),
#  datetime.date(2016, 7, 20),
#  datetime.date(2018, 1, 25),
#  datetime.date(2024, 2, 15),
#  datetime.date(2021, 2, 1),
#  datetime.date(2016, 5, 18),
#  datetime.date(2017, 11, 22),
#  datetime.date(2024, 4, 11),
#  datetime.date(2020, 6, 11),
#  datetime.date(2019, 7, 9),
#  datetime.date(2020, 9, 30),
#  datetime.date(2020, 12, 3),
#  datetime.date(2021, 8, 2),
#  datetime.date(2019, 12, 4),
#  datetime.date(2017, 9, 22),
#  datetime.date(2018, 11, 23),
#  datetime.date(2023, 2, 17),
#  datetime.date(2021, 9, 9),
#  datetime.date(2023, 11, 29),
#  datetime.date(2018, 11, 7),
#  datetime.date(2024, 2, 19),
#  datetime.date(2016, 3, 28),
#  datetime.date(2016, 6, 16),
#  datetime.date(2019, 9, 24),
#  datetime.date(2020, 6, 26),
#  datetime.date(2020, 1, 13),
#  datetime.date(2020, 6, 4),
#  datetime.date(2017, 12, 28),
#  datetime.date(2018, 5, 21),
#  datetime.date(2021, 4, 14),
#  datetime.date(2015, 5, 13),
#  datetime.date(2017, 11, 27),
#  datetime.date(2021, 12, 1),
#  datetime.date(2023, 11, 28),
#  datetime.date(2016, 8, 3),
#  datetime.date(2020, 7, 6),
#  datetime.date(2020, 5, 19),
#  datetime.date(2017, 7, 20),
#  datetime.date(2023, 3, 30),
#  datetime.date(2015, 11, 2),
#  datetime.date(2021, 6, 28),
#  datetime.date(2024, 7, 30),
#  datetime.date(2023, 2, 3),
#  datetime.date(2015, 5, 27),
#  datetime.date(2023, 1, 17),
#  datetime.date(2024, 5, 15),
#  datetime.date(2022, 10, 6),
#  datetime.date(2018, 2, 1),
#  datetime.date(2022, 11, 8),
#  datetime.date(2017, 5, 15),
#  datetime.date(2022, 6, 17),
#  datetime.date(2016, 11, 16),
#  datetime.date(2024, 9, 25),
#  datetime.date(2022, 7, 4),
#  datetime.date(2016, 9, 28),
#  datetime.date(2022, 1, 20),
#  datetime.date(2021, 5, 7),
#  datetime.date(2015, 11, 6),
#  datetime.date(2022, 1, 5),
#  datetime.date(2016, 10, 5),
#  datetime.date(2023, 12, 15),
#  datetime.date(2020, 8, 10),
#  datetime.date(2019, 5, 1),
#  datetime.date(2020, 10, 20),
#  datetime.date(2018, 2, 19),
#  datetime.date(2018, 9, 14),
#  datetime.date(2020, 10, 6),
#  datetime.date(2017, 2, 17),
#  datetime.date(2024, 6, 13),
#  datetime.date(2019, 5, 7),
#  datetime.date(2022, 10, 27),
#  datetime.date(2019, 6, 7),
#  datetime.date(2022, 6, 22),
#  datetime.date(2020, 11, 20),
#  datetime.date(2019, 11, 25),
#  datetime.date(2023, 9, 13),
#  datetime.date(2020, 9, 16),
#  datetime.date(2021, 5, 12),
#  datetime.date(2021, 4, 1),
#  datetime.date(2021, 9, 17),
#  datetime.date(2024, 10, 11),
#  datetime.date(2018, 7, 23),
#  datetime.date(2022, 4, 21),
#  datetime.date(2022, 11, 2),
#  datetime.date(2020, 6, 2),
#  datetime.date(2022, 6, 14),
#  datetime.date(2021, 4, 5),
#  datetime.date(2022, 3, 14),
#  datetime.date(2016, 12, 13),
#  datetime.date(2017, 9, 19),
#  datetime.date(2017, 7, 3),
#  datetime.date(2019, 1, 4),
#  datetime.date(2019, 1, 30),
#  datetime.date(2023, 12, 8),
#  datetime.date(2015, 7, 13),
#  datetime.date(2024, 7, 25),
#  datetime.date(2022, 1, 21),
#  datetime.date(2023, 1, 16),
#  datetime.date(2020, 1, 31),
#  datetime.date(2024, 3, 1),
#  datetime.date(2024, 3, 26),
#  datetime.date(2022, 8, 5),
#  datetime.date(2019, 10, 7),
#  datetime.date(2024, 9, 16),
#  datetime.date(2023, 1, 31),
#  datetime.date(2015, 9, 22),
#  datetime.date(2016, 1, 20),
#  datetime.date(2017, 10, 19),
#  datetime.date(2022, 9, 5),
#  datetime.date(2024, 10, 1),
#  datetime.date(2019, 7, 26),
#  datetime.date(2017, 10, 27),
#  datetime.date(2016, 1, 18),
#  datetime.date(2017, 12, 7),
#  datetime.date(2015, 10, 1),
#  datetime.date(2023, 6, 2),
#  datetime.date(2020, 11, 25),
#  datetime.date(2019, 4, 11),
#  datetime.date(2021, 12, 31),
#  datetime.date(2022, 12, 23),
#  datetime.date(2021, 7, 29),
#  datetime.date(2015, 9, 10),
#  datetime.date(2022, 5, 27),
#  datetime.date(2021, 4, 9),
#  datetime.date(2016, 2, 26),
#  datetime.date(2016, 10, 20),
#  datetime.date(2022, 3, 21),
#  datetime.date(2019, 2, 12),
#  datetime.date(2021, 6, 25),
#  datetime.date(2016, 11, 18),
#  datetime.date(2017, 7, 27),
#  datetime.date(2021, 4, 8),
#  datetime.date(2021, 11, 25),
#  datetime.date(2024, 8, 2),
#  datetime.date(2015, 7, 14),
#  datetime.date(2024, 6, 19),
#  datetime.date(2018, 8, 14),
#  datetime.date(2019, 12, 5),
#  datetime.date(2019, 1, 3),
#  datetime.date(2021, 5, 17),
#  datetime.date(2016, 3, 1),
#  datetime.date(2023, 3, 9),
#  datetime.date(2015, 5, 14),
#  datetime.date(2020, 11, 12),
#  datetime.date(2018, 4, 27),
#  datetime.date(2018, 10, 12),
#  datetime.date(2022, 11, 28),
#  datetime.date(2016, 4, 6),
#  datetime.date(2022, 12, 21),
#  datetime.date(2018, 1, 9),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 8, 27),
#  datetime.date(2016, 11, 23),
#  datetime.date(2023, 10, 13),
#  datetime.date(2015, 3, 6),
#  datetime.date(2015, 4, 7),
#  datetime.date(2019, 12, 18),
#  datetime.date(2017, 6, 26),
#  datetime.date(2022, 5, 31),
#  datetime.date(2023, 7, 12),
#  datetime.date(2022, 3, 11),
#  datetime.date(2016, 2, 18),
#  datetime.date(2018, 10, 10),
#  datetime.date(2022, 12, 16),
#  datetime.date(2020, 2, 11),
#  datetime.date(2017, 11, 21),
#  datetime.date(2018, 11, 12),
#  datetime.date(2019, 8, 9),
#  datetime.date(2020, 10, 22),
#  datetime.date(2022, 3, 31),
#  datetime.date(2019, 6, 25),
#  datetime.date(2015, 3, 16),
#  datetime.date(2016, 1, 19),
#  datetime.date(2024, 2, 16),
#  datetime.date(2024, 8, 14),
#  datetime.date(2019, 1, 25),
#  datetime.date(2020, 2, 19),
#  datetime.date(2023, 9, 8),
#  datetime.date(2022, 8, 24),
#  datetime.date(2024, 10, 10),
#  datetime.date(2018, 11, 26),
#  datetime.date(2020, 9, 21),
#  datetime.date(2015, 4, 1),
#  datetime.date(2018, 11, 6),
#  datetime.date(2020, 7, 2),
#  datetime.date(2023, 5, 9),
#  datetime.date(2015, 7, 17),
#  datetime.date(2021, 8, 24),
#  datetime.date(2021, 6, 24),
#  datetime.date(2022, 12, 8),
#  datetime.date(2016, 2, 4),
#  datetime.date(2019, 10, 8),
#  datetime.date(2017, 8, 2),
#  datetime.date(2020, 4, 21),
#  datetime.date(2022, 7, 18),
#  datetime.date(2024, 7, 12),
#  datetime.date(2016, 3, 22),
#  datetime.date(2022, 10, 18),
#  datetime.date(2024, 9, 18),
#  datetime.date(2016, 3, 18),
#  datetime.date(2024, 4, 10),
#  datetime.date(2017, 1, 16),
#  datetime.date(2018, 8, 23),
#  datetime.date(2016, 4, 4),
#  datetime.date(2015, 4, 29),
#  datetime.date(2016, 10, 13),
#  datetime.date(2020, 12, 17),
#  datetime.date(2015, 12, 14),
#  datetime.date(2023, 2, 22),
#  datetime.date(2017, 8, 23),
#  datetime.date(2017, 6, 13),
#  datetime.date(2023, 3, 6),
#  datetime.date(2017, 5, 12),
#  datetime.date(2016, 6, 13),
#  datetime.date(2021, 4, 6),
#  datetime.date(2020, 10, 1),
#  datetime.date(2022, 10, 21),
#  datetime.date(2015, 11, 27),
#  datetime.date(2015, 10, 23),
#  datetime.date(2018, 1, 19),
#  datetime.date(2021, 10, 6),
#  datetime.date(2021, 1, 20),
#  datetime.date(2020, 9, 15),
#  datetime.date(2015, 6, 19),
#  datetime.date(2017, 8, 14),
#  datetime.date(2020, 10, 19),
#  datetime.date(2018, 9, 4),
#  datetime.date(2023, 4, 14),
#  datetime.date(2016, 11, 1),
#  datetime.date(2018, 11, 22),
#  datetime.date(2020, 12, 11),
#  datetime.date(2024, 1, 16),
#  datetime.date(2018, 12, 28),
#  datetime.date(2015, 6, 24),
#  datetime.date(2022, 9, 1),
#  datetime.date(2021, 10, 15),
#  datetime.date(2021, 12, 7),
#  datetime.date(2016, 8, 1),
#  datetime.date(2019, 2, 22),
#  datetime.date(2016, 8, 10),
#  datetime.date(2018, 5, 24),
#  datetime.date(2023, 12, 13),
#  datetime.date(2021, 4, 13),
#  datetime.date(2024, 9, 12),
#  datetime.date(2022, 12, 15),
#  datetime.date(2023, 6, 21),
#  datetime.date(2017, 1, 30),
#  datetime.date(2021, 8, 10),
#  datetime.date(2017, 12, 29),
#  datetime.date(2021, 6, 8),
#  datetime.date(2023, 1, 5),
#  datetime.date(2015, 10, 19),
#  datetime.date(2017, 2, 27),
#  datetime.date(2024, 2, 1),
#  datetime.date(2019, 11, 14),
#  datetime.date(2016, 10, 26),
#  datetime.date(2017, 12, 12),
#  datetime.date(2017, 7, 10),
#  datetime.date(2015, 6, 15),
#  datetime.date(2019, 3, 6),
#  datetime.date(2020, 4, 9),
#  datetime.date(2016, 2, 19),
#  datetime.date(2016, 5, 13),
#  datetime.date(2021, 11, 17),
#  datetime.date(2019, 11, 22),
#  datetime.date(2015, 6, 2),
#  datetime.date(2021, 12, 10),
#  datetime.date(2020, 4, 29),
#  datetime.date(2021, 3, 5),
#  datetime.date(2023, 6, 5),
#  datetime.date(2022, 6, 20),
#  datetime.date(2021, 3, 12),
#  datetime.date(2015, 12, 2),
#  datetime.date(2024, 1, 30),
#  datetime.date(2018, 6, 19),
#  datetime.date(2015, 12, 8),
#  datetime.date(2015, 9, 25),
#  datetime.date(2019, 4, 25),
#  datetime.date(2022, 10, 13),
#  datetime.date(2022, 12, 14),
#  datetime.date(2015, 8, 12),
#  datetime.date(2017, 7, 24),
#  datetime.date(2018, 11, 13),
#  datetime.date(2023, 1, 13),
#  datetime.date(2020, 10, 15),
#  datetime.date(2023, 3, 20),
#  datetime.date(2021, 2, 4),
#  datetime.date(2018, 5, 10),
#  datetime.date(2015, 9, 4),
#  datetime.date(2020, 8, 25),
#  datetime.date(2019, 3, 18),
#  datetime.date(2020, 10, 27),
#  datetime.date(2021, 1, 1),
#  datetime.date(2015, 7, 16),
#  datetime.date(2016, 4, 7),
#  datetime.date(2023, 5, 2),
#  datetime.date(2021, 8, 31),
#  datetime.date(2023, 3, 27),
#  datetime.date(2020, 3, 20),
#  datetime.date(2017, 5, 4),
#  datetime.date(2024, 6, 7),
#  datetime.date(2019, 11, 15),
#  datetime.date(2016, 7, 19),
#  datetime.date(2019, 5, 20),
#  datetime.date(2020, 2, 4),
#  datetime.date(2016, 6, 21),
#  datetime.date(2016, 10, 28),
#  datetime.date(2021, 6, 4),
#  datetime.date(2016, 2, 22),
#  datetime.date(2017, 9, 8),
#  datetime.date(2019, 6, 4),
#  datetime.date(2023, 2, 9),
#  datetime.date(2017, 12, 11),
#  datetime.date(2024, 7, 5),
#  datetime.date(2018, 7, 12),
#  datetime.date(2020, 8, 14),
#  datetime.date(2023, 7, 14),
#  datetime.date(2016, 4, 1),
#  datetime.date(2015, 7, 22),
#  datetime.date(2020, 12, 24),
#  datetime.date(2016, 9, 1),
#  datetime.date(2017, 10, 25),
#  datetime.date(2020, 3, 2),
#  datetime.date(2024, 1, 3),
#  datetime.date(2021, 5, 10),
#  datetime.date(2015, 7, 8),
#  datetime.date(2023, 7, 27),
#  datetime.date(2018, 5, 1),
#  datetime.date(2017, 10, 30),
#  datetime.date(2019, 5, 28),
#  datetime.date(2022, 12, 12),
#  datetime.date(2019, 12, 30),
#  datetime.date(2021, 9, 23),
#  datetime.date(2018, 5, 25),
#  datetime.date(2021, 10, 26),
#  datetime.date(2019, 12, 11),
#  datetime.date(2021, 2, 18),
#  datetime.date(2022, 9, 20),
#  datetime.date(2020, 11, 26),
#  datetime.date(2019, 4, 3),
#  datetime.date(2021, 8, 25),
#  datetime.date(2017, 5, 9),
#  datetime.date(2018, 1, 1),
#  datetime.date(2021, 8, 18),
#  datetime.date(2016, 6, 3),
#  datetime.date(2021, 10, 1),
#  datetime.date(2015, 4, 23),
#  datetime.date(2017, 6, 15),
#  datetime.date(2017, 12, 6),
#  datetime.date(2018, 6, 28),
#  datetime.date(2016, 12, 12),
#  datetime.date(2021, 7, 20),
#  datetime.date(2015, 6, 22),
#  datetime.date(2021, 11, 18),
#  datetime.date(2022, 7, 29),
#  datetime.date(2015, 5, 29),
#  datetime.date(2020, 1, 24),
#  datetime.date(2021, 10, 28),
#  datetime.date(2018, 12, 21),
#  datetime.date(2019, 3, 19),
#  datetime.date(2016, 2, 12),
#  datetime.date(2019, 12, 6),
#  datetime.date(2016, 7, 28),
#  datetime.date(2019, 3, 22),
#  datetime.date(2020, 2, 17),
#  datetime.date(2021, 4, 12),
#  datetime.date(2019, 1, 22),
#  datetime.date(2018, 7, 5),
#  datetime.date(2015, 5, 19),
#  datetime.date(2016, 9, 13),
#  datetime.date(2015, 6, 29),
#  datetime.date(2018, 1, 29),
#  datetime.date(2018, 5, 22),
#  datetime.date(2019, 1, 21),
#  datetime.date(2015, 4, 28),
#  datetime.date(2015, 4, 13),
#  datetime.date(2022, 9, 22),
#  datetime.date(2019, 12, 2),
#  datetime.date(2016, 6, 27),
#  datetime.date(2019, 1, 29),
#  datetime.date(2023, 4, 27),
#  datetime.date(2016, 2, 15),
#  datetime.date(2022, 7, 13),
#  datetime.date(2017, 4, 20),
#  datetime.date(2016, 1, 21),
#  datetime.date(2019, 1, 8),
#  datetime.date(2021, 10, 18),
#  datetime.date(2018, 5, 9),
#  datetime.date(2023, 8, 8),
#  datetime.date(2022, 8, 30),
#  datetime.date(2021, 6, 30),
#  datetime.date(2022, 7, 1),
#  datetime.date(2023, 7, 18),
#  datetime.date(2021, 5, 4),
#  datetime.date(2021, 3, 30),
#  datetime.date(2019, 8, 1),
#  datetime.date(2024, 7, 8),
#  datetime.date(2023, 7, 13),
#  datetime.date(2024, 9, 4),
#  datetime.date(2019, 9, 19),
#  datetime.date(2015, 5, 6),
#  datetime.date(2023, 7, 17),
#  datetime.date(2016, 1, 6),
#  datetime.date(2021, 7, 5),
#  datetime.date(2018, 3, 19),
#  datetime.date(2019, 6, 3),
#  datetime.date(2022, 9, 29),
#  datetime.date(2019, 10, 18),
#  datetime.date(2024, 3, 28),
#  datetime.date(2017, 9, 7),
#  datetime.date(2018, 2, 5),
#  datetime.date(2016, 2, 24),
#  datetime.date(2020, 12, 15),
#  datetime.date(2017, 3, 2),
#  datetime.date(2017, 2, 20),
#  datetime.date(2020, 4, 27),
#  datetime.date(2023, 4, 3),
#  datetime.date(2018, 6, 8),
#  datetime.date(2020, 7, 10),
#  datetime.date(2019, 6, 12),
#  datetime.date(2022, 10, 11),
#  datetime.date(2023, 11, 6),
#  datetime.date(2018, 8, 1),
#  datetime.date(2017, 5, 19),
#  datetime.date(2016, 4, 22),
#  datetime.date(2018, 4, 16),
#  datetime.date(2021, 10, 7),
#  datetime.date(2020, 9, 4),
#  datetime.date(2021, 12, 3),
#  datetime.date(2015, 5, 15),
#  datetime.date(2024, 3, 11),
#  datetime.date(2020, 10, 30),
#  datetime.date(2024, 8, 22),
#  datetime.date(2022, 6, 7),
#  datetime.date(2016, 11, 14),
#  datetime.date(2021, 2, 16),
#  datetime.date(2023, 8, 2),
#  datetime.date(2016, 6, 28),
#  datetime.date(2016, 2, 9),
#  datetime.date(2018, 8, 8),
#  datetime.date(2023, 11, 23),
#  datetime.date(2023, 6, 16),
#  datetime.date(2015, 10, 6),
#  datetime.date(2016, 1, 13),
#  datetime.date(2023, 8, 21),
#  datetime.date(2019, 1, 31),
#  datetime.date(2022, 3, 15),
#  datetime.date(2019, 2, 26),
#  datetime.date(2018, 10, 15),
#  datetime.date(2020, 9, 2),
#  datetime.date(2024, 6, 21),
#  datetime.date(2018, 8, 9),
#  datetime.date(2022, 7, 12),
#  datetime.date(2024, 6, 28),
#  datetime.date(2016, 8, 31),
#  datetime.date(2022, 3, 17),
#  datetime.date(2022, 5, 6),
#  datetime.date(2017, 9, 11),
#  datetime.date(2017, 2, 8),
#  datetime.date(2020, 5, 14),
#  datetime.date(2022, 2, 21),
#  datetime.date(2024, 7, 23),
#  datetime.date(2022, 3, 29),
#  datetime.date(2020, 8, 17),
#  datetime.date(2017, 2, 24),
#  datetime.date(2015, 6, 25),
#  datetime.date(2015, 12, 28),
#  datetime.date(2017, 6, 30),
#  datetime.date(2020, 11, 30),
#  datetime.date(2019, 2, 11),
#  datetime.date(2016, 11, 8),
#  datetime.date(2019, 2, 20),
#  datetime.date(2015, 4, 6),
#  datetime.date(2018, 6, 14),
#  datetime.date(2016, 1, 22),
#  datetime.date(2022, 7, 19),
#  datetime.date(2022, 11, 11),
#  datetime.date(2016, 8, 24),
#  datetime.date(2023, 1, 18),
#  datetime.date(2016, 3, 29),
#  datetime.date(2017, 4, 24),
#  datetime.date(2021, 6, 18),
#  datetime.date(2016, 8, 9),
#  datetime.date(2021, 6, 23),
#  datetime.date(2019, 6, 20),
#  datetime.date(2023, 4, 19),
#  datetime.date(2016, 4, 14),
#  datetime.date(2016, 3, 10),
#  datetime.date(2018, 2, 7),
#  datetime.date(2017, 9, 20),
#  datetime.date(2022, 9, 23),
#  datetime.date(2016, 2, 2),
#  datetime.date(2023, 4, 25),
#  datetime.date(2019, 11, 11),
#  datetime.date(2018, 2, 21),
#  datetime.date(2020, 8, 28),
#  datetime.date(2020, 1, 2),
#  datetime.date(2020, 4, 17),
#  datetime.date(2019, 3, 25),
#  datetime.date(2018, 3, 27),
#  datetime.date(2015, 9, 21),
#  datetime.date(2015, 7, 31),
#  datetime.date(2021, 3, 11),
#  datetime.date(2017, 2, 14),
#  datetime.date(2024, 1, 11),
#  datetime.date(2024, 2, 9),
#  datetime.date(2018, 10, 23),
#  datetime.date(2016, 4, 15),
#  datetime.date(2020, 12, 28),
#  datetime.date(2015, 8, 14),
#  datetime.date(2019, 3, 4),
#  datetime.date(2019, 4, 12),
#  datetime.date(2022, 8, 19),
#  datetime.date(2016, 1, 27),
#  datetime.date(2021, 8, 3),
#  datetime.date(2017, 5, 10),
#  datetime.date(2017, 3, 31),
#  datetime.date(2022, 6, 1),
#  datetime.date(2018, 5, 15),
#  datetime.date(2024, 4, 4),
#  datetime.date(2023, 2, 15),
#  datetime.date(2023, 4, 17),
#  datetime.date(2023, 11, 27),
#  datetime.date(2024, 3, 22),
#  datetime.date(2024, 7, 3),
#  datetime.date(2023, 7, 25),
#  datetime.date(2021, 12, 29),
#  datetime.date(2023, 7, 28),
#  datetime.date(2023, 12, 28),
#  datetime.date(2024, 5, 30),
#  datetime.date(2024, 7, 11),
#  datetime.date(2017, 4, 26),
#  datetime.date(2016, 1, 14),
#  datetime.date(2024, 4, 5),
#  datetime.date(2023, 5, 16),
#  datetime.date(2021, 4, 19),
#  datetime.date(2018, 5, 7),
#  datetime.date(2015, 5, 1),
#  datetime.date(2015, 5, 12),
#  datetime.date(2018, 6, 22),
#  datetime.date(2019, 6, 27),
#  datetime.date(2016, 8, 16),
#  datetime.date(2019, 7, 2),
#  datetime.date(2024, 4, 25),
#  datetime.date(2016, 5, 31),
#  datetime.date(2017, 12, 26),
#  datetime.date(2018, 6, 11),
#  datetime.date(2023, 3, 10),
#  datetime.date(2022, 5, 13),
#  datetime.date(2016, 8, 8),
#  datetime.date(2019, 9, 23),
#  datetime.date(2020, 11, 13),
#  datetime.date(2024, 9, 13),
#  datetime.date(2020, 5, 4),
#  datetime.date(2021, 6, 1),
#  datetime.date(2015, 3, 31),
#  datetime.date(2024, 6, 17),
#  datetime.date(2022, 3, 10),
#  datetime.date(2023, 10, 16),
#  datetime.date(2018, 3, 22),
#  datetime.date(2015, 3, 24),
#  datetime.date(2020, 11, 10),
#  datetime.date(2024, 4, 30),
#  datetime.date(2019, 11, 6),
#  datetime.date(2017, 12, 19),
#  datetime.date(2023, 4, 18),
#  datetime.date(2018, 11, 30),
#  datetime.date(2019, 10, 15),
#  datetime.date(2020, 3, 27),
#  datetime.date(2017, 11, 13),
#  datetime.date(2024, 4, 1),
#  datetime.date(2016, 9, 23),
#  datetime.date(2016, 7, 15),
#  datetime.date(2017, 5, 29),
#  datetime.date(2018, 3, 7),
#  datetime.date(2016, 4, 5),
#  datetime.date(2018, 11, 1),
#  datetime.date(2020, 11, 2),
#  datetime.date(2023, 6, 7),
#  datetime.date(2021, 11, 16),
#  datetime.date(2019, 3, 21),
#  datetime.date(2021, 5, 27),
#  datetime.date(2024, 5, 23),
#  datetime.date(2016, 9, 9),
#  datetime.date(2021, 6, 16),
#  datetime.date(2015, 4, 16),
#  datetime.date(2017, 3, 16),
#  datetime.date(2023, 10, 12),
#  datetime.date(2016, 1, 1),
#  datetime.date(2020, 11, 16),
#  datetime.date(2017, 4, 12),
#  datetime.date(2016, 5, 10),
#  datetime.date(2019, 7, 16),
#  datetime.date(2021, 4, 20),
#  datetime.date(2019, 9, 6),
#  datetime.date(2015, 8, 18),
#  datetime.date(2021, 9, 24),
#  datetime.date(2016, 10, 12),
#  datetime.date(2022, 4, 12),
#  datetime.date(2017, 10, 12),
#  datetime.date(2023, 7, 31),
#  datetime.date(2020, 1, 10),
#  datetime.date(2018, 8, 30),
#  datetime.date(2015, 7, 1),
#  datetime.date(2023, 9, 29),
#  datetime.date(2023, 1, 25),
#  datetime.date(2016, 12, 1),
#  datetime.date(2017, 6, 16),
#  datetime.date(2021, 1, 5),
#  datetime.date(2021, 1, 22),
#  datetime.date(2021, 4, 23),
#  datetime.date(2023, 4, 13),
#  datetime.date(2019, 8, 16),
#  datetime.date(2019, 11, 21),
#  datetime.date(2020, 6, 30),
#  datetime.date(2016, 8, 26),
#  datetime.date(2017, 1, 31),
#  datetime.date(2018, 8, 7),
#  datetime.date(2017, 11, 6),
#  datetime.date(2015, 10, 8),
#  datetime.date(2022, 11, 9),
#  datetime.date(2024, 9, 3),
#  datetime.date(2018, 3, 29),
#  datetime.date(2016, 12, 29),
#  datetime.date(2023, 1, 10),
#  datetime.date(2019, 4, 17),
#  datetime.date(2023, 4, 10),
#  datetime.date(2020, 7, 16),
#  datetime.date(2024, 2, 5),
#  datetime.date(2024, 4, 19),
#  datetime.date(2022, 1, 11),
#  datetime.date(2022, 8, 10),
#  datetime.date(2019, 10, 29),
#  datetime.date(2018, 11, 28),
#  datetime.date(2017, 8, 3),
#  datetime.date(2017, 11, 14),
#  datetime.date(2016, 3, 30),
#  datetime.date(2017, 3, 17),
#  datetime.date(2018, 1, 8),
#  datetime.date(2020, 8, 5),
#  datetime.date(2019, 8, 13),
#  datetime.date(2024, 3, 25),
#  datetime.date(2017, 3, 29),
#  datetime.date(2020, 12, 23),
#  datetime.date(2021, 5, 13),
#  datetime.date(2021, 12, 8),
#  datetime.date(2021, 9, 14),
#  datetime.date(2023, 12, 26),
#  datetime.date(2017, 4, 28),
#  datetime.date(2021, 3, 23),
#  datetime.date(2019, 9, 10),
#  datetime.date(2024, 9, 6),
#  datetime.date(2022, 12, 6),
#  datetime.date(2023, 9, 26),
#  datetime.date(2017, 9, 13),
#  datetime.date(2018, 4, 3),
#  datetime.date(2022, 11, 29),
#  datetime.date(2023, 4, 12),
#  datetime.date(2022, 8, 26),
#  datetime.date(2015, 9, 3),
#  datetime.date(2022, 3, 16),
#  datetime.date(2019, 11, 7),
#  datetime.date(2023, 6, 23),
#  datetime.date(2023, 9, 7),
#  datetime.date(2023, 12, 1),
#  datetime.date(2017, 7, 12),
#  datetime.date(2021, 7, 2),
#  datetime.date(2017, 10, 9),
#  datetime.date(2015, 5, 7),
#  datetime.date(2017, 9, 28),
#  datetime.date(2016, 3, 15),
#  datetime.date(2020, 1, 16),
#  datetime.date(2024, 9, 19),
#  datetime.date(2019, 10, 4),
#  datetime.date(2018, 1, 3),
#  datetime.date(2017, 8, 31),
#  datetime.date(2022, 10, 31),
#  datetime.date(2020, 5, 7),
#  datetime.date(2021, 12, 30),
#  datetime.date(2015, 12, 23),
#  datetime.date(2017, 2, 15),
#  datetime.date(2018, 6, 27),
#  datetime.date(2018, 11, 19),
#  datetime.date(2024, 5, 3),
#  datetime.date(2019, 4, 22),
#  datetime.date(2022, 9, 2),
#  datetime.date(2017, 4, 3),
#  ...}

# %%
def rename_ohlc_columns(df: pl.DataFrame) -> pl.DataFrame:

    column_mapping = {"o": "open", "h": "high", "l": "low", "c": "close", "v": "volume"}
    df = df.rename(column_mapping)

    return df

# %%
PORTFOLIO_VALUE = 10_00_000 # 10 Lacs
RPT_PCT = 0.01 # 1% RPT
SLIPPAGE_ = 0.001
LEVERAGE_ = 5

# %%
def calculate_signals(df, ema_length, x_days, pct):
    # Calculate X-day High/Low and 20 EMA
    df['X_High'] = df['high'].rolling(x_days).mean()
    df['X_Low'] = df['low'].rolling(x_days).mean()
    df['EMA_20'] = df['close'].ewm(span=ema_length, adjust=False).mean()
    
    # Trend conditions
    df['EMA_Trend'] = df['EMA_20'] > df['EMA_20'].shift(1)
    
    # Signal conditions
    df['Buy_Signal'] = (
        (df['close'] > df['X_High'].shift(1) * (1 + (pct / 100))) & 
        (df['EMA_Trend']) & 
        (df['close'] > df['EMA_20'])
    )
    df['Sell_Signal'] = (
        (df['close'] < df['X_Low'].shift(1) * (1 - (pct / 100))) & 
        (~df['EMA_Trend']) & 
        (df['close'] < df['EMA_20'])
    )
    return df

# %%
# def backtest(df):
#     position = 0
#     entry_price = 0
#     trades = []
#     trailing_stop = None
    
#     for i in range(len(df)):
#         if df.loc[i, 'Buy_Signal'] and position == 0:
#             position = 1
#             # entry_price = df.loc[i, 'close']
#             trailing_stop_long = df.loc[i, 'EMA_20']
#             # trades.append({'Type': 'Buy', 'Price': entry_price, 'Date': df.loc[i, 'datetime']})
#             entry_time_long = df.loc[i, 'datetime']
#             entry_price_long = df.loc[i, 'close']
#             initial_sl_long = trailing_stop_long
        
#         elif df.loc[i, 'Sell_Signal'] and position == 0:
#             position = -1
#             entry_price = df.loc[i, 'close']
#             trailing_stop_short = df.loc[i, 'EMA_20']
#             # trades.append({'Type': 'Sell', 'Price': entry_price, 'Date': df.loc[i, 'datetime']})
#             entry_time_short = df.loc[i, 'datetime']
#             entry_price_short = df.loc[i, 'close']
#             initial_sl_short = trailing_stop_short
        
#         elif position == 1:
#             if df.loc[i, 'low'] < trailing_stop_long:
#                 # trades.append({'Type': 'Exit', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 position = 0
#                 exit_time_long = df.loc[i, 'datetime']
#                 exit_price_long = trailing_stop_long
#                 points_long = exit_price_long - entry_price_long
                
#             elif df.loc[i, 'Add_Long']:
#                 # trades.append({'Type': 'Add Long', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 entry_time_long = df.loc[i, 'datetime']
#                 entry_price_long = df.loc[i, 'close']
#                 initial_sl_long = trailing_stop_long
#                 trailing_stop_long = max(trailing_stop_long, df.loc[i, 'EMA_20'])
        
#         elif position == -1:
#             if df.loc[i, 'high'] > trailing_stop:
#                 trades.append({'Type': 'Exit', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 position = 0
#             elif df.loc[i, 'Add_Short']:
#                 trades.append({'Type': 'Add Short', 'Price': df.loc[i, 'close'], 'Date': df.loc[i, 'datetime']})
#                 trailing_stop = min(trailing_stop, df.loc[i, 'EMA_20'])
    
#     return pd.DataFrame(trades)

# %%
def backtest(df, y_days, fractal_num):
    # Variables for long trades
    long_position = 0  # 0 = no position, 1 = long
    long_entry_price = 0
    long_entry_date = None
    long_trades = []
    tradebook = pd.DataFrame()
    tradebook_long = pd.DataFrame()
    tradebook_short = pd.DataFrame()
    long_trailing_stop = 0
    # Variables for short trades
    short_position = 0  # 0 = no position, -1 = short
    short_entry_price = 0
    short_entry_date = None
    short_trades = []
    short_trailing_stop = None

    can_add_long = False
    can_add_short = False

    trade_number = 0
    lock_initial_sl = False
    first_sl = 0

    lock_initial_sl_2 = False
    first_sl_2 = 0

    for i in range(len(df)):
        # Entry signals for long trades
        
        if df.loc[i, 'Buy_Signal'] and long_position == 0:
            long_position = 1
            long_entry_price = df.loc[i, 'close']
            long_entry_date = df.loc[i, 'datetime']
            # long_trailing_stop = df.loc[i, 'EMA_20']
            long_initial_sl = df.loc[i, 'X_Low']

            tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
                'Trade No.': trade_number,
                'Entry_Date': df.loc[i, 'datetime'],
                'Exit_Date': None,
                'Trade_Type': 'Long',
                'Entry_Price': df.loc[i, 'close'],
                'Initial SL': long_initial_sl,
                'Trailing SL': long_trailing_stop,
                'Exit_Price': None,
                # 'Profit/Loss': None  # Filled when exited
            }])], ignore_index=True)

            if not lock_initial_sl:
                first_sl = long_initial_sl
                lock_initial_sl = True
                
        # Exit or add to long position
        if long_position == 1:
            
            y_days_low = df['low'].rolling(y_days).min().iloc[i-1]
            y_days_high = df['high'].rolling(y_days).max().iloc[i-1]

            if all(df.loc[i - j, 'low'] >= df.loc[i - fractal_num, 'low'] for j in range(0, ((fractal_num * 2) + 1))):
                long_trailing_stop = df.loc[i - fractal_num, 'low']
            
            # print(df.iloc[i]['datetime'], y_days_high, y_days_low)
            
            if df.loc[i, 'low'] <= long_initial_sl:
                tradebook_long.loc[
                    (tradebook_long['Trade No.'] == trade_number),
                    ['Exit_Date', 'Exit_Price', 'Exit Remark', 'Trailing SL']
                ] = [df.loc[i, 'datetime'] , long_initial_sl , 'Initial SL Hit', long_trailing_stop]
                long_position = 0
                can_add_long = False
                trade_number += 1
                lock_initial_sl = False
                first_sl = 0
                long_trailing_stop = 0
            
            elif df.loc[i, 'close'] <= long_trailing_stop:
                tradebook_long.loc[
                    (tradebook_long['Trade No.'] == trade_number),
                    ['Exit_Date', 'Exit_Price', 'Exit Remark', 'Trailing SL']
                ] = [df.loc[i, 'datetime'] , df.loc[i, 'close'] , 'Trailing SL Hit', long_trailing_stop]
                long_position = 0
                can_add_long = False
                trade_number += 1
                lock_initial_sl = False
                first_sl = 0
                long_trailing_stop = 0

            elif (df.loc[i, 'low'] <= y_days_low) and not can_add_long:
                # Previous Y Candle Low Breached, confirmation found. Add position on high break
                can_add_long = True

            if can_add_long and long_position:
                if df.loc[i, 'high'] >= y_days_high:
                    tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
                        'Trade No.': trade_number,
                        'Entry_Date': df.loc[i, 'datetime'],
                        'Exit_Date': None,
                        'Trade_Type': 'Add_Long',
                        'Entry_Price': y_days_high,
                        'Initial SL': first_sl,
                        'Trailing SL': long_trailing_stop,
                        'Exit_Price': None,
                        # 'Profit/Loss': None  # Filled when exited
                    }])], ignore_index=True)
                    can_add_long = False

    tradebook = pd.concat([tradebook, tradebook_long], ignore_index=True)
    return tradebook

# %%
# def backtest(df, y_days):
#     # Variables for long trades
#     long_position = 0  # 0 = no position, 1 = long
#     long_entry_price = 0
#     long_entry_date = None
#     long_trades = []
#     tradebook = pd.DataFrame()
#     tradebook_long = pd.DataFrame()
#     tradebook_short = pd.DataFrame()
#     long_trailing_stop = None
#     # Variables for short trades
#     short_position = 0  # 0 = no position, -1 = short
#     short_entry_price = 0
#     short_entry_date = None
#     short_trades = []
#     short_trailing_stop = None

#     can_add_long = False
#     can_add_short = False

#     trade_number = 0

#     for i in range(len(df)):
#         # Entry signals for long trades
#         long_trailing_stop = df.loc[i, 'EMA_20']
#         short_trailing_stop = df.loc[i, 'EMA_20']
        
#         if df.loc[i, 'Buy_Signal'] and long_position == 0:
#             long_position = 1
#             long_entry_price = df.loc[i, 'close']
#             long_entry_date = df.loc[i, 'datetime']
#             long_trailing_stop = df.loc[i, 'EMA_20']
#             long_initial_sl = df.loc[i, 'X_Low']

#             tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
#                 'Trade No.': trade_number,
#                 'Entry_Date': df.loc[i, 'datetime'],
#                 'Exit_Date': None,
#                 'Trade_Type': 'Long',
#                 'Entry_Price': df.loc[i, 'close'],
#                 'Initial SL': long_initial_sl,
#                 'Exit_Price': None,
#                 # 'Profit/Loss': None  # Filled when exited
#             }])], ignore_index=True)

#         # Exit or add to long position
#         if long_position == 1:
            
#             y_days_low = df['low'].rolling(y_days).min().iloc[i-1]
#             y_days_high = df['high'].rolling(y_days).max().iloc[i-1]
            
#             # print(df.iloc[i]['datetime'], y_days_high, y_days_low)
            
#             if df.loc[i, 'low'] <= long_initial_sl:
#                 tradebook_long.loc[
#                     (tradebook_long['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] , long_initial_sl]
#                 long_position = 0
#                 can_add_long = False
#                 trade_number += 1
            
#             elif df.loc[i, 'close'] <= long_trailing_stop:
#                 tradebook_long.loc[
#                     (tradebook_long['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] , df.loc[i, 'close']]
#                 long_position = 0
#                 can_add_long = False
#                 trade_number += 1

#             elif (df.loc[i, 'low'] <= y_days_low) and not can_add_long:
#                 # Previous Y Candle Low Breached, confirmation found. Add position on high break
#                 can_add_long = True

#             if can_add_long and long_position:
#                 if df.loc[i, 'high'] >= y_days_high:
#                     tradebook_long = pd.concat([tradebook_long, pd.DataFrame([{
#                         'Trade No.': trade_number,
#                         'Entry_Date': df.loc[i, 'datetime'],
#                         'Exit_Date': None,
#                         'Trade_Type': 'Add_Long',
#                         'Entry_Price': y_days_high,
#                         'Initial SL': long_initial_sl,
#                         'Exit_Price': None,
#                         # 'Profit/Loss': None  # Filled when exited
#                     }])], ignore_index=True)
#                     can_add_long = False

#     for i in range(len(df)):
        
#         # Entry signals for long trades
#         long_trailing_stop = df.loc[i, 'EMA_20']
#         short_trailing_stop = df.loc[i, 'EMA_20']

#         # Entry signals for short trades
#         if df.loc[i, 'Sell_Signal'] and short_position == 0:
#             short_position = -1
#             short_entry_price = df.loc[i, 'close']
#             short_entry_date = df.loc[i, 'datetime']
#             short_trailing_stop = df.loc[i, 'EMA_20']
#             short_initial_sl = df.loc[i, 'X_High']

#             tradebook_short = pd.concat([tradebook_short, pd.DataFrame([{
#                 'Trade No.': trade_number,
#                 'Entry_Date': df.loc[i, 'datetime'],
#                 'Exit_Date': None,
#                 'Trade_Type': 'Short',
#                 'Entry_Price': df.loc[i, 'close'],
#                 'Initial SL': short_initial_sl,
#                 'Exit_Price': None,
#                 # 'Profit/Loss': None  # Filled when exited
#             }])], ignore_index=True)

#         if short_position == -1:
            
#             y_days_low = df['low'].rolling(y_days).min().iloc[i-1]
#             y_days_high = df['high'].rolling(y_days).max().iloc[i-1]
            
#             # print(df.iloc[i]['datetime'], y_days_high, y_days_low)
            
#             if df.loc[i, 'high'] >= short_initial_sl:
#                 tradebook_short.loc[
#                     (tradebook_short['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] ,short_initial_sl]
#                 short_position = 0
#                 can_add_short = False
#                 trade_number += 1
            
#             elif df.loc[i, 'close'] >= short_trailing_stop:
#                 tradebook_short.loc[
#                     (tradebook_short['Trade No.'] == trade_number),
#                     ['Exit_Date', 'Exit_Price']
#                 ] = [df.loc[i, 'datetime'] , df.loc[i, 'close']]
#                 short_position = 0
#                 can_add_short = False
#                 trade_number += 1

#             elif (df.loc[i, 'high'] >= y_days_high) and not can_add_short:
#                 # Previous Y Candle High Breached, confirmation found. Add position on low break
#                 can_add_short = True

#             if can_add_short and short_position:
#                 if df.loc[i, 'low'] <= y_days_low:
#                     tradebook_short = pd.concat([tradebook_short, pd.DataFrame([{
#                         'Trade No.': trade_number,
#                         'Entry_Date': df.loc[i, 'datetime'],
#                         'Exit_Date': None,
#                         'Trade_Type': 'Add_Short',
#                         'Entry_Price': y_days_low,
#                         'Initial SL': short_initial_sl,
#                         'Exit_Price': None,
#                         # 'Profit/Loss': None  # Filled when exited
#                     }])], ignore_index=True)
#                     can_add_short = False
    
#     tradebook = pd.concat([tradebook_long, tradebook_short], ignore_index=True)
#     return tradebook

# %%
ema_length = 55
x_days = 28
y_days = 7
pct = 1.05
RPT = 5
df = bnf_1min
df = calculate_signals(df, ema_length=ema_length, x_days=x_days, pct=pct)
tb = backtest(df, y_days, 3)
tb = tb.sort_values(by='Entry_Date')
variation = f'EMA: {ema_length}, X: {x_days}, Y: {y_days}, PCT: {pct}%, RPT: {RPT}%'
# Out:
# /tmp/ipykernel_2691/3840507368.py:78: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Trailing SL Hit' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_long.loc[

# %%
import numpy as np
portfolio = 10000000
tb['PnL'] = np.where(
    tb['Trade_Type'].isin(['Long', 'Add_Long']),  # For Long and Add_Long
    tb['Exit_Price'] - tb['Entry_Price'],
    np.where(
        tb['Trade_Type'].isin(['Short', 'Add_Short']),  # For Short and Add_Short
        tb['Entry_Price'] - tb['Exit_Price'],
        0  # Default case if Trade_Type is something unexpected
    )
)

tb['Slippage'] = SLIPPAGE_ * (tb['Entry_Price'] + tb['Exit_Price'])
tb['PnL w cs'] = tb['PnL'] - tb['Slippage']
tb['Qty'] = abs(RPT / 100 * portfolio / (tb['Entry_Price'] - tb['Initial SL']))
tb['Profit_Loss INR'] = tb['Qty'] * tb['PnL w cs']
tb['ROI%'] = tb['Profit_Loss INR'] * 100 / portfolio

# %%
tb['Cumulative_PnL'] = tb['PnL w cs'].cumsum()

# %%
# tb.to_csv('GOLD TRADE CHECK JJPP.csv', index=False)

# %%
tb = tb.reset_index()
# tb

# %%
tb_long_only = tb[(tb['Trade_Type'] == 'Long') | (tb['Trade_Type'] == 'Add_Long')].copy()
tb_long_only['Cumulative_PnL'] = tb_long_only['PnL w cs'].cumsum()
tb_short_only = tb[(tb['Trade_Type'] == 'Short') | (tb['Trade_Type'] == 'Add_Short')].copy()
tb_short_only['Cumulative_PnL'] = tb_short_only['PnL w cs'].cumsum()

# %%
# tb2 = tb.groupby('Trade No.', as_index=False)['PnL w cs'].sum()
# tb2['Cumulative_PnL'] = tb2['PnL w cs'].cumsum()

# %%
# plot_cumulative_pnl(tb_long_only)
# print(tb_long_only['PnL w cs'].sum())

# %%
# plot_cumulative_pnl(tb_short_only)
# print(tb_short_only['PnL w cs'].sum())

# %%
# plot_cumulative_pnl(tb)
# print(tb['PnL w cs'].sum())

# %%
# plot_cumulative_pnl(tb2)
# print(tb2['PnL w cs'].sum())

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2015, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2015, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI%"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI%"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI%"] > 0]["ROI%"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI%"] < 0]["ROI%"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI%"].cumsum() - year_trades["ROI%"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI%"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI%"] > 0]["ROI%"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI%"].cumsum() - combined_df_sorted["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation

    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    
    # print(f'{overall_total_roi} , {overall_max_drawdown} , {overall_roi_dd_ratio}')
    
    return {overall_roi_dd_ratio: stats_df8}

# %%
tb_long_only['Entry_Date'] = pd.to_datetime(tb_long_only['Entry_Date'])
tb_long_only['Trade Year'] = tb_long_only['Entry_Date'].dt.year
tb_long_only['ROI% w cs'] = tb_long_only['ROI%']

# %%
stats = generate_stats(tb_long_only, variation)
lol = pd.DataFrame()
for x, y in stats.items():
    lol = pd.DataFrame(y)

lol
# Out:
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 
# 140  4.6576     13825.4504        2022    4.6576
# 141  2.8505     15340.4904        2022    2.8505
# 142  1.5239     16314.9904        2022    1.5239
# 143 -0.6126     16216.1344        2022   -0.6126
# 144 -2.1329     15874.4144        2022   -2.1329
# 145 -5.6647     14999.9055        2022   -5.6647
# 146 -5.4641     13794.4431        2022   -5.4641
# 147  2.4653     14251.1931        2022    2.4653
# 148 -1.7118     13531.7681        2022   -1.7118
# 149  0.4857     13632.5961        2022    0.4857
# 150  5.7952     14789.5171        2022    5.7952
# 151 -0.2533     14742.6511        2022   -0.2533
# 152 16.6902     17350.2491        2022   16.6902
# 153  7.5194     19385.2751        2022    7.5194
# 154  5.0400     21085.9671        2022    5.0400
# 155  3.7482     22537.4101        2022    3.7482
# 156  1.2048     23195.0601        2023    1.2048
# 157  0.9018     23712.5701        2023    0.9018
# 158 -0.1070     23638.4891        2023   -0.1070
# 159 -0.7254     23063.9081        2023   -0.7254
# 160 -0.8726     22348.1861        2023   -0.8726
# 161 21.3510     26366.2871        2023   21.3510
# 162  1.3232     27403.4101        2023    1.3232
# 163  1.5369     28568.6611        2023    1.5369
# 164 -0.9258     28379.8161        2023   -0.9258
# 165 -1.9636     27842.6231        2023   -1.9636
# 166 -2.3565     27410.2081        2023   -2.3565
# 167 -2.5056     27031.4761        2023   -2.5056
# 168 -2.7091     26585.6771        2023   -2.7091
# 169 11.9577     28776.4981        2023   11.9577
# 170 -3.3512     28164.1331        2023   -3.3512
# 171 -3.5347     27437.6541        2023   -3.5347
# 172  8.2566     28948.2021        2023    8.2566
# 173  7.0567     30367.6591        2023    7.0567
# 174  0.4226     30451.9491        2023    0.4226
# 175  3.5970     30904.6071        2023    3.5970
# 176 -1.9595     30208.1171        2024   -1.9595
# 177 13.4794     32454.7541        2024   13.4794
# 178 16.5727     36681.7391        2024   16.5727
# 179 31.6225     41433.2481        2024   31.6225
# 180 -1.3488     39402.9821        2024   -1.3488
# 181 -1.2602     37550.8941        2024   -1.2602
# 182 -1.1365     37162.0101        2024   -1.1365
# 183 -5.6091     35825.9528        2024   -5.6091
# 184 -5.6755     34615.0399        2024   -5.6755
# 185 -2.1925     34131.3009        2024   -2.1925
# 186 -2.3512     33581.4959        2024   -2.3512
# 187 -5.6024     32215.0397        2024   -5.6024
# 188 -5.3487     30079.8537        2024   -5.3487
# 189 -5.3283     27818.5417        2024   -5.3283
# 190  0.6122     27985.7527        2024    0.6122
# 191 -0.2716     27897.7087        2024   -0.2716
# 192 -0.3435     27784.6397        2024   -0.3435
# 193 10.7998     30502.1017        2024   10.7998
# 194  5.7775     32632.9777        2024    5.7775
# 195 -0.2080     32460.5527        2024   -0.2080
# 196 -1.0370     31421.2617        2024   -1.0370

# %%
# tb_long_only.to_csv('GOLD Range JJPP.csv', index=False)

# %%
tb_long_only_1 = tb_long_only[tb_long_only['Trade_Type'] == 'Add_Long']
tb_long_only_2 = tb_long_only[tb_long_only['Trade_Type'] == 'Long']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 tb_long_only_1 = tb_long_only[tb_long_only['Trade_Type'] == 'Add_Long']
#       2 tb_long_only_2 = tb_long_only[tb_long_only['Trade_Type'] == 'Long']
#
# NameError: name 'tb_long_only' is not defined

# %%
tb_long_only_1['ROI%'].sum() , tb_long_only_2['ROI%'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 tb_long_only_1['ROI%'].sum() , tb_long_only_2['ROI%'].sum()
#
# NameError: name 'tb_long_only_1' is not defined

# %%
# ema_length = 55
# x_days = 28
# y_days = 7
# pct = 1.05
# RPT = 5

pct_range = [0.5, 0.75, 0.9, 1.05, 1.25, 1.4]

for ema_length in range(25, 81, 5):
    for x_days in range(4, 37, 4):
        for y_days in range(3, 19, 3):
            for pct in pct_range:
                RPT = 5
                variation = f'EMA:{ema_length}, X:{x_days}, Y:{y_days}, PCT:{pct}, RPT:{5}'
                print(variation)
                df = bnf_1min
                df = calculate_signals(df, ema_length=ema_length, x_days=x_days, pct=pct)
                tb = backtest(df, y_days=y_days)
                if len(tb) > 0:
                    tb = tb.sort_values(by='Entry_Date')
                    portfolio = 10000000
                    tb['PnL'] = np.where(
                        tb['Trade_Type'].isin(['Long', 'Add_Long']),  # For Long and Add_Long
                        tb['Exit_Price'] - tb['Entry_Price'],
                        np.where(
                            tb['Trade_Type'].isin(['Short', 'Add_Short']),  # For Short and Add_Short
                            tb['Entry_Price'] - tb['Exit_Price'],
                            0  # Default case if Trade_Type is something unexpected
                        )
                    )
                    
                    tb['Slippage'] = SLIPPAGE_ * (tb['Entry_Price'] + tb['Exit_Price'])
                    tb['PnL w cs'] = tb['PnL'] - tb['Slippage']
                    tb['Qty'] = abs(RPT / 100 * portfolio / (tb['Entry_Price'] - tb['Initial SL']))
                    tb['Profit_Loss INR'] = tb['Qty'] * tb['PnL w cs']
                    tb['ROI%'] = tb['Profit_Loss INR'] * 100 / portfolio
                    tb['Entry_Date'] = pd.to_datetime(tb['Entry_Date'])
                    tb['Trade Year'] = tb['Entry_Date'].dt.year
                    tb_long_only = tb[(tb['Trade_Type'] == 'Long') | (tb['Trade_Type'] == 'Add_Long')].copy()
                    tb_long_only['Cumulative_PnL'] = tb_long_only['PnL w cs'].cumsum()
                    tb_short_only = tb[(tb['Trade_Type'] == 'Short') | (tb['Trade_Type'] == 'Add_Short')].copy()
                    tb_short_only['Cumulative_PnL'] = tb_short_only['PnL w cs'].cumsum()

                    stats1 = generate_stats(tb_long_only, variation)
                    for x, y in stats1.items():
                        if x > 2:
                            print('Long Only')
                            print(pd.DataFrame(y).to_string())
                        break
                    stats2 = generate_stats(tb_short_only, variation)
                    for x, y in stats2.items():
                        if x > 2:
                            print('Short Only')
                            print(pd.DataFrame(y).to_string())
                        break
# Out:
# EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# /tmp/ipykernel_2484/453456106.py:76: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Trailing SL Hit' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_long.loc[
# /tmp/ipykernel_2484/453456106.py:152: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Trailing SL Hit' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_short.loc[
# Long Only
#         Total ROI Total Trades Win Rate Avg Profit% per Trade Avg Loss% per Trade Max Drawdown ROI/DD Ratio                         Variation
# 2015     -10.4907           37  27.0270                9.5618             -3.9300     -53.4513      -0.1963  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2016     110.7251           49  38.7755               10.2685             -2.8126     -45.3811       2.4399  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2017     -24.7094           50  24.0000                5.3332             -2.3344     -58.6098      -0.4216  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2018     -34.4612           41  34.1463                3.8950             -3.2960     -62.1415      -0.5546  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2019      15.7352           53  30.1887                8.4490             -3.2283     -63.4594       0.2480  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2020      52.1499           56  35.7143                7.6980             -2.8280     -48.1340       1.0834  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2021     -56.1503           50  30.0000                3.5960             -3.1454     -52.6194      -1.0671  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2022      40.4968           49  40.8163                6.1063             -2.8148     -38.3656       1.0556  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2023      33.0695           32  37.5000                8.2146             -3.2753     -30.8135       1.0732  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# 2024     124.8223           38  36.8421               12.8036             -2.3665     -34.8992       3.5766  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# Overall  251.1871          455  33.4066                7.5808             -2.9838    -109.6321       2.2912  EMA:25, X:4, Y:3, PCT:0.5, RPT:5
# EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# /tmp/ipykernel_2484/453456106.py:76: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Trailing SL Hit' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_long.loc[
# /tmp/ipykernel_2484/453456106.py:152: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Trailing SL Hit' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_short.loc[
# Long Only
#         Total ROI Total Trades Win Rate Avg Profit% per Trade Avg Loss% per Trade Max Drawdown ROI/DD Ratio                          Variation
# 2015     -33.3079           22  18.1818                9.3994             -3.9392     -39.1528      -0.8507  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2016      89.5199           41  39.0244                9.9028             -2.7570     -37.4115       2.3928  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2017     -23.8991           32  25.0000                3.8688             -2.2854     -45.7482      -0.5224  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2018      -5.2815           24  41.6667                4.3309             -3.4707     -34.6120      -0.1526  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2019      10.9014           33  36.3636                6.7004             -3.3097     -43.0486       0.2532  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2020      32.5295           41  34.1463                6.9959             -2.4227     -33.9253       0.9589  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2021     -19.1174           40  37.5000                3.0021             -2.5659     -31.9564      -0.5982  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2022      43.8966           34  50.0000                4.9361             -2.3539     -24.7778       1.7716  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2023       8.4626           21  33.3333                7.1001             -2.9456     -15.3051       0.5529  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# 2024     123.4230           30  40.0000               14.0479             -2.6560     -39.6582       3.1122  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# Overall  227.1271          318  36.1635                6.9206             -2.8156     -85.5094       2.6562  EMA:25, X:4, Y:3, PCT:0.75, RPT:5
# EMA:25, X:4, Y:3, PCT:0.9, RPT:5
# /tmp/ipykernel_2484/453456106.py:76: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Trailing SL Hit' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_long.loc[
# /tmp/ipykernel_2484/453456106.py:152: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Trailing SL Hit' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tradebook_short.loc[
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 18
#      16 df = bnf_1min
#      17 df = calculate_signals(df, ema_length=ema_length, x_days=x_days, pct=pct)
# ---> 18 tb = backtest(df, y_days=y_days)
#      19 if len(tb) > 0:
#      20     tb = tb.sort_values(by='Entry_Date')
#
# Cell In[14], line 135, in backtest(df, y_days)
#     131         lock_initial_sl_2 = True
#     133 if short_position == -1:
# --> 135     y_days_low = df['low'].rolling(y_days).min().iloc[i-1]
#     136     y_days_high = df['high'].rolling(y_days).max().iloc[i-1]
#     138     # print(df.iloc[i]['datetime'], y_days_high, y_days_low)
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/window/rolling.py:2210, in Rolling.min(self, numeric_only, engine, engine_kwargs)
#    2174 @doc(
#    2175     template_header,
#    2176     create_section_header("Parameters"),
#    (...)
#    2208     engine_kwargs: dict[str, bool] | None = None,
#    2209 ):
# -> 2210     return super().min(
#    2211         numeric_only=numeric_only,
#    2212         engine=engine,
#    2213         engine_kwargs=engine_kwargs,
#    2214     )
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/window/rolling.py:1603, in RollingAndExpandingMixin.min(self, numeric_only, engine, engine_kwargs)
#    1601         return self._numba_apply(sliding_min_max, engine_kwargs, is_max=False)
#    1602 window_func = window_aggregations.roll_min
# -> 1603 return self._apply(window_func, name="min", numeric_only=numeric_only)
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/window/rolling.py:619, in BaseWindow._apply(self, func, name, numeric_only, numba_args, **kwargs)
#     616     return result
#     618 if self.method == "single":
# --> 619     return self._apply_columnwise(homogeneous_func, name, numeric_only)
#     620 else:
#     621     return self._apply_tablewise(homogeneous_func, name, numeric_only)
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/window/rolling.py:472, in BaseWindow._apply_columnwise(self, homogeneous_func, name, numeric_only)
#     470 self._validate_numeric_only(name, numeric_only)
#     471 if self._selected_obj.ndim == 1:
# --> 472     return self._apply_series(homogeneous_func, name)
#     474 obj = self._create_data(self._selected_obj, numeric_only)
#     475 if name == "count":
#     476     # GH 12541: Special case for count where we support date-like types
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/window/rolling.py:456, in BaseWindow._apply_series(self, homogeneous_func, name)
#     453 except (TypeError, NotImplementedError) as err:
#     454     raise DataError("No numeric types to aggregate") from err
# --> 456 result = homogeneous_func(values)
#     457 index = self._slice_axis_for_step(obj.index, result)
#     458 return obj._constructor(result, index=index, name=obj.name)
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/window/rolling.py:614, in BaseWindow._apply.<locals>.homogeneous_func(values)
#     611     return func(x, start, end, min_periods, *numba_args)
#     613 with np.errstate(all="ignore"):
# --> 614     result = calc(values)
#     616 return result
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/window/rolling.py:611, in BaseWindow._apply.<locals>.homogeneous_func.<locals>.calc(x)
#     602 start, end = window_indexer.get_window_bounds(
#     603     num_values=len(x),
#     604     min_periods=min_periods,
#    (...)
#     607     step=self.step,
#     608 )
#     609 self._check_window_bounds(start, end, len(x))
# --> 611 return func(x, start, end, min_periods, *numba_args)
#
# KeyboardInterrupt:
