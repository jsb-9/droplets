# %%
# MTREND

# %%
import datetime as dt

import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

# %%
import sys

sys.path.append("..")
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
def get_expiry(f_today):
    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry


def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"

# %%
bnf_pandas = pd.read_csv("../data/adaniensol_1hr_tv.csv")

# INDEX = 'BNF'
# INDEX = 'BNF'
# INDEX = 'NIFTY'
# INDEX = 'FNF'
INDEX = 'STOCK'

if INDEX == 'BNF':
    lev_ = 5.066
    slippage_ = 0.0001
    lot_size_ = 15
elif INDEX == 'NIFTY' or INDEX == 'FNF':
    lev_ = 6.333
    slippage_ = 0.0002
    lot_size_ = 25
elif INDEX == 'MIDCP':
    lev_ = 6.333
    slippage_ = 0.0005
    lot_size_ = 50
elif INDEX == 'STOCK':
    lev_ = 1
    slippage_ = 0.001
    lot_size_ = 1
# bnf_pandas = pd.read_csv("../data/finnifty_1hr_tv (2).csv")
# bnf_pandas = pd.read_csv('../data/midcp_1hr_tv (4).csv')
# bnf_pandas = pd.read_csv('../data/finnifty_1hr_tv.csv')
# bnf_pandas = pd.read_csv('../data/bnf_fut_1hr_tv.csv')
# bnf_pandas = pd.read_csv('../data/gold_4hr_tv.csv')

# %%
# bnf_pandas

# %%
# If Stocks Data ...
bnf_pandas["datetime"] = pd.to_datetime(bnf_pandas["time"])
bnf_pandas["datetime"] = bnf_pandas["datetime"].dt.tz_localize(None)
bnf_pandas = bnf_pandas[bnf_pandas["datetime"].dt.year >= 2017]
bnf_pandas.drop(columns=["time"], inplace=True)
# bnf_pandas

# %%
bnf = pl.DataFrame(bnf_pandas)
print(type(bnf))
# bnf
# Out:
# <class 'polars.dataframe.frame.DataFrame'>

# %%
# # For crude oil Data
# bnf1 = pd.DataFrame(bnf_pandas)
# bnf1 = bnf1.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
# bnf1['datetime'] = pd.to_datetime(bnf1['datetime'])
# bnf1['index'] = bnf1['datetime']
# bnf1.rename(columns={'o': 'open', 'h': 'high', 'l': 'low', 'c': 'close'}, inplace=True)
# bnf = pl.DataFrame(bnf1)
# print(type(bnf))
# bnf

# %%
# bnf['datetime'] = pd.to_datetime(bnf['datetime'])
# bnf = bnf.drop(columns=['Unnamed: 0'])
# bnf.set_index(bnf['datetime'], inplace=True)
# bnf
# bnf = bnf.with_columns(pl.col('datetime').str.to_datetime(format='%Y-%m-%dT%H:%M:%S.%f'))
# print(bnf)
# bnf = bnf.with_columns(pl.col('datetime').cast(pl.DateTime))

# Set 'datetime' column as index
bnf = bnf.with_columns([pl.col("datetime").alias("index")]).drop("datetime")

# Now 'datetime' is set as the index
# bnf

# %%
bnf = bnf.with_columns(pl.col("index").alias("datetime"))
# bnf

# %%
bnf.tail()
# Out:
# shape: (5, 6)
# ┌────────┬────────┬────────┬────────┬─────────────────────┬─────────────────────┐
# │ open   ┆ high   ┆ low    ┆ close  ┆ index               ┆ datetime            │
# │ ---    ┆ ---    ┆ ---    ┆ ---    ┆ ---                 ┆ ---                 │
# │ f64    ┆ f64    ┆ f64    ┆ f64    ┆ datetime[ns]        ┆ datetime[ns]        │
# ╞════════╪════════╪════════╪════════╪═════════════════════╪═════════════════════╡
# │ 982.7  ┆ 986.15 ┆ 980.0  ┆ 985.75 ┆ 2024-10-14 11:15:00 ┆ 2024-10-14 11:15:00 │
# │ 985.75 ┆ 987.1  ┆ 982.8  ┆ 984.2  ┆ 2024-10-14 12:15:00 ┆ 2024-10-14 12:15:00 │
# │ 984.1  ┆ 985.65 ┆ 983.05 ┆ 984.8  ┆ 2024-10-14 13:15:00 ┆ 2024-10-14 13:15:00 │
# │ 985.05 ┆ 986.7  ┆ 980.2  ┆ 982.25 ┆ 2024-10-14 14:15:00 ┆ 2024-10-14 14:15:00 │
# │ 982.25 ┆ 984.5  ┆ 977.1  ┆ 981.5  ┆ 2024-10-14 15:15:00 ┆ 2024-10-14 15:15:00 │
# └────────┴────────┴────────┴────────┴─────────────────────┴─────────────────────┘

# %%
def configure(df):
    df["datetime"] = pd.to_datetime(df["time"])
    df["datetime"] = df["datetime"].dt.tz_localize(None)
    df = df[df["datetime"].dt.year >= 2017]
    df.drop(columns=["time"], inplace=True)
    bnf = pl.DataFrame(df)
    bnf = bnf.with_columns([pl.col("datetime").alias("index")]).drop("datetime")
    bnf = bnf.with_columns(pl.col("index").alias("datetime"))
    return bnf

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("open").first().alias("open"),
                pl.col("high").max().alias("high"),
                pl.col("low").min().alias("low"),
                pl.col("close").last().alias("close"),
                pl.col("volume").sum().alias("volume"),
            ]
        )
    )

# %%
# bnf_final = bnf
# bnf_final

# %%
# # bnf_final = bnf_1hr
# bnf_final['datetime'] = pd.to_datetime(bnf_final['datetime'])
# bnf_final

# %%
def generate_signals1(df, signal_ma, trailing_ma, candles_in_num):
    df["c"] = pd.to_numeric(df["c"], errors="coerce")
    df["MA20"] = df["c"].rolling(window=signal_ma).mean()
    df["MA10"] = df["c"].rolling(window=trailing_ma).mean()

    df["Buy_Signal"] = 0

    # Generate signals using boolean masking
    buy_signal_mask = df["MA20"] > df["MA20"].shift(1)
    
    for i in range(1, candles_in_num):
        buy_signal_mask &= df["MA20"].shift(i) > df["MA20"].shift(i + 1)

    df.loc[buy_signal_mask, "Buy_Signal"] = 1

    return df

# %%
def generate_signals2(df, i, j, candles_in_num):
    df["close"] = pd.to_numeric(df["close"], errors="coerce")
    df["MA20"] = df["close"].rolling(window=i).mean()
    df["MA10"] = df["close"].rolling(window=j).mean()

    df["Sell_Signal"] = 0

    # Generate signals using boolean masking
    sell_signal_mask = df["MA20"] < df["MA20"].shift(1)

    for i in range(1, candles_in_num):
        sell_signal_mask &= df["MA20"].shift(i) < df["MA20"].shift(i + 1)

    df.loc[sell_signal_mask, "Sell_Signal"] = 1

    return df

# %%
# Positional

def execute(df):

    trade_book = []
    in_trade = False
    signal_entry_price = 100000
    signal_initial_sl = 0
    already_signal_exists = False
    is_trailing_active = False
    remark = ""
    portfolio_value = 7500000
    previous_trade_exit_time = None

    for i in range(1, len(df)):
        points = 0
        current_candle_open = df.iloc[i]["o"]
        current_candle_high = df.iloc[i]["h"]
        current_candle_low = df.iloc[i]["l"]
        current_candle_close = df.iloc[i]["c"]
        current_moving_average_price = df.iloc[i]["MA10"]

        if not in_trade:
            if df.iloc[i]["Buy_Signal"] == 1:
                if not already_signal_exists:
                    # Fresh Buy Signal
                    # print(df.iloc[i])
                    # print('Fresh Buy Signal')
                    signal_entry_price = current_candle_high
                    signal_initial_sl = min(current_candle_low, df.iloc[i-1]['l'], df.iloc[i-2]['l'])
                    signal_creation_time = df.iloc[i]["datetime"]
                    already_signal_exists = True

                    # if (signal_entry_price - signal_initial_sl > 400):
                    #     # Skip Signal Candle Due To Big Size
                    #     already_signal_exists = False
                    #     signal_entry_price = 100000
                    #     signal_initial_sl = 0

                else:
                    if current_candle_open > signal_entry_price:
                        # Gap Up Open, SKIP trade
                        # print(df.iloc[i])
                        # print('Gap Up Open, Skip Trade')
                        already_signal_exists = False
                        signal_entry_price = 100000
                        signal_initial_sl = 0
                    elif current_candle_high < signal_entry_price:
                        # Better Candle
                        # print(df.iloc[i])
                        # print('Better Candle')
                        signal_entry_price = current_candle_high
                        signal_initial_sl = min(current_candle_low, df.iloc[i-1]['l'], df.iloc[i-2]['l'])
                        signal_creation_time = df.iloc[i]["datetime"]

                        # if (signal_entry_price - signal_initial_sl > 400):
                        #     # Skip Signal Candle Due To Big Size
                        #     already_signal_exists = False
                        #     signal_entry_price = 100000
                        #     signal_initial_sl = 0

                    elif current_candle_high > signal_entry_price:
                        # Entry Triggered
                        # print(df.iloc[i])
                        # print('Entry Triggered')
                        in_trade = True
                        entry_time = df.iloc[i]["datetime"]
                        entry_price = signal_entry_price
                        points = 0
            else:
                if df.iloc[i - 1]["Buy_Signal"] == 1:
                    # Considering the forward bias condition as well now
                    signal_entry_price = df.iloc[i - 1]["h"]
                    signal_initial_sl = min(df.iloc[i-1]['l'], df.iloc[i-2]['l'], df.iloc[i-3]['l'])
                    signal_creation_time = df.iloc[i - 1]["datetime"]
                    already_signal_exists = True

                    if current_candle_open > signal_entry_price:
                        already_signal_exists = False
                        signal_entry_price = 100000
                        signal_initial_sl = 0

                    elif current_candle_high > signal_entry_price:
                        if df.iloc[i-1]['datetime'] != previous_trade_exit_time:
                            in_trade = True
                            entry_time = df.iloc[i]["datetime"]
                            entry_price = signal_entry_price
                            points = 0
                    else:
                        # Discard Existing Signal
                        already_signal_exists = False
                        signal_entry_price = 100000
                        signal_initial_sl = 0

            # if df.iloc[i-1]["Buy_Signal"] == 1:
            #     signal_entry_price = df.iloc[i-1]['h']
            #     signal_initial_sl = df.iloc[i-1]['l']
            #     signal_creation_time = df.iloc[i-1]["datetime"]

            #     if current_candle_open > signal_entry_price:
            #         # Gap Up Open, SKIP trade
            #         already_signal_exists = False
            #         signal_entry_price = 100000
            #         signal_initial_sl = 0
                
            #     elif current_candle_high >= signal_entry_price:
            #         # Entry Triggered
            #         in_trade = True
            #         entry_time = df.iloc[i]["datetime"]
            #         entry_price = signal_entry_price
            #         points = 0

        if in_trade:
            trade_entry_price = signal_entry_price
            trade_initial_sl = signal_initial_sl
            trade_final_sl = signal_initial_sl

            if (
                not is_trailing_active
                and current_candle_low > current_moving_average_price
            ):
                is_trailing_active = True

            if not is_trailing_active:
                if current_candle_open < trade_initial_sl:
                    # if df.iloc[i-1]['l'] < trade_initial_sl:
                    #     #Previous Candle Already Hit the SL Hence don't check gap down
                    #     print(df.iloc[i])
                    #     print('Initial SL Hit Before Gap Down')
                    #     in_trade = False
                    #     points = trade_initial_sl - trade_entry_price
                    #     exit_price = trade_initial_sl
                    #     exit_time = df.iloc[i-1]['datetime']
                    #     remark = 'Initial SL Hit Before Gap Down'
                    # else:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        if current_candle_close <= trade_initial_sl:
                            in_trade = False
                            points = trade_initial_sl - trade_entry_price
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL hit"

                    else:
                        # Gap Open Outside ISL
                        # print(df.iloc[i])
                        # print('Gap Open Outside ISL')
                        in_trade = False
                        points = current_candle_open - trade_entry_price
                        exit_price = current_candle_open
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif current_candle_low <= trade_initial_sl:
                    # Initial SL Hit
                    # print(df.iloc[i])
                    # print('Initial SL Hit')
                    in_trade = False
                    points = trade_initial_sl - trade_entry_price
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL Hit"

            else:
                trade_final_sl = max(trade_initial_sl, current_moving_average_price)

                if current_candle_open <= trade_initial_sl:
                    # if df.iloc[i-1]['l'] < trade_initial_sl:
                    #     #Previous Candle Already Hit the SL Hence don't check gap down
                    #     print(df.iloc[i])
                    #     print('Initial SL Hit Before Gap Down')
                    #     in_trade = False
                    #     points = trade_initial_sl - trade_entry_price
                    #     exit_price = trade_initial_sl
                    #     exit_time = df.iloc[i-1]['datetime']
                    #     remark = 'Initial SL Hit'
                    # else:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        if current_candle_close <= trade_initial_sl:
                            in_trade = False
                            points = trade_initial_sl - trade_entry_price
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL hit"

                    else:
                        # Gap Open Outside ISL
                        # print(df.iloc[i])
                        # print('Gap Open Outside ISL')
                        in_trade = False
                        points = current_candle_open - trade_entry_price
                        exit_price = current_candle_open
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif current_candle_low <= trade_initial_sl:
                    # if trade_initial_sl >= current_moving_average_price:
                    # Despite Trailing, Initial SL hit
                    # print(df.iloc[i])
                    # print('Initial SL Hit')
                    in_trade = False
                    points = trade_initial_sl - trade_entry_price
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL hit"

                elif current_candle_close <= trade_final_sl:
                    # Price Closed below TSL i.e. MA10 , TSL Hit
                    # print(df.iloc[i])
                    # print('Initial SL Hit')
                    in_trade = False
                    points = current_candle_close - trade_entry_price
                    exit_price = current_candle_close
                    exit_time = df.iloc[i]["datetime"]
                    is_trailing_active = False
                    remark = "TSL Hit"

            if points:
                index_lev = lev_
                qty = int(round(portfolio_value * index_lev / entry_price / lot_size_)) * lot_size_
                slippage = slippage_ * (entry_price + exit_price)
                # slippage = 10
                final_points = points - slippage
                # final_points = points
                previous_trade_exit_time = exit_time
                trade = {
                    "Signal Generated At": signal_creation_time,
                    "Trade Type": "LONG",
                    "Entry Time": entry_time,
                    "Entry Price": entry_price,
                    "Initial SL": trade_initial_sl,
                    "Final SL": trade_final_sl,
                    "Exit Time": exit_time,
                    "Exit Price": exit_price,
                    "Points Captured": points,
                    "After Costs": final_points,
                    "PnL": final_points * qty,
                    "Remarks": remark,
                    "Qty": qty,
                    "Leverage": index_lev,
                    "ROI%": (final_points * qty / portfolio_value) * 100,
                    "Trade Year": entry_time.year,
                    "Trade Month": entry_time.month,
                }
                trade_book.append(trade)
                points = 0
                in_trade = False
                already_signal_exists = False
                remark = ""
                is_trailing_active = False

    trade_book_df = pd.DataFrame(trade_book)
    return trade_book_df

# %%
bnf1 = bnf
bnf2 = bnf

# %%
def generate_stats(tb_expiry, signal_ma, trailing_ma):
    stats_df8 = pd.DataFrame(
        index=range(2017, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2017, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI%"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI%"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI%"] > 0]["ROI%"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI%"] < 0]["ROI%"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI%"].cumsum() - year_trades["ROI%"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = f'{signal_ma} , {trailing_ma}'
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI%"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI%"] > 0]["ROI%"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI%"].cumsum() - combined_df_sorted["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation
    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    return {overall_roi_dd_ratio : stats_df8}

# %%
bnf1 = bnf1.to_pandas()
bnf2 = bnf2.to_pandas()
# signals_df1 = generate_signals1(bnf1)
# signals_df2 = generate_signals2(bnf2)

# %%
# stats_dictionary = {}

# for i in range(6, 81):
#     for j in range(4, 101, 2):
#         print(f"Signal MA : {i} , Trailing MA : {j}")
#         signals_df1 = generate_signals1(bnf1, i, j)
#         signals_df1 = signals_df1.rename(columns={"open": "o", "high": "h", "low": "l", "close": "c"})
#         new_tb = execute(signals_df1)
#         new_tb["DD%"] = new_tb["ROI%"].cumsum() - new_tb["ROI%"].cumsum().cummax()
#         tradebook_buy_side = new_tb
#         stats = generate_stats(tradebook_buy_side, i, j)
#         for overall_roi_dd_ratio, stats_df in stats.items():
#             if overall_roi_dd_ratio is not None and overall_roi_dd_ratio > 10:
#                 print(stats_df.to_string())
#                 stats_dictionary[overall_roi_dd_ratio] = stats_df

# %%
# sorted_stats = {k: v for k, v in sorted(stats_dictionary.items(), key=lambda item: item[0], reverse=True)}
# sorted_stats

# %%
bnf1 = bnf1.rename(columns={"open": "o", "high": "h", "low": "l", "close": "c"})
signals_df1 = generate_signals1(bnf1, 48, 18, 1)
# signals_df1 = signals_df1.rename(columns={"open": "o", "high": "h", "low": "l", "close": "c"})

# signals_df1 = signals_df1.rename(
#     columns={"open": "o", "high": "h", "low": "l", "close": "c"}
# )
# signals_df2 = signals_df2.rename(
#     columns={"open": "o", "high": "h", "low": "l", "close": "c"}
# )

# %%
# signals_df2.tail(130)

# %%
new_tb = execute(signals_df1)
new_tb["DD%"] = new_tb["ROI%"].cumsum() - new_tb["ROI%"].cumsum().cummax()
tradebook_buy_side = new_tb
# new_tb

# %%
# tradebook_buy_side['DD%'] = (tradebook_buy_side['ROI%'].cumsum() - tradebook_buy_side['ROI%'].cumsum().cummax())
# tradebook_buy_side

# %%
new_tb.tail(8)
# Out:
#     Signal Generated At Trade Type          Entry Time  Entry Price  \
# 566 2024-08-21 15:15:00       LONG 2024-08-22 09:15:00    1093.0000
# 567 2024-09-09 14:15:00       LONG 2024-09-09 15:15:00    1008.0000
# 568 2024-09-20 12:15:00       LONG 2024-09-20 13:15:00    1006.0000
# 569 2024-09-26 10:15:00       LONG 2024-09-26 11:15:00    1043.9500
# 570 2024-09-26 15:15:00       LONG 2024-09-27 09:15:00    1040.0000
# 571 2024-09-27 10:15:00       LONG 2024-09-27 11:15:00    1050.2000
# 572 2024-09-27 15:15:00       LONG 2024-09-30 09:15:00    1015.0000
# 573 2024-09-30 11:15:00       LONG 2024-09-30 12:15:00    1011.3500
#
#      Initial SL  Final SL           Exit Time  Exit Price  Points Captured  \
# 566   1075.0000 1075.0000 2024-08-22 15:15:00   1075.0000         -18.0000
# 567    968.3000 1001.9222 2024-09-11 13:15:00   1000.5000          -7.5000
# 568    978.1500 1040.1694 2024-09-25 13:15:00   1039.8500          33.8500
# 569   1035.0000 1035.0000 2024-09-26 14:15:00   1035.0000          -8.9500
# 570   1033.0000 1033.0000 2024-09-27 09:15:00   1033.0000          -7.0000
# 571   1029.1500 1043.0472 2024-09-27 13:15:00   1036.2000         -14.0000
# 572   1001.0500 1001.0500 2024-09-30 09:15:00   1001.0500         -13.9500
# 573    994.0000 1025.3556 2024-10-03 11:15:00   1023.0000          11.6500
#
#      After Costs          PnL         Remarks   Qty  Leverage    ROI%  \
# 566     -20.1680 -138392.8160  Initial SL Hit  6862         1 -1.8452
# 567      -9.5085  -70743.2400         TSL Hit  7440         1 -0.9432
# 568      31.8041  237099.9382         TSL Hit  7455         1  3.1613
# 569     -11.0290  -79231.9768  Initial SL Hit  7184         1 -1.0564
# 570      -9.0730  -65434.4760  Initial SL Hit  7212         1 -0.8725
# 571     -16.0864 -114872.9824         TSL Hit  7141         1 -1.5316
# 572     -15.9661 -117973.1435  Initial SL Hit  7389         1 -1.5730
# 573       9.6156   71309.6604         TSL Hit  7416         1  0.9508
#
#      Trade Year  Trade Month      DD%
# 566        2024            8 -61.2520
# 567        2024            9 -62.1952
# 568        2024            9 -59.0339
# 569        2024            9 -60.0903
# 570        2024            9 -60.9628
# 571        2024            9 -62.4944
# 572        2024            9 -64.0674
# 573        2024            9 -63.1166

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2017, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2017, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI%"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI%"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI%"] > 0]["ROI%"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI%"] < 0]["ROI%"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI%"].cumsum() - year_trades["ROI%"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI%"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI%"] > 0]["ROI%"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI%"].cumsum() - combined_df_sorted["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation

    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    
    print(f'{overall_total_roi} , {overall_max_drawdown} , {overall_roi_dd_ratio}')
    
    return {overall_roi_dd_ratio: stats_df8}

# %%
bnf1 = bnf1.rename(columns={"open": "o", "high": "h", "low": "l", "close": "c"})

# %%
import os
stats_dict = {}
path = f'../data/stocks'

path = '../data/stocks/'
results = []

i = 1
for filename in os.listdir(path):
    if filename.endswith('.csv'):
        stock = filename[:-4]  # Extract stock name from filename
        print(stock, str(stock))
        if i>2:
            df = pd.read_csv(os.path.join(path, filename))
            df = configure(df)
            for i in range(10, 81, 2):
                for j in range(10, 81, 5):
                    for n in range(1, 5):
                        variation = f'{stock[:-4]}, SMA : {i} , TMA : {j}, Num Candles : {n}'
                        print(variation)
                        signals_df1 = generate_signals1(bnf1, i, j, n)
                        new_tb = execute(signals_df1)
                        stats = generate_stats(new_tb, variation)
                        for overall_roi_dd_ratio, stats_df in stats.items():
                            if overall_roi_dd_ratio is not None and overall_roi_dd_ratio > 8:
                                stats_dict[overall_roi_dd_ratio] = stats_df
                                print(stats_df.to_string())
    
        i += 1
    # stats_df = get_stats(df)
    # stats_df['Stock'] = stock  # Add a column for the stock name
    # results.append(stats_df)

# Concatenate all results into a single DataFrame
# final_df = pd.concat(results, ignore_index=True)
# Out:
# NSE_NAUKRI, 60 NSE_NAUKRI, 60
# NSE_LTIM, 60 NSE_LTIM, 60
# NSE_UNITDSPR, 60 (1) NSE_UNITDSPR, 60 (1)
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 10, Num Candles : 1
# /tmp/ipykernel_18246/2534505416.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["time"], inplace=True)
# 219.16752397733336 , -138.38446239733318 , 1.5837581776200689
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 10, Num Candles : 2
# 213.5729311326665 , -107.4537287933333 , 1.9875804546851343
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 10, Num Candles : 3
# 236.0576397666667 , -123.01498093399991 , 1.9189340840796987
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 10, Num Candles : 4
# 200.2329800280002 , -121.48221776599999 , 1.6482492969768676
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 15, Num Candles : 1
# 268.4918990813334 , -112.06634340866661 , 2.395829924620969
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 15, Num Candles : 2
# 226.82951275799994 , -99.32951177199982 , 2.283606439933608
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 15, Num Candles : 3
# 241.54741611133346 , -114.50596751466665 , 2.1094744785278947
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 15, Num Candles : 4
# 200.56547751933357 , -109.03887085199993 , 1.8393942999608281
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 20, Num Candles : 1
# 315.0791477946666 , -93.90755367933336 , 3.355205576652216
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 20, Num Candles : 2
# 266.86612056266654 , -86.78139582199991 , 3.0751535860294776
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 20, Num Candles : 3
# 265.89120174733335 , -93.02844885733332 , 2.8581708607772134
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 20, Num Candles : 4
# 231.28232873133348 , -94.4754568486666 , 2.4480678521809947
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 25, Num Candles : 1
# 278.8566275793334 , -104.46887414333332 , 2.669279532932811
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 25, Num Candles : 2
# 230.41398026533324 , -93.61166979933323 , 2.4613809449105073
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 25, Num Candles : 3
# 253.93648077933335 , -91.81175034133328 , 2.7658385755119643
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 25, Num Candles : 4
# 239.97240835133346 , -90.23188412866662 , 2.65950789644538
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 30, Num Candles : 1
# 233.81015009666677 , -114.04257392066667 , 2.0502005703529282
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 30, Num Candles : 2
# 218.2114623906665 , -97.16903805266658 , 2.2456892315059633
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 30, Num Candles : 3
# 216.0217338966668 , -100.71784739733332 , 2.144820798685838
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 30, Num Candles : 4
# 205.23832031533354 , -95.981389006 , 2.1383137131147754
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 35, Num Candles : 1
# 298.4983789626668 , -85.2373861373334 , 3.501965422563873
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 35, Num Candles : 2
# 264.5251637753332 , -87.92886112066662 , 3.008399749569368
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 35, Num Candles : 3
# 252.6672774953334 , -94.63537755866665 , 2.669902989911982
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 35, Num Candles : 4
# 226.72034735133354 , -93.65012823733326 , 2.420929384920504
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 40, Num Candles : 1
# 308.8341029666666 , -85.97756975866679 , 3.59203108245026
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 40, Num Candles : 2
# 267.24246174133305 , -85.91267245533336 , 3.110629131927823
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 40, Num Candles : 3
# 264.1604483586666 , -98.67471889800007 , 2.6770833634877533
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 40, Num Candles : 4
# 234.7372747860001 , -98.13208151933335 , 2.3920543735715385
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 45, Num Candles : 1
# 305.1513966933332 , -79.51638213066664 , 3.837591556817663
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 45, Num Candles : 2
# 266.5186961359999 , -71.85071456599992 , 3.7093395346984863
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 45, Num Candles : 3
# 267.24392084199997 , -84.63052161866672 , 3.1577723465555803
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 45, Num Candles : 4
# 249.52860130266686 , -75.83896048 , 3.2902429005269886
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 50, Num Candles : 1
# 281.0486312053333 , -88.1421061386668 , 3.1885853823731236
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 50, Num Candles : 2
# 254.37231651866657 , -78.82231725866657 , 3.2271611057044653
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 50, Num Candles : 3
# 240.96744945600014 , -86.71001173466664 , 2.7790037694074194
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 50, Num Candles : 4
# 220.28569310533345 , -83.78791007533334 , 2.629086856412525
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 55, Num Candles : 1
# 299.93581725 , -90.37190843600014 , 3.3189054258205632
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 55, Num Candles : 2
# 290.42502146999976 , -68.59556450533327 , 4.233874647207245
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 55, Num Candles : 3
# 257.8724002893334 , -89.08095301733333 , 2.8948096260168743
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 55, Num Candles : 4
# 270.7764112140001 , -83.13113755466664 , 3.257220088392738
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 60, Num Candles : 1
# 297.777103374 , -89.37040941600006 , 3.331942925179088
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 60, Num Candles : 2
# 286.89576451866657 , -67.33787680466656 , 4.260540696150736
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 60, Num Candles : 3
# 243.3105490560001 , -91.68561883066658 , 2.6537482340100507
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 60, Num Candles : 4
# 236.67135341600013 , -88.95056323599991 , 2.660706630806526
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 65, Num Candles : 1
# 318.2479384759999 , -85.97189927000007 , 3.7017669864024123
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 65, Num Candles : 2
# 286.4167571853332 , -72.19128088466658 , 3.967470221825197
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 65, Num Candles : 3
# 231.6471534333334 , -97.84555554866645 , 2.367477522452378
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 65, Num Candles : 4
# 213.74585105800014 , -95.42193100266647 , 2.2400076042479924
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 70, Num Candles : 1
# 336.5119793019999 , -63.41736103333335 , 5.306306882197808
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 70, Num Candles : 2
# 298.0752459266665 , -55.842073133999946 , 5.337825571256966
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 70, Num Candles : 3
# 213.82144832800003 , -105.1463050206664 , 2.033561220111098
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 70, Num Candles : 4
# 198.71993300400004 , -97.73286815266653 , 2.033296850488248
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 75, Num Candles : 1
# 359.0038031533332 , -60.17062843266682 , 5.966429344427936
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 75, Num Candles : 2
# 308.6978879119998 , -63.40099536666665 , 4.868975417920632
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 75, Num Candles : 3
# 228.7644166386667 , -105.62042445066646 , 2.165910786937982
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 75, Num Candles : 4
# 216.68894850533346 , -95.00340061199995 , 2.2808546547749926
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 80, Num Candles : 1
# 367.42598214399993 , -54.38681948933342 , 6.755790936001711
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 80, Num Candles : 2
# 315.97400194799985 , -60.38541211399998 , 5.2326214376326705
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 80, Num Candles : 3
# 230.91705799266668 , -112.76771987133328 , 2.0477230386154877
# NSE_UNITDSPR, 60, SMA : 10 , TMA : 80, Num Candles : 4
# 223.80271055066675 , -99.8495773033333 , 2.2413986778409276
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 10, Num Candles : 1
# 212.5034802900001 , -123.55203768333323 , 1.7199512389641969
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 10, Num Candles : 2
# 241.48471902333358 , -105.42087403666653 , 2.2906727081331404
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 10, Num Candles : 3
# 273.91642527333346 , -93.72639937466654 , 2.9225109158239015
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 10, Num Candles : 4
# 279.4420251080002 , -84.94281028266661 , 3.289766658038426
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 15, Num Candles : 1
# 249.96494622066672 , -101.74086308866661 , 2.4568785700473526
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 15, Num Candles : 2
# 238.3071807940001 , -106.15095552533333 , 2.244983849788589
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 15, Num Candles : 3
# 239.37401080066672 , -99.48539994666663 , 2.4061220131697043
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 15, Num Candles : 4
# 267.3226985373334 , -79.40315661599998 , 3.3666507722120844
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 20, Num Candles : 1
# 285.79575033933327 , -92.4983195860002 , 3.0897399176383415
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 20, Num Candles : 2
# 285.57595107599997 , -92.59904432466668 , 3.084005382115243
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 20, Num Candles : 3
# 280.9952912333333 , -75.26696955933333 , 3.733314797692543
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 20, Num Candles : 4
# 308.9123037646668 , -58.240790356666565 , 5.304054115215265
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 25, Num Candles : 1
# 238.90783904600016 , -104.1873699433332 , 2.293059505926107
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 25, Num Candles : 2
# 250.89084575866673 , -101.17050921599993 , 2.4798812193681123
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 25, Num Candles : 3
# 262.0261228480001 , -92.06885075599997 , 2.8459801626330643
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 25, Num Candles : 4
# 299.93549923733354 , -68.8409985433332 , 4.356931270375658
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 30, Num Candles : 1
# 210.8006038486669 , -110.42471209733323 , 1.9089984464968124
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 30, Num Candles : 2
# 236.23912727600012 , -99.3469047773333 , 2.3779213635843415
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 30, Num Candles : 3
# 231.08018982600015 , -97.85205181533337 , 2.3615262586633876
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 30, Num Candles : 4
# 271.93308760133357 , -74.16062038866662 , 3.6668124696930255
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 35, Num Candles : 1
# 274.81954313266687 , -91.93269790399998 , 2.989355793948798
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 35, Num Candles : 2
# 289.71072273200014 , -78.28790638133339 , 3.7005807936776995
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 35, Num Candles : 3
# 291.44762659733345 , -79.23897496266675 , 3.678084260108719
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 35, Num Candles : 4
# 301.39343944066684 , -62.32012376333333 , 4.836213749915476
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 40, Num Candles : 1
# 309.64502988666675 , -92.60758993266671 , 3.3436247516192137
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 40, Num Candles : 2
# 300.84851819933334 , -72.1454520586668 , 4.170027487729804
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 40, Num Candles : 3
# 302.0483271306667 , -79.80613482466673 , 3.7847757919145413
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 40, Num Candles : 4
# 310.5112494533334 , -61.66339074333334 , 5.0355850644963756
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 45, Num Candles : 1
# 314.49311982533334 , -89.0906097386665 , 3.5300366755581782
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 45, Num Candles : 2
# 320.76144526533335 , -63.98475184400013 , 5.013091963650575
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 45, Num Candles : 3
# 302.10311316333343 , -73.3663977213335 , 4.117731312239251
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 45, Num Candles : 4
# 308.9772407853335 , -60.03205661533349 , 5.146870825451847
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 50, Num Candles : 1
# 288.9437908426669 , -79.15637646933328 , 3.650290775432467
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 50, Num Candles : 2
# 296.25839410533337 , -67.22883606800008 , 4.406716097325801
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 50, Num Candles : 3
# 272.43452767466687 , -73.60584046400007 , 3.7012623720791837
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 50, Num Candles : 4
# 277.73717679200007 , -54.43229493333331 , 5.102433713885524
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 55, Num Candles : 1
# 324.17965120533336 , -64.38102846400008 , 5.035328868450817
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 55, Num Candles : 2
# 329.2564689646666 , -61.854014911333365 , 5.323122022663362
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 55, Num Candles : 3
# 303.22188313066664 , -74.15118419933339 , 4.089238579326594
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 55, Num Candles : 4
# 317.4800153873334 , -53.65657547866661 , 5.916889263899459
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 60, Num Candles : 1
# 320.4993025860001 , -75.86038070666677 , 4.224857555425292
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 60, Num Candles : 2
# 322.04959853200006 , -65.89881892266658 , 4.887031418725894
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 60, Num Candles : 3
# 302.4092646186667 , -71.27863074999998 , 4.242635716156301
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 60, Num Candles : 4
# 326.9548422793335 , -51.178274304666616 , 6.38854761559478
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 65, Num Candles : 1
# 336.4668095133333 , -73.39793834200026 , 4.584145237779765
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 65, Num Candles : 2
# 329.17892539066673 , -59.39526878666669 , 5.54217418516948
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 65, Num Candles : 3
# 291.82944919666664 , -70.01806114400007 , 4.1679167407461675
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 65, Num Candles : 4
# 305.22818090733335 , -49.07240084866659 , 6.219956138861446
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 70, Num Candles : 1
# 348.6485328333333 , -71.79993754400016 , 4.8558333719952875
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 70, Num Candles : 2
# 345.3227480039999 , -62.43030485733334 , 5.531332079718921
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 70, Num Candles : 3
# 288.93958924199995 , -58.258629148666785 , 4.959601581160998
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 70, Num Candles : 4
# 294.73559396600007 , -49.860306942000136 , 5.911227026918435
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 1
# 374.8773220619999 , -73.49888697666677 , 5.1004489657239285
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 2
# 372.00237747266675 , -43.4727103313333 , 8.557147107631407
#         Total ROI Total Trades Win Rate Avg Profit% per Trade Avg Loss% per Trade Max Drawdown ROI/DD Ratio                                               Variation
# 2017     145.1082           38  26.3158               18.8655             -1.5552     -17.7787       8.1619  NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 2
# 2018      14.4224           40  27.5000                5.8632             -1.7267     -16.7461       0.8612  NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 2
# 2019       5.8251           47  19.1489                7.5259             -1.6292     -36.7173       0.1586  NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 2
# 2020      19.5807           47  19.1489               10.7834             -2.0387     -39.6924       0.4933  NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 2
# 2021     195.8717           30  30.0000               27.2990             -2.3723     -22.9672       8.5283  NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 2
# 2022       8.8691           53  13.2075               12.0930             -1.6474     -42.7574       0.2074  NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 2
# 2023       3.4496           34  23.5294                5.9181             -1.6883     -23.4026       0.1474  NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 2
# 2024     -21.1244           34  17.6471                3.5453             -1.5141     -27.6512      -0.7640  NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 2
# Overall  372.0024          323  21.3622               11.8390             -1.7515     -43.4727       8.5571  NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 2
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 3
# 305.4684593553334 , -56.78927806799997 , 5.378981204683793
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 75, Num Candles : 4
# 305.03490717400007 , -47.339346431333226 , 6.4435808723396715
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 1
# 376.74718460933343 , -75.51495855000013 , 4.98904047414501
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 2
# 376.3003268493333 , -41.93323249066657 , 8.973797260516218
#         Total ROI Total Trades Win Rate Avg Profit% per Trade Avg Loss% per Trade Max Drawdown ROI/DD Ratio                                               Variation
# 2017     135.8606           38  26.3158               17.9407             -1.5552     -18.2635       7.4389  NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 2
# 2018      14.8729           38  28.9474                5.7179             -1.7787     -15.9278       0.9338  NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 2
# 2019       1.6841           46  19.5652                7.0385             -1.6666     -39.1951       0.0430  NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 2
# 2020      32.2874           48  16.6667               13.1733             -1.8275     -33.1060       0.9753  NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 2
# 2021     197.7380           31  32.2581               24.5844             -2.2908     -20.8567       9.4808  NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 2
# 2022      13.6834           52  11.5385               15.3576             -1.7057     -41.4044       0.3305  NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 2
# 2023       1.0074           39  28.2051                4.2610             -1.6380     -26.0345       0.0387  NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 2
# 2024     -20.8335           31  16.1290                3.5977             -1.4932     -26.6890      -0.7806  NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 2
# Overall  376.3003          323  21.6718               11.6270             -1.7296     -41.9332       8.9738  NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 2
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 3
# 310.58079777266664 , -59.054343757999845 , 5.259237136651672
# NSE_UNITDSPR, 60, SMA : 12 , TMA : 80, Num Candles : 4
# 310.2624409293334 , -50.457947145333264 , 6.148931109616671
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 10, Num Candles : 1
# 185.54338473933348 , -132.94814201799983 , 1.3956072038540621
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 10, Num Candles : 2
# 215.54401053466674 , -99.33746614666654 , 2.1698158700406887
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 10, Num Candles : 3
# 169.44865819800017 , -113.65224968866654 , 1.4909397628483343
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 10, Num Candles : 4
# 180.81924635800024 , -107.6679800166666 , 1.6794152386810832
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 15, Num Candles : 1
# 236.3781659246666 , -111.06410324599993 , 2.1283039165328153
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 15, Num Candles : 2
# 230.73774186133332 , -93.22758214599996 , 2.4749943798819563
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 15, Num Candles : 3
# 182.59940856600016 , -106.92325872866655 , 1.7077613490005288
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 15, Num Candles : 4
# 182.75445979400016 , -96.7240618559999 , 1.8894415338561765
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 20, Num Candles : 1
# 272.6910613186666 , -99.26127793533327 , 2.7472048213636677
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 20, Num Candles : 2
# 261.6008991453333 , -80.98392213733321 , 3.2302819157327094
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 20, Num Candles : 3
# 220.33388281333345 , -95.05178406933327 , 2.3180404762588793
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 20, Num Candles : 4
# 239.38593490933346 , -83.63392700133322 , 2.8623065243070243
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 25, Num Candles : 1
# 254.2930665300001 , -100.12394258733319 , 2.539782792793969
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 25, Num Candles : 2
# 251.2340712 , -81.06844300333314 , 3.099036590472947
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 25, Num Candles : 3
# 194.83079418600022 , -95.58822119066654 , 2.038230147597139
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 25, Num Candles : 4
# 211.48117934533357 , -80.8550538473332 , 2.615559192436414
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 30, Num Candles : 1
# 223.15457676600016 , -109.38077422933328 , 2.0401627099303847
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 30, Num Candles : 2
# 230.40928241333341 , -92.15013140066658 , 2.5003684629761334
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 30, Num Candles : 3
# 185.3703109626669 , -99.63366601533323 , 1.8605188223641107
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 30, Num Candles : 4
# 194.37270527066698 , -87.24368937133326 , 2.227928537539982
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 35, Num Candles : 1
# 274.70150783200006 , -72.3255229093333 , 3.798126813080407
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 35, Num Candles : 2
# 268.2834598193334 , -68.12979684999998 , 3.93782855994724
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 35, Num Candles : 3
# 244.27456733733345 , -78.638871028 , 3.1062827345315975
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 35, Num Candles : 4
# 231.94247481066685 , -67.15472895133331 , 3.4538517008795373
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 40, Num Candles : 1
# 315.4868765086667 , -74.55575596666671 , 4.231556268435107
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 40, Num Candles : 2
# 305.36543657066665 , -58.35081533066675 , 5.233267690266178
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 40, Num Candles : 3
# 283.9991517420001 , -70.88530874400007 , 4.006459967151354
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 40, Num Candles : 4
# 268.20897824733345 , -65.13938423400013 , 4.117462598108798
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 45, Num Candles : 1
# 330.849932556 , -72.73082070533343 , 4.54896465277668
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 45, Num Candles : 2
# 315.94875879333335 , -59.25091409800012 , 5.332386235776191
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 45, Num Candles : 3
# 294.11128860533347 , -72.06772658333341 , 4.08104019023337
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 45, Num Candles : 4
# 267.27978807333346 , -67.78057100800015 , 3.9433097729699913
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 50, Num Candles : 1
# 279.2742547346667 , -69.53709553199998 , 4.016190963945981
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 50, Num Candles : 2
# 271.1019212340001 , -57.28380291266666 , 4.732610396822201
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 50, Num Candles : 3
# 262.18671224266683 , -57.40342608266678 , 4.567440136153045
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 50, Num Candles : 4
# 228.47147954733356 , -55.79106229733355 , 4.095126892004941
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 55, Num Candles : 1
# 310.14704536333346 , -67.43525411799997 , 4.599182570301137
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 55, Num Candles : 2
# 336.61850484666655 , -52.44077398600007 , 6.419022437322005
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 55, Num Candles : 3
# 294.9178764933334 , -61.984812189999914 , 4.757905462217612
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 55, Num Candles : 4
# 280.82182173866676 , -56.347332003333335 , 4.983764301778374
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 60, Num Candles : 1
# 323.4433859153334 , -73.47358458866665 , 4.402172396053544
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 60, Num Candles : 2
# 340.43267911199996 , -53.07510957799997 , 6.414168182011854
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 60, Num Candles : 3
# 288.1626640126668 , -66.02112036733324 , 4.364704240239576
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 60, Num Candles : 4
# 277.6315755413334 , -59.0077175426667 , 4.705004482516824
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 65, Num Candles : 1
# 340.45794444866664 , -68.58985315200016 , 4.963677990302542
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 65, Num Candles : 2
# 328.54113014466657 , -55.49533426400001 , 5.920157694370213
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 65, Num Candles : 3
# 275.2988326026668 , -70.37890335133335 , 3.9116669839023737
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 65, Num Candles : 4
# 233.99858107000017 , -65.55923246733343 , 3.5692696858004855
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 70, Num Candles : 1
# 343.2353983386667 , -65.24830832333356 , 5.2604490010344325
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 70, Num Candles : 2
# 334.233404218 , -58.06956285800004 , 5.755741696132879
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 70, Num Candles : 3
# 270.2923425546668 , -62.651808347333315 , 4.314198579172717
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 70, Num Candles : 4
# 234.5630219386668 , -58.380332811333346 , 4.017843178398791
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 1
# 394.510054774 , -65.48265815933337 , 6.024649363104234
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 2
# 378.45456919466665 , -42.533311147999996 , 8.897839340036013
#         Total ROI Total Trades Win Rate Avg Profit% per Trade Avg Loss% per Trade Max Drawdown ROI/DD Ratio                                               Variation
# 2017     153.9512           35  25.7143               21.7010             -1.5907     -16.0532       9.5901  NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 2
# 2018       3.2609           38  28.9474                4.8163             -1.8414     -19.0268       0.1714  NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 2
# 2019      12.6651           45  17.7778                7.0632             -1.1849     -31.5658       0.4012  NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 2
# 2020      19.0180           54  12.9630               14.8359             -1.8050     -33.8963       0.5611  NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 2
# 2021     195.7148           29  31.0345               27.0359             -2.3804     -17.0571      11.4741  NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 2
# 2022      19.8266           48  16.6667               10.7966             -1.6636     -40.0259       0.4953  NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 2
# 2023      10.7128           32  28.1250                4.8042             -1.4141     -17.2998       0.6192  NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 2
# 2024     -36.6949           37  10.8108                3.4694             -1.5325     -42.5333      -0.8627  NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 2
# Overall  378.4546          318  20.4403               12.2378             -1.6482     -42.5333       8.8978  NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 2
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 3
# 302.43526034333354 , -53.81894490533307 , 5.6194944154946525
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 75, Num Candles : 4
# 245.5589247153334 , -57.17529160933324 , 4.294843415809506
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 80, Num Candles : 1
# 399.63814307399997 , -70.47462743933329 , 5.670666984625363
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 80, Num Candles : 2
# 372.77263745533327 , -48.87121288733323 , 7.627652669777529
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 80, Num Candles : 3
# 294.3140494813334 , -60.70399893666655 , 4.8483469727982165
# NSE_UNITDSPR, 60, SMA : 14 , TMA : 80, Num Candles : 4
# 235.08165234000006 , -60.151612099999966 , 3.9081521530825305
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 10, Num Candles : 1
# 159.10985470466687 , -121.75160138466656 , 1.306839933891048
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 10, Num Candles : 2
# 233.85867260200024 , -107.6224422413332 , 2.1729545226040696
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 10, Num Candles : 3
# 204.3666342853335 , -116.97722665933325 , 1.7470634252639612
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 10, Num Candles : 4
# 176.2369559553335 , -117.4257555379999 , 1.5008373175704357
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 15, Num Candles : 1
# 224.1566635253334 , -93.61943313133327 , 2.394339038678829
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 15, Num Candles : 2
# 264.3613526166668 , -101.56518019066664 , 2.602873860120029
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 15, Num Candles : 3
# 231.96338854000018 , -107.70349168266657 , 2.1537220838062354
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 15, Num Candles : 4
# 186.77273124600012 , -105.02469635866662 , 1.7783696380150273
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 20, Num Candles : 1
# 258.5066245113333 , -89.70902449400023 , 2.8816122566199827
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 20, Num Candles : 2
# 294.74878105066676 , -92.6274145813333 , 3.182090122917734
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 20, Num Candles : 3
# 260.33297502666676 , -93.53566575199994 , 2.783248218031745
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 20, Num Candles : 4
# 223.13567371800005 , -91.88141419199991 , 2.428518059721249
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 25, Num Candles : 1
# 218.65006515066693 , -101.87971549133334 , 2.146158968899623
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 25, Num Candles : 2
# 259.4108477666669 , -102.03451994933326 , 2.542383184587737
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 25, Num Candles : 3
# 222.5774689313336 , -102.28300587399983 , 2.176094327981736
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 25, Num Candles : 4
# 179.98601317733366 , -102.81191927666659 , 1.7506337246072783
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 30, Num Candles : 1
# 217.51898886400028 , -90.8015021866666 , 2.3955439461434485
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 30, Num Candles : 2
# 261.80910568533363 , -98.97309403599994 , 2.6452553417204943
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 30, Num Candles : 3
# 207.28277157466704 , -104.9579826399999 , 1.974911925333355
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 30, Num Candles : 4
# 169.37699190066695 , -102.65657129733324 , 1.6499381360603356
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 35, Num Candles : 1
# 284.05635603666684 , -69.55262084866666 , 4.084049638542302
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 35, Num Candles : 2
# 304.1504215700002 , -79.47115220533341 , 3.827180217346695
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 35, Num Candles : 3
# 236.87985107666697 , -92.06351257599994 , 2.5730047056494696
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 35, Num Candles : 4
# 180.4078413400003 , -86.77708321599994 , 2.0789802405658264
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 40, Num Candles : 1
# 299.3216085993334 , -73.88563190933331 , 4.051147711190148
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 40, Num Candles : 2
# 340.6171838473335 , -80.87695702866675 , 4.211547965715402
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 40, Num Candles : 3
# 276.81286405466693 , -86.08287131000006 , 3.215655563553561
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 40, Num Candles : 4
# 217.04349307466688 , -91.52975618266665 , 2.371288880541881
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 45, Num Candles : 1
# 321.6697912753334 , -69.4335163026667 , 4.632774031969618
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 45, Num Candles : 2
# 355.1500921006668 , -65.15036772266672 , 5.451236954064116
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 45, Num Candles : 3
# 280.8398679106669 , -62.15060842466667 , 4.518698610184573
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 45, Num Candles : 4
# 217.64995256333356 , -70.83275377200016 , 3.0727303538687143
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 50, Num Candles : 1
# 257.98736094400005 , -77.92763821533336 , 3.3106015638651476
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 50, Num Candles : 2
# 302.0773494740001 , -71.73789009533333 , 4.210847978279901
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 50, Num Candles : 3
# 227.89705264266695 , -72.7837837426666 , 3.13115148627635
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 50, Num Candles : 4
# 171.9526685046669 , -78.07843175866655 , 2.2023068936138115
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 55, Num Candles : 1
# 284.4203766986667 , -68.21288988533342 , 4.169598695741821
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 55, Num Candles : 2
# 343.060100036 , -60.179916957333376 , 5.700574500280954
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 55, Num Candles : 3
# 253.58454894600013 , -75.27823784333326 , 3.3686302470808687
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 55, Num Candles : 4
# 207.58525417666692 , -79.22103734266652 , 2.620329916645342
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 60, Num Candles : 1
# 277.45159924066684 , -78.73012689199999 , 3.5240842380613455
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 60, Num Candles : 2
# 334.9389139633335 , -63.09327907733325 , 5.308630631684237
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 60, Num Candles : 3
# 248.97040412266688 , -76.55964809599986 , 3.251979473710189
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 60, Num Candles : 4
# 215.7126916066669 , -80.75683206333314 , 2.6711386033257885
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 65, Num Candles : 1
# 287.6106376873334 , -80.73393047066673 , 3.5624505831761986
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 65, Num Candles : 2
# 326.3258850520001 , -63.9934427026667 , 5.099364423448993
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 65, Num Candles : 3
# 227.85549964400013 , -72.4929012199999 , 3.143142236127496
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 65, Num Candles : 4
# 187.6268077573335 , -78.69262815466652 , 2.38429967529566
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 70, Num Candles : 1
# 304.9199590393333 , -77.96789239800006 , 3.91084008636297
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 70, Num Candles : 2
# 344.2230102326668 , -67.2292915446667 , 5.120134428368434
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 70, Num Candles : 3
# 246.61560278466678 , -63.76710451066657 , 3.867442385492263
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 70, Num Candles : 4
# 203.01875727466688 , -69.96513564266664 , 2.90171319486245
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 75, Num Candles : 1
# 356.24230495866675 , -57.98179044466673 , 6.144037675046211
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 75, Num Candles : 2
# 376.8737755133334 , -47.9458575613333 , 7.860403269067175
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 75, Num Candles : 3
# 259.40986320800016 , -63.384929557999925 , 4.0926110515060055
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 75, Num Candles : 4
# 213.0335580826669 , -70.00478473666662 , 3.0431285359139983
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 80, Num Candles : 1
# 352.7358703113334 , -60.9815450866667 , 5.784305232181748
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 80, Num Candles : 2
# 371.95052087666676 , -52.99471572333334 , 7.018634137382467
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 80, Num Candles : 3
# 248.1978932280001 , -64.71461121199994 , 3.8352682428226834
# NSE_UNITDSPR, 60, SMA : 16 , TMA : 80, Num Candles : 4
# 201.9781953420002 , -72.62075937199992 , 2.781273524108536
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 10, Num Candles : 1
# 170.7522853400003 , -137.0698454553332 , 1.245731946167862
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 10, Num Candles : 2
# 192.23042013933366 , -102.41861672466658 , 1.876908967205732
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 10, Num Candles : 3
# 249.53149066733354 , -89.72129634666663 , 2.7811846331688033
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 10, Num Candles : 4
# 216.94232952533355 , -85.99686089133328 , 2.5226773079480727
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 15, Num Candles : 1
# 233.5940184546669 , -120.00151247199996 , 1.9465922857361615
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 15, Num Candles : 2
# 217.5883070100003 , -96.54186159599993 , 2.2538234027488
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 15, Num Candles : 3
# 277.71593426666675 , -80.11850877800003 , 3.466314319905634
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 15, Num Candles : 4
# 239.98627010800018 , -77.75049601466662 , 3.086620438572249
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 20, Num Candles : 1
# 276.49230594666676 , -100.86410113133327 , 2.7412360081080904
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 20, Num Candles : 2
# 241.46170479933352 , -85.13537712799999 , 2.8362087882255906
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 20, Num Candles : 3
# 284.9464453713335 , -69.54190739400005 , 4.097478140151188
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 20, Num Candles : 4
# 272.76786950200017 , -67.70219755000011 , 4.028936716574863
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 25, Num Candles : 1
# 242.13879165600036 , -99.88972973666655 , 2.424060934936321
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 25, Num Candles : 2
# 204.1475528273336 , -90.12391340599991 , 2.265187397130301
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 25, Num Candles : 3
# 260.3220256773336 , -67.8822137693335 , 3.8349077206279443
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 25, Num Candles : 4
# 246.29422859333366 , -75.84964040866649 , 3.247137722292911
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 30, Num Candles : 1
# 218.85844700200033 , -106.10143039733337 , 2.06272852479377
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 30, Num Candles : 2
# 183.99569857000043 , -93.42717928999988 , 1.9694022656819596
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 30, Num Candles : 3
# 221.55566981600035 , -73.88127403399999 , 2.99880683857781
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 30, Num Candles : 4
# 220.58941605133367 , -66.37584084199997 , 3.3233389325556164
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 35, Num Candles : 1
# 272.33601407866684 , -84.8206063400001 , 3.2107293950130296
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 35, Num Candles : 2
# 244.01879327400027 , -80.71871761199992 , 3.023075694127772
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 35, Num Candles : 3
# 275.8840724573337 , -56.42082159199987 , 4.889756382002994
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 35, Num Candles : 4
# 242.10222699733364 , -65.65772282133318 , 3.6873381621250956
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 40, Num Candles : 1
# 293.1975364433334 , -91.83808302600008 , 3.1925485243450353
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 40, Num Candles : 2
# 286.0522572526668 , -79.12763226733335 , 3.615074141056526
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 40, Num Candles : 3
# 321.2699422066669 , -52.24041919600012 , 6.1498346902864345
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 40, Num Candles : 4
# 285.1847864200002 , -62.69720565733326 , 4.548604414344328
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 45, Num Candles : 1
# 322.6999123000001 , -69.6742363153333 , 4.631552914904115
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 45, Num Candles : 2
# 311.3529323913336 , -82.83284799733337 , 3.758809939763956
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 45, Num Candles : 3
# 329.46417003200014 , -62.210980834000054 , 5.295916663187196
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 45, Num Candles : 4
# 289.8598661166669 , -75.02287834199996 , 3.8636196387361887
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 50, Num Candles : 1
# 265.47489481800005 , -78.6531343733334 , 3.3752614810987978
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 50, Num Candles : 2
# 250.39965145200023 , -87.53918857866665 , 2.860429203395915
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 50, Num Candles : 3
# 279.7186535060002 , -59.08459808066664 , 4.73420591139687
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 50, Num Candles : 4
# 246.13326415333356 , -73.22182143399979 , 3.36147420718278
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 55, Num Candles : 1
# 292.1958625360001 , -66.60130740200005 , 4.3872391389005285
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 55, Num Candles : 2
# 276.2566984400001 , -82.55726500133329 , 3.3462433431574867
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 55, Num Candles : 3
# 303.84382027200013 , -50.43744792399997 , 6.02417118189321
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 55, Num Candles : 4
# 264.24688456600006 , -60.744475302666615 , 4.350138564031681
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 60, Num Candles : 1
# 292.60737356866684 , -69.65704716733319 , 4.200685866941111
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 60, Num Candles : 2
# 290.62355713333346 , -83.7653193839999 , 3.4694973918865735
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 60, Num Candles : 3
# 318.0208543653335 , -53.17394136466663 , 5.980765130505335
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 60, Num Candles : 4
# 282.41504428066685 , -60.65767869266671 , 4.65588282254543
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 65, Num Candles : 1
# 296.6975491793334 , -68.15054648799993 , 4.353560821872153
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 65, Num Candles : 2
# 275.7576540793334 , -85.75081509133327 , 3.2158021330249014
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 65, Num Candles : 3
# 281.92308337466676 , -67.87166744800004 , 4.153766865837833
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 65, Num Candles : 4
# 245.38703179466683 , -88.57401472000001 , 2.7704178541571567
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 70, Num Candles : 1
# 326.11722005133345 , -66.56321940866667 , 4.899360682197897
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 70, Num Candles : 2
# 296.23975879666676 , -88.96880657199995 , 3.329703636711461
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 70, Num Candles : 3
# 306.7966542106669 , -61.02098658400001 , 5.027723597820531
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 70, Num Candles : 4
# 279.0577237866668 , -69.34173402666659 , 4.024383406381938
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 75, Num Candles : 1
# 357.897328694 , -56.62772749466677 , 6.320178197645437
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 75, Num Candles : 2
# 317.38774559533346 , -71.55035550800005 , 4.43586538937387
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 75, Num Candles : 3
# 314.43802855266676 , -53.2623919626667 , 5.9035656673674435
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 75, Num Candles : 4
# 283.3808949020001 , -62.48543853933364 , 4.535150933182874
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 80, Num Candles : 1
# 356.59072489400006 , -60.48178203133341 , 5.895836943251166
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 80, Num Candles : 2
# 313.5281435053334 , -74.53646714000007 , 4.206372471564032
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 80, Num Candles : 3
# 305.0850313426668 , -58.85356600933346 , 5.183798570409209
# NSE_UNITDSPR, 60, SMA : 18 , TMA : 80, Num Candles : 4
# 270.66704313133346 , -71.49732311600036 , 3.7856947831765884
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 10, Num Candles : 1
# 170.11271726133344 , -95.96618625799985 , 1.772631839343857
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 10, Num Candles : 2
# 248.00765610600016 , -73.84118509133337 , 3.358662998152618
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 10, Num Candles : 3
# 272.4836308253335 , -69.18228722133327 , 3.9386328751112694
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 10, Num Candles : 4
# 308.26791407066685 , -54.305231109999994 , 5.676578623636519
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 15, Num Candles : 1
# 205.4298032766667 , -89.32870128799996 , 2.2997065927819915
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 15, Num Candles : 2
# 276.32972543466684 , -62.552345930000044 , 4.417575733193075
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 15, Num Candles : 3
# 290.96732307133345 , -62.79955503000011 , 4.633270457606504
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 15, Num Candles : 4
# 284.43498359666665 , -60.56786946800008 , 4.696136517513509
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 20, Num Candles : 1
# 225.82172864333324 , -106.58133597133354 , 2.118773672569379
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 20, Num Candles : 2
# 282.95315617266675 , -75.91781834533344 , 3.7270980955429347
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 20, Num Candles : 3
# 296.2933539326666 , -61.58933860266711 , 4.81078967001337
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 20, Num Candles : 4
# 303.0377354893333 , -69.3161741580002 , 4.371818542647566
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 25, Num Candles : 1
# 191.54873519866686 , -111.47416239733317 , 1.718324058950268
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 25, Num Candles : 2
# 245.73448672266684 , -74.3393436733333 , 3.3055778351028904
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 25, Num Candles : 3
# 276.46301608133354 , -65.18784534000037 , 4.241020924060074
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 25, Num Candles : 4
# 286.9146733453334 , -60.079434791333426 , 4.7755887574814775
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 30, Num Candles : 1
# 185.90201425933358 , -102.48930656733341 , 1.8138674217412105
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 30, Num Candles : 2
# 225.17280436800021 , -60.64945002066651 , 3.7126932608831873
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 30, Num Candles : 3
# 250.12143927866697 , -57.84374311533327 , 4.324088065669536
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 30, Num Candles : 4
# 275.8659575440002 , -57.20233670533332 , 4.822634413784001
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 35, Num Candles : 1
# 246.87215588466685 , -92.51506061666666 , 2.6684537008257943
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 35, Num Candles : 2
# 274.99919018666685 , -63.82315344266652 , 4.30876845397029
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 35, Num Candles : 3
# 287.5808475286668 , -62.944178437333505 , 4.568823593670048
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 35, Num Candles : 4
# 284.5785931726668 , -61.5604683200001 , 4.62274899686251
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 40, Num Candles : 1
# 282.80272106266665 , -88.16773789600006 , 3.207553327456943
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 40, Num Candles : 2
# 331.86079931733343 , -60.8450395546667 , 5.4541964595021835
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 40, Num Candles : 3
# 346.9505918753335 , -62.506643405333534 , 5.550619469765498
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 40, Num Candles : 4
# 337.9328886673333 , -61.6186753880001 , 5.48426084363936
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 45, Num Candles : 1
# 298.64204496866677 , -87.41548621399994 , 3.4163517004020054
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 45, Num Candles : 2
# 341.36752704066686 , -64.86058236333326 , 5.263096854857218
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 45, Num Candles : 3
# 341.2724108340002 , -67.93508193266678 , 5.023507753655897
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 45, Num Candles : 4
# 336.8269905400001 , -67.10232239333345 , 5.0196025789632515
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 50, Num Candles : 1
# 251.81234957266673 , -86.3948501753334 , 2.9146685139406805
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 50, Num Candles : 2
# 286.1953772220002 , -69.0436492726667 , 4.14513688423043
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 50, Num Candles : 3
# 297.3739386480001 , -67.04273030200005 , 4.435588128771789
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 50, Num Candles : 4
# 294.47030095666673 , -68.45661578733353 , 4.3015608874307265
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 55, Num Candles : 1
# 276.5773761479999 , -70.93582945933326 , 3.8989799408288968
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 55, Num Candles : 2
# 309.1932148666668 , -55.26110676400003 , 5.595132507698731
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 55, Num Candles : 3
# 322.6152402813335 , -50.774747660666776 , 6.353852163626822
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 55, Num Candles : 4
# 314.31182911400003 , -50.09358751666679 , 6.2744922992274095
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 60, Num Candles : 1
# 277.26508027799997 , -79.39085783133322 , 3.4924056478524617
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 60, Num Candles : 2
# 318.0038697006668 , -62.29252062533328 , 5.105008859945542
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 60, Num Candles : 3
# 336.0741348006669 , -49.540647718 , 6.783805829784466
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 60, Num Candles : 4
# 317.5532810206668 , -58.09632541533358 , 5.465978764585579
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 65, Num Candles : 1
# 264.10754405599994 , -74.75099986133324 , 3.533164031864889
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 65, Num Candles : 2
# 301.91007369466683 , -66.7457166559999 , 4.523287617850869
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 65, Num Candles : 3
# 311.3832184886668 , -57.573638922667044 , 5.4084338651395125
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 65, Num Candles : 4
# 311.7273616626668 , -69.45435037533366 , 4.488233782017708
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 70, Num Candles : 1
# 293.56321887533323 , -77.60306516599991 , 3.782881748902253
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 70, Num Candles : 2
# 340.9990070873335 , -64.75690425133331 , 5.265832439485593
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 70, Num Candles : 3
# 343.0053706993334 , -54.51738607266702 , 6.29166941793828
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 70, Num Candles : 4
# 323.57125615466674 , -64.46276905933371 , 5.019506001314353
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 75, Num Candles : 1
# 332.40797867866667 , -60.15409842199989 , 5.525940665700287
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 75, Num Candles : 2
# 350.56453041133335 , -50.12287007333333 , 6.994103288547373
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 75, Num Candles : 3
# 343.7451921900001 , -58.30993135333358 , 5.895139716544156
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 75, Num Candles : 4
# 327.16663594933334 , -65.5218208806669 , 4.993247006141557
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 80, Num Candles : 1
# 328.2952618706667 , -61.31121708400002 , 5.354570949405272
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 80, Num Candles : 2
# 341.4456063886668 , -50.941684417999966 , 6.702676016500524
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 80, Num Candles : 3
# 328.6615587740002 , -64.91347461600026 , 5.063071430365087
# NSE_UNITDSPR, 60, SMA : 20 , TMA : 80, Num Candles : 4
# 311.5134075413334 , -71.84232480733357 , 4.336070810302265
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 10, Num Candles : 1
# 219.9152035073336 , -95.2460140386666 , 2.308917656313214
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 10, Num Candles : 2
# 259.2062674680001 , -81.41545590333334 , 3.1837476630452373
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 10, Num Candles : 3
# 306.12739918333335 , -60.77711517199995 , 5.0368859778386845
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 10, Num Candles : 4
# 285.2205337346668 , -57.67076667133328 , 4.945669187304959
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 15, Num Candles : 1
# 257.25536156733347 , -88.41371181533327 , 2.9096772014803998
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 15, Num Candles : 2
# 260.87702226066665 , -82.43171177799996 , 3.164765314630911
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 15, Num Candles : 3
# 300.03631881466674 , -74.42463637133325 , 4.031411283189477
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 15, Num Candles : 4
# 270.5541256646666 , -76.75975160399986 , 3.524687352565226
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 20, Num Candles : 1
# 271.57760769333345 , -78.12613286999998 , 3.476142971843136
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 20, Num Candles : 2
# 296.1565170239998 , -66.55220041466667 , 4.449988357691225
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 20, Num Candles : 3
# 319.74470701066656 , -60.64925474666664 , 5.272030272197864
# NSE_UNITDSPR, 60, SMA : 22 , TMA : 20, Num Candles : 4
# ...
# 277.8390350726666 , -67.38015639399998 , 4.123454885560453
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 30, Num Candles : 4
# 286.25390126266655 , -64.28286943000012 , 4.453035525652421
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 35, Num Candles : 1
# 319.21606909999986 , -70.02494937333341 , 4.558604782391493
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 35, Num Candles : 2
# 341.3294780946664 , -53.84886872066659 , 6.3386564324176415
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 35, Num Candles : 3
# 303.35625567133314 , -57.9012028633333 , 5.239204725804366
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 35, Num Candles : 4
# 309.60079369266657 , -51.14655832533328 , 6.053208736418907
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 40, Num Candles : 1
# 342.6004910193333 , -70.81912013733347 , 4.8376835288966795
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 40, Num Candles : 2
# 367.6465372579998 , -54.87538859333324 , 6.699661664039038
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 40, Num Candles : 3
# 317.23154179733325 , -61.21850617466666 , 5.181954961335033
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 40, Num Candles : 4
# 324.77128041933327 , -54.01438926066663 , 6.01268078496691
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 45, Num Candles : 1
# 327.21194970666653 , -79.87586105133352 , 4.096506070793759
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 45, Num Candles : 2
# 350.2414042433331 , -63.82163787333326 , 5.487815980819183
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 45, Num Candles : 3
# 289.48118462799994 , -60.93728509466666 , 4.750477218968454
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 45, Num Candles : 4
# 296.3563278439999 , -54.14033718933328 , 5.473854490555112
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 50, Num Candles : 1
# 298.9924368286667 , -68.12265387866682 , 4.389030958206675
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 50, Num Candles : 2
# 300.8229490726665 , -59.83452406866661 , 5.027581546858124
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 50, Num Candles : 3
# 256.011810496 , -62.839837196666664 , 4.074036819904112
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 50, Num Candles : 4
# 268.08310461866665 , -55.86162540333329 , 4.799056645470792
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 55, Num Candles : 1
# 346.02108055999986 , -58.21479749266649 , 5.9438681480183675
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 55, Num Candles : 2
# 353.4147918453332 , -51.7659866346666 , 6.827162289777718
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 55, Num Candles : 3
# 278.08991358599985 , -59.04477575066666 , 4.709814036051445
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 55, Num Candles : 4
# 287.46076688199986 , -51.22821847533328 , 5.611375437941768
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 60, Num Candles : 1
# 326.14080647466665 , -67.70762364466651 , 4.81689932268591
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 60, Num Candles : 2
# 335.4933403599999 , -62.37383384866661 , 5.37875130738291
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 60, Num Candles : 3
# 276.3761839006666 , -60.73565957000008 , 4.550476373474349
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 60, Num Candles : 4
# 283.56929445666657 , -49.96139659333326 , 5.675767968714178
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 65, Num Candles : 1
# 331.0449641333333 , -62.9760823066668 , 5.256677646622805
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 65, Num Candles : 2
# 350.07100565799976 , -56.131409369999915 , 6.236633100559547
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 65, Num Candles : 3
# 294.90613558799987 , -66.39373858466666 , 4.441776316179718
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 65, Num Candles : 4
# 301.1982098733332 , -58.5771813093333 , 5.141903436472494
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 70, Num Candles : 1
# 356.28552601599995 , -62.314804499999866 , 5.717510130614318
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 70, Num Candles : 2
# 369.46102864133314 , -57.703510055333254 , 6.4027479140705355
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 70, Num Candles : 3
# 310.5799241566666 , -56.84712775733331 , 5.463423332177088
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 70, Num Candles : 4
# 327.0091252459998 , -49.030570481999945 , 6.669494603699361
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 1
# 372.8416232853332 , -63.86299926466671 , 5.838147715865486
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 2
# 414.3266351899998 , -46.179799671333356 , 8.972031887076328
#         Total ROI Total Trades Win Rate Avg Profit% per Trade Avg Loss% per Trade Max Drawdown ROI/DD Ratio                                               Variation
# 2017     127.5287           35  25.7143               18.6781             -1.5605     -13.3561       9.5483  NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 2
# 2018       2.6827           44  15.9091               11.2433             -2.0546     -36.7548       0.0730  NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 2
# 2019       5.6513           52  17.3077                6.6177             -1.2537     -32.7278       0.1727  NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 2
# 2020      56.9270           34  20.5882               13.5351             -1.4007     -10.8991       5.2231  NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 2
# 2021     196.5013           26  34.6154               25.1190             -1.7394     -13.6000      14.4486  NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 2
# 2022      39.1686           39  17.9487               14.1333             -1.8676     -35.3708       1.1074  NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 2
# 2023       0.6499           37  24.3243                6.2068             -1.9718     -39.5139       0.0164  NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 2
# 2024     -14.7829           38  21.0526                2.7923             -1.2374     -27.0078      -0.5474  NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 2
# Overall  414.3266          305  21.3115               12.3741             -1.6250     -46.1798       8.9720  NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 2
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 3
# 349.60026949133317 , -57.93275437733334 , 6.034587397904166
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 75, Num Candles : 4
# 362.33102102533326 , -50.11619710199997 , 7.22981874079336
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 1
# 387.0643169186666 , -62.29742007133336 , 6.213167679744369
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 2
# 425.28006359066654 , -41.47403003000002 , 10.25412922937661
#         Total ROI Total Trades Win Rate Avg Profit% per Trade Avg Loss% per Trade Max Drawdown ROI/DD Ratio                                               Variation
# 2017     119.8115           34  26.4706               17.7189             -1.5863     -13.5117       8.8672  NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 2
# 2018       8.8554           41  17.0732               10.8210             -1.9674     -32.0491       0.2763  NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 2
# 2019       4.3682           50  18.0000                6.1310             -1.2393     -31.5896       0.1383  NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 2
# 2020      59.2763           35  20.0000               14.2492             -1.4453     -16.9407       3.4990  NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 2
# 2021     200.2668           27  33.3333               25.2244             -1.4863     -10.4491      19.1660  NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 2
# 2022      48.3456           38  18.4211               15.1618             -1.8641     -26.3255       1.8365  NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 2
# 2023      -0.4899           38  23.6842                6.0250             -1.8867     -39.3447      -0.0125  NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 2
# 2024     -15.1539           37  21.6216                2.6225             -1.2460     -26.3602      -0.5749  NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 2
# Overall  425.2801          300  21.6667               12.2846             -1.5882     -41.4740      10.2541  NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 2
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 3
# 360.9070990493332 , -54.65811586466664 , 6.602991949867762
# NSE_UNITDSPR, 60, SMA : 56 , TMA : 80, Num Candles : 4
# 373.6934206133333 , -47.45399895066663 , 7.8748562582012624
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 10, Num Candles : 1
# 169.43981805666655 , -119.69472768199986 , 1.4155996787663652
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 10, Num Candles : 2
# 163.23949987799983 , -103.54939929199995 , 1.5764408194940773
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 10, Num Candles : 3
# 167.23088461999987 , -104.75792663999994 , 1.5963554261119344
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 10, Num Candles : 4
# 174.71760179266664 , -85.92045237666665 , 2.0334809345128004
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 15, Num Candles : 1
# 239.01081073599997 , -88.77427273800026 , 2.692343213459976
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 15, Num Candles : 2
# 241.18261723066647 , -72.55730602933343 , 3.324029383521506
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 15, Num Candles : 3
# 225.64961890533323 , -71.31961070133326 , 3.1639210686425536
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 15, Num Candles : 4
# 233.98088112266657 , -55.62252845333339 , 4.206584771114345
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 20, Num Candles : 1
# 258.4377389606665 , -111.56501843066724 , 2.316476460058797
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 20, Num Candles : 2
# 259.56418907999966 , -97.99042991266722 , 2.6488728471885783
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 20, Num Candles : 3
# 251.51898844533312 , -99.4113550840004 , 2.530083089932786
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 20, Num Candles : 4
# 271.7406126473331 , -66.48757651066688 , 4.0870885495989855
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 25, Num Candles : 1
# 246.06968863933338 , -106.24574418333347 , 2.3160427792262928
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 25, Num Candles : 2
# 260.18945240666653 , -84.02308027666697 , 3.096642631404702
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 25, Num Candles : 3
# 251.8429354839999 , -85.35287475266699 , 2.950608707835358
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 25, Num Candles : 4
# 263.65675579733335 , -63.80961066800012 , 4.131928608201877
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 30, Num Candles : 1
# 233.3381507186666 , -102.40798732466658 , 2.278515151156217
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 30, Num Candles : 2
# 243.52728166133315 , -78.67428800866688 , 3.0953858983065192
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 30, Num Candles : 3
# 235.80936402266653 , -77.7588048013335 , 3.032574441249933
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 30, Num Candles : 4
# 241.10372573799992 , -61.41779401533344 , 3.925633110134279
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 35, Num Candles : 1
# 284.6422634519999 , -81.70768941800014 , 3.4836655580336777
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 35, Num Candles : 2
# 281.28491765399986 , -60.161571154000114 , 4.6754915514751705
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 35, Num Candles : 3
# 267.0092935113332 , -55.484181756666715 , 4.812349845625157
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 35, Num Candles : 4
# 273.0045259659999 , -49.11654772666665 , 5.5583003814777205
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 40, Num Candles : 1
# 308.31329916599987 , -83.31215404000022 , 3.700700128554725
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 40, Num Candles : 2
# 304.3616415233331 , -57.78512850933333 , 5.267127535662973
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 40, Num Candles : 3
# 286.8207640586665 , -55.81351573333342 , 5.138912327778144
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 40, Num Candles : 4
# 296.0161821693332 , -51.191402386666645 , 5.782537073968379
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 45, Num Candles : 1
# 285.67544057599997 , -96.34605407400039 , 2.9650974637381786
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 45, Num Candles : 2
# 292.58907345733314 , -72.30282755000025 , 4.046716890221151
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 45, Num Candles : 3
# 262.81240792933335 , -71.11876137466703 , 3.695401928399569
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 45, Num Candles : 4
# 264.353648658 , -64.50375281733338 , 4.0982677303538715
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 50, Num Candles : 1
# 263.4906370626666 , -84.29733075133345 , 3.1257293049993593
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 50, Num Candles : 2
# 254.7110303613333 , -64.20678443266664 , 3.967042308876994
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 50, Num Candles : 3
# 237.91822748866673 , -66.78810187400006 , 3.562284610775649
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 50, Num Candles : 4
# 233.011240412 , -62.178483078 , 3.74745778406492
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 55, Num Candles : 1
# 300.6704919406666 , -84.0350873593332 , 3.5779160989623597
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 55, Num Candles : 2
# 289.54871199066645 , -68.47239285199987 , 4.22869276113241
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 55, Num Candles : 3
# 261.13596558199987 , -70.42149044000007 , 3.7081857249881804
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 55, Num Candles : 4
# 250.47526970466657 , -64.33718834400003 , 3.8931646867347984
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 60, Num Candles : 1
# 296.12945272199994 , -86.35469529733331 , 3.4292223683075704
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 60, Num Candles : 2
# 286.80876559333313 , -71.55777142266663 , 4.0080729163469115
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 60, Num Candles : 3
# 251.89596954866659 , -80.47768693800003 , 3.1300100578527696
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 60, Num Candles : 4
# 238.94059376533323 , -74.38772051200004 , 3.212097267139513
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 65, Num Candles : 1
# 295.79970111599994 , -80.10388571266662 , 3.692701027975549
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 65, Num Candles : 2
# 297.6623956046665 , -58.708842015333175 , 5.070145916469023
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 65, Num Candles : 3
# 257.4669748099998 , -68.47484689333342 , 3.7600226432206347
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 65, Num Candles : 4
# 245.37389314666657 , -63.11868972933331 , 3.887499791248571
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 70, Num Candles : 1
# 303.7748961999998 , -81.67598639799996 , 3.7192681667746403
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 70, Num Candles : 2
# 320.9613325206664 , -60.28094270066657 , 5.32442457169996
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 70, Num Candles : 3
# 288.5596871079998 , -68.16431751866656 , 4.233295331226323
# NSE_UNITDSPR, 60, SMA : 58 , TMA : 70, Num Candles : 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 22
#      20 print(variation)
#      21 signals_df1 = generate_signals1(bnf1, i, j, n)
# ---> 22 new_tb = execute(signals_df1)
#      23 stats = generate_stats(new_tb, variation)
#      24 for overall_roi_dd_ratio, stats_df in stats.items():
#
# Cell In[19], line 24, in execute(df)
#      21 current_moving_average_price = df.iloc[i]["MA10"]
#      23 if not in_trade:
# ---> 24     if df.iloc[i]["Buy_Signal"] == 1:
#      25         if not already_signal_exists:
#      26             # Fresh Buy Signal
#      27             # print(df.iloc[i])
#      28             # print('Fresh Buy Signal')
#      29             signal_entry_price = current_candle_high
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/series.py:1111, in Series.__getitem__(self, key)
#    1108     return self._values[key]
#    1110 elif key_is_scalar:
# -> 1111     return self._get_value(key)
#    1113 # Convert generator to list before going through hashable part
#    1114 # (We will iterate through the generator there to check for slices)
#    1115 if is_iterator(key):
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/series.py:1227, in Series._get_value(self, label, takeable)
#    1224     return self._values[label]
#    1226 # Similar to Index.get_value, but we do not fall back to positional
# -> 1227 loc = self.index.get_loc(label)
#    1229 if is_integer(loc):
#    1230     return self._values[loc]
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3800 casted_key = self._maybe_cast_indexer(key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#
# KeyboardInterrupt:

# %%
sorted_stats = {k: v for k, v in sorted(stats_dict.items(), key=lambda item: item[0], reverse=True)}

# %%
sorted_stats
# Out:
# {10.402718780933279:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     582.7492           40  25.0000               82.3007
#  2018      94.6296           34  23.5294               47.6403
#  2019      22.5257           40  20.0000               32.6067
#  2020     192.6415           47  14.8936               74.5809
#  2021    1027.5213           29  31.0345              131.2101
#  2022     261.2991           41  21.9512               60.8114
#  2023       8.2754           42  23.8095               27.7697
#  2024    -104.7510           39  20.5128               14.3844
#  Overall 2084.8907          312  22.1154               59.5364
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.0086     -71.2807       8.1754
#  2018               -11.0190    -138.6387       0.6826
#  2019                -7.4478    -146.3150       0.1540
#  2020                -8.2356    -154.4363       1.2474
#  2021                -7.6685     -79.5368      12.9188
#  2022                -8.9376    -115.5606       2.2611
#  2023                -8.4194    -199.4267       0.0415
#  2024                -7.0912    -135.5967      -0.7725
#  Overall             -8.3256    -200.4179      10.4027
#
#                                      Variation
#  2017     SMA : 50 , TMA : 80, Num Candles : 1
#  2018     SMA : 50 , TMA : 80, Num Candles : 1
#  2019     SMA : 50 , TMA : 80, Num Candles : 1
#  2020     SMA : 50 , TMA : 80, Num Candles : 1
#  2021     SMA : 50 , TMA : 80, Num Candles : 1
#  2022     SMA : 50 , TMA : 80, Num Candles : 1
#  2023     SMA : 50 , TMA : 80, Num Candles : 1
#  2024     SMA : 50 , TMA : 80, Num Candles : 1
#  Overall  SMA : 50 , TMA : 80, Num Candles : 1  ,
#  10.256589835076857:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     684.8353           33  30.3030               87.6532
#  2018     121.7213           28  35.7143               32.7486
#  2019     -20.9410           51  13.7255               40.3057
#  2020     230.9286           51  17.6471               62.0290
#  2021     880.9159           30  23.3333              160.0958
#  2022     194.3291           45  22.2222               55.0585
#  2023      43.9866           34  23.5294               33.1145
#  2024     -75.5672           38  18.4211               13.1153
#  Overall 2060.2085          310  21.9355               59.8882
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.3346     -71.0837       9.6342
#  2018               -11.4314    -115.5456       1.0534
#  2019                -6.8882    -200.8668      -0.1043
#  2020                -7.7936    -112.3409       2.0556
#  2021               -10.4241     -79.9246      11.0218
#  2022               -10.1787    -139.6481       1.3916
#  2023                -8.4973    -154.5612       0.2846
#  2024                -5.3992    -117.0512      -0.6456
#  Overall             -8.3148    -200.8668      10.2566
#
#                                      Variation
#  2017     SMA : 34 , TMA : 80, Num Candles : 1
#  2018     SMA : 34 , TMA : 80, Num Candles : 1
#  2019     SMA : 34 , TMA : 80, Num Candles : 1
#  2020     SMA : 34 , TMA : 80, Num Candles : 1
#  2021     SMA : 34 , TMA : 80, Num Candles : 1
#  2022     SMA : 34 , TMA : 80, Num Candles : 1
#  2023     SMA : 34 , TMA : 80, Num Candles : 1
#  2024     SMA : 34 , TMA : 80, Num Candles : 1
#  Overall  SMA : 34 , TMA : 80, Num Candles : 1  ,
#  9.568602899610502:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     756.6579           31  38.7097               77.7456
#  2018     122.1316           33  33.3333               34.1923
#  2019     101.5675           44  25.0000               30.2759
#  2020     209.6931           56  21.4286               47.2524
#  2021     936.2169           30  26.6667              142.9464
#  2022     136.2236           49  20.4082               46.3740
#  2023      41.9029           35  20.0000               36.5755
#  2024    -134.5640           47  17.0213               12.9783
#  Overall 2169.8296          325  24.3077               52.8644
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -9.2784     -68.5303      11.0412
#  2018               -11.5447    -122.4884       0.9971
#  2019                -7.0142     -94.8726       1.0706
#  2020                -8.1213    -121.2811       1.7290
#  2021                -9.4252     -82.4411      11.3562
#  2022                -8.3979    -183.2490       0.7434
#  2023                -7.6473    -132.6939       0.3158
#  2024                -6.1126    -181.7607      -0.7403
#  Overall             -8.1563    -226.7656       9.5686
#
#                                      Variation
#  2017     SMA : 28 , TMA : 75, Num Candles : 1
#  2018     SMA : 28 , TMA : 75, Num Candles : 1
#  2019     SMA : 28 , TMA : 75, Num Candles : 1
#  2020     SMA : 28 , TMA : 75, Num Candles : 1
#  2021     SMA : 28 , TMA : 75, Num Candles : 1
#  2022     SMA : 28 , TMA : 75, Num Candles : 1
#  2023     SMA : 28 , TMA : 75, Num Candles : 1
#  2024     SMA : 28 , TMA : 75, Num Candles : 1
#  Overall  SMA : 28 , TMA : 75, Num Candles : 1  ,
#  9.376240929167693:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     617.3338           41  24.3902               86.6795
#  2018      66.6538           38  21.0526               48.6005
#  2019      27.4707           42  19.0476               35.3360
#  2020     149.1751           46  17.3913               59.4669
#  2021     989.6766           30  30.0000              130.0378
#  2022     203.1433           44  20.4545               55.5159
#  2023      16.2127           39  25.6410               28.6712
#  2024    -108.8897           41  19.5122               14.7913
#  Overall 1960.7764          321  21.8069               58.4150
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.0471     -69.8882       8.8332
#  2018               -10.7383    -182.3710       0.3655
#  2019                -7.5064    -153.4767       0.1790
#  2020                -8.5937    -165.4606       0.9016
#  2021                -8.6030     -84.4687      11.7165
#  2022                -8.4714    -145.4741       1.3964
#  2023                -9.3276    -208.9803       0.0776
#  2024                -6.8854    -144.8449      -0.7518
#  Overall             -8.4792    -209.1218       9.3762
#
#                                      Variation
#  2017     SMA : 50 , TMA : 75, Num Candles : 1
#  2018     SMA : 50 , TMA : 75, Num Candles : 1
#  2019     SMA : 50 , TMA : 75, Num Candles : 1
#  2020     SMA : 50 , TMA : 75, Num Candles : 1
#  2021     SMA : 50 , TMA : 75, Num Candles : 1
#  2022     SMA : 50 , TMA : 75, Num Candles : 1
#  2023     SMA : 50 , TMA : 75, Num Candles : 1
#  2024     SMA : 50 , TMA : 75, Num Candles : 1
#  Overall  SMA : 50 , TMA : 75, Num Candles : 1  ,
#  9.300726130922637:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     715.6651           31  38.7097               73.9441
#  2018     116.9041           32  37.5000               30.1167
#  2019      58.5860           44  20.4545               33.5089
#  2020     229.6647           58  18.9655               53.0372
#  2021     944.8711           29  27.5862              143.5280
#  2022     131.6977           49  20.4082               47.6400
#  2023      42.6110           40  25.0000               26.4458
#  2024    -133.9410           46  17.3913               13.4594
#  Overall 2106.0588          329  24.3161               51.6310
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -9.0350     -68.5303      10.4431
#  2018               -12.2248    -122.4884       0.9544
#  2019                -6.9427     -98.5870       0.5943
#  2020                -7.5265    -125.0707       1.8363
#  2021                -9.6835     -78.4393      12.0459
#  2022                -8.8385    -204.1643       0.6451
#  2023                -7.3949    -142.1715       0.2997
#  2024                -6.3583    -184.8094      -0.7248
#  Overall             -8.1302    -226.4403       9.3007
#
#                                      Variation
#  2017     SMA : 28 , TMA : 80, Num Candles : 1
#  2018     SMA : 28 , TMA : 80, Num Candles : 1
#  2019     SMA : 28 , TMA : 80, Num Candles : 1
#  2020     SMA : 28 , TMA : 80, Num Candles : 1
#  2021     SMA : 28 , TMA : 80, Num Candles : 1
#  2022     SMA : 28 , TMA : 80, Num Candles : 1
#  2023     SMA : 28 , TMA : 80, Num Candles : 1
#  2024     SMA : 28 , TMA : 80, Num Candles : 1
#  Overall  SMA : 28 , TMA : 80, Num Candles : 1  ,
#  9.234876573992665:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     664.4314           37  21.6216              119.2634
#  2018     193.7938           33  36.3636               34.2849
#  2019      52.4872           48  22.9167               29.0514
#  2020     103.6802           62  16.1290               53.5861
#  2021     857.0705           35  25.7143              127.9765
#  2022     130.0625           46  17.3913               58.6970
#  2023      -1.4208           37  24.3243               25.5436
#  2024     -91.0524           40  12.5000               23.4991
#  Overall 1909.0524          338  21.3018               58.1903
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -9.9888     -83.9274       7.9167
#  2018               -10.3631    -102.2872       1.8946
#  2019                -7.2183    -130.2549       0.4030
#  2020                -8.3112    -146.4614       0.7079
#  2021               -11.3353     -72.5671      11.8107
#  2022                -8.9346    -184.7642       0.7039
#  2023                -8.2612    -122.7906      -0.0116
#  2024                -5.9585    -139.3176      -0.6536
#  Overall             -8.5739    -206.7220       9.2349
#
#                                      Variation
#  2017     SMA : 22 , TMA : 75, Num Candles : 1
#  2018     SMA : 22 , TMA : 75, Num Candles : 1
#  2019     SMA : 22 , TMA : 75, Num Candles : 1
#  2020     SMA : 22 , TMA : 75, Num Candles : 1
#  2021     SMA : 22 , TMA : 75, Num Candles : 1
#  2022     SMA : 22 , TMA : 75, Num Candles : 1
#  2023     SMA : 22 , TMA : 75, Num Candles : 1
#  2024     SMA : 22 , TMA : 75, Num Candles : 1
#  Overall  SMA : 22 , TMA : 75, Num Candles : 1  ,
#  9.160692917541741:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     782.0373           32  28.1250              106.0833
#  2018      38.9176           30  26.6667               37.4189
#  2019     -12.6842           47  17.0213               35.0423
#  2020     157.2222           54  20.3704               48.9077
#  2021     960.3791           27  25.9259              165.9620
#  2022     147.5822           45  17.7778               63.1927
#  2023       2.6659           42  21.4286               29.4780
#  2024    -116.3352           44  15.9091               16.6646
#  Overall 1959.7851          321  20.8723               61.5172
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -7.5092     -78.7218       9.9342
#  2018               -11.8379    -119.7037       0.3251
#  2019                -7.5134    -197.7766      -0.0641
#  2020                -8.8549    -160.6320       0.9788
#  2021               -10.0678     -82.1589      11.6893
#  2022                -9.6746    -185.4699       0.7957
#  2023                -7.9587    -175.2640       0.0152
#  2024                -6.2970    -152.5329      -0.7627
#  Overall             -8.5113    -213.9342       9.1607
#
#                                      Variation
#  2017     SMA : 38 , TMA : 80, Num Candles : 1
#  2018     SMA : 38 , TMA : 80, Num Candles : 1
#  2019     SMA : 38 , TMA : 80, Num Candles : 1
#  2020     SMA : 38 , TMA : 80, Num Candles : 1
#  2021     SMA : 38 , TMA : 80, Num Candles : 1
#  2022     SMA : 38 , TMA : 80, Num Candles : 1
#  2023     SMA : 38 , TMA : 80, Num Candles : 1
#  2024     SMA : 38 , TMA : 80, Num Candles : 1
#  Overall  SMA : 38 , TMA : 80, Num Candles : 1  ,
#  8.915259264581469:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     487.0912           40  25.0000               74.3965
#  2018      44.0332           45  13.3333               67.5148
#  2019      -9.9391           49  22.4490               25.6713
#  2020     258.7386           43  20.9302               59.0728
#  2021     866.0723           36  30.5556               98.2278
#  2022     292.9531           34  26.4706               62.2988
#  2023      10.2503           43  18.6047               34.3686
#  2024    -105.0616           41  19.5122               12.3702
#  Overall 1844.1379          331  21.7523               55.2528
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.5625     -73.1583       6.6580
#  2018                -9.2578    -148.9410       0.2956
#  2019                -7.6927    -194.3871      -0.0511
#  2020                -8.0270    -136.6746       1.8931
#  2021                -8.5773     -60.3311      14.3553
#  2022               -10.7094     -98.5132       2.9737
#  2023                -7.5628    -184.6207       0.0555
#  2024                -6.1825    -134.6107      -0.7805
#  Overall             -8.2396    -206.8519       8.9153
#
#                                      Variation
#  2017     SMA : 64 , TMA : 80, Num Candles : 1
#  2018     SMA : 64 , TMA : 80, Num Candles : 1
#  2019     SMA : 64 , TMA : 80, Num Candles : 1
#  2020     SMA : 64 , TMA : 80, Num Candles : 1
#  2021     SMA : 64 , TMA : 80, Num Candles : 1
#  2022     SMA : 64 , TMA : 80, Num Candles : 1
#  2023     SMA : 64 , TMA : 80, Num Candles : 1
#  2024     SMA : 64 , TMA : 80, Num Candles : 1
#  Overall  SMA : 64 , TMA : 80, Num Candles : 1  ,
#  8.815821192862854:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     590.6587           36  25.0000               92.0685
#  2018     103.4829           34  23.5294               47.8622
#  2019     -34.3389           47  17.0213               32.5135
#  2020     226.6725           42  16.6667               74.6428
#  2021    1036.7525           26  38.4615              116.2693
#  2022     173.1191           46  17.3913               65.7075
#  2023       3.5778           41  21.9512               30.5667
#  2024    -113.1624           39  17.9487               16.2173
#  Overall 1986.7622          311  21.2219               61.6833
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.8132     -64.3374       9.1806
#  2018               -10.7467    -135.8117       0.7620
#  2019                -7.5499    -213.8304      -0.1606
#  2020                -8.4522    -114.2074       1.9847
#  2021                -7.8713     -58.6140      17.6878
#  2022                -9.2774    -148.2628       1.1677
#  2023                -8.4851    -191.0870       0.0187
#  2024                -7.0839    -142.1199      -0.7962
#  Overall             -8.5075    -225.3633       8.8158
#
#                                      Variation
#  2017     SMA : 48 , TMA : 80, Num Candles : 1
#  2018     SMA : 48 , TMA : 80, Num Candles : 1
#  2019     SMA : 48 , TMA : 80, Num Candles : 1
#  2020     SMA : 48 , TMA : 80, Num Candles : 1
#  2021     SMA : 48 , TMA : 80, Num Candles : 1
#  2022     SMA : 48 , TMA : 80, Num Candles : 1
#  2023     SMA : 48 , TMA : 80, Num Candles : 1
#  2024     SMA : 48 , TMA : 80, Num Candles : 1
#  Overall  SMA : 48 , TMA : 80, Num Candles : 1  ,
#  8.634161653032773:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     630.2971           38  26.3158               85.6190
#  2018      59.2855           36  19.4444               54.2891
#  2019     -49.9365           54  16.6667               30.1582
#  2020     266.7389           43  20.9302               61.5586
#  2021    1062.5796           29  37.9310              108.6539
#  2022     217.6985           46  15.2174               77.4357
#  2023     -38.5568           46  19.5652               29.8958
#  2024     -89.3742           33  21.2121               13.9792
#  Overall 2058.7321          325  21.2308               60.3743
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.0676     -71.1859       8.8542
#  2018               -11.0599    -155.7298       0.3807
#  2019                -7.1413    -218.7771      -0.2283
#  2020                -8.4497    -117.9734       2.2610
#  2021                -7.3674     -51.7639      20.5274
#  2022                -8.3167    -143.4379       1.5177
#  2023                -8.3140    -221.2736      -0.1742
#  2024                -7.2011    -126.4977      -0.7065
#  Overall             -8.2308    -238.4403       8.6342
#
#                                      Variation
#  2017     SMA : 54 , TMA : 80, Num Candles : 1
#  2018     SMA : 54 , TMA : 80, Num Candles : 1
#  2019     SMA : 54 , TMA : 80, Num Candles : 1
#  2020     SMA : 54 , TMA : 80, Num Candles : 1
#  2021     SMA : 54 , TMA : 80, Num Candles : 1
#  2022     SMA : 54 , TMA : 80, Num Candles : 1
#  2023     SMA : 54 , TMA : 80, Num Candles : 1
#  2024     SMA : 54 , TMA : 80, Num Candles : 1
#  Overall  SMA : 54 , TMA : 80, Num Candles : 1  ,
#  8.61368906471652:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     741.5241           27  37.0370               90.8601
#  2018     104.2485           31  38.7097               30.2349
#  2019     103.0466           48  22.9167               29.8343
#  2020     181.7448           61  14.7541               65.7292
#  2021     929.9082           33  24.2424              144.8805
#  2022     120.0750           51  21.5686               44.1735
#  2023      15.0528           41  21.9512               29.1729
#  2024    -174.9407           44  15.9091               10.5679
#  Overall 2020.6591          336  22.9167               54.1902
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -9.8281     -64.9898      11.4099
#  2018               -13.6090    -134.3605       0.7759
#  2019                -6.0846     -90.5009       1.1386
#  2020                -7.8811    -140.9418       1.2895
#  2021                -9.1654     -72.4195      12.8406
#  2022                -9.1459    -215.4765       0.5573
#  2023                -7.7345    -169.6167       0.0887
#  2024                -6.7275    -184.7481      -0.9469
#  Overall             -8.3088    -234.5870       8.6137
#
#                                      Variation
#  2017     SMA : 26 , TMA : 80, Num Candles : 1
#  2018     SMA : 26 , TMA : 80, Num Candles : 1
#  2019     SMA : 26 , TMA : 80, Num Candles : 1
#  2020     SMA : 26 , TMA : 80, Num Candles : 1
#  2021     SMA : 26 , TMA : 80, Num Candles : 1
#  2022     SMA : 26 , TMA : 80, Num Candles : 1
#  2023     SMA : 26 , TMA : 80, Num Candles : 1
#  2024     SMA : 26 , TMA : 80, Num Candles : 1
#  Overall  SMA : 26 , TMA : 80, Num Candles : 1  ,
#  8.466389480502395:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     470.0503           36  30.5556               63.0301
#  2018      18.3224           44  18.1818               50.1484
#  2019      22.1669           41  24.3902               27.9744
#  2020     234.5698           50  20.0000               54.4018
#  2021     751.1855           40  20.0000              136.6711
#  2022     189.9006           43  18.6047               62.7612
#  2023     100.2497           39  30.7692               27.4502
#  2024     -87.0456           35  20.0000               16.3289
#  Overall 1699.3996          328  22.5610               53.4790
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.9312     -71.8245       6.5444
#  2018               -10.6351    -182.2133       0.1006
#  2019                -8.3089    -145.6419       0.1522
#  2020                -7.7362    -171.0025       1.3717
#  2021               -10.6932     -97.4490       7.7085
#  2022                -8.9197    -128.8552       1.4738
#  2023                -8.4871    -120.5872       0.8313
#  2024                -7.1910    -121.5926      -0.7159
#  Overall             -8.8899    -200.7231       8.4664
#
#                                      Variation
#  2017     SMA : 72 , TMA : 80, Num Candles : 1
#  2018     SMA : 72 , TMA : 80, Num Candles : 1
#  2019     SMA : 72 , TMA : 80, Num Candles : 1
#  2020     SMA : 72 , TMA : 80, Num Candles : 1
#  2021     SMA : 72 , TMA : 80, Num Candles : 1
#  2022     SMA : 72 , TMA : 80, Num Candles : 1
#  2023     SMA : 72 , TMA : 80, Num Candles : 1
#  2024     SMA : 72 , TMA : 80, Num Candles : 1
#  Overall  SMA : 72 , TMA : 80, Num Candles : 1  ,
#  8.3863393503331:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     724.3278           33  30.3030               91.9872
#  2018     108.0320           30  33.3333               34.4931
#  2019     -29.2967           53  15.0943               36.9454
#  2020     184.7793           50  20.0000               51.3641
#  2021     879.8319           30  23.3333              160.2723
#  2022     107.1576           50  18.0000               55.5034
#  2023      58.1008           32  25.0000               33.7397
#  2024     -81.4593           40  17.5000               13.3299
#  Overall 1951.4735          318  21.6981               58.8213
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.5019     -74.9306       9.6666
#  2018               -11.8450    -115.5456       0.9350
#  2019                -7.2191    -212.9182      -0.1376
#  2020                -8.2215    -103.7236       1.7815
#  2021               -10.5250     -73.9100      11.9041
#  2022                -9.5701    -201.1339       0.5328
#  2023                -8.8257    -154.5612       0.3759
#  2024                -5.2960    -126.2994      -0.6450
#  Overall             -8.4626    -232.6967       8.3863
#
#                                      Variation
#  2017     SMA : 34 , TMA : 75, Num Candles : 1
#  2018     SMA : 34 , TMA : 75, Num Candles : 1
#  2019     SMA : 34 , TMA : 75, Num Candles : 1
#  2020     SMA : 34 , TMA : 75, Num Candles : 1
#  2021     SMA : 34 , TMA : 75, Num Candles : 1
#  2022     SMA : 34 , TMA : 75, Num Candles : 1
#  2023     SMA : 34 , TMA : 75, Num Candles : 1
#  2024     SMA : 34 , TMA : 75, Num Candles : 1
#  Overall  SMA : 34 , TMA : 75, Num Candles : 1  ,
#  8.26790966387498:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     700.2185           36  27.7778               93.2752
#  2018     115.7843           31  35.4839               31.7547
#  2019      85.2706           43  27.9070               26.9735
#  2020     204.1960           59  13.5593               74.6820
#  2021     812.4798           41  21.9512              126.1721
#  2022     135.3607           52  15.3846               58.3194
#  2023     -45.1835           43  25.5814               19.1074
#  2024    -115.6305           42  16.6667               17.6627
#  Overall 1892.4959          347  21.9020               54.4620
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.9436     -81.8227       8.5578
#  2018               -11.6759    -129.9863       0.8907
#  2019                -7.6907    -108.5745       0.7854
#  2020                -7.7110    -138.8251       1.4709
#  2021               -10.0959     -85.0223       9.5561
#  2022                -7.5271    -193.1239       0.7009
#  2023                -7.9801    -166.0212      -0.2722
#  2024                -6.8363    -166.4990      -0.6945
#  Overall             -8.2901    -228.8965       8.2679
#
#                                      Variation
#  2017     SMA : 24 , TMA : 80, Num Candles : 1
#  2018     SMA : 24 , TMA : 80, Num Candles : 1
#  2019     SMA : 24 , TMA : 80, Num Candles : 1
#  2020     SMA : 24 , TMA : 80, Num Candles : 1
#  2021     SMA : 24 , TMA : 80, Num Candles : 1
#  2022     SMA : 24 , TMA : 80, Num Candles : 1
#  2023     SMA : 24 , TMA : 80, Num Candles : 1
#  2024     SMA : 24 , TMA : 80, Num Candles : 1
#  Overall  SMA : 24 , TMA : 80, Num Candles : 1  ,
#  8.25351024620875:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     624.0636           37  24.3243               96.8027
#  2018     109.2100           35  22.8571               49.8015
#  2019     -25.2323           49  16.3265               35.2425
#  2020     219.4855           42  19.0476               62.9834
#  2021    1000.3340           26  38.4615              115.8101
#  2022      97.8826           49  14.2857               68.5127
#  2023      11.5149           38  23.6842               31.5684
#  2024    -117.3011           41  17.0732               16.6823
#  Overall 1919.9571          317  20.8202               62.0307
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.8272     -64.3374       9.6999
#  2018               -10.7112    -142.6548       0.7656
#  2019                -7.4920    -216.8356      -0.1164
#  2020                -8.3642    -118.6214       1.8503
#  2021                -9.8604     -62.1197      16.1033
#  2022                -9.0882    -206.4179       0.4742
#  2023                -9.4000    -200.6406       0.0574
#  2024                -6.8846    -151.3681      -0.7749
#  Overall             -8.6616    -232.6231       8.2535
#
#                                      Variation
#  2017     SMA : 48 , TMA : 75, Num Candles : 1
#  2018     SMA : 48 , TMA : 75, Num Candles : 1
#  2019     SMA : 48 , TMA : 75, Num Candles : 1
#  2020     SMA : 48 , TMA : 75, Num Candles : 1
#  2021     SMA : 48 , TMA : 75, Num Candles : 1
#  2022     SMA : 48 , TMA : 75, Num Candles : 1
#  2023     SMA : 48 , TMA : 75, Num Candles : 1
#  2024     SMA : 48 , TMA : 75, Num Candles : 1
#  Overall  SMA : 48 , TMA : 75, Num Candles : 1  ,
#  8.251134294751784:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     517.8972           41  24.3902               76.9770
#  2018      83.1102           43  16.2791               58.6540
#  2019      -8.0447           50  24.0000               24.7970
#  2020     262.4862           45  22.2222               53.2926
#  2021     789.2229           39  25.6410              106.9603
#  2022     230.2350           39  23.0769               59.5368
#  2023      22.2957           37  21.6216               33.8395
#  2024    -124.0356           42  19.0476               12.3702
#  Overall 1773.1667          336  22.0238               53.8642
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.1249     -75.9920       6.8152
#  2018                -9.0963    -154.1552       0.5391
#  2019                -8.0423    -202.5183      -0.0397
#  2020                -7.7269    -147.9815       1.7738
#  2021                -9.6683     -86.4413       9.1302
#  2022               -10.1865    -136.1264       1.6913
#  2023                -8.5662    -172.5753       0.1292
#  2024                -6.5587    -153.5848      -0.8076
#  Overall             -8.4457    -214.8998       8.2511
#
#                                      Variation
#  2017     SMA : 66 , TMA : 80, Num Candles : 1
#  2018     SMA : 66 , TMA : 80, Num Candles : 1
#  2019     SMA : 66 , TMA : 80, Num Candles : 1
#  2020     SMA : 66 , TMA : 80, Num Candles : 1
#  2021     SMA : 66 , TMA : 80, Num Candles : 1
#  2022     SMA : 66 , TMA : 80, Num Candles : 1
#  2023     SMA : 66 , TMA : 80, Num Candles : 1
#  2024     SMA : 66 , TMA : 80, Num Candles : 1
#  Overall  SMA : 66 , TMA : 80, Num Candles : 1  ,
#  8.229501818735068:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     708.0157           32  31.2500               90.0395
#  2018     146.3217           30  26.6667               47.7092
#  2019     -10.1494           47  19.1489               30.2417
#  2020     233.0389           43  20.9302               60.1232
#  2021     968.9610           28  25.0000              163.7415
#  2022     130.9696           51  17.6471               57.3994
#  2023     -10.9824           42  19.0476               34.1121
#  2024    -112.9381           42  16.6667               17.3706
#  Overall 2053.2371          315  21.2698               61.9795
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.7445     -49.4488      14.3182
#  2018               -10.6978    -104.3842       1.4018
#  2019                -7.4296    -187.4611      -0.0541
#  2020                -9.0609    -152.4795       1.5283
#  2021                -8.4395     -89.6580      10.8073
#  2022                -9.1815    -160.3831       0.8166
#  2023                -8.3494    -195.2897      -0.0562
#  2024                -6.7009    -157.7225      -0.7161
#  Overall             -8.4653    -249.4971       8.2295
#
#                                      Variation
#  2017     SMA : 46 , TMA : 80, Num Candles : 1
#  2018     SMA : 46 , TMA : 80, Num Candles : 1
#  2019     SMA : 46 , TMA : 80, Num Candles : 1
#  2020     SMA : 46 , TMA : 80, Num Candles : 1
#  2021     SMA : 46 , TMA : 80, Num Candles : 1
#  2022     SMA : 46 , TMA : 80, Num Candles : 1
#  2023     SMA : 46 , TMA : 80, Num Candles : 1
#  2024     SMA : 46 , TMA : 80, Num Candles : 1
#  Overall  SMA : 46 , TMA : 80, Num Candles : 1  ,
#  8.136606476803804:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     677.1054           32  31.2500               87.6532
#  2018      42.6391           33  27.2727               35.5095
#  2019     -23.8549           49  14.2857               40.0974
#  2020     173.6912           57  14.0351               68.6463
#  2021     930.3133           29  24.1379              165.5106
#  2022     130.0729           50  22.0000               47.6321
#  2023      73.2501           31  29.0323               28.2956
#  2024    -105.2922           41  17.0732               13.2901
#  Overall 1897.9249          322  21.1180               59.6498
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -9.0648     -79.9597       8.4681
#  2018               -11.5394    -140.8940       0.3026
#  2019                -7.2509    -199.3690      -0.1197
#  2020                -7.6628    -137.3152       1.2649
#  2021               -10.3755     -85.3706      10.8974
#  2022               -10.0995    -216.4678       0.6009
#  2023                -8.2459    -129.4918       0.5657
#  2024                -5.8330    -139.8392      -0.7530
#  Overall             -8.4971    -233.2576       8.1366
#
#                                      Variation
#  2017     SMA : 32 , TMA : 80, Num Candles : 1
#  2018     SMA : 32 , TMA : 80, Num Candles : 1
#  2019     SMA : 32 , TMA : 80, Num Candles : 1
#  2020     SMA : 32 , TMA : 80, Num Candles : 1
#  2021     SMA : 32 , TMA : 80, Num Candles : 1
#  2022     SMA : 32 , TMA : 80, Num Candles : 1
#  2023     SMA : 32 , TMA : 80, Num Candles : 1
#  2024     SMA : 32 , TMA : 80, Num Candles : 1
#  Overall  SMA : 32 , TMA : 80, Num Candles : 1  ,
#  8.086782334377995:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     473.8820           37  29.7297               62.9651
#  2018      44.0189           45  15.5556               53.5144
#  2019      -7.8760           47  23.4043               25.4761
#  2020     228.7804           48  20.8333               54.4018
#  2021     750.1591           38  21.0526              136.6711
#  2022     250.6060           41  24.3902               52.3422
#  2023     107.3905           36  33.3333               27.3159
#  2024     -80.9799           37  21.6216               15.0915
#  Overall 1765.9809          329  23.4043               51.3868
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.4128     -81.5431       5.8114
#  2018                -8.6995    -152.0830       0.2894
#  2019                -8.0031    -182.2436      -0.0432
#  2020                -8.2957    -165.5271       1.3821
#  2021               -11.4403     -91.3079       8.2157
#  2022                -8.8005    -117.9480       2.1247
#  2023                -9.1834    -111.7227       0.9612
#  2024                -6.9556    -136.6221      -0.5927
#  Overall             -8.6937    -218.3787       8.0868
#
#                                      Variation
#  2017     SMA : 70 , TMA : 80, Num Candles : 1
#  2018     SMA : 70 , TMA : 80, Num Candles : 1
#  2019     SMA : 70 , TMA : 80, Num Candles : 1
#  2020     SMA : 70 , TMA : 80, Num Candles : 1
#  2021     SMA : 70 , TMA : 80, Num Candles : 1
#  2022     SMA : 70 , TMA : 80, Num Candles : 1
#  2023     SMA : 70 , TMA : 80, Num Candles : 1
#  2024     SMA : 70 , TMA : 80, Num Candles : 1
#  Overall  SMA : 70 , TMA : 80, Num Candles : 1  ,
#  8.059796490186294:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2017     641.1457           40  27.5000               81.6371
#  2018     191.7034           33  30.3030               45.1880
#  2019      13.5162           49  18.3673               32.0343
#  2020     179.4948           58  24.1379               37.6796
#  2021     862.6960           38  28.9474              102.5353
#  2022      77.6205           54  24.0741               33.8369
#  2023     114.9919           35  31.4286               26.0899
#  2024     -92.5043           50  24.0000               12.5235
#  Overall 1988.6643          357  25.4902               45.8324
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2017                -8.8573     -77.1191       8.3137
#  2018               -11.3120    -151.4302       1.2660
#  2019                -6.8698    -140.0490       0.0965
#  2020                -7.9095    -102.4477       1.7521
#  2021                -9.8219     -93.1153       9.2648
#  2022                -8.8356    -219.9173       0.3530
#  2023                -7.1665     -99.2459       1.1587
#  2024                -6.3891    -136.0031      -0.6802
#  Overall             -8.2033    -246.7388       8.0598
#
#                                      Variation
#  2017     SMA : 28 , TMA : 55, Num Candles : 1
#  2018     SMA : 28 , TMA : 55, Num Candles : 1
#  2019     SMA : 28 , TMA : 55, Num Candles : 1
#  2020     SMA : 28 , TMA : 55, Num Candles : 1
#  2021     SMA : 28 , TMA : 55, Num Candles : 1
#  2022     SMA : 28 , TMA : 55, Num Candles : 1
#  2023     SMA : 28 , TMA : 55, Num Candles : 1
#  2024     SMA : 28 , TMA : 55, Num Candles : 1
#  Overall  SMA : 28 , TMA : 55, Num Candles : 1  }

# %% [markdown]
# # MTrend BNF

# %%
# new_tb.to_csv('BNF Mtrend New.csv', index=False)

# %%
# Positional Sell Side


def execute_sell_side(df):
    portfolio_value = 7500000
    trade_book = []
    in_trade = False
    signal_entry_price = 100000
    signal_initial_sl = 0
    already_signal_exists = False
    remark = ""
    is_trailing_active = False
    previous_trade_exit_time = None

    for i in range(1, len(df)):
        points = 0
        current_candle_open = df.iloc[i]["o"]
        current_candle_high = df.iloc[i]["h"]
        current_candle_low = df.iloc[i]["l"]
        current_candle_close = df.iloc[i]["c"]
        current_moving_average_price = df.iloc[i]["MA10"]

        if not in_trade:
            if df.iloc[i]["Sell_Signal"] == 1:
                if not already_signal_exists:
                    # Fresh Sell Signal
                    # print(df.iloc[i])
                    # print('Fresh Short Sell Signal')
                    signal_entry_price = current_candle_low
                    signal_initial_sl = current_candle_high
                    signal_creation_time = df.iloc[i]["datetime"]
                    already_signal_exists = True

                    # if (signal_initial_sl - signal_entry_price > 400):
                    #     # Skip Signal Candle Due To Big Size
                    #     already_signal_exists = False
                    #     signal_entry_price = 100000
                    #     signal_initial_sl = 0

                else:
                    if current_candle_open < signal_entry_price:
                        # Gap Down Outside, SKIP trade
                        # print('Signal Entry Price' , signal_entry_price)
                        # print(df.iloc[i])
                        # print('Gap Outside, Skip Trade')
                        already_signal_exists = False
                        signal_entry_price = 100000
                        signal_initial_sl = 0
                    elif current_candle_low > signal_entry_price:
                        # Better Candle
                        
                        # print(df.iloc[i])
                        # print('Better Candle')
                        signal_entry_price = current_candle_low
                        signal_initial_sl = current_candle_high
                        signal_creation_time = df.iloc[i]["datetime"]

                        # if (signal_initial_sl - signal_entry_price > 400):
                        #     # Skip Signal Candle Due To Big Size
                        #     already_signal_exists = False
                        #     signal_entry_price = 100000
                        #     signal_initial_sl = 0

                    elif current_candle_low < signal_entry_price:
                        # Entry Triggered
                        
                        # print(df.iloc[i])
                        # print('Entry Triggered')
                        in_trade = True
                        entry_time = df.iloc[i]["datetime"]
                        entry_price = signal_entry_price
                        points = 0
            else:
                if df.iloc[i - 1]["Sell_Signal"] == 1:
                    # Considering the forward bias condition as well now
                    signal_entry_price = df.iloc[i - 1]["l"]
                    signal_initial_sl = df.iloc[i - 1]["h"]
                    signal_creation_time = df.iloc[i - 1]["datetime"]
                    already_signal_exists = True

                    if current_candle_low < signal_entry_price:
                        if df.iloc[i-1]['datetime'] != previous_trade_exit_time:
                            in_trade = True
                            entry_time = df.iloc[i]["datetime"]
                            entry_price = signal_entry_price
                            points = 0
                    else:
                        # Discard Existing Signal
                        already_signal_exists = False
                        signal_entry_price = 100000
                        signal_initial_sl = 0

        if in_trade:
            trade_entry_price = signal_entry_price
            trade_initial_sl = signal_initial_sl
            trade_final_sl = signal_initial_sl

            if (
                not is_trailing_active
                and current_candle_high < current_moving_average_price
            ):
                is_trailing_active = True

            if not is_trailing_active:
                if current_candle_open > trade_initial_sl:
                    # if df.iloc[i-1]['h'] > trade_initial_sl:
                    #     #Previous Candle Already Hit the SL Hence don't check gap down
                    #     in_trade = False
                    #     points = -1 * (trade_initial_sl - trade_entry_price)
                    #     exit_price = trade_initial_sl
                    #     exit_time = df.iloc[i-1]['datetime']
                    #     remark = 'Initial SL Hit'
                    # else:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        if current_candle_close >= trade_initial_sl:
                            in_trade = False
                            points = -1 * (trade_initial_sl - trade_entry_price)
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL Hit"
                    else:
                        # Gap Open Outside ISL
                        
                        # print(df.iloc[i])
                        # print('Gap Outside Initial SL')
                        in_trade = False
                        points = trade_entry_price - current_candle_open
                        exit_price = current_candle_open
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif current_candle_high >= trade_initial_sl:
                    # Initial SL Hit
                    
                    # print(df.iloc[i])
                    # print('Initial SL Hit')
                    in_trade = False
                    points = -1 * (trade_initial_sl - trade_entry_price)
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL Hit"

                elif current_candle_close >= trade_final_sl:
                    # TSL Hit
                    # print(df.iloc[i])
                    # print('TSL Hit')
                    in_trade = False
                    points = -1 * (current_candle_close - trade_entry_price)
                    exit_price = current_candle_close
                    exit_time = df.iloc[i]["datetime"]
                    remark = "TSL Hit"

            elif is_trailing_active:
                trade_final_sl = min(trade_initial_sl, current_moving_average_price)

                if current_candle_open > trade_initial_sl:
                    # if df.iloc[i-1]['h'] > trade_initial_sl:
                    #     #Previous Candle Already Hit the SL Hence don't check gap down
                    #     in_trade = False
                    #     points = -1 * (trade_initial_sl - trade_entry_price)
                    #     exit_price = trade_initial_sl
                    #     exit_time = df.iloc[i-1]['datetime']
                    #     remark = 'Initial SL Hit'
                    # else:
                    if (
                        df.iloc[i]["datetime"].date() == entry_time.date()
                        and df.iloc[i]["datetime"].time() == entry_time.time()
                    ):
                        if current_candle_close >= trade_initial_sl:
                            in_trade = False
                            points = -1 * (trade_initial_sl - trade_entry_price)
                            exit_price = trade_initial_sl
                            exit_time = df.iloc[i]["datetime"]
                            remark = "Initial SL Hit"
                    else:
                        # Gap Open Outside ISL
                        
                        # print(df.iloc[i])
                        # print('Gap Outside Initial SL')
                        in_trade = False
                        points = trade_entry_price - current_candle_open
                        exit_price = current_candle_open
                        exit_time = df.iloc[i]["datetime"]
                        remark = "Gap Open Outside ISL"

                elif current_candle_high >= trade_initial_sl:
                    # if trade_initial_sl <= current_moving_average_price:
                    # Despite Trailing, Initial SL hit
                    # print(df.iloc[i])
                    # print('Initial SL Hit')
                    in_trade = False
                    points = -1 * (trade_initial_sl - trade_entry_price)
                    exit_price = trade_initial_sl
                    exit_time = df.iloc[i]["datetime"]
                    remark = "Initial SL hit"

                elif current_candle_close >= trade_final_sl:
                    # Price Closed below TSL i.e. MA10 , TSL Hit
                    # print(df.iloc[i])
                    # print('TSL Hit')
                    in_trade = False
                    points = -1 * (current_candle_close - trade_entry_price)
                    exit_price = current_candle_close
                    exit_time = df.iloc[i]["datetime"]
                    is_trailing_active = False
                    remark = "TSL Hit"

            if points:
                qty = int(round(portfolio_value * 3.5 / entry_price / 50)) * 50
                slippage = 0.0005 * (entry_price + exit_price)
                # slippage = 10
                final_points = points - slippage
                # final_points = points
                previous_trade_exit_time = exit_time
                trade = {
                    "Signal Generated At": signal_creation_time,
                    "Trade Type": "SHORT",
                    "Entry Time": entry_time,
                    "Entry Price": entry_price,
                    "Initial SL": trade_initial_sl,
                    "Final SL": trade_final_sl,
                    "Exit Time": exit_time,
                    "Exit Price": exit_price,
                    "Points Captured": points,
                    "After Costs": final_points,
                    "PnL": final_points * qty,
                    "Remarks": remark,
                    "Qty": qty,
                    "Leverage": "3x",
                    "ROI%": (final_points * qty / portfolio_value) * 100,
                    "Trade Year": entry_time.year,
                    "Trade Month": entry_time.month,
                }
                # print(trade)
                trade_book.append(trade)
                points = 0
                in_trade = False
                already_signal_exists = False
                remark = ""
                is_trailing_active = False

    trade_book_df = pd.DataFrame(trade_book)
    return trade_book_df

# %%
data = pd.read_csv('../data/midcp.csv')
data = pl.DataFrame(data)
data = data.with_columns([
    pl.col("datetime").str.strptime(pl.Datetime, "%Y-%m-%d %H:%M:%S")
])

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2022, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2022, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI%"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI%"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI%"] > 0]["ROI%"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI%"] < 0]["ROI%"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI%"].cumsum() - year_trades["ROI%"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI%"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI%"] > 0]["ROI%"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI%"].cumsum() - combined_df_sorted["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation
    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    return {overall_roi_dd_ratio : stats_df8}

# %%
targets = [2, 4, 6, 8, 10, 12, 15, 18, 20, 25, 30, 50, 100]
time_frames = ["3m", "5m", "10m", "15m", "30m", "60m"]
num_candles = [1, 2, 3, 4, 5]
for i in range(5, 81, 5):
    for j in range(5, 81, 5):
        for k in targets:
            for tf in time_frames:
                for candles in num_candles:
                    if tf == "10m":
                        offset = "5m"
                    elif tf == "30m" or tf == "60m":
                        offset = "15m"
                    else:
                        offset = "0m"
                    variation = f"SMA: {i}, TMA: {j}, Target: {k}R, TF: {tf}, Candles: {candles}"
                    print(variation)
                    data_w_signals = (resample(data, tf, offset)).to_pandas()
                    data_w_signals = generate_signals2(data_w_signals, i, j, candles)
                    data_w_signals2 = data_w_signals.rename(columns={"open": "o", "high": "h", "low": "l", "close": "c"})
                    sell_tb = execute_sell_side(data_w_signals2)
                    stats = generate_stats(sell_tb, variation)
                    for overall_roi_dd_ratio, stats_df in stats.items():
                        if overall_roi_dd_ratio is not None and overall_roi_dd_ratio > 3:
                            print(stats_df.to_string())
                            stats_dictionary[overall_roi_dd_ratio] = stats_df
# Out:
# SMA: 5, TMA: 5, Target: 2R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 2R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 2R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 2R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 2R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 2R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 2R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 2R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 2R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 2R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 2R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 2R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 2R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 2R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 2R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 2R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 2R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 2R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 2R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 2R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 2R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 2R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 2R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 2R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 2R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 2R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 2R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 2R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 2R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 2R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 4R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 4R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 4R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 4R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 4R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 4R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 4R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 4R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 4R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 4R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 4R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 4R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 4R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 4R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 4R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 4R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 4R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 4R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 4R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 4R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 4R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 4R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 4R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 4R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 4R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 4R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 4R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 4R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 4R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 4R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 6R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 6R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 6R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 6R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 6R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 6R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 6R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 6R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 6R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 6R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 6R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 6R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 6R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 6R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 6R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 6R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 6R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 6R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 6R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 6R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 6R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 6R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 6R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 6R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 6R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 6R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 6R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 6R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 6R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 6R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 8R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 8R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 8R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 8R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 8R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 8R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 8R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 8R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 8R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 8R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 8R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 8R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 8R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 8R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 8R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 8R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 8R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 8R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 8R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 8R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 8R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 8R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 8R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 8R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 8R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 8R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 8R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 8R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 8R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 8R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 10R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 10R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 10R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 10R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 10R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 10R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 10R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 10R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 10R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 10R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 10R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 10R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 10R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 10R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 10R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 10R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 10R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 10R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 10R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 10R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 10R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 10R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 10R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 10R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 10R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 10R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 10R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 10R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 10R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 10R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 12R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 12R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 12R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 12R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 12R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 12R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 12R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 12R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 12R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 12R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 12R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 12R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 12R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 12R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 12R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 12R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 12R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 12R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 12R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 12R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 12R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 12R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 12R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 12R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 12R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 12R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 12R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 12R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 12R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 12R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 15R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 15R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 15R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 15R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 15R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 15R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 15R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 15R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 15R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 15R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 15R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 15R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 15R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 15R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 15R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 15R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 15R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 15R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 15R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 15R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 15R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 15R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 15R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 15R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 15R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 15R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 15R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 15R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 15R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 15R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 18R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 18R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 18R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 18R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 18R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 18R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 18R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 18R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 18R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 18R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 18R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 18R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 18R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 18R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 18R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 18R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 18R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 18R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 18R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 18R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 18R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 18R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 18R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 18R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 18R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 18R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 18R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 18R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 18R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 18R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 20R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 20R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 20R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 20R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 20R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 20R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 20R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 20R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 20R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 20R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 20R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 20R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 20R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 20R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 20R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 20R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 20R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 20R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 20R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 20R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 20R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 20R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 20R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 20R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 20R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 20R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 20R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 20R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 20R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 20R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 25R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 25R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 25R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 25R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 25R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 25R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 25R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 25R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 25R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 25R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 25R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 25R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 25R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 25R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 25R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 25R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 25R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 25R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 25R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 25R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 25R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 25R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 25R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 25R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 25R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 25R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 25R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 25R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 25R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 25R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 30R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 30R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 30R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 30R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 30R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 30R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 30R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 30R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 30R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 30R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 30R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 30R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 30R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 30R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 30R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 30R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 30R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 30R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 30R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 30R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 30R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 30R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 30R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 30R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 30R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 30R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 30R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 30R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 30R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 30R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 50R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 50R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 50R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 50R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 50R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 50R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 50R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 50R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 50R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 50R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 50R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 50R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 50R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 50R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 50R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 50R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 50R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 50R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 50R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 50R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 50R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 50R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 50R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 50R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 50R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 50R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 50R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 50R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 50R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 50R, TF: 60m, Candles: 5
# SMA: 5, TMA: 5, Target: 100R, TF: 3m, Candles: 1
# SMA: 5, TMA: 5, Target: 100R, TF: 3m, Candles: 2
# SMA: 5, TMA: 5, Target: 100R, TF: 3m, Candles: 3
# SMA: 5, TMA: 5, Target: 100R, TF: 3m, Candles: 4
# SMA: 5, TMA: 5, Target: 100R, TF: 3m, Candles: 5
# SMA: 5, TMA: 5, Target: 100R, TF: 5m, Candles: 1
# SMA: 5, TMA: 5, Target: 100R, TF: 5m, Candles: 2
# SMA: 5, TMA: 5, Target: 100R, TF: 5m, Candles: 3
# SMA: 5, TMA: 5, Target: 100R, TF: 5m, Candles: 4
# SMA: 5, TMA: 5, Target: 100R, TF: 5m, Candles: 5
# SMA: 5, TMA: 5, Target: 100R, TF: 10m, Candles: 1
# SMA: 5, TMA: 5, Target: 100R, TF: 10m, Candles: 2
# SMA: 5, TMA: 5, Target: 100R, TF: 10m, Candles: 3
# SMA: 5, TMA: 5, Target: 100R, TF: 10m, Candles: 4
# SMA: 5, TMA: 5, Target: 100R, TF: 10m, Candles: 5
# SMA: 5, TMA: 5, Target: 100R, TF: 15m, Candles: 1
# SMA: 5, TMA: 5, Target: 100R, TF: 15m, Candles: 2
# SMA: 5, TMA: 5, Target: 100R, TF: 15m, Candles: 3
# SMA: 5, TMA: 5, Target: 100R, TF: 15m, Candles: 4
# SMA: 5, TMA: 5, Target: 100R, TF: 15m, Candles: 5
# SMA: 5, TMA: 5, Target: 100R, TF: 30m, Candles: 1
# SMA: 5, TMA: 5, Target: 100R, TF: 30m, Candles: 2
# SMA: 5, TMA: 5, Target: 100R, TF: 30m, Candles: 3
# SMA: 5, TMA: 5, Target: 100R, TF: 30m, Candles: 4
# SMA: 5, TMA: 5, Target: 100R, TF: 30m, Candles: 5
# SMA: 5, TMA: 5, Target: 100R, TF: 60m, Candles: 1
# SMA: 5, TMA: 5, Target: 100R, TF: 60m, Candles: 2
# SMA: 5, TMA: 5, Target: 100R, TF: 60m, Candles: 3
# SMA: 5, TMA: 5, Target: 100R, TF: 60m, Candles: 4
# SMA: 5, TMA: 5, Target: 100R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 2R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 2R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 2R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 2R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 2R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 2R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 2R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 2R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 2R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 2R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 2R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 2R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 2R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 2R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 2R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 2R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 2R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 2R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 2R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 2R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 2R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 2R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 2R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 2R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 2R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 2R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 2R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 2R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 2R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 2R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 4R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 4R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 4R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 4R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 4R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 4R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 4R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 4R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 4R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 4R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 4R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 4R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 4R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 4R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 4R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 4R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 4R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 4R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 4R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 4R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 4R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 4R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 4R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 4R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 4R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 4R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 4R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 4R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 4R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 4R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 6R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 6R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 6R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 6R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 6R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 6R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 6R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 6R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 6R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 6R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 6R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 6R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 6R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 6R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 6R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 6R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 6R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 6R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 6R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 6R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 6R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 6R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 6R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 6R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 6R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 6R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 6R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 6R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 6R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 6R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 8R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 8R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 8R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 8R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 8R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 8R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 8R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 8R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 8R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 8R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 8R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 8R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 8R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 8R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 8R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 8R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 8R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 8R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 8R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 8R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 8R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 8R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 8R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 8R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 8R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 8R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 8R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 8R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 8R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 8R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 10R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 10R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 10R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 10R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 10R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 10R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 10R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 10R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 10R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 10R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 10R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 10R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 10R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 10R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 10R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 10R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 10R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 10R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 10R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 10R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 10R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 10R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 10R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 10R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 10R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 10R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 10R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 10R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 10R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 10R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 12R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 12R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 12R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 12R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 12R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 12R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 12R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 12R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 12R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 12R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 12R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 12R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 12R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 12R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 12R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 12R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 12R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 12R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 12R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 12R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 12R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 12R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 12R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 12R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 12R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 12R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 12R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 12R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 12R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 12R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 15R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 15R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 15R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 15R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 15R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 15R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 15R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 15R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 15R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 15R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 15R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 15R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 15R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 15R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 15R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 15R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 15R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 15R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 15R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 15R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 15R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 15R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 15R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 15R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 15R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 15R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 15R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 15R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 15R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 15R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 18R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 18R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 18R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 18R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 18R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 18R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 18R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 18R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 18R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 18R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 18R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 18R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 18R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 18R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 18R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 18R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 18R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 18R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 18R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 18R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 18R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 18R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 18R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 18R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 18R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 18R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 18R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 18R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 18R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 18R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 20R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 20R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 20R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 20R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 20R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 20R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 20R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 20R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 20R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 20R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 20R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 20R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 20R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 20R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 20R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 20R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 20R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 20R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 20R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 20R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 20R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 20R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 20R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 20R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 20R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 20R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 20R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 20R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 20R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 20R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 25R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 25R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 25R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 25R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 25R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 25R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 25R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 25R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 25R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 25R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 25R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 25R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 25R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 25R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 25R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 25R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 25R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 25R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 25R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 25R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 25R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 25R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 25R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 25R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 25R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 25R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 25R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 25R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 25R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 25R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 30R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 30R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 30R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 30R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 30R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 30R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 30R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 30R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 30R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 30R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 30R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 30R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 30R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 30R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 30R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 30R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 30R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 30R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 30R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 30R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 30R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 30R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 30R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 30R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 30R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 30R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 30R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 30R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 30R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 30R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 50R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 50R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 50R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 50R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 50R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 50R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 50R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 50R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 50R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 50R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 50R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 50R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 50R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 50R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 50R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 50R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 50R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 50R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 50R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 50R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 50R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 50R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 50R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 50R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 50R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 50R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 50R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 50R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 50R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 50R, TF: 60m, Candles: 5
# SMA: 5, TMA: 10, Target: 100R, TF: 3m, Candles: 1
# SMA: 5, TMA: 10, Target: 100R, TF: 3m, Candles: 2
# SMA: 5, TMA: 10, Target: 100R, TF: 3m, Candles: 3
# SMA: 5, TMA: 10, Target: 100R, TF: 3m, Candles: 4
# SMA: 5, TMA: 10, Target: 100R, TF: 3m, Candles: 5
# SMA: 5, TMA: 10, Target: 100R, TF: 5m, Candles: 1
# SMA: 5, TMA: 10, Target: 100R, TF: 5m, Candles: 2
# SMA: 5, TMA: 10, Target: 100R, TF: 5m, Candles: 3
# SMA: 5, TMA: 10, Target: 100R, TF: 5m, Candles: 4
# SMA: 5, TMA: 10, Target: 100R, TF: 5m, Candles: 5
# SMA: 5, TMA: 10, Target: 100R, TF: 10m, Candles: 1
# SMA: 5, TMA: 10, Target: 100R, TF: 10m, Candles: 2
# SMA: 5, TMA: 10, Target: 100R, TF: 10m, Candles: 3
# SMA: 5, TMA: 10, Target: 100R, TF: 10m, Candles: 4
# SMA: 5, TMA: 10, Target: 100R, TF: 10m, Candles: 5
# SMA: 5, TMA: 10, Target: 100R, TF: 15m, Candles: 1
# SMA: 5, TMA: 10, Target: 100R, TF: 15m, Candles: 2
# SMA: 5, TMA: 10, Target: 100R, TF: 15m, Candles: 3
# SMA: 5, TMA: 10, Target: 100R, TF: 15m, Candles: 4
# SMA: 5, TMA: 10, Target: 100R, TF: 15m, Candles: 5
# SMA: 5, TMA: 10, Target: 100R, TF: 30m, Candles: 1
# SMA: 5, TMA: 10, Target: 100R, TF: 30m, Candles: 2
# SMA: 5, TMA: 10, Target: 100R, TF: 30m, Candles: 3
# SMA: 5, TMA: 10, Target: 100R, TF: 30m, Candles: 4
# SMA: 5, TMA: 10, Target: 100R, TF: 30m, Candles: 5
# SMA: 5, TMA: 10, Target: 100R, TF: 60m, Candles: 1
# SMA: 5, TMA: 10, Target: 100R, TF: 60m, Candles: 2
# SMA: 5, TMA: 10, Target: 100R, TF: 60m, Candles: 3
# SMA: 5, TMA: 10, Target: 100R, TF: 60m, Candles: 4
# SMA: 5, TMA: 10, Target: 100R, TF: 60m, Candles: 5
# SMA: 5, TMA: 15, Target: 2R, TF: 3m, Candles: 1
# SMA: 5, TMA: 15, Target: 2R, TF: 3m, Candles: 2
# SMA: 5, TMA: 15, Target: 2R, TF: 3m, Candles: 3
# SMA: 5, TMA: 15, Target: 2R, TF: 3m, Candles: 4
# SMA: 5, TMA: 15, Target: 2R, TF: 3m, Candles: 5
# SMA: 5, TMA: 15, Target: 2R, TF: 5m, Candles: 1
# SMA: 5, TMA: 15, Target: 2R, TF: 5m, Candles: 2
# SMA: 5, TMA: 15, Target: 2R, TF: 5m, Candles: 3
# SMA: 5, TMA: 15, Target: 2R, TF: 5m, Candles: 4
# SMA: 5, TMA: 15, Target: 2R, TF: 5m, Candles: 5
# SMA: 5, TMA: 15, Target: 2R, TF: 10m, Candles: 1
# SMA: 5, TMA: 15, Target: 2R, TF: 10m, Candles: 2
# SMA: 5, TMA: 15, Target: 2R, TF: 10m, Candles: 3
# SMA: 5, TMA: 15, Target: 2R, TF: 10m, Candles: 4
# SMA: 5, TMA: 15, Target: 2R, TF: 10m, Candles: 5
# SMA: 5, TMA: 15, Target: 2R, TF: 15m, Candles: 1
# SMA: 5, TMA: 15, Target: 2R, TF: 15m, Candles: 2
# SMA: 5, TMA: 15, Target: 2R, TF: 15m, Candles: 3
# SMA: 5, TMA: 15, Target: 2R, TF: 15m, Candles: 4
# SMA: 5, TMA: 15, Target: 2R, TF: 15m, Candles: 5
# SMA: 5, TMA: 15, Target: 2R, TF: 30m, Candles: 1
# SMA: 5, TMA: 15, Target: 2R, TF: 30m, Candles: 2
# SMA: 5, TMA: 15, Target: 2R, TF: 30m, Candles: 3
# SMA: 5, TMA: 15, Target: 2R, TF: 30m, Candles: 4
# SMA: 5, TMA: 15, Target: 2R, TF: 30m, Candles: 5
# SMA: 5, TMA: 15, Target: 2R, TF: 60m, Candles: 1
# SMA: 5, TMA: 15, Target: 2R, TF: 60m, Candles: 2
# SMA: 5, TMA: 15, Target: 2R, TF: 60m, Candles: 3
# SMA: 5, TMA: 15, Target: 2R, TF: 60m, Candles: 4
# SMA: 5, TMA: 15, Target: 2R, TF: 60m, Candles: 5
# SMA: 5, TMA: 15, Target: 4R, TF: 3m, Candles: 1
# SMA: 5, TMA: 15, Target: 4R, TF: 3m, Candles: 2
# SMA: 5, TMA: 15, Target: 4R, TF: 3m, Candles: 3
# SMA: 5, TMA: 15, Target: 4R, TF: 3m, Candles: 4
# SMA: 5, TMA: 15, Target: 4R, TF: 3m, Candles: 5
# SMA: 5, TMA: 15, Target: 4R, TF: 5m, Candles: 1
# SMA: 5, TMA: 15, Target: 4R, TF: 5m, Candles: 2
# SMA: 5, TMA: 15, Target: 4R, TF: 5m, Candles: 3
# SMA: 5, TMA: 15, Target: 4R, TF: 5m, Candles: 4
# SMA: 5, TMA: 15, Target: 4R, TF: 5m, Candles: 5
# SMA: 5, TMA: 15, Target: 4R, TF: 10m, Candles: 1
# SMA: 5, TMA: 15, Target: 4R, TF: 10m, Candles: 2
# SMA: 5, TMA: 15, Target: 4R, TF: 10m, Candles: 3
# SMA: 5, TMA: 15, Target: 4R, TF: 10m, Candles: 4
# SMA: 5, TMA: 15, Target: 4R, TF: 10m, Candles: 5
# SMA: 5, TMA: 15, Target: 4R, TF: 15m, Candles: 1
# SMA: 5, TMA: 15, Target: 4R, TF: 15m, Candles: 2
# SMA: 5, TMA: 15, Target: 4R, TF: 15m, Candles: 3
# SMA: 5, TMA: 15, Target: 4R, TF: 15m, Candles: 4
# SMA: 5, TMA: 15, Target: 4R, TF: 15m, Candles: 5
# SMA: 5, TMA: 15, Target: 4R, TF: 30m, Candles: 1
# SMA: 5, TMA: 15, Target: 4R, TF: 30m, Candles: 2
# SMA: 5, TMA: 15, Target: 4R, TF: 30m, Candles: 3
# SMA: 5, TMA: 15, Target: 4R, TF: 30m, Candles: 4
# SMA: 5, TMA: 15, Target: 4R, TF: 30m, Candles: 5
# SMA: 5, TMA: 15, Target: 4R, TF: 60m, Candles: 1
# SMA: 5, TMA: 15, Target: 4R, TF: 60m, Candles: 2
# SMA: 5, TMA: 15, Target: 4R, TF: 60m, Candles: 3
# SMA: 5, TMA: 15, Target: 4R, TF: 60m, Candles: 4
# SMA: 5, TMA: 15, Target: 4R, TF: 60m, Candles: 5
# SMA: 5, TMA: 15, Target: 6R, TF: 3m, Candles: 1
# SMA: 5, TMA: 15, Target: 6R, TF: 3m, Candles: 2
# SMA: 5, TMA: 15, Target: 6R, TF: 3m, Candles: 3
# SMA: 5, TMA: 15, Target: 6R, TF: 3m, Candles: 4
# SMA: 5, TMA: 15, Target: 6R, TF: 3m, Candles: 5
# SMA: 5, TMA: 15, Target: 6R, TF: 5m, Candles: 1
# SMA: 5, TMA: 15, Target: 6R, TF: 5m, Candles: 2
# SMA: 5, TMA: 15, Target: 6R, TF: 5m, Candles: 3
# SMA: 5, TMA: 15, Target: 6R, TF: 5m, Candles: 4
# SMA: 5, TMA: 15, Target: 6R, TF: 5m, Candles: 5
# SMA: 5, TMA: 15, Target: 6R, TF: 10m, Candles: 1
# SMA: 5, TMA: 15, Target: 6R, TF: 10m, Candles: 2
# SMA: 5, TMA: 15, Target: 6R, TF: 10m, Candles: 3
# SMA: 5, TMA: 15, Target: 6R, TF: 10m, Candles: 4
# SMA: 5, TMA: 15, Target: 6R, TF: 10m, Candles: 5
# SMA: 5, TMA: 15, Target: 6R, TF: 15m, Candles: 1
# SMA: 5, TMA: 15, Target: 6R, TF: 15m, Candles: 2
# SMA: 5, TMA: 15, Target: 6R, TF: 15m, Candles: 3
# SMA: 5, TMA: 15, Target: 6R, TF: 15m, Candles: 4
# SMA: 5, TMA: 15, Target: 6R, TF: 15m, Candles: 5
# SMA: 5, TMA: 15, Target: 6R, TF: 30m, Candles: 1
# SMA: 5, TMA: 15, Target: 6R, TF: 30m, Candles: 2
# SMA: 5, TMA: 15, Target: 6R, TF: 30m, Candles: 3
# SMA: 5, TMA: 15, Target: 6R, TF: 30m, Candles: 4
# SMA: 5, TMA: 15, Target: 6R, TF: 30m, Candles: 5
# SMA: 5, TMA: 15, Target: 6R, TF: 60m, Candles: 1
# SMA: 5, TMA: 15, Target: 6R, TF: 60m, Candles: 2
# SMA: 5, TMA: 15, Target: 6R, TF: 60m, Candles: 3
# SMA: 5, TMA: 15, Target: 6R, TF: 60m, Candles: 4
# SMA: 5, TMA: 15, Target: 6R, TF: 60m, Candles: 5
# SMA: 5, TMA: 15, Target: 8R, TF: 3m, Candles: 1
# SMA: 5, TMA: 15, Target: 8R, TF: 3m, Candles: 2
# SMA: 5, TMA: 15, Target: 8R, TF: 3m, Candles: 3
# SMA: 5, TMA: 15, Target: 8R, TF: 3m, Candles: 4
# SMA: 5, TMA: 15, Target: 8R, TF: 3m, Candles: 5
# SMA: 5, TMA: 15, Target: 8R, TF: 5m, Candles: 1
# SMA: 5, TMA: 15, Target: 8R, TF: 5m, Candles: 2
# SMA: 5, TMA: 15, Target: 8R, TF: 5m, Candles: 3
# SMA: 5, TMA: 15, Target: 8R, TF: 5m, Candles: 4
# SMA: 5, TMA: 15, Target: 8R, TF: 5m, Candles: 5
# SMA: 5, TMA: 15, Target: 8R, TF: 10m, Candles: 1
# SMA: 5, TMA: 15, Target: 8R, TF: 10m, Candles: 2
# SMA: 5, TMA: 15, Target: 8R, TF: 10m, Candles: 3
# SMA: 5, TMA: 15, Target: 8R, TF: 10m, Candles: 4
# SMA: 5, TMA: 15, Target: 8R, TF: 10m, Candles: 5
# SMA: 5, TMA: 15, Target: 8R, TF: 15m, Candles: 1
# SMA: 5, TMA: 15, Target: 8R, TF: 15m, Candles: 2
# SMA: 5, TMA: 15, Target: 8R, TF: 15m, Candles: 3
# SMA: 5, TMA: 15, Target: 8R, TF: 15m, Candles: 4
# SMA: 5, TMA: 15, Target: 8R, TF: 15m, Candles: 5
# SMA: 5, TMA: 15, Target: 8R, TF: 30m, Candles: 1
# SMA: 5, TMA: 15, Target: 8R, TF: 30m, Candles: 2
# SMA: 5, TMA: 15, Target: 8R, TF: 30m, Candles: 3
# SMA: 5, TMA: 15, Target: 8R, TF: 30m, Candles: 4
# SMA: 5, TMA: 15, Target: 8R, TF: 30m, Candles: 5
# SMA: 5, TMA: 15, Target: 8R, TF: 60m, Candles: 1
# SMA: 5, TMA: 15, Target: 8R, TF: 60m, Candles: 2
# SMA: 5, TMA: 15, Target: 8R, TF: 60m, Candles: 3
# SMA: 5, TMA: 15, Target: 8R, TF: 60m, Candles: 4
# SMA: 5, TMA: 15, Target: 8R, TF: 60m, Candles: 5
# SMA: 5, TMA: 15, Target: 10R, TF: 3m, Candles: 1
# SMA: 5, TMA: 15, Target: 10R, TF: 3m, Candles: 2
# SMA: 5, TMA: 15, Target: 10R, TF: 3m, Candles: 3
# SMA: 5, TMA: 15, Target: 10R, TF: 3m, Candles: 4
# SMA: 5, TMA: 15, Target: 10R, TF: 3m, Candles: 5
# SMA: 5, TMA: 15, Target: 10R, TF: 5m, Candles: 1
# SMA: 5, TMA: 15, Target: 10R, TF: 5m, Candles: 2
# SMA: 5, TMA: 15, Target: 10R, TF: 5m, Candles: 3
# SMA: 5, TMA: 15, Target: 10R, TF: 5m, Candles: 4
# SMA: 5, TMA: 15, Target: 10R, TF: 5m, Candles: 5
# SMA: 5, TMA: 15, Target: 10R, TF: 10m, Candles: 1
# SMA: 5, TMA: 15, Target: 10R, TF: 10m, Candles: 2
# SMA: 5, TMA: 15, Target: 10R, TF: 10m, Candles: 3
# SMA: 5, TMA: 15, Target: 10R, TF: 10m, Candles: 4
# SMA: 5, TMA: 15, Target: 10R, TF: 10m, Candles: 5
# SMA: 5, TMA: 15, Target: 10R, TF: 15m, Candles: 1
# SMA: 5, TMA: 15, Target: 10R, TF: 15m, Candles: 2
# SMA: 5, TMA: 15, Target: 10R, TF: 15m, Candles: 3
# SMA: 5, TMA: 15, Target: 10R, TF: 15m, Candles: 4
# SMA: 5, TMA: 15, Target: 10R, TF: 15m, Candles: 5
# SMA: 5, TMA: 15, Target: 10R, TF: 30m, Candles: 1
# SMA: 5, TMA: 15, Target: 10R, TF: 30m, Candles: 2
# SMA: 5, TMA: 15, Target: 10R, TF: 30m, Candles: 3
# SMA: 5, TMA: 15, Target: 10R, TF: 30m, Candles: 4
# SMA: 5, TMA: 15, Target: 10R, TF: 30m, Candles: 5
# SMA: 5, TMA: 15, Target: 10R, TF: 60m, Candles: 1
# SMA: 5, TMA: 15, Target: 10R, TF: 60m, Candles: 2
# SMA: 5, TMA: 15, Target: 10R, TF: 60m, Candles: 3
# SMA: 5, TMA: 15, Target: 10R, TF: 60m, Candles: 4
# SMA: 5, TMA: 15, Target: 10R, TF: 60m, Candles: 5
# SMA: 5, TMA: 15, Target: 12R, TF: 3m, Candles: 1
# SMA: 5, TMA: 15, Target: 12R, TF: 3m, Candles: 2
# SMA: 5, TMA: 15, Target: 12R, TF: 3m, Candles: 3
# SMA: 5, TMA: 15, Target: 12R, TF: 3m, Candles: 4
# SMA: 5, TMA: 15, Target: 12R, TF: 3m, Candles: 5
# SMA: 5, TMA: 15, Target: 12R, TF: 5m, Candles: 1
# SMA: 5, TMA: 15, Target: 12R, TF: 5m, Candles: 2
# SMA: 5, TMA: 15, Target: 12R, TF: 5m, Candles: 3
# SMA: 5, TMA: 15, Target: 12R, TF: 5m, Candles: 4
# SMA: 5, TMA: 15, Target: 12R, TF: 5m, Candles: 5
# SMA: 5, TMA: 15, Target: 12R, TF: 10m, Candles: 1
# SMA: 5, TMA: 15, Target: 12R, TF: 10m, Candles: 2
# SMA: 5, TMA: 15, Target: 12R, TF: 10m, Candles: 3
# SMA: 5, TMA: 15, Target: 12R, TF: 10m, Candles: 4
# SMA: 5, TMA: 15, Target: 12R, TF: 10m, Candles: 5
# SMA: 5, TMA: 15, Target: 12R, TF: 15m, Candles: 1
# SMA: 5, TMA: 15, Target: 12R, TF: 15m, Candles: 2
# SMA: 5, TMA: 15, Target: 12R, TF: 15m, Candles: 3
# SMA: 5, TMA: 15, Target: 12R, TF: 15m, Candles: 4
# SMA: 5, TMA: 15, Target: 12R, TF: 15m, Candles: 5
# SMA: 5, TMA: 15, Target: 12R, TF: 30m, Candles: 1
# SMA: 5, TMA: 15, Target: 12R, TF: 30m, Candles: 2
# SMA: 5, TMA: 15, Target: 12R, TF: 30m, Candles: 3
# SMA: 5, TMA: 15, Target: 12R, TF: 30m, Candles: 4
# SMA: 5, TMA: 15, Target: 12R, TF: 30m, Candles: 5
# SMA: 5, TMA: 15, Target: 12R, TF: 60m, Candles: 1
# SMA: 5, TMA: 15, Target: 12R, TF: 60m, Candles: 2
# SMA: 5, TMA: 15, Target: 12R, TF: 60m, Candles: 3
# SMA: 5, TMA: 15, Target: 12R, TF: 60m, Candles: 4
# SMA: 5, TMA: 15, Target: 12R, TF: 60m, Candles: 5
# SMA: 5, TMA: 15, Target: 15R, TF: 3m, Candles: 1
# SMA: 5, TMA: 15, Target: 15R, TF: 3m, Candles: 2
# SMA: 5, TMA: 15, Target: 15R, TF: 3m, Candles: 3
# SMA: 5, TMA: 15, Target: 15R, TF: 3m, Candles: 4
# SMA: 5, TMA: 15, Target: 15R, TF: 3m, Candles: 5
# SMA: 5, TMA: 15, Target: 15R, TF: 5m, Candles: 1
# SMA: 5, TMA: 15, Target: 15R, TF: 5m, Candles: 2
# SMA: 5, TMA: 15, Target: 15R, TF: 5m, Candles: 3
# SMA: 5, TMA: 15, Target: 15R, TF: 5m, Candles: 4
# SMA: 5, TMA: 15, Target: 15R, TF: 5m, Candles: 5
# SMA: 5, TMA: 15, Target: 15R, TF: 10m, Candles: 1
# SMA: 5, TMA: 15, Target: 15R, TF: 10m, Candles: 2
# SMA: 5, TMA: 15, Target: 15R, TF: 10m, Candles: 3
# SMA: 5, TMA: 15, Target: 15R, TF: 10m, Candles: 4
# SMA: 5, TMA: 15, Target: 15R, TF: 10m, Candles: 5
# SMA: 5, TMA: 15, Target: 15R, TF: 15m, Candles: 1
# SMA: 5, TMA: 15, Target: 15R, TF: 15m, Candles: 2
# SMA: 5, TMA: 15, Target: 15R, TF: 15m, Candles: 3
# SMA: 5, TMA: 15, Target: 15R, TF: 15m, Candles: 4
# SMA: 5, TMA: 15, Target: 15R, TF: 15m, Candles: 5
# ...
# SMA: 5, TMA: 20, Target: 4R, TF: 15m, Candles: 3
# SMA: 5, TMA: 20, Target: 4R, TF: 15m, Candles: 4
# SMA: 5, TMA: 20, Target: 4R, TF: 15m, Candles: 5
# SMA: 5, TMA: 20, Target: 4R, TF: 30m, Candles: 1
# SMA: 5, TMA: 20, Target: 4R, TF: 30m, Candles: 2
# SMA: 5, TMA: 20, Target: 4R, TF: 30m, Candles: 3
# SMA: 5, TMA: 20, Target: 4R, TF: 30m, Candles: 4
# SMA: 5, TMA: 20, Target: 4R, TF: 30m, Candles: 5
# SMA: 5, TMA: 20, Target: 4R, TF: 60m, Candles: 1
# SMA: 5, TMA: 20, Target: 4R, TF: 60m, Candles: 2
# SMA: 5, TMA: 20, Target: 4R, TF: 60m, Candles: 3
# SMA: 5, TMA: 20, Target: 4R, TF: 60m, Candles: 4
# SMA: 5, TMA: 20, Target: 4R, TF: 60m, Candles: 5
# SMA: 5, TMA: 20, Target: 6R, TF: 3m, Candles: 1
# SMA: 5, TMA: 20, Target: 6R, TF: 3m, Candles: 2
# SMA: 5, TMA: 20, Target: 6R, TF: 3m, Candles: 3
# SMA: 5, TMA: 20, Target: 6R, TF: 3m, Candles: 4
# SMA: 5, TMA: 20, Target: 6R, TF: 3m, Candles: 5
# SMA: 5, TMA: 20, Target: 6R, TF: 5m, Candles: 1
# SMA: 5, TMA: 20, Target: 6R, TF: 5m, Candles: 2
# SMA: 5, TMA: 20, Target: 6R, TF: 5m, Candles: 3
# SMA: 5, TMA: 20, Target: 6R, TF: 5m, Candles: 4
# SMA: 5, TMA: 20, Target: 6R, TF: 5m, Candles: 5
# SMA: 5, TMA: 20, Target: 6R, TF: 10m, Candles: 1
# SMA: 5, TMA: 20, Target: 6R, TF: 10m, Candles: 2
# SMA: 5, TMA: 20, Target: 6R, TF: 10m, Candles: 3
# SMA: 5, TMA: 20, Target: 6R, TF: 10m, Candles: 4
# SMA: 5, TMA: 20, Target: 6R, TF: 10m, Candles: 5
# SMA: 5, TMA: 20, Target: 6R, TF: 15m, Candles: 1
# SMA: 5, TMA: 20, Target: 6R, TF: 15m, Candles: 2
# SMA: 5, TMA: 20, Target: 6R, TF: 15m, Candles: 3
# SMA: 5, TMA: 20, Target: 6R, TF: 15m, Candles: 4
# SMA: 5, TMA: 20, Target: 6R, TF: 15m, Candles: 5
# SMA: 5, TMA: 20, Target: 6R, TF: 30m, Candles: 1
# SMA: 5, TMA: 20, Target: 6R, TF: 30m, Candles: 2
# SMA: 5, TMA: 20, Target: 6R, TF: 30m, Candles: 3
# SMA: 5, TMA: 20, Target: 6R, TF: 30m, Candles: 4
# SMA: 5, TMA: 20, Target: 6R, TF: 30m, Candles: 5
# SMA: 5, TMA: 20, Target: 6R, TF: 60m, Candles: 1
# SMA: 5, TMA: 20, Target: 6R, TF: 60m, Candles: 2
# SMA: 5, TMA: 20, Target: 6R, TF: 60m, Candles: 3
# SMA: 5, TMA: 20, Target: 6R, TF: 60m, Candles: 4
# SMA: 5, TMA: 20, Target: 6R, TF: 60m, Candles: 5
# SMA: 5, TMA: 20, Target: 8R, TF: 3m, Candles: 1
# SMA: 5, TMA: 20, Target: 8R, TF: 3m, Candles: 2
# SMA: 5, TMA: 20, Target: 8R, TF: 3m, Candles: 3
# SMA: 5, TMA: 20, Target: 8R, TF: 3m, Candles: 4
# SMA: 5, TMA: 20, Target: 8R, TF: 3m, Candles: 5
# SMA: 5, TMA: 20, Target: 8R, TF: 5m, Candles: 1
# SMA: 5, TMA: 20, Target: 8R, TF: 5m, Candles: 2
# SMA: 5, TMA: 20, Target: 8R, TF: 5m, Candles: 3
# SMA: 5, TMA: 20, Target: 8R, TF: 5m, Candles: 4
# SMA: 5, TMA: 20, Target: 8R, TF: 5m, Candles: 5
# SMA: 5, TMA: 20, Target: 8R, TF: 10m, Candles: 1
# SMA: 5, TMA: 20, Target: 8R, TF: 10m, Candles: 2
# SMA: 5, TMA: 20, Target: 8R, TF: 10m, Candles: 3
# SMA: 5, TMA: 20, Target: 8R, TF: 10m, Candles: 4
# SMA: 5, TMA: 20, Target: 8R, TF: 10m, Candles: 5
# SMA: 5, TMA: 20, Target: 8R, TF: 15m, Candles: 1
# SMA: 5, TMA: 20, Target: 8R, TF: 15m, Candles: 2
# SMA: 5, TMA: 20, Target: 8R, TF: 15m, Candles: 3
# SMA: 5, TMA: 20, Target: 8R, TF: 15m, Candles: 4
# SMA: 5, TMA: 20, Target: 8R, TF: 15m, Candles: 5
# SMA: 5, TMA: 20, Target: 8R, TF: 30m, Candles: 1
# SMA: 5, TMA: 20, Target: 8R, TF: 30m, Candles: 2
# SMA: 5, TMA: 20, Target: 8R, TF: 30m, Candles: 3
# SMA: 5, TMA: 20, Target: 8R, TF: 30m, Candles: 4
# SMA: 5, TMA: 20, Target: 8R, TF: 30m, Candles: 5
# SMA: 5, TMA: 20, Target: 8R, TF: 60m, Candles: 1
# SMA: 5, TMA: 20, Target: 8R, TF: 60m, Candles: 2
# SMA: 5, TMA: 20, Target: 8R, TF: 60m, Candles: 3
# SMA: 5, TMA: 20, Target: 8R, TF: 60m, Candles: 4
# SMA: 5, TMA: 20, Target: 8R, TF: 60m, Candles: 5
# SMA: 5, TMA: 20, Target: 10R, TF: 3m, Candles: 1
# SMA: 5, TMA: 20, Target: 10R, TF: 3m, Candles: 2
# SMA: 5, TMA: 20, Target: 10R, TF: 3m, Candles: 3
# SMA: 5, TMA: 20, Target: 10R, TF: 3m, Candles: 4
# SMA: 5, TMA: 20, Target: 10R, TF: 3m, Candles: 5
# SMA: 5, TMA: 20, Target: 10R, TF: 5m, Candles: 1
# SMA: 5, TMA: 20, Target: 10R, TF: 5m, Candles: 2
# SMA: 5, TMA: 20, Target: 10R, TF: 5m, Candles: 3
# SMA: 5, TMA: 20, Target: 10R, TF: 5m, Candles: 4
# SMA: 5, TMA: 20, Target: 10R, TF: 5m, Candles: 5
# SMA: 5, TMA: 20, Target: 10R, TF: 10m, Candles: 1
# SMA: 5, TMA: 20, Target: 10R, TF: 10m, Candles: 2
# SMA: 5, TMA: 20, Target: 10R, TF: 10m, Candles: 3
# SMA: 5, TMA: 20, Target: 10R, TF: 10m, Candles: 4
# SMA: 5, TMA: 20, Target: 10R, TF: 10m, Candles: 5
# SMA: 5, TMA: 20, Target: 10R, TF: 15m, Candles: 1
# SMA: 5, TMA: 20, Target: 10R, TF: 15m, Candles: 2
# SMA: 5, TMA: 20, Target: 10R, TF: 15m, Candles: 3
# SMA: 5, TMA: 20, Target: 10R, TF: 15m, Candles: 4
# SMA: 5, TMA: 20, Target: 10R, TF: 15m, Candles: 5
# SMA: 5, TMA: 20, Target: 10R, TF: 30m, Candles: 1
# SMA: 5, TMA: 20, Target: 10R, TF: 30m, Candles: 2
# SMA: 5, TMA: 20, Target: 10R, TF: 30m, Candles: 3
# SMA: 5, TMA: 20, Target: 10R, TF: 30m, Candles: 4
# SMA: 5, TMA: 20, Target: 10R, TF: 30m, Candles: 5
# SMA: 5, TMA: 20, Target: 10R, TF: 60m, Candles: 1
# SMA: 5, TMA: 20, Target: 10R, TF: 60m, Candles: 2
# SMA: 5, TMA: 20, Target: 10R, TF: 60m, Candles: 3
# SMA: 5, TMA: 20, Target: 10R, TF: 60m, Candles: 4
# SMA: 5, TMA: 20, Target: 10R, TF: 60m, Candles: 5
# SMA: 5, TMA: 20, Target: 12R, TF: 3m, Candles: 1
# SMA: 5, TMA: 20, Target: 12R, TF: 3m, Candles: 2
# SMA: 5, TMA: 20, Target: 12R, TF: 3m, Candles: 3
# SMA: 5, TMA: 20, Target: 12R, TF: 3m, Candles: 4
# SMA: 5, TMA: 20, Target: 12R, TF: 3m, Candles: 5
# SMA: 5, TMA: 20, Target: 12R, TF: 5m, Candles: 1
# SMA: 5, TMA: 20, Target: 12R, TF: 5m, Candles: 2
# SMA: 5, TMA: 20, Target: 12R, TF: 5m, Candles: 3
# SMA: 5, TMA: 20, Target: 12R, TF: 5m, Candles: 4
# SMA: 5, TMA: 20, Target: 12R, TF: 5m, Candles: 5
# SMA: 5, TMA: 20, Target: 12R, TF: 10m, Candles: 1
# SMA: 5, TMA: 20, Target: 12R, TF: 10m, Candles: 2
# SMA: 5, TMA: 20, Target: 12R, TF: 10m, Candles: 3
# SMA: 5, TMA: 20, Target: 12R, TF: 10m, Candles: 4
# SMA: 5, TMA: 20, Target: 12R, TF: 10m, Candles: 5
# SMA: 5, TMA: 20, Target: 12R, TF: 15m, Candles: 1
# SMA: 5, TMA: 20, Target: 12R, TF: 15m, Candles: 2
# SMA: 5, TMA: 20, Target: 12R, TF: 15m, Candles: 3
# SMA: 5, TMA: 20, Target: 12R, TF: 15m, Candles: 4
# SMA: 5, TMA: 20, Target: 12R, TF: 15m, Candles: 5
# SMA: 5, TMA: 20, Target: 12R, TF: 30m, Candles: 1
# SMA: 5, TMA: 20, Target: 12R, TF: 30m, Candles: 2
# SMA: 5, TMA: 20, Target: 12R, TF: 30m, Candles: 3
# SMA: 5, TMA: 20, Target: 12R, TF: 30m, Candles: 4
# SMA: 5, TMA: 20, Target: 12R, TF: 30m, Candles: 5
# SMA: 5, TMA: 20, Target: 12R, TF: 60m, Candles: 1
# SMA: 5, TMA: 20, Target: 12R, TF: 60m, Candles: 2
# SMA: 5, TMA: 20, Target: 12R, TF: 60m, Candles: 3
# SMA: 5, TMA: 20, Target: 12R, TF: 60m, Candles: 4
# SMA: 5, TMA: 20, Target: 12R, TF: 60m, Candles: 5
# SMA: 5, TMA: 20, Target: 15R, TF: 3m, Candles: 1
# SMA: 5, TMA: 20, Target: 15R, TF: 3m, Candles: 2
# SMA: 5, TMA: 20, Target: 15R, TF: 3m, Candles: 3
# SMA: 5, TMA: 20, Target: 15R, TF: 3m, Candles: 4
# SMA: 5, TMA: 20, Target: 15R, TF: 3m, Candles: 5
# SMA: 5, TMA: 20, Target: 15R, TF: 5m, Candles: 1
# SMA: 5, TMA: 20, Target: 15R, TF: 5m, Candles: 2
# SMA: 5, TMA: 20, Target: 15R, TF: 5m, Candles: 3
# SMA: 5, TMA: 20, Target: 15R, TF: 5m, Candles: 4
# SMA: 5, TMA: 20, Target: 15R, TF: 5m, Candles: 5
# SMA: 5, TMA: 20, Target: 15R, TF: 10m, Candles: 1
# SMA: 5, TMA: 20, Target: 15R, TF: 10m, Candles: 2
# SMA: 5, TMA: 20, Target: 15R, TF: 10m, Candles: 3
# SMA: 5, TMA: 20, Target: 15R, TF: 10m, Candles: 4
# SMA: 5, TMA: 20, Target: 15R, TF: 10m, Candles: 5
# SMA: 5, TMA: 20, Target: 15R, TF: 15m, Candles: 1
# SMA: 5, TMA: 20, Target: 15R, TF: 15m, Candles: 2
# SMA: 5, TMA: 20, Target: 15R, TF: 15m, Candles: 3
# SMA: 5, TMA: 20, Target: 15R, TF: 15m, Candles: 4
# SMA: 5, TMA: 20, Target: 15R, TF: 15m, Candles: 5
# SMA: 5, TMA: 20, Target: 15R, TF: 30m, Candles: 1
# SMA: 5, TMA: 20, Target: 15R, TF: 30m, Candles: 2
# SMA: 5, TMA: 20, Target: 15R, TF: 30m, Candles: 3
# SMA: 5, TMA: 20, Target: 15R, TF: 30m, Candles: 4
# SMA: 5, TMA: 20, Target: 15R, TF: 30m, Candles: 5
# SMA: 5, TMA: 20, Target: 15R, TF: 60m, Candles: 1
# SMA: 5, TMA: 20, Target: 15R, TF: 60m, Candles: 2
# SMA: 5, TMA: 20, Target: 15R, TF: 60m, Candles: 3
# SMA: 5, TMA: 20, Target: 15R, TF: 60m, Candles: 4
# SMA: 5, TMA: 20, Target: 15R, TF: 60m, Candles: 5
# SMA: 5, TMA: 20, Target: 18R, TF: 3m, Candles: 1
# SMA: 5, TMA: 20, Target: 18R, TF: 3m, Candles: 2
# SMA: 5, TMA: 20, Target: 18R, TF: 3m, Candles: 3
# SMA: 5, TMA: 20, Target: 18R, TF: 3m, Candles: 4
# SMA: 5, TMA: 20, Target: 18R, TF: 3m, Candles: 5
# SMA: 5, TMA: 20, Target: 18R, TF: 5m, Candles: 1
# SMA: 5, TMA: 20, Target: 18R, TF: 5m, Candles: 2
# SMA: 5, TMA: 20, Target: 18R, TF: 5m, Candles: 3
# SMA: 5, TMA: 20, Target: 18R, TF: 5m, Candles: 4
# SMA: 5, TMA: 20, Target: 18R, TF: 5m, Candles: 5
# SMA: 5, TMA: 20, Target: 18R, TF: 10m, Candles: 1
# SMA: 5, TMA: 20, Target: 18R, TF: 10m, Candles: 2
# SMA: 5, TMA: 20, Target: 18R, TF: 10m, Candles: 3
# SMA: 5, TMA: 20, Target: 18R, TF: 10m, Candles: 4
# SMA: 5, TMA: 20, Target: 18R, TF: 10m, Candles: 5
# SMA: 5, TMA: 20, Target: 18R, TF: 15m, Candles: 1
# SMA: 5, TMA: 20, Target: 18R, TF: 15m, Candles: 2
# SMA: 5, TMA: 20, Target: 18R, TF: 15m, Candles: 3
# SMA: 5, TMA: 20, Target: 18R, TF: 15m, Candles: 4
# SMA: 5, TMA: 20, Target: 18R, TF: 15m, Candles: 5
# SMA: 5, TMA: 20, Target: 18R, TF: 30m, Candles: 1
# SMA: 5, TMA: 20, Target: 18R, TF: 30m, Candles: 2
# SMA: 5, TMA: 20, Target: 18R, TF: 30m, Candles: 3
# SMA: 5, TMA: 20, Target: 18R, TF: 30m, Candles: 4
# SMA: 5, TMA: 20, Target: 18R, TF: 30m, Candles: 5
# SMA: 5, TMA: 20, Target: 18R, TF: 60m, Candles: 1
# SMA: 5, TMA: 20, Target: 18R, TF: 60m, Candles: 2
# SMA: 5, TMA: 20, Target: 18R, TF: 60m, Candles: 3
# SMA: 5, TMA: 20, Target: 18R, TF: 60m, Candles: 4
# SMA: 5, TMA: 20, Target: 18R, TF: 60m, Candles: 5
# SMA: 5, TMA: 20, Target: 20R, TF: 3m, Candles: 1
# SMA: 5, TMA: 20, Target: 20R, TF: 3m, Candles: 2
# SMA: 5, TMA: 20, Target: 20R, TF: 3m, Candles: 3
# SMA: 5, TMA: 20, Target: 20R, TF: 3m, Candles: 4
# SMA: 5, TMA: 20, Target: 20R, TF: 3m, Candles: 5
# SMA: 5, TMA: 20, Target: 20R, TF: 5m, Candles: 1
# SMA: 5, TMA: 20, Target: 20R, TF: 5m, Candles: 2
# SMA: 5, TMA: 20, Target: 20R, TF: 5m, Candles: 3
# SMA: 5, TMA: 20, Target: 20R, TF: 5m, Candles: 4
# SMA: 5, TMA: 20, Target: 20R, TF: 5m, Candles: 5
# SMA: 5, TMA: 20, Target: 20R, TF: 10m, Candles: 1
# SMA: 5, TMA: 20, Target: 20R, TF: 10m, Candles: 2
# SMA: 5, TMA: 20, Target: 20R, TF: 10m, Candles: 3
# SMA: 5, TMA: 20, Target: 20R, TF: 10m, Candles: 4
# SMA: 5, TMA: 20, Target: 20R, TF: 10m, Candles: 5
# SMA: 5, TMA: 20, Target: 20R, TF: 15m, Candles: 1
# SMA: 5, TMA: 20, Target: 20R, TF: 15m, Candles: 2
# SMA: 5, TMA: 20, Target: 20R, TF: 15m, Candles: 3
# SMA: 5, TMA: 20, Target: 20R, TF: 15m, Candles: 4
# SMA: 5, TMA: 20, Target: 20R, TF: 15m, Candles: 5
# SMA: 5, TMA: 20, Target: 20R, TF: 30m, Candles: 1
# SMA: 5, TMA: 20, Target: 20R, TF: 30m, Candles: 2
# SMA: 5, TMA: 20, Target: 20R, TF: 30m, Candles: 3
# SMA: 5, TMA: 20, Target: 20R, TF: 30m, Candles: 4
# SMA: 5, TMA: 20, Target: 20R, TF: 30m, Candles: 5
# SMA: 5, TMA: 20, Target: 20R, TF: 60m, Candles: 1
# SMA: 5, TMA: 20, Target: 20R, TF: 60m, Candles: 2
# SMA: 5, TMA: 20, Target: 20R, TF: 60m, Candles: 3
# SMA: 5, TMA: 20, Target: 20R, TF: 60m, Candles: 4
# SMA: 5, TMA: 20, Target: 20R, TF: 60m, Candles: 5
# SMA: 5, TMA: 20, Target: 25R, TF: 3m, Candles: 1
# SMA: 5, TMA: 20, Target: 25R, TF: 3m, Candles: 2
# SMA: 5, TMA: 20, Target: 25R, TF: 3m, Candles: 3
# SMA: 5, TMA: 20, Target: 25R, TF: 3m, Candles: 4
# SMA: 5, TMA: 20, Target: 25R, TF: 3m, Candles: 5
# SMA: 5, TMA: 20, Target: 25R, TF: 5m, Candles: 1
# SMA: 5, TMA: 20, Target: 25R, TF: 5m, Candles: 2
# SMA: 5, TMA: 20, Target: 25R, TF: 5m, Candles: 3
# SMA: 5, TMA: 20, Target: 25R, TF: 5m, Candles: 4
# SMA: 5, TMA: 20, Target: 25R, TF: 5m, Candles: 5
# SMA: 5, TMA: 20, Target: 25R, TF: 10m, Candles: 1
# SMA: 5, TMA: 20, Target: 25R, TF: 10m, Candles: 2
# SMA: 5, TMA: 20, Target: 25R, TF: 10m, Candles: 3
# SMA: 5, TMA: 20, Target: 25R, TF: 10m, Candles: 4
# SMA: 5, TMA: 20, Target: 25R, TF: 10m, Candles: 5
# SMA: 5, TMA: 20, Target: 25R, TF: 15m, Candles: 1
# SMA: 5, TMA: 20, Target: 25R, TF: 15m, Candles: 2
# SMA: 5, TMA: 20, Target: 25R, TF: 15m, Candles: 3
# SMA: 5, TMA: 20, Target: 25R, TF: 15m, Candles: 4
# SMA: 5, TMA: 20, Target: 25R, TF: 15m, Candles: 5
# SMA: 5, TMA: 20, Target: 25R, TF: 30m, Candles: 1
# SMA: 5, TMA: 20, Target: 25R, TF: 30m, Candles: 2
# SMA: 5, TMA: 20, Target: 25R, TF: 30m, Candles: 3
# SMA: 5, TMA: 20, Target: 25R, TF: 30m, Candles: 4
# SMA: 5, TMA: 20, Target: 25R, TF: 30m, Candles: 5
# SMA: 5, TMA: 20, Target: 25R, TF: 60m, Candles: 1
# SMA: 5, TMA: 20, Target: 25R, TF: 60m, Candles: 2
# SMA: 5, TMA: 20, Target: 25R, TF: 60m, Candles: 3
# SMA: 5, TMA: 20, Target: 25R, TF: 60m, Candles: 4
# SMA: 5, TMA: 20, Target: 25R, TF: 60m, Candles: 5
# SMA: 5, TMA: 20, Target: 30R, TF: 3m, Candles: 1
# SMA: 5, TMA: 20, Target: 30R, TF: 3m, Candles: 2
# SMA: 5, TMA: 20, Target: 30R, TF: 3m, Candles: 3
# SMA: 5, TMA: 20, Target: 30R, TF: 3m, Candles: 4
# SMA: 5, TMA: 20, Target: 30R, TF: 3m, Candles: 5
# SMA: 5, TMA: 20, Target: 30R, TF: 5m, Candles: 1
# SMA: 5, TMA: 20, Target: 30R, TF: 5m, Candles: 2
# SMA: 5, TMA: 20, Target: 30R, TF: 5m, Candles: 3
# SMA: 5, TMA: 20, Target: 30R, TF: 5m, Candles: 4
# SMA: 5, TMA: 20, Target: 30R, TF: 5m, Candles: 5
# SMA: 5, TMA: 20, Target: 30R, TF: 10m, Candles: 1
# SMA: 5, TMA: 20, Target: 30R, TF: 10m, Candles: 2
# SMA: 5, TMA: 20, Target: 30R, TF: 10m, Candles: 3
# SMA: 5, TMA: 20, Target: 30R, TF: 10m, Candles: 4
# SMA: 5, TMA: 20, Target: 30R, TF: 10m, Candles: 5
# SMA: 5, TMA: 20, Target: 30R, TF: 15m, Candles: 1
# SMA: 5, TMA: 20, Target: 30R, TF: 15m, Candles: 2
# SMA: 5, TMA: 20, Target: 30R, TF: 15m, Candles: 3
# SMA: 5, TMA: 20, Target: 30R, TF: 15m, Candles: 4
# SMA: 5, TMA: 20, Target: 30R, TF: 15m, Candles: 5
# SMA: 5, TMA: 20, Target: 30R, TF: 30m, Candles: 1
# SMA: 5, TMA: 20, Target: 30R, TF: 30m, Candles: 2
# SMA: 5, TMA: 20, Target: 30R, TF: 30m, Candles: 3
# SMA: 5, TMA: 20, Target: 30R, TF: 30m, Candles: 4
# SMA: 5, TMA: 20, Target: 30R, TF: 30m, Candles: 5
# SMA: 5, TMA: 20, Target: 30R, TF: 60m, Candles: 1
# SMA: 5, TMA: 20, Target: 30R, TF: 60m, Candles: 2
# SMA: 5, TMA: 20, Target: 30R, TF: 60m, Candles: 3
# SMA: 5, TMA: 20, Target: 30R, TF: 60m, Candles: 4
# SMA: 5, TMA: 20, Target: 30R, TF: 60m, Candles: 5
# SMA: 5, TMA: 20, Target: 50R, TF: 3m, Candles: 1
# SMA: 5, TMA: 20, Target: 50R, TF: 3m, Candles: 2
# SMA: 5, TMA: 20, Target: 50R, TF: 3m, Candles: 3
# SMA: 5, TMA: 20, Target: 50R, TF: 3m, Candles: 4
# SMA: 5, TMA: 20, Target: 50R, TF: 3m, Candles: 5
# SMA: 5, TMA: 20, Target: 50R, TF: 5m, Candles: 1
# SMA: 5, TMA: 20, Target: 50R, TF: 5m, Candles: 2
# SMA: 5, TMA: 20, Target: 50R, TF: 5m, Candles: 3
# SMA: 5, TMA: 20, Target: 50R, TF: 5m, Candles: 4
# SMA: 5, TMA: 20, Target: 50R, TF: 5m, Candles: 5
# SMA: 5, TMA: 20, Target: 50R, TF: 10m, Candles: 1
# SMA: 5, TMA: 20, Target: 50R, TF: 10m, Candles: 2
# SMA: 5, TMA: 20, Target: 50R, TF: 10m, Candles: 3
# SMA: 5, TMA: 20, Target: 50R, TF: 10m, Candles: 4
# SMA: 5, TMA: 20, Target: 50R, TF: 10m, Candles: 5
# SMA: 5, TMA: 20, Target: 50R, TF: 15m, Candles: 1
# SMA: 5, TMA: 20, Target: 50R, TF: 15m, Candles: 2
# SMA: 5, TMA: 20, Target: 50R, TF: 15m, Candles: 3
# SMA: 5, TMA: 20, Target: 50R, TF: 15m, Candles: 4
# SMA: 5, TMA: 20, Target: 50R, TF: 15m, Candles: 5
# SMA: 5, TMA: 20, Target: 50R, TF: 30m, Candles: 1
# SMA: 5, TMA: 20, Target: 50R, TF: 30m, Candles: 2
# SMA: 5, TMA: 20, Target: 50R, TF: 30m, Candles: 3
# SMA: 5, TMA: 20, Target: 50R, TF: 30m, Candles: 4
# SMA: 5, TMA: 20, Target: 50R, TF: 30m, Candles: 5
# SMA: 5, TMA: 20, Target: 50R, TF: 60m, Candles: 1
# SMA: 5, TMA: 20, Target: 50R, TF: 60m, Candles: 2
# SMA: 5, TMA: 20, Target: 50R, TF: 60m, Candles: 3
# SMA: 5, TMA: 20, Target: 50R, TF: 60m, Candles: 4
# SMA: 5, TMA: 20, Target: 50R, TF: 60m, Candles: 5
# SMA: 5, TMA: 20, Target: 100R, TF: 3m, Candles: 1
# SMA: 5, TMA: 20, Target: 100R, TF: 3m, Candles: 2
# SMA: 5, TMA: 20, Target: 100R, TF: 3m, Candles: 3
# SMA: 5, TMA: 20, Target: 100R, TF: 3m, Candles: 4
# SMA: 5, TMA: 20, Target: 100R, TF: 3m, Candles: 5
# SMA: 5, TMA: 20, Target: 100R, TF: 5m, Candles: 1
# SMA: 5, TMA: 20, Target: 100R, TF: 5m, Candles: 2
# SMA: 5, TMA: 20, Target: 100R, TF: 5m, Candles: 3
# SMA: 5, TMA: 20, Target: 100R, TF: 5m, Candles: 4
# SMA: 5, TMA: 20, Target: 100R, TF: 5m, Candles: 5

# %%
# tradebook_sell_side
