# %%
import pandas as pd
import polars as pl
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import mplfinance as mpf
from plotly.subplots import make_subplots
from dash import Dash, dcc, html
import pandas_market_calendars as mcal
nse = mcal.get_calendar('NSE')

pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)
# Out:
# polars.config.Config

# %%
import sys
sys.path.append('..')
from tooling.filter import find_atm, option_tool
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm
from tooling.enums import Index, AssetClass, StrikeSpread, Spot

# %%
def get_expiry(f_today):
    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry

def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = '0'
    mth=expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime('%y%b').upper()
        return f'{symbol}{date_string}{strike}{opt_type}'
    else:
        if expiry.day<=9:
            date_string = f'{expiry.year - 2000}{mth}{temp}{expiry.day}'
        else :
            date_string = f'{expiry.year - 2000}{mth}{expiry.day}'
        return f'{symbol}{date_string}{strike}{opt_type}'

# %%
bnf = await fetch_spot_data(
    instrument='bnf',
    start_date=dt.date(2023, 1, 1),
    start_time=dt.time(9, 15),
    end_date=dt.date(2023, 1, 5),
    end_time=dt.time(15, 30),
)
bnf = bnf.to_pandas()

# %%
opt = await fetch_option_data(
    index='bnf',
    expiry=dt.date(2023, 7, 27),
    strike=45900,
    asset_class=AssetClass.CALL,
    start_date=dt.date(2023, 7, 27),
    start_time=dt.time(9, 15),
    end_date=dt.date(2023, 7, 27),
    end_time=dt.time(15, 30)
)
opt
# Out:
# shape: (376, 11)
# ┌───────┬─────────┬────────┬────────┬────────┬────────┬────────┬────────┬────────┬────────┬────────┐
# │ index ┆ expiry  ┆ strike ┆ asset_ ┆ dateti ┆ o      ┆ h      ┆ l      ┆ c      ┆ v      ┆ oi     │
# │ ---   ┆ ---     ┆ ---    ┆ class  ┆ me     ┆ ---    ┆ ---    ┆ ---    ┆ ---    ┆ ---    ┆ ---    │
# │ str   ┆ date    ┆ i64    ┆ ---    ┆ ---    ┆ f64    ┆ f64    ┆ f64    ┆ f64    ┆ i64    ┆ i64    │
# │       ┆         ┆        ┆ str    ┆ dateti ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ me[μs] ┆        ┆        ┆        ┆        ┆        ┆        │
# ╞═══════╪═════════╪════════╪════════╪════════╪════════╪════════╪════════╪════════╪════════╪════════╡
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 275.5  ┆ 358.35 ┆ 275.5  ┆ 335.45 ┆ 389538 ┆ 125725 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 09:15: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 338.35 ┆ 349.65 ┆ 323.5  ┆ 331.5  ┆ 284715 ┆ 125725 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 09:16: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 336.0  ┆ 339.5  ┆ 320.9  ┆ 333.45 ┆ 171780 ┆ 121767 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 09:17: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 333.35 ┆ 350.0  ┆ 333.35 ┆ 346.8  ┆ 207675 ┆ 121767 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 09:18: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 346.5  ┆ 370.7  ┆ 344.5  ┆ 359.7  ┆ 311130 ┆ 121767 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 09:19: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 362.75 ┆ 371.15 ┆ 358.8  ┆ 361.0  ┆ 224445 ┆ 115137 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 09:20: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 360.7  ┆ 368.45 ┆ 353.5  ┆ 364.45 ┆ 211275 ┆ 115137 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 09:21: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 364.9  ┆ 377.0  ┆ 364.1  ┆ 372.0  ┆ 225570 ┆ 115137 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 09:22: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 371.1  ┆ 372.5  ┆ 364.25 ┆ 364.25 ┆ 140805 ┆ 114597 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 09:23: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 363.3  ┆ 363.3  ┆ 353.55 ┆ 359.05 ┆ 160965 ┆ 114597 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 09:24: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 356.55 ┆ 360.7  ┆ 351.95 ┆ 355.9  ┆ 119250 ┆ 114597 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 09:25: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 356.0  ┆ 356.3  ┆ 342.15 ┆ 344.65 ┆ 163920 ┆ 113233 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 09:26: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 342.8  ┆ 355.85 ┆ 341.7  ┆ 353.45 ┆ 126000 ┆ 113233 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 09:27: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 352.05 ┆ 352.05 ┆ 344.0  ┆ 350.1  ┆ 102645 ┆ 113233 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 09:28: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆
┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.35   ┆ 0.35   ┆ 0.3    ┆ 0.3    ┆ 382875 ┆ 382891 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 15:10: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.3    ┆ 0.3    ┆ 0.25   ┆ 0.25   ┆ 232665 ┆ 382891 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 15:11: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.25   ┆ 0.35   ┆ 0.25   ┆ 0.3    ┆ 594615 ┆ 360906 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 15:12: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.3    ┆ 0.65   ┆ 0.3    ┆ 0.5    ┆ 714405 ┆ 360906 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 15:13: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.5    ┆ 0.7    ┆ 0.45   ┆ 0.65   ┆ 491280 ┆ 360906 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 15:14: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.7    ┆ 0.85   ┆ 0.55   ┆ 0.6    ┆ 643830 ┆ 353773 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 15:15: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.55   ┆ 0.75   ┆ 0.45   ┆ 0.5    ┆ 517650 ┆ 353773 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 15:16: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.5    ┆ 0.5    ┆ 0.35   ┆ 0.45   ┆ 597375 ┆ 353773 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 15:17: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.4    ┆ 0.55   ┆ 0.4    ┆ 0.4    ┆ 545355 ┆ 352629 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 15:18: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.4    ┆ 0.55   ┆ 0.35   ┆ 0.5    ┆ 841110 ┆ 352629 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 15:19: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.5    ┆ 0.5    ┆ 0.25   ┆ 0.25   ┆ 674325 ┆ 352629 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 15:20: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.3    ┆ 0.3    ┆ 0.15   ┆ 0.15   ┆ 608430 ┆ 338839 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 15:21: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.15   ┆ 0.2    ┆ 0.05   ┆ 0.05   ┆ 532320 ┆ 338839 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 15:22: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.05   ┆ 0.1    ┆ 0.05   ┆ 0.05   ┆ 296475 ┆ 338839 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 15:23: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.05   ┆ 0.1    ┆ 0.05   ┆ 0.05   ┆ 225375 ┆ 315112 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 15:24: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.05   ┆ 0.1    ┆ 0.05   ┆ 0.05   ┆ 343095 ┆ 315112 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 15:25: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.05   ┆ 0.1    ┆ 0.05   ┆ 0.05   ┆ 179040 ┆ 315112 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 5      │
# │       ┆         ┆        ┆        ┆ 15:26: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.05   ┆ 0.1    ┆ 0.05   ┆ 0.05   ┆ 149820 ┆ 308580 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 15:27: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.1    ┆ 0.1    ┆ 0.05   ┆ 0.05   ┆ 235620 ┆ 308580 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 15:28: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.05   ┆ 0.05   ┆ 0.05   ┆ 0.05   ┆ 77715  ┆ 308580 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 15:29: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# │ bnf   ┆ 2023-07 ┆ 45900  ┆ C      ┆ 2023-0 ┆ 0.05   ┆ 0.05   ┆ 0.05   ┆ 0.05   ┆ 915    ┆ 308580 │
# │       ┆ -27     ┆        ┆        ┆ 7-27   ┆        ┆        ┆        ┆        ┆        ┆ 0      │
# │       ┆         ┆        ┆        ┆ 15:30: ┆        ┆        ┆        ┆        ┆        ┆        │
# │       ┆         ┆        ┆        ┆ 00     ┆        ┆        ┆        ┆        ┆        ┆        │
# └───────┴─────────┴────────┴────────┴────────┴────────┴────────┴────────┴────────┴────────┴────────┘

# %%
df = bnf

async def generate_trades():
    is_ce_trade_active = False
    is_pe_trade_active = False
    max_price = 0
    portfolio_value = 10_00_000
    trade_book = []
    ce_df = pd.DataFrame()
    pe_df = pd.DataFrame()
    atm_flag = False
    ce_base_price_flag = False
    pe_base_price_flag = False
    
    for i in range(1, len(df)):
        ce_points = 0
        pe_points = 0
        points = 0
        print(df.iloc[i]['datetime'])
        if df.iloc[i]['datetime'].time() >= dt.time(9, 30) and df.iloc[i]['datetime'].time() <= dt.time(15, 0) and (not is_ce_trade_active):
            signal_time = df.iloc[i]['datetime'].time()
            if not atm_flag:
                atm = int(df.iloc[i]['o'] / 100) * 100
                atm_flag = True
            current_date = df.iloc[i]['datetime'].date()
            expiry_date = get_expiry(current_date)
            
            ce_df = await fetch_option_data(
                index='bnf',
                expiry=expiry_date,
                strike=atm,
                asset_class=AssetClass.CALL,
                start_date=current_date,
                start_time=dt.time(9, 15),
                end_date=current_date,
                end_time=dt.time(15, 30)
            )
    
            pe_df = await fetch_option_data(
                index='bnf',
                expiry=expiry_date,
                strike=atm,
                asset_class=AssetClass.PUT,
                start_date=current_date,
                start_time=dt.time(9, 15),
                end_date=current_date,
                end_time=dt.time(15, 30)
            )

            ce_df = ce_df.to_pandas()
            pe_df = pe_df.to_pandas()

            # print(ce_df, pe_df)

            if not ce_base_price_flag:
                ce_base_price = ce_df.loc[ce_df['datetime'].dt.time == signal_time, 'c'].values[0]
                ce_base_price_flag = True
            if not pe_base_price_flag:
                pe_base_price = pe_df.loc[pe_df['datetime'].dt.time == signal_time, 'c'].values[0]
                pe_base_price_flag = True

            print(ce_base_price, pe_base_price)
        
        if not is_ce_trade_active:
            for j in range(1, len(ce_df)):
                if ce_df.iloc[j]['datetime'].time() > signal_time:
                    if ce_df.iloc[j]['o'] >= ce_base_price * 1.12 and not is_ce_trade_active:
                        # Entry Triggered
                        print(ce_df.iloc[j]['datetime'], 'Entry Triggered CE')
                        is_ce_trade_active = True
                        ce_entry_price = ce_df.iloc[j]['o']
                        ce_sl_price = ce_df.iloc[j]['o'] * 0.92
                        ce_initial_sl = ce_sl_price
                        ce_atm = atm
                        ce_entry_time = ce_df.iloc[j]['datetime']
                        
                    if is_ce_trade_active:
                        max_price = max(max_price, df.iloc[j]['o'])
                        if ce_df.iloc[j]['o'] > ce_df.iloc[j-1]['o'] and ce_df.iloc[j]['o'] > max_price:
                            # Trailing
                            ce_sl_price += (ce_df.iloc[j]['o'] - ce_df.iloc[j-1]['o'])
                        k
                        if ce_df.iloc[j]['o'] < ce_sl_price:
                            # Stoploss Hit
                            print(ce_df.iloc[j]['datetime'], 'SL Hit')
                            is_ce_trade_active = False
                            ce_exit_price = ce_sl_price
                            ce_points = ce_exit_price - ce_entry_price
                            ce_exit_time = ce_df.iloc[j]['datetime']
                            break

                        elif df.iloc[j]['datetime'].time() >= dt.time(15, 20):
                            # EOD SquareOff
                            print(ce_df.iloc[j]['datetime'], 'EOD')
                            is_ce_trade_active = False
                            ce_exit_price = df.iloc[j]['o']
                            ce_points = ce_exit_price - ce_entry_price
                            ce_exit_time = ce_df.iloc[j]['datetime']
                            break

        if ce_points != 0:
            qty = 10000 / ce_entry_price # For 1% RPT
            points = ce_points * 0.95 if ce_points > 0 else ce_points * 1.05
            trade = {
                'Signal Generated At': signal_time,
                'Strike': ce_atm,
                'Entry Time': ce_entry_time,
                'Entry Price': ce_entry_price,
                'Initial SL': ce_initial_sl,
                'SL': ce_sl_price,
                'Exit Time': ce_exit_time,
                'Exit Price': ce_exit_price,
                'Points Captured': ce_points,
                'After Costs': points,
                'Qty': qty,
                'ROI%': ((points) * qty / portfolio_value) * 100,
                'Trade Year': ce_entry_time.year
            }
            print(trade)
            trade_book.append(trade)
            atm_flag = False
            
        # if not is_pe_trade_active:
        #     for k in range(1, len(pe_df)):
        #         if pe_df.iloc[k]['datetime'].time() > signal_time:
        #             if pe_df.iloc[k]['o'] >= pe_base_price * 1.12 and not is_pe_trade_active:
        #                 # Entry Triggered
        #                 print(ce_df.iloc[k]['datetime'], 'Entry Triggered PE')
        #                 is_pe_trade_active = True
        #                 pe_entry_price = pe_df.iloc[k]['o']
        #                 pe_sl_price = pe_df.iloc[k]['o'] * 0.92
        #                 pe_initial_sl = pe_sl_price
        #                 pe_atm = atm
        #                 pe_entry_time = pe_df.iloc[k]['datetime']

        #             if is_pe_trade_active:
        #                 if pe_df.iloc[k]['o'] > pe_df.iloc[k-1]['o']:
        #                     # Trailing Up
        #                     pe_sl_price += (pe_df.iloc[k]['o'] - pe_df.iloc[k-1]['o'])
                            
        #                 if pe_df.iloc[k]['o'] < pe_sl_price:
        #                     # Stoploss Hit
        #                     print(pe_df.iloc[k]['datetime'], 'SL Hit')
        #                     is_pe_trade_active = False
        #                     pe_exit_price = pe_sl_price
        #                     pe_points = pe_exit_price - pe_entry_price
        #                     pe_exit_time = pe_df.iloc[k]['datetime']
        #                     break

        #                 elif df.iloc[k]['datetime'].time() >= dt.time(15, 20):
        #                     # EOD SquareOff
        #                     print(pe_df.iloc[k]['datetime'], 'EOD')
        #                     is_pe_trade_active = False
        #                     pe_exit_price = df.iloc[k]['o']
        #                     pe_points = pe_exit_price - pe_entry_price
        #                     pe_exit_time = pe_df.iloc[k]['datetime']
        #                     break

        # if pe_points != 0:
        #     qty = 10000 / pe_entry_price # For 1% RPT
        #     points = pe_points * 0.95 if pe_points > 0 else pe_points * 1.05
        #     trade = {
        #         'Signal Generated At': signal_time,
        #         'Strike': pe_atm,
        #         'Entry Time': pe_entry_time,
        #         'Entry Price': pe_entry_price,
        #         'Initial SL': pe_initial_sl,
        #         'SL': pe_sl_price,
        #         'Exit Time': pe_exit_time,
        #         'Exit Price': pe_exit_price,
        #         'Points Captured': pe_points,
        #         'After Costs': points,
        #         'Qty': qty,
        #         'ROI%': ((points) * qty / portfolio_value) * 100,
        #         'Trade Year': pe_entry_time.year
        #     }
        #     print(trade)
        #     trade_book.append(trade)
        #     atm_flag = False

    return pd.DataFrame(trade_book)

tb = await generate_trades()
tb
# Out:
# 2023-01-03 09:15:00
# 2023-01-03 09:16:00
# 2023-01-03 09:17:00
# 2023-01-03 09:18:00
# 2023-01-03 09:19:00
# 2023-01-03 09:20:00
# 2023-01-03 09:21:00
# 2023-01-03 09:22:00
# 2023-01-03 09:23:00
# 2023-01-03 09:24:00
# 2023-01-03 09:25:00
# 2023-01-03 09:26:00
# 2023-01-03 09:27:00
# 2023-01-03 09:28:00
# 2023-01-03 09:29:00
# 2023-01-03 09:30:00
# 327.25 203.15
# 2023-01-03 10:10:00 Entry Triggered CE
# 2023-01-03 11:39:00 SL Hit
# {'Signal Generated At': datetime.time(9, 30), 'Strike': 43200, 'Entry Time': Timestamp('2023-01-03 10:10:00'), 'Entry Price': 374.55, 'Initial SL': 344.586, 'SL': 344.586, 'Exit Time': Timestamp('2023-01-03 11:39:00'), 'Exit Price': 344.586, 'Points Captured': -29.964, 'After Costs': -31.4622, 'Qty': 26.698705112802028, 'ROI%': -0.08399999999999999, 'Trade Year': 2023}
# 2023-01-03 12:34:00 Entry Triggered PE
# 2023-01-03 12:35:00 SL Hit
# {'Signal Generated At': datetime.time(9, 30), 'Strike': 43200, 'Entry Time': Timestamp('2023-01-03 12:34:00'), 'Entry Price': 245.4, 'Initial SL': 225.76800000000003, 'SL': 245.06800000000004, 'Exit Time': Timestamp('2023-01-03 12:35:00'), 'Exit Price': 245.06800000000004, 'Points Captured': -0.3319999999999652, 'After Costs': -0.3485999999999635, 'Qty': 40.74979625101874, 'ROI%': -0.0014205378973103646, 'Trade Year': 2023}
# 2023-01-03 09:31:00
# 327.25 203.15
# 2023-01-03 09:32:00 Entry Triggered PE
# 2023-01-03 09:40:00 SL Hit
# {'Signal Generated At': datetime.time(9, 31), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 09:32:00'), 'Entry Price': 228.85, 'Initial SL': 210.542, 'SL': 228.14200000000002, 'Exit Time': Timestamp('2023-01-03 09:40:00'), 'Exit Price': 228.14200000000002, 'Points Captured': -0.70799999999997, 'After Costs': -0.7433999999999685, 'Qty': 43.69674459252786, 'ROI%': -0.0032484159930083836, 'Trade Year': 2023}
# 2023-01-03 09:32:00
# 327.25 203.15
# 2023-01-03 09:33:00 Entry Triggered PE
# 2023-01-03 09:37:00 SL Hit
# {'Signal Generated At': datetime.time(9, 32), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 09:33:00'), 'Entry Price': 235.45, 'Initial SL': 216.614, 'SL': 225.16400000000002, 'Exit Time': Timestamp('2023-01-03 09:37:00'), 'Exit Price': 225.16400000000002, 'Points Captured': -10.285999999999973, 'After Costs': -10.800299999999972, 'Qty': 42.47186239116586, 'ROI%': -0.04587088553833074, 'Trade Year': 2023}
# 2023-01-03 09:33:00
# 327.25 203.15
# 2023-01-03 09:34:00 Entry Triggered PE
# 2023-01-03 09:41:00 SL Hit
# {'Signal Generated At': datetime.time(9, 33), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 09:34:00'), 'Entry Price': 232.15, 'Initial SL': 213.578, 'SL': 224.57800000000003, 'Exit Time': Timestamp('2023-01-03 09:41:00'), 'Exit Price': 224.57800000000003, 'Points Captured': -7.571999999999974, 'After Costs': -7.950599999999973, 'Qty': 43.07559767391773, 'ROI%': -0.03424768468662491, 'Trade Year': 2023}
# 2023-01-03 09:34:00
# 327.25 203.15
# 2023-01-03 09:35:00 Entry Triggered PE
# 2023-01-03 09:41:00 SL Hit
# {'Signal Generated At': datetime.time(9, 34), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 09:35:00'), 'Entry Price': 228.85, 'Initial SL': 210.542, 'SL': 221.54200000000003, 'Exit Time': Timestamp('2023-01-03 09:41:00'), 'Exit Price': 221.54200000000003, 'Points Captured': -7.307999999999964, 'After Costs': -7.673399999999963, 'Qty': 43.69674459252786, 'ROI%': -0.03353025999563016, 'Trade Year': 2023}
# 2023-01-03 09:35:00
# 327.25 203.15
# 2023-01-03 09:36:00 Entry Triggered PE
# 2023-01-03 09:41:00 SL Hit
# {'Signal Generated At': datetime.time(9, 35), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 09
 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:11:00'), 'Entry Price': 243.0, 'Initial SL': 223.56, 'SL': 233.91, 'Exit Time': Timestamp('2023-01-03 10:17:00'), 'Exit Price': 233.91, 'Points Captured': -9.090000000000003, 'After Costs': -9.544500000000005, 'Qty': 41.1522633744856, 'ROI%': -0.0392777777777778, 'Trade Year': 2023}
# 2023-01-03 10:11:00
# 327.25 203.15
# 2023-01-03 10:12:00 Entry Triggered PE
# 2023-01-03 10:17:00 SL Hit
# {'Signal Generated At': datetime.time(10, 11), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:12:00'), 'Entry Price': 244.7, 'Initial SL': 225.124, 'SL': 232.724, 'Exit Time': Timestamp('2023-01-03 10:17:00'), 'Exit Price': 232.724, 'Points Captured': -11.975999999999999, 'After Costs': -12.5748, 'Qty': 40.86636697997548, 'ROI%': -0.05138863914997956, 'Trade Year': 2023}
# 2023-01-03 10:12:00
# 327.25 203.15
# 2023-01-03 10:13:00 Entry Triggered PE
# 2023-01-03 10:22:00 SL Hit
# {'Signal Generated At': datetime.time(10, 12), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:13:00'), 'Entry Price': 238.05, 'Initial SL': 219.00600000000003, 'SL': 236.55600000000004, 'Exit Time': Timestamp('2023-01-03 10:22:00'), 'Exit Price': 236.55600000000004, 'Points Captured': -1.4939999999999714, 'After Costs': -1.56869999999997, 'Qty': 42.00798151648813, 'ROI%': -0.006589792060491367, 'Trade Year': 2023}
# 2023-01-03 10:13:00
# 327.25 203.15
# 2023-01-03 10:14:00 Entry Triggered PE
# 2023-01-03 10:29:00 SL Hit
# {'Signal Generated At': datetime.time(10, 13), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:14:00'), 'Entry Price': 228.45, 'Initial SL': 210.174, 'SL': 243.924, 'Exit Time': Timestamp('2023-01-03 10:29:00'), 'Exit Price': 243.924, 'Points Captured': 15.474000000000018, 'After Costs': 14.700300000000016, 'Qty': 43.77325454147516, 'ROI%': 0.0643479973736048, 'Trade Year': 2023}
# 2023-01-03 10:14:00
# 327.25 203.15
# 2023-01-03 10:15:00 Entry Triggered PE
# 2023-01-03 10:29:00 SL Hit
# {'Signal Generated At': datetime.time(10, 14), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:15:00'), 'Entry Price': 229.35, 'Initial SL': 211.002, 'SL': 244.752, 'Exit Time': Timestamp('2023-01-03 10:29:00'), 'Exit Price': 244.752, 'Points Captured': 15.402000000000015, 'After Costs': 14.631900000000014, 'Qty': 43.60148245040332, 'ROI%': 0.0637972531066057, 'Trade Year': 2023}
# 2023-01-03 10:15:00
# 327.25 203.15
# 2023-01-03 10:16:00 Entry Triggered PE
# 2023-01-03 10:26:00 SL Hit
# {'Signal Generated At': datetime.time(10, 15), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:16:00'), 'Entry Price': 234.35, 'Initial SL': 215.602, 'SL': 239.15200000000002, 'Exit Time': Timestamp('2023-01-03 10:26:00'), 'Exit Price': 239.15200000000002, 'Points Captured': 4.802000000000021, 'After Costs': 4.56190000000002, 'Qty': 42.67121826328142, 'ROI%': 0.019466183059526437, 'Trade Year': 2023}
# 2023-01-03 10:16:00
# 327.25 203.15
# 2023-01-03 10:17:00 Entry Triggered PE
# 2023-01-03 10:31:00 SL Hit
# {'Signal Generated At': datetime.time(10, 16), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:17:00'), 'Entry Price': 228.35, 'Initial SL': 210.082, 'SL': 243.03199999999998, 'Exit Time': Timestamp('2023-01-03 10:31:00'), 'Exit Price': 243.03199999999998, 'Points Captured': 14.681999999999988, 'After Costs': 13.947899999999988, 'Qty': 43.79242391066346, 'ROI%': 0.06108123494635423, 'Trade Year': 2023}
# 2023-01-03 10:17:00
# 327.25 203.15
# 2023-01-03 10:18:00 Entry Triggered PE
# 2023-01-03 10:29:00 SL Hit
# {'Signal Generated At': datetime.time(10, 17), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:18:00'), 'Entry Price': 232.1, 'Initial SL': 213.532, 'SL': 241.382, 'Exit Time': Timestamp('2023-01-03 10:29:00'), 'Exit Price': 241.382, 'Points Captured': 9.28200000000001, 'After Costs': 8.81790000000001, 'Qty': 43.08487720809996, 'ROI%': 0.03799181387333051, 'Trade Year': 2023}
# 2023-01-03 10:18:00
# 327.25 203.15
# 2023-01-03 10:19:00 Entry Triggered PE
# 2023-01-03 10:29:00 SL Hit
# {'Signal Generated At': datetime.time(10, 18), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:19:00'), 'Entry Price': 233.95, 'Initial SL': 215.234, 'SL': 239.334, 'Exit Time': Timestamp('2023-01-03 10:29:00'), 'Exit Price': 239.334, 'Points Captured': 5.3840000000000146, 'After Costs': 5.114800000000014, 'Qty': 42.74417610600556, 'ROI%': 0.021862791194699784, 'Trade Year': 2023}
# 2023-01-03 10:19:00
# 327.25 203.15
# 2023-01-03 10:20:00 Entry Triggered PE
# 2023-01-03 10:31:00 SL Hit
# {'Signal Generated At': datetime.time(10, 19), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:20:00'), 'Entry Price': 235.65, 'Initial SL': 216.798, 'SL': 244.148, 'Exit Time': Timestamp('2023-01-03 10:31:00'), 'Exit Price': 244.148, 'Points Captured': 8.49799999999999, 'After Costs': 8.073099999999991, 'Qty': 42.435815828559306, 'ROI%': 0.034258858476554174, 'Trade Year': 2023}
# 2023-01-03 10:20:00
# 327.25 203.15
# 2023-01-03 10:21:00 Entry Triggered PE
# 2023-01-03 10:29:00 SL Hit
# {'Signal Generated At': datetime.time(10, 20), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:21:00'), 'Entry Price': 240.0, 'Initial SL': 220.8, 'SL': 241.35, 'Exit Time': Timestamp('2023-01-03 10:29:00'), 'Exit Price': 241.35, 'Points Captured': 1.3499999999999943, 'After Costs': 1.2824999999999946, 'Qty': 41.666666666666664, 'ROI%': 0.005343749999999977, 'Trade Year': 2023}
# 2023-01-03 10:21:00
# 327.25 203.15
# 2023-01-03 10:22:00 Entry Triggered PE
# 2023-01-03 10:33:00 SL Hit
# {'Signal Generated At': datetime.time(10, 21), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:22:00'), 'Entry Price': 236.35, 'Initial SL': 217.442, 'SL': 240.992, 'Exit Time': Timestamp('2023-01-03 10:33:00'), 'Exit Price': 240.992, 'Points Captured': 4.641999999999996, 'After Costs': 4.409899999999996, 'Qty': 42.31013327691982, 'ROI%': 0.018658345673788854, 'Trade Year': 2023}
# 2023-01-03 10:22:00
# 327.25 203.15
# 2023-01-03 10:23:00 Entry Triggered PE
# 2023-01-03 10:33:00 SL Hit
# {'Signal Generated At': datetime.time(10, 22), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:23:00'), 'Entry Price': 238.1, 'Initial SL': 219.052, 'SL': 242.60199999999998, 'Exit Time': Timestamp('2023-01-03 10:33:00'), 'Exit Price': 242.60199999999998, 'Points Captured': 4.501999999999981, 'After Costs': 4.276899999999982, 'Qty': 41.999160016799664, 'ROI%': 0.017962620747584975, 'Trade Year': 2023}
# 2023-01-03 10:23:00
# 327.25 203.15
# 2023-01-03 10:24:00 Entry Triggered PE
# 2023-01-03 10:33:00 SL Hit
# {'Signal Generated At': datetime.time(10, 23), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:24:00'), 'Entry Price': 235.25, 'Initial SL': 216.43, 'SL': 238.23, 'Exit Time': Timestamp('2023-01-03 10:33:00'), 'Exit Price': 238.23, 'Points Captured': 2.9799999999999898, 'After Costs': 2.83099999999999, 'Qty': 42.50797024442083, 'ROI%': 0.012034006376195496, 'Trade Year': 2023}
# 2023-01-03 10:24:00
# 327.25 203.15
# 2023-01-03 10:25:00 Entry Triggered PE
# 2023-01-03 10:33:00 SL Hit
# {'Signal Generated At': datetime.time(10, 24), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:25:00'), 'Entry Price': 240.4, 'Initial SL': 221.168, 'SL': 242.968, 'Exit Time': Timestamp('2023-01-03 10:33:00'), 'Exit Price': 242.968, 'Points Captured': 2.5679999999999836, 'After Costs': 2.4395999999999844, 'Qty': 41.597337770382694, 'ROI%': 0.010148086522462497, 'Trade Year': 2023}
# 2023-01-03 10:25:00
# 327.25 203.15
# 2023-01-03 10:26:00 Entry Triggered PE
# 2023-01-03 10:35:00 SL Hit
# {'Signal Generated At': datetime.time(10, 25), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:26:00'), 'Entry Price': 237.55, 'Initial SL': 218.54600000000002, 'SL': 237.796, 'Exit Time': Timestamp('2023-01-03 10:35:00'), 'Exit Price': 237.796, 'Points Captured': 0.2459999999999809, 'After Costs': 0.23369999999998184, 'Qty': 42.09640075773521, 'ROI%': 0.0009837928857081954, 'Trade Year': 2023}
# 2023-01-03 10:26:00
# 327.25 203.15
# 2023-01-03 10:27:00 Entry Triggered PE
# 2023-01-03 10:35:00 SL Hit
# {'Signal Generated At': datetime.time(10, 26), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:27:00'), 'Entry Price': 235.55, 'Initial SL': 216.70600000000002, 'SL': 235.956, 'Exit Time': Timestamp('2023-01-03 10:35:00'), 'Exit Price': 235.956, 'Points Captured': 0.4059999999999775, 'After Costs': 0.3856999999999786, 'Qty': 42.45383145828911, 'ROI%': 0.00163744427934612, 'Trade Year': 2023}
# 2023-01-03 10:27:00
# 327.25 203.15
# 2023-01-03 10:28:00 Entry Triggered PE
# 2023-01-03 10:33:00 SL Hit
# {'Signal Generated At': datetime.time(10, 27), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:28:00'), 'Entry Price': 244.85, 'Initial SL': 225.262, 'SL': 241.91199999999998, 'Exit Time': Timestamp('2023-01-03 10:33:00'), 'Exit Price': 241.91199999999998, 'Points Captured': -2.9380000000000166, 'After Costs': -3.0849000000000175, 'Qty': 40.84133142740453, 'ROI%': -0.012599142332040094, 'Trade Year': 2023}
# 2023-01-03 10:28:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 28), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:29:00
# 327.25 203.15
# 2023-01-03 10:30:00 Entry Triggered PE
# 2023-01-03 10:42:00 SL Hit
# {'Signal Generated At': datetime.time(10, 29), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:30:00'), 'Entry Price': 244.35, 'Initial SL': 224.802, 'SL': 251.902, 'Exit Time': Timestamp('2023-01-03 10:42:00'), 'Exit Price': 251.902, 'Points Captured': 7.5519999999999925, 'After Costs': 7.174399999999992, 'Qty': 40.92490280335584, 'ROI%': 0.029361162267239577, 'Trade Year': 2023}
# 2023-01-03 10:30:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 30), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:31:00
# 327.25 203.15
# 2023-01-03 10:32:00 Entry Triggered PE
# 2023-01-03 10:43:00 SL Hit
# {'Signal Generated At': datetime.time(10, 31), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:32:00'), 'Entry Price': 243.05, 'Initial SL': 223.60600000000002, 'SL': 245.60600000000002, 'Exit Time': Timestamp('2023-01-03 10:43:00'), 'Exit Price': 245.60600000000002, 'Points Captured': 2.5560000000000116, 'After Costs': 2.428200000000011, 'Qty': 41.14379757251594, 'ROI%': 0.009990536926558368, 'Trade Year': 2023}
# 2023-01-03 10:32:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 32), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:33:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 33), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:34:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 34), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:35:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 35), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:36:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 36), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:37:00
# 327.25 203.15
# 2023-01-03 10:38:00 Entry Triggered PE
# 2023-01-03 10:46:00 SL Hit
# {'Signal Generated At': datetime.time(10, 37), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:38:00'), 'Entry Price': 246.8, 'Initial SL': 227.056, 'SL': 251.156, 'Exit Time': Timestamp('2023-01-03 10:46:00'), 'Exit Price': 251.156, 'Points Captured': 4.3559999999999945, 'After Costs': 4.138199999999995, 'Qty': 40.51863857374392, 'ROI%': 0.01676742301458669, 'Trade Year': 2023}
# 2023-01-03 10:38:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 38), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:39:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 39), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:40:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 40), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:41:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 41), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:42:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 42), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:43:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 43), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:44:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 44), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:45:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 45), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:46:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 46), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:47:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 47), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:48:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 48), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:49:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 49), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:50:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 50), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:51:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 51), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:52:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 52), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:53:00
# 327.25 203.15
# 2023-01-03 12:12:00 Entry Triggered PE
# 2023-01-03 12:19:00 SL Hit
# {'Signal Generated At': datetime.time(10, 53), 'Strike': 43300, 'Entry Time': Timestamp('2023-01-03 12:12:00'), 'Entry Price': 232.45, 'Initial SL': 213.85399999999998, 'SL': 252.35399999999998, 'Exit Time': Timestamp('2023-01-03 12:19:00'), 'Exit Price': 252.35399999999998, 'Points Captured': 19.903999999999996, 'After Costs': 18.908799999999996, 'Qty': 43.02000430200043, 'ROI%': 0.08134566573456656, 'Trade Year': 2023}
# 2023-01-03 10:54:00
# 327.25 203.15
# 2023-01-03 10:55:00 Entry Triggered PE
# 2023-01-03 11:12:00 SL Hit
# {'Signal Generated At': datetime.time(10, 54), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:55:00'), 'Entry Price': 231.55, 'Initial SL': 213.026, 'SL': 238.626, 'Exit Time': Timestamp('2023-01-03 11:12:00'), 'Exit Price': 238.626, 'Points Captured': 7.075999999999993, 'After Costs': 6.722199999999994, 'Qty': 43.187216583891164, 'ROI%': 0.029031310732023294, 'Trade Year': 2023}
# 2023-01-03 10:55:00
# 327.25 203.15
# 2023-01-03 10:56:00 Entry Triggered PE
# 2023-01-03 11:04:00 SL Hit
# {'Signal Generated At': datetime.time(10, 55), 'Strike': 43400, 'Entry Time': Timestamp('2023-01-03 10:56:00'), 'Entry Price': 240.35, 'Initial SL': 221.122, 'SL': 239.722, 'Exit Time': Timestamp('2023-01-03 11:04:00'), 'Exit Price': 239.722, 'Points Captured': -0.6279999999999859, 'After Costs': -0.6593999999999852, 'Qty': 41.60599126274184, 'ROI%': -0.0027434990638651353, 'Trade Year': 2023}
# 2023-01-03 10:56:00
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[40], line 183
#     179             atm_flag = False
#     181     return pd.DataFrame(trade_book)
# --> 183 tb = await generate_trades()
#     184 tb
#
# Cell In[40], line 39, in generate_trades()
#      26 expiry_date = get_expiry(current_date)
#      28 ce_df = await fetch_option_data(
#      29     index='bnf',
#      30     expiry=expiry_date,
#    (...)
#      36     end_time=dt.time(15, 30)
#      37 )
# ---> 39 pe_df = await fetch_option_data(
#      40     index='bnf',
#      41     expiry=expiry_date,
#      42     strike=atm,
#      43     asset_class=AssetClass.PUT,
#      44     start_date=current_date,
#      45     start_time=dt.time(9, 15),
#      46     end_date=current_date,
#      47     end_time=dt.time(15, 30)
#      48 )
#      50 ce_df = ce_df.to_pandas()
#      51 pe_df = pe_df.to_pandas()
#
# File ~/strategies/droplets/droplets/bnf_systems/../tooling/fetch.py:23, in fetch_option_data(index, expiry, strike, asset_class, start_date, end_date, start_time, end_time)
#      11 @validate_call(config=dict(arbitrary_types_allowed=True))
#      12 async def fetch_option_data(
#      13     index: Index,
#    (...)
#      20     end_time: dt.time = dt.time(15, 30),
#      21 ) -> str | pl.DataFrame:
#      22     async with httpx.AsyncClient(timeout=20.0) as client:
# ---> 23         resp = await client.get(
#      24             API_URL + "/options/get",
#      25             params={
#      26                 "index": index,
#      27                 "expiry": expiry,  # type:ignore[dict-item]
#      28                 "strike": strike,
#      29                 "asset_class": asset_class,
#      30                 "start_date": dt.datetime.combine(
#      31                     date=start_date, time=start_time
#      32                 ),  # type:ignore[dict-item]
#      33                 "end_date": dt.datetime.combine(
#      34                     date=end_date, time=end_time
#      35                 ),  # type:ignore[dict-item]
#      36             },
#      37         )
#      39     if resp.status_code != 200:
#      40         msg: str = resp.json()["msg"]["error"]
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpx/_client.py:1786, in AsyncClient.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1769 async def get(
#    1770     self,
#    1771     url: URLTypes,
#    (...)
#    1779     extensions: typing.Optional[RequestExtensions] = None,
#    1780 ) -> Response:
#    1781     """
#    1782     Send a `GET` request.
#    1783
#    1784     **Parameters**: See `httpx.request`.
#    1785     """
# -> 1786     return await self.request(
#    1787         "GET",
#    1788         url,
#    1789         params=params,
#    1790         headers=headers,
#    1791         cookies=cookies,
#    1792         auth=auth,
#    1793         follow_redirects=follow_redirects,
#    1794         timeout=timeout,
#    1795         extensions=extensions,
#    1796     )
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpx/_client.py:1559, in AsyncClient.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1530 """
#    1531 Build and send a request.
#    1532
#    (...)
#    1544 [0]: /advanced/#merging-of-configuration
#    1545 """
#    1546 request = self.build_request(
#    1547     method=method,
#    1548     url=url,
#    (...)
#    1557     extensions=extensions,
#    1558 )
# -> 1559 return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpx/_client.py:1660, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1658 except BaseException as exc:  # pragma: no cover
#    1659     await response.aclose()
# -> 1660     raise exc
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpx/_client.py:1654, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1652 try:
#    1653     if not stream:
# -> 1654         await response.aread()
#    1656     return response
#    1658 except BaseException as exc:  # pragma: no cover
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpx/_models.py:915, in Response.aread(self)
#     911 """
#     912 Read and return the response content.
#     913 """
#     914 if not hasattr(self, "_content"):
# --> 915     self._content = b"".join([part async for part in self.aiter_bytes()])
#     916 return self._content
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpx/_models.py:915, in <listcomp>(.0)
#     911 """
#     912 Read and return the response content.
#     913 """
#     914 if not hasattr(self, "_content"):
# --> 915     self._content = b"".join([part async for part in self.aiter_bytes()])
#     916 return self._content
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpx/_models.py:933, in Response.aiter_bytes(self, chunk_size)
#     931 chunker = ByteChunker(chunk_size=chunk_size)
#     932 with request_context(request=self._request):
# --> 933     async for raw_bytes in self.aiter_raw():
#     934         decoded = decoder.decode(raw_bytes)
#     935         for chunk in chunker.decode(decoded):
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpx/_models.py:991, in Response.aiter_raw(self, chunk_size)
#     988 chunker = ByteChunker(chunk_size=chunk_size)
#     990 with request_context(request=self._request):
# --> 991     async for raw_stream_bytes in self.stream:
#     992         self._num_bytes_downloaded += len(raw_stream_bytes)
#     993         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpx/_client.py:147, in BoundAsyncStream.__aiter__(self)
#     146 async def __aiter__(self) -> typing.AsyncIterator[bytes]:
# --> 147     async for chunk in self._stream:
#     148         yield chunk
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpx/_transports/default.py:252, in AsyncResponseStream.__aiter__(self)
#     250 async def __aiter__(self) -> typing.AsyncIterator[bytes]:
#     251     with map_httpcore_exceptions():
# --> 252         async for part in self._httpcore_stream:
#     253             yield part
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:361, in ConnectionPoolByteStream.__aiter__(self)
#     360 async def __aiter__(self) -> AsyncIterator[bytes]:
# --> 361     async for part in self._stream:
#     362         yield part
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpcore/_async/http11.py:337, in HTTP11ConnectionByteStream.__aiter__(self)
#     335 with AsyncShieldCancellation():
#     336     await self.aclose()
# --> 337 raise exc
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpcore/_async/http11.py:329, in HTTP11ConnectionByteStream.__aiter__(self)
#     327 try:
#     328     async with Trace("receive_response_body", logger, self._request, kwargs):
# --> 329         async for chunk in self._connection._receive_response_body(**kwargs):
#     330             yield chunk
#     331 except BaseException as exc:
#     332     # If we get an exception while streaming the response,
#     333     # we want to close the response (and possibly the connection)
#     334     # before raising that exception.
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpcore/_async/http11.py:198, in AsyncHTTP11Connection._receive_response_body(self, request)
#     195 timeout = timeouts.get("read", None)
#     197 while True:
# --> 198     event = await self._receive_event(timeout=timeout)
#     199     if isinstance(event, h11.Data):
#     200         yield bytes(event.data)
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpcore/_async/http11.py:212, in AsyncHTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = await self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/httpcore/_backends/anyio.py:34, in AnyIOStream.read(self, max_bytes, timeout)
#      32 with anyio.fail_after(timeout):
#      33     try:
# ---> 34         return await self._stream.receive(max_bytes=max_bytes)
#      35     except anyio.EndOfStream:  # pragma: nocover
#      36         return b""
#
# File ~/strategies/droplets/.venv/lib/python3.11/site-packages/anyio/_backends/_asyncio.py:1123, in SocketStream.receive(self, max_bytes)
#    1118 if (
#    1119     not self._protocol.read_event.is_set()
#    1120     and not self._transport.is_closing()
#    1121 ):
#    1122     self._transport.resume_reading()
# -> 1123     await self._protocol.read_event.wait()
#    1124     self._transport.pause_reading()
#    1126 try:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/asyncio/locks.py:213, in Event.wait(self)
#     211 self._waiters.append(fut)
#     212 try:
# --> 213     await fut
#     214     return True
#     215 finally:
#
# CancelledError:
