# %%
import asyncio
import datetime as dt
import math
from typing import Literal

import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

# %%
import sys

sys.path.append("..")
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
from fetching_from_local_db.enums import AssetClass, Index, StrikeSpread
from fetching_from_local_db.fetch_from_db import _fetch_batch, fetch_data, fetch_spot_data

# %%
from expiries import dict_expiries

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("o").first().alias("o"),
                pl.col("h").max().alias("h"),
                pl.col("l").min().alias("l"),
                pl.col("c").last().alias("c"),
                # pl.col("volume").sum().alias("volume"),
            ]
        )
    )


# ohlc_resampled = resample(pl.DataFrame(bnf_1min), '7d', pd.Timedelta(days=4))
# ohlc_resampled

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2019, 2026),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe

    # Iterate over each year
    for year in range(2019, 2026):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]

        # Calculate total ROI
        total_roi = year_trades["ROI%"].sum()

        # Calculate total number of trades
        total_trades = len(year_trades)

        # Calculate win rate
        win_rate = (year_trades["ROI%"] > 0).mean() * 100

        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI%"] > 0]["ROI%"].mean()

        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI%"] < 0]["ROI%"].mean()

        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI%"].cumsum() - year_trades["ROI%"].cumsum().cummax()
        ).min()

        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = f"{variation}"

        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]

    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI%"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI%"] > 0][
        "ROI%"
    ].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI%"].cumsum()
        - combined_df_sorted["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation

    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    return {overall_roi_dd_ratio: stats_df8}

# %%
bnf_1min = pd.read_csv("../data/nifty_min.csv")

# %%
bnf_1min.columns = ['index', 'datetime', 'o', 'h', 'l', 'c', 'v']
bnf_1min.tail()
# Out:
#         index             datetime          o          h          l  \
# 750760  nifty  2025-03-28 15:25:00 23500.2500 23502.5000 23485.7500
# 750761  nifty  2025-03-28 15:26:00 23490.7500 23494.3500 23486.7500
# 750762  nifty  2025-03-28 15:27:00 23494.2000 23497.4500 23489.7500
# 750763  nifty  2025-03-28 15:28:00 23497.1000 23500.4500 23491.0500
# 750764  nifty  2025-03-28 15:29:00 23492.2500 23503.1000 23450.2000
#
#                 c  v
# 750760 23490.4000  0
# 750761 23494.0500  0
# 750762 23496.8000  0
# 750763 23492.0000  0
# 750764 23495.1500  0

# %%
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["datetime"]).dt.tz_localize(None)
# bnf_1min = bnf_1min[((bnf_1min['datetime'].dt.year == 2020) & (bnf_1min['datetime'].dt.month == 4))]
bnf_1min = bnf_1min[
    (bnf_1min["datetime"].dt.year >= 2019) & (bnf_1min["datetime"].dt.year <= 2025)
]

# %%
dict_expiries
# Out:
# {'nifty': [datetime.datetime(2017, 1, 25, 0, 0),
#   datetime.datetime(2017, 2, 23, 0, 0),
#   datetime.datetime(2017, 3, 30, 0, 0),
#   datetime.datetime(2017, 4, 27, 0, 0),
#   datetime.datetime(2017, 5, 25, 0, 0),
#   datetime.datetime(2017, 6, 29, 0, 0),
#   datetime.datetime(2017, 7, 27, 0, 0),
#   datetime.datetime(2017, 8, 31, 0, 0),
#   datetime.datetime(2017, 9, 28, 0, 0),
#   datetime.datetime(2017, 10, 26, 0, 0),
#   datetime.datetime(2017, 11, 30, 0, 0),
#   datetime.datetime(2017, 12, 28, 0, 0),
#   datetime.datetime(2018, 1, 25, 0, 0),
#   datetime.datetime(2018, 2, 22, 0, 0),
#   datetime.datetime(2018, 3, 28, 0, 0),
#   datetime.datetime(2018, 4, 26, 0, 0),
#   datetime.datetime(2018, 5, 31, 0, 0),
#   datetime.datetime(2018, 6, 28, 0, 0),
#   datetime.datetime(2018, 7, 26, 0, 0),
#   datetime.datetime(2018, 8, 30, 0, 0),
#   datetime.datetime(2018, 9, 27, 0, 0),
#   datetime.datetime(2018, 10, 25, 0, 0),
#   datetime.datetime(2018, 11, 29, 0, 0),
#   datetime.datetime(2018, 12, 27, 0, 0),
#   datetime.datetime(2019, 1, 31, 0, 0),
#   datetime.datetime(2019, 2, 14, 0, 0),
#   datetime.datetime(2019, 2, 21, 0, 0),
#   datetime.datetime(2019, 2, 28, 0, 0),
#   datetime.datetime(2019, 3, 7, 0, 0),
#   datetime.datetime(2019, 3, 14, 0, 0),
#   datetime.datetime(2019, 3, 20, 0, 0),
#   datetime.datetime(2019, 3, 28, 0, 0),
#   datetime.datetime(2019, 4, 4, 0, 0),
#   datetime.datetime(2019, 4, 11, 0, 0),
#   datetime.datetime(2019, 4, 18, 0, 0),
#   datetime.datetime(2019, 4, 25, 0, 0),
#   datetime.datetime(2019, 5, 2, 0, 0),
#   datetime.datetime(2019, 5, 9, 0, 0),
#   datetime.datetime(2019, 5, 16, 0, 0),
#   datetime.datetime(2019, 5, 23, 0, 0),
#   datetime.datetime(2019, 5, 30, 0, 0),
#   datetime.datetime(2019, 6, 6, 0, 0),
#   datetime.datetime(2019, 6, 13, 0, 0),
#   datetime.datetime(2019, 6, 20, 0, 0),
#   datetime.datetime(2019, 6, 27, 0, 0),
#   datetime.datetime(2019, 7, 4, 0, 0),
#   datetime.datetime(2019, 7, 11, 0, 0),
#   datetime.datetime(2019, 7, 18, 0, 0),
#   datetime.datetime(2019, 7, 25, 0, 0),
#   datetime.datetime(2019, 8, 1, 0, 0),
#   datetime.datetime(2019, 8, 8, 0, 0),
#   datetime.datetime(2019, 8, 14, 0, 0),
#   datetime.datetime(2019, 8, 22, 0, 0),
#   datetime.datetime(2019, 8, 29, 0, 0),
#   datetime.datetime(2019, 9, 5, 0, 0),
#   datetime.datetime(2019, 9, 12, 0, 0),
#   datetime.datetime(2019, 9, 19, 0, 0),
#   datetime.datetime(2019, 9, 26, 0, 0),
#   datetime.datetime(2019, 10, 3, 0, 0),
#   datetime.datetime(2019, 10, 10, 0, 0),
#   datetime.datetime(2019, 10, 17, 0, 0),
#   datetime.datetime(2019, 10, 24, 0, 0),
#   datetime.datetime(2019, 10, 31, 0, 0),
#   datetime.datetime(2019, 11, 7, 0, 0),
#   datetime.datetime(2019, 11, 14, 0, 0),
#   datetime.datetime(2019, 11, 21, 0, 0),
#   datetime.datetime(2019, 11, 28, 0, 0),
#   datetime.datetime(2019, 12, 5, 0, 0),
#   datetime.datetime(2019, 12, 12, 0, 0),
#   datetime.datetime(2019, 12, 19, 0, 0),
#   datetime.datetime(2019, 12, 26, 0, 0),
#   datetime.datetime(2020, 1, 2, 0, 0),
#   datetime.datetime(2020, 1, 9, 0, 0),
#   datetime.datetime(2020, 1, 16, 0, 0),
#   datetime.datetime(2020, 1, 23, 0, 0),
#   datetime.datetime(2020, 1, 30, 0, 0),
#   datetime.datetime(2020, 2, 6, 0, 0),
#   datetime.datetime(2020, 2, 13, 0, 0),
#   datetime.datetime(2020, 2, 20, 0, 0),
#   datetime.datetime(2020, 2, 27, 0, 0),
#   datetime.datetime(2020, 3, 5, 0, 0),
#   datetime.datetime(2020, 3, 12, 0, 0),
#   datetime.datetime(2020, 3, 19, 0, 0),
#   datetime.datetime(2020, 3, 26, 0, 0),
#   datetime.datetime(2020, 4, 1, 0, 0),
#   datetime.datetime(2020, 4, 9, 0, 0),
#   datetime.datetime(2020, 4, 16, 0, 0),
#   datetime.datetime(2020, 4, 23, 0, 0),
#   datetime.datetime(2020, 4, 30, 0, 0),
#   datetime.datetime(2020, 5, 7, 0, 0),
#   datetime.datetime(2020, 5, 14, 0, 0),
#   datetime.datetime(2020, 5, 21, 0, 0),
#   datetime.datetime(2020, 5, 28, 0, 0),
#   datetime.datetime(2020, 6, 4, 0, 0),
#   datetime.datetime(2020, 6, 11, 0, 0),
#   datetime.datetime(2020, 6, 18, 0, 0),
#   datetime.datetime(2020, 6, 25, 0, 0),
#   datetime.datetime(2020, 7, 2, 0, 0),
#   datetime.datetime(2020, 7, 9, 0, 0),
#   datetime.datetime(2020, 7, 16, 0, 0),
#   datetime.datetime(2020, 7, 23, 0, 0),
#   datetime.datetime(2020, 7, 30, 0, 0),
#   datetime.datetime(2020, 8, 6, 0, 0),
#   datetime.datetime(2020, 8, 13, 0, 0),
#   datetime.datetime(2020, 8, 20, 0, 0),
#   datetime.datetime(2020, 8, 27, 0, 0),
#   datetime.datetime(2020, 9, 3, 0, 0),
#   datetime.datetime(2020, 9, 10, 0, 0),
#   datetime.datetime(2020, 9, 17, 0, 0),
#   datetime.datetime(2020, 9, 24, 0, 0),
#   datetime.datetime(2020, 10, 1, 0, 0),
#   datetime.datetime(2020, 10, 8, 0, 0),
#   datetime.datetime(2020, 10, 15, 0, 0),
#   datetime.datetime(2020, 10, 22, 0, 0),
#   datetime.datetime(2020, 10, 29, 0, 0),
#   datetime.datetime(2020, 11, 5, 0, 0),
#   datetime.datetime(2020, 11, 12, 0, 0),
#   datetime.datetime(2020, 11, 19, 0, 0),
#   datetime.datetime(2020, 11, 26, 0, 0),
#   datetime.datetime(2020, 12, 3, 0, 0),
#   datetime.datetime(2020, 12, 10, 0, 0),
#   datetime.datetime(2020, 12, 17, 0, 0),
#   datetime.datetime(2020, 12, 24, 0, 0),
#   datetime.datetime(2020, 12, 31, 0, 0),
#   datetime.datetime(2021, 1, 7, 0, 0),
#   datetime.datetime(2021, 1, 14, 0, 0),
#   datetime.datetime(2021, 1, 21, 0, 0),
#   datetime.datetime(2021, 1, 28, 0, 0),
#   datetime.datetime(2021, 2, 4, 0, 0),
#   datetime.datetime(2021, 2, 11, 0, 0),
#   datetime.datetime(2021, 2, 18, 0, 0),
#   datetime.datetime(2021, 2, 25, 0, 0),
#   datetime.datetime(2021, 3, 4, 0, 0),
#   datetime.datetime(2021, 3, 10, 0, 0),
#   datetime.datetime(2021, 3, 18, 0, 0),
#   datetime.datetime(2021, 3, 25, 0, 0),
#   datetime.datetime(2021, 4, 1, 0, 0),
#   datetime.datetime(2021, 4, 8, 0, 0),
#   datetime.datetime(2021, 4, 15, 0, 0),
#   datetime.datetime(2021, 4, 22, 0, 0),
#   datetime.datetime(2021, 4, 29, 0, 0),
#   datetime.datetime(2021, 5, 6, 0, 0),
#   datetime.datetime(2021, 5, 12, 0, 0),
#   datetime.datetime(2021, 5, 20, 0, 0),
#   datetime.datetime(2021, 5, 27, 0, 0),
#   datetime.datetime(2021, 6, 3, 0, 0),
#   datetime.datetime(2021, 6, 10, 0, 0),
#   datetime.datetime(2021, 6, 17, 0, 0),
#   datetime.datetime(2021, 6, 24, 0, 0),
#   datetime.datetime(2021, 7, 1, 0, 0),
#   datetime.datetime(2021, 7, 8, 0, 0),
#   datetime.datetime(2021, 7, 15, 0, 0),
#   datetime.datetime(2021, 7, 22, 0, 0),
#   datetime.datetime(2021, 7, 29, 0, 0),
#   datetime.datetime(2021, 8, 5, 0, 0),
#   datetime.datetime(2021, 8, 12, 0, 0),
#   datetime.datetime(2021, 8, 18, 0, 0),
#   datetime.datetime(2021, 8, 26, 0, 0),
#   datetime.datetime(2021, 9, 2, 0, 0),
#   datetime.datetime(2021, 9, 9, 0, 0),
#   datetime.datetime(2021, 9, 16, 0, 0),
#   datetime.datetime(2021, 9, 23, 0, 0),
#   datetime.datetime(2021, 9, 30, 0, 0),
#   datetime.datetime(2021, 10, 7, 0, 0),
#   datetime.datetime(2021, 10, 14, 0, 0),
#   datetime.datetime(2021, 10, 21, 0, 0),
#   datetime.datetime(2021, 10, 28, 0, 0),
#   datetime.datetime(2021, 11, 3, 0, 0),
#   datetime.datetime(2021, 11, 11, 0, 0),
#   datetime.datetime(2021, 11, 18, 0, 0),
#   datetime.datetime(2021, 11, 25, 0, 0),
#   datetime.datetime(2021, 12, 2, 0, 0),
#   datetime.datetime(2021, 12, 9, 0, 0),
#   datetime.datetime(2021, 12, 16, 0, 0),
#   datetime.datetime(2021, 12, 23, 0, 0),
#   datetime.datetime(2021, 12, 30, 0, 0),
#   datetime.datetime(2022, 1, 6, 0, 0),
#   datetime.datetime(2022, 1, 13, 0, 0),
#   datetime.datetime(2022, 1, 20, 0, 0),
#   datetime.datetime(2022, 1, 22, 0, 0),
#   datetime.datetime(2022, 1, 27, 0, 0),
#   datetime.datetime(2022, 2, 3, 0, 0),
#   datetime.datetime(2022, 2, 10, 0, 0),
#   datetime.datetime(2022, 2, 17, 0, 0),
#   datetime.datetime(2022, 2, 24, 0, 0),
#   datetime.datetime(2022, 3, 3, 0, 0),
#   datetime.datetime(2022, 3, 10, 0, 0),
#   datetime.datetime(2022, 3, 17, 0, 0),
#   datetime.datetime(2022, 3, 24, 0, 0),
#   datetime.datetime(2022, 3, 31, 0, 0),
#   datetime.datetime(2022, 4, 7, 0, 0),
#   datetime.datetime(2022, 4, 13, 0, 0),
#   datetime.datetime(2022, 4, 21, 0, 0),
#   datetime.datetime(2022, 4, 28, 0, 0),
#   datetime.datetime(2022, 5, 5, 0, 0),
#   datetime.datetime(2022, 5, 12, 0, 0),
#   datetime.datetime(2022, 5, 19, 0, 0),
#   datetime.datetime(2022, 5, 26, 0, 0),
#   datetime.datetime(2022, 6, 2, 0, 0),
#   datetime.datetime(2022, 6, 9, 0, 0),
#   datetime.datetime(2022, 6, 16, 0, 0),
#   datetime.datetime(2022, 6, 23, 0, 0),
#   datetime.datetime(2022, 6, 30, 0, 0),
#   datetime.datetime(2022, 7, 7, 0, 0),
#   datetime.datetime(2022, 7, 14, 0, 0),
#   datetime.datetime(2022, 7, 21, 0, 0),
#   datetime.datetime(2022, 7, 28, 0, 0),
#   datetime.datetime(2022, 8, 4, 0, 0),
#   datetime.datetime(2022, 8, 11, 0, 0),
#   datetime.datetime(2022, 8, 18, 0, 0),
#   datetime.datetime(2022, 8, 25, 0, 0),
#   datetime.datetime(2022, 9, 1, 0, 0),
#   datetime.datetime(2022, 9, 8, 0, 0),
#   datetime.datetime(2022, 9, 15, 0, 0),
#   datetime.datetime(2022, 9, 22, 0, 0),
#   datetime.datetime(2022, 9, 29, 0, 0),
#   datetime.datetime(2022, 10, 6, 0, 0),
#   datetime.datetime(2022, 10, 13, 0, 0),
#   datetime.datetime(2022, 10, 20, 0, 0),
#   datetime.datetime(2022, 10, 27, 0, 0),
#   datetime.datetime(2022, 11, 3, 0, 0),
#   datetime.datetime(2022, 11, 10, 0, 0),
#   datetime.datetime(2022, 11, 17, 0, 0),
#   datetime.datetime(2022, 11, 24, 0, 0),
#   datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 8, 0, 0),
#   datetime.datetime(2022, 12, 15, 0, 0),
#   datetime.datetime(2022, 12, 22, 0, 0),
#   datetime.datetime(2022, 12, 29, 0, 0),
#   datetime.datetime(2023, 1, 5, 0, 0),
#   datetime.datetime(2023, 1, 12, 0, 0),
#   datetime.datetime(2023, 1, 19, 0, 0),
#   datetime.datetime(2023, 1, 25, 0, 0),
#   datetime.datetime(2023, 2, 2, 0, 0),
#   datetime.datetime(2023, 2, 9, 0, 0),
#   datetime.datetime(2023, 2, 16, 0, 0),
#   datetime.datetime(2023, 2, 23, 0, 0),
#   datetime.datetime(2023, 3, 2, 0, 0),
#   datetime.datetime(2023, 3, 9, 0, 0),
#   datetime.datetime(2023, 3, 16, 0, 0),
#   datetime.datetime(2023, 3, 23, 0, 0),
#   datetime.datetime(2023, 3, 29, 0, 0),
#   datetime.datetime(2023, 3, 30, 0, 0),
#   datetime.datetime(2023, 4, 6, 0, 0),
#   datetime.datetime(2023, 4, 13, 0, 0),
#   datetime.datetime(2023, 4, 20, 0, 0),
#   datetime.datetime(2023, 4, 27, 0, 0),
#   datetime.datetime(2023, 5, 4, 0, 0),
#   datetime.datetime(2023, 5, 11, 0, 0),
#   datetime.datetime(2023, 5, 18, 0, 0),
#   datetime.datetime(2023, 5, 25, 0, 0),
#   datetime.datetime(2023, 6, 1, 0, 0),
#   datetime.datetime(2023, 6, 8, 0, 0),
#   datetime.datetime(2023, 6, 15, 0, 0),
#   datetime.datetime(2023, 6, 22, 0, 0),
#   datetime.datetime(2023, 6, 28, 0, 0),
#   datetime.datetime(2023, 6, 29, 0, 0),
#   datetime.datetime(2023, 7, 6, 0, 0),
#   datetime.datetime(2023, 7, 13, 0, 0),
#   datetime.datetime(2023, 7, 20, 0, 0),
#   datetime.datetime(2023, 7, 27, 0, 0),
#   datetime.datetime(2023, 8, 3, 0, 0),
#   datetime.datetime(2023, 8, 10, 0, 0),
#   datetime.datetime(2023, 8, 17, 0, 0),
#   datetime.datetime(2023, 8, 24, 0, 0),
#   datetime.datetime(2023, 8, 31, 0, 0),
#   datetime.datetime(2023, 9, 7, 0, 0),
#   datetime.datetime(2023, 9, 14, 0, 0),
#   datetime.datetime(2023, 9, 21, 0, 0),
#   datetime.datetime(2023, 9, 28, 0, 0),
#   datetime.datetime(2023, 10, 5, 0, 0),
#   datetime.datetime(2023, 10, 12, 0, 0),
#   datetime.datetime(2023, 10, 19, 0, 0),
#   datetime.datetime(2023, 10, 26, 0, 0),
#   datetime.datetime(2023, 11, 2, 0, 0),
#   datetime.datetime(2023, 11, 9, 0, 0),
#   datetime.datetime(2023, 11, 16, 0, 0),
#   datetime.datetime(2023, 11, 23, 0, 0),
#   datetime.datetime(2023, 11, 30, 0, 0),
#   datetime.datetime(2023, 12, 7, 0, 0),
#   datetime.datetime(2023, 12, 14, 0, 0),
#   datetime.datetime(2023, 12, 21, 0, 0),
#   datetime.datetime(2023, 12, 28, 0, 0),
#   datetime.datetime(2024, 1, 4, 0, 0),
#   datetime.datetime(2024, 1, 11, 0, 0),
#   datetime.datetime(2024, 1, 18, 0, 0),
#   datetime.datetime(2024, 1, 25, 0, 0),
#   datetime.datetime(2024, 2, 1, 0, 0),
#   datetime.datetime(2024, 2, 8, 0, 0),
#   datetime.datetime(2024, 2, 15, 0, 0),
#   datetime.datetime(2024, 2, 22, 0, 0),
#   datetime.datetime(2024, 2, 29, 0, 0),
#   datetime.datetime(2024, 3, 7, 0, 0),
#   datetime.datetime(2024, 3, 14, 0, 0),
#   datetime.datetime(2024, 3, 21, 0, 0),
#   datetime.datetime(2024, 3, 28, 0, 0),
#   datetime.datetime(2024, 4, 4, 0, 0),
#   datetime.datetime(2024, 4, 10, 0, 0),
#   datetime.datetime(2024, 4, 18, 0, 0),
#   datetime.datetime(2024, 4, 25, 0, 0),
#   datetime.datetime(2024, 5, 2, 0, 0),
#   datetime.datetime(2024, 5, 9, 0, 0),
#   datetime.datetime(2024, 5, 16, 0, 0),
#   datetime.datetime(2024, 5, 23, 0, 0),
#   datetime.datetime(2024, 5, 30, 0, 0),
#   datetime.datetime(2024, 6, 6, 0, 0),
#   datetime.datetime(2024, 6, 13, 0, 0),
#   datetime.datetime(2024, 6, 20, 0, 0),
#   datetime.datetime(2024, 6, 27, 0, 0),
#   datetime.datetime(2024, 7, 4, 0, 0),
#   datetime.datetime(2024, 7, 11, 0, 0),
#   datetime.datetime(2024, 7, 18, 0, 0),
#   datetime.datetime(2024, 7, 25, 0, 0),
#   datetime.datetime(2024, 8, 1, 0, 0),
#   datetime.datetime(2024, 8, 8, 0, 0),
#   datetime.datetime(2024, 8, 14, 0, 0),
#   datetime.datetime(2024, 8, 22, 0, 0),
#   datetime.datetime(2024, 8, 29, 0, 0),
#   datetime.datetime(2024, 9, 5, 0, 0),
#   datetime.datetime(2024, 9, 12, 0, 0),
#   datetime.datetime(2024, 9, 19, 0, 0),
#   datetime.datetime(2024, 9, 26, 0, 0),
#   datetime.datetime(2024, 10, 3, 0, 0),
#   datetime.datetime(2024, 10, 10, 0, 0),
#   datetime.datetime(2024, 10, 17, 0, 0),
#   datetime.datetime(2024, 10, 24, 0, 0),
#   datetime.datetime(2024, 10, 31, 0, 0),
#   datetime.datetime(2024, 11, 7, 0, 0),
#   datetime.datetime(2024, 11, 14, 0, 0),
#   datetime.datetime(2024, 11, 21, 0, 0),
#   datetime.datetime(2024, 11, 28, 0, 0),
#   datetime.datetime(2024, 12, 5, 0, 0),
#   datetime.datetime(2024, 12, 12, 0, 0),
#   datetime.datetime(2024, 12, 19, 0, 0),
#   datetime.datetime(2024, 12, 26, 0, 0),
#   datetime.datetime(2025, 1, 2, 0, 0),
#   datetime.datetime(2025, 1, 9, 0, 0),
#   datetime.datetime(2025, 1, 16, 0, 0),
#   datetime.datetime(2025, 1, 23, 0, 0),
#   datetime.datetime(2025, 1, 30, 0, 0),
#   datetime.datetime(2025, 2, 6, 0, 0),
#   datetime.datetime(2025, 2, 13, 0, 0),
#   datetime.datetime(2025, 2, 20, 0, 0),
#   datetime.datetime(2025, 2, 27, 0, 0),
#   datetime.datetime(2025, 3, 6, 0, 0),
#   datetime.datetime(2025, 3, 13, 0, 0),
#   datetime.datetime(2025, 3, 20, 0, 0),
#   datetime.datetime(2025, 3, 27, 0, 0),
#   datetime.datetime(2025, 4, 3, 0, 0),
#   datetime.datetime(2025, 4, 24, 0, 0),
#   datetime.datetime(2025, 5, 29, 0, 0),
#   datetime.datetime(2025, 6, 26, 0, 0),
#   datetime.datetime(2025, 9, 25, 0, 0),
#   datetime.datetime(2025, 12, 24, 0, 0),
#   datetime.datetime(2026, 6, 25, 0, 0),
#   datetime.datetime(2026, 12, 31, 0, 0)],
#  'midcpnifty': [datetime.datetime(2023, 9, 4, 0, 0),
#   datetime.datetime(2023, 9, 11, 0, 0),
#   datetime.datetime(2023, 9, 18, 0, 0),
#   datetime.datetime(2023, 9, 25, 0, 0),
#   datetime.datetime(2023, 9, 29, 0, 0),
#   datetime.datetime(2023, 10, 9, 0, 0),
#   datetime.datetime(2023, 10, 16, 0, 0),
#   datetime.datetime(2023, 10, 23, 0, 0),
#   datetime.datetime(2023, 10, 30, 0, 0),
#   datetime.datetime(2023, 11, 6, 0, 0),
#   datetime.datetime(2023, 11, 13, 0, 0),
#   datetime.datetime(2023, 11, 20, 0, 0),
#   datetime.datetime(2023, 11, 24, 0, 0),
#   datetime.datetime(2023, 12, 4, 0, 0),
#   datetime.datetime(2023, 12, 11, 0, 0),
#   datetime.datetime(2023, 12, 18, 0, 0),
#   datetime.datetime(2023, 12, 22, 0, 0),
#   datetime.datetime(2024, 1, 1, 0, 0),
#   datetime.datetime(2024, 1, 8, 0, 0),
#   datetime.datetime(2024, 1, 15, 0, 0),
#   datetime.datetime(2024, 1, 22, 0, 0),
#   datetime.datetime(2024, 1, 29, 0, 0),
#   datetime.datetime(2024, 2, 5, 0, 0),
#   datetime.datetime(2024, 2, 12, 0, 0),
#   datetime.datetime(2024, 2, 19, 0, 0),
#   datetime.datetime(2024, 2, 26, 0, 0),
#   datetime.datetime(2024, 3, 4, 0, 0),
#   datetime.datetime(2024, 3, 11, 0, 0),
#   datetime.datetime(2024, 3, 18, 0, 0),
#   datetime.datetime(2024, 3, 22, 0, 0),
#   datetime.datetime(2024, 4, 1, 0, 0),
#   datetime.datetime(2024, 4, 8, 0, 0),
#   datetime.datetime(2024, 4, 15, 0, 0),
#   datetime.datetime(2024, 4, 22, 0, 0),
#   datetime.datetime(2024, 4, 29, 0, 0),
#   datetime.datetime(2024, 5, 6, 0, 0),
#   datetime.datetime(2024, 5, 13, 0, 0),
#   datetime.datetime(2024, 5, 17, 0, 0),
#   datetime.datetime(2024, 5, 27, 0, 0),
#   datetime.datetime(2024, 6, 3, 0, 0),
#   datetime.datetime(2024, 6, 10, 0, 0),
#   datetime.datetime(2024, 6, 14, 0, 0),
#   datetime.datetime(2024, 6, 24, 0, 0),
#   datetime.datetime(2024, 7, 1, 0, 0),
#   datetime.datetime(2024, 7, 8, 0, 0),
#   datetime.datetime(2024, 7, 15, 0, 0),
#   datetime.datetime(2024, 7, 22, 0, 0),
#   datetime.datetime(2024, 7, 29, 0, 0),
#   datetime.datetime(2024, 8, 5, 0, 0),
#   datetime.datetime(2024, 8, 12, 0, 0),
#   datetime.datetime(2024, 8, 19, 0, 0),
#   datetime.datetime(2024, 8, 26, 0, 0),
#   datetime.datetime(2024, 9, 2, 0, 0),
#   datetime.datetime(2024, 9, 9, 0, 0),
#   datetime.datetime(2024, 9, 16, 0, 0),
#   datetime.datetime(2024, 9, 23, 0, 0),
#   datetime.datetime(2024, 9, 30, 0, 0),
#   datetime.datetime(2024, 10, 7, 0, 0),
#   datetime.datetime(2024, 10, 14, 0, 0),
#   datetime.datetime(2024, 10, 21, 0, 0),
#   datetime.datetime(2024, 10, 28, 0, 0),
#   datetime.datetime(2024, 11, 4, 0, 0),
#   datetime.datetime(2024, 11, 11, 0, 0),
#   datetime.datetime(2024, 11, 18, 0, 0),
#   datetime.datetime(2024, 11, 25, 0, 0),
#   datetime.datetime(2024, 12, 30, 0, 0),
#   datetime.datetime(2025, 1, 27, 0, 0),
#   datetime.datetime(2025, 1, 30, 0, 0),
#   datetime.datetime(2025, 2, 24, 0, 0),
#   datetime.datetime(2025, 2, 27, 0, 0),
#   datetime.datetime(2025, 3, 27, 0, 0),
#   datetime.datetime(2025, 4, 24, 0, 0)],
#  'bankex': [datetime.datetime(2023, 9, 1, 0, 0),
#   datetime.datetime(2023, 9, 8, 0, 0),
#   datetime.datetime(2023, 9, 15, 0, 0),
#   datetime.datetime(2023, 9, 22, 0, 0),
#   datetime.datetime(2023, 9, 29, 0, 0),
#   datetime.datetime(2023, 10, 6, 0, 0),
#   datetime.datetime(2023, 10, 13, 0, 0),
#   datetime.datetime(2023, 10, 16, 0, 0),
#   datetime.datetime(2023, 10, 23, 0, 0),
#   datetime.datetime(2023, 10, 30, 0, 0),
#   datetime.datetime(2023, 11, 6, 0, 0),
#   datetime.datetime(2023, 11, 13, 0, 0),
#   datetime.datetime(2023, 11, 20, 0, 0),
#   datetime.datetime(2023, 11, 24, 0, 0),
#   datetime.datetime(2023, 12, 4, 0, 0),
#   datetime.datetime(2023, 12, 11, 0, 0),
#   datetime.datetime(2023, 12, 18, 0, 0),
#   datetime.datetime(2023, 12, 22, 0, 0),
#   datetime.datetime(2024, 1, 1, 0, 0),
#   datetime.datetime(2024, 1, 8, 0, 0),
#   datetime.datetime(2024, 1, 15, 0, 0),
#   datetime.datetime(2024, 1, 20, 0, 0),
#   datetime.datetime(2024, 1, 22, 0, 0),
#   datetime.datetime(2024, 1, 29, 0, 0),
#   datetime.datetime(2024, 2, 5, 0, 0),
#   datetime.datetime(2024, 2, 12, 0, 0),
#   datetime.datetime(2024, 2, 19, 0, 0),
#   datetime.datetime(2024, 2, 26, 0, 0),
#   datetime.datetime(2024, 3, 4, 0, 0),
#   datetime.datetime(2024, 3, 11, 0, 0),
#   datetime.datetime(2024, 3, 18, 0, 0),
#   datetime.datetime(2024, 3, 22, 0, 0),
#   datetime.datetime(2024, 4, 1, 0, 0),
#   datetime.datetime(2024, 4, 8, 0, 0),
#   datetime.datetime(2024, 4, 15, 0, 0),
#   datetime.datetime(2024, 4, 22, 0, 0),
#   datetime.datetime(2024, 4, 29, 0, 0),
#   datetime.datetime(2024, 5, 6, 0, 0),
#   datetime.datetime(2024, 5, 13, 0, 0),
#   datetime.datetime(2024, 5, 17, 0, 0),
#   datetime.datetime(2024, 5, 27, 0, 0),
#   datetime.datetime(2024, 6, 3, 0, 0),
#   datetime.datetime(2024, 6, 10, 0, 0),
#   datetime.datetime(2024, 6, 14, 0, 0),
#   datetime.datetime(2024, 6, 24, 0, 0),
#   datetime.datetime(2024, 7, 1, 0, 0),
#   datetime.datetime(2024, 7, 8, 0, 0),
#   datetime.datetime(2024, 7, 15, 0, 0),
#   datetime.datetime(2024, 7, 22, 0, 0),
#   datetime.datetime(2024, 7, 29, 0, 0),
#   datetime.datetime(2024, 8, 5, 0, 0),
#   datetime.datetime(2024, 8, 12, 0, 0),
#   datetime.datetime(2024, 8, 19, 0, 0),
#   datetime.datetime(2024, 8, 26, 0, 0),
#   datetime.datetime(2024, 9, 2, 0, 0),
#   datetime.datetime(2024, 9, 9, 0, 0),
#   datetime.datetime(2024, 9, 16, 0, 0),
#   datetime.datetime(2024, 9, 23, 0, 0),
#   datetime.datetime(2024, 9, 30, 0, 0),
#   datetime.datetime(2024, 10, 7, 0, 0),
#   datetime.datetime(2024, 10, 14, 0, 0),
#   datetime.datetime(2024, 10, 21, 0, 0),
#   datetime.datetime(2024, 10, 28, 0, 0),
#   datetime.datetime(2024, 11, 4, 0, 0),
#   datetime.datetime(2024, 11, 11, 0, 0),
#   datetime.datetime(2024, 11, 18, 0, 0),
#   datetime.datetime(2024, 11, 25, 0, 0),
#   datetime.datetime(2024, 12, 30, 0, 0),
#   datetime.datetime(2025, 1, 27, 0, 0),
#   datetime.datetime(2025, 1, 28, 0, 0),
#   datetime.datetime(2025, 2, 24, 0, 0),
#   datetime.datetime(2025, 2, 25, 0, 0),
#   datetime.datetime(2025, 3, 25, 0, 0)],
#  'bnf': [datetime.datetime(2017, 1, 5, 0, 0),
#   datetime.datetime(2017, 1, 12, 0, 0),
#   datetime.datetime(2017, 1, 19, 0, 0),
#   datetime.datetime(2017, 1, 25, 0, 0),
#   datetime.datetime(2017, 2, 2, 0, 0),
#   datetime.datetime(2017, 2, 9, 0, 0),
#   datetime.datetime(2017, 2, 16, 0, 0),
#   datetime.datetime(2017, 2, 23, 0, 0),
#   datetime.datetime(2017, 3, 2, 0, 0),
#   datetime.datetime(2017, 3, 9, 0, 0),
#   datetime.datetime(2017, 3, 16, 0, 0),
#   datetime.datetime(2017, 3, 23, 0, 0),
#   datetime.datetime(2017, 3, 30, 0, 0),
#   datetime.datetime(2017, 4, 6, 0, 0),
#   datetime.datetime(2017, 4, 13, 0, 0),
#   datetime.datetime(2017, 4, 20, 0, 0),
#   datetime.datetime(2017, 4, 27, 0, 0),
#   datetime.datetime(2017, 5, 4, 0, 0),
#   datetime.datetime(2017, 5, 11, 0, 0),
#   datetime.datetime(2017, 5, 18, 0, 0),
#   datetime.datetime(2017, 5, 25, 0, 0),
#   datetime.datetime(2017, 6, 1, 0, 0),
#   datetime.datetime(2017, 6, 8, 0, 0),
#   datetime.datetime(2017, 6, 15, 0, 0),
#   datetime.datetime(2017, 6, 22, 0, 0),
#   datetime.datetime(2017, 6, 29, 0, 0),
#   datetime.datetime(2017, 7, 6, 0, 0),
#   datetime.datetime(2017, 7, 13, 0, 0),
#   datetime.datetime(2017, 7, 20, 0, 0),
#   datetime.datetime(2017, 7, 27, 0, 0),
#   datetime.datetime(2017, 8, 3, 0, 0),
#   datetime.datetime(2017, 8, 10, 0, 0),
#   datetime.datetime(2017, 8, 17, 0, 0),
#   datetime.datetime(2017, 8, 24, 0, 0),
#   datetime.datetime(2017, 8, 31, 0, 0),
#   datetime.datetime(2017, 9, 7, 0, 0),
#   datetime.datetime(2017, 9, 14, 0, 0),
#   datetime.datetime(2017, 9, 21, 0, 0),
#   datetime.datetime(2017, 9, 28, 0, 0),
#   datetime.datetime(2017, 10, 5, 0, 0),
#   datetime.datetime(2017, 10, 12, 0, 0),
#   datetime.datetime(2017, 10, 18, 0, 0),
#   datetime.datetime(2017, 10, 26, 0, 0),
#   datetime.datetime(2017, 11, 2, 0, 0),
#   datetime.datetime(2017, 11, 9, 0, 0),
#   datetime.datetime(2017, 11, 16, 0, 0),
#   datetime.datetime(2017, 11, 23, 0, 0),
#   datetime.datetime(2017, 11, 30, 0, 0),
#   datetime.datetime(2017, 12, 7, 0, 0),
#   datetime.datetime(2017, 12, 14, 0, 0),
#   datetime.datetime(2017, 12, 21, 0, 0),
#   datetime.datetime(2017, 12, 28, 0, 0),
#   datetime.datetime(2018, 1, 4, 0, 0),
#   datetime.datetime(2018, 1, 11, 0, 0),
#   datetime.datetime(2018, 1, 18, 0, 0),
#   datetime.datetime(2018, 1, 25, 0, 0),
#   datetime.datetime(2018, 2, 1, 0, 0),
#   datetime.datetime(2018, 2, 8, 0, 0),
#   datetime.datetime(2018, 2, 15, 0, 0),
#   datetime.datetime(2018, 2, 22, 0, 0),
#   datetime.datetime(2018, 3, 1, 0, 0),
#   datetime.datetime(2018, 3, 8, 0, 0),
#   datetime.datetime(2018, 3, 15, 0, 0),
#   datetime.datetime(2018, 3, 22, 0, 0),
#   datetime.datetime(2018, 3, 28, 0, 0),
#   datetime.datetime(2018, 4, 5, 0, 0),
#   datetime.datetime(2018, 4, 12, 0, 0),
#   datetime.datetime(2018, 4, 19, 0, 0),
#   datetime.datetime(2018, 4, 26, 0, 0),
#   datetime.datetime(2018, 5, 3, 0, 0),
#   datetime.datetime(2018, 5, 10, 0, 0),
#   datetime.datetime(2018, 5, 17, 0, 0),
#   datetime.datetime(2018, 5, 24, 0, 0),
#   datetime.datetime(2018, 5, 31, 0, 0),
#   datetime.datetime(2018, 6, 7, 0, 0),
#   datetime.datetime(2018, 6, 14, 0, 0),
#   datetime.datetime(2018, 6, 21, 0, 0),
#   datetime.datetime(2018, 6, 28, 0, 0),
#   datetime.datetime(2018, 7, 5, 0, 0),
#   datetime.datetime(2018, 7, 12, 0, 0),
#   datetime.datetime(2018, 7, 19, 0, 0),
#   datetime.datetime(2018, 7, 26, 0, 0),
#   datetime.datetime(2018, 8, 2, 0, 0),
#   datetime.datetime(2018, 8, 9, 0, 0),
#   datetime.datetime(2018, 8, 16, 0, 0),
#   datetime.datetime(2018, 8, 23, 0, 0),
#   datetime.datetime(2018, 8, 30, 0, 0),
#   datetime.datetime(2018, 9, 6, 0, 0),
#   datetime.datetime(2018, 9, 12, 0, 0),
#   datetime.datetime(2018, 9, 19, 0, 0),
#   datetime.datetime(2018, 9, 27, 0, 0),
#   datetime.datetime(2018, 10, 4, 0, 0),
#   datetime.datetime(2018, 10, 11, 0, 0),
#   datetime.datetime(2018, 10, 17, 0, 0),
#   datetime.datetime(2018, 10, 25, 0, 0),
#   datetime.datetime(2018, 11, 1, 0, 0),
#   datetime.datetime(2018, 11, 6, 0, 0),
#   datetime.datetime(2018, 11, 15, 0, 0),
#   datetime.datetime(2018, 11, 22, 0, 0),
#   datetime.datetime(2018, 11, 29, 0, 0),
#   datetime.datetime(2018, 12, 6, 0, 0),
#   datetime.datetime(2018, 12, 13, 0, 0),
#   datetime.datetime(2018, 12, 20, 0, 0),
#   datetime.datetime(2018, 12, 27, 0, 0),
#   datetime.datetime(2019, 1, 3, 0, 0),
#   datetime.datetime(2019, 1, 10, 0, 0),
#   datetime.datetime(2019, 1, 17, 0, 0),
#   datetime.datetime(2019, 1, 24, 0, 0),
#   datetime.datetime(2019, 1, 31, 0, 0),
#   datetime.datetime(2019, 2, 7, 0, 0),
#   datetime.datetime(2019, 2, 14, 0, 0),
#   datetime.datetime(2019, 2, 21, 0, 0),
#   datetime.datetime(2019, 2, 28, 0, 0),
#   datetime.datetime(2019, 3, 7, 0, 0),
#   datetime.datetime(2019, 3, 14, 0, 0),
#   datetime.datetime(2019, 3, 20, 0, 0),
#   datetime.datetime(2019, 3, 28, 0, 0),
#   datetime.datetime(2019, 4, 4, 0, 0),
#   datetime.datetime(2019, 4, 11, 0, 0),
#   datetime.datetime(2019, 4, 18, 0, 0),
#   datetime.datetime(2019, 4, 25, 0, 0),
#   datetime.datetime(2019, 5, 2, 0, 0),
#   datetime.datetime(2019, 5, 9, 0, 0),
#   datetime.datetime(2019, 5, 16, 0, 0),
#   datetime.datetime(2019, 5, 23, 0, 0),
#   datetime.datetime(2019, 5, 30, 0, 0),
#   datetime.datetime(2019, 6, 6, 0, 0),
#   datetime.datetime(2019, 6, 13, 0, 0),
#   datetime.datetime(2019, 6, 20, 0, 0),
#   datetime.datetime(2019, 6, 27, 0, 0),
#   datetime.datetime(2019, 7, 4, 0, 0),
#   datetime.datetime(2019, 7, 11, 0, 0),
#   datetime.datetime(2019, 7, 18, 0, 0),
#   datetime.datetime(2019, 7, 25, 0, 0),
#   datetime.datetime(2019, 8, 1, 0, 0),
#   datetime.datetime(2019, 8, 8, 0, 0),
#   datetime.datetime(2019, 8, 14, 0, 0),
#   datetime.datetime(2019, 8, 22, 0, 0),
#   datetime.datetime(2019, 8, 29, 0, 0),
#   datetime.datetime(2019, 9, 5, 0, 0),
#   datetime.datetime(2019, 9, 12, 0, 0),
#   datetime.datetime(2019, 9, 19, 0, 0),
#   datetime.datetime(2019, 9, 26, 0, 0),
#   datetime.datetime(2019, 10, 3, 0, 0),
#   datetime.datetime(2019, 10, 10, 0, 0),
#   datetime.datetime(2019, 10, 17, 0, 0),
#   datetime.datetime(2019, 10, 24, 0, 0),
#   datetime.datetime(2019, 10, 31, 0, 0),
#   datetime.datetime(2019, 11, 7, 0, 0),
#   datetime.datetime(2019, 11, 14, 0, 0),
#   datetime.datetime(2019, 11, 21, 0, 0),
#   datetime.datetime(2019, 11, 28, 0, 0),
#   datetime.datetime(2019, 12, 5, 0, 0),
#   datetime.datetime(2019, 12, 12, 0, 0),
#   datetime.datetime(2019, 12, 19, 0, 0),
#   datetime.datetime(2019, 12, 26, 0, 0),
#   datetime.datetime(2020, 1, 2, 0, 0),
#   datetime.datetime(2020, 1, 9, 0, 0),
#   datetime.datetime(2020, 1, 16, 0, 0),
#   datetime.datetime(2020, 1, 23, 0, 0),
#   datetime.datetime(2020, 1, 30, 0, 0),
#   datetime.datetime(2020, 2, 6, 0, 0),
#   datetime.datetime(2020, 2, 13, 0, 0),
#   datetime.datetime(2020, 2, 20, 0, 0),
#   datetime.datetime(2020, 2, 27, 0, 0),
#   datetime.datetime(2020, 3, 5, 0, 0),
#   datetime.datetime(2020, 3, 12, 0, 0),
#   datetime.datetime(2020, 3, 19, 0, 0),
#   datetime.datetime(2020, 3, 26, 0, 0),
#   datetime.datetime(2020, 4, 1, 0, 0),
#   datetime.datetime(2020, 4, 9, 0, 0),
#   datetime.datetime(2020, 4, 16, 0, 0),
#   datetime.datetime(2020, 4, 23, 0, 0),
#   datetime.datetime(2020, 4, 30, 0, 0),
#   datetime.datetime(2020, 5, 7, 0, 0),
#   datetime.datetime(2020, 5, 14, 0, 0),
#   datetime.datetime(2020, 5, 21, 0, 0),
#   datetime.datetime(2020, 5, 28, 0, 0),
#   datetime.datetime(2020, 6, 4, 0, 0),
#   datetime.datetime(2020, 6, 11, 0, 0),
#   datetime.datetime(2020, 6, 18, 0, 0),
#   datetime.datetime(2020, 6, 25, 0, 0),
#   datetime.datetime(2020, 7, 2, 0, 0),
#   datetime.datetime(2020, 7, 9, 0, 0),
#   datetime.datetime(2020, 7, 16, 0, 0),
#   datetime.datetime(2020, 7, 23, 0, 0),
#   datetime.datetime(2020, 7, 30, 0, 0),
#   datetime.datetime(2020, 8, 6, 0, 0),
#   datetime.datetime(2020, 8, 13, 0, 0),
#   datetime.datetime(2020, 8, 20, 0, 0),
#   datetime.datetime(2020, 8, 27, 0, 0),
#   datetime.datetime(2020, 9, 3, 0, 0),
#   datetime.datetime(2020, 9, 10, 0, 0),
#   datetime.datetime(2020, 9, 17, 0, 0),
#   datetime.datetime(2020, 9, 24, 0, 0),
#   datetime.datetime(2020, 10, 1, 0, 0),
#   datetime.datetime(2020, 10, 8, 0, 0),
#   datetime.datetime(2020, 10, 15, 0, 0),
#   datetime.datetime(2020, 10, 22, 0, 0),
#   datetime.datetime(2020, 10, 29, 0, 0),
#   datetime.datetime(2020, 11, 5, 0, 0),
#   datetime.datetime(2020, 11, 12, 0, 0),
#   datetime.datetime(2020, 11, 19, 0, 0),
#   datetime.datetime(2020, 11, 26, 0, 0),
#   datetime.datetime(2020, 12, 3, 0, 0),
#   datetime.datetime(2020, 12, 10, 0, 0),
#   datetime.datetime(2020, 12, 17, 0, 0),
#   datetime.datetime(2020, 12, 24, 0, 0),
#   datetime.datetime(2020, 12, 31, 0, 0),
#   datetime.datetime(2021, 1, 7, 0, 0),
#   datetime.datetime(2021, 1, 14, 0, 0),
#   datetime.datetime(2021, 1, 21, 0, 0),
#   datetime.datetime(2021, 1, 28, 0, 0),
#   datetime.datetime(2021, 2, 4, 0, 0),
#   datetime.datetime(2021, 2, 11, 0, 0),
#   datetime.datetime(2021, 2, 18, 0, 0),
#   datetime.datetime(2021, 2, 25, 0, 0),
#   datetime.datetime(2021, 3, 4, 0, 0),
#   datetime.datetime(2021, 3, 10, 0, 0),
#   datetime.datetime(2021, 3, 18, 0, 0),
#   datetime.datetime(2021, 3, 25, 0, 0),
#   datetime.datetime(2021, 4, 1, 0, 0),
#   datetime.datetime(2021, 4, 8, 0, 0),
#   datetime.datetime(2021, 4, 15, 0, 0),
#   datetime.datetime(2021, 4, 22, 0, 0),
#   datetime.datetime(2021, 4, 29, 0, 0),
#   datetime.datetime(2021, 5, 6, 0, 0),
#   datetime.datetime(2021, 5, 12, 0, 0),
#   datetime.datetime(2021, 5, 20, 0, 0),
#   datetime.datetime(2021, 5, 27, 0, 0),
#   datetime.datetime(2021, 6, 3, 0, 0),
#   datetime.datetime(2021, 6, 10, 0, 0),
#   datetime.datetime(2021, 6, 17, 0, 0),
#   datetime.datetime(2021, 6, 24, 0, 0),
#   datetime.datetime(2021, 7, 1, 0, 0),
#   datetime.datetime(2021, 7, 8, 0, 0),
#   datetime.datetime(2021, 7, 15, 0, 0),
#   datetime.datetime(2021, 7, 22, 0, 0),
#   datetime.datetime(2021, 7, 29, 0, 0),
#   datetime.datetime(2021, 8, 5, 0, 0),
#   datetime.datetime(2021, 8, 12, 0, 0),
#   datetime.datetime(2021, 8, 18, 0, 0),
#   datetime.datetime(2021, 8, 26, 0, 0),
#   datetime.datetime(2021, 9, 2, 0, 0),
#   datetime.datetime(2021, 9, 9, 0, 0),
#   datetime.datetime(2021, 9, 16, 0, 0),
#   datetime.datetime(2021, 9, 23, 0, 0),
#   datetime.datetime(2021, 9, 30, 0, 0),
#   datetime.datetime(2021, 10, 7, 0, 0),
#   datetime.datetime(2021, 10, 14, 0, 0),
#   datetime.datetime(2021, 10, 21, 0, 0),
#   datetime.datetime(2021, 10, 28, 0, 0),
#   datetime.datetime(2021, 11, 3, 0, 0),
#   datetime.datetime(2021, 11, 11, 0, 0),
#   datetime.datetime(2021, 11, 18, 0, 0),
#   datetime.datetime(2021, 11, 25, 0, 0),
#   datetime.datetime(2021, 12, 2, 0, 0),
#   datetime.datetime(2021, 12, 9, 0, 0),
#   datetime.datetime(2021, 12, 16, 0, 0),
#   datetime.datetime(2021, 12, 23, 0, 0),
#   datetime.datetime(2021, 12, 30, 0, 0),
#   datetime.datetime(2022, 1, 6, 0, 0),
#   datetime.datetime(2022, 1, 13, 0, 0),
#   datetime.datetime(2022, 1, 20, 0, 0),
#   datetime.datetime(2022, 1, 27, 0, 0),
#   datetime.datetime(2022, 2, 3, 0, 0),
#   datetime.datetime(2022, 2, 10, 0, 0),
#   datetime.datetime(2022, 2, 17, 0, 0),
#   datetime.datetime(2022, 2, 24, 0, 0),
#   datetime.datetime(2022, 3, 3, 0, 0),
#   datetime.datetime(2022, 3, 10, 0, 0),
#   datetime.datetime(2022, 3, 17, 0, 0),
#   datetime.datetime(2022, 3, 24, 0, 0),
#   datetime.datetime(2022, 3, 31, 0, 0),
#   datetime.datetime(2022, 4, 7, 0, 0),
#   datetime.datetime(2022, 4, 13, 0, 0),
#   datetime.datetime(2022, 4, 21, 0, 0),
#   datetime.datetime(2022, 4, 28, 0, 0),
#   datetime.datetime(2022, 5, 5, 0, 0),
#   datetime.datetime(2022, 5, 12, 0, 0),
#   datetime.datetime(2022, 5, 19, 0, 0),
#   datetime.datetime(2022, 5, 26, 0, 0),
#   datetime.datetime(2022, 6, 2, 0, 0),
#   datetime.datetime(2022, 6, 9, 0, 0),
#   datetime.datetime(2022, 6, 16, 0, 0),
#   datetime.datetime(2022, 6, 23, 0, 0),
#   datetime.datetime(2022, 6, 30, 0, 0),
#   datetime.datetime(2022, 7, 7, 0, 0),
#   datetime.datetime(2022, 7, 14, 0, 0),
#   datetime.datetime(2022, 7, 21, 0, 0),
#   datetime.datetime(2022, 7, 28, 0, 0),
#   datetime.datetime(2022, 8, 4, 0, 0),
#   datetime.datetime(2022, 8, 11, 0, 0),
#   datetime.datetime(2022, 8, 18, 0, 0),
#   datetime.datetime(2022, 8, 25, 0, 0),
#   datetime.datetime(2022, 9, 1, 0, 0),
#   datetime.datetime(2022, 9, 8, 0, 0),
#   datetime.datetime(2022, 9, 15, 0, 0),
#   datetime.datetime(2022, 9, 22, 0, 0),
#   datetime.datetime(2022, 9, 29, 0, 0),
#   datetime.datetime(2022, 10, 6, 0, 0),
#   datetime.datetime(2022, 10, 13, 0, 0),
#   datetime.datetime(2022, 10, 20, 0, 0),
#   datetime.datetime(2022, 10, 27, 0, 0),
#   datetime.datetime(2022, 11, 3, 0, 0),
#   datetime.datetime(2022, 11, 10, 0, 0),
#   datetime.datetime(2022, 11, 17, 0, 0),
#   datetime.datetime(2022, 11, 24, 0, 0),
#   datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 8, 0, 0),
#   datetime.datetime(2022, 12, 15, 0, 0),
#   datetime.datetime(2022, 12, 22, 0, 0),
#   datetime.datetime(2022, 12, 29, 0, 0),
#   datetime.datetime(2023, 1, 5, 0, 0),
#   datetime.datetime(2023, 1, 12, 0, 0),
#   datetime.datetime(2023, 1, 19, 0, 0),
#   datetime.datetime(2023, 1, 25, 0, 0),
#   datetime.datetime(2023, 2, 2, 0, 0),
#   datetime.datetime(2023, 2, 9, 0, 0),
#   datetime.datetime(2023, 2, 16, 0, 0),
#   datetime.datetime(2023, 2, 23, 0, 0),
#   datetime.datetime(2023, 3, 2, 0, 0),
#   datetime.datetime(2023, 3, 9, 0, 0),
#   datetime.datetime(2023, 3, 16, 0, 0),
#   datetime.datetime(2023, 3, 23, 0, 0),
#   datetime.datetime(2023, 3, 29, 0, 0),
#   datetime.datetime(2023, 3, 30, 0, 0),
#   datetime.datetime(2023, 4, 6, 0, 0),
#   datetime.datetime(2023, 4, 13, 0, 0),
#   datetime.datetime(2023, 4, 20, 0, 0),
#   datetime.datetime(2023, 4, 27, 0, 0),
#   datetime.datetime(2023, 5, 4, 0, 0),
#   datetime.datetime(2023, 5, 11, 0, 0),
#   datetime.datetime(2023, 5, 18, 0, 0),
#   datetime.datetime(2023, 5, 25, 0, 0),
#   datetime.datetime(2023, 6, 1, 0, 0),
#   datetime.datetime(2023, 6, 8, 0, 0),
#   datetime.datetime(2023, 6, 15, 0, 0),
#   datetime.datetime(2023, 6, 22, 0, 0),
#   datetime.datetime(2023, 6, 28, 0, 0),
#   datetime.datetime(2023, 6, 29, 0, 0),
#   datetime.datetime(2023, 7, 6, 0, 0),
#   datetime.datetime(2023, 7, 13, 0, 0),
#   datetime.datetime(2023, 7, 20, 0, 0),
#   datetime.datetime(2023, 7, 27, 0, 0),
#   datetime.datetime(2023, 8, 3, 0, 0),
#   datetime.datetime(2023, 8, 10, 0, 0),
#   datetime.datetime(2023, 8, 17, 0, 0),
#   datetime.datetime(2023, 8, 24, 0, 0),
#   datetime.datetime(2023, 8, 31, 0, 0),
#   datetime.datetime(2023, 9, 6, 0, 0),
#   datetime.datetime(2023, 9, 7, 0, 0),
#   datetime.datetime(2023, 9, 13, 0, 0),
#   datetime.datetime(2023, 9, 14, 0, 0),
#   datetime.datetime(2023, 9, 20, 0, 0),
#   datetime.datetime(2023, 9, 21, 0, 0),
#   datetime.datetime(2023, 9, 28, 0, 0),
#   datetime.datetime(2023, 10, 4, 0, 0),
#   datetime.datetime(2023, 10, 5, 0, 0),
#   datetime.datetime(2023, 10, 11, 0, 0),
#   datetime.datetime(2023, 10, 18, 0, 0),
#   datetime.datetime(2023, 10, 26, 0, 0),
#   datetime.datetime(2023, 11, 1, 0, 0),
#   datetime.datetime(2023, 11, 8, 0, 0),
#   datetime.datetime(2023, 11, 15, 0, 0),
#   datetime.datetime(2023, 11, 22, 0, 0),
#   datetime.datetime(2023, 11, 30, 0, 0),
#   datetime.datetime(2023, 12, 6, 0, 0),
#   datetime.datetime(2023, 12, 13, 0, 0),
#   datetime.datetime(2023, 12, 20, 0, 0),
#   datetime.datetime(2023, 12, 28, 0, 0),
#   datetime.datetime(2024, 1, 3, 0, 0),
#   datetime.datetime(2024, 1, 10, 0, 0),
#   datetime.datetime(2024, 1, 17, 0, 0),
#   datetime.datetime(2024, 1, 25, 0, 0),
#   datetime.datetime(2024, 1, 31, 0, 0),
#   datetime.datetime(2024, 2, 7, 0, 0),
#   datetime.datetime(2024, 2, 14, 0, 0),
#   datetime.datetime(2024, 2, 21, 0, 0),
#   datetime.datetime(2024, 2, 29, 0, 0),
#   datetime.datetime(2024, 3, 6, 0, 0),
#   datetime.datetime(2024, 3, 13, 0, 0),
#   datetime.datetime(2024, 3, 20, 0, 0),
#   datetime.datetime(2024, 3, 27, 0, 0),
#   datetime.datetime(2024, 3, 28, 0, 0),
#   datetime.datetime(2024, 4, 3, 0, 0),
#   datetime.datetime(2024, 4, 10, 0, 0),
#   datetime.datetime(2024, 4, 16, 0, 0),
#   datetime.datetime(2024, 4, 24, 0, 0),
#   datetime.datetime(2024, 4, 25, 0, 0),
#   datetime.datetime(2024, 4, 30, 0, 0),
#   datetime.datetime(2024, 5, 8, 0, 0),
#   datetime.datetime(2024, 5, 15, 0, 0),
#   datetime.datetime(2024, 5, 22, 0, 0),
#   datetime.datetime(2024, 5, 29, 0, 0),
#   datetime.datetime(2024, 6, 5, 0, 0),
#   datetime.datetime(2024, 6, 12, 0, 0),
#   datetime.datetime(2024, 6, 19, 0, 0),
#   datetime.datetime(2024, 6, 26, 0, 0),
#   datetime.datetime(2024, 6, 27, 0, 0),
#   datetime.datetime(2024, 7, 3, 0, 0),
#   datetime.datetime(2024, 7, 10, 0, 0),
#   datetime.datetime(2024, 7, 16, 0, 0),
#   datetime.datetime(2024, 7, 24, 0, 0),
#   datetime.datetime(2024, 7, 31, 0, 0),
#   datetime.datetime(2024, 8, 7, 0, 0),
#   datetime.datetime(2024, 8, 14, 0, 0),
#   datetime.datetime(2024, 8, 21, 0, 0),
#   datetime.datetime(2024, 8, 28, 0, 0),
#   datetime.datetime(2024, 9, 4, 0, 0),
#   datetime.datetime(2024, 9, 11, 0, 0),
#   datetime.datetime(2024, 9, 18, 0, 0),
#   datetime.datetime(2024, 9, 25, 0, 0),
#   datetime.datetime(2024, 9, 26, 0, 0),
#   datetime.datetime(2024, 10, 1, 0, 0),
#   datetime.datetime(2024, 10, 9, 0, 0),
#   datetime.datetime(2024, 10, 16, 0, 0),
#   datetime.datetime(2024, 10, 23, 0, 0),
#   datetime.datetime(2024, 10, 30, 0, 0),
#   datetime.datetime(2024, 11, 6, 0, 0),
#   datetime.datetime(2024, 11, 13, 0, 0),
#   datetime.datetime(2024, 11, 27, 0, 0),
#   datetime.datetime(2024, 12, 24, 0, 0),
#   datetime.datetime(2024, 12, 26, 0, 0),
#   datetime.datetime(2025, 1, 30, 0, 0),
#   datetime.datetime(2025, 2, 26, 0, 0),
#   datetime.datetime(2025, 2, 27, 0, 0),
#   datetime.datetime(2025, 3, 26, 0, 0),
#   datetime.datetime(2025, 3, 27, 0, 0),
#   datetime.datetime(2025, 4, 24, 0, 0),
#   datetime.datetime(2025, 5, 29, 0, 0),
#   datetime.datetime(2025, 6, 25, 0, 0),
#   datetime.datetime(2025, 6, 26, 0, 0),
#   datetime.datetime(2025, 9, 24, 0, 0),
#   datetime.datetime(2025, 9, 25, 0, 0),
#   datetime.datetime(2025, 12, 24, 0, 0)],
#  'finnifty': [datetime.datetime(2021, 1, 14, 0, 0),
#   datetime.datetime(2021, 1, 21, 0, 0),
#   datetime.datetime(2021, 1, 28, 0, 0),
#   datetime.datetime(2021, 2, 4, 0, 0),
#   datetime.datetime(2021, 2, 11, 0, 0),
#   datetime.datetime(2021, 2, 18, 0, 0),
#   datetime.datetime(2021, 2, 25, 0, 0),
#   datetime.datetime(2021, 3, 4, 0, 0),
#   datetime.datetime(2021, 3, 10, 0, 0),
#   datetime.datetime(2021, 3, 18, 0, 0),
#   datetime.datetime(2021, 3, 25, 0, 0),
#   datetime.datetime(2021, 4, 1, 0, 0),
#   datetime.datetime(2021, 4, 8, 0, 0),
#   datetime.datetime(2021, 4, 15, 0, 0),
#   datetime.datetime(2021, 4, 22, 0, 0),
#   datetime.datetime(2021, 4, 29, 0, 0),
#   datetime.datetime(2021, 5, 6, 0, 0),
#   datetime.datetime(2021, 5, 12, 0, 0),
#   datetime.datetime(2021, 5, 20, 0, 0),
#   datetime.datetime(2021, 5, 27, 0, 0),
#   datetime.datetime(2021, 6, 3, 0, 0),
#   datetime.datetime(2021, 6, 10, 0, 0),
#   datetime.datetime(2021, 6, 17, 0, 0),
#   datetime.datetime(2021, 6, 24, 0, 0),
#   datetime.datetime(2021, 7, 1, 0, 0),
#   datetime.datetime(2021, 7, 8, 0, 0),
#   datetime.datetime(2021, 7, 15, 0, 0),
#   datetime.datetime(2021, 7, 22, 0, 0),
#   datetime.datetime(2021, 7, 29, 0, 0),
#   datetime.datetime(2021, 8, 5, 0, 0),
#   datetime.datetime(2021, 8, 12, 0, 0),
#   datetime.datetime(2021, 8, 18, 0, 0),
#   datetime.datetime(2021, 8, 26, 0, 0),
#   datetime.datetime(2021, 9, 2, 0, 0),
#   datetime.datetime(2021, 9, 9, 0, 0),
#   datetime.datetime(2021, 9, 16, 0, 0),
#   datetime.datetime(2021, 9, 23, 0, 0),
#   datetime.datetime(2021, 9, 30, 0, 0),
#   datetime.datetime(2021, 10, 7, 0, 0),
#   datetime.datetime(2021, 10, 14, 0, 0),
#   datetime.datetime(2021, 10, 19, 0, 0),
#   datetime.datetime(2021, 10, 21, 0, 0),
#   datetime.datetime(2021, 10, 28, 0, 0),
#   datetime.datetime(2021, 11, 2, 0, 0),
#   datetime.datetime(2021, 11, 3, 0, 0),
#   datetime.datetime(2021, 11, 9, 0, 0),
#   datetime.datetime(2021, 11, 11, 0, 0),
#   datetime.datetime(2021, 11, 16, 0, 0),
#   datetime.datetime(2021, 11, 18, 0, 0),
#   datetime.datetime(2021, 11, 23, 0, 0),
#   datetime.datetime(2021, 11, 25, 0, 0),
#   datetime.datetime(2021, 12, 7, 0, 0),
#   datetime.datetime(2021, 12, 14, 0, 0),
#   datetime.datetime(2021, 12, 21, 0, 0),
#   datetime.datetime(2021, 12, 30, 0, 0),
#   datetime.datetime(2022, 1, 4, 0, 0),
#   datetime.datetime(2022, 1, 11, 0, 0),
#   datetime.datetime(2022, 1, 18, 0, 0),
#   datetime.datetime(2022, 1, 27, 0, 0),
#   datetime.datetime(2022, 2, 1, 0, 0),
#   datetime.datetime(2022, 2, 8, 0, 0),
#   datetime.datetime(2022, 2, 15, 0, 0),
#   datetime.datetime(2022, 2, 24, 0, 0),
#   datetime.datetime(2022, 2, 28, 0, 0),
#   datetime.datetime(2022, 3, 8, 0, 0),
#   datetime.datetime(2022, 3, 15, 0, 0),
#   datetime.datetime(2022, 3, 22, 0, 0),
#   datetime.datetime(2022, 3, 31, 0, 0),
#   datetime.datetime(2022, 4, 5, 0, 0),
#   datetime.datetime(2022, 4, 12, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   datetime.datetime(2022, 4, 28, 0, 0),
#   datetime.datetime(2022, 5, 2, 0, 0),
#   datetime.datetime(2022, 5, 10, 0, 0),
#   datetime.datetime(2022, 5, 17, 0, 0),
#   datetime.datetime(2022, 5, 24, 0, 0),
#   datetime.datetime(2022, 5, 26, 0, 0),
#   datetime.datetime(2022, 6, 7, 0, 0),
#   datetime.datetime(2022, 6, 14, 0, 0),
#   datetime.datetime(2022, 6, 21, 0, 0),
#   datetime.datetime(2022, 6, 30, 0, 0),
#   datetime.datetime(2022, 7, 5, 0, 0),
#   datetime.datetime(2022, 7, 12, 0, 0),
#   datetime.datetime(2022, 7, 19, 0, 0),
#   datetime.datetime(2022, 7, 28, 0, 0),
#   datetime.datetime(2022, 8, 2, 0, 0),
#   datetime.datetime(2022, 8, 8, 0, 0),
#   datetime.datetime(2022, 8, 16, 0, 0),
#   datetime.datetime(2022, 8, 23, 0, 0),
#   datetime.datetime(2022, 8, 25, 0, 0),
#   datetime.datetime(2022, 9, 6, 0, 0),
#   datetime.datetime(2022, 9, 13, 0, 0),
#   datetime.datetime(2022, 9, 20, 0, 0),
#   datetime.datetime(2022, 9, 29, 0, 0),
#   datetime.datetime(2022, 10, 4, 0, 0),
#   datetime.datetime(2022, 10, 11, 0, 0),
#   datetime.datetime(2022, 10, 18, 0, 0),
#   datetime.datetime(2022, 10, 25, 0, 0),
#   datetime.datetime(2022, 11, 1, 0, 0),
#   datetime.datetime(2022, 11, 7, 0, 0),
#   datetime.datetime(2022, 11, 15, 0, 0),
#   datetime.datetime(2022, 11, 22, 0, 0),
#   datetime.datetime(2022, 11, 29, 0, 0),
#   datetime.datetime(2022, 12, 6, 0, 0),
#   datetime.datetime(2022, 12, 13, 0, 0),
#   datetime.datetime(2022, 12, 20, 0, 0),
#   datetime.datetime(2022, 12, 27, 0, 0),
#   datetime.datetime(2023, 1, 3, 0, 0),
#   datetime.datetime(2023, 1, 10, 0, 0),
#   datetime.datetime(2023, 1, 17, 0, 0),
#   datetime.datetime(2023, 1, 24, 0, 0),
#   datetime.datetime(2023, 1, 31, 0, 0),
#   datetime.datetime(2023, 2, 7, 0, 0),
#   datetime.datetime(2023, 2, 14, 0, 0),
#   datetime.datetime(2023, 2, 21, 0, 0),
#   datetime.datetime(2023, 2, 28, 0, 0),
#   datetime.datetime(2023, 3, 6, 0, 0),
#   datetime.datetime(2023, 3, 14, 0, 0),
#   datetime.datetime(2023, 3, 21, 0, 0),
#   datetime.datetime(2023, 3, 28, 0, 0),
#   datetime.datetime(2023, 4, 3, 0, 0),
#   datetime.datetime(2023, 4, 11, 0, 0),
#   datetime.datetime(2023, 4, 18, 0, 0),
#   datetime.datetime(2023, 4, 25, 0, 0),
#   datetime.datetime(2023, 5, 2, 0, 0),
#   datetime.datetime(2023, 5, 9, 0, 0),
#   datetime.datetime(2023, 5, 16, 0, 0),
#   datetime.datetime(2023, 5, 23, 0, 0),
#   datetime.datetime(2023, 5, 30, 0, 0),
#   datetime.datetime(2023, 6, 6, 0, 0),
#   datetime.datetime(2023, 6, 13, 0, 0),
#   datetime.datetime(2023, 6, 20, 0, 0),
#   datetime.datetime(2023, 6, 27, 0, 0),
#   datetime.datetime(2023, 7, 4, 0, 0),
#   datetime.datetime(2023, 7, 11, 0, 0),
#   datetime.datetime(2023, 7, 18, 0, 0),
#   datetime.datetime(2023, 7, 25, 0, 0),
#   datetime.datetime(2023, 8, 1, 0, 0),
#   datetime.datetime(2023, 8, 8, 0, 0),
#   datetime.datetime(2023, 8, 14, 0, 0),
#   datetime.datetime(2023, 8, 22, 0, 0),
#   datetime.datetime(2023, 8, 29, 0, 0),
#   datetime.datetime(2023, 9, 5, 0, 0),
#   datetime.datetime(2023, 9, 12, 0, 0),
#   datetime.datetime(2023, 9, 18, 0, 0),
#   datetime.datetime(2023, 9, 26, 0, 0),
#   datetime.datetime(2023, 10, 3, 0, 0),
#   datetime.datetime(2023, 10, 10, 0, 0),
#   datetime.datetime(2023, 10, 17, 0, 0),
#   datetime.datetime(2023, 10, 23, 0, 0),
#   datetime.datetime(2023, 10, 31, 0, 0),
#   datetime.datetime(2023, 11, 7, 0, 0),
#   datetime.datetime(2023, 11, 13, 0, 0),
#   datetime.datetime(2023, 11, 21, 0, 0),
#   datetime.datetime(2023, 11, 28, 0, 0),
#   datetime.datetime(2023, 12, 5, 0, 0),
#   datetime.datetime(2023, 12, 12, 0, 0),
#   datetime.datetime(2023, 12, 19, 0, 0),
#   datetime.datetime(2023, 12, 26, 0, 0),
#   datetime.datetime(2024, 1, 2, 0, 0),
#   datetime.datetime(2024, 1, 9, 0, 0),
#   datetime.datetime(2024, 1, 16, 0, 0),
#   datetime.datetime(2024, 1, 23, 0, 0),
#   datetime.datetime(2024, 1, 30, 0, 0),
#   datetime.datetime(2024, 2, 6, 0, 0),
#   datetime.datetime(2024, 2, 13, 0, 0),
#   datetime.datetime(2024, 2, 20, 0, 0),
#   datetime.datetime(2024, 2, 27, 0, 0),
#   datetime.datetime(2024, 3, 5, 0, 0),
#   datetime.datetime(2024, 3, 12, 0, 0),
#   datetime.datetime(2024, 3, 19, 0, 0),
#   datetime.datetime(2024, 3, 26, 0, 0),
#   datetime.datetime(2024, 4, 2, 0, 0),
#   datetime.datetime(2024, 4, 9, 0, 0),
#   datetime.datetime(2024, 4, 16, 0, 0),
#   datetime.datetime(2024, 4, 23, 0, 0),
#   datetime.datetime(2024, 4, 30, 0, 0),
#   datetime.datetime(2024, 5, 7, 0, 0),
#   datetime.datetime(2024, 5, 14, 0, 0),
#   datetime.datetime(2024, 5, 21, 0, 0),
#   datetime.datetime(2024, 5, 28, 0, 0),
#   datetime.datetime(2024, 6, 4, 0, 0),
#   datetime.datetime(2024, 6, 11, 0, 0),
#   datetime.datetime(2024, 6, 18, 0, 0),
#   datetime.datetime(2024, 6, 25, 0, 0),
#   datetime.datetime(2024, 7, 2, 0, 0),
#   datetime.datetime(2024, 7, 9, 0, 0),
#   datetime.datetime(2024, 7, 16, 0, 0),
#   datetime.datetime(2024, 7, 23, 0, 0),
#   datetime.datetime(2024, 7, 30, 0, 0),
#   datetime.datetime(2024, 8, 6, 0, 0),
#   datetime.datetime(2024, 8, 13, 0, 0),
#   datetime.datetime(2024, 8, 20, 0, 0),
#   datetime.datetime(2024, 8, 27, 0, 0),
#   datetime.datetime(2024, 9, 3, 0, 0),
#   datetime.datetime(2024, 9, 10, 0, 0),
#   datetime.datetime(2024, 9, 17, 0, 0),
#   datetime.datetime(2024, 9, 24, 0, 0),
#   datetime.datetime(2024, 10, 1, 0, 0),
#   datetime.datetime(2024, 10, 8, 0, 0),
#   datetime.datetime(2024, 10, 15, 0, 0),
#   datetime.datetime(2024, 10, 22, 0, 0),
#   datetime.datetime(2024, 10, 29, 0, 0),
#   datetime.datetime(2024, 11, 5, 0, 0),
#   datetime.datetime(2024, 11, 12, 0, 0),
#   datetime.datetime(2024, 11, 19, 0, 0),
#   datetime.datetime(2024, 11, 26, 0, 0),
#   datetime.datetime(2024, 12, 31, 0, 0),
#   datetime.datetime(2025, 1, 28, 0, 0),
#   datetime.datetime(2025, 1, 30, 0, 0),
#   datetime.datetime(2025, 2, 25, 0, 0),
#   datetime.datetime(2025, 2, 27, 0, 0),
#   datetime.datetime(2025, 3, 27, 0, 0),
#   datetime.datetime(2025, 4, 24, 0, 0)],
#  'sensex': [datetime.datetime(2023, 9, 1, 0, 0),
#   datetime.datetime(2023, 9, 8, 0, 0),
#   datetime.datetime(2023, 9, 15, 0, 0),
#   datetime.datetime(2023, 9, 22, 0, 0),
#   datetime.datetime(2023, 9, 29, 0, 0),
#   datetime.datetime(2023, 10, 6, 0, 0),
#   datetime.datetime(2023, 10, 13, 0, 0),
#   datetime.datetime(2023, 10, 20, 0, 0),
#   datetime.datetime(2023, 10, 27, 0, 0),
#   datetime.datetime(2023, 11, 3, 0, 0),
#   datetime.datetime(2023, 11, 10, 0, 0),
#   datetime.datetime(2023, 11, 17, 0, 0),
#   datetime.datetime(2023, 11, 24, 0, 0),
#   datetime.datetime(2023, 12, 1, 0, 0),
#   datetime.datetime(2023, 12, 8, 0, 0),
#   datetime.datetime(2023, 12, 15, 0, 0),
#   datetime.datetime(2023, 12, 22, 0, 0),
#   datetime.datetime(2023, 12, 29, 0, 0),
#   datetime.datetime(2024, 1, 5, 0, 0),
#   datetime.datetime(2024, 1, 12, 0, 0),
#   datetime.datetime(2024, 1, 19, 0, 0),
#   datetime.datetime(2024, 1, 25, 0, 0),
#   datetime.datetime(2024, 2, 2, 0, 0),
#   datetime.datetime(2024, 2, 9, 0, 0),
#   datetime.datetime(2024, 2, 16, 0, 0),
#   datetime.datetime(2024, 2, 23, 0, 0),
#   datetime.datetime(2024, 3, 1, 0, 0),
#   datetime.datetime(2024, 3, 7, 0, 0),
#   datetime.datetime(2024, 3, 15, 0, 0),
#   datetime.datetime(2024, 3, 22, 0, 0),
#   datetime.datetime(2024, 3, 28, 0, 0),
#   datetime.datetime(2024, 4, 5, 0, 0),
#   datetime.datetime(2024, 4, 12, 0, 0),
#   datetime.datetime(2024, 4, 19, 0, 0),
#   datetime.datetime(2024, 4, 26, 0, 0),
#   datetime.datetime(2024, 5, 3, 0, 0),
#   datetime.datetime(2024, 5, 10, 0, 0),
#   datetime.datetime(2024, 5, 17, 0, 0),
#   datetime.datetime(2024, 5, 24, 0, 0),
#   datetime.datetime(2024, 5, 31, 0, 0),
#   datetime.datetime(2024, 6, 7, 0, 0),
#   datetime.datetime(2024, 6, 14, 0, 0),
#   datetime.datetime(2024, 6, 21, 0, 0),
#   datetime.datetime(2024, 6, 28, 0, 0),
#   datetime.datetime(2024, 7, 5, 0, 0),
#   datetime.datetime(2024, 7, 12, 0, 0),
#   datetime.datetime(2024, 7, 19, 0, 0),
#   datetime.datetime(2024, 7, 26, 0, 0),
#   datetime.datetime(2024, 8, 2, 0, 0),
#   datetime.datetime(2024, 8, 9, 0, 0),
#   datetime.datetime(2024, 8, 16, 0, 0),
#   datetime.datetime(2024, 8, 23, 0, 0),
#   datetime.datetime(2024, 8, 30, 0, 0),
#   datetime.datetime(2024, 9, 6, 0, 0),
#   datetime.datetime(2024, 9, 13, 0, 0),
#   datetime.datetime(2024, 9, 20, 0, 0),
#   datetime.datetime(2024, 9, 27, 0, 0),
#   datetime.datetime(2024, 10, 4, 0, 0),
#   datetime.datetime(2024, 10, 11, 0, 0),
#   datetime.datetime(2024, 10, 18, 0, 0),
#   datetime.datetime(2024, 10, 25, 0, 0),
#   datetime.datetime(2024, 10, 31, 0, 0),
#   datetime.datetime(2024, 11, 1, 0, 0),
#   datetime.datetime(2024, 11, 8, 0, 0),
#   datetime.datetime(2024, 11, 14, 0, 0),
#   datetime.datetime(2024, 11, 22, 0, 0),
#   datetime.datetime(2024, 11, 29, 0, 0),
#   datetime.datetime(2024, 12, 6, 0, 0),
#   datetime.datetime(2024, 12, 13, 0, 0),
#   datetime.datetime(2024, 12, 20, 0, 0),
#   datetime.datetime(2024, 12, 27, 0, 0),
#   datetime.datetime(2025, 1, 3, 0, 0),
#   datetime.datetime(2025, 1, 7, 0, 0),
#   datetime.datetime(2025, 1, 10, 0, 0),
#   datetime.datetime(2025, 1, 14, 0, 0),
#   datetime.datetime(2025, 1, 17, 0, 0),
#   datetime.datetime(2025, 1, 21, 0, 0),
#   datetime.datetime(2025, 1, 28, 0, 0),
#   datetime.datetime(2025, 1, 31, 0, 0),
#   datetime.datetime(2025, 2, 4, 0, 0),
#   datetime.datetime(2025, 2, 7, 0, 0),
#   datetime.datetime(2025, 2, 11, 0, 0),
#   datetime.datetime(2025, 2, 18, 0, 0),
#   datetime.datetime(2025, 2, 25, 0, 0),
#   datetime.datetime(2025, 3, 4, 0, 0),
#   datetime.datetime(2025, 3, 11, 0, 0),
#   datetime.datetime(2025, 3, 18, 0, 0),
#   datetime.datetime(2025, 3, 25, 0, 0),
#   datetime.datetime(2025, 3, 28, 0, 0),
#   datetime.datetime(2025, 4, 1, 0, 0),
#   datetime.datetime(2025, 4, 8, 0, 0),
#   datetime.datetime(2025, 4, 15, 0, 0),
#   datetime.datetime(2025, 4, 29, 0, 0),
#   datetime.datetime(2025, 6, 24, 0, 0)]}

# %%
from datetime import date
from bisect import bisect_left

def get_next_expiry(input_date, index_symbol):
    expiries = dict_expiries.get(index_symbol)
    if not expiries:
        return None
        
    expiry_dates = sorted({dt.date() for dt in expiries})
    pos = bisect_left(expiry_dates, input_date)
    return expiry_dates[pos] if pos < len(expiry_dates) else None

# %%
index_ = 'nifty'

if index_ == 'nifty':
    LOT_SIZE_ = 75
    STRIKE_SPREAD_ = 50
    INDEX_LEVERAGE_ = 8
    PORTFOLIO_ = 1_00_00_000

# %%
import pandas as pd

async def add_atr(df, period=14):
    """
    Adds an 'ATR' column to the DataFrame using Wilder's smoothing (like TradingView).
    
    Parameters:
    df (pd.DataFrame): Must contain 'h', 'l', 'c' columns for high, low, close
    period (int): ATR period (default 14)
    
    Returns:
    pd.DataFrame: With 'ATR' column added
    """
    high = df['h']
    low = df['l']
    close = df['c']

    # True Range
    tr1 = high - low
    tr2 = (high - close.shift()).abs()
    tr3 = (low - close.shift()).abs()
    tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)

    # ATR with Wilder's smoothing (like an EMA with alpha=1/period)
    atr = tr.ewm(alpha=1/period, adjust=False).mean()

    df['ATR'] = atr
    return df

# %%
async def send_trade(spot_price, entry_timestamp, expiry, direction, atr, tf, offset, dte, tradebook, trade_num):
    if direction == 1:
        opt_type = 'P'
        side = 'LONG'
    elif direction == -1:
        opt_type = "C"
        side = 'SHORT'
    else:
        return tradebook

    current_date = entry_timestamp.date()
    current_time = entry_timestamp.time()

    strike = int(round(spot_price / STRIKE_SPREAD_) * STRIKE_SPREAD_)

    option_df = await fetch_data(
        index=index_,
        expiry=expiry,
        strike=strike,
        asset_class=opt_type,
        start_date=current_date,
        start_time=entry_timestamp.time(),
        end_date=current_date,
        end_time=dt.time(15, 30),
    )

    if option_df is not None and not isinstance(option_df, str):
        option_df = resample(option_df, tf, offset)
        option_df_pandas = option_df.to_pandas()
        entry_price = option_df_pandas.iloc[0]['c']
    else:
        entry_price = float('nan')

    # print(f'{entry_timestamp} : {side} TRADE Entered ! ')

    trade = {
        'date': current_date,
        # 'high level': high_level,
        # 'low level': low_level,
        # 'atr_multiplier': multiplier,
        'Morning ATR': atr,
        'side': side,
        'strike': strike,
        'type': opt_type,
        'expiry': expiry,
        'dte': dte,
        'entry_time': current_time,
        'entry price': entry_price,
        'trade_num': trade_num,
    }
        
    tradebook.append(trade)
    return tradebook

async def take_exit(strike, opt_type, expiry, exit_timestamp, tf, offset, tradebook, trade_num):

    current_date = exit_timestamp.date()
    current_time = exit_timestamp.time()

    strike = int(round(strike / STRIKE_SPREAD_) * STRIKE_SPREAD_)

    if opt_type == 'P':
        side = 'LONG'
    elif opt_type == 'C':
        side = 'SHORT'
    else:
        side = 'None'

    for trade in tradebook:
        if (
            trade['type'] == opt_type and
            trade['date'] == current_date and
            'exit_time' not in trade
        ):
            option_df = await fetch_data(
                index=index_,
                expiry=expiry,
                strike=strike,
                asset_class=opt_type,
                start_date=current_date,
                start_time=current_time,
                end_date=current_date,
                end_time=dt.time(15, 30),
            )
            # print(option_df)
            if option_df is not None and not isinstance(option_df, str):
                option_df = resample(option_df, tf, offset)
                option_df_pandas = option_df.to_pandas()
                exit_price = option_df_pandas.iloc[0]['c']
                # print(f'{side} Trade Exited')
            else:
                exit_price = float('nan')

            if current_time > dt.time(15, 20):
                remark = 'EOD Exit'
            else:
                remark = 'TSL Hit'

            # print(f'{exit_timestamp} : {side} {remark}')

            if option_df is not None and not isinstance(option_df, str):
                trade['exit price'] = exit_price
                trade['exit_time'] = option_df_pandas['datetime'].iloc[0] if len(option_df_pandas) != 0 else float('nan')
                trade['remarks'] = remark
                # trade['high level at exit'] = high_level
                # trade['low level at exit'] = low_level
                trade['points'] = trade['entry price'] - trade['exit price']
            else:
                trade['exit price'] = float('nan')
                trade['exit_time'] = float('nan')
                trade['remarks'] = remark
                # trade['high level at exit'] = high_level
                # trade['low level at exit'] = low_level
                trade['points'] = trade['entry price'] - trade['exit price']

    return tradebook

# %%
async def backtest_intraday_levels2(df, multiplier, tf, offset):
    df['datetime'] = pd.to_datetime(df['datetime'])
    # df = df[df['datetime'].dt.year >= 2025]
    df['date'] = df['datetime'].dt.date
    # print(df.head().to_string())
    
    tradebook = []

    eod_time = dt.time(15, 20)
    no_more_trade_time = dt.time(14, 0)

    for date, group in df.groupby('date'):
        current_date = date
        group = group.reset_index(drop=True)
        # print(date)
        # Get 9:15 candle
        morning_candle = group[group['datetime'].dt.time == pd.to_datetime("09:15").time()]
        if morning_candle.empty:
            continue

        morning_atr = morning_candle.iloc[0]['ATR']
        running_high = group.iloc[0]['h'] # Initialising
        running_low = group.iloc[0]['l'] # Initialising

        is_high_breached = False
        is_low_breached = False

        in_trade_long = False
        in_trade_short = False

        data_fetched_pe = False
        data_fetched_ce = False

        trade_num = 1
        max_trades = 25

        for i in range(0, len(group)):
            row = group.iloc[i]
            previous_row = group.iloc[i-1]
            running_high = max(running_high, row['h'])
            running_low = min(running_low, row['l'])
            
            current_datetime = row['datetime']
            
            high_level = running_low + (multiplier * morning_atr)
            low_level = running_high - (multiplier * morning_atr)
            
            long_tsl = low_level
            short_tsl = high_level
            
            # print(row)
            # print(group.iloc[i]['datetime'], high_level, low_level, row['c'])
            # print(f'RH : {running_high} , RL : {running_low}')

            # high_strike = int(round(high_level / STRIKE_SPREAD_) * STRIKE_SPREAD_)
            # low_strike = int(round(low_level / STRIKE_SPREAD_) * STRIKE_SPREAD_)

            expiry = get_next_expiry(date, index_)
            dte = (expiry - current_date).days            

            if not in_trade_long and not in_trade_short and current_datetime.time() < no_more_trade_time:
                if row['c'] >= high_level and trade_num <= max_trades:
                    tradebook = await send_trade(high_level, current_datetime, expiry, 1, morning_atr, tf, offset, dte, tradebook, trade_num)
                    trade_num += 1
                    # is_high_breached = True
                    in_trade_long = True
                    long_tsl = low_level

            if in_trade_long:
                if row['c'] <= long_tsl:
                    # TSL Hit
                    tradebook = await take_exit(high_level, 'P', expiry, current_datetime, tf, offset, tradebook, trade_num)
                    in_trade_long = False
                    # is_high_breached = False

                    # Send Short Trade
                    running_low = row['l']
                    # print(f'Running Low changed to {running_low}')
                    high_level = running_low + (multiplier * morning_atr)
                    # print(f'High Level changed to {high_level}')
                    if trade_num <= max_trades and current_datetime.time() <= no_more_trade_time:
                        tradebook = await send_trade(long_tsl, current_datetime, expiry, -1, morning_atr, tf, offset, dte, tradebook, trade_num)
                        trade_num += 1
                        long_tsl = float('inf')
                        short_tsl = high_level
                        in_trade_short = True
                        # is_low_breached = True
                    else:
                        continue
                    
                elif current_datetime.time() >= eod_time:
                    # EOD Exit
                    tradebook = await take_exit(high_level, 'P', expiry, current_datetime, tf, offset, tradebook, trade_num)
    
                    in_trade_long = False
                    # is_high_breached = False
                    long_tsl = float('inf')

            if not in_trade_short and not in_trade_long and current_datetime.time() < no_more_trade_time:
                if row['c'] <= low_level and trade_num <= max_trades:
                    tradebook = await send_trade(low_level, current_datetime, expiry, -1, morning_atr, tf, offset, dte, tradebook, trade_num)
                    trade_num += 1
                    
                    # is_low_breached = True
                    in_trade_short = True

            if in_trade_short:
                if row['c'] >= short_tsl:
                    # TSL Hit
                    tradebook = await take_exit(low_level, 'C', expiry, current_datetime, tf, offset, tradebook, trade_num)
                    
                    in_trade_short = False
                    # is_low_breached = False

                    # Send Long Trade
                    running_high = row['h']
                    # print(f'Running High changed to {running_high}')
                    low_level = running_high - (multiplier * morning_atr)
                    # print(f'Low Level changed to {low_level}')
                    if trade_num <= max_trades and current_datetime.time() <= no_more_trade_time:
                        tradebook = await send_trade(short_tsl, current_datetime, expiry, 1, morning_atr, tf, offset, dte, tradebook, trade_num)
                        trade_num += 1
                        short_tsl = float('-inf')
                        long_tsl = low_level
                        in_trade_long = True
                        # is_high_breached = True
                    else:
                        continue

                elif current_datetime.time() >= eod_time:
                    # EOD Exit
                    tradebook = await take_exit(low_level, 'C', expiry, current_datetime, tf, offset, tradebook, trade_num)

                    in_trade_short = False
                    # is_low_breached = False
                    short_tsl = float('-inf')

    tb = pd.DataFrame(tradebook)
    if len(tb) > 0:
        tb['exit_time'] = pd.to_datetime(tb['exit_time'])
        tb['slippage'] = 0.01 * (tb['entry price'] + tb['exit price'])
        tb['final_points'] = tb['points'] - tb['slippage']
        tb['portfolio'] = PORTFOLIO_
        tb['index leverage'] = np.where(tb['type'] == 'C', 8, 8)
        tb['qty'] = tb['portfolio'] * tb['index leverage'] / tb['strike']
        tb['pnl'] = tb['final_points'] * tb['qty']
        tb['ROI%'] = tb['pnl'] * 100 / tb['portfolio']
        tb['Trade Year'] = tb['exit_time'].dt.year
        # tb = tb[tb['entry_time'] != tb['exit_time']]

    return tb

# %%
TF_ = '10m'
OFFSET_ = '5m'
ATR_WINDOW_ = 14
MULTIPLIER_ = 2
bnf_df = resample(pl.DataFrame(bnf_1min), TF_, OFFSET_)
bnf_df_pandas = bnf_df.to_pandas()
bnf_df_pandas = await add_atr(bnf_df_pandas, ATR_WINDOW_)
tb = await backtest_intraday_levels2(bnf_df_pandas, MULTIPLIER_, TF_, OFFSET_)
# tb
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[17], line 8
#       6 bnf_df_pandas = bnf_df.to_pandas()
#       7 bnf_df_pandas = await add_atr(bnf_df_pandas, ATR_WINDOW_)
# ----> 8 tb = await backtest_intraday_levels2(bnf_df_pandas, MULTIPLIER_, TF_, OFFSET_)
#       9 # tb
#
# Cell In[16], line 71, in backtest_intraday_levels2(df, multiplier, tf, offset)
#      68 if in_trade_long:
#      69     if row['c'] <= long_tsl:
#      70         # TSL Hit
# ---> 71         tradebook = await take_exit(high_level, 'P', expiry, current_datetime, tf, offset, tradebook, trade_num)
#      72         in_trade_long = False
#      73         # is_high_breached = False
#      74
#      75         # Send Short Trade
#
# Cell In[15], line 75, in take_exit(strike, opt_type, expiry, exit_timestamp, tf, offset, tradebook, trade_num)
#      69 for trade in tradebook:
#      70     if (
#      71         trade['type'] == opt_type and
#      72         trade['date'] == current_date and
#      73         'exit_time' not in trade
#      74     ):
# ---> 75         option_df = await fetch_data(
#      76             index=index_,
#      77             expiry=expiry,
#      78             strike=strike,
#      79             asset_class=opt_type,
#      80             start_date=current_date,
#      81             start_time=current_time,
#      82             end_date=current_date,
#      83             end_time=dt.time(15, 30),
#      84         )
#      85         # print(option_df)
#      86         if option_df is not None and not isinstance(option_df, str):
#
# File ~/strategies/droplets/ATR-Intraday_JJMS/../fetching_from_local_db/fetch_from_db.py:97, in fetch_data(index, start_date, end_date, start_time, end_time, expiry, strike, asset_class, ffill)
#      93         batches.append((batch_start_date, batch_end_date))
#      95     batch_start_date = batch_end_date + dt.timedelta(days=1)
# ---> 97 results = await asyncio.gather(
#      98     *(
#      99         _fetch_batch(
#     100             index=index,
#     101             start_date=batch_start,
#     102             end_date=batch_end,
#     103             start_time=start_time,
#     104             end_time=end_time,
#     105             expiry=expiry,
#     106             strike=strike,
#     107             asset_class=asset_class,
#     108         )
#     109         for batch_start, batch_end in batches
#     110     )
#     111 )
#     113 if results:
#     114     all_documents = [doc for batch in results if batch for doc in batch if doc]
#
# File ~/strategies/droplets/ATR-Intraday_JJMS/../fetching_from_local_db/fetch_from_db.py:42, in _fetch_batch(index, start_date, end_date, start_time, end_time, expiry, strike, asset_class)
#      39 documents = []
#      41 if asset_class and expiry:
# ---> 42     async for document in options_collection.find(
#      43         {
#      44             "index": index,
#      45             "datetime": {
#      46                 "$gte": dt.datetime.combine(start_date, start_time),
#      47                 "$lte": dt.datetime.combine(end_date, end_time),
#      48             },
#      49             "expiry": dt.datetime.combine(expiry, dt.time(0, 0)),
#      50             "strike": strike,
#      51             "asset_class": asset_class,
#      52         }
#      53     ):
#      54         documents.append(document)
#      55 else:
#
# File ~/strategies/droplets/.venv/lib/python3.12/site-packages/motor/core.py:1425, in AgnosticBaseCursor.next(self)
#    1420 async def next(self):
#    1421     """Advance the cursor.
#    1422
#    1423     .. versionadded:: 2.2
#    1424     """
# -> 1425     if self.alive and (self._buffer_size() or await self._get_more()):
#    1426         return next(self.delegate)
#    1427     raise StopAsyncIteration
#
# CancelledError:

# %%
tb[tb['Trade Year'] >= 2025]
# Out:
#             date  Morning ATR   side  strike type      expiry  dte entry_time  \
# 3905  2025-01-01      35.1421  SHORT   23600    C  2025-01-02    1   09:35:00
# 3906  2025-01-01      35.1421   LONG   23650    P  2025-01-02    1   10:25:00
# 4047  142661.2613  1.4266   2025.0000
# 4048   36237.1041  0.3624   2025.0000
# 4049   -8769.1610 -0.0877   2025.0000
# 4050  125529.5711  1.2553   2025.0000
# 4051  -87511.4094 -0.8751   2025.0000
# 4052  -15523.9374 -0.1552   2025.0000
# 4053   64164.2857  0.6416   2025.0000
# 4054   34491.4798  0.3449   2025.0000
# 4055  -32812.5000 -0.3281   2025.0000
# 4056  135060.7143  1.3506   2025.0000
# 4057 -101908.6475 -1.0191   2025.0000
# 4058  -84108.4444 -0.8411   2025.0000
# 4059  -30807.9823 -0.3081   2025.0000
# 4060 -121472.2838 -1.2147   2025.0000
# 4061  -56838.9381 -0.5684   2025.0000
# 4062   66270.5100  0.6627   2025.0000
# 4063  212515.0442  2.1252   2025.0000
# 4064  179012.5000  1.7901   2025.0000
# 4065  142759.1111  1.4276   2025.0000
# 4066  125328.5714  1.2533   2025.0000
# 4067 -123354.6667 -1.2335   2025.0000
# 4068 -157534.3681 -1.5753   2025.0000
# 4069   78492.4444  0.7849   2025.0000
# 4070  -23255.3571 -0.2326   2025.0000
# 4071  -36567.1111 -0.3657   2025.0000
# 4072    6460.4444  0.0646   2025.0000
# 4073   32261.3687  0.3226   2025.0000
# 4074 -164548.0176 -1.6455   2025.0000
# 4075   95351.2088  0.9535   2025.0000
# 4076  -70228.4464 -0.7023   2025.0000
# 4077   90086.6521  0.9009   2025.0000
# 4078  -99632.1041 -0.9963   2025.0000
# 4079  -82932.1739 -0.8293   2025.0000
# 4080  158908.4599  1.5891   2025.0000
# 4081  136089.6552  1.3609   2025.0000
# 4082   31158.8865  0.3116   2025.0000
# 4083   45409.8501  0.4541   2025.0000
# 4084  142437.4468  1.4244   2025.0000
# 4085 -101473.4177 -1.0147   2025.0000
# 4086   23205.0526  0.2321   2025.0000
# 4087  -95031.9328 -0.9503   2025.0000
# 4088    6968.0672  0.0697   2025.0000
# 4089  119693.4737  1.1969   2025.0000
# 4090    8794.9367  0.0879   2025.0000
# 4091   74752.7426  0.7475   2025.0000
# 4092  254335.7294  2.5434   2025.0000
# 4093  204733.6170  2.0473   2025.0000
# 4094 -142061.9958 -1.4206   2025.0000
# 4095  -58019.5329 -0.5802   2025.0000
# 4096  206796.6102  2.0680   2025.0000
# 4097   36796.5957  0.3680   2025.0000
# 4098    5966.8790  0.0597   2025.0000

# %%
tb['ROI%'].sum()
# Out:
# 727.47490839846

# %%
stats = generate_stats(tb, 'ATR Dynamic')
for x, y in stats.items():
    z = pd.DataFrame(y)
    break

z
# Out:
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2019     114.3771          609  50.7389                1.1762
# 2020     251.0527          625  54.0800                1.9879
# 2021      94.2552          656  50.3049                1.2235
# 2022     134.4618          595  52.9412                1.3034
# 2023      21.3142          640  47.1875                0.8364
# 2024      80.8750          724  47.6519                1.0843
# 2025      31.1388          193  58.0311                0.9362
# Overall  727.4749         4042  50.0366                1.2585
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio    Variation
# 2019                -0.8303      -9.1377      12.5170  ATR Dynamic
# 2020                -1.4664     -23.4149      10.7219  ATR Dynamic
# 2021                -0.9494     -24.0505       3.9191  ATR Dynamic
# 2022                -0.9861     -20.9244       6.4261  ATR Dynamic
# 2023                -0.6842     -18.4602       1.1546  ATR Dynamic
# 2024                -0.7736     -24.8346       3.2565  ATR Dynamic
# 2025                -0.9100      -9.0518       3.4401  ATR Dynamic
# Overall             -0.9311     -24.8346      29.2928  ATR Dynamic

# %%
stats = generate_stats(tb, 'ATR Dynamic')
for x, y in stats.items():
    z = pd.DataFrame(y)
    break

z
# Out:
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2019     114.3771          609  50.7389                1.1762
# 2020     251.0527          625  54.0800                1.9879
# 2021      94.2552          656  50.3049                1.2235
# 2022     134.4618          595  52.9412                1.3034
# 2023      21.3142          640  47.1875                0.8364
# 2024      80.8750          724  47.6519                1.0843
# 2025      31.1388          193  58.0311                0.9362
# Overall  727.4749         4042  50.0366                1.2585
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio    Variation
# 2019                -0.8303      -9.1377      12.5170  ATR Dynamic
# 2020                -1.4664     -23.4149      10.7219  ATR Dynamic
# 2021                -0.9494     -24.0505       3.9191  ATR Dynamic
# 2022                -0.9861     -20.9244       6.4261  ATR Dynamic
# 2023                -0.6842     -18.4602       1.1546  ATR Dynamic
# 2024                -0.7736     -24.8346       3.2565  ATR Dynamic
# 2025                -0.9100      -9.0518       3.4401  ATR Dynamic
# Overall             -0.9311     -24.8346      29.2928  ATR Dynamic

# %%
# tb.to_csv('ATR_Dynamic_JJMS_10m_14_2.csv', index=False)

# %%
# tb = tb_with_hedge
tb['Cumulative ROI%'] = tb['ROI%'].cumsum()
tb['Max Cumulative ROI%'] = tb['Cumulative ROI%'].cummax()  # Maximum value so far
tb['DD'] = tb['Cumulative ROI%'] - tb['Max Cumulative ROI%']  # Drawdown
tb.tail()
# Out:
#             date  Morning ATR   side  strike type      expiry  dte entry_time  \
# 4094  2025-03-28      29.4007  SHORT   23550    C  2025-04-03    6   09:15:00
# 4095  2025-03-28      29.4007   LONG   23550    P  2025-04-03    6   10:25:00
# 4096  2025-03-28      29.4007  SHORT   23600    C  2025-04-03    6   11:05:00
# 4097  2025-03-28      29.4007   LONG   23500    P  2025-04-03    6   14:15:00
# 4098  2025-03-28      29.4007  SHORT   23550    C  2025-04-03    6   14:55:00
#
#       entry price  trade_num  exit price           exit_time   remarks  \
# 4094     189.6500          1    227.3000 2025-03-28 10:25:00   TSL Hit
# 4095      93.9500          2    109.0000 2025-03-28 11:05:00   TSL Hit
# 4096     156.5000          3     93.0000 2025-03-28 14:15:00   TSL Hit
# 4097     111.0000          4     98.1000 2025-03-28 14:55:00   TSL Hit
# 4098     116.7000          5    112.6500 2025-03-28 15:25:00  EOD Exit
#
#        points  slippage  final_points  portfolio  index leverage       qty  \
# 4094 -37.6500    4.1695      -41.8195   10000000               8 3397.0276
# 4095 -15.0500    2.0295      -17.0795   10000000               8 3397.0276
# 4096  63.5000    2.4950       61.0050   10000000               8 3389.8305
# 4097  12.9000    2.0910       10.8090   10000000               8 3404.2553
# 4098   4.0500    2.2935        1.7565   10000000               8 3397.0276
#
#               pnl    ROI%  Trade Year  Cumulative ROI%  Max Cumulative ROI%  \
# 4094 -142061.9958 -1.4206   2025.0000         725.5595             726.9801
# 4095  -58019.5329 -0.5802   2025.0000         724.9793             726.9801
# 4096  206796.6102  2.0680   2025.0000         727.0473             727.0473
# 4097   36796.5957  0.3680   2025.0000         727.4152             727.4152
# 4098    5966.8790  0.0597   2025.0000         727.4749             727.4749
#
#           DD
# 4094 -1.4206
# 4095 -2.0008
# 4096  0.0000
# 4097  0.0000
# 4098  0.0000

# %%
import pandas as pd

def calculate_dte_stats(df):

    # print(df.columns)
    if 'dte' not in df.columns or 'ROI%' not in df.columns or 'DD' not in df.columns:
        raise ValueError("DataFrame must contain 'DTE', 'returns', and 'drawdown' columns.")
    
    # Group by DTE and calculate required stats
    grouped_stats = df.groupby('dte').agg(
        returns_sum=('ROI%', 'sum'),
        max_drawdown=('DD', 'min'),  # Assuming 'drawdown' contains negative values
        total_trades=('dte', 'count')
    ).reset_index()
    
    # Calculate ratio of returns sum to max drawdown
    grouped_stats['returns_to_max_dd_ratio'] = (
        grouped_stats['returns_sum'] / grouped_stats['max_drawdown'].abs()
    )

    return grouped_stats

# %%
import pandas as pd

def calculate_opt_type_stats(df):

    # print(df.columns)
    if 'type' not in df.columns or 'ROI%' not in df.columns or 'DD' not in df.columns:
        raise ValueError("DataFrame must contain 'DTE', 'returns', and 'drawdown' columns.")
    
    # Group by DTE and calculate required stats
    grouped_stats = df.groupby('type').agg(
        returns_sum=('ROI%', 'sum'),
        max_drawdown=('DD', 'min'),  # Assuming 'drawdown' contains negative values
        total_trades=('type', 'count')
    ).reset_index()
    
    # Calculate ratio of returns sum to max drawdown
    grouped_stats['returns_to_max_dd_ratio'] = (
        grouped_stats['returns_sum'] / grouped_stats['max_drawdown'].abs()
    )

    return grouped_stats

# %%
import pandas as pd

def calculate_trade_num_stats(df):

    # print(df.columns)
    if 'trade_num' not in df.columns or 'ROI%' not in df.columns or 'DD' not in df.columns:
        raise ValueError("DataFrame must contain 'DTE', 'returns', and 'drawdown' columns.")
    
    # Group by DTE and calculate required stats
    grouped_stats = df.groupby('trade_num').agg(
        returns_sum=('ROI%', 'sum'),
        max_drawdown=('DD', 'min'),  # Assuming 'drawdown' contains negative values
        total_trades=('trade_num', 'count')
    ).reset_index()
    
    # Calculate ratio of returns sum to max drawdown
    grouped_stats['returns_to_max_dd_ratio'] = (
        grouped_stats['returns_sum'] / grouped_stats['max_drawdown'].abs()
    )

    return grouped_stats

# %%
stats_dte = calculate_dte_stats(tb)
stats_dte
# Out:
#     dte  returns_sum  max_drawdown  total_trades  returns_to_max_dd_ratio
# 0     0     221.2153      -24.0773           831                   9.1877
# 1     1     134.4954      -24.8346           829                   5.4156
# 2     2     172.9882      -24.3747           825                   7.0970
# 3     3     120.7567      -24.2252           673                   4.9848
# 4     5      -1.6365      -13.5432            56                  -0.1208
# 5     6      81.2986      -24.0505           827                   3.3803
# 6     7       0.2466       -3.8501             8                   0.0640
# 7     8       0.9229       -5.3265             4                   0.1733
# 8     9       0.2689       -3.3174             4                   0.0811
# 9    10       0.9790       -3.5864             2                   0.2730
# 10   13      -1.0365       -5.7007             7                  -0.1818
# 11   14       1.7052       -4.1560             3                   0.4103
# 12   15      -1.8688       -5.2340             4                  -0.3570
# 13   16       1.4449       -3.3653             1                   0.4294
# 14   17       0.2338       -4.8687             2                   0.0480
# 15   20       0.8059       -5.0439             2                   0.1598
# 16   21      -0.0605       -5.8499             1                  -0.0103
# 17   22       0.2374       -8.7425             4                   0.0272
# 18   23      -3.6865       -6.0267             4                  -0.6117
# 19   24      -0.0504       -2.3403             1                  -0.0215
# 20   27      -1.1152       -2.7970             4                  -0.3987
# 21   28      -0.9961       -4.5111             3                  -0.2208
# 22   29       0.6340       -1.4558             3                   0.4355
# 23   30      -0.3074        0.0000             1                     -inf

# %%
stats_opt_type = calculate_opt_type_stats(tb)
stats_opt_type
# Out:
#   type  returns_sum  max_drawdown  total_trades  returns_to_max_dd_ratio
# 0    C     279.0507      -24.7315          1993                  11.2832
# 1    P     448.4243      -24.8346          2106                  18.0564

# %%
stats_trade_num = calculate_trade_num_stats(tb)
stats_trade_num
# Out:
#     trade_num  returns_sum  max_drawdown  total_trades  \
# 0           1     313.9153      -24.3747          1505
# 1           2     177.4682      -24.1137          1155
# 2           3     152.2019      -24.8346           755
# 3           4      20.3934      -24.7315           391
# 4           5      41.4301      -23.2589           156
# 5           6       3.6560      -24.1415            68
# 6           7       9.4540      -24.1267            31
# 7           8       9.2791      -17.3485            21
# 8           9      -1.7207       -8.6490             9
# 9          10      -0.2452       -6.0677             5
# 10         11       1.8637       -4.0024             2
# 11         12      -0.2210       -1.4073             1
#
#     returns_to_max_dd_ratio
# 0                   12.8787
# 1                    7.3596
# 2                    6.1286
# 3                    0.8246
# 4                    1.7813
# 5                    0.1514
# 6                    0.3918
# 7                    0.5349
# 8                   -0.1989
# 9                   -0.0404
# 10                   0.4656
# 11                  -0.1570

# %%
# SIMULATION

TF_ = ['10m']
ATR_WINDOW_ = [11, 12, 13, 14, 15, 16, 17]
MULTIPLIER_ = [1.5, 1.75, 2, 2.25, 2.5]

for i in TF_:
    for j in ATR_WINDOW_:
        for k in MULTIPLIER_:
            if i == '10m':
                z = '5m'
            else:
                z = '0m'
            variation = f'TF: {i}, ATR: {j}, MULT: {k}'
            print(variation)
            bnf_df = resample(pl.DataFrame(bnf_1min), i, z)
            bnf_df_pandas = bnf_df.to_pandas()
            bnf_df_pandas = await add_atr(bnf_df_pandas, j)
            tb = await backtest_intraday_levels2(bnf_df_pandas, k, i, z)

            if len(tb) > 0:
                stats = generate_stats(tb, variation)
                for x, y in stats.items():
                    if x > 18:
                        q = pd.DataFrame(y)
                        print(q.to_string())
# Out:
# TF: 10m, ATR: 11, MULT: 1.5
#         Total ROI Total Trades Win Rate Avg Profit% per Trade Avg Loss% per Trade Max Drawdown ROI/DD Ratio                    Variation
# 2019     173.9766          848  51.8868                1.0011             -0.6532      -8.5355      20.3828  TF: 10m, ATR: 11, MULT: 1.5
# 2020     249.4165          879  50.9670                1.7134             -1.2023     -34.6099       7.2065  TF: 10m, ATR: 11, MULT: 1.5
# 2021     110.8479          949  47.3130                1.0935             -0.7603     -13.2280       8.3798  TF: 10m, ATR: 11, MULT: 1.5
# 2022      97.0716          855  50.1754                1.0551             -0.8347     -16.6586       5.8271  TF: 10m, ATR: 11, MULT: 1.5
