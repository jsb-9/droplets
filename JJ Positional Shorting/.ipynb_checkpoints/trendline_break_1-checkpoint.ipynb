# %%
import asyncio
import datetime as dt
import math
from typing import Literal

import matplotlib.pyplot as plt
import mplfinance as mpf

import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

# %%
import sys

sys.path.append("..")
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
async def get_expiry(f_today, index):

    if index == 'bnf':    
        if (f_today <= dt.date(2024, 1, 25)) and (f_today >= dt.date(2024, 1, 18)):
            f_expiry = dt.date(2024, 1, 25)
        elif (f_today <= dt.date(2024, 1, 31)) and (f_today >= dt.date(2024, 1, 26)):
            f_expiry = dt.date(2024, 1, 31)
        elif (f_today <= dt.date(2024, 2, 22)) and (f_today >= dt.date(2024, 2, 29)):
            f_expiry = dt.date(2024, 2, 29)
        elif (f_today <= dt.date(2024, 3, 25)) and (f_today >= dt.date(2024, 3, 27)):
            f_expiry = dt.date(2024, 2, 27)
        elif f_today < dt.date(2023, 9, 1):
            days_to_thursday = (3 - f_today.weekday()) % 7
            nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
            f_expiry = nearest_thursday
            if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
                f_expiry = nearest_thursday - dt.timedelta(days=1)
        elif f_today >= dt.date(2023, 9, 1):
            if f_today.day < 24:
                days_to_wednesday = (2 - f_today.weekday()) % 7
                nearest_wednesday = f_today + dt.timedelta(days=days_to_wednesday)
                f_expiry = nearest_wednesday
                if nse.valid_days(
                    start_date=nearest_wednesday, end_date=nearest_wednesday
                ).empty:
                    f_expiry = nearest_wednesday - dt.timedelta(days=1)
            else:
                days_to_thursday = (3 - f_today.weekday()) % 7
                nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
                f_expiry = nearest_thursday
                if nse.valid_days(
                    start_date=nearest_thursday, end_date=nearest_thursday
                ).empty:
                    f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'nifty':
        days_to_thursday = (3 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'finnifty' or index == 'fnf':
        days_to_thursday = (1 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'midcpnifty' or index == 'midcp':
        days_to_thursday = (0 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

async def get_expiry_nifty(f_today):

    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry


async def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"


def get_option_contract_name2(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"

# %%
bnf_1min = pd.read_csv("../data/bnf_wave.csv")
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["time"])
bnf_1min = bnf_1min[bnf_1min["datetime"].dt.year >= 2017]

# %%
bnf_1min.tail()
# Out:
#                             time       open       high        low      close  \
# 22214  2024-12-05T11:45:00+05:30 53037.0000 53507.1000 52998.8500 53484.5000
# 22215  2024-12-05T12:15:00+05:30 53475.8000 53647.8000 53472.6500 53521.0500
# 22216  2024-12-05T12:45:00+05:30 53523.2500 53621.1000 53452.6500 53609.9500
# 22217  2024-12-05T13:15:00+05:30 53614.8000 53642.3500 53461.3500 53598.9000
# 22218  2024-12-05T13:45:00+05:30 53599.7500 53640.9000 53560.0000 53564.1500
#
#               MA     Plot  Zero line  MACD Signal                  datetime
# 22214 53167.1400 204.1806          0     204.1806 2024-12-05 11:45:00+05:30
# 22215 53191.2367 270.8858          0     270.8858 2024-12-05 12:15:00+05:30
# 22216 53230.6600 327.7843          0     327.7843 2024-12-05 12:45:00+05:30
# 22217 53269.0200 351.5606          0     351.5606 2024-12-05 13:15:00+05:30
# 22218 53299.1367 348.2676          0     348.2676 2024-12-05 13:45:00+05:30

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("open").first().alias("open"),
                pl.col("high").max().alias("high"),
                pl.col("low").min().alias("low"),
                pl.col("close").last().alias("close"),
                pl.col("volume").sum().alias("volume"),
            ]
        )
    )


# ohlc_resampled = resample(pl.DataFrame(bnf_1min), '7d', pd.Timedelta(days=4))
# ohlc_resampled

# %%
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["datetime"])
list_of_traded_dates = set(bnf_1min["datetime"].dt.date)
list_of_traded_dates
# Out:
# {datetime.date(2020, 10, 29),
#  datetime.date(2020, 9, 7),
#  datetime.date(2019, 9, 27),
#  datetime.date(2022, 10, 27),
#  datetime.date(2020, 2, 13),
#  datetime.date(2024, 11, 22),
#  datetime.date(2023, 1, 30),
#  datetime.date(2020, 8, 21),
#  datetime.date(2023, 9, 20),
#  datetime.date(2020, 10, 30),
#  datetime.date(2022, 1, 20),
#  datetime.date(2018, 4, 17),
#  datetime.date(2024, 3, 2),
#  datetime.date(2021, 2, 19),
#  datetime.date(2022, 4, 5),
#  datetime.date(2018, 1, 8),
#  datetime.date(2022, 3, 9),
#  datetime.date(2023, 1, 5),
#  datetime.date(2023, 1, 9),
#  datetime.date(2019, 11, 13),
#  datetime.date(2024, 2, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2019, 6, 13),
#  datetime.date(2022, 6, 29),
#  datetime.date(2021, 5, 3),
#  datetime.date(2019, 8, 22),
#  datetime.date(2023, 11, 23),
#  datetime.date(2020, 2, 24),
#  datetime.date(2024, 3, 21),
#  datetime.date(2024, 9, 19),
#  datetime.date(2023, 6, 7),
#  datetime.date(2022, 3, 28),
#  datetime.date(2018, 4, 6),
#  datetime.date(2021, 2, 22),
#  datetime.date(2024, 10, 23),
#  datetime.date(2018, 4, 16),
#  datetime.date(2021, 5, 25),
#  datetime.date(2020, 12, 9),
#  datetime.date(2024, 3, 13),
#  datetime.date(2020, 11, 6),
#  datetime.date(2022, 9, 1),
#  datetime.date(2022, 6, 16),
#  datetime.date(2024, 4, 29),
#  datetime.date(2020, 4, 20),
#  datetime.date(2022, 11, 14),
#  datetime.date(2019, 3, 1),
#  datetime.date(2018, 2, 28),
#  datetime.date(2024, 4, 26),
#  datetime.date(2018, 4, 30),
#  datetime.date(2024, 11, 14),
#  datetime.date(2022, 8, 18),
#  datetime.date(2018, 6, 27),
#  datetime.date(2024, 1, 2),
#  datetime.date(2024, 6, 14),
#  datetime.date(2024, 7, 24),
#  datetime.date(2022, 5, 25),
#  datetime.date(2020, 7, 23),
#  datetime.date(2024, 12, 5),
#  datetime.date(2018, 2, 27),
#  datetime.date(2021, 8, 2),
#  datetime.date(2021, 3, 2),
#  datetime.date(2018, 12, 13),
#  datetime.date(2019, 1, 21),
#  datetime.date(2022, 10, 14),
#  datetime.date(2022, 2, 3),
#  datetime.date(2021, 7, 1),
#  datetime.date(2023, 9, 13),
#  datetime.date(2022, 9, 5),
#  datetime.date(2023, 8, 10),
#  datetime.date(2022, 1, 14),
#  datetime.date(2023, 8, 29),
#  datetime.date(2020, 7, 13),
#  datetime.date(2019, 5, 7),
#  datetime.date(2021, 7, 16),
#  datetime.date(2020, 7, 10),
#  datetime.date(2024, 6, 11),
#  datetime.date(2023, 2, 2),
#  datetime.date(2020, 10, 5),
#  datetime.date(2024, 7, 31),
#  datetime.date(2021, 3, 31),
#  datetime.date(2024, 7, 18),
#  datetime.date(2023, 2, 21),
#  datetime.date(2021, 5, 4),
#  datetime.date(2021, 1, 29),
#  datetime.date(2024, 3, 27),
#  datetime.date(2022, 5, 23),
#  datetime.date(2019, 6, 12),
#  datetime.date(2024, 3, 20),
#  datetime.date(2022, 11, 3),
#  datetime.date(2024, 6, 28),
#  datetime.date(2024, 9, 6),
#  datetime.date(2019, 3, 15),
#  datetime.date(2024, 2, 1),
#  datetime.date(2022, 8, 8),
#  datetime.date(2022, 7, 7),
#  datetime.date(2021, 12, 3),
#  datetime.date(2018, 2, 6),
#  datetime.date(2019, 11, 29),
#  datetime.date(2020, 5, 15),
#  datetime.date(2020, 12, 15),
#  datetime.date(2024, 2, 8),
#  datetime.date(2022, 12, 6),
#  datetime.date(2022, 3, 14),
#  datetime.date(2023, 5, 30),
#  datetime.date(2023, 8, 4),
#  datetime.date(2019, 5, 28),
#  datetime.date(2023, 9, 28),
#  datetime.date(2019, 5, 9),
#  datetime.date(2019, 10, 24),
#  datetime.date(2020, 8, 12),
#  datetime.date(2023, 5, 31),
#  datetime.date(2018, 8, 24),
#  datetime.date(2019, 2, 21),
#  datetime.date(2019, 3, 22),
#  datetime.date(2024, 4, 5),
#  datetime.date(2018, 11, 21),
#  datetime.date(2023, 8, 23),
#  datetime.date(2022, 2, 7),
#  datetime.date(2022, 6, 28),
#  datetime.date(2024, 3, 1),
#  datetime.date(2024, 7, 23),
#  datetime.date(2019, 7, 5),
#  datetime.date(2022, 11, 29),
#  datetime.date(2021, 5, 14),
#  datetime.date(2022, 7, 28),
#  datetime.date(2022, 8, 29),
#  datetime.date(2022, 10, 10),
#  datetime.date(2023, 4, 13),
#  datetime.date(2022, 5, 13),
#  datetime.date(2023, 9, 26),
#  datetime.date(2020, 3, 27),
#  datetime.date(2021, 11, 16),
#  datetime.date(2018, 12, 11),
#  datetime.date(2024, 3, 14),
#  datetime.date(2024, 5, 21),
#  datetime.date(2019, 5, 14),
#  datetime.date(2023, 8, 3),
#  datetime.date(2020, 9, 21),
#  datetime.date(2021, 1, 7),
#  datetime.date(2021, 9, 7),
#  datetime.date(2019, 1, 23),
#  datetime.date(2020, 3, 3),
#  datetime.date(2020, 5, 5),
#  datetime.date(2021, 12, 22),
#  datetime.date(2020, 1, 7),
#  datetime.date(2020, 10, 1),
#  datetime.date(2024, 10, 17),
#  datetime.date(2021, 10, 14),
#  datetime.date(2021, 10, 28),
#  datetime.date(2021, 10, 21),
#  datetime.date(2023, 9, 21),
#  datetime.date(2024, 6, 24),
#  datetime.date(2024, 7, 5),
#  datetime.date(2022, 2, 23),
#  datetime.date(2022, 8, 26),
#  datetime.date(2019, 8, 13),
#  datetime.date(2019, 7, 16),
#  datetime.date(2022, 8, 10),
#  datetime.date(2022, 8, 17),
#  datetime.date(2021, 8, 27),
#  datetime.date(2020, 8, 25),
#  datetime.date(2020, 2, 17),
#  datetime.date(2020, 2, 11),
#  datetime.date(2022, 8, 24),
#  datetime.date(2024, 5, 16),
#  datetime.date(2018, 2, 15),
#  datetime.date(2022, 11, 7),
#  datetime.date(2021, 9, 13),
#  datetime.date(2019, 9, 4),
#  datetime.date(2020, 11, 4),
#  datetime.date(2022, 1, 25),
#  datetime.date(2022, 2, 10),
#  datetime.date(2023, 6, 21),
#  datetime.date(2022, 2, 28),
#  datetime.date(2024, 11, 29),
#  datetime.date(2023, 5, 24),
#  datetime.date(2021, 4, 12),
#  datetime.date(2020, 1, 27),
#  datetime.date(2022, 5, 31),
#  datetime.date(2023, 6, 20),
#  datetime.date(2019, 10, 3),
#  datetime.date(2023, 4, 20),
#  datetime.date(2020, 6, 5),
#  datetime.date(2024, 4, 1),
#  datetime.date(2021, 4, 26),
#  datetime.date(2022, 10, 6),
#  datetime.date(2021, 7, 12),
#  datetime.date(2024, 5, 3),
#  datetime.date(2020, 4, 29),
#  datetime.date(2021, 7, 26),
#  datetime.date(2020, 10, 13),
#  datetime.date(2023, 1, 17),
#  datetime.date(2022, 7, 19),
#  datetime.date(2019, 5, 21),
#  datetime.date(2023, 8, 14),
#  datetime.date(2022, 1, 21),
#  datetime.date(2024, 1, 17),
#  datetime.date(2022, 7, 22),
#  datetime.date(2021, 3, 23),
#  datetime.date(2018, 5, 22),
#  datetime.date(2021, 8, 10),
#  datetime.date(2018, 11, 16),
#  datetime.date(2018, 10, 24),
#  datetime.date(2023, 1, 3),
#  datetime.date(2022, 3, 3),
#  datetime.date(2018, 10, 22),
#  datetime.date(2023, 9, 6),
#  datetime.date(2021, 1, 20),
#  datetime.date(2024, 2, 15),
#  datetime.date(2024, 7, 8),
#  datetime.date(2018, 12, 6),
#  datetime.date(2022, 11, 22),
#  datetime.date(2020, 12, 17),
#  datetime.date(2022, 9, 16),
#  datetime.date(2019, 8, 23),
#  datetime.date(2021, 3, 25),
#  datetime.date(2018, 5, 15),
#  datetime.date(2020, 4, 17),
#  datetime.date(2022, 10, 18),
#  datetime.date(2023, 8, 31),
#  datetime.date(2018, 12, 26),
#  datetime.date(2020, 12, 10),
#  datetime.date(2020, 10, 28),
#  datetime.date(2022, 7, 5),
#  datetime.date(2019, 1, 25),
#  datetime.date(2021, 3, 9),
#  datetime.date(2019, 12, 2),
#  datetime.date(2021, 1, 5),
#  datetime.date(2022, 9, 7),
#  datetime.date(2022, 2, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2024, 11, 7),
#  datetime.date(2021, 11, 23),
#  datetime.date(2023, 7, 14),
#  datetime.date(2019, 10, 29),
#  datetime.date(2021, 3, 16),
#  datetime.date(2024, 10, 18),
#  datetime.date(2019, 6, 25),
#  datetime.date(2023, 7, 10),
#  datetime.date(2018, 3, 20),
#  datetime.date(2023, 3, 31),
#  datetime.date(2023, 4, 18),
#  datetime.date(2022, 11, 25),
#  datetime.date(2023, 8, 1),
#  datetime.date(2024, 2, 2),
#  datetime.date(2024, 9, 11),
#  datetime.date(2021, 1, 13),
#  datetime.date(2019, 9, 25),
#  datetime.date(2024, 5, 31),
#  datetime.date(2019, 5, 23),
#  datetime.date(2020, 2, 5),
#  datetime.date(2018, 11, 28),
#  datetime.date(2020, 9, 17),
#  datetime.date(2022, 6, 21),
#  datetime.date(2024, 6, 21),
#  datetime.date(2024, 8, 19),
#  datetime.date(2023, 10, 4),
#  datetime.date(2020, 10, 16),
#  datetime.date(2023, 6, 28),
#  datetime.date(2018, 6, 15),
#  datetime.date(2022, 12, 19),
#  datetime.date(2022, 3, 30),
#  datetime.date(2020, 12, 28),
#  datetime.date(2024, 3, 5),
#  datetime.date(2020, 1, 6),
#  datetime.date(2022, 9, 29),
#  datetime.date(2018, 12, 3),
#  datetime.date(2021, 12, 30),
#  datetime.date(2018, 6, 29),
#  datetime.date(2023, 6, 16),
#  datetime.date(2018, 5, 8),
#  datetime.date(2020, 11, 14),
#  datetime.date(2022, 12, 28),
#  datetime.date(2024, 2, 14),
#  datetime.date(2021, 11, 12),
#  datetime.date(2018, 8, 7),
#  datetime.date(2024, 8, 12),
#  datetime.date(2019, 1, 8),
#  datetime.date(2023, 10, 27),
#  datetime.date(2024, 8, 14),
#  datetime.date(2020, 2, 12),
#  datetime.date(2023, 4, 19),
#  datetime.date(2021, 3, 22),
#  datetime.date(2020, 8, 19),
#  datetime.date(2022, 3, 15),
#  datetime.date(2020, 3, 20),
#  datetime.date(2022, 4, 27),
#  datetime.date(2019, 9, 24),
#  datetime.date(2020, 11, 26),
#  datetime.date(2021, 10, 29),
#  datetime.date(2020, 1, 9),
#  datetime.date(2024, 6, 3),
#  datetime.date(2024, 1, 29),
#  datetime.date(2023, 1, 27),
#  datetime.date(2021, 7, 6),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 6, 18),
#  datetime.date(2022, 2, 22),
#  datetime.date(2020, 6, 30),
#  datetime.date(2023, 12, 29),
#  datetime.date(2019, 2, 27),
#  datetime.date(2021, 12, 17),
#  datetime.date(2023, 12, 7),
#  datetime.date(2019, 8, 26),
#  datetime.date(2019, 3, 14),
#  datetime.date(2022, 8, 22),
#  datetime.date(2018, 12, 28),
#  datetime.date(2024, 1, 19),
#  datetime.date(2020, 4, 15),
#  datetime.date(2019, 7, 17),
#  datetime.date(2018, 9, 6),
#  datetime.date(2019, 7, 26),
#  datetime.date(2022, 3, 11),
#  datetime.date(2019, 12, 20),
#  datetime.date(2020, 9, 8),
#  datetime.date(2020, 1, 13),
#  datetime.date(2019, 7, 25),
#  datetime.date(2018, 2, 20),
#  datetime.date(2018, 5, 18),
#  datetime.date(2019, 6, 18),
#  datetime.date(2022, 9, 30),
#  datetime.date(2022, 4, 29),
#  datetime.date(2023, 11, 15),
#  datetime.date(2020, 8, 4),
#  datetime.date(2023, 7, 11),
#  datetime.date(2018, 5, 3),
#  datetime.date(2024, 8, 20),
#  datetime.date(2019, 6, 24),
#  datetime.date(2019, 6, 14),
#  datetime.date(2019, 6, 10),
#  datetime.date(2019, 11, 11),
#  datetime.date(2020, 8, 11),
#  datetime.date(2023, 1, 13),
#  datetime.date(2023, 3, 15),
#  datetime.date(2024, 3, 26),
#  datetime.date(2024, 2, 5),
#  datetime.date(2021, 4, 27),
#  datetime.date(2018, 7, 3),
#  datetime.date(2020, 11, 9),
#  datetime.date(2019, 3, 27),
#  datetime.date(2018, 4, 2),
#  datetime.date(2018, 11, 30),
#  datetime.date(2023, 12, 19),
#  datetime.date(2019, 11, 19),
#  datetime.date(2020, 12, 8),
#  datetime.date(2022, 9, 26),
#  datetime.date(2024, 10, 15),
#  datetime.date(2022, 4, 11),
#  datetime.date(2020, 5, 19),
#  datetime.date(2019, 11, 4),
#  datetime.date(2019, 1, 30),
#  datetime.date(2022, 1, 31),
#  datetime.date(2020, 1, 8),
#  datetime.date(2024, 4, 12),
#  datetime.date(2019, 3, 20),
#  datetime.date(2021, 12, 2),
#  datetime.date(2021, 1, 25),
#  datetime.date(2020, 4, 27),
#  datetime.date(2020, 6, 2),
#  datetime.date(2018, 12, 10),
#  datetime.date(2023, 10, 3),
#  datetime.date(2022, 5, 2),
#  datetime.date(2018, 12, 24),
#  datetime.date(2022, 4, 13),
#  datetime.date(2021, 4, 29),
#  datetime.date(2018, 7, 20),
#  datetime.date(2020, 2, 26),
#  datetime.date(2022, 8, 30),
#  datetime.date(2019, 3, 19),
#  datetime.date(2019, 12, 16),
#  datetime.date(2023, 7, 24),
#  datetime.date(2021, 1, 14),
#  datetime.date(2024, 4, 15),
#  datetime.date(2020, 11, 27),
#  datetime.date(2019, 10, 27),
#  datetime.date(2022, 2, 1),
#  datetime.date(2019, 3, 18),
#  datetime.date(2023, 10, 26),
#  datetime.date(2021, 6, 28),
#  datetime.date(2021, 10, 8),
#  datetime.date(2024, 2, 28),
#  datetime.date(2023, 5, 17),
#  datetime.date(2024, 1, 24),
#  datetime.date(2023, 5, 4),
#  datetime.date(2022, 6, 10),
#  datetime.date(2021, 8, 24),
#  datetime.date(2021, 3, 8),
#  datetime.date(2020, 12, 16),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 12),
#  datetime.date(2019, 1, 22),
#  datetime.date(2023, 7, 27),
#  datetime.date(2021, 11, 4),
#  datetime.date(2022, 10, 12),
#  datetime.date(2021, 2, 25),
#  datetime.date(2018, 11, 12),
#  datetime.date(2023, 1, 25),
#  datetime.date(2024, 9, 25),
#  datetime.date(2022, 12, 2),
#  datetime.date(2018, 7, 13),
#  datetime.date(2023, 3, 13),
#  datetime.date(2022, 8, 1),
#  datetime.date(2024, 11, 28),
#  datetime.date(2018, 12, 18),
#  datetime.date(2018, 10, 30),
#  datetime.date(2021, 5, 10),
#  datetime.date(2018, 8, 17),
#  datetime.date(2021, 5, 20),
#  datetime.date(2023, 11, 28),
#  datetime.date(2021, 5, 31),
#  datetime.date(2022, 5, 5),
#  datetime.date(2024, 2, 27),
#  datetime.date(2023, 11, 22),
#  datetime.date(2024, 2, 26),
#  datetime.date(2023, 4, 5),
#  datetime.date(2022, 12, 27),
#  datetime.date(2021, 8, 11),
#  datetime.date(2018, 10, 12),
#  datetime.date(2020, 8, 13),
#  datetime.date(2024, 11, 25),
#  datetime.date(2021, 4, 16),
#  datetime.date(2019, 7, 11),
#  datetime.date(2019, 2, 4),
#  datetime.date(2018, 8, 27),
#  datetime.date(2023, 8, 8),
#  datetime.date(2024, 1, 25),
#  datetime.date(2018, 1, 29),
#  datetime.date(2018, 3, 15),
#  datetime.date(2022, 6, 7),
#  datetime.date(2024, 7, 25),
#  datetime.date(2022, 8, 19),
#  datetime.date(2023, 3, 10),
#  datetime.date(2021, 1, 18),
#  datetime.date(2019, 8, 7),
#  datetime.date(2023, 3, 23),
#  datetime.date(2019, 4, 15),
#  datetime.date(2020, 2, 28),
#  datetime.date(2020, 8, 7),
#  datetime.date(2023, 10, 30),
#  datetime.date(2018, 6, 14),
#  datetime.date(2018, 2, 23),
#  datetime.date(2019, 8, 8),
#  datetime.date(2022, 1, 13),
#  datetime.date(2023, 8, 2),
#  datetime.date(2018, 4, 23),
#  datetime.date(2018, 7, 2),
#  datetime.date(2020, 10, 27),
#  datetime.date(2018, 1, 25),
#  datetime.date(2024, 5, 7),
#  datetime.date(2020, 5, 8),
#  datetime.date(2018, 8, 28),
#  datetime.date(2019, 12, 17),
#  datetime.date(2023, 2, 28),
#  datetime.date(2023, 11, 12),
#  datetime.date(2019, 12, 23),
#  datetime.date(2020, 7, 3),
#  datetime.date(2019, 10, 9),
#  datetime.date(2021, 12, 13),
#  datetime.date(2024, 2, 6),
#  datetime.date(2020, 7, 30),
#  datetime.date(2020, 12, 3),
#  datetime.date(2018, 12, 4),
#  datetime.date(2020, 10, 19),
#  datetime.date(2020, 6, 18),
#  datetime.date(2021, 7, 9),
#  datetime.date(2023, 3, 16),
#  datetime.date(2022, 12, 8),
#  datetime.date(2020, 6, 24),
#  datetime.date(2024, 8, 6),
#  datetime.date(2020, 6, 1),
#  datetime.date(2019, 6, 7),
#  datetime.date(2023, 2, 3),
#  datetime.date(2019, 4, 2),
#  datetime.date(2019, 10, 10),
#  datetime.date(2019, 6, 17),
#  datetime.date(2024, 4, 4),
#  datetime.date(2024, 5, 17),
#  datetime.date(2018, 5, 29),
#  datetime.date(2020, 10, 8),
#  datetime.date(2019, 9, 20),
#  datetime.date(2021, 3, 1),
#  datetime.date(2021, 2, 1),
#  datetime.date(2024, 11, 11),
#  datetime.date(2019, 5, 10),
#  datetime.date(2018, 1, 15),
#  datetime.date(2020, 1, 24),
#  datetime.date(2021, 6, 2),
#  datetime.date(2021, 8, 4),
#  datetime.date(2018, 5, 30),
#  datetime.date(2019, 5, 15),
#  datetime.date(2021, 10, 20),
#  datetime.date(2023, 9, 8),
#  datetime.date(2021, 4, 23),
#  datetime.date(2022, 11, 30),
#  datetime.date(2020, 11, 2),
#  datetime.date(2021, 5, 11),
#  datetime.date(2018, 11, 6),
#  datetime.date(2024, 7, 9),
#  datetime.date(2020, 5, 20),
#  datetime.date(2019, 2, 13),
#  datetime.date(2018, 9, 7),
#  datetime.date(2019, 11, 8),
#  datetime.date(2023, 6, 5),
#  datetime.date(2022, 12, 23),
#  datetime.date(2021, 6, 7),
#  datetime.date(2020, 10, 15),
#  datetime.date(2020, 2, 3),
#  datetime.date(2023, 5, 26),
#  datetime.date(2023, 12, 12),
#  datetime.date(2024, 5, 22),
#  datetime.date(2020, 3, 11),
#  datetime.date(2022, 6, 17),
#  datetime.date(2023, 5, 23),
#  datetime.date(2023, 8, 16),
#  datetime.date(2019, 4, 8),
#  datetime.date(2020, 3, 18),
#  datetime.date(2021, 7, 15),
#  datetime.date(2023, 7, 25),
#  datetime.date(2022, 9, 27),
#  datetime.date(2022, 1, 18),
#  datetime.date(2024, 11, 19),
#  datetime.date(2024, 2, 29),
#  datetime.date(2024, 6, 19),
#  datetime.date(2018, 8, 31),
#  datetime.date(2019, 9, 9),
#  datetime.date(2023, 11, 10),
#  datetime.date(2019, 1, 29),
#  datetime.date(2022, 5, 20),
#  datetime.date(2020, 7, 6),
#  datetime.date(2024, 1, 4),
#  datetime.date(2018, 8, 10),
#  datetime.date(2019, 8, 30),
#  datetime.date(2023, 1, 12),
#  datetime.date(2019, 10, 14),
#  datetime.date(2019, 1, 9),
#  datetime.date(2018, 6, 26),
#  datetime.date(2019, 5, 3),
#  datetime.date(2022, 7, 21),
#  datetime.date(2020, 2, 27),
#  datetime.date(2018, 7, 10),
#  datetime.date(2020, 5, 22),
#  datetime.date(2023, 1, 24),
#  datetime.date(2020, 11, 25),
#  datetime.date(2020, 9, 3),
#  datetime.date(2020, 7, 16),
#  datetime.date(2018, 10, 11),
#  datetime.date(2018, 4, 20),
#  datetime.date(2019, 5, 6),
#  datetime.date(2023, 11, 29),
#  datetime.date(2018, 9, 27),
#  datetime.date(2021, 9, 14),
#  datetime.date(2021, 9, 21),
#  datetime.date(2023, 6, 23),
#  datetime.date(2019, 7, 10),
#  datetime.date(2022, 6, 2),
#  datetime.date(2024, 2, 21),
#  datetime.date(2019, 9, 12),
#  datetime.date(2022, 5, 18),
#  datetime.date(2019, 1, 3),
#  datetime.date(2019, 12, 27),
#  datetime.date(2022, 8, 5),
#  datetime.date(2023, 6, 13),
#  datetime.date(2019, 4, 22),
#  datetime.date(2023, 6, 26),
#  datetime.date(2018, 8, 1),
#  datetime.date(2018, 1, 9),
#  datetime.date(2019, 9, 5),
#  datetime.date(2022, 6, 8),
#  datetime.date(2023, 1, 23),
#  datetime.date(2022, 8, 2),
#  datetime.date(2022, 12, 20),
#  datetime.date(2023, 6, 15),
#  datetime.date(2023, 1, 18),
#  datetime.date(2024, 3, 12),
#  datetime.date(2022, 4, 28),
#  datetime.date(2020, 3, 12),
#  datetime.date(2022, 12, 30),
#  datetime.date(2024, 10, 25),
#  datetime.date(2022, 8, 4),
#  datetime.date(2018, 9, 25),
#  datetime.date(2020, 7, 1),
#  datetime.date(2024, 1, 15),
#  datetime.date(2023, 9, 22),
#  datetime.date(2023, 10, 23),
#  datetime.date(2024, 10, 22),
#  datetime.date(2024, 4, 19),
#  datetime.date(2023, 3, 8),
#  datetime.date(2018, 3, 13),
#  datetime.date(2020, 5, 13),
#  datetime.date(2021, 8, 25),
#  datetime.date(2018, 7, 5),
#  datetime.date(2020, 8, 5),
#  datetime.date(2023, 5, 16),
#  datetime.date(2019, 2, 12),
#  datetime.date(2024, 5, 13),
#  datetime.date(2019, 12, 9),
#  datetime.date(2024, 7, 4),
#  datetime.date(2023, 7, 26),
#  datetime.date(2019, 3, 12),
#  datetime.date(2024, 4, 22),
#  datetime.date(2018, 3, 16),
#  datetime.date(2021, 4, 28),
#  datetime.date(2022, 4, 25),
#  datetime.date(2020, 1, 16),
#  datetime.date(2021, 7, 5),
#  datetime.date(2020, 1, 1),
#  datetime.date(2023, 4, 25),
#  datetime.date(2018, 5, 24),
#  datetime.date(2018, 10, 16),
#  datetime.date(2024, 8, 23),
#  datetime.date(2023, 3, 24),
#  datetime.date(2019, 3, 11),
#  datetime.date(2021, 7, 22),
#  datetime.date(2024, 1, 18),
#  datetime.date(2021, 1, 21),
#  datetime.date(2019, 6, 27),
#  datetime.date(2020, 2, 14),
#  datetime.date(2018, 7, 24),
#  datetime.date(2024, 8, 5),
#  datetime.date(2022, 4, 18),
#  datetime.date(2018, 6, 13),
#  datetime.date(2021, 3, 5),
#  datetime.date(2024, 3, 4),
#  datetime.date(2020, 7, 24),
#  datetime.date(2024, 1, 1),
#  datetime.date(2021, 3, 24),
#  datetime.date(2018, 5, 28),
#  datetime.date(2023, 11, 6),
#  datetime.date(2022, 7, 13),
#  datetime.date(2020, 5, 21),
#  datetime.date(2022, 10, 3),
#  datetime.date(2019, 4, 5),
#  datetime.date(2021, 9, 9),
#  datetime.date(2020, 3, 24),
#  datetime.date(2020, 8, 10),
#  datetime.date(2021, 7, 8),
#  datetime.date(2019, 9, 16),
#  datetime.date(2024, 3, 6),
#  datetime.date(2022, 4, 26),
#  datetime.date(2022, 11, 1),
#  datetime.date(2022, 5, 10),
#  datetime.date(2021, 5, 27),
#  datetime.date(2019, 7, 15),
#  datetime.date(2023, 1, 19),
#  datetime.date(2024, 9, 3),
#  datetime.date(2024, 8, 16),
#  datetime.date(2023, 12, 21),
#  datetime.date(2024, 7, 3),
#  datetime.date(2023, 10, 19),
#  datetime.date(2019, 7, 24),
#  datetime.date(2023, 9, 18),
#  datetime.date(2018, 8, 2),
#  datetime.date(2020, 11, 3),
#  datetime.date(2019, 4, 11),
#  datetime.date(2023, 12, 18),
#  datetime.date(2023, 11, 8),
#  datetime.date(2018, 10, 26),
#  datetime.date(2022, 2, 16),
#  datetime.date(2018, 1, 30),
#  datetime.date(2018, 6, 25),
#  datetime.date(2022, 2, 15),
#  datetime.date(2022, 12, 13),
#  datetime.date(2022, 2, 8),
#  datetime.date(2022, 6, 23),
#  datetime.date(2021, 6, 8),
#  datetime.date(2023, 7, 13),
#  datetime.date(2020, 5, 11),
#  datetime.date(2019, 2, 18),
#  datetime.date(2024, 1, 31),
#  datetime.date(2021, 8, 20),
#  datetime.date(2020, 6, 25),
#  datetime.date(2020, 10, 23),
#  datetime.date(2022, 3, 2),
#  datetime.date(2018, 12, 31),
#  datetime.date(2020, 1, 22),
#  datetime.date(2021, 4, 20),
#  datetime.date(2019, 7, 2),
#  datetime.date(2024, 7, 30),
#  datetime.date(2018, 3, 6),
#  datetime.date(2020, 7, 21),
#  datetime.date(2023, 8, 7),
#  datetime.date(2021, 3, 12),
#  datetime.date(2022, 1, 28),
#  datetime.date(2020, 4, 1),
#  datetime.date(2020, 8, 14),
#  datetime.date(2020, 12, 30),
#  datetime.date(2019, 9, 17),
#  datetime.date(2020, 2, 25),
#  datetime.date(2024, 5, 2),
#  datetime.date(2019, 5, 16),
#  datetime.date(2020, 2, 1),
#  datetime.date(2022, 6, 13),
#  datetime.date(2021, 10, 13),
#  datetime.date(2021, 12, 1),
#  datetime.date(2022, 8, 16),
#  datetime.date(2018, 4, 4),
#  datetime.date(2021, 12, 23),
#  datetime.date(2018, 1, 18),
#  datetime.date(2021, 11, 22),
#  datetime.date(2021, 1, 22),
#  datetime.date(2021, 9, 15),
#  datetime.date(2022, 11, 15),
#  datetime.date(2018, 3, 26),
#  datetime.date(2018, 11, 26),
#  datetime.date(2023, 12, 13),
#  datetime.date(2020, 3, 31),
#  datetime.date(2022, 7, 12),
#  datetime.date(2022, 9, 19),
#  datetime.date(2023, 2, 22),
#  datetime.date(2020, 8, 18),
#  datetime.date(2020, 12, 21),
#  datetime.date(2020, 3, 5),
#  datetime.date(2018, 1, 11),
#  datetime.date(2018, 1, 31),
#  datetime.date(2024, 5, 10),
#  datetime.date(2024, 5, 28),
#  datetime.date(2020, 10, 12),
#  datetime.date(2020, 3, 9),
#  datetime.date(2020, 8, 17),
#  datetime.date(2019, 8, 6),
#  datetime.date(2022, 2, 18),
#  datetime.date(2024, 7, 16),
#  datetime.date(2021, 11, 25),
#  datetime.date(2023, 10, 25),
#  datetime.date(2022, 11, 11),
#  datetime.date(2021, 3, 4),
#  datetime.date(2019, 4, 4),
#  datetime.date(2021, 9, 28),
#  datetime.date(2018, 3, 21),
#  datetime.date(2022, 5, 6),
#  datetime.date(2024, 10, 31),
#  datetime.date(2023, 2, 17),
#  datetime.date(2024, 9, 20),
#  datetime.date(2020, 11, 17),
#  datetime.date(2024, 4, 2),
#  datetime.date(2020, 6, 15),
#  datetime.date(2024, 2, 7),
#  datetime.date(2024, 11, 27),
#  datetime.date(2018, 7, 25),
#  datetime.date(2023, 12, 14),
#  datetime.date(2021, 10, 25),
#  datetime.date(2018, 12, 27),
#  datetime.date(2018, 4, 27),
#  datetime.date(2021, 3, 3),
#  datetime.date(2020, 7, 22),
#  datetime.date(2023, 9, 12),
#  datetime.date(2020, 6, 26),
#  datetime.date(2023, 6, 22),
#  datetime.date(2024, 5, 6),
#  datetime.date(2018, 4, 26),
#  datetime.date(2019, 2, 28),
#  datetime.date(2021, 8, 31),
#  datetime.date(2021, 2, 3),
#  datetime.date(2018, 10, 8),
#  datetime.date(2018, 5, 4),
#  datetime.date(2024, 12, 4),
#  datetime.date(2024, 9, 30),
#  datetime.date(2019, 9, 11),
#  datetime.date(2020, 12, 1),
#  datetime.date(2021, 11, 3),
#  datetime.date(2020, 7, 15),
#  datetime.date(2022, 12, 9),
#  datetime.date(2020, 2, 4),
#  datetime.date(2020, 12, 31),
#  datetime.date(2023, 3, 17),
#  datetime.date(2018, 4, 3),
#  datetime.date(2022, 4, 8),
#  datetime.date(2024, 8, 27),
#  datetime.date(2020, 1, 14),
#  datetime.date(2023, 5, 11),
#  datetime.date(2019, 5, 29),
#  datetime.date(2022, 7, 15),
#  datetime.date(2019, 11, 25),
#  datetime.date(2019, 9, 6),
#  datetime.date(2018, 6, 19),
#  datetime.date(2020, 7, 2),
#  datetime.date(2022, 11, 18),
#  datetime.date(2024, 10, 10),
#  datetime.date(2024, 10, 1),
#  datetime.date(2020, 7, 8),
#  datetime.date(2020, 6, 12),
#  datetime.date(2023, 10, 5),
#  datetime.date(2018, 3, 1),
#  datetime.date(2022, 11, 10),
#  datetime.date(2018, 6, 1),
#  datetime.date(2022, 2, 11),
#  datetime.date(2023, 11, 16),
#  datetime.date(2018, 4, 25),
#  datetime.date(2021, 4, 30),
#  datetime.date(2023, 2, 8),
#  datetime.date(2021, 11, 18),
#  datetime.date(2019, 7, 3),
#  datetime.date(2022, 11, 9),
#  datetime.date(2021, 7, 23),
#  datetime.date(2022, 3, 23),
#  datetime.date(2018, 8, 29),
#  datetime.date(2021, 11, 9),
#  datetime.date(2022, 12, 22),
#  datetime.date(2021, 11, 26),
#  datetime.date(2024, 11, 4),
#  datetime.date(2020, 2, 18),
#  datetime.date(2024, 10, 14),
#  datetime.date(2020, 6, 29),
#  datetime.date(2019, 10, 30),
#  datetime.date(2020, 7, 28),
#  datetime.date(2024, 10, 9),
#  datetime.date(2022, 7, 27),
#  datetime.date(2018, 7, 27),
#  datetime.date(2020, 1, 17),
#  datetime.date(2021, 9, 27),
#  datetime.date(2018, 11, 20),
#  datetime.date(2024, 12, 2),
#  datetime.date(2020, 8, 27),
#  datetime.date(2018, 2, 14),
#  datetime.date(2020, 7, 9),
#  datetime.date(2019, 9, 3),
#  datetime.date(2018, 11, 22),
#  datetime.date(2024, 9, 5),
#  datetime.date(2019, 12, 18),
#  datetime.date(2024, 4, 9),
#  datetime.date(2022, 9, 21),
#  datetime.date(2023, 3, 1),
#  datetime.date(2019, 8, 9),
#  datetime.date(2019, 2, 6),
#  datetime.date(2024, 2, 22),
#  datetime.date(2023, 2, 13),
#  datetime.date(2023, 3, 22),
#  datetime.date(2023, 4, 11),
#  datetime.date(2023, 6, 30),
#  datetime.date(2023, 10, 12),
#  datetime.date(2018, 6, 8),
#  datetime.date(2021, 9, 6),
#  datetime.date(2018, 2, 9),
#  datetime.date(2020, 9, 10),
#  datetime.date(2022, 7, 14),
#  datetime.date(2024, 6, 10),
#  datetime.date(2020, 8, 24),
#  datetime.date(2019, 12, 24),
#  datetime.date(2024, 1, 16),
#  datetime.date(2019, 12, 13),
#  datetime.date(2021, 10, 27),
#  datetime.date(2018, 8, 6),
#  datetime.date(2024, 6, 6),
#  datetime.date(2021, 10, 18),
#  datetime.date(2020, 1, 3),
#  datetime.date(2021, 9, 30),
#  datetime.date(2023, 11, 9),
#  datetime.date(2022, 3, 21),
#  datetime.date(2023, 9, 1),
#  datetime.date(2018, 2, 16),
#  datetime.date(2018, 8, 20),
#  datetime.date(2021, 10, 26),
#  datetime.date(2018, 11, 5),
#  datetime.date(2022, 9, 13),
#  datetime.date(2024, 6, 20),
#  datetime.date(2024, 7, 1),
#  datetime.date(2020, 12, 7),
#  datetime.date(2018, 11, 14),
#  datetime.date(2022, 12, 29),
#  datetime.date(2019, 7, 9),
#  datetime.date(2023, 8, 25),
#  datetime.date(2022, 10, 31),
#  datetime.date(2021, 12, 8),
#  datetime.date(2020, 4, 28),
#  datetime.date(2020, 8, 20),
#  datetime.date(2022, 6, 22),
#  datetime.date(2019, 6, 20),
#  datetime.date(2019, 6, 21),
#  datetime.date(2023, 7, 28),
#  datetime.date(2020, 3, 25),
#  datetime.date(2023, 9, 5),
#  datetime.date(2021, 9, 2),
#  datetime.date(2019, 4, 25),
#  datetime.date(2021, 10, 5),
#  datetime.date(2022, 10, 21),
#  datetime.date(2024, 9, 27),
#  datetime.date(2024, 6, 7),
#  datetime.date(2022, 8, 25),
#  datetime.date(2022, 1, 4),
#  datetime.date(2021, 10, 4),
#  datetime.date(2019, 7, 23),
#  datetime.date(2020, 9, 25),
#  datetime.date(2019, 1, 14),
#  datetime.date(2022, 4, 7),
#  datetime.date(2020, 6, 23),
#  datetime.date(2020, 6, 10),
#  datetime.date(2021, 6, 10),
#  datetime.date(2020, 6, 8),
#  datetime.date(2020, 1, 30),
#  datetime.date(2022, 12, 5),
#  datetime.date(2021, 9, 8),
#  datetime.date(2022, 7, 20),
#  datetime.date(2024, 11, 6),
#  datetime.date(2020, 10, 20),
#  datetime.date(2024, 11, 12),
#  datetime.date(2020, 12, 24),
#  datetime.date(2018, 7, 16),
#  datetime.date(2021, 4, 19),
#  datetime.date(2018, 9, 19),
#  datetime.date(2019, 8, 1),
#  datetime.date(2021, 9, 16),
#  datetime.date(2024, 5, 30),
#  datetime.date(2024, 4, 18),
#  datetime.date(2024, 10, 30),
#  datetime.date(2024, 11, 26),
#  datetime.date(2018, 10, 1),
#  datetime.date(2023, 12, 6),
#  datetime.date(2022, 7, 11),
#  datetime.date(2022, 9, 14),
#  datetime.date(2018, 5, 11),
#  datetime.date(2024, 1, 3),
#  datetime.date(2024, 9, 16),
#  datetime.date(2018, 9, 24),
#  datetime.date(2023, 8, 9),
#  datetime.date(2023, 11, 13),
#  datetime.date(2019, 2, 5),
#  datetime.date(2021, 7, 14),
#  datetime.date(2018, 2, 19),
#  datetime.date(2023, 6, 12),
#  datetime.date(2023, 7, 18),
#  datetime.date(2020, 11, 10),
#  datetime.date(2024, 4, 23),
#  datetime.date(2018, 9, 18),
#  datetime.date(2023, 5, 5),
#  datetime.date(2019, 3, 13),
#  datetime.date(2020, 1, 29),
#  datetime.date(2023, 4, 21),
#  datetime.date(2024, 5, 29),
#  datetime.date(2018, 5, 23),
#  datetime.date(2018, 3, 7),
#  datetime.date(2019, 9, 18),
#  datetime.date(2022, 9, 20),
#  datetime.date(2022, 2, 25),
#  datetime.date(2018, 11, 9),
#  datetime.date(2018, 3, 9),
#  datetime.date(2021, 1, 15),
#  datetime.date(2023, 3, 27),
#  datetime.date(2022, 5, 24),
#  datetime.date(2019, 9, 23),
#  datetime.date(2023, 12, 15),
#  datetime.date(2023, 1, 10),
#  datetime.date(2020, 9, 1),
#  datetime.date(2022, 3, 4),
#  datetime.date(2024, 9, 26),
#  datetime.date(2024, 11, 21),
#  datetime.date(2020, 11, 19),
#  datetime.date(2020, 4, 22),
#  datetime.date(2024, 10, 7),
#  datetime.date(2018, 7, 26),
#  datetime.date(2019, 2, 26),
#  datetime.date(2024, 3, 11),
#  datetime.date(2021, 6, 15),
#  datetime.date(2018, 8, 13),
#  datetime.date(2022, 11, 28),
#  datetime.date(2018, 3, 27),
#  datetime.date(2022, 2, 17),
#  datetime.date(2024, 3, 18),
#  datetime.date(2024, 9, 2),
#  datetime.date(2023, 4, 17),
#  datetime.date(2018, 9, 17),
#  datetime.date(2021, 11, 24),
#  datetime.date(2018, 9, 10),
#  datetime.date(2020, 7, 27),
#  datetime.date(2021, 2, 15),
#  datetime.date(2022, 1, 10),
#  datetime.date(2022, 6, 27),
#  datetime.date(2020, 2, 10),
#  datetime.date(2018, 4, 10),
#  datetime.date(2018, 10, 29),
#  datetime.date(2019, 8, 27),
#  datetime.date(2019, 7, 8),
#  datetime.date(2019, 10, 7),
#  datetime.date(2022, 6, 15),
#  datetime.date(2020, 4, 24),
#  datetime.date(2021, 8, 26),
#  datetime.date(2021, 7, 28),
#  datetime.date(2023, 7, 4),
#  datetime.date(2023, 5, 25),
#  datetime.date(2023, 7, 3),
#  datetime.date(2023, 8, 22),
#  datetime.date(2024, 8, 22),
#  datetime.date(2018, 3, 19),
#  datetime.date(2019, 3, 8),
#  datetime.date(2023, 3, 20),
#  datetime.date(2023, 6, 6),
#  datetime.date(2024, 5, 23),
#  datetime.date(2018, 6, 11),
#  datetime.date(2023, 5, 19),
#  datetime.date(2024, 4, 25),
#  datetime.date(2021, 5, 28),
#  datetime.date(2020, 7, 17),
#  datetime.date(2020, 10, 26),
#  datetime.date(2019, 2, 25),
#  datetime.date(2023, 11, 3),
#  datetime.date(2018, 6, 6),
#  datetime.date(2023, 4, 24),
#  datetime.date(2018, 3, 14),
#  datetime.date(2020, 12, 2),
#  datetime.date(2021, 2, 10),
#  datetime.date(2019, 4, 12),
#  ...}

# %%
PORTFOLIO_VALUE = 10_00_000 # 10 Lacs
# RPT_PCT = 0.01 # 1% RPT
SLIPPAGE_ = 0.0001
LEVERAGE_ = 5

# %%
# !poetry add ta
# Out:
# Using version ^0.11.0 for ta
#
# Updating dependencies
# Resolving dependencies... (3.5s)s://files.pythonhosted.org/packages/e0/9a/37d92a6b470dc9088612c2399a68f1a9ac22872d4e1eff416818e22ab11b/ta-0.11.0.tar.gz (0.4s)Resolving dependencies... (1.4s)
#
# Package operations: 1 install, 0 updates, 0 removals
#
#   • Installing ta (0.11.0): Pending...
#   • Installing ta (0.11.0): Downloading... 0%
#   • Installing ta (0.11.0): Downloading... 100%
#   • Installing ta (0.11.0): Preparing...
#   • Installing ta (0.11.0): Installing...
#   • Installing ta (0.11.0)
#
# Writing lock file

# %%
def calculate_signals(df, ema_length=20):
    df['ema'] = df['close'].ewm(span=ema_length, adjust=False).mean()
    df['Sell_Signal'] = df['close'] < df['ema']
    return df

# %%
lev_ = 5
portfolio_value = 10000000
lot_size_ = 15
slippage_ = 0.0001

# %%
def backtest_short(df):
    trade_book = []
    in_trade = False
    points = 0
    is_trailing_active = False
    trailing_sl = 0
    df = calculate_signals(df)
    # print(df[df['Sell_Signal']].to_string())
    for i in range(0, len(df)):
        # print(i, df.loc[i], df.loc[i, 'open'])
        # break
        if df.loc[i, 'Sell_Signal'] and not in_trade:
            # Entry Triggered
            entry_price = df.loc[i, 'close']
            entry_time = df.loc[i, 'datetime']
            initial_sl = df.loc[i-3:i, 'high'].max()
            sl_in_points = initial_sl - entry_price
            target = 5 * sl_in_points
            in_trade = True

        if in_trade:
            if df.loc[i, 'high'] < df.loc[i, 'ema']:
                is_trailing_active = True
            if is_trailing_active:
                trailing_sl = df.loc[i, 'ema']
            print(df.loc[i, 'open'], initial_sl)
            # break
            if df.loc[i, 'open'] > initial_sl and not points:
                # Gap condition
                if df.loc[i, 'close'] < initial_sl:
                    initial_sl = df.loc[i, 'high']
                else:
                    exit_price = df.loc[i, 'close']
                    exit_time = df.loc[i, 'datetime']
                    in_trade = False
                    remark = 'Gap SL'
                    points = entry_price - exit_price
            if df.loc[i, 'high'] > initial_sl and not points:
                # Initial SL Hit
                exit_price = df.loc[i, 'close']
                exit_time = df.loc[i, 'datetime']
                in_trade = False
                remark = 'Initial SL'
                points = entry_price - exit_price
            if is_trailing_active:
                if df.loc[i, 'close'] > trailing_sl and not points:
                    # TSL Hit
                    exit_price = df.loc[i, 'close']
                    exit_time = df.loc[i, 'datetime']
                    in_trade = False
                    remark = 'Trailing SL'
                    points = entry_price - exit_price
            if df.loc[i, 'low'] < entry_price - target and not points:
                # Target Hit
                exit_price = entry_price - target
                exit_time = df.loc[i, 'datetime']
                in_trade = False
                remark = 'Target'
                points = entry_price - exit_price

        if points:
            index_lev = lev_
            qty = int(round(portfolio_value * index_lev / entry_price / lot_size_)) * lot_size_
            slippage = slippage_ * (entry_price + exit_price)
            final_points = points - slippage
            trade = {
                "Trade Type": "Short",
                "Entry Time": entry_time,
                "Entry Price": entry_price,
                "Initial SL": initial_sl,
                "Trailing SL": trailing_sl,
                "Exit Time": exit_time,
                "Exit Price": exit_price,
                "Points Captured": points,
                "Slippage in Points": slippage,
                "After Costs": final_points,
                "PnL": final_points * qty,
                "Remarks": remark,
                "Qty": qty,
                "Leverage": index_lev,
                "ROI%": (final_points * qty / portfolio_value) * 100,
                "Trade Year": entry_time.year,
                "Trade Month": entry_time.month,
            }
            # print(trade)
            trade_book.append(trade)
            points = 0
            in_trade = False
            is_trailing_active = False
            trailing_sl = 0

    return pd.DataFrame(trade_book)

# %%
tb = backtest_short(bnf_1min)

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2018, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2018, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI%"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI%"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI%"] > 0]["ROI%"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI%"] < 0]["ROI%"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI%"].cumsum() - year_trades["ROI%"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI%"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI%"] > 0]["ROI%"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI%"].cumsum() - combined_df_sorted["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation
    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    return {overall_roi_dd_ratio : stats_df8}

# %%
variation = 1
stats = generate_stats(tb, variation)
for x, y in stats.items():
    final_stats = y

final_stats
# Out:
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2018     -32.0553           44  13.6364               19.7304
# 2019     -46.1032           58  17.2414               15.0550
# 2020      67.3749           61  26.2295               28.5069
# 2021     -51.8290           37  18.9189               16.9938
# 2022     -71.8139           57  17.5439               13.0565
# 2023     -66.8276           60  18.3333                9.8990
# 2024     -64.0383           33  21.2121               10.1880
# Overall -265.2924     350.0000  19.1429               17.2354
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio Variation
# 2018                -3.9589     -80.4409      -0.3985         1
# 2019                -4.0970     -62.6688      -0.7357         1
# 2020                -8.6386    -198.7372       0.3390         1
# 2021                -5.6929     -99.6001      -0.5204         1
# 2022                -4.3059    -101.3048      -0.7089         1
# 2023                -3.5860     -99.4934      -0.6717         1
# 2024                -5.2059     -76.0539      -0.8420         1
# Overall             -5.0179    -463.6386      -0.5722    1.0000

# %%
# bnf_1min.tail(25)

# %%
tb[tb['Trade Year'] > 2023]
# Out:
#     Trade Type                Entry Time  Entry Price  Initial SL  \
# 713      Short 2024-01-01 14:45:00+05:30   48213.6500  48450.0000
# 714      Short 2024-01-05 11:15:00+05:30   48084.6500  48344.7000
# 715      Short 2024-01-08 10:45:00+05:30   47874.5000  48154.5000
# 716      Short 2024-01-09 13:45:00+05:30   47674.8000  47877.0500
# 717      Short 2024-01-11 13:45:00+05:30   47300.2500  47595.1500
# 718      Short 2024-01-16 13:15:00+05:30   48078.7500  48305.4000
# 719      Short 2024-01-17 11:15:00+05:30   46380.8500  47115.5000
# 720      Short 2024-01-19 10:45:00+05:30   45930.1500  46249.8500
# 721      Short 2024-01-20 12:15:00+05:30   45733.0500  46006.0500
# 722      Short 2024-01-23 10:15:00+05:30   45682.5000  46580.3000
# 723      Short 2024-01-25 09:45:00+05:30   44824.3500  45148.2000
# 724      Short 2024-01-30 14:15:00+05:30   45307.8000  45492.5000
# 725      Short 2024-02-01 09:15:00+05:30   45797.0000  46173.3000
# 726      Short 2024-02-02 12:45:00+05:30   46254.7000  46892.3500
# 727      Short 2024-02-07 11:15:00+05:30   45680.0500  45958.1500
# 728      Short 2024-02-08 10:45:00+05:30   45405.0000  46181.2000
# 729      Short 2024-02-12 09:45:00+05:30   45376.3500  45748.5000
# 730      Short 2024-02-13 11:45:00+05:30   45082.8500  45461.9500
# 731      Short 2024-02-14 09:15:00+05:30   45082.6000  45622.2500
# 713              9.6106     311.1894  322080.9773  Trailing SL  1035
# 714              9.6252     -92.5752  -95815.3579  Trailing SL  1035
# 715              9.5757     -17.8257  -18717.0112  Trailing SL  1050
# 716              9.5178     161.7822  169871.2785  Trailing SL  1050
# 717              9.4930    -338.8430 -355785.1342   Initial SL  1050
# 718              9.5024    1123.7476 1163078.7401       Target  1035
# 719              9.2466     286.8034  309747.7098  Trailing SL  1080
# 720              9.1858      -7.1358   -7813.7284  Trailing SL  1095
# 721              9.1811    -354.2811 -387937.8264   Initial SL  1095
# 722              9.0791     564.9709  618643.1410  Trailing SL  1095
# 723              8.9697     -57.0697  -63347.3448  Trailing SL  1110
# 724              9.1132    -525.7632 -583597.1797   Initial SL  1110
# 725              9.1896    -311.1396 -340697.8565   Initial SL  1095
# 726              9.2029     471.0471  508730.8518  Trailing SL  1080
# 727              9.1454    -102.6454 -112396.6692  Trailing SL  1095
# 728              9.0810      -8.7310   -9560.4067  Trailing SL  1095
# 729              9.0516     228.0484  249713.0418  Trailing SL  1095
# 730              9.0369    -211.9869 -235305.4202  Trailing SL  1110
# 731              9.0444    -287.7944 -319451.7784  Trailing SL  1110
# 732              9.3720     137.3780  146307.5221  Trailing SL  1065
# 733              9.3537     198.5463  211451.8202  Trailing SL  1065
# 734              9.2348      50.8652   54934.3836  Trailing SL  1080
# 735              9.5720     -64.0720  -67275.6105  Trailing SL  1050
# 736              9.5508      58.3992   61319.1547  Trailing SL  1050
# 737              9.4174      35.4826   37788.9797  Trailing SL  1065
# 738              9.3493     304.7507  324559.4955  Trailing SL  1065
# 739              9.2826    -169.2326 -182771.2350   Initial SL  1080
# 740              9.2599    -334.0099 -360730.6758  Trailing SL  1080
# 741              9.2654     -95.5154 -103156.6482  Trailing SL  1080
# 742              9.3521    -103.3521 -110069.9759  Trailing SL  1065
# 743              9.4552    -488.2052 -519938.5540   Initial SL  1065
# 744              9.4960    -297.1460 -312003.2528   Initial SL  1050
# 745              9.7477    -299.3977 -309876.6350   Initial SL  1035
# 746              9.6450    1000.3050 1020311.1459  Trailing SL  1020
# 747              9.4516      30.1484   32108.0673  Trailing SL  1065
# 748              9.6798    -234.5798 -242790.0516   Initial SL  1035
# 749              9.8761    -188.2761 -192041.6322  Trailing SL  1020
# 750              9.8208       0.9292     947.7993  Trailing SL  1020
# 751              9.6617    1309.3383 1335525.1068       Target  1020
# 752              9.4990      70.3510   73868.5447  Trailing SL  1050
# 753              9.5454       7.7046    8089.8667  Trailing SL  1050
# 754              9.5315    -361.7314 -379818.0225  Trailing SL  1050
# 755              9.5149    -353.7649 -371453.0978  Trailing SL  1050
# 756              9.6232    -240.8732 -249303.7982   Initial SL  1035
# 757              9.5937     115.2063  119238.5308  Trailing SL  1035
# 758              9.7939     355.3561  362463.2577  Trailing SL  1020
# 759              9.7306    -210.7306 -218106.1503  Trailing SL  1035
# 760              9.7728    -264.1727 -269456.2050   Initial SL  1020
# 761              9.7236     948.0764  967037.9484  Trailing SL  1020
# 762              9.9549    -183.7049 -184623.4295  Trailing SL  1005
# 763              9.9581    -125.7582 -126386.9408  Trailing SL  1005
# 764              9.9926    -133.7426 -134411.3080  Trailing SL  1005
# 765             10.3160    -171.2660 -166984.3256  Trailing SL   975
# 766             10.2677    -288.5677 -281353.4977  Trailing SL   975
# 767             10.5415     244.3085  230871.5561  Trailing SL   945
# 768             10.5131    -105.9131 -100087.9173   Initial SL   945
# 769             10.5321    -896.4321 -860574.7968       Gap SL   960
# 770             10.5854     -40.6854  -38447.6935  Trailing SL   945
# 771             10.5082    -299.8082 -287815.9008  Trailing SL   960
# 772             10.4856    -215.6356 -207010.2192  Trailing SL   960
# 773             10.4325     652.8175  616912.5706       Target   945
# 774             10.3970    -377.5970 -362493.1392  Trailing SL   960
# 775             10.4675    -228.4675 -219328.7904  Trailing SL   960
# 776             10.5004    -222.1004 -213216.4224   Initial SL   960
# 777             10.4668    -198.5668 -190624.0896  Trailing SL   960
# 778             10.4664     -77.8164  -74703.7008  Trailing SL   960
# 779             10.2421     287.9579  280758.9232  Trailing SL   975
# 780             10.3069    -154.8069 -150936.7470  Trailing SL   975
# 781             10.2982    -122.9982 -119923.2645   Initial SL   975
# 782             10.3127       0.4373     426.3236  Trailing SL   975
# 783             10.1348    1324.8652 1291743.5310       Target   975
# 784             10.0004     -82.7504  -83164.1771  Trailing SL  1005
# 785             10.0123    -276.0623 -277442.5763   Initial SL  1005
# 786             10.0710    -501.4710 -503978.3852       Gap SL  1005
# 787             10.0851    -334.2851 -330942.2391   Initial SL   990
# 788             10.0461     440.4039  435999.8560  Trailing SL   990
# 789             10.0988    -345.9988 -342538.8318   Initial SL   990
# 790             10.1401      27.3099   27036.8257  Trailing SL   990
# 791             10.2170    -336.1170 -327714.0945       Gap SL   975
# 792             10.2162    -135.0662 -131689.5889   Initial SL   975
# 793             10.2384     -51.1884  -49908.6851  Trailing SL   975
# 794             10.2440     -90.4440  -88182.9195   Initial SL   975
# 795             10.2461    -165.6461 -161504.9183   Initial SL   975
# 796             10.2462    -243.1462 -237067.5743  Trailing SL   975
# 797             10.2797    -229.2297 -223498.9721   Initial SL   975
# 798             10.2690    -162.4190 -158358.4811  Trailing SL   975
# 799             10.2320     494.2680  481911.3390       Target   975
# 800             10.1679     -24.0679  -23827.2309  Trailing SL   990
# 801             10.2432    -111.6932 -108900.8359  Trailing SL   975
# 802             10.4578    -299.0578 -287095.4784   Initial SL   960
# 803             10.8159    -212.9659 -198058.3196   Initial SL   930
# 804             10.7210     975.7790  907474.4700       Target   930
# 805             10.4934    1261.7566 1192359.9823       Target   945
# 806             10.2940     740.3060  710693.7312  Trailing SL   960
# 807             10.2269    -106.6769 -104010.0019  Trailing SL   975
# 808             10.2942    -248.2942 -242086.8060  Trailing SL   975
# 809             10.3397     276.2603  265209.8688  Trailing SL   960
# 810             10.3974    -270.1474 -259341.4896   Initial SL   960
# 811             10.3263     -42.4263  -41365.6425  Trailing SL   975
# 812             10.2289     673.2711  656439.2932       Target   975
# 813             10.1711    -564.7711 -559123.3989  Trailing SL   990
# 814             10.3687     -22.1687  -21281.9136  Trailing SL   960
# 815             10.3434      14.4066   13830.3600  Trailing SL   960
# 816             10.3098    -450.7097 -439442.0062   Initial SL   975
# 817             10.4172      39.2328   37663.5120  Trailing SL   960
# 818             10.3646     -17.5146  -16813.9920   Initial SL   960
# 819             10.3344    -253.0344 -246708.5692   Initial SL   975
# 820             10.3797    -141.6797 -136012.5312   Initial SL   960
# 821             10.2045    1353.4455 1299307.6944  Trailing SL   960
# 822             10.1071     141.6929  140276.0007  Trailing SL   990
# 823             10.4304     164.2196  157650.8592  Trailing SL   960
# 824             10.3873    -149.3373 -143363.7936  Trailing SL   960
# 825             10.6438    -541.9438 -512136.8627   Initial SL   945
#
#      Leverage    ROI%  Trade Year  Trade Month
# 713         5  3.2208        2024            1
# 714         5 -0.9582        2024            1
# 715         5 -0.1872        2024            1
# 716         5  1.6987        2024            1
# 717         5 -3.5579        2024            1
# 718         5 11.6308        2024            1
# 719         5  3.0975        2024            1
# 720         5 -0.0781        2024            1
# 721         5 -3.8794        2024            1
# 722         5  6.1864        2024            1
# 723         5 -0.6335        2024            1
# 724         5 -5.8360        2024            1
# 725         5 -3.4070        2024            2
# 726         5  5.0873        2024            2
# 727         5 -1.1240        2024            2
# 728         5 -0.0956        2024            2
# 729         5  2.4971        2024            2
# 730         5 -2.3531        2024            2
# 731         5 -3.1945        2024            2
# 732         5  1.4631        2024            2
# 733         5  2.1145        2024            2
# 734         5  0.5493        2024            2
# 735         5 -0.6728        2024            3
# 736         5  0.6132        2024            3
# 737         5  0.3779        2024            3
# 738         5  3.2456        2024            3
# 739         5 -1.8277        2024            3
# 740         5 -3.6073        2024            3
# 741         5 -1.0316        2024            3
# 742         5 -1.1007        2024            3
# 743         5 -5.1994        2024            3
# 744         5 -3.1200        2024            4
# 745         5 -3.0988        2024            4
# 746         5 10.2031        2024            4
# 747         5  0.3211        2024            4
# 748         5 -2.4279        2024            4
# 749         5 -1.9204        2024            4
# 750         5  0.0095        2024            5
# 751         5 13.3553        2024            5
# 752         5  0.7387        2024            5
# 753         5  0.0809        2024            5
# 754         5 -3.7982        2024            5
# 755         5 -3.7145        2024            5
# 756         5 -2.4930        2024            5
# 757         5  1.1924        2024            5
# 758         5  3.6246        2024            5
# 759         5 -2.1811        2024            5
# 760         5 -2.6946        2024            5
# 761         5  9.6704        2024            6
# 762         5 -1.8462        2024            6
# 763         5 -1.2639        2024            6
# 764         5 -1.3441        2024            6
# 765         5 -1.6698        2024            6
# 766         5 -2.8135        2024            6
# 767         5  2.3087        2024            6
# 768         5 -1.0009        2024            7
# 769         5 -8.6057        2024            7
# 770         5 -0.3845        2024            7
# 771         5 -2.8782        2024            7
# 772         5 -2.0701        2024            7
# 773         5  6.1691        2024            7
# 774         5 -3.6249        2024            7
# 775         5 -2.1933        2024            7
# 776         5 -2.1322        2024            7
# 777         5 -1.9062        2024            7
# 778         5 -0.7470        2024            7
# 779         5  2.8076        2024            7
# 780         5 -1.5094        2024            7
# 781         5 -1.1992        2024            7
# 782         5  0.0043        2024            8
# 783         5 12.9174        2024            8
# 784         5 -0.8316        2024            8
# 785         5 -2.7744        2024            8
# 786         5 -5.0398        2024            8
# 787         5 -3.3094        2024            8
# 788         5  4.3600        2024            8
# 789         5 -3.4254        2024            8
# 790         5  0.2704        2024            8
# 791         5 -3.2771        2024            8
# 792         5 -1.3169        2024            8
# 793         5 -0.4991        2024            8
# 794         5 -0.8818        2024            8
# 795         5 -1.6150        2024            8
# 796         5 -2.3707        2024            8
# 797         5 -2.2350        2024            9
# 798         5 -1.5836        2024            9
# 799         5  4.8191        2024            9
# 800         5 -0.2383        2024            9
# 801         5 -1.0890        2024            9
# 802         5 -2.8710        2024            9
# 803         5 -1.9806        2024            9
# 804         5  9.0747        2024            9
# 805         5 11.9236        2024            9
# 806         5  7.1069        2024           10
# 807         5 -1.0401        2024           10
# 808         5 -2.4209        2024           10
# 809         5  2.6521        2024           10
# 810         5 -2.5934        2024           10
# 811         5 -0.4137        2024           10
# 812         5  6.5644        2024           10
# 813         5 -5.5912        2024           10
# 814         5 -0.2128        2024           10
# 815         5  0.1383        2024           10
# 816         5 -4.3944        2024           11
# 817         5  0.3766        2024           11
# 818         5 -0.1681        2024           11
# 819         5 -2.4671        2024           11
# 820         5 -1.3601        2024           11
# 821         5 12.9931        2024           11
# 822         5  1.4028        2024           11
# 823         5  1.5765        2024           11
# 824         5 -1.4336        2024           12
# 825         5 -5.1214        2024           12

# %%
stats_dictionary = {}
for i in range(2, 7):
    for l in range(6, 36, 2):
        variation = f'n {i} ema {l}'
        print(variation)
        tb = backtest_short(bnf_1min, i, l)
        if len(tb) > 0:
            stats = generate_stats(tb, variation)
            for x, y in stats.items():
                if x > 8:
                    final_stats = y
                    print(final_stats.to_string())
                    stats_dictionary[x] = y
# Out:
# n 2 ema 6
# n 2 ema 8
# n 2 ema 10
# n 2 ema 12
# n 2 ema 14
# n 2 ema 16
# n 2 ema 18
# n 2 ema 20
# n 2 ema 22
# n 2 ema 24
# n 2 ema 26
# n 2 ema 28
# n 2 ema 30
# n 2 ema 32
# n 2 ema 34
# n 3 ema 6
# n 3 ema 8
# n 3 ema 10
# n 3 ema 12
# n 3 ema 14
# n 3 ema 16
# n 3 ema 18
# n 3 ema 20
# n 3 ema 22
# n 3 ema 24
# n 3 ema 26
# n 3 ema 28
# n 3 ema 30
# n 3 ema 32
# n 3 ema 34
# n 4 ema 6
# n 4 ema 8
# n 4 ema 10
# n 4 ema 12
# n 4 ema 14
# n 4 ema 16
# n 4 ema 18
# n 4 ema 20
# n 4 ema 22
# n 4 ema 24
# n 4 ema 26
# n 4 ema 28
# n 4 ema 30
# n 4 ema 32
# n 4 ema 34
# n 5 ema 6
# n 5 ema 8
# n 5 ema 10
# n 5 ema 12
# n 5 ema 14
# n 5 ema 16
# n 5 ema 18
# n 5 ema 20
# n 5 ema 22
# n 5 ema 24
# n 5 ema 26
# n 5 ema 28
# n 5 ema 30
# n 5 ema 32
# n 5 ema 34
# n 6 ema 6
# n 6 ema 8
# n 6 ema 10
# n 6 ema 12
# n 6 ema 14
# n 6 ema 16
# n 6 ema 18
# n 6 ema 20
# n 6 ema 22
# n 6 ema 24
# n 6 ema 26
# n 6 ema 28
# n 6 ema 30
# n 6 ema 32
# n 6 ema 34

# %%
stats_dictionary
