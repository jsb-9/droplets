# %%
import asyncio
import datetime as dt
import math
from typing import Literal

import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import pandas_market_calendars as mcal
import plotly.graph_objects as go
import polars as pl
from dash import Dash, dcc, html
from plotly.subplots import make_subplots

nse = mcal.get_calendar("NSE")

# %%
pd.set_option("display.max_rows", 25_000)
pd.set_option("display.max_columns", 500)
pl.Config.set_tbl_cols(500)
pl.Config.set_tbl_rows(10_000)

pd.options.display.float_format = "{:.4f}".format

# %%
import sys

sys.path.append("..")
from tooling.enums import AssetClass, Index, Spot, StrikeSpread
from tooling.fetch import fetch_option_data, fetch_spot_data
from tooling.filter import find_atm, option_tool

# %%
async def get_expiry(f_today, index):

    if index == 'bnf':    
        if (f_today <= dt.date(2024, 1, 25)) and (f_today >= dt.date(2024, 1, 18)):
            f_expiry = dt.date(2024, 1, 25)
        elif (f_today <= dt.date(2024, 1, 31)) and (f_today >= dt.date(2024, 1, 26)):
            f_expiry = dt.date(2024, 1, 31)
        elif (f_today <= dt.date(2024, 2, 22)) and (f_today >= dt.date(2024, 2, 29)):
            f_expiry = dt.date(2024, 2, 29)
        elif (f_today <= dt.date(2024, 3, 25)) and (f_today >= dt.date(2024, 3, 27)):
            f_expiry = dt.date(2024, 2, 27)
        elif f_today < dt.date(2023, 9, 1):
            days_to_thursday = (3 - f_today.weekday()) % 7
            nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
            f_expiry = nearest_thursday
            if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
                f_expiry = nearest_thursday - dt.timedelta(days=1)
        elif f_today >= dt.date(2023, 9, 1):
            if f_today.day < 24:
                days_to_wednesday = (2 - f_today.weekday()) % 7
                nearest_wednesday = f_today + dt.timedelta(days=days_to_wednesday)
                f_expiry = nearest_wednesday
                if nse.valid_days(
                    start_date=nearest_wednesday, end_date=nearest_wednesday
                ).empty:
                    f_expiry = nearest_wednesday - dt.timedelta(days=1)
            else:
                days_to_thursday = (3 - f_today.weekday()) % 7
                nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
                f_expiry = nearest_thursday
                if nse.valid_days(
                    start_date=nearest_thursday, end_date=nearest_thursday
                ).empty:
                    f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'nifty':
        days_to_thursday = (3 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'finnifty' or index == 'fnf':
        days_to_thursday = (1 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

    elif index == 'midcpnifty' or index == 'midcp':
        days_to_thursday = (0 - f_today.weekday()) % 7
        nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
        f_expiry = nearest_thursday
        if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
            f_expiry = nearest_thursday - dt.timedelta(days=1)
        return f_expiry

async def get_expiry_nifty(f_today):

    days_to_thursday = (3 - f_today.weekday()) % 7
    nearest_thursday = f_today + dt.timedelta(days=days_to_thursday)
    f_expiry = nearest_thursday
    if nse.valid_days(start_date=nearest_thursday, end_date=nearest_thursday).empty:
        f_expiry = nearest_thursday - dt.timedelta(days=1)
    return f_expiry


async def get_option_contract_name(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"


def get_option_contract_name2(symbol, strike, expiry, opt_type):
    temp = "0"
    mth = expiry.month

    if (expiry + dt.timedelta(days=7)).month != expiry.month:
        date_string = expiry.strftime("%y%b").upper()
        return f"{symbol}{date_string}{strike}{opt_type}"
    else:
        if expiry.day <= 9:
            date_string = f"{expiry.year - 2000}{mth}{temp}{expiry.day}"
        else:
            date_string = f"{expiry.year - 2000}{mth}{expiry.day}"
        return f"{symbol}{date_string}{strike}{opt_type}"

# %%
bnf_1min = pd.read_csv("../data/bnf_wave.csv")
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["time"])
bnf_1min = bnf_1min[bnf_1min["datetime"].dt.year >= 2017]

# %%
bnf_1min.tail()
# Out:
#                             time       open       high        low      close  \
# 22214  2024-12-05T11:45:00+05:30 53037.0000 53507.1000 52998.8500 53484.5000
# 22215  2024-12-05T12:15:00+05:30 53475.8000 53647.8000 53472.6500 53521.0500
# 22216  2024-12-05T12:45:00+05:30 53523.2500 53621.1000 53452.6500 53609.9500
# 22217  2024-12-05T13:15:00+05:30 53614.8000 53642.3500 53461.3500 53598.9000
# 22218  2024-12-05T13:45:00+05:30 53599.7500 53640.9000 53560.0000 53564.1500
#
#               MA     Plot  Zero line  MACD Signal                  datetime
# 22214 53167.1400 204.1806          0     204.1806 2024-12-05 11:45:00+05:30
# 22215 53191.2367 270.8858          0     270.8858 2024-12-05 12:15:00+05:30
# 22216 53230.6600 327.7843          0     327.7843 2024-12-05 12:45:00+05:30
# 22217 53269.0200 351.5606          0     351.5606 2024-12-05 13:15:00+05:30
# 22218 53299.1367 348.2676          0     348.2676 2024-12-05 13:45:00+05:30

# %%
def resample(
    data: pl.DataFrame, timeframe, offset: dt.timedelta | None = None
) -> pl.DataFrame:
    return (
        data.set_sorted("datetime")
        .group_by_dynamic(
            index_column="datetime",
            every=timeframe,
            period=timeframe,
            label="left",
            offset=offset,
        )
        .agg(
            [
                pl.col("open").first().alias("open"),
                pl.col("high").max().alias("high"),
                pl.col("low").min().alias("low"),
                pl.col("close").last().alias("close"),
                pl.col("volume").sum().alias("volume"),
            ]
        )
    )


# ohlc_resampled = resample(pl.DataFrame(bnf_1min), '7d', pd.Timedelta(days=4))
# ohlc_resampled

# %%
bnf_1min["datetime"] = pd.to_datetime(bnf_1min["datetime"])
list_of_traded_dates = set(bnf_1min["datetime"].dt.date)
list_of_traded_dates
# Out:
# {datetime.date(2024, 7, 30),
#  datetime.date(2019, 7, 25),
#  datetime.date(2020, 4, 8),
#  datetime.date(2021, 2, 12),
#  datetime.date(2019, 8, 30),
#  datetime.date(2019, 2, 15),
#  datetime.date(2021, 4, 19),
#  datetime.date(2020, 11, 23),
#  datetime.date(2020, 2, 18),
#  datetime.date(2020, 7, 27),
#  datetime.date(2023, 8, 9),
#  datetime.date(2022, 10, 19),
#  datetime.date(2020, 10, 15),
#  datetime.date(2024, 1, 24),
#  datetime.date(2022, 8, 19),
#  datetime.date(2024, 6, 24),
#  datetime.date(2023, 11, 22),
#  datetime.date(2019, 1, 1),
#  datetime.date(2021, 12, 31),
#  datetime.date(2021, 12, 30),
#  datetime.date(2020, 7, 23),
#  datetime.date(2019, 1, 23),
#  datetime.date(2018, 12, 21),
#  datetime.date(2018, 9, 7),
#  datetime.date(2021, 3, 8),
#  datetime.date(2020, 9, 8),
#  datetime.date(2018, 11, 5),
#  datetime.date(2019, 3, 29),
#  datetime.date(2024, 11, 1),
#  datetime.date(2021, 2, 11),
#  datetime.date(2020, 4, 16),
#  datetime.date(2022, 8, 26),
#  datetime.date(2023, 9, 14),
#  datetime.date(2018, 11, 27),
#  datetime.date(2020, 3, 9),
#  datetime.date(2020, 9, 7),
#  datetime.date(2024, 8, 26),
#  datetime.date(2019, 11, 29),
#  datetime.date(2023, 4, 5),
#  datetime.date(2020, 9, 4),
#  datetime.date(2023, 10, 25),
#  datetime.date(2023, 10, 26),
#  datetime.date(2018, 6, 20),
#  datetime.date(2020, 4, 7),
#  datetime.date(2020, 6, 29),
#  datetime.date(2019, 2, 28),
#  datetime.date(2018, 9, 25),
#  datetime.date(2023, 9, 28),
#  datetime.date(2023, 6, 23),
#  datetime.date(2023, 12, 15),
#  datetime.date(2020, 6, 25),
#  datetime.date(2024, 10, 24),
#  datetime.date(2022, 2, 11),
#  datetime.date(2018, 10, 9),
#  datetime.date(2022, 9, 14),
#  datetime.date(2023, 12, 20),
#  datetime.date(2021, 11, 30),
#  datetime.date(2019, 11, 14),
#  datetime.date(2024, 5, 22),
#  datetime.date(2023, 2, 27),
#  datetime.date(2018, 10, 11),
#  datetime.date(2024, 5, 21),
#  datetime.date(2022, 3, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2018, 11, 15),
#  datetime.date(2024, 9, 3),
#  datetime.date(2020, 8, 3),
#  datetime.date(2023, 2, 15),
#  datetime.date(2022, 5, 2),
#  datetime.date(2018, 11, 28),
#  datetime.date(2020, 7, 21),
#  datetime.date(2024, 9, 2),
#  datetime.date(2024, 10, 10),
#  datetime.date(2019, 6, 10),
#  datetime.date(2020, 3, 17),
#  datetime.date(2018, 6, 22),
#  datetime.date(2019, 10, 29),
#  datetime.date(2022, 6, 6),
#  datetime.date(2021, 12, 24),
#  datetime.date(2021, 7, 13),
#  datetime.date(2019, 3, 12),
#  datetime.date(2020, 1, 27),
#  datetime.date(2018, 9, 12),
#  datetime.date(2024, 11, 12),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 2, 18),
#  datetime.date(2018, 5, 14),
#  datetime.date(2021, 2, 3),
#  datetime.date(2024, 6, 25),
#  datetime.date(2018, 1, 16),
#  datetime.date(2018, 11, 30),
#  datetime.date(2021, 4, 15),
#  datetime.date(2024, 7, 9),
#  datetime.date(2023, 12, 28),
#  datetime.date(2022, 2, 3),
#  datetime.date(2024, 7, 22),
#  datetime.date(2018, 2, 7),
#  datetime.date(2021, 1, 25),
#  datetime.date(2024, 8, 5),
#  datetime.date(2018, 9, 24),
#  datetime.date(2019, 2, 22),
#  datetime.date(2021, 9, 20),
#  datetime.date(2024, 2, 7),
#  datetime.date(2023, 12, 11),
#  datetime.date(2021, 7, 12),
#  datetime.date(2020, 5, 28),
#  datetime.date(2023, 1, 20),
#  datetime.date(2018, 4, 24),
#  datetime.date(2021, 7, 16),
#  datetime.date(2021, 10, 27),
#  datetime.date(2019, 1, 16),
#  datetime.date(2019, 1, 17),
#  datetime.date(2020, 3, 31),
#  datetime.date(2018, 2, 8),
#  datetime.date(2022, 9, 15),
#  datetime.date(2022, 11, 3),
#  datetime.date(2022, 8, 2),
#  datetime.date(2022, 4, 27),
#  datetime.date(2018, 8, 9),
#  datetime.date(2024, 3, 7),
#  datetime.date(2023, 9, 25),
#  datetime.date(2018, 12, 17),
#  datetime.date(2023, 11, 17),
#  datetime.date(2022, 12, 7),
#  datetime.date(2019, 1, 28),
#  datetime.date(2021, 2, 22),
#  datetime.date(2020, 8, 7),
#  datetime.date(2021, 11, 23),
#  datetime.date(2024, 9, 19),
#  datetime.date(2018, 10, 26),
#  datetime.date(2021, 6, 16),
#  datetime.date(2021, 10, 19),
#  datetime.date(2021, 9, 30),
#  datetime.date(2020, 8, 13),
#  datetime.date(2024, 11, 19),
#  datetime.date(2019, 3, 8),
#  datetime.date(2022, 12, 20),
#  datetime.date(2021, 4, 6),
#  datetime.date(2020, 1, 16),
#  datetime.date(2018, 7, 27),
#  datetime.date(2019, 8, 8),
#  datetime.date(2020, 5, 20),
#  datetime.date(2022, 1, 17),
#  datetime.date(2022, 4, 21),
#  datetime.date(2021, 6, 3),
#  datetime.date(2023, 5, 26),
#  datetime.date(2021, 8, 30),
#  datetime.date(2019, 8, 2),
#  datetime.date(2021, 1, 8),
#  datetime.date(2022, 8, 5),
#  datetime.date(2021, 1, 13),
#  datetime.date(2024, 6, 7),
#  datetime.date(2021, 10, 28),
#  datetime.date(2023, 3, 22),
#  datetime.date(2018, 10, 5),
#  datetime.date(2018, 2, 26),
#  datetime.date(2024, 10, 15),
#  datetime.date(2021, 6, 28),
#  datetime.date(2019, 9, 26),
#  datetime.date(2020, 8, 21),
#  datetime.date(2018, 2, 1),
#  datetime.date(2019, 4, 8),
#  datetime.date(2018, 10, 25),
#  datetime.date(2024, 1, 30),
#  datetime.date(2022, 2, 25),
#  datetime.date(2024, 8, 16),
#  datetime.date(2019, 4, 11),
#  datetime.date(2021, 9, 9),
#  datetime.date(2018, 5, 24),
#  datetime.date(2020, 12, 23),
#  datetime.date(2021, 3, 25),
#  datetime.date(2018, 10, 17),
#  datetime.date(2022, 12, 13),
#  datetime.date(2021, 2, 10),
#  datetime.date(2023, 11, 10),
#  datetime.date(2023, 1, 17),
#  datetime.date(2018, 7, 9),
#  datetime.date(2020, 12, 18),
#  datetime.date(2022, 6, 2),
#  datetime.date(2024, 6, 5),
#  datetime.date(2020, 9, 11),
#  datetime.date(2022, 10, 31),
#  datetime.date(2019, 9, 27),
#  datetime.date(2021, 1, 4),
#  datetime.date(2019, 6, 20),
#  datetime.date(2023, 10, 10),
#  datetime.date(2021, 9, 21),
#  datetime.date(2019, 8, 21),
#  datetime.date(2021, 12, 3),
#  datetime.date(2024, 1, 29),
#  datetime.date(2022, 12, 30),
#  datetime.date(2023, 2, 22),
#  datetime.date(2024, 9, 26),
#  datetime.date(2022, 11, 24),
#  datetime.date(2024, 3, 18),
#  datetime.date(2024, 7, 29),
#  datetime.date(2024, 2, 8),
#  datetime.date(2018, 8, 14),
#  datetime.date(2019, 12, 18),
#  datetime.date(2020, 10, 28),
#  datetime.date(2021, 3, 12),
#  datetime.date(2021, 2, 26),
#  datetime.date(2018, 12, 10),
#  datetime.date(2018, 4, 4),
#  datetime.date(2020, 7, 14),
#  datetime.date(2023, 10, 20),
#  datetime.date(2021, 3, 31),
#  datetime.date(2018, 12, 31),
#  datetime.date(2023, 12, 5),
#  datetime.date(2019, 5, 27),
#  datetime.date(2021, 1, 21),
#  datetime.date(2022, 1, 18),
#  datetime.date(2018, 4, 20),
#  datetime.date(2019, 5, 31),
#  datetime.date(2023, 10, 4),
#  datetime.date(2022, 3, 28),
#  datetime.date(2023, 12, 1),
#  datetime.date(2020, 1, 17),
#  datetime.date(2020, 11, 20),
#  datetime.date(2021, 5, 7),
#  datetime.date(2023, 4, 19),
#  datetime.date(2024, 1, 18),
#  datetime.date(2021, 9, 16),
#  datetime.date(2023, 1, 27),
#  datetime.date(2024, 5, 18),
#  datetime.date(2021, 3, 5),
#  datetime.date(2022, 5, 5),
#  datetime.date(2021, 9, 29),
#  datetime.date(2023, 5, 19),
#  datetime.date(2018, 2, 14),
#  datetime.date(2022, 5, 23),
#  datetime.date(2021, 1, 19),
#  datetime.date(2019, 7, 11),
#  datetime.date(2021, 2, 23),
#  datetime.date(2024, 3, 11),
#  datetime.date(2019, 7, 10),
#  datetime.date(2020, 10, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2024, 5, 24),
#  datetime.date(2018, 5, 17),
#  datetime.date(2024, 9, 24),
#  datetime.date(2021, 12, 9),
#  datetime.date(2021, 7, 27),
#  datetime.date(2020, 7, 24),
#  datetime.date(2019, 3, 11),
#  datetime.date(2022, 7, 26),
#  datetime.date(2018, 6, 14),
#  datetime.date(2019, 6, 14),
#  datetime.date(2020, 1, 28),
#  datetime.date(2022, 2, 16),
#  datetime.date(2020, 12, 21),
#  datetime.date(2018, 2, 12),
#  datetime.date(2019, 1, 2),
#  datetime.date(2019, 11, 21),
#  datetime.date(2022, 7, 25),
#  datetime.date(2020, 8, 27),
#  datetime.date(2022, 7, 8),
#  datetime.date(2021, 11, 24),
#  datetime.date(2024, 4, 4),
#  datetime.date(2018, 9, 19),
#  datetime.date(2020, 3, 2),
#  datetime.date(2021, 11, 9),
#  datetime.date(2024, 10, 30),
#  datetime.date(2021, 4, 28),
#  datetime.date(2023, 10, 17),
#  datetime.date(2018, 8, 8),
#  datetime.date(2019, 5, 2),
#  datetime.date(2020, 11, 9),
#  datetime.date(2021, 3, 17),
#  datetime.date(2024, 3, 12),
#  datetime.date(2024, 8, 29),
#  datetime.date(2018, 1, 5),
#  datetime.date(2022, 8, 11),
#  datetime.date(2024, 9, 23),
#  datetime.date(2019, 1, 31),
#  datetime.date(2020, 11, 2),
#  datetime.date(2018, 9, 14),
#  datetime.date(2020, 4, 20),
#  datetime.date(2022, 4, 26),
#  datetime.date(2023, 2, 1),
#  datetime.date(2021, 5, 21),
#  datetime.date(2024, 4, 15),
#  datetime.date(2021, 6, 30),
#  datetime.date(2018, 11, 20),
#  datetime.date(2022, 10, 24),
#  datetime.date(2019, 11, 18),
#  datetime.date(2022, 1, 21),
#  datetime.date(2021, 11, 3),
#  datetime.date(2022, 9, 9),
#  datetime.date(2022, 3, 25),
#  datetime.date(2018, 8, 29),
#  datetime.date(2023, 12, 14),
#  datetime.date(2020, 1, 3),
#  datetime.date(2024, 2, 23),
#  datetime.date(2019, 12, 5),
#  datetime.date(2020, 3, 16),
#  datetime.date(2018, 8, 30),
#  datetime.date(2019, 5, 24),
#  datetime.date(2020, 11, 19),
#  datetime.date(2022, 12, 15),
#  datetime.date(2021, 8, 10),
#  datetime.date(2018, 2, 21),
#  datetime.date(2023, 11, 29),
#  datetime.date(2023, 3, 24),
#  datetime.date(2024, 4, 30),
#  datetime.date(2021, 11, 8),
#  datetime.date(2024, 7, 10),
#  datetime.date(2020, 5, 22),
#  datetime.date(2024, 1, 31),
#  datetime.date(2018, 5, 15),
#  datetime.date(2020, 12, 9),
#  datetime.date(2021, 5, 18),
#  datetime.date(2022, 11, 10),
#  datetime.date(2018, 4, 6),
#  datetime.date(2022, 11, 1),
#  datetime.date(2019, 4, 1),
#  datetime.date(2024, 2, 1),
#  datetime.date(2023, 7, 31),
#  datetime.date(2019, 10, 1),
#  datetime.date(2019, 2, 12),
#  datetime.date(2023, 4, 6),
#  datetime.date(2024, 5, 29),
#  datetime.date(2020, 10, 8),
#  datetime.date(2019, 4, 23),
#  datetime.date(2018, 3, 12),
#  datetime.date(2021, 8, 2),
#  datetime.date(2023, 10, 16),
#  datetime.date(2024, 9, 11),
#  datetime.date(2022, 7, 14),
#  datetime.date(2019, 9, 24),
#  datetime.date(2019, 4, 22),
#  datetime.date(2021, 6, 25),
#  datetime.date(2023, 6, 30),
#  datetime.date(2023, 1, 6),
#  datetime.date(2018, 10, 24),
#  datetime.date(2019, 8, 1),
#  datetime.date(2018, 5, 4),
#  datetime.date(2023, 6, 19),
#  datetime.date(2018, 6, 26),
#  datetime.date(2021, 5, 24),
#  datetime.date(2023, 3, 9),
#  datetime.date(2018, 11, 1),
#  datetime.date(2019, 3, 14),
#  datetime.date(2020, 6, 9),
#  datetime.date(2022, 2, 21),
#  datetime.date(2022, 7, 4),
#  datetime.date(2023, 4, 24),
#  datetime.date(2020, 2, 20),
#  datetime.date(2023, 10, 6),
#  datetime.date(2022, 3, 22),
#  datetime.date(2022, 9, 27),
#  datetime.date(2022, 9, 6),
#  datetime.date(2021, 8, 25),
#  datetime.date(2023, 11, 9),
#  datetime.date(2021, 5, 31),
#  datetime.date(2020, 11, 5),
#  datetime.date(2018, 10, 12),
#  datetime.date(2019, 5, 21),
#  datetime.date(2019, 7, 3),
#  datetime.date(2018, 4, 19),
#  datetime.date(2022, 6, 24),
#  datetime.date(2020, 3, 20),
#  datetime.date(2021, 3, 22),
#  datetime.date(2018, 4, 17),
#  datetime.date(2018, 4, 30),
#  datetime.date(2020, 10, 6),
#  datetime.date(2019, 2, 4),
#  datetime.date(2023, 10, 11),
#  datetime.date(2023, 10, 19),
#  datetime.date(2023, 1, 31),
#  datetime.date(2019, 1, 11),
#  datetime.date(2020, 1, 24),
#  datetime.date(2021, 8, 17),
#  datetime.date(2024, 7, 4),
#  datetime.date(2020, 7, 30),
#  datetime.date(2022, 11, 23),
#  datetime.date(2024, 4, 22),
#  datetime.date(2019, 8, 16),
#  datetime.date(2024, 10, 29),
#  datetime.date(2022, 4, 12),
#  datetime.date(2023, 3, 1),
#  datetime.date(2024, 10, 8),
#  datetime.date(2024, 6, 21),
#  datetime.date(2022, 1, 28),
#  datetime.date(2019, 8, 22),
#  datetime.date(2022, 7, 29),
#  datetime.date(2019, 8, 27),
#  datetime.date(2023, 12, 27),
#  datetime.date(2021, 8, 26),
#  datetime.date(2021, 7, 20),
#  datetime.date(2022, 11, 11),
#  datetime.date(2023, 7, 6),
#  datetime.date(2024, 9, 20),
#  datetime.date(2023, 9, 20),
#  datetime.date(2023, 11, 12),
#  datetime.date(2019, 5, 14),
#  datetime.date(2018, 5, 16),
#  datetime.date(2022, 4, 13),
#  datetime.date(2022, 10, 17),
#  datetime.date(2022, 7, 27),
#  datetime.date(2023, 3, 8),
#  datetime.date(2021, 3, 16),
#  datetime.date(2022, 2, 28),
#  datetime.date(2022, 4, 19),
#  datetime.date(2022, 7, 19),
#  datetime.date(2020, 1, 6),
#  datetime.date(2024, 5, 7),
#  datetime.date(2024, 6, 14),
#  datetime.date(2021, 12, 29),
#  datetime.date(2019, 10, 25),
#  datetime.date(2019, 2, 7),
#  datetime.date(2022, 3, 17),
#  datetime.date(2018, 5, 28),
#  datetime.date(2024, 1, 8),
#  datetime.date(2020, 6, 17),
#  datetime.date(2018, 3, 13),
#  datetime.date(2019, 8, 13),
#  datetime.date(2024, 10, 18),
#  datetime.date(2019, 3, 20),
#  datetime.date(2019, 6, 3),
#  datetime.date(2023, 9, 21),
#  datetime.date(2022, 3, 30),
#  datetime.date(2024, 6, 26),
#  datetime.date(2020, 3, 30),
#  datetime.date(2024, 11, 8),
#  datetime.date(2019, 2, 21),
#  datetime.date(2020, 1, 15),
#  datetime.date(2024, 4, 25),
#  datetime.date(2021, 2, 8),
#  datetime.date(2022, 7, 1),
#  datetime.date(2021, 11, 22),
#  datetime.date(2023, 11, 24),
#  datetime.date(2021, 2, 24),
#  datetime.date(2019, 12, 10),
#  datetime.date(2021, 7, 26),
#  datetime.date(2018, 9, 5),
#  datetime.date(2022, 1, 27),
#  datetime.date(2022, 5, 20),
#  datetime.date(2021, 6, 1),
#  datetime.date(2023, 10, 5),
#  datetime.date(2023, 11, 15),
#  datetime.date(2018, 3, 7),
#  datetime.date(2018, 8, 6),
#  datetime.date(2023, 5, 22),
#  datetime.date(2018, 10, 4),
#  datetime.date(2024, 10, 23),
#  datetime.date(2021, 10, 5),
#  datetime.date(2023, 2, 14),
#  datetime.date(2023, 5, 3),
#  datetime.date(2020, 8, 24),
#  datetime.date(2018, 7, 13),
#  datetime.date(2020, 1, 22),
#  datetime.date(2023, 11, 3),
#  datetime.date(2024, 1, 15),
#  datetime.date(2020, 7, 31),
#  datetime.date(2023, 6, 5),
#  datetime.date(2018, 10, 22),
#  datetime.date(2022, 10, 20),
#  datetime.date(2018, 5, 29),
#  datetime.date(2022, 4, 28),
#  datetime.date(2019, 4, 18),
#  datetime.date(2022, 7, 28),
#  datetime.date(2018, 8, 13),
#  datetime.date(2024, 6, 6),
#  datetime.date(2024, 7, 16),
#  datetime.date(2018, 3, 26),
#  datetime.date(2020, 8, 17),
#  datetime.date(2023, 9, 8),
#  datetime.date(2020, 6, 8),
#  datetime.date(2021, 8, 12),
#  datetime.date(2021, 9, 6),
#  datetime.date(2023, 8, 7),
#  datetime.date(2018, 9, 6),
#  datetime.date(2023, 2, 2),
#  datetime.date(2021, 12, 17),
#  datetime.date(2020, 2, 13),
#  datetime.date(2023, 8, 1),
#  datetime.date(2019, 8, 26),
#  datetime.date(2019, 8, 9),
#  datetime.date(2022, 4, 20),
#  datetime.date(2023, 4, 27),
#  datetime.date(2022, 4, 25),
#  datetime.date(2022, 9, 29),
#  datetime.date(2024, 4, 5),
#  datetime.date(2022, 11, 4),
#  datetime.date(2019, 7, 23),
#  datetime.date(2024, 7, 11),
#  datetime.date(2024, 8, 14),
#  datetime.date(2018, 8, 20),
#  datetime.date(2019, 8, 23),
#  datetime.date(2021, 4, 22),
#  datetime.date(2019, 3, 25),
#  datetime.date(2023, 7, 13),
#  datetime.date(2022, 5, 17),
#  datetime.date(2022, 6, 1),
#  datetime.date(2019, 5, 15),
#  datetime.date(2021, 7, 29),
#  datetime.date(2023, 9, 22),
#  datetime.date(2024, 3, 26),
#  datetime.date(2024, 4, 8),
#  datetime.date(2018, 2, 19),
#  datetime.date(2022, 2, 10),
#  datetime.date(2022, 1, 14),
#  datetime.date(2023, 2, 23),
#  datetime.date(2024, 5, 8),
#  datetime.date(2022, 5, 19),
#  datetime.date(2022, 8, 23),
#  datetime.date(2021, 8, 31),
#  datetime.date(2023, 9, 4),
#  datetime.date(2024, 4, 26),
#  datetime.date(2022, 11, 7),
#  datetime.date(2024, 3, 6),
#  datetime.date(2024, 9, 13),
#  datetime.date(2023, 1, 16),
#  datetime.date(2024, 1, 17),
#  datetime.date(2018, 12, 18),
#  datetime.date(2020, 6, 15),
#  datetime.date(2020, 8, 12),
#  datetime.date(2024, 2, 28),
#  datetime.date(2024, 7, 26),
#  datetime.date(2020, 8, 25),
#  datetime.date(2019, 10, 3),
#  datetime.date(2024, 10, 11),
#  datetime.date(2021, 8, 20),
#  datetime.date(2018, 12, 3),
#  datetime.date(2024, 4, 9),
#  datetime.date(2021, 3, 30),
#  datetime.date(2022, 11, 21),
#  datetime.date(2023, 6, 9),
#  datetime.date(2022, 6, 17),
#  datetime.date(2022, 9, 5),
#  datetime.date(2023, 8, 11),
#  datetime.date(2022, 6, 20),
#  datetime.date(2021, 7, 1),
#  datetime.date(2024, 5, 6),
#  datetime.date(2021, 5, 12),
#  datetime.date(2023, 11, 20),
#  datetime.date(2018, 9, 18),
#  datetime.date(2024, 1, 3),
#  datetime.date(2022, 1, 25),
#  datetime.date(2018, 2, 15),
#  datetime.date(2018, 10, 19),
#  datetime.date(2021, 12, 27),
#  datetime.date(2018, 5, 23),
#  datetime.date(2018, 12, 28),
#  datetime.date(2024, 7, 18),
#  datetime.date(2018, 1, 8),
#  datetime.date(2018, 9, 11),
#  datetime.date(2024, 9, 6),
#  datetime.date(2021, 11, 11),
#  datetime.date(2024, 11, 14),
#  datetime.date(2022, 5, 26),
#  datetime.date(2022, 12, 26),
#  datetime.date(2019, 11, 25),
#  datetime.date(2020, 6, 23),
#  datetime.date(2021, 11, 4),
#  datetime.date(2022, 3, 8),
#  datetime.date(2024, 1, 12),
#  datetime.date(2020, 4, 30),
#  datetime.date(2020, 6, 12),
#  datetime.date(2024, 2, 16),
#  datetime.date(2020, 1, 30),
#  datetime.date(2019, 3, 22),
#  datetime.date(2023, 5, 11),
#  datetime.date(2021, 12, 7),
#  datetime.date(2024, 10, 4),
#  datetime.date(2023, 4, 3),
#  datetime.date(2024, 5, 30),
#  datetime.date(2024, 2, 6),
#  datetime.date(2024, 6, 20),
#  datetime.date(2021, 11, 29),
#  datetime.date(2021, 5, 6),
#  datetime.date(2021, 3, 2),
#  datetime.date(2023, 7, 21),
#  datetime.date(2018, 4, 9),
#  datetime.date(2019, 1, 7),
#  datetime.date(2022, 9, 19),
#  datetime.date(2021, 4, 7),
#  datetime.date(2018, 12, 24),
#  datetime.date(2022, 10, 14),
#  datetime.date(2022, 4, 18),
#  datetime.date(2022, 11, 25),
#  datetime.date(2020, 7, 10),
#  datetime.date(2022, 5, 13),
#  datetime.date(2019, 12, 3),
#  datetime.date(2022, 12, 8),
#  datetime.date(2018, 3, 1),
#  datetime.date(2019, 2, 14),
#  datetime.date(2018, 7, 18),
#  datetime.date(2020, 7, 1),
#  datetime.date(2023, 11, 30),
#  datetime.date(2021, 7, 9),
#  datetime.date(2022, 2, 23),
#  datetime.date(2018, 7, 16),
#  datetime.date(2022, 8, 25),
#  datetime.date(2019, 7, 17),
#  datetime.date(2024, 3, 5),
#  datetime.date(2020, 1, 31),
#  datetime.date(2019, 5, 7),
#  datetime.date(2020, 7, 9),
#  datetime.date(2018, 3, 6),
#  datetime.date(2019, 5, 30),
#  datetime.date(2022, 9, 8),
#  datetime.date(2018, 11, 19),
#  datetime.date(2023, 3, 13),
#  datetime.date(2018, 11, 2),
#  datetime.date(2024, 1, 4),
#  datetime.date(2024, 1, 16),
#  datetime.date(2018, 10, 10),
#  datetime.date(2018, 9, 28),
#  datetime.date(2020, 3, 3),
#  datetime.date(2020, 4, 21),
#  datetime.date(2024, 2, 2),
#  datetime.date(2022, 4, 7),
#  datetime.date(2024, 8, 21),
#  datetime.date(2022, 1, 7),
#  datetime.date(2024, 3, 27),
#  datetime.date(2022, 1, 11),
#  datetime.date(2024, 10, 1),
#  datetime.date(2024, 10, 21),
#  datetime.date(2024, 11, 6),
#  datetime.date(2021, 2, 16),
#  datetime.date(2020, 8, 31),
#  datetime.date(2018, 7, 26),
#  datetime.date(2018, 8, 7),
#  datetime.date(2022, 5, 31),
#  datetime.date(2022, 4, 8),
#  datetime.date(2020, 5, 14),
#  datetime.date(2022, 10, 13),
#  datetime.date(2023, 3, 31),
#  datetime.date(2021, 12, 16),
#  datetime.date(2019, 11, 20),
#  datetime.date(2020, 10, 23),
#  datetime.date(2024, 11, 27),
#  datetime.date(2018, 8, 1),
#  datetime.date(2022, 9, 2),
#  datetime.date(2023, 2, 7),
#  datetime.date(2021, 6, 4),
#  datetime.date(2018, 11, 29),
#  datetime.date(2021, 4, 8),
#  datetime.date(2023, 1, 23),
#  datetime.date(2018, 3, 8),
#  datetime.date(2020, 4, 27),
#  datetime.date(2020, 9, 9),
#  datetime.date(2018, 6, 15),
#  datetime.date(2020, 9, 24),
#  datetime.date(2023, 2, 3),
#  datetime.date(2023, 2, 17),
#  datetime.date(2021, 6, 9),
#  datetime.date(2020, 2, 1),
#  datetime.date(2020, 12, 28),
#  datetime.date(2019, 1, 8),
#  datetime.date(2018, 2, 27),
#  datetime.date(2023, 11, 16),
#  datetime.date(2018, 2, 20),
#  datetime.date(2022, 4, 4),
#  datetime.date(2023, 1, 9),
#  datetime.date(2021, 6, 22),
#  datetime.date(2019, 1, 18),
#  datetime.date(2019, 6, 18),
#  datetime.date(2019, 5, 8),
#  datetime.date(2019, 5, 10),
#  datetime.date(2020, 6, 5),
#  datetime.date(2021, 9, 27),
#  datetime.date(2022, 10, 21),
#  datetime.date(2023, 6, 12),
#  datetime.date(2024, 1, 25),
#  datetime.date(2019, 10, 31),
#  datetime.date(2023, 7, 17),
#  datetime.date(2022, 2, 9),
#  datetime.date(2020, 9, 1),
#  datetime.date(2019, 1, 9),
#  datetime.date(2019, 12, 2),
#  datetime.date(2021, 8, 3),
#  datetime.date(2023, 2, 16),
#  datetime.date(2019, 12, 23),
#  datetime.date(2021, 1, 7),
#  datetime.date(2023, 12, 4),
#  datetime.date(2023, 1, 13),
#  datetime.date(2019, 9, 23),
#  datetime.date(2024, 9, 18),
#  datetime.date(2020, 12, 11),
#  datetime.date(2019, 3, 18),
#  datetime.date(2024, 3, 15),
#  datetime.date(2018, 7, 31),
#  datetime.date(2024, 8, 28),
#  datetime.date(2019, 10, 18),
#  datetime.date(2020, 2, 10),
#  datetime.date(2023, 4, 21),
#  datetime.date(2024, 3, 22),
#  datetime.date(2021, 1, 11),
#  datetime.date(2022, 5, 27),
#  datetime.date(2023, 5, 9),
#  datetime.date(2022, 10, 25),
#  datetime.date(2018, 7, 6),
#  datetime.date(2018, 1, 10),
#  datetime.date(2019, 11, 7),
#  datetime.date(2018, 12, 4),
#  datetime.date(2021, 12, 23),
#  datetime.date(2020, 4, 17),
#  datetime.date(2018, 10, 30),
#  datetime.date(2019, 5, 28),
#  datetime.date(2019, 10, 9),
#  datetime.date(2020, 7, 20),
#  datetime.date(2023, 5, 8),
#  datetime.date(2021, 6, 21),
#  datetime.date(2018, 1, 29),
#  datetime.date(2019, 2, 8),
#  datetime.date(2023, 4, 28),
#  datetime.date(2019, 1, 15),
#  datetime.date(2020, 12, 1),
#  datetime.date(2018, 1, 30),
#  datetime.date(2019, 6, 7),
#  datetime.date(2018, 2, 22),
#  datetime.date(2020, 1, 9),
#  datetime.date(2023, 8, 28),
#  datetime.date(2022, 12, 21),
#  datetime.date(2019, 4, 12),
#  datetime.date(2018, 12, 6),
#  datetime.date(2019, 10, 27),
#  datetime.date(2024, 6, 19),
#  datetime.date(2020, 6, 26),
#  datetime.date(2018, 6, 25),
#  datetime.date(2022, 7, 18),
#  datetime.date(2024, 9, 10),
#  datetime.date(2021, 9, 28),
#  datetime.date(2023, 8, 14),
#  datetime.date(2020, 1, 10),
#  datetime.date(2022, 2, 14),
#  datetime.date(2022, 9, 12),
#  datetime.date(2024, 7, 12),
#  datetime.date(2018, 7, 23),
#  datetime.date(2018, 3, 28),
#  datetime.date(2022, 8, 30),
#  datetime.date(2018, 8, 24),
#  datetime.date(2018, 1, 25),
#  datetime.date(2021, 1, 27),
#  datetime.date(2020, 1, 21),
#  datetime.date(2023, 4, 25),
#  datetime.date(2024, 1, 11),
#  datetime.date(2023, 5, 5),
#  datetime.date(2020, 6, 10),
#  datetime.date(2024, 3, 19),
#  datetime.date(2022, 7, 12),
#  datetime.date(2020, 1, 7),
#  datetime.date(2024, 10, 28),
#  datetime.date(2023, 3, 17),
#  datetime.date(2018, 11, 14),
#  datetime.date(2023, 2, 20),
#  datetime.date(2019, 10, 7),
#  datetime.date(2019, 3, 13),
#  datetime.date(2018, 4, 16),
#  datetime.date(2023, 7, 11),
#  datetime.date(2024, 8, 22),
#  datetime.date(2020, 2, 24),
#  datetime.date(2020, 9, 16),
#  datetime.date(2022, 11, 14),
#  datetime.date(2020, 12, 10),
#  datetime.date(2018, 2, 23),
#  datetime.date(2022, 6, 21),
#  datetime.date(2024, 5, 16),
#  datetime.date(2020, 3, 24),
#  datetime.date(2022, 9, 13),
#  datetime.date(2021, 1, 1),
#  datetime.date(2023, 10, 9),
#  datetime.date(2018, 4, 2),
#  datetime.date(2021, 12, 15),
#  datetime.date(2023, 12, 13),
#  datetime.date(2022, 12, 28),
#  datetime.date(2022, 4, 22),
#  datetime.date(2018, 5, 30),
#  datetime.date(2023, 5, 12),
#  datetime.date(2021, 10, 1),
#  datetime.date(2022, 12, 23),
#  datetime.date(2024, 12, 3),
#  datetime.date(2024, 1, 2),
#  datetime.date(2020, 4, 9),
#  datetime.date(2021, 6, 7),
#  datetime.date(2019, 4, 24),
#  datetime.date(2023, 6, 21),
#  datetime.date(2022, 2, 15),
#  datetime.date(2018, 10, 16),
#  datetime.date(2022, 8, 12),
#  datetime.date(2024, 6, 4),
#  datetime.date(2020, 8, 18),
#  datetime.date(2019, 7, 18),
#  datetime.date(2019, 5, 13),
#  datetime.date(2024, 5, 14),
#  datetime.date(2024, 8, 12),
#  datetime.date(2019, 11, 13),
#  datetime.date(2019, 10, 16),
#  datetime.date(2020, 11, 4),
#  datetime.date(2020, 10, 9),
#  datetime.date(2024, 3, 20),
#  datetime.date(2023, 2, 6),
#  datetime.date(2022, 6, 27),
#  datetime.date(2020, 5, 19),
#  datetime.date(2022, 6, 14),
#  datetime.date(2018, 8, 3),
#  datetime.date(2020, 4, 24),
#  datetime.date(2022, 1, 6),
#  datetime.date(2019, 3, 7),
#  datetime.date(2024, 12, 2),
#  datetime.date(2019, 4, 15),
#  datetime.date(2023, 9, 5),
#  datetime.date(2020, 12, 22),
#  datetime.date(2023, 11, 8),
#  datetime.date(2023, 1, 5),
#  datetime.date(2022, 12, 5),
#  datetime.date(2023, 10, 30),
#  datetime.date(2019, 7, 26),
#  datetime.date(2020, 10, 27),
#  datetime.date(2019, 10, 22),
#  datetime.date(2019, 9, 19),
#  datetime.date(2023, 7, 4),
#  datetime.date(2020, 5, 12),
#  datetime.date(2019, 2, 25),
#  datetime.date(2018, 5, 31),
#  datetime.date(2020, 12, 17),
#  datetime.date(2022, 8, 4),
#  datetime.date(2021, 3, 15),
#  datetime.date(2020, 9, 23),
#  datetime.date(2021, 5, 19),
#  datetime.date(2024, 1, 20),
#  datetime.date(2018, 7, 11),
#  datetime.date(2018, 12, 12),
#  datetime.date(2018, 2, 28),
#  datetime.date(2019, 6, 17),
#  datetime.date(2019, 12, 30),
#  datetime.date(2020, 7, 13),
#  datetime.date(2024, 4, 18),
#  datetime.date(2020, 5, 11),
#  datetime.date(2018, 11, 22),
#  datetime.date(2020, 2, 3),
#  datetime.date(2020, 2, 11),
#  datetime.date(2023, 8, 21),
#  datetime.date(2018, 12, 13),
#  datetime.date(2021, 4, 23),
#  datetime.date(2019, 7, 16),
#  datetime.date(2023, 3, 16),
#  datetime.date(2024, 9, 9),
#  datetime.date(2020, 2, 19),
#  datetime.date(2019, 5, 3),
#  datetime.date(2019, 7, 8),
#  datetime.date(2019, 4, 16),
#  datetime.date(2023, 2, 10),
#  datetime.date(2018, 6, 7),
#  datetime.date(2020, 6, 16),
#  datetime.date(2019, 3, 19),
#  datetime.date(2020, 5, 29),
#  datetime.date(2021, 12, 10),
#  datetime.date(2021, 6, 24),
#  datetime.date(2021, 4, 12),
#  datetime.date(2020, 2, 6),
#  datetime.date(2022, 3, 14),
#  datetime.date(2023, 11, 23),
#  datetime.date(2021, 1, 12),
#  datetime.date(2020, 10, 13),
#  datetime.date(2018, 3, 23),
#  datetime.date(2021, 9, 3),
#  datetime.date(2021, 12, 8),
#  datetime.date(2023, 6, 8),
#  datetime.date(2019, 7, 1),
#  datetime.date(2020, 1, 2),
#  datetime.date(2018, 4, 26),
#  datetime.date(2021, 4, 1),
#  datetime.date(2019, 9, 17),
#  datetime.date(2020, 2, 14),
#  datetime.date(2022, 7, 13),
#  datetime.date(2019, 9, 30),
#  datetime.date(2018, 4, 13),
#  datetime.date(2024, 8, 7),
#  datetime.date(2018, 7, 20),
#  datetime.date(2022, 9, 26),
#  datetime.date(2022, 2, 7),
#  datetime.date(2022, 5, 6),
#  datetime.date(2023, 11, 28),
#  datetime.date(2021, 7, 14),
#  datetime.date(2020, 8, 11),
#  datetime.date(2023, 12, 8),
#  datetime.date(2024, 1, 10),
#  datetime.date(2020, 6, 3),
#  datetime.date(2023, 6, 28),
#  datetime.date(2021, 2, 2),
#  datetime.date(2018, 2, 2),
#  datetime.date(2023, 4, 20),
#  datetime.date(2024, 11, 21),
#  datetime.date(2018, 1, 24),
#  datetime.date(2023, 1, 25),
#  datetime.date(2019, 12, 27),
#  datetime.date(2023, 7, 25),
#  datetime.date(2019, 7, 19),
#  datetime.date(2020, 11, 14),
#  datetime.date(2019, 6, 21),
#  datetime.date(2024, 10, 31),
#  datetime.date(2018, 2, 5),
#  datetime.date(2022, 1, 3),
#  datetime.date(2019, 4, 26),
#  datetime.date(2018, 6, 28),
#  datetime.date(2019, 8, 28),
#  datetime.date(2019, 8, 5),
#  datetime.date(2022, 6, 10),
#  datetime.date(2024, 10, 14),
#  datetime.date(2020, 9, 28),
#  datetime.date(2024, 7, 19),
#  datetime.date(2022, 3, 31),
#  datetime.date(2023, 3, 10),
#  datetime.date(2023, 5, 25),
#  datetime.date(2024, 5, 17),
#  datetime.date(2022, 1, 12),
#  datetime.date(2021, 12, 28),
#  datetime.date(2018, 4, 23),
#  datetime.date(2024, 2, 20),
#  datetime.date(2024, 9, 12),
#  datetime.date(2021, 4, 13),
#  datetime.date(2018, 8, 2),
#  datetime.date(2019, 8, 29),
#  datetime.date(2024, 5, 10),
#  datetime.date(2018, 1, 2),
#  datetime.date(2024, 4, 3),
#  datetime.date(2023, 8, 17),
#  datetime.date(2023, 5, 18),
#  datetime.date(2020, 11, 26),
#  datetime.date(2019, 12, 17),
#  datetime.date(2023, 9, 7),
#  datetime.date(2021, 12, 1),
#  datetime.date(2020, 3, 13),
#  datetime.date(2020, 1, 13),
#  datetime.date(2019, 11, 11),
#  datetime.date(2021, 9, 22),
#  datetime.date(2020, 5, 5),
#  datetime.date(2021, 6, 14),
#  datetime.date(2022, 10, 6),
#  datetime.date(2020, 7, 22),
#  datetime.date(2021, 1, 20),
#  datetime.date(2023, 6, 27),
#  datetime.date(2020, 7, 15),
#  datetime.date(2020, 11, 11),
#  datetime.date(2020, 11, 17),
#  datetime.date(2023, 7, 27),
#  datetime.date(2022, 8, 8),
#  datetime.date(2019, 2, 26),
#  datetime.date(2022, 3, 11),
#  datetime.date(2021, 1, 22),
#  datetime.date(2021, 5, 5),
#  datetime.date(2022, 3, 29),
#  datetime.date(2018, 12, 27),
#  datetime.date(2022, 2, 22),
#  datetime.date(2022, 4, 1),
#  datetime.date(2021, 11, 12),
#  datetime.date(2022, 11, 16),
#  datetime.date(2019, 5, 23),
#  datetime.date(2020, 8, 10),
#  datetime.date(2018, 5, 7),
#  datetime.date(2021, 9, 15),
#  datetime.date(2021, 10, 7),
#  datetime.date(2020, 7, 2),
#  datetime.date(2019, 8, 6),
#  datetime.date(2021, 1, 18),
#  datetime.date(2018, 12, 5),
#  datetime.date(2023, 10, 23),
#  datetime.date(2019, 12, 4),
#  datetime.date(2020, 4, 3),
#  datetime.date(2021, 8, 16),
#  datetime.date(2020, 3, 23),
#  datetime.date(2018, 4, 12),
#  datetime.date(2021, 8, 4),
#  datetime.date(2020, 11, 6),
#  datetime.date(2018, 10, 3),
#  datetime.date(2018, 3, 14),
#  datetime.date(2024, 7, 3),
#  datetime.date(2019, 7, 30),
#  datetime.date(2023, 6, 1),
#  datetime.date(2024, 2, 19),
#  datetime.date(2019, 7, 22),
#  datetime.date(2018, 6, 5),
#  datetime.date(2018, 7, 3),
#  datetime.date(2023, 6, 15),
#  datetime.date(2018, 6, 4),
#  datetime.date(2019, 1, 24),
#  datetime.date(2020, 5, 26),
#  datetime.date(2021, 1, 29),
#  datetime.date(2021, 3, 18),
#  datetime.date(2024, 4, 2),
#  datetime.date(2024, 6, 13),
#  datetime.date(2024, 11, 22),
#  datetime.date(2021, 5, 28),
#  datetime.date(2023, 11, 7),
#  datetime.date(2023, 5, 23),
#  datetime.date(2023, 9, 1),
#  datetime.date(2018, 5, 11),
#  datetime.date(2022, 1, 13),
#  datetime.date(2023, 10, 31),
#  datetime.date(2023, 4, 17),
#  datetime.date(2019, 1, 21),
#  datetime.date(2021, 5, 17),
#  datetime.date(2022, 10, 7),
#  datetime.date(2024, 10, 3),
#  datetime.date(2024, 6, 11),
#  datetime.date(2019, 1, 14),
#  ...}

# %%
PORTFOLIO_VALUE = 10_00_000 # 10 Lacs
# RPT_PCT = 0.01 # 1% RPT
SLIPPAGE_ = 0.0001
LEVERAGE_ = 5

# %%
import pandas as pd

def calculate_signals(df, n, rsi_period, rsi_overbought, ema_length):
    # Calculate RSI
    def calculate_rsi(series, period):
        # Calculate the price changes
        delta = series.diff()
    
        # Separate gains and losses
        gain = delta.where(delta > 0, 0)
        loss = -delta.where(delta < 0, 0)
    
        # Calculate the first average gain and loss (Simple Moving Average for the first period)
        avg_gain = gain.rolling(window=period, min_periods=period).mean()
        avg_loss = loss.rolling(window=period, min_periods=period).mean()
    
        # Calculate the subsequent smoothed averages (similar to EMA)
        for i in range(period, len(series)):
            avg_gain.iloc[i] = (avg_gain.iloc[i - 1] * (period - 1) + gain.iloc[i]) / period
            avg_loss.iloc[i] = (avg_loss.iloc[i - 1] * (period - 1) + loss.iloc[i]) / period
    
        # Calculate the Relative Strength (RS) and the RSI
        rs = avg_gain / avg_loss
        rsi = 100 - (100 / (1 + rs))
    
        return rsi

    # Apply the TradingView-style RSI calculation
    df['RSI'] = calculate_rsi(df['close'], rsi_period)

    # Calculate the previous n candles' low
    df['Prev_N_Low'] = df['low'].rolling(window=n).min().shift(1)
    df['ema'] = df['close'].ewm(span=ema_length, adjust=False).mean()

    # Signal generation logic
    df['Sell_Signal'] = (
        (df['close'] < df['Prev_N_Low']) &
        (df['RSI'] > rsi_overbought)
    )

    return df
# Out:
#   Cell In[528], line 33
#     df['Prev_N_Low'] = df['low'].rolling(window=n).min().shift(1)
#     ^
# IndentationError: unexpected indent

# %%
bnf_1min.head()
# Out:
#                         time       open       high        low      close  MA  \
# 0  2018-01-01T09:15:00+05:30 25566.4500 25588.0000 25496.5500 25551.5000 NaN
# 1  2018-01-01T09:45:00+05:30 25551.7000 25574.2500 25537.1500 25561.5000 NaN
# 2  2018-01-01T10:15:00+05:30 25563.6500 25573.2500 25541.4000 25554.0500 NaN
# 3  2018-01-01T10:45:00+05:30 25556.3000 25562.6500 25545.0500 25552.6500 NaN
# 4  2018-01-01T11:15:00+05:30 25555.0000 25566.3000 25547.8500 25551.8000 NaN
#
#    Plot  Zero line  MACD Signal                  datetime  RSI  Prev_N_Low  \
# 0   NaN          0          NaN 2018-01-01 09:15:00+05:30  NaN         NaN
# 1   NaN          0          NaN 2018-01-01 09:45:00+05:30  NaN         NaN
# 2   NaN          0          NaN 2018-01-01 10:15:00+05:30  NaN         NaN
# 3   NaN          0          NaN 2018-01-01 10:45:00+05:30  NaN         NaN
# 4   NaN          0          NaN 2018-01-01 11:15:00+05:30  NaN         NaN
#
#          ema  Sell_Signal
# 0 25551.5000        False
# 1 25553.1667        False
# 2 25553.3139        False
# 3 25553.2032        False
# 4 25552.9694        False

# %%
lev_ = 5
portfolio_value = 10000000
lot_size_ = 15
slippage_ = 0.0001

# %%
def backtest_short(df, n, rsi_period, rsi_overbought, ema_length):
    trade_book = []
    in_trade = False
    points = 0
    is_trailing_active = False
    trailing_sl = 0
    df = calculate_signals(df, n, rsi_period, rsi_overbought, ema_length)
    # print(df[df['Sell_Signal']].to_string())
    for i in range(n, len(df)):
        # print(i, df.loc[i], df.loc[i, 'open'])
        # break
        if df.loc[i, 'Sell_Signal'] and not in_trade:
            # Entry Triggered
            entry_price = df.loc[i, 'close']
            entry_time = df.loc[i, 'datetime']
            initial_sl = df.loc[i-n:i, 'high'].max()
            sl_in_points = initial_sl - entry_price
            target = 5 * sl_in_points
            in_trade = True

        if in_trade:
            if df.loc[i, 'high'] < df.loc[i, 'ema']:
                is_trailing_active = True
            if is_trailing_active:
                trailing_sl = df.loc[i, 'ema']
            # print(df.loc[i, 'open'], initial_sl)
            # break
            if df.loc[i, 'open'] > initial_sl and not points:
                # Gap condition
                if df.loc[i, 'close'] < initial_sl:
                    initial_sl = df.loc[i, 'high']
                else:
                    exit_price = df.loc[i, 'close']
                    exit_time = df.loc[i, 'datetime']
                    in_trade = False
                    remark = 'Gap SL'
                    points = entry_price - exit_price
            if df.loc[i, 'high'] > initial_sl and not points:
                # Initial SL Hit
                exit_price = df.loc[i, 'close']
                exit_time = df.loc[i, 'datetime']
                in_trade = False
                remark = 'Initial SL'
                points = entry_price - exit_price
            if is_trailing_active:
                if df.loc[i, 'close'] > trailing_sl and not points:
                    # TSL Hit
                    exit_price = df.loc[i, 'close']
                    exit_time = df.loc[i, 'datetime']
                    in_trade = False
                    remark = 'Trailing SL'
                    points = entry_price - exit_price
            if df.loc[i, 'low'] < entry_price - target and not points:
                # Target Hit
                exit_price = entry_price - target
                exit_time = df.loc[i, 'datetime']
                in_trade = False
                remark = 'Target'
                points = entry_price - exit_price

        if points:
            index_lev = lev_
            qty = int(round(portfolio_value * index_lev / entry_price / lot_size_)) * lot_size_
            slippage = slippage_ * (entry_price + exit_price)
            final_points = points - slippage
            trade = {
                "Trade Type": "Short",
                "Entry Time": entry_time,
                "Entry Price": entry_price,
                "Initial SL": initial_sl,
                "Trailing SL": trailing_sl,
                "Exit Time": exit_time,
                "Exit Price": exit_price,
                "Points Captured": points,
                "Slippage in Points": slippage,
                "After Costs": final_points,
                "PnL": final_points * qty,
                "Remarks": remark,
                "Qty": qty,
                "Leverage": index_lev,
                "ROI%": (final_points * qty / portfolio_value) * 100,
                "Trade Year": entry_time.year,
                "Trade Month": entry_time.month,
            }
            # print(trade)
            trade_book.append(trade)
            points = 0
            in_trade = False
            is_trailing_active = False
            trailing_sl = 0

    return pd.DataFrame(trade_book)

# %%
tb = backtest_short(bnf_1min, n=3, rsi_period=7, rsi_overbought=65, ema_length=10)

# %%
def generate_stats(tb_expiry, variation):
    stats_df8 = pd.DataFrame(
        index=range(2018, 2025),
        columns=[
            "Total ROI",
            "Total Trades",
            "Win Rate",
            "Avg Profit% per Trade",
            "Avg Loss% per Trade",
            "Max Drawdown",
            "ROI/DD Ratio",
            "Variation",
        ],
    )
    combined_df_sorted = tb_expiry
    # combined_df_sorted = tb_expiry_ce
    # combined_df_sorted = tb_expiry_pe
    
    # Iterate over each year
    for year in range(2018, 2025):
        # Filter trades for the current year
        year_trades = combined_df_sorted[(combined_df_sorted["Trade Year"] == year)]
    
        # Calculate total ROI
        total_roi = year_trades["ROI%"].sum()
    
        # Calculate total number of trades
        total_trades = len(year_trades)
    
        # Calculate win rate
        win_rate = (year_trades["ROI%"] > 0).mean() * 100
    
        # Calculate average profit per trade
        avg_profit = year_trades[year_trades["ROI%"] > 0]["ROI%"].mean()
    
        # Calculate average loss per trade
        avg_loss = year_trades[year_trades["ROI%"] < 0]["ROI%"].mean()
    
        # Calculate maximum drawdown
        max_drawdown = (
            year_trades["ROI%"].cumsum() - year_trades["ROI%"].cumsum().cummax()
        ).min()
    
        # Calculate ROI/DD ratio
        roi_dd_ratio = total_roi / abs(max_drawdown)

        variation = variation
    
        # Store the statistics in the DataFrame
        stats_df8.loc[year] = [
            total_roi,
            total_trades,
            win_rate,
            avg_profit,
            avg_loss,
            max_drawdown,
            roi_dd_ratio,
            variation,
        ]
    
    # Calculate overall statistics
    overall_total_roi = stats_df8["Total ROI"].sum()
    overall_total_trades = stats_df8["Total Trades"].sum()
    overall_win_rate = (combined_df_sorted["ROI%"] > 0).mean() * 100
    overall_avg_profit = combined_df_sorted[combined_df_sorted["ROI%"] > 0]["ROI%"].mean()
    overall_avg_loss = combined_df_sorted[combined_df_sorted["ROI%"] < 0]["ROI%"].mean()
    overall_max_drawdown = (
        combined_df_sorted["ROI%"].cumsum() - combined_df_sorted["ROI%"].cumsum().cummax()
    ).min()
    overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
    overall_variation = variation
    
    # Store the overall statistics in the DataFrame
    stats_df8.loc["Overall"] = [
        overall_total_roi,
        overall_total_trades,
        overall_win_rate,
        overall_avg_profit,
        overall_avg_loss,
        overall_max_drawdown,
        overall_roi_dd_ratio,
        overall_variation,
    ]
    return {overall_roi_dd_ratio : stats_df8}

# %%
variation = 1
stats = generate_stats(tb, variation)
for x, y in stats.items():
    final_stats = y

final_stats
# Out:
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2018      -9.1190           14  42.8571                0.8933
# 2019      34.7243           10  60.0000                6.8465
# 2020      76.8846           18  66.6667                7.9801
# 2021      21.3986           15  40.0000                7.7230
# 2022      39.2466           20  50.0000                6.5214
# 2023      -4.4168           12  25.0000                4.8966
# 2024       8.4831           11  36.3636                5.8314
# Overall  167.2012     100.0000  47.0000                6.2078
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio Variation
# 2018                -1.8099     -12.6805      -0.7191         1
# 2019                -1.5887      -3.2626      10.6432         1
# 2020                -3.1460     -10.0492       7.6508         1
# 2021                -2.7711     -16.5736       1.2911         1
# 2022                -2.5967     -13.9560       2.8122         1
# 2023                -2.1230     -11.3722      -0.3884         1
# 2024                -2.1204      -9.0676       0.9355         1
# Overall             -2.3503     -18.5185       9.0289    1.0000

# %%
tb[tb['Trade Year'] > 2023]
# Out:
#     Trade Type                Entry Time  Entry Price  Initial SL  \
# 186      Short 2024-01-05 10:15:00+05:30   48166.6500  48381.9500
# 187      Short 2024-01-12 14:45:00+05:30   47659.9500  47873.7000
# 188      Short 2024-01-18 12:15:00+05:30   45862.6500  46184.0500
# 189      Short 2024-01-19 10:45:00+05:30   45930.1500  46249.8500
# 190      Short 2024-01-24 11:15:00+05:30   45057.2000  45485.5000
# 191      Short 2024-01-25 09:45:00+05:30   44824.3500  45148.2000
# 192      Short 2024-01-31 12:15:00+05:30   45915.6500  46179.7500
# 193      Short 2024-02-12 09:45:00+05:30   45376.3500  45748.5000
# 194      Short 2024-02-13 15:15:00+05:30   45419.8500  45750.4000
# 195      Short 2024-03-20 14:15:00+05:30   46283.9500  46655.5500
# 196      Short 2024-05-30 14:15:00+05:30   48736.5500  49044.6000
# 197      Short 2024-06-28 11:15:00+05:30   52834.8000  53023.1000
# 198      Short 2024-07-09 12:15:00+05:30   52493.9500  52626.6000
# 199      Short 2024-07-19 09:15:00+05:30   52551.8500  52782.7500
# 200      Short 2024-08-02 12:15:00+05:30   51391.2000  51568.3500
# 201      Short 2024-08-21 13:15:00+05:30   50422.6000  50607.2000
# 202      Short 2024-08-29 11:15:00+05:30   51152.6500  51304.0500
# 203      Short 2024-09-09 12:15:00+05:30   50649.8500  50891.6500
# 204      Short 2024-09-18 13:15:00+05:30   52708.2000  52954.2000
# 205      Short 2024-09-19 11:15:00+05:30   52915.9500  53299.7500
# 206      Short 2024-10-04 12:15:00+05:30   51845.4500  52358.3500
# 207      Short 2024-10-14 12:45:00+05:30   51686.2000  51792.2500
# 208      Short 2024-11-25 12:15:00+05:30   52168.0000  52295.6000
#
#      Trailing SL                 Exit Time  Exit Price  Points Captured  \
# 186   48076.0490 2024-01-05 14:45:00+05:30  48167.6000          -0.9500
# 187       0.0000 2024-01-15 09:15:00+05:30  48073.5500        -413.6000
# 188   45926.3041 2024-01-19 09:15:00+05:30  46084.8000        -222.1500
# 189   45831.7843 2024-01-20 09:15:00+05:30  45873.5000          56.6500
# 190   45006.9758 2024-01-24 14:15:00+05:30  45098.7500         -41.5500
# 191   44702.1564 2024-01-25 14:45:00+05:30  44872.4500         -48.1000
# 192       0.0000 2024-02-01 11:45:00+05:30  46098.9500        -183.3000
# 193   45055.1683 2024-02-13 09:15:00+05:30  45139.2500         237.1000
# 194   45304.8074 2024-02-14 10:45:00+05:30  45361.3500          58.5000
# 195       0.0000 2024-03-21 09:15:00+05:30  46809.2500        -525.3000
# 196       0.0000 2024-05-31 09:15:00+05:30  48990.9500        -254.4000
# 197   52536.4599 2024-07-01 11:15:00+05:30  52566.7500         268.0500
# 198   52156.3384 2024-07-11 10:15:00+05:30  51830.7000         663.2500
# 199   52326.7843 2024-07-22 09:45:00+05:30  52365.4500         186.4000
# 200   51494.3934 2024-08-02 13:15:00+05:30  51558.3500        -167.1500
# 201   50568.9933 2024-08-21 14:45:00+05:30  50681.6500        -259.0500
# 202       0.0000 2024-08-29 12:15:00+05:30  51308.0500        -155.4000
# 203   50766.9017 2024-09-09 13:15:00+05:30  50846.5000        -196.6500
# 204       0.0000 2024-09-19 09:15:00+05:30  53277.5500        -569.3500
# 205       0.0000 2024-09-20 09:15:00+05:30  53103.0500        -187.1000
# 206   50940.5401 2024-10-08 10:15:00+05:30  51018.5000         826.9500
# 207       0.0000 2024-10-14 13:45:00+05:30  51782.0500         -95.8500
# 208       0.0000 2024-11-25 15:15:00+05:30  52199.4000         -31.4000
#
#      Slippage in Points  After Costs          PnL      Remarks   Qty  \
# 186              9.6334     -10.5834  -10953.8449  Trailing SL  1035
# 187              9.5733    -423.1734 -444332.0175   Initial SL  1050
# 188              9.1947    -231.3447 -253322.4958  Trailing SL  1095
# 189              9.1804      47.4696   51979.2503  Trailing SL  1095
# 190              9.0156     -50.5656  -56127.8105  Trailing SL  1110
# 191              8.9697     -57.0697  -63347.3448  Trailing SL  1110
# 192              9.2015    -192.5015 -210789.0987   Initial SL  1095
# 193              9.0516     228.0484  249713.0418  Trailing SL  1095
# 194              9.0781      49.4219   54116.9586  Trailing SL  1095
# 195              9.3093    -534.6093 -577378.0656       Gap SL  1080
# 196              9.7728    -264.1727 -269456.2050   Initial SL  1020
# 197             10.5402     257.5098  243346.8035  Trailing SL   945
# 198             10.4325     652.8175  616912.5706       Target   945
# 199             10.4917     175.9083  166233.3152  Trailing SL   945
# 200             10.2950    -177.4450 -173008.8311   Initial SL   975
# 201             10.1104    -269.1604 -266468.8208   Initial SL   990
# 202             10.2461    -165.6461 -161504.9183   Initial SL   975
# 203             10.1496    -206.7996 -204731.6387   Initial SL   990
# 204             10.5986    -579.9486 -548051.4034   Initial SL   945
# 205             10.6019    -197.7019 -186828.2955   Initial SL   945
# 206             10.2864     816.6636  783997.0608  Trailing SL   960
# 207             10.3468    -106.1968 -101948.9520   Initial SL   960
# 208             10.4367     -41.8367  -40163.2704   Initial SL   960
#
#      Leverage    ROI%  Trade Year  Trade Month
# 186         5 -0.1095        2024            1
# 187         5 -4.4433        2024            1
# 188         5 -2.5332        2024            1
# 189         5  0.5198        2024            1
# 190         5 -0.5613        2024            1
# 191         5 -0.6335        2024            1
# 192         5 -2.1079        2024            1
# 193         5  2.4971        2024            2
# 194         5  0.5412        2024            2
# 195         5 -5.7738        2024            3
# 196         5 -2.6946        2024            5
# 197         5  2.4335        2024            6
# 198         5  6.1691        2024            7
# 199         5  1.6623        2024            7
# 200         5 -1.7301        2024            8
# 201         5 -2.6647        2024            8
# 202         5 -1.6150        2024            8
# 203         5 -2.0473        2024            9
# 204         5 -5.4805        2024            9
# 205         5 -1.8683        2024            9
# 206         5  7.8400        2024           10
# 207         5 -1.0195        2024           10
# 208         5 -0.4016        2024           11

# %%
stats_dictionary = {}
rsi_lengths = [4, 5, 6, 7, 8, 9, 12, 15]
for i in range(2, 5):
    for j in rsi_lengths:
        for k in range(30, 66, 5):
            for l in range(5, 36, 5):
                variation = f'n {i}, rsi {j}, threshold {k}, ema {l}'
                print(variation)
                tb = backtest_short(bnf_1min, i, j, k, l)
                if len(tb) > 0:
                    stats = generate_stats(tb, variation)
                    for x, y in stats.items():
                        if x > 8:
                            final_stats = y
                            print(final_stats)
                            stats_dictionary[x] = y
# Out:
# n 2, rsi 4, threshold 30, ema 5
# n 2, rsi 4, threshold 30, ema 10
# n 2, rsi 4, threshold 30, ema 15
# n 2, rsi 4, threshold 30, ema 20
# n 2, rsi 4, threshold 30, ema 25
# n 2, rsi 4, threshold 30, ema 30
# n 2, rsi 4, threshold 30, ema 35
# n 2, rsi 4, threshold 35, ema 5
# n 2, rsi 4, threshold 35, ema 10
# n 2, rsi 4, threshold 35, ema 15
# n 2, rsi 4, threshold 35, ema 20
# n 2, rsi 4, threshold 35, ema 25
# n 2, rsi 4, threshold 35, ema 30
# n 2, rsi 4, threshold 35, ema 35
# n 2, rsi 4, threshold 40, ema 5
# n 2, rsi 4, threshold 40, ema 10
# n 2, rsi 4, threshold 40, ema 15
# n 2, rsi 4, threshold 40, ema 20
# n 2, rsi 4, threshold 40, ema 25
# n 2, rsi 4, threshold 40, ema 30
# n 2, rsi 4, threshold 40, ema 35
# n 2, rsi 4, threshold 45, ema 5
# n 2, rsi 4, threshold 45, ema 10
# n 2, rsi 4, threshold 45, ema 15
# n 2, rsi 4, threshold 45, ema 20
# n 2, rsi 4, threshold 45, ema 25
# n 2, rsi 4, threshold 45, ema 30
# n 2, rsi 4, threshold 45, ema 35
# n 2, rsi 4, threshold 50, ema 5
# n 2, rsi 4, threshold 50, ema 10
# n 2, rsi 4, threshold 50, ema 15
# n 2, rsi 4, threshold 50, ema 20
# n 2, rsi 4, threshold 50, ema 25
# n 2, rsi 4, threshold 50, ema 30
# n 2, rsi 4, threshold 50, ema 35
# n 2, rsi 4, threshold 55, ema 5
# n 2, rsi 4, threshold 55, ema 10
# n 2, rsi 4, threshold 55, ema 15
# n 2, rsi 4, threshold 55, ema 20
# n 2, rsi 4, threshold 55, ema 25
# n 2, rsi 4, threshold 55, ema 30
# n 2, rsi 4, threshold 55, ema 35
# n 2, rsi 4, threshold 60, ema 5
# n 2, rsi 4, threshold 60, ema 10
# n 2, rsi 4, threshold 60, ema 15
# n 2, rsi 4, threshold 60, ema 20
# n 2, rsi 4, threshold 60, ema 25
# n 2, rsi 4, threshold 60, ema 30
# n 2, rsi 4, threshold 60, ema 35
# n 2, rsi 4, threshold 65, ema 5
# n 2, rsi 4, threshold 65, ema 10
# n 2, rsi 4, threshold 65, ema 15
# n 2, rsi 4, threshold 65, ema 20
# n 2, rsi 4, threshold 65, ema 25
# n 2, rsi 4, threshold 65, ema 30
# n 2, rsi 4, threshold 65, ema 35
# n 2, rsi 5, threshold 30, ema 5
# n 2, rsi 5, threshold 30, ema 10
# n 2, rsi 5, threshold 30, ema 15
# n 2, rsi 5, threshold 30, ema 20
# n 2, rsi 5, threshold 30, ema 25
# n 2, rsi 5, threshold 30, ema 30
# n 2, rsi 5, threshold 30, ema 35
# n 2, rsi 5, threshold 35, ema 5
# n 2, rsi 5, threshold 35, ema 10
# n 2, rsi 5, threshold 35, ema 15
# n 2, rsi 5, threshold 35, ema 20
# n 2, rsi 5, threshold 35, ema 25
# n 2, rsi 5, threshold 35, ema 30
# n 2, rsi 5, threshold 35, ema 35
# n 2, rsi 5, threshold 40, ema 5
# n 2, rsi 5, threshold 40, ema 10
# n 2, rsi 5, threshold 40, ema 15
# n 2, rsi 5, threshold 40, ema 20
# n 2, rsi 5, threshold 40, ema 25
# n 2, rsi 5, threshold 40, ema 30
# n 2, rsi 5, threshold 40, ema 35
# n 2, rsi 5, threshold 45, ema 5
# n 2, rsi 5, threshold 45, ema 10
# n 2, rsi 5, threshold 45, ema 15
# n 2, rsi 5, threshold 45, ema 20
# n 2, rsi 5, threshold 45, ema 25
# n 2, rsi 5, threshold 45, ema 30
# n 2, rsi 5, threshold 45, ema 35
# n 2, rsi 5, threshold 50, ema 5
# n 2, rsi 5, threshold 50, ema 10
# n 2, rsi 5, threshold 50, ema 15
# n 2, rsi 5, threshold 50, ema 20
# n 2, rsi 5, threshold 50, ema 25
# n 2, rsi 5, threshold 50, ema 30
# n 2, rsi 5, threshold 50, ema 35
# n 2, rsi 5, threshold 55, ema 5
# n 2, rsi 5, threshold 55, ema 10
# n 2, rsi 5, threshold 55, ema 15
# n 2, rsi 5, threshold 55, ema 20
# n 2, rsi 5, threshold 55, ema 25
# n 2, rsi 5, threshold 55, ema 30
# n 2, rsi 5, threshold 55, ema 35
# n 2, rsi 5, threshold 60, ema 5
# n 2, rsi 5, threshold 60, ema 10
# n 2, rsi 5, threshold 60, ema 15
# n 2, rsi 5, threshold 60, ema 20
# n 2, rsi 5, threshold 60, ema 25
# n 2, rsi 5, threshold 60, ema 30
# n 2, rsi 5, threshold 60, ema 35
# n 2, rsi 5, threshold 65, ema 5
# n 2, rsi 5, threshold 65, ema 10
# n 2, rsi 5, threshold 65, ema 15
# n 2, rsi 5, threshold 65, ema 20
# n 2, rsi 5, threshold 65, ema 25
# n 2, rsi 5, threshold 65, ema 30
# n 2, rsi 5, threshold 65, ema 35
# n 2, rsi 6, threshold 30, ema 5
# n 2, rsi 6, threshold 30, ema 10
# n 2, rsi 6, threshold 30, ema 15
# n 2, rsi 6, threshold 30, ema 20
# n 2, rsi 6, threshold 30, ema 25
# n 2, rsi 6, threshold 30, ema 30
# n 2, rsi 6, threshold 30, ema 35
# n 2, rsi 6, threshold 35, ema 5
# n 2, rsi 6, threshold 35, ema 10
# n 2, rsi 6, threshold 35, ema 15
# n 2, rsi 6, threshold 35, ema 20
# n 2, rsi 6, threshold 35, ema 25
# n 2, rsi 6, threshold 35, ema 30
# n 2, rsi 6, threshold 35, ema 35
# n 2, rsi 6, threshold 40, ema 5
# n 2, rsi 6, threshold 40, ema 10
# n 2, rsi 6, threshold 40, ema 15
# n 2, rsi 6, threshold 40, ema 20
# n 2, rsi 6, threshold 40, ema 25
# n 2, rsi 6, threshold 40, ema 30
# n 2, rsi 6, threshold 40, ema 35
# n 2, rsi 6, threshold 45, ema 5
# n 2, rsi 6, threshold 45, ema 10
# n 2, rsi 6, threshold 45, ema 15
# n 2, rsi 6, threshold 45, ema 20
# n 2, rsi 6, threshold 45, ema 25
# n 2, rsi 6, threshold 45, ema 30
# n 2, rsi 6, threshold 45, ema 35
# n 2, rsi 6, threshold 50, ema 5
# n 2, rsi 6, threshold 50, ema 10
# n 2, rsi 6, threshold 50, ema 15
# n 2, rsi 6, threshold 50, ema 20
# n 2, rsi 6, threshold 50, ema 25
# n 2, rsi 6, threshold 50, ema 30
# n 2, rsi 6, threshold 50, ema 35
# n 2, rsi 6, threshold 55, ema 5
# n 2, rsi 6, threshold 55, ema 10
# n 2, rsi 6, threshold 55, ema 15
# n 2, rsi 6, threshold 55, ema 20
# n 2, rsi 6, threshold 55, ema 25
# n 2, rsi 6, threshold 55, ema 30
# n 2, rsi 6, threshold 55, ema 35
# n 2, rsi 6, threshold 60, ema 5
# n 2, rsi 6, threshold 60, ema 10
# n 2, rsi 6, threshold 60, ema 15
# n 2, rsi 6, threshold 60, ema 20
# n 2, rsi 6, threshold 60, ema 25
# n 2, rsi 6, threshold 60, ema 30
# n 2, rsi 6, threshold 60, ema 35
# n 2, rsi 6, threshold 65, ema 5
# n 2, rsi 6, threshold 65, ema 10
# n 2, rsi 6, threshold 65, ema 15
# n 2, rsi 6, threshold 65, ema 20
# n 2, rsi 6, threshold 65, ema 25
# n 2, rsi 6, threshold 65, ema 30
# n 2, rsi 6, threshold 65, ema 35
# n 2, rsi 7, threshold 30, ema 5
# n 2, rsi 7, threshold 30, ema 10
# n 2, rsi 7, threshold 30, ema 15
# n 2, rsi 7, threshold 30, ema 20
# n 2, rsi 7, threshold 30, ema 25
# n 2, rsi 7, threshold 30, ema 30
# n 2, rsi 7, threshold 30, ema 35
# n 2, rsi 7, threshold 35, ema 5
# n 2, rsi 7, threshold 35, ema 10
# n 2, rsi 7, threshold 35, ema 15
# n 2, rsi 7, threshold 35, ema 20
# n 2, rsi 7, threshold 35, ema 25
# n 2, rsi 7, threshold 35, ema 30
# n 2, rsi 7, threshold 35, ema 35
# n 2, rsi 7, threshold 40, ema 5
# n 2, rsi 7, threshold 40, ema 10
# n 2, rsi 7, threshold 40, ema 15
# n 2, rsi 7, threshold 40, ema 20
# n 2, rsi 7, threshold 40, ema 25
# n 2, rsi 7, threshold 40, ema 30
# n 2, rsi 7, threshold 40, ema 35
# n 2, rsi 7, threshold 45, ema 5
# n 2, rsi 7, threshold 45, ema 10
# n 2, rsi 7, threshold 45, ema 15
# n 2, rsi 7, threshold 45, ema 20
# n 2, rsi 7, threshold 45, ema 25
# n 2, rsi 7, threshold 45, ema 30
# n 2, rsi 7, threshold 45, ema 35
# n 2, rsi 7, threshold 50, ema 5
# n 2, rsi 7, threshold 50, ema 10
# n 2, rsi 7, threshold 50, ema 15
# n 2, rsi 7, threshold 50, ema 20
# n 2, rsi 7, threshold 50, ema 25
# n 2, rsi 7, threshold 50, ema 30
# n 2, rsi 7, threshold 50, ema 35
# n 2, rsi 7, threshold 55, ema 5
# n 2, rsi 7, threshold 55, ema 10
# n 2, rsi 7, threshold 55, ema 15
# n 2, rsi 7, threshold 55, ema 20
# n 2, rsi 7, threshold 55, ema 25
# n 2, rsi 7, threshold 55, ema 30
# n 2, rsi 7, threshold 55, ema 35
# n 2, rsi 7, threshold 60, ema 5
# n 2, rsi 7, threshold 60, ema 10
# n 2, rsi 7, threshold 60, ema 15
# n 2, rsi 7, threshold 60, ema 20
# n 2, rsi 7, threshold 60, ema 25
# n 2, rsi 7, threshold 60, ema 30
# n 2, rsi 7, threshold 60, ema 35
# n 2, rsi 7, threshold 65, ema 5
# n 2, rsi 7, threshold 65, ema 10
# n 2, rsi 7, threshold 65, ema 15
# n 2, rsi 7, threshold 65, ema 20
# n 2, rsi 7, threshold 65, ema 25
# n 2, rsi 7, threshold 65, ema 30
# n 2, rsi 7, threshold 65, ema 35
# n 2, rsi 8, threshold 30, ema 5
# n 2, rsi 8, threshold 30, ema 10
# n 2, rsi 8, threshold 30, ema 15
# n 2, rsi 8, threshold 30, ema 20
# n 2, rsi 8, threshold 30, ema 25
# n 2, rsi 8, threshold 30, ema 30
# n 2, rsi 8, threshold 30, ema 35
# n 2, rsi 8, threshold 35, ema 5
# n 2, rsi 8, threshold 35, ema 10
# n 2, rsi 8, threshold 35, ema 15
# n 2, rsi 8, threshold 35, ema 20
# n 2, rsi 8, threshold 35, ema 25
# n 2, rsi 8, threshold 35, ema 30
# n 2, rsi 8, threshold 35, ema 35
# n 2, rsi 8, threshold 40, ema 5
# n 2, rsi 8, threshold 40, ema 10
# n 2, rsi 8, threshold 40, ema 15
# n 2, rsi 8, threshold 40, ema 20
# n 2, rsi 8, threshold 40, ema 25
# n 2, rsi 8, threshold 40, ema 30
# n 2, rsi 8, threshold 40, ema 35
# n 2, rsi 8, threshold 45, ema 5
# n 2, rsi 8, threshold 45, ema 10
# n 2, rsi 8, threshold 45, ema 15
# n 2, rsi 8, threshold 45, ema 20
# n 2, rsi 8, threshold 45, ema 25
# n 2, rsi 8, threshold 45, ema 30
# n 2, rsi 8, threshold 45, ema 35
# n 2, rsi 8, threshold 50, ema 5
# n 2, rsi 8, threshold 50, ema 10
# n 2, rsi 8, threshold 50, ema 15
# n 2, rsi 8, threshold 50, ema 20
# n 2, rsi 8, threshold 50, ema 25
# n 2, rsi 8, threshold 50, ema 30
# n 2, rsi 8, threshold 50, ema 35
# n 2, rsi 8, threshold 55, ema 5
# n 2, rsi 8, threshold 55, ema 10
# n 2, rsi 8, threshold 55, ema 15
# n 2, rsi 8, threshold 55, ema 20
# n 2, rsi 8, threshold 55, ema 25
# n 2, rsi 8, threshold 55, ema 30
# n 2, rsi 8, threshold 55, ema 35
# n 2, rsi 8, threshold 60, ema 5
# n 2, rsi 8, threshold 60, ema 10
# n 2, rsi 8, threshold 60, ema 15
# n 2, rsi 8, threshold 60, ema 20
# n 2, rsi 8, threshold 60, ema 25
# n 2, rsi 8, threshold 60, ema 30
# n 2, rsi 8, threshold 60, ema 35
# n 2, rsi 8, threshold 65, ema 5
# n 2, rsi 8, threshold 65, ema 10
# n 2, rsi 8, threshold 65, ema 15
# n 2, rsi 8, threshold 65, ema 20
# n 2, rsi 8, threshold 65, ema 25
# n 2, rsi 8, threshold 65, ema 30
# n 2, rsi 8, threshold 65, ema 35
# n 2, rsi 9, threshold 30, ema 5
# n 2, rsi 9, threshold 30, ema 10
# n 2, rsi 9, threshold 30, ema 15
# n 2, rsi 9, threshold 30, ema 20
# n 2, rsi 9, threshold 30, ema 25
# n 2, rsi 9, threshold 30, ema 30
# n 2, rsi 9, threshold 30, ema 35
# n 2, rsi 9, threshold 35, ema 5
# n 2, rsi 9, threshold 35, ema 10
# n 2, rsi 9, threshold 35, ema 15
# n 2, rsi 9, threshold 35, ema 20
# n 2, rsi 9, threshold 35, ema 25
# n 2, rsi 9, threshold 35, ema 30
# n 2, rsi 9, threshold 35, ema 35
# n 2, rsi 9, threshold 40, ema 5
# n 2, rsi 9, threshold 40, ema 10
# n 2, rsi 9, threshold 40, ema 15
# n 2, rsi 9, threshold 40, ema 20
# n 2, rsi 9, threshold 40, ema 25
# n 2, rsi 9, threshold 40, ema 30
# n 2, rsi 9, threshold 40, ema 35
# n 2, rsi 9, threshold 45, ema 5
# n 2, rsi 9, threshold 45, ema 10
# n 2, rsi 9, threshold 45, ema 15
# n 2, rsi 9, threshold 45, ema 20
# n 2, rsi 9, threshold 45, ema 25
# n 2, rsi 9, threshold 45, ema 30
# n 2, rsi 9, threshold 45, ema 35
# n 2, rsi 9, threshold 50, ema 5
# n 2, rsi 9, threshold 50, ema 10
# n 2, rsi 9, threshold 50, ema 15
# n 2, rsi 9, threshold 50, ema 20
# n 2, rsi 9, threshold 50, ema 25
# n 2, rsi 9, threshold 50, ema 30
# n 2, rsi 9, threshold 50, ema 35
# n 2, rsi 9, threshold 55, ema 5
# n 2, rsi 9, threshold 55, ema 10
# n 2, rsi 9, threshold 55, ema 15
# n 2, rsi 9, threshold 55, ema 20
# n 2, rsi 9, threshold 55, ema 25
# n 2, rsi 9, threshold 55, ema 30
# n 2, rsi 9, threshold 55, ema 35
# n 2, rsi 9, threshold 60, ema 5
# n 2, rsi 9, threshold 60, ema 10
# n 2, rsi 9, threshold 60, ema 15
# n 2, rsi 9, threshold 60, ema 20
# n 2, rsi 9, threshold 60, ema 25
# n 2, rsi 9, threshold 60, ema 30
# n 2, rsi 9, threshold 60, ema 35
# n 2, rsi 9, threshold 65, ema 5
# n 2, rsi 9, threshold 65, ema 10
# n 2, rsi 9, threshold 65, ema 15
# n 2, rsi 9, threshold 65, ema 20
# n 2, rsi 9, threshold 65, ema 25
# n 2, rsi 9, threshold 65, ema 30
# n 2, rsi 9, threshold 65, ema 35
# n 2, rsi 12, threshold 30, ema 5
# n 2, rsi 12, threshold 30, ema 10
# n 2, rsi 12, threshold 30, ema 15
# n 2, rsi 12, threshold 30, ema 20
# n 2, rsi 12, threshold 30, ema 25
# n 2, rsi 12, threshold 30, ema 30
# n 2, rsi 12, threshold 30, ema 35
# n 2, rsi 12, threshold 35, ema 5
# n 2, rsi 12, threshold 35, ema 10
# n 2, rsi 12, threshold 35, ema 15
# n 2, rsi 12, threshold 35, ema 20
# n 2, rsi 12, threshold 35, ema 25
# n 2, rsi 12, threshold 35, ema 30
# n 2, rsi 12, threshold 35, ema 35
# n 2, rsi 12, threshold 40, ema 5
# n 2, rsi 12, threshold 40, ema 10
# n 2, rsi 12, threshold 40, ema 15
# n 2, rsi 12, threshold 40, ema 20
# n 2, rsi 12, threshold 40, ema 25
# n 2, rsi 12, threshold 40, ema 30
# n 2, rsi 12, threshold 40, ema 35
# n 2, rsi 12, threshold 45, ema 5
# n 2, rsi 12, threshold 45, ema 10
# n 2, rsi 12, threshold 45, ema 15
# n 2, rsi 12, threshold 45, ema 20
# n 2, rsi 12, threshold 45, ema 25
# n 2, rsi 12, threshold 45, ema 30
# n 2, rsi 12, threshold 45, ema 35
# n 2, rsi 12, threshold 50, ema 5
# n 2, rsi 12, threshold 50, ema 10
# n 2, rsi 12, threshold 50, ema 15
# n 2, rsi 12, threshold 50, ema 20
# n 2, rsi 12, threshold 50, ema 25
# n 2, rsi 12, threshold 50, ema 30
# n 2, rsi 12, threshold 50, ema 35
# n 2, rsi 12, threshold 55, ema 5
# n 2, rsi 12, threshold 55, ema 10
# n 2, rsi 12, threshold 55, ema 15
# n 2, rsi 12, threshold 55, ema 20
# n 2, rsi 12, threshold 55, ema 25
# n 2, rsi 12, threshold 55, ema 30
# n 2, rsi 12, threshold 55, ema 35
# n 2, rsi 12, threshold 60, ema 5
# n 2, rsi 12, threshold 60, ema 10
# n 2, rsi 12, threshold 60, ema 15
# n 2, rsi 12, threshold 60, ema 20
# n 2, rsi 12, threshold 60, ema 25
# n 2, rsi 12, threshold 60, ema 30
# n 2, rsi 12, threshold 60, ema 35
# n 2, rsi 12, threshold 65, ema 5
# n 2, rsi 12, threshold 65, ema 10
# n 2, rsi 12, threshold 65, ema 15
# n 2, rsi 12, threshold 65, ema 20
# n 2, rsi 12, threshold 65, ema 25
# n 2, rsi 12, threshold 65, ema 30
# n 2, rsi 12, threshold 65, ema 35
# n 2, rsi 15, threshold 30, ema 5
# n 2, rsi 15, threshold 30, ema 10
# n 2, rsi 15, threshold 30, ema 15
# n 2, rsi 15, threshold 30, ema 20
# n 2, rsi 15, threshold 30, ema 25
# n 2, rsi 15, threshold 30, ema 30
# n 2, rsi 15, threshold 30, ema 35
# n 2, rsi 15, threshold 35, ema 5
# n 2, rsi 15, threshold 35, ema 10
# n 2, rsi 15, threshold 35, ema 15
# n 2, rsi 15, threshold 35, ema 20
# n 2, rsi 15, threshold 35, ema 25
# n 2, rsi 15, threshold 35, ema 30
# n 2, rsi 15, threshold 35, ema 35
# n 2, rsi 15, threshold 40, ema 5
# n 2, rsi 15, threshold 40, ema 10
# n 2, rsi 15, threshold 40, ema 15
# n 2, rsi 15, threshold 40, ema 20
# n 2, rsi 15, threshold 40, ema 25
# n 2, rsi 15, threshold 40, ema 30
# n 2, rsi 15, threshold 40, ema 35
# n 2, rsi 15, threshold 45, ema 5
# n 2, rsi 15, threshold 45, ema 10
# n 2, rsi 15, threshold 45, ema 15
# n 2, rsi 15, threshold 45, ema 20
# n 2, rsi 15, threshold 45, ema 25
# n 2, rsi 15, threshold 45, ema 30
# n 2, rsi 15, threshold 45, ema 35
# n 2, rsi 15, threshold 50, ema 5
# n 2, rsi 15, threshold 50, ema 10
# n 2, rsi 15, threshold 50, ema 15
# n 2, rsi 15, threshold 50, ema 20
# n 2, rsi 15, threshold 50, ema 25
# n 2, rsi 15, threshold 50, ema 30
# n 2, rsi 15, threshold 50, ema 35
# n 2, rsi 15, threshold 55, ema 5
# n 2, rsi 15, threshold 55, ema 10
# n 2, rsi 15, threshold 55, ema 15
# n 2, rsi 15, threshold 55, ema 20
# n 2, rsi 15, threshold 55, ema 25
# n 2, rsi 15, threshold 55, ema 30
# n 2, rsi 15, threshold 55, ema 35
# n 2, rsi 15, threshold 60, ema 5
# n 2, rsi 15, threshold 60, ema 10
# n 2, rsi 15, threshold 60, ema 15
# n 2, rsi 15, threshold 60, ema 20
# n 2, rsi 15, threshold 60, ema 25
# n 2, rsi 15, threshold 60, ema 30
# n 2, rsi 15, threshold 60, ema 35
# n 2, rsi 15, threshold 65, ema 5
# n 2, rsi 15, threshold 65, ema 10
# n 2, rsi 15, threshold 65, ema 15
# n 2, rsi 15, threshold 65, ema 20
# n 2, rsi 15, threshold 65, ema 25
# n 2, rsi 15, threshold 65, ema 30
# n 2, rsi 15, threshold 65, ema 35
# n 3, rsi 4, threshold 30, ema 5
# n 3, rsi 4, threshold 30, ema 10
# n 3, rsi 4, threshold 30, ema 15
# n 3, rsi 4, threshold 30, ema 20
# n 3, rsi 4, threshold 30, ema 25
# n 3, rsi 4, threshold 30, ema 30
# n 3, rsi 4, threshold 30, ema 35
# n 3, rsi 4, threshold 35, ema 5
# n 3, rsi 4, threshold 35, ema 10
# n 3, rsi 4, threshold 35, ema 15
# n 3, rsi 4, threshold 35, ema 20
# n 3, rsi 4, threshold 35, ema 25
# n 3, rsi 4, threshold 35, ema 30
# n 3, rsi 4, threshold 35, ema 35
# n 3, rsi 4, threshold 40, ema 5
# n 3, rsi 4, threshold 40, ema 10
# n 3, rsi 4, threshold 40, ema 15
# n 3, rsi 4, threshold 40, ema 20
# n 3, rsi 4, threshold 40, ema 25
# n 3, rsi 4, threshold 40, ema 30
# n 3, rsi 4, threshold 40, ema 35
# n 3, rsi 4, threshold 45, ema 5
# n 3, rsi 4, threshold 45, ema 10
# n 3, rsi 4, threshold 45, ema 15
# n 3, rsi 4, threshold 45, ema 20
# n 3, rsi 4, threshold 45, ema 25
# n 3, rsi 4, threshold 45, ema 30
# n 3, rsi 4, threshold 45, ema 35
# n 3, rsi 4, threshold 50, ema 5
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 50, ema 10
# n 3, rsi 4, threshold 50, ema 15
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 50, ema 20
# n 3, rsi 4, threshold 50, ema 25
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 50, ema 30
# n 3, rsi 4, threshold 50, ema 35
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 55, ema 5
# n 3, rsi 4, threshold 55, ema 10
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 55, ema 15
# n 3, rsi 4, threshold 55, ema 20
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 55, ema 25
# n 3, rsi 4, threshold 55, ema 30
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 55, ema 35
# n 3, rsi 4, threshold 60, ema 5
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 60, ema 10
# n 3, rsi 4, threshold 60, ema 15
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 60, ema 20
# n 3, rsi 4, threshold 60, ema 25
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 60, ema 30
# n 3, rsi 4, threshold 60, ema 35
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 65, ema 5
# n 3, rsi 4, threshold 65, ema 10
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 65, ema 15
# n 3, rsi 4, threshold 65, ema 20
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 65, ema 25
# n 3, rsi 4, threshold 65, ema 30
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 3, rsi 4, threshold 65, ema 35
# n 3, rsi 5, threshold 30, ema 5
# n 3, rsi 5, threshold 30, ema 10
# n 3, rsi 5, threshold 30, ema 15
# n 3, rsi 5, threshold 30, ema 20
# n 3, rsi 5, threshold 30, ema 25
# n 3, rsi 5, threshold 30, ema 30
# n 3, rsi 5, threshold 30, ema 35
# n 3, rsi 5, threshold 35, ema 5
# n 3, rsi 5, threshold 35, ema 10
# n 3, rsi 5, threshold 35, ema 15
# n 3, rsi 5, threshold 35, ema 20
# n 3, rsi 5, threshold 35, ema 25
# n 3, rsi 5, threshold 35, ema 30
# n 3, rsi 5, threshold 35, ema 35
# n 3, rsi 5, threshold 40, ema 5
# n 3, rsi 5, threshold 40, ema 10
# n 3, rsi 5, threshold 40, ema 15
# n 3, rsi 5, threshold 40, ema 20
# n 3, rsi 5, threshold 40, ema 25
# n 3, rsi 5, threshold 40, ema 30
# n 3, rsi 5, threshold 40, ema 35
# n 3, rsi 5, threshold 45, ema 5
# n 3, rsi 5, threshold 45, ema 10
# n 3, rsi 5, threshold 45, ema 15
# n 3, rsi 5, threshold 45, ema 20
# n 3, rsi 5, threshold 45, ema 25
# n 3, rsi 5, threshold 45, ema 30
# n 3, rsi 5, threshold 45, ema 35
# n 3, rsi 5, threshold 50, ema 5
# n 3, rsi 5, threshold 50, ema 10
# n 3, rsi 5, threshold 50, ema 15
# n 3, rsi 5, threshold 50, ema 20
# n 3, rsi 5, threshold 50, ema 25
# n 3, rsi 5, threshold 50, ema 30
# n 3, rsi 5, threshold 50, ema 35
# n 3, rsi 5, threshold 55, ema 5
# n 3, rsi 5, threshold 55, ema 10
# n 3, rsi 5, threshold 55, ema 15
# n 3, rsi 5, threshold 55, ema 20
# n 3, rsi 5, threshold 55, ema 25
# n 3, rsi 5, threshold 55, ema 30
# n 3, rsi 5, threshold 55, ema 35
# n 3, rsi 5, threshold 60, ema 5
# n 3, rsi 5, threshold 60, ema 10
# n 3, rsi 5, threshold 60, ema 15
# n 3, rsi 5, threshold 60, ema 20
# n 3, rsi 5, threshold 60, ema 25
# n 3, rsi 5, threshold 60, ema 30
# n 3, rsi 5, threshold 60, ema 35
# n 3, rsi 5, threshold 65, ema 5
# n 3, rsi 5, threshold 65, ema 10
# n 3, rsi 5, threshold 65, ema 15
# n 3, rsi 5, threshold 65, ema 20
# n 3, rsi 5, threshold 65, ema 25
# n 3, rsi 5, threshold 65, ema 30
# n 3, rsi 5, threshold 65, ema 35
# n 3, rsi 6, threshold 30, ema 5
# n 3, rsi 6, threshold 30, ema 10
# n 3, rsi 6, threshold 30, ema 15
# n 3, rsi 6, threshold 30, ema 20
# n 3, rsi 6, threshold 30, ema 25
# n 3, rsi 6, threshold 30, ema 30
# n 3, rsi 6, threshold 30, ema 35
# n 3, rsi 6, threshold 35, ema 5
# n 3, rsi 6, threshold 35, ema 10
# n 3, rsi 6, threshold 35, ema 15
# n 3, rsi 6, threshold 35, ema 20
# n 3, rsi 6, threshold 35, ema 25
# n 3, rsi 6, threshold 35, ema 30
# n 3, rsi 6, threshold 35, ema 35
# n 3, rsi 6, threshold 40, ema 5
# n 3, rsi 6, threshold 40, ema 10
# n 3, rsi 6, threshold 40, ema 15
# n 3, rsi 6, threshold 40, ema 20
# n 3, rsi 6, threshold 40, ema 25
# n 3, rsi 6, threshold 40, ema 30
# n 3, rsi 6, threshold 40, ema 35
# n 3, rsi 6, threshold 45, ema 5
# n 3, rsi 6, threshold 45, ema 10
# n 3, rsi 6, threshold 45, ema 15
# n 3, rsi 6, threshold 45, ema 20
# n 3, rsi 6, threshold 45, ema 25
# n 3, rsi 6, threshold 45, ema 30
# n 3, rsi 6, threshold 45, ema 35
# n 3, rsi 6, threshold 50, ema 5
# n 3, rsi 6, threshold 50, ema 10
# n 3, rsi 6, threshold 50, ema 15
# n 3, rsi 6, threshold 50, ema 20
# n 3, rsi 6, threshold 50, ema 25
# n 3, rsi 6, threshold 50, ema 30
# n 3, rsi 6, threshold 50, ema 35
# n 3, rsi 6, threshold 55, ema 5
# n 3, rsi 6, threshold 55, ema 10
# n 3, rsi 6, threshold 55, ema 15
# n 3, rsi 6, threshold 55, ema 20
# n 3, rsi 6, threshold 55, ema 25
# n 3, rsi 6, threshold 55, ema 30
# n 3, rsi 6, threshold 55, ema 35
# n 3, rsi 6, threshold 60, ema 5
# n 3, rsi 6, threshold 60, ema 10
# n 3, rsi 6, threshold 60, ema 15
# n 3, rsi 6, threshold 60, ema 20
# n 3, rsi 6, threshold 60, ema 25
# n 3, rsi 6, threshold 60, ema 30
# n 3, rsi 6, threshold 60, ema 35
# n 3, rsi 6, threshold 65, ema 5
# n 3, rsi 6, threshold 65, ema 10
# n 3, rsi 6, threshold 65, ema 15
# n 3, rsi 6, threshold 65, ema 20
# n 3, rsi 6, threshold 65, ema 25
# n 3, rsi 6, threshold 65, ema 30
# n 3, rsi 6, threshold 65, ema 35
# n 3, rsi 7, threshold 30, ema 5
# n 3, rsi 7, threshold 30, ema 10
# n 3, rsi 7, threshold 30, ema 15
# n 3, rsi 7, threshold 30, ema 20
# n 3, rsi 7, threshold 30, ema 25
# n 3, rsi 7, threshold 30, ema 30
# n 3, rsi 7, threshold 30, ema 35
# n 3, rsi 7, threshold 35, ema 5
# n 3, rsi 7, threshold 35, ema 10
# n 3, rsi 7, threshold 35, ema 15
# n 3, rsi 7, threshold 35, ema 20
# n 3, rsi 7, threshold 35, ema 25
# n 3, rsi 7, threshold 35, ema 30
# n 3, rsi 7, threshold 35, ema 35
# n 3, rsi 7, threshold 40, ema 5
# n 3, rsi 7, threshold 40, ema 10
# n 3, rsi 7, threshold 40, ema 15
# n 3, rsi 7, threshold 40, ema 20
# n 3, rsi 7, threshold 40, ema 25
# n 3, rsi 7, threshold 40, ema 30
# n 3, rsi 7, threshold 40, ema 35
# n 3, rsi 7, threshold 45, ema 5
# n 3, rsi 7, threshold 45, ema 10
# n 3, rsi 7, threshold 45, ema 15
# n 3, rsi 7, threshold 45, ema 20
# n 3, rsi 7, threshold 45, ema 25
# n 3, rsi 7, threshold 45, ema 30
# n 3, rsi 7, threshold 45, ema 35
# n 3, rsi 7, threshold 50, ema 5
# n 3, rsi 7, threshold 50, ema 10
# n 3, rsi 7, threshold 50, ema 15
# n 3, rsi 7, threshold 50, ema 20
# n 3, rsi 7, threshold 50, ema 25
# n 3, rsi 7, threshold 50, ema 30
# n 3, rsi 7, threshold 50, ema 35
# n 3, rsi 7, threshold 55, ema 5
# n 3, rsi 7, threshold 55, ema 10
# n 3, rsi 7, threshold 55, ema 15
# n 3, rsi 7, threshold 55, ema 20
# n 3, rsi 7, threshold 55, ema 25
# n 3, rsi 7, threshold 55, ema 30
# n 3, rsi 7, threshold 55, ema 35
# n 3, rsi 7, threshold 60, ema 5
# n 3, rsi 7, threshold 60, ema 10
# n 3, rsi 7, threshold 60, ema 15
# n 3, rsi 7, threshold 60, ema 20
# n 3, rsi 7, threshold 60, ema 25
# n 3, rsi 7, threshold 60, ema 30
# n 3, rsi 7, threshold 60, ema 35
# n 3, rsi 7, threshold 65, ema 5
# n 3, rsi 7, threshold 65, ema 10
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2018      -9.1190           14  42.8571                0.8933
# 2019      34.7243           10  60.0000                6.8465
# 2020      76.8846           18  66.6667                7.9801
# 2021      21.3986           15  40.0000                7.7230
# 2022      39.2466           20  50.0000                6.5214
# 2023      -4.4168           12  25.0000                4.8966
# 2024       8.4831           11  36.3636                5.8314
# Overall  167.2012          100  47.0000                6.2078
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
# 2018                -1.8099     -12.6805      -0.7191
# 2019                -1.5887      -3.2626      10.6432
# 2020                -3.1460     -10.0492       7.6508
# 2021                -2.7711     -16.5736       1.2911
# 2022                -2.5967     -13.9560       2.8122
# 2023                -2.1230     -11.3722      -0.3884
# 2024                -2.1204      -9.0676       0.9355
# Overall             -2.3503     -18.5185       9.0289
#
#                                 Variation
# 2018     n 3, rsi 7, threshold 65, ema 10
# 2019     n 3, rsi 7, threshold 65, ema 10
# 2020     n 3, rsi 7, threshold 65, ema 10
# 2021     n 3, rsi 7, threshold 65, ema 10
# 2022     n 3, rsi 7, threshold 65, ema 10
# 2023     n 3, rsi 7, threshold 65, ema 10
# 2024     n 3, rsi 7, threshold 65, ema 10
# Overall  n 3, rsi 7, threshold 65, ema 10
# n 3, rsi 7, threshold 65, ema 15
# n 3, rsi 7, threshold 65, ema 20
# n 3, rsi 7, threshold 65, ema 25
# n 3, rsi 7, threshold 65, ema 30
# n 3, rsi 7, threshold 65, ema 35
# n 3, rsi 8, threshold 30, ema 5
# n 3, rsi 8, threshold 30, ema 10
# n 3, rsi 8, threshold 30, ema 15
# n 3, rsi 8, threshold 30, ema 20
# n 3, rsi 8, threshold 30, ema 25
# n 3, rsi 8, threshold 30, ema 30
# n 3, rsi 8, threshold 30, ema 35
# n 3, rsi 8, threshold 35, ema 5
# n 3, rsi 8, threshold 35, ema 10
# n 3, rsi 8, threshold 35, ema 15
# n 3, rsi 8, threshold 35, ema 20
# n 3, rsi 8, threshold 35, ema 25
# n 3, rsi 8, threshold 35, ema 30
# n 3, rsi 8, threshold 35, ema 35
# n 3, rsi 8, threshold 40, ema 5
# n 3, rsi 8, threshold 40, ema 10
# n 3, rsi 8, threshold 40, ema 15
# n 3, rsi 8, threshold 40, ema 20
# n 3, rsi 8, threshold 40, ema 25
# n 3, rsi 8, threshold 40, ema 30
# n 3, rsi 8, threshold 40, ema 35
# n 3, rsi 8, threshold 45, ema 5
# n 3, rsi 8, threshold 45, ema 10
# n 3, rsi 8, threshold 45, ema 15
# n 3, rsi 8, threshold 45, ema 20
# n 3, rsi 8, threshold 45, ema 25
# n 3, rsi 8, threshold 45, ema 30
# n 3, rsi 8, threshold 45, ema 35
# n 3, rsi 8, threshold 50, ema 5
# n 3, rsi 8, threshold 50, ema 10
# n 3, rsi 8, threshold 50, ema 15
# n 3, rsi 8, threshold 50, ema 20
# n 3, rsi 8, threshold 50, ema 25
# n 3, rsi 8, threshold 50, ema 30
# n 3, rsi 8, threshold 50, ema 35
# n 3, rsi 8, threshold 55, ema 5
# n 3, rsi 8, threshold 55, ema 10
# n 3, rsi 8, threshold 55, ema 15
# n 3, rsi 8, threshold 55, ema 20
# n 3, rsi 8, threshold 55, ema 25
# n 3, rsi 8, threshold 55, ema 30
# n 3, rsi 8, threshold 55, ema 35
# n 3, rsi 8, threshold 60, ema 5
# n 3, rsi 8, threshold 60, ema 10
# n 3, rsi 8, threshold 60, ema 15
# n 3, rsi 8, threshold 60, ema 20
# n 3, rsi 8, threshold 60, ema 25
# n 3, rsi 8, threshold 60, ema 30
# n 3, rsi 8, threshold 60, ema 35
# n 3, rsi 8, threshold 65, ema 5
# n 3, rsi 8, threshold 65, ema 10
# n 3, rsi 8, threshold 65, ema 15
# n 3, rsi 8, threshold 65, ema 20
# n 3, rsi 8, threshold 65, ema 25
# n 3, rsi 8, threshold 65, ema 30
# n 3, rsi 8, threshold 65, ema 35
# n 3, rsi 9, threshold 30, ema 5
# n 3, rsi 9, threshold 30, ema 10
# n 3, rsi 9, threshold 30, ema 15
# n 3, rsi 9, threshold 30, ema 20
# n 3, rsi 9, threshold 30, ema 25
# n 3, rsi 9, threshold 30, ema 30
# n 3, rsi 9, threshold 30, ema 35
# n 3, rsi 9, threshold 35, ema 5
# n 3, rsi 9, threshold 35, ema 10
# n 3, rsi 9, threshold 35, ema 15
# n 3, rsi 9, threshold 35, ema 20
# n 3, rsi 9, threshold 35, ema 25
# n 3, rsi 9, threshold 35, ema 30
# n 3, rsi 9, threshold 35, ema 35
# n 3, rsi 9, threshold 40, ema 5
# n 3, rsi 9, threshold 40, ema 10
# n 3, rsi 9, threshold 40, ema 15
# n 3, rsi 9, threshold 40, ema 20
# n 3, rsi 9, threshold 40, ema 25
# n 3, rsi 9, threshold 40, ema 30
# n 3, rsi 9, threshold 40, ema 35
# n 3, rsi 9, threshold 45, ema 5
# n 3, rsi 9, threshold 45, ema 10
# n 3, rsi 9, threshold 45, ema 15
# n 3, rsi 9, threshold 45, ema 20
# n 3, rsi 9, threshold 45, ema 25
# n 3, rsi 9, threshold 45, ema 30
# n 3, rsi 9, threshold 45, ema 35
# n 3, rsi 9, threshold 50, ema 5
# n 3, rsi 9, threshold 50, ema 10
# n 3, rsi 9, threshold 50, ema 15
# n 3, rsi 9, threshold 50, ema 20
# n 3, rsi 9, threshold 50, ema 25
# n 3, rsi 9, threshold 50, ema 30
# n 3, rsi 9, threshold 50, ema 35
# n 3, rsi 9, threshold 55, ema 5
# n 3, rsi 9, threshold 55, ema 10
# n 3, rsi 9, threshold 55, ema 15
# n 3, rsi 9, threshold 55, ema 20
# n 3, rsi 9, threshold 55, ema 25
# n 3, rsi 9, threshold 55, ema 30
# n 3, rsi 9, threshold 55, ema 35
# n 3, rsi 9, threshold 60, ema 5
# n 3, rsi 9, threshold 60, ema 10
# n 3, rsi 9, threshold 60, ema 15
# n 3, rsi 9, threshold 60, ema 20
# n 3, rsi 9, threshold 60, ema 25
# n 3, rsi 9, threshold 60, ema 30
# n 3, rsi 9, threshold 60, ema 35
# n 3, rsi 9, threshold 65, ema 5
# n 3, rsi 9, threshold 65, ema 10
# n 3, rsi 9, threshold 65, ema 15
# n 3, rsi 9, threshold 65, ema 20
# n 3, rsi 9, threshold 65, ema 25
# n 3, rsi 9, threshold 65, ema 30
# n 3, rsi 9, threshold 65, ema 35
# n 3, rsi 12, threshold 30, ema 5
# n 3, rsi 12, threshold 30, ema 10
# n 3, rsi 12, threshold 30, ema 15
# n 3, rsi 12, threshold 30, ema 20
# n 3, rsi 12, threshold 30, ema 25
# n 3, rsi 12, threshold 30, ema 30
# n 3, rsi 12, threshold 30, ema 35
# n 3, rsi 12, threshold 35, ema 5
# n 3, rsi 12, threshold 35, ema 10
# n 3, rsi 12, threshold 35, ema 15
# n 3, rsi 12, threshold 35, ema 20
# n 3, rsi 12, threshold 35, ema 25
# n 3, rsi 12, threshold 35, ema 30
# n 3, rsi 12, threshold 35, ema 35
# n 3, rsi 12, threshold 40, ema 5
# n 3, rsi 12, threshold 40, ema 10
# n 3, rsi 12, threshold 40, ema 15
# n 3, rsi 12, threshold 40, ema 20
# n 3, rsi 12, threshold 40, ema 25
# n 3, rsi 12, threshold 40, ema 30
# n 3, rsi 12, threshold 40, ema 35
# n 3, rsi 12, threshold 45, ema 5
# n 3, rsi 12, threshold 45, ema 10
# n 3, rsi 12, threshold 45, ema 15
# n 3, rsi 12, threshold 45, ema 20
# n 3, rsi 12, threshold 45, ema 25
# n 3, rsi 12, threshold 45, ema 30
# n 3, rsi 12, threshold 45, ema 35
# n 3, rsi 12, threshold 50, ema 5
# n 3, rsi 12, threshold 50, ema 10
# n 3, rsi 12, threshold 50, ema 15
# n 3, rsi 12, threshold 50, ema 20
# n 3, rsi 12, threshold 50, ema 25
# n 3, rsi 12, threshold 50, ema 30
# n 3, rsi 12, threshold 50, ema 35
# n 3, rsi 12, threshold 55, ema 5
# n 3, rsi 12, threshold 55, ema 10
# n 3, rsi 12, threshold 55, ema 15
# n 3, rsi 12, threshold 55, ema 20
# n 3, rsi 12, threshold 55, ema 25
# n 3, rsi 12, threshold 55, ema 30
# n 3, rsi 12, threshold 55, ema 35
# n 3, rsi 12, threshold 60, ema 5
# n 3, rsi 12, threshold 60, ema 10
# n 3, rsi 12, threshold 60, ema 15
# n 3, rsi 12, threshold 60, ema 20
# n 3, rsi 12, threshold 60, ema 25
# n 3, rsi 12, threshold 60, ema 30
# n 3, rsi 12, threshold 60, ema 35
# n 3, rsi 12, threshold 65, ema 5
# n 3, rsi 12, threshold 65, ema 10
# n 3, rsi 12, threshold 65, ema 15
# n 3, rsi 12, threshold 65, ema 20
# n 3, rsi 12, threshold 65, ema 25
# n 3, rsi 12, threshold 65, ema 30
# n 3, rsi 12, threshold 65, ema 35
# n 3, rsi 15, threshold 30, ema 5
# n 3, rsi 15, threshold 30, ema 10
# n 3, rsi 15, threshold 30, ema 15
# n 3, rsi 15, threshold 30, ema 20
# n 3, rsi 15, threshold 30, ema 25
# n 3, rsi 15, threshold 30, ema 30
# n 3, rsi 15, threshold 30, ema 35
# n 3, rsi 15, threshold 35, ema 5
# n 3, rsi 15, threshold 35, ema 10
# n 3, rsi 15, threshold 35, ema 15
# n 3, rsi 15, threshold 35, ema 20
# n 3, rsi 15, threshold 35, ema 25
# n 3, rsi 15, threshold 35, ema 30
# n 3, rsi 15, threshold 35, ema 35
# n 3, rsi 15, threshold 40, ema 5
# n 3, rsi 15, threshold 40, ema 10
# n 3, rsi 15, threshold 40, ema 15
# n 3, rsi 15, threshold 40, ema 20
# n 3, rsi 15, threshold 40, ema 25
# n 3, rsi 15, threshold 40, ema 30
# n 3, rsi 15, threshold 40, ema 35
# n 3, rsi 15, threshold 45, ema 5
# n 3, rsi 15, threshold 45, ema 10
# n 3, rsi 15, threshold 45, ema 15
# n 3, rsi 15, threshold 45, ema 20
# n 3, rsi 15, threshold 45, ema 25
# n 3, rsi 15, threshold 45, ema 30
# n 3, rsi 15, threshold 45, ema 35
# n 3, rsi 15, threshold 50, ema 5
# n 3, rsi 15, threshold 50, ema 10
# n 3, rsi 15, threshold 50, ema 15
# n 3, rsi 15, threshold 50, ema 20
# n 3, rsi 15, threshold 50, ema 25
# n 3, rsi 15, threshold 50, ema 30
# n 3, rsi 15, threshold 50, ema 35
# n 3, rsi 15, threshold 55, ema 5
# n 3, rsi 15, threshold 55, ema 10
# n 3, rsi 15, threshold 55, ema 15
# n 3, rsi 15, threshold 55, ema 20
# n 3, rsi 15, threshold 55, ema 25
# n 3, rsi 15, threshold 55, ema 30
# n 3, rsi 15, threshold 55, ema 35
# n 3, rsi 15, threshold 60, ema 5
# n 3, rsi 15, threshold 60, ema 10
# n 3, rsi 15, threshold 60, ema 15
# n 3, rsi 15, threshold 60, ema 20
# n 3, rsi 15, threshold 60, ema 25
# n 3, rsi 15, threshold 60, ema 30
# n 3, rsi 15, threshold 60, ema 35
# n 3, rsi 15, threshold 65, ema 5
# n 3, rsi 15, threshold 65, ema 10
# n 3, rsi 15, threshold 65, ema 15
# n 3, rsi 15, threshold 65, ema 20
# n 3, rsi 15, threshold 65, ema 25
# n 3, rsi 15, threshold 65, ema 30
# n 3, rsi 15, threshold 65, ema 35
# n 4, rsi 4, threshold 30, ema 5
# n 4, rsi 4, threshold 30, ema 10
# n 4, rsi 4, threshold 30, ema 15
# n 4, rsi 4, threshold 30, ema 20
# n 4, rsi 4, threshold 30, ema 25
# n 4, rsi 4, threshold 30, ema 30
# n 4, rsi 4, threshold 30, ema 35
# n 4, rsi 4, threshold 35, ema 5
# n 4, rsi 4, threshold 35, ema 10
# n 4, rsi 4, threshold 35, ema 15
# n 4, rsi 4, threshold 35, ema 20
# n 4, rsi 4, threshold 35, ema 25
# n 4, rsi 4, threshold 35, ema 30
# n 4, rsi 4, threshold 35, ema 35
# n 4, rsi 4, threshold 40, ema 5
# n 4, rsi 4, threshold 40, ema 10
# n 4, rsi 4, threshold 40, ema 15
# n 4, rsi 4, threshold 40, ema 20
# n 4, rsi 4, threshold 40, ema 25
# n 4, rsi 4, threshold 40, ema 30
# n 4, rsi 4, threshold 40, ema 35
# n 4, rsi 4, threshold 45, ema 5
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 4, threshold 45, ema 10
# n 4, rsi 4, threshold 45, ema 15
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 4, threshold 45, ema 20
# n 4, rsi 4, threshold 45, ema 25
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 4, threshold 45, ema 30
# n 4, rsi 4, threshold 45, ema 35
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 4, threshold 50, ema 5
# n 4, rsi 4, threshold 50, ema 10
# n 4, rsi 4, threshold 50, ema 15
# n 4, rsi 4, threshold 50, ema 20
# n 4, rsi 4, threshold 50, ema 25
# n 4, rsi 4, threshold 50, ema 30
# n 4, rsi 4, threshold 50, ema 35
# n 4, rsi 4, threshold 55, ema 5
# n 4, rsi 4, threshold 55, ema 10
# n 4, rsi 4, threshold 55, ema 15
# n 4, rsi 4, threshold 55, ema 20
# n 4, rsi 4, threshold 55, ema 25
# n 4, rsi 4, threshold 55, ema 30
# n 4, rsi 4, threshold 55, ema 35
# n 4, rsi 4, threshold 60, ema 5
# n 4, rsi 4, threshold 60, ema 10
# n 4, rsi 4, threshold 60, ema 15
# n 4, rsi 4, threshold 60, ema 20
# n 4, rsi 4, threshold 60, ema 25
# n 4, rsi 4, threshold 60, ema 30
# n 4, rsi 4, threshold 60, ema 35
# n 4, rsi 4, threshold 65, ema 5
# n 4, rsi 4, threshold 65, ema 10
# n 4, rsi 4, threshold 65, ema 15
# n 4, rsi 4, threshold 65, ema 20
# n 4, rsi 4, threshold 65, ema 25
# n 4, rsi 4, threshold 65, ema 30
# n 4, rsi 4, threshold 65, ema 35
# n 4, rsi 5, threshold 30, ema 5
# n 4, rsi 5, threshold 30, ema 10
# n 4, rsi 5, threshold 30, ema 15
# n 4, rsi 5, threshold 30, ema 20
# n 4, rsi 5, threshold 30, ema 25
# n 4, rsi 5, threshold 30, ema 30
# n 4, rsi 5, threshold 30, ema 35
# n 4, rsi 5, threshold 35, ema 5
# n 4, rsi 5, threshold 35, ema 10
# n 4, rsi 5, threshold 35, ema 15
# n 4, rsi 5, threshold 35, ema 20
# n 4, rsi 5, threshold 35, ema 25
# n 4, rsi 5, threshold 35, ema 30
# n 4, rsi 5, threshold 35, ema 35
# n 4, rsi 5, threshold 40, ema 5
# n 4, rsi 5, threshold 40, ema 10
# n 4, rsi 5, threshold 40, ema 15
# n 4, rsi 5, threshold 40, ema 20
# n 4, rsi 5, threshold 40, ema 25
# n 4, rsi 5, threshold 40, ema 30
# n 4, rsi 5, threshold 40, ema 35
# n 4, rsi 5, threshold 45, ema 5
# n 4, rsi 5, threshold 45, ema 10
# n 4, rsi 5, threshold 45, ema 15
# n 4, rsi 5, threshold 45, ema 20
# n 4, rsi 5, threshold 45, ema 25
# n 4, rsi 5, threshold 45, ema 30
# n 4, rsi 5, threshold 45, ema 35
# n 4, rsi 5, threshold 50, ema 5
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 5, threshold 50, ema 10
# n 4, rsi 5, threshold 50, ema 15
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 5, threshold 50, ema 20
# n 4, rsi 5, threshold 50, ema 25
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 5, threshold 50, ema 30
# n 4, rsi 5, threshold 50, ema 35
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 5, threshold 55, ema 5
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2018      -2.4081            1   0.0000                   NaN
# 2019      19.7419            3  66.6667               10.6493
# 2020       1.5039            3  66.6667                2.7717
# 2021       1.9618            1 100.0000                1.9618
# 2022       3.2046            2 100.0000                1.6023
# 2023       9.5708            4  75.0000                3.3922
# 2024       0.0000            0      NaN                   NaN
# Overall   33.5750           14  71.4286                4.2185
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
# 2018                -2.4081       0.0000         -inf
# 2019                -1.5568       0.0000          inf
# 2020                -4.0395       0.0000          inf
# 2021                    NaN       0.0000          inf
# 2022                    NaN       0.0000          inf
# 2023                -0.6059      -0.6059      15.7967
# 2024                    NaN          NaN          NaN
# Overall             -2.1526      -4.0395       8.3116
#
#                                Variation
# 2018     n 4, rsi 5, threshold 55, ema 5
# 2019     n 4, rsi 5, threshold 55, ema 5
# 2020     n 4, rsi 5, threshold 55, ema 5
# 2021     n 4, rsi 5, threshold 55, ema 5
# 2022     n 4, rsi 5, threshold 55, ema 5
# 2023     n 4, rsi 5, threshold 55, ema 5
# 2024     n 4, rsi 5, threshold 55, ema 5
# Overall  n 4, rsi 5, threshold 55, ema 5
# n 4, rsi 5, threshold 55, ema 10
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 5, threshold 55, ema 15
# n 4, rsi 5, threshold 55, ema 20
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 5, threshold 55, ema 25
# n 4, rsi 5, threshold 55, ema 30
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 5, threshold 55, ema 35
# n 4, rsi 5, threshold 60, ema 5
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 5, threshold 60, ema 10
# n 4, rsi 5, threshold 60, ema 15
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 5, threshold 60, ema 20
# n 4, rsi 5, threshold 60, ema 25
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 5, threshold 60, ema 30
# n 4, rsi 5, threshold 60, ema 35
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:70: RuntimeWarning: divide by zero encountered in scalar divide
#   overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
# n 4, rsi 5, threshold 65, ema 5
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2018       0.0000            0      NaN                   NaN
# 2019      -1.5568            1   0.0000                   NaN
# 2020       5.5290            1 100.0000                5.5290
# 2021       0.0000            0      NaN                   NaN
# 2022       0.0000            0      NaN                   NaN
# 2023       2.9363            1 100.0000                2.9363
# 2024       0.0000            0      NaN                   NaN
# Overall    6.9085            3  66.6667                4.2326
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
# 2018                    NaN          NaN          NaN
# 2019                -1.5568       0.0000         -inf
# 2020                    NaN       0.0000          inf
# 2021                    NaN          NaN          NaN
# 2022                    NaN          NaN          NaN
# 2023                    NaN       0.0000          inf
# 2024                    NaN          NaN          NaN
# Overall             -1.5568       0.0000          inf
#
#                                Variation
# 2018     n 4, rsi 5, threshold 65, ema 5
# 2019     n 4, rsi 5, threshold 65, ema 5
# 2020     n 4, rsi 5, threshold 65, ema 5
# 2021     n 4, rsi 5, threshold 65, ema 5
# 2022     n 4, rsi 5, threshold 65, ema 5
# 2023     n 4, rsi 5, threshold 65, ema 5
# 2024     n 4, rsi 5, threshold 65, ema 5
# Overall  n 4, rsi 5, threshold 65, ema 5
# n 4, rsi 5, threshold 65, ema 10
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:70: RuntimeWarning: divide by zero encountered in scalar divide
#   overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:70: RuntimeWarning: divide by zero encountered in scalar divide
#   overall_roi_dd_ratio = overall_total_roi / abs(overall_max_drawdown)
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2018       0.0000            0      NaN                   NaN
# 2019      -1.5568            1   0.0000                   NaN
# 2020       5.5290            1 100.0000                5.5290
# 2021       0.0000            0      NaN                   NaN
# 2022       0.0000            0      NaN                   NaN
# 2023       6.2132            1 100.0000                6.2132
# 2024       0.0000            0      NaN                   NaN
# Overall   10.1854            3  66.6667                5.8711
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
# 2018                    NaN          NaN          NaN
# 2019                -1.5568       0.0000         -inf
# 2020                    NaN       0.0000          inf
# 2021                    NaN          NaN          NaN
# 2022                    NaN          NaN          NaN
# 2023                    NaN       0.0000          inf
# 2024                    NaN          NaN          NaN
# Overall             -1.5568       0.0000          inf
#
#                                 Variation
# 2018     n 4, rsi 5, threshold 65, ema 10
# 2019     n 4, rsi 5, threshold 65, ema 10
# 2020     n 4, rsi 5, threshold 65, ema 10
# 2021     n 4, rsi 5, threshold 65, ema 10
# ...
# 2023       8.7739            1 100.0000                8.7739
# 2024       0.0000            0      NaN                   NaN
# Overall    8.2242            3  66.6667                4.8905
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
# 2018                    NaN          NaN          NaN
# 2019                -1.5568       0.0000         -inf
# 2020                    NaN       0.0000          inf
# 2021                    NaN          NaN          NaN
# 2022                    NaN          NaN          NaN
# 2023                    NaN       0.0000          inf
# 2024                    NaN          NaN          NaN
# Overall             -1.5568       0.0000          inf
#
#                                 Variation
# 2018     n 4, rsi 5, threshold 65, ema 30
# 2019     n 4, rsi 5, threshold 65, ema 30
# 2020     n 4, rsi 5, threshold 65, ema 30
# 2021     n 4, rsi 5, threshold 65, ema 30
# 2022     n 4, rsi 5, threshold 65, ema 30
# 2023     n 4, rsi 5, threshold 65, ema 30
# 2024     n 4, rsi 5, threshold 65, ema 30
# Overall  n 4, rsi 5, threshold 65, ema 30
# n 4, rsi 5, threshold 65, ema 35
#         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
# 2018       0.0000            0      NaN                   NaN
# 2019      -1.5568            1   0.0000                   NaN
# 2020       1.0071            1 100.0000                1.0071
# 2021       0.0000            0      NaN                   NaN
# 2022       0.0000            0      NaN                   NaN
# 2023       8.7739            1 100.0000                8.7739
# 2024       0.0000            0      NaN                   NaN
# Overall    8.2242            3  66.6667                4.8905
#
#         Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
# 2018                    NaN          NaN          NaN
# 2019                -1.5568       0.0000         -inf
# 2020                    NaN       0.0000          inf
# 2021                    NaN          NaN          NaN
# 2022                    NaN          NaN          NaN
# 2023                    NaN       0.0000          inf
# 2024                    NaN          NaN          NaN
# Overall             -1.5568       0.0000          inf
#
#                                 Variation
# 2018     n 4, rsi 5, threshold 65, ema 35
# 2019     n 4, rsi 5, threshold 65, ema 35
# 2020     n 4, rsi 5, threshold 65, ema 35
# 2021     n 4, rsi 5, threshold 65, ema 35
# 2022     n 4, rsi 5, threshold 65, ema 35
# 2023     n 4, rsi 5, threshold 65, ema 35
# 2024     n 4, rsi 5, threshold 65, ema 35
# Overall  n 4, rsi 5, threshold 65, ema 35
# n 4, rsi 6, threshold 30, ema 5
# n 4, rsi 6, threshold 30, ema 10
# n 4, rsi 6, threshold 30, ema 15
# n 4, rsi 6, threshold 30, ema 20
# n 4, rsi 6, threshold 30, ema 25
# n 4, rsi 6, threshold 30, ema 30
# n 4, rsi 6, threshold 30, ema 35
# n 4, rsi 6, threshold 35, ema 5
# n 4, rsi 6, threshold 35, ema 10
# n 4, rsi 6, threshold 35, ema 15
# n 4, rsi 6, threshold 35, ema 20
# n 4, rsi 6, threshold 35, ema 25
# n 4, rsi 6, threshold 35, ema 30
# n 4, rsi 6, threshold 35, ema 35
# n 4, rsi 6, threshold 40, ema 5
# n 4, rsi 6, threshold 40, ema 10
# n 4, rsi 6, threshold 40, ema 15
# n 4, rsi 6, threshold 40, ema 20
# n 4, rsi 6, threshold 40, ema 25
# n 4, rsi 6, threshold 40, ema 30
# n 4, rsi 6, threshold 40, ema 35
# n 4, rsi 6, threshold 45, ema 5
# n 4, rsi 6, threshold 45, ema 10
# n 4, rsi 6, threshold 45, ema 15
# n 4, rsi 6, threshold 45, ema 20
# n 4, rsi 6, threshold 45, ema 25
# n 4, rsi 6, threshold 45, ema 30
# n 4, rsi 6, threshold 45, ema 35
# n 4, rsi 6, threshold 50, ema 5
# n 4, rsi 6, threshold 50, ema 10
# n 4, rsi 6, threshold 50, ema 15
# n 4, rsi 6, threshold 50, ema 20
# n 4, rsi 6, threshold 50, ema 25
# n 4, rsi 6, threshold 50, ema 30
# n 4, rsi 6, threshold 50, ema 35
# n 4, rsi 6, threshold 55, ema 5
# n 4, rsi 6, threshold 55, ema 10
# n 4, rsi 6, threshold 55, ema 15
# n 4, rsi 6, threshold 55, ema 20
# n 4, rsi 6, threshold 55, ema 25
# n 4, rsi 6, threshold 55, ema 30
# n 4, rsi 6, threshold 55, ema 35
# n 4, rsi 6, threshold 60, ema 5
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 6, threshold 60, ema 10
# n 4, rsi 6, threshold 60, ema 15
# n 4, rsi 6, threshold 60, ema 20
# n 4, rsi 6, threshold 60, ema 25
# n 4, rsi 6, threshold 60, ema 30
# n 4, rsi 6, threshold 60, ema 35
# n 4, rsi 6, threshold 65, ema 5
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 6, threshold 65, ema 10
# n 4, rsi 6, threshold 65, ema 15
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 6, threshold 65, ema 20
# n 4, rsi 6, threshold 65, ema 25
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 6, threshold 65, ema 30
# n 4, rsi 6, threshold 65, ema 35
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 7, threshold 30, ema 5
# n 4, rsi 7, threshold 30, ema 10
# n 4, rsi 7, threshold 30, ema 15
# n 4, rsi 7, threshold 30, ema 20
# n 4, rsi 7, threshold 30, ema 25
# n 4, rsi 7, threshold 30, ema 30
# n 4, rsi 7, threshold 30, ema 35
# n 4, rsi 7, threshold 35, ema 5
# n 4, rsi 7, threshold 35, ema 10
# n 4, rsi 7, threshold 35, ema 15
# n 4, rsi 7, threshold 35, ema 20
# n 4, rsi 7, threshold 35, ema 25
# n 4, rsi 7, threshold 35, ema 30
# n 4, rsi 7, threshold 35, ema 35
# n 4, rsi 7, threshold 40, ema 5
# n 4, rsi 7, threshold 40, ema 10
# n 4, rsi 7, threshold 40, ema 15
# n 4, rsi 7, threshold 40, ema 20
# n 4, rsi 7, threshold 40, ema 25
# n 4, rsi 7, threshold 40, ema 30
# n 4, rsi 7, threshold 40, ema 35
# n 4, rsi 7, threshold 45, ema 5
# n 4, rsi 7, threshold 45, ema 10
# n 4, rsi 7, threshold 45, ema 15
# n 4, rsi 7, threshold 45, ema 20
# n 4, rsi 7, threshold 45, ema 25
# n 4, rsi 7, threshold 45, ema 30
# n 4, rsi 7, threshold 45, ema 35
# n 4, rsi 7, threshold 50, ema 5
# n 4, rsi 7, threshold 50, ema 10
# n 4, rsi 7, threshold 50, ema 15
# n 4, rsi 7, threshold 50, ema 20
# n 4, rsi 7, threshold 50, ema 25
# n 4, rsi 7, threshold 50, ema 30
# n 4, rsi 7, threshold 50, ema 35
# n 4, rsi 7, threshold 55, ema 5
# n 4, rsi 7, threshold 55, ema 10
# n 4, rsi 7, threshold 55, ema 15
# n 4, rsi 7, threshold 55, ema 20
# n 4, rsi 7, threshold 55, ema 25
# n 4, rsi 7, threshold 55, ema 30
# n 4, rsi 7, threshold 55, ema 35
# n 4, rsi 7, threshold 60, ema 5
# n 4, rsi 7, threshold 60, ema 10
# n 4, rsi 7, threshold 60, ema 15
# n 4, rsi 7, threshold 60, ema 20
# n 4, rsi 7, threshold 60, ema 25
# n 4, rsi 7, threshold 60, ema 30
# n 4, rsi 7, threshold 60, ema 35
# n 4, rsi 7, threshold 65, ema 5
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 7, threshold 65, ema 10
# n 4, rsi 7, threshold 65, ema 15
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 7, threshold 65, ema 20
# n 4, rsi 7, threshold 65, ema 25
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 7, threshold 65, ema 30
# n 4, rsi 7, threshold 65, ema 35
# /tmp/ipykernel_2712/873016624.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   roi_dd_ratio = total_roi / abs(max_drawdown)
# n 4, rsi 8, threshold 30, ema 5
# n 4, rsi 8, threshold 30, ema 10
# n 4, rsi 8, threshold 30, ema 15
# n 4, rsi 8, threshold 30, ema 20
# n 4, rsi 8, threshold 30, ema 25
# n 4, rsi 8, threshold 30, ema 30
# n 4, rsi 8, threshold 30, ema 35
# n 4, rsi 8, threshold 35, ema 5
# n 4, rsi 8, threshold 35, ema 10
# n 4, rsi 8, threshold 35, ema 15
# n 4, rsi 8, threshold 35, ema 20
# n 4, rsi 8, threshold 35, ema 25
# n 4, rsi 8, threshold 35, ema 30
# n 4, rsi 8, threshold 35, ema 35
# n 4, rsi 8, threshold 40, ema 5
# n 4, rsi 8, threshold 40, ema 10
# n 4, rsi 8, threshold 40, ema 15
# n 4, rsi 8, threshold 40, ema 20
# n 4, rsi 8, threshold 40, ema 25
# n 4, rsi 8, threshold 40, ema 30
# n 4, rsi 8, threshold 40, ema 35
# n 4, rsi 8, threshold 45, ema 5
# n 4, rsi 8, threshold 45, ema 10
# n 4, rsi 8, threshold 45, ema 15
# n 4, rsi 8, threshold 45, ema 20
# n 4, rsi 8, threshold 45, ema 25
# n 4, rsi 8, threshold 45, ema 30
# n 4, rsi 8, threshold 45, ema 35
# n 4, rsi 8, threshold 50, ema 5
# n 4, rsi 8, threshold 50, ema 10
# n 4, rsi 8, threshold 50, ema 15
# n 4, rsi 8, threshold 50, ema 20
# n 4, rsi 8, threshold 50, ema 25
# n 4, rsi 8, threshold 50, ema 30
# n 4, rsi 8, threshold 50, ema 35
# n 4, rsi 8, threshold 55, ema 5
# n 4, rsi 8, threshold 55, ema 10
# n 4, rsi 8, threshold 55, ema 15
# n 4, rsi 8, threshold 55, ema 20
# n 4, rsi 8, threshold 55, ema 25
# n 4, rsi 8, threshold 55, ema 30
# n 4, rsi 8, threshold 55, ema 35
# n 4, rsi 8, threshold 60, ema 5
# n 4, rsi 8, threshold 60, ema 10
# n 4, rsi 8, threshold 60, ema 15
# n 4, rsi 8, threshold 60, ema 20
# n 4, rsi 8, threshold 60, ema 25
# n 4, rsi 8, threshold 60, ema 30
# n 4, rsi 8, threshold 60, ema 35
# n 4, rsi 8, threshold 65, ema 5
# n 4, rsi 8, threshold 65, ema 10
# n 4, rsi 8, threshold 65, ema 15
# n 4, rsi 8, threshold 65, ema 20
# n 4, rsi 8, threshold 65, ema 25
# n 4, rsi 8, threshold 65, ema 30
# n 4, rsi 8, threshold 65, ema 35
# n 4, rsi 9, threshold 30, ema 5
# n 4, rsi 9, threshold 30, ema 10
# n 4, rsi 9, threshold 30, ema 15
# n 4, rsi 9, threshold 30, ema 20
# n 4, rsi 9, threshold 30, ema 25
# n 4, rsi 9, threshold 30, ema 30
# n 4, rsi 9, threshold 30, ema 35
# n 4, rsi 9, threshold 35, ema 5
# n 4, rsi 9, threshold 35, ema 10
# n 4, rsi 9, threshold 35, ema 15
# n 4, rsi 9, threshold 35, ema 20
# n 4, rsi 9, threshold 35, ema 25
# n 4, rsi 9, threshold 35, ema 30
# n 4, rsi 9, threshold 35, ema 35
# n 4, rsi 9, threshold 40, ema 5
# n 4, rsi 9, threshold 40, ema 10
# n 4, rsi 9, threshold 40, ema 15
# n 4, rsi 9, threshold 40, ema 20
# n 4, rsi 9, threshold 40, ema 25
# n 4, rsi 9, threshold 40, ema 30
# n 4, rsi 9, threshold 40, ema 35
# n 4, rsi 9, threshold 45, ema 5
# n 4, rsi 9, threshold 45, ema 10
# n 4, rsi 9, threshold 45, ema 15
# n 4, rsi 9, threshold 45, ema 20
# n 4, rsi 9, threshold 45, ema 25
# n 4, rsi 9, threshold 45, ema 30
# n 4, rsi 9, threshold 45, ema 35
# n 4, rsi 9, threshold 50, ema 5
# n 4, rsi 9, threshold 50, ema 10
# n 4, rsi 9, threshold 50, ema 15
# n 4, rsi 9, threshold 50, ema 20
# n 4, rsi 9, threshold 50, ema 25
# n 4, rsi 9, threshold 50, ema 30
# n 4, rsi 9, threshold 50, ema 35
# n 4, rsi 9, threshold 55, ema 5
# n 4, rsi 9, threshold 55, ema 10
# n 4, rsi 9, threshold 55, ema 15
# n 4, rsi 9, threshold 55, ema 20
# n 4, rsi 9, threshold 55, ema 25
# n 4, rsi 9, threshold 55, ema 30
# n 4, rsi 9, threshold 55, ema 35
# n 4, rsi 9, threshold 60, ema 5
# n 4, rsi 9, threshold 60, ema 10
# n 4, rsi 9, threshold 60, ema 15
# n 4, rsi 9, threshold 60, ema 20
# n 4, rsi 9, threshold 60, ema 25
# n 4, rsi 9, threshold 60, ema 30
# n 4, rsi 9, threshold 60, ema 35
# n 4, rsi 9, threshold 65, ema 5
# n 4, rsi 9, threshold 65, ema 10
# n 4, rsi 9, threshold 65, ema 15
# n 4, rsi 9, threshold 65, ema 20
# n 4, rsi 9, threshold 65, ema 25
# n 4, rsi 9, threshold 65, ema 30
# n 4, rsi 9, threshold 65, ema 35
# n 4, rsi 12, threshold 30, ema 5
# n 4, rsi 12, threshold 30, ema 10
# n 4, rsi 12, threshold 30, ema 15
# n 4, rsi 12, threshold 30, ema 20
# n 4, rsi 12, threshold 30, ema 25
# n 4, rsi 12, threshold 30, ema 30
# n 4, rsi 12, threshold 30, ema 35
# n 4, rsi 12, threshold 35, ema 5
# n 4, rsi 12, threshold 35, ema 10
# n 4, rsi 12, threshold 35, ema 15
# n 4, rsi 12, threshold 35, ema 20
# n 4, rsi 12, threshold 35, ema 25
# n 4, rsi 12, threshold 35, ema 30
# n 4, rsi 12, threshold 35, ema 35
# n 4, rsi 12, threshold 40, ema 5
# n 4, rsi 12, threshold 40, ema 10
# n 4, rsi 12, threshold 40, ema 15
# n 4, rsi 12, threshold 40, ema 20
# n 4, rsi 12, threshold 40, ema 25
# n 4, rsi 12, threshold 40, ema 30
# n 4, rsi 12, threshold 40, ema 35
# n 4, rsi 12, threshold 45, ema 5
# n 4, rsi 12, threshold 45, ema 10
# n 4, rsi 12, threshold 45, ema 15
# n 4, rsi 12, threshold 45, ema 20
# n 4, rsi 12, threshold 45, ema 25
# n 4, rsi 12, threshold 45, ema 30
# n 4, rsi 12, threshold 45, ema 35
# n 4, rsi 12, threshold 50, ema 5
# n 4, rsi 12, threshold 50, ema 10
# n 4, rsi 12, threshold 50, ema 15
# n 4, rsi 12, threshold 50, ema 20
# n 4, rsi 12, threshold 50, ema 25
# n 4, rsi 12, threshold 50, ema 30
# n 4, rsi 12, threshold 50, ema 35
# n 4, rsi 12, threshold 55, ema 5
# n 4, rsi 12, threshold 55, ema 10
# n 4, rsi 12, threshold 55, ema 15
# n 4, rsi 12, threshold 55, ema 20
# n 4, rsi 12, threshold 55, ema 25
# n 4, rsi 12, threshold 55, ema 30
# n 4, rsi 12, threshold 55, ema 35
# n 4, rsi 12, threshold 60, ema 5
# n 4, rsi 12, threshold 60, ema 10
# n 4, rsi 12, threshold 60, ema 15
# n 4, rsi 12, threshold 60, ema 20
# n 4, rsi 12, threshold 60, ema 25
# n 4, rsi 12, threshold 60, ema 30
# n 4, rsi 12, threshold 60, ema 35
# n 4, rsi 12, threshold 65, ema 5
# n 4, rsi 12, threshold 65, ema 10
# n 4, rsi 12, threshold 65, ema 15
# n 4, rsi 12, threshold 65, ema 20
# n 4, rsi 12, threshold 65, ema 25
# n 4, rsi 12, threshold 65, ema 30
# n 4, rsi 12, threshold 65, ema 35
# n 4, rsi 15, threshold 30, ema 5
# n 4, rsi 15, threshold 30, ema 10
# n 4, rsi 15, threshold 30, ema 15
# n 4, rsi 15, threshold 30, ema 20
# n 4, rsi 15, threshold 30, ema 25
# n 4, rsi 15, threshold 30, ema 30
# n 4, rsi 15, threshold 30, ema 35
# n 4, rsi 15, threshold 35, ema 5
# n 4, rsi 15, threshold 35, ema 10
# n 4, rsi 15, threshold 35, ema 15
# n 4, rsi 15, threshold 35, ema 20
# n 4, rsi 15, threshold 35, ema 25
# n 4, rsi 15, threshold 35, ema 30
# n 4, rsi 15, threshold 35, ema 35
# n 4, rsi 15, threshold 40, ema 5
# n 4, rsi 15, threshold 40, ema 10
# n 4, rsi 15, threshold 40, ema 15
# n 4, rsi 15, threshold 40, ema 20
# n 4, rsi 15, threshold 40, ema 25
# n 4, rsi 15, threshold 40, ema 30
# n 4, rsi 15, threshold 40, ema 35
# n 4, rsi 15, threshold 45, ema 5
# n 4, rsi 15, threshold 45, ema 10
# n 4, rsi 15, threshold 45, ema 15
# n 4, rsi 15, threshold 45, ema 20
# n 4, rsi 15, threshold 45, ema 25
# n 4, rsi 15, threshold 45, ema 30
# n 4, rsi 15, threshold 45, ema 35
# n 4, rsi 15, threshold 50, ema 5
# n 4, rsi 15, threshold 50, ema 10
# n 4, rsi 15, threshold 50, ema 15
# n 4, rsi 15, threshold 50, ema 20
# n 4, rsi 15, threshold 50, ema 25
# n 4, rsi 15, threshold 50, ema 30
# n 4, rsi 15, threshold 50, ema 35
# n 4, rsi 15, threshold 55, ema 5
# n 4, rsi 15, threshold 55, ema 10
# n 4, rsi 15, threshold 55, ema 15
# n 4, rsi 15, threshold 55, ema 20
# n 4, rsi 15, threshold 55, ema 25
# n 4, rsi 15, threshold 55, ema 30
# n 4, rsi 15, threshold 55, ema 35
# n 4, rsi 15, threshold 60, ema 5
# n 4, rsi 15, threshold 60, ema 10
# n 4, rsi 15, threshold 60, ema 15
# n 4, rsi 15, threshold 60, ema 20
# n 4, rsi 15, threshold 60, ema 25
# n 4, rsi 15, threshold 60, ema 30
# n 4, rsi 15, threshold 60, ema 35
# n 4, rsi 15, threshold 65, ema 5
# n 4, rsi 15, threshold 65, ema 10
# n 4, rsi 15, threshold 65, ema 15
# n 4, rsi 15, threshold 65, ema 20
# n 4, rsi 15, threshold 65, ema 25
# n 4, rsi 15, threshold 65, ema 30
# n 4, rsi 15, threshold 65, ema 35

# %%
stats_dictionary
# Out:
# {9.028853253710498:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2018      -9.1190           14  42.8571                0.8933
#  2019      34.7243           10  60.0000                6.8465
#  2020      76.8846           18  66.6667                7.9801
#  2021      21.3986           15  40.0000                7.7230
#  2022      39.2466           20  50.0000                6.5214
#  2023      -4.4168           12  25.0000                4.8966
#  2024       8.4831           11  36.3636                5.8314
#  Overall  167.2012          100  47.0000                6.2078
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2018                -1.8099     -12.6805      -0.7191
#  2019                -1.5887      -3.2626      10.6432
#  2020                -3.1460     -10.0492       7.6508
#  2021                -2.7711     -16.5736       1.2911
#  2022                -2.5967     -13.9560       2.8122
#  2023                -2.1230     -11.3722      -0.3884
#  2024                -2.1204      -9.0676       0.9355
#  Overall             -2.3503     -18.5185       9.0289
#
#                                  Variation
#  2018     n 3, rsi 7, threshold 65, ema 10
#  2019     n 3, rsi 7, threshold 65, ema 10
#  2020     n 3, rsi 7, threshold 65, ema 10
#  2021     n 3, rsi 7, threshold 65, ema 10
#  2022     n 3, rsi 7, threshold 65, ema 10
#  2023     n 3, rsi 7, threshold 65, ema 10
#  2024     n 3, rsi 7, threshold 65, ema 10
#  Overall  n 3, rsi 7, threshold 65, ema 10  ,
#  8.311606653353902:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2018      -2.4081            1   0.0000                   NaN
#  2019      19.7419            3  66.6667               10.6493
#  2020       1.5039            3  66.6667                2.7717
#  2021       1.9618            1 100.0000                1.9618
#  2022       3.2046            2 100.0000                1.6023
#  2023       9.5708            4  75.0000                3.3922
#  2024       0.0000            0      NaN                   NaN
#  Overall   33.5750           14  71.4286                4.2185
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2018                -2.4081       0.0000         -inf
#  2019                -1.5568       0.0000          inf
#  2020                -4.0395       0.0000          inf
#  2021                    NaN       0.0000          inf
#  2022                    NaN       0.0000          inf
#  2023                -0.6059      -0.6059      15.7967
#  2024                    NaN          NaN          NaN
#  Overall             -2.1526      -4.0395       8.3116
#
#                                 Variation
#  2018     n 4, rsi 5, threshold 55, ema 5
#  2019     n 4, rsi 5, threshold 55, ema 5
#  2020     n 4, rsi 5, threshold 55, ema 5
#  2021     n 4, rsi 5, threshold 55, ema 5
#  2022     n 4, rsi 5, threshold 55, ema 5
#  2023     n 4, rsi 5, threshold 55, ema 5
#  2024     n 4, rsi 5, threshold 55, ema 5
#  Overall  n 4, rsi 5, threshold 55, ema 5  ,
#  inf:         Total ROI Total Trades Win Rate Avg Profit% per Trade  \
#  2018       0.0000            0      NaN                   NaN
#  2019      -1.5568            1   0.0000                   NaN
#  2020       1.0071            1 100.0000                1.0071
#  2021       0.0000            0      NaN                   NaN
#  2022       0.0000            0      NaN                   NaN
#  2023       8.7739            1 100.0000                8.7739
#  2024       0.0000            0      NaN                   NaN
#  Overall    8.2242            3  66.6667                4.8905
#
#          Avg Loss% per Trade Max Drawdown ROI/DD Ratio  \
#  2018                    NaN          NaN          NaN
#  2019                -1.5568       0.0000         -inf
#  2020                    NaN       0.0000          inf
#  2021                    NaN          NaN          NaN
#  2022                    NaN          NaN          NaN
#  2023                    NaN       0.0000          inf
#  2024                    NaN          NaN          NaN
#  Overall             -1.5568       0.0000          inf
#
#                                  Variation
#  2018     n 4, rsi 5, threshold 65, ema 35
#  2019     n 4, rsi 5, threshold 65, ema 35
#  2020     n 4, rsi 5, threshold 65, ema 35
#  2021     n 4, rsi 5, threshold 65, ema 35
#  2022     n 4, rsi 5, threshold 65, ema 35
#  2023     n 4, rsi 5, threshold 65, ema 35
#  2024     n 4, rsi 5, threshold 65, ema 35
#  Overall  n 4, rsi 5, threshold 65, ema 35  }
